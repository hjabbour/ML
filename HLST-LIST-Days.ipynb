# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
## choose either white list or read from fix entries 

fixentries= pd.read_csv('fixentries.csv')
fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
whitelist[0]
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')
# Out:
# 'GLMRUSDT'

# %%
#whitelist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/US
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

# %%
#whitelist=whitelist.lstrip()
#array = whitelist.split(",")
array = whitelist
array
wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(fixentries['Indicator'])
final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            dflive=dflive.loc[(dflive.open_time>start)]

            dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
            dflive['RSI'] = FRSI(dflive['c'])
            dflive['STRSI'] = STRSIA(dflive['c'])[0]
            dflive['STRSIK'] = STRSIA(dflive['c'])[1]
            dflive['STRSID'] = STRSIA(dflive['c'])[2]



            #print(dflive)


            lastrow = dflive.iloc[-1]
            beforelast = dflive.iloc[-2]
            now = float(lastrow.c)
            RSI = float(lastrow.RSI)
            RSIM = float(beforelast.RSI)
            STRSI = float(lastrow.STRSI)
            STRSIK = float(lastrow.STRSIK)
            STRSID = float(lastrow.STRSID)


            tuple =(symbol,RSI,RSIM,STRSI,STRSIK,STRSID)
            table.append(tuple)
            #print(table)
            del dflive
            #print("name is: ",array[0] ,alth,altl)


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','RSI','RSIM','STRSI','STRSIK','STRSID'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'RSI':('RSI'+interval),'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSID':('STRSID'+interval)})
    test.set_index(['Indicator'])
    final=final.merge(test,how='left',on=['Indicator'])
            

final
# Out:
#    Indicator      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSID3d      RSI1d  \
# 0   GLMRUSDT  17.596693  15.032261       NaN       NaN       NaN  17.596693
# 1   GLMRUSDT  17.596693  15.032261       NaN       NaN       NaN  29.648138
# 2   CAKEUSDT  29.068333  29.104068  0.244971  0.256796  0.380010  29.068333
# 3   CAKEUSDT  29.068333  29.104068  0.244971  0.256796  0.380010  36.323465
# 4     SCUSDT  35.994390  34.226473  0.398057  0.284856  0.349595  35.994390
# ..       ...        ...        ...       ...       ...       ...        ...
# 63  DENTUSDT  38.866174  37.216163  0.409701  0.289432  0.309674  42.725258
# 64   ANTUSDT  45.500707  43.283619  0.354501  0.179718  0.167965  45.500707
# 65   ANTUSDT  45.500707  43.283619  0.354501  0.179718  0.167965  44.657800
# 66  GALAUSDT  45.928616  43.976908  0.495581  0.414488  0.511704  45.928616
# 67  GALAUSDT  45.928616  43.976908  0.495581  0.414488  0.511704  46.005628
#
#        RSIM1d   STRSI1d  STRSIK1d  STRSID1d
# 0   15.032261       NaN       NaN       NaN
# 1   29.717213  0.403329  0.345748  0.215022
# 2   29.104068  0.244971  0.256796  0.380010
# 3   34.454260  0.315034  0.266068  0.186087
# 4   34.226473  0.398057  0.284856  0.349595
# ..        ...       ...       ...       ...
# 63  39.054954  0.424309  0.304808  0.197336
# 64  43.283619  0.354501  0.179718  0.167965
# 65  44.347101  0.929462  0.912221  0.747635
# 66  43.976908  0.495581  0.414488  0.511704
# 67  46.094708  0.295043  0.322388  0.245269
#
# [68 rows x 11 columns]

# %%
final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
final
# Out:
#     Indicator      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSID3d      RSI1d  \
# 1    GLMRUSDT  17.596693  15.032261       NaN       NaN       NaN  29.648138
# 3    CAKEUSDT  29.068333  29.104068  0.244971  0.256796  0.380010  36.323465
# 7   27.806505  0.228541  0.153113  0.114486
# 9   60.974958  0.841872  0.844877  0.603138
# 11  36.391245  0.296982  0.307963  0.202985
# 13  35.118108  0.320166  0.219975  0.132450
# 15  28.764211  0.140956  0.161155  0.126211
# 17  43.634766  0.269346  0.255857  0.167457
# 19  35.481267  0.138749  0.144231  0.102589
# 21  47.102377  0.792747  0.771759  0.616697
# 23  36.108966  0.300343  0.258571  0.168416
# 25  31.447456  0.279166  0.284664  0.196804
# 27  38.311646  0.590712  0.464574  0.286654
# 29  35.424374  0.288400  0.302712  0.205013
# 31  39.146335  0.473143  0.449508  0.323351
# 33  40.973444  0.541583  0.501916  0.371566
# 35  37.344833  0.083448  0.096352  0.112655
# 37  38.305966  0.524595  0.492895  0.355806
# 39  42.067189  0.357995  0.329199  0.232123
# 41  42.837774  0.584443  0.578525  0.448353
# 43  42.620922  0.741851  0.734096  0.507688
# 45  38.586954  0.411348  0.393426  0.262030
# 47  44.000434  0.568053  0.531070  0.379701
# 49  35.896424  0.538629  0.465644  0.321004
# 51  39.773250  0.461326  0.435614  0.309513
# 53  41.118520  1.000000  0.844658  0.721835
# 55  34.400014  0.348142  0.319924  0.210283
# 57  32.993845  0.362192  0.302075  0.209011
# 59  41.172306  0.562075  0.510740  0.352528
# 61  39.735694  0.630103  0.378407  0.218494
# 63  39.054954  0.424309  0.304808  0.197336
# 65  44.347101  0.929462  0.912221  0.747635
# 67  46.094708  0.295043  0.322388  0.245269

# %%
def updown (number):
    if number > 0 :
        return "UP" 
    else :
        return "DOWN"

updown8 = final.loc[:]
updown8['1dRSI'] = ((final['RSI1d'] - final['RSIM1d'])) 
updown8['1dST'] = ((final['STRSIK1d'] - final['STRSID1d']))
updown8['3dRSI'] = ((final['RSI3d'] - final['RSIM3d'])) 
updown8['3dST'] = ((final['STRSIK3d'] - final['STRSID3d']))

#updown8['2RSI'] = "UP" if updown8['2RSI'] > 0 else "down"
updown8['1dRSI']=updown8['1dRSI'].apply(updown)
updown8['3dRSI']= updown8['3dRSI'].apply(updown)
updown8['1dST']=updown8['1dST'].apply(updown)
updown8['3dST']=updown8['3dST'].apply(updown)

updownd = updown8[['Indicator','1dRSI','3dRSI','1dST','3dST']]
updownd.to_csv("updownd.csv")

RSIST = pd.read_csv("updown8.csv")
RSIST = RSIST.merge(updownd,how='left',on ='Indicator')
RSIST =RSIST[['Indicator','2RSI','4RSI','8RSI','1dRSI','3dRSI','2ST','4ST','8ST','1dST','3dST']]
RSIST
# Out:
#     Indicator  2RSI  4RSI  8RSI 1dRSI 3dRSI   2ST   4ST   8ST  1dST  3dST
# 0    GLMRUSDT    UP  DOWN  DOWN  DOWN    UP    UP  DOWN  DOWN    UP  DOWN
# 1    CAKEUSDT    UP    UP    UP    UP  DOWN    UP    UP    UP    UP  DOWN
# 2      SCUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP  DOWN
# 3     IMXUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP  DOWN
# 4     MIRUSDT  DOWN  DOWN  DOWN  DOWN    UP  DOWN  DOWN  DOWN    UP    UP
# 5     CRVUSDT    UP    UP    UP  DOWN  DOWN    UP  DOWN  DOWN    UP    UP
# 6    MOVRUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP  DOWN
# 7     RAYUSDT    UP    UP    UP  DOWN  DOWN    UP    UP  DOWN    UP  DOWN
# 8   TFUELUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP  DOWN
# 9   AUDIOUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP  DOWN
# 10    HNTUSDT    UP    UP    UP  DOWN    UP    UP  DOWN  DOWN    UP  DOWN
# 11   VTHOUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP  DOWN
# 12    KSMUSDT    UP    UP    UP  DOWN  DOWN    UP  DOWN  DOWN    UP  DOWN
# 13    SRMUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP  DOWN
# 14    WINUSDT    UP    UP    UP  DOWN    UP    UP  DOWN  DOWN    UP  DOWN
# 15   NEARUSDT    UP    UP    UP  DOWN  DOWN    UP  DOWN  DOWN    UP    UP
# 16    OMGUSDT    UP    UP    UP  DOWN    UP    UP  DOWN  DOWN    UP  DOWN
# 17    GRTUSDT    UP    UP    UP    UP  DOWN    UP    UP  DOWN  DOWN  DOWN
# 18  1INCHUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP    UP
# 19    ZRXUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP  DOWN
# 20    XLMUSDT    UP    UP    UP  DOWN  DOWN    UP  DOWN  DOWN    UP    UP
# 21   ALGOUSDT    UP    UP    UP  DOWN  DOWN    UP  DOWN  DOWN    UP    UP
# 22    ZILUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP  DOWN
# 23   WAXPUSDT    UP    UP    UP  DOWN    UP    UP  DOWN  DOWN    UP  DOWN
# 24   COTIUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP    UP
# 25    VETUSDT    UP    UP    UP  DOWN    UP    UP  DOWN  DOWN    UP  DOWN
# 26     ARUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP    UP
# 27   ROSEUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP    UP
# 28  SUSHIUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP  DOWN
# 29   FLUXUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP  DOWN
# 30    FILUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP  DOWN
# 31   DENTUSDT    UP    UP    UP    UP    UP    UP    UP  DOWN    UP  DOWN
# 32    ANTUSDT    UP    UP    UP    UP    UP    UP  DOWN  DOWN    UP    UP
# 33   GALAUSDT    UP    UP    UP  DOWN    UP    UP  DOWN  DOWN    UP  DOWN

# %%
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1)]
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1) & (AllTime['RSI'] > AllTime['RSIM'])]
#drop = final.loc[ (((final['RSI8h'] < final['RSIM8h']) | (final['STRSIK4h'] <= final['STRSID4h'])))]
#drop = final.loc[(final['RSI2h'] > final['RSIM2h'])]
#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK2h'] < final['STRSID2h']))]


#1day going uo
#drop = final.loc[((final['RSI1d'] > final['RSIM1d']) & (final['STRSIK1d'] > final['STRSID1d']))]

# 1 day going down
#drop = final.loc[((final['RSI1d'] < final['RSIM1d']) & (final['STRSIK1d'] < final['STRSID1d']))]


# 3 days going down

#drop = final.loc[((final['RSI3d'] < final['RSIM3d']) & (final['STRSIK3d'] < final['STRSID3d']))]

# 1 day going down 


#drop = final.loc[((final['RSI1d'] < final['RSIM1d']) & (final['STRSIK1d'] < final['STRSID1d']))]


# 1 day going up

drop = final.loc[((final['RSI1d'] > final['RSIM1d']) & (final['STRSIK1d'] > final['STRSID1d']))]

# 1 day going down

#drop = final.loc[((final['RSI1d'] < final['RSIM1d']) & (final['STRSIK1d'] < final['STRSID1d']))]


# 3 days going up
#drop = final.loc[((final['RSI3d'] > final['RSIM3d']) | (final['STRSIK3d'] > final['STRSID3d']))]
#drop = final.loc[((final['RSI3d'] > final['RSIM3d']) & (final['STRSIK3d'] > final['STRSID3d']))]




#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']))]
#drop = final.loc[((final['RSI4h'] > final['RSIM4h']) & (final['STRSIK4h'] > final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']))]
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']) & (final['RSI8h'] < final['RSIM8h']) )]


#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK4h'] > 0.9))]


#drop = final.loc[((final['STRSI12h'] > 0.7))]

#drop = final.loc[ (final['RSI1h'] < final['RSIM1h'])]

#drop = AllTime.loc[((AllTime['RSI'] > AllTime['RSIM']) | (AllTime['STRSIK'] >= AllTime['STRSID']))]

#drop = AllTime.loc[ (AllTime['STRSI'] < 0.9) & (AllTime['STRSIK'] > AllTime['STRSID'])]



#drop = AllTime.loc[(AllTime['MONTH'] < 70)]
#drop = AllTime.loc[(AllTime['MONTH'] < 80)&(AllTime['2MONTH'] < 70)&(AllTime['ALLTIME'] < 40)]
#drop = AllTime.loc[(AllTime['MONTH'] <70)&(AllTime['2MONTH'] > (AllTime['3MONTH']))]

#drop = drop.sort_values(by=['RSI1h'],ascending=False,inplace = True)
#drop = drop.loc[(drop['ALLTIME'] < drop['3MONTH'])]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','Current']]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','STRSI']]

drop

print("Low  RSI")
print(drop.iloc[0:60,0:14])
print(drop.iloc[60:110,])
print(drop.iloc[110:160,])
#del drop
# Out:
# Low  RSI
#     Indicator      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSID3d      RSI1d  \
# 3    CAKEUSDT  29.068333  29.104068  0.244971  0.256796  0.380010  36.323465
# 5      SCUSDT  35.994390  34.226473  0.398057  0.284856  0.349595  41.318309
# 7     IMXUSDT  23.595346  22.616169       NaN       NaN       NaN  29.747755
# 13   MOVRUSDT  26.217891  24.747277  0.714468  0.635405  0.665713  38.064774
# 17  TFUELUSDT  43.669187  40.624919  0.623700  0.541820  0.632444  43.938811
# 19  AUDIOUSDT  31.296184  31.008177  0.231081  0.206109  0.276495  35.998801
# 23   VTHOUSDT  33.229124  31.126533  0.608186  0.529772  0.602881  37.796733
# 27    SRMUSDT  33.885507  32.388934  0.567284  0.455447  0.519089  40.645009
# 37  1INCHUSDT  33.939912  33.320150  0.310402  0.179545  0.157237  39.515476
# 39    ZRXUSDT  38.459296  38.270462  0.567936  0.519367  0.557663  42.454021
# 45    ZILUSDT  34.142064  33.945045  0.478167  0.409688  0.423013  38.968997
# 49   COTIUSDT  38.511042  37.791788  0.197399  0.091543  0.048590  37.679764
# 53     ARUSDT  38.981608  38.287050  0.500927  0.303651  0.227575  46.066380
# 55   ROSEUSDT  40.458817  40.405012  0.080878  0.041534  0.018703  34.563378
# 57  SUSHIUSDT  33.351598  33.257096  0.014268  0.004756  0.067933  34.684250
# 59   FLUXUSDT  44.046995  43.760309       NaN       NaN       NaN  42.625616
# 61    FILUSDT  34.871491  31.509756  0.912096  0.741454  0.761865  44.810192
# 63   DENTUSDT  38.866174  37.216163  0.409701  0.289432  0.309674  42.725258
# 65    ANTUSDT  45.500707  43.283619  0.354501  0.179718  0.167965  44.657800
#
#        RSIM1d   STRSI1d  STRSIK1d  STRSID1d
# 3   34.454260  0.315034  0.266068  0.186087
# 5   40.507619  0.604013  0.515794  0.344853
# 7   27.806505  0.228541  0.153113  0.114486
# 13  35.118108  0.320166  0.219975  0.132450
# 17  43.634766  0.269346  0.255857  0.167457
# 19  35.481267  0.138749  0.144231  0.102589
# 23  36.108966  0.300343  0.258571  0.168416
# 27  38.311646  0.590712  0.464574  0.286654
# 37  38.305966  0.524595  0.492895  0.355806
# 39  42.067189  0.357995  0.329199  0.232123
# 45  38.586954  0.411348  0.393426  0.262030
# 49  35.896424  0.538629  0.465644  0.321004
# 53  41.118520  1.000000  0.844658  0.721835
# 55  34.400014  0.348142  0.319924  0.210283
# 57  32.993845  0.362192  0.302075  0.209011
# 59  41.172306  0.562075  0.510740  0.352528
# 61  39.735694  0.630103  0.378407  0.218494
# 63  39.054954  0.424309  0.304808  0.197336
# 65  44.347101  0.929462  0.912221  0.747635
# Empty DataFrame
# Columns: [Indicator, RSI3d, RSIM3d, STRSI3d, STRSIK3d, STRSID3d, RSI1d, RSIM1d, STRSI1d, STRSIK1d, STRSID1d]
# Index: []
# Empty DataFrame
# Columns: [Indicator, RSI3d, RSIM3d, STRSI3d, STRSIK3d, STRSID3d, RSI1d, RSIM1d, STRSI1d, STRSIK1d, STRSID1d]
# Index: []

# %%
#save = drop[['Indicator','RSI','STRSI']]
#save = save.rename(columns={'STRSI': 'STRSI1','RSI':'RSI1'})
#save
#save.to_csv("strsi1KD.csv")
RSITABLE = drop[['Indicator', 'RSI1d', 'RSIM1d','RSI3d', 'RSIM3d']]
sort1 = RSITABLE.sort_values(by=['RSI3d'],ascending=True,inplace = True)


RSITABLE
# Out:
# /Users/hjabbour/opt/anaconda3/envs/cryptodev/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Empty DataFrame
# Columns: [Indicator, RSI1d, RSIM1d, RSI3d, RSIM3d]
# Index: []

# %%
STCHTABLE = drop[['Indicator','STRSIK1d', 'STRSID1d','STRSIK3d', 'STRSID3d']]
STCHTABLE
# Out:
# Empty DataFrame
# Columns: [Indicator, STRSIK1d, STRSID1d, STRSIK3d, STRSID3d]
# Index: []

# %%
#save
