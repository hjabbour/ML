# %% [markdown]
# # Read STRSI MACD file

# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta

# %%
MLDATA = pd.read_csv('MLSTRSIMACDBTTOP.csv')

# %%
MLDATA.tail()
# Out:
#      Unnamed: 0  Indicator       O5m        C5m        H5m        L5m  \
# 320         666  THETAUSDT     1.246     1.2390     1.2460     1.2360
# 321         677   MANAUSDT     0.723     0.7144     0.7241     0.7142
# 322         688   PAXGUSDT  1856.000  1858.0000  1858.0000  1856.0000
# 323         699    INJUSDT     1.886     1.8790     1.8880     1.8790
# 324         710   PERPUSDT     1.200     1.2000     1.2000     1.2000
#
#              V5m       OM5m       CM5m       HM5m  ...  SMA200M1w     MACD1w  \
# 320   92491.2000     1.2570     1.2460     1.2660  ...        NaN  -1.798495
# 321  305898.0000     0.7309     0.7226     0.7336  ...        NaN  -0.689371
# 322       7.5302  1859.0000  1858.0000  1861.0000  ...        NaN  22.137101
# 323    1929.0000     1.9120     1.8830     1.9150  ...        NaN  -3.120525
# 324    1175.7300     1.2100     1.2000     1.2200  ...        NaN  -4.426083
#
#      MACDSIGNAL1w    MACDM1w  MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w  \
# ...

# %%
MLDATA.head()
# Out:
#    Unnamed: 0 Indicator       O5m       C5m       H5m       L5m          V5m  \
# 0          10  ANKRUSDT   0.03149   0.03292   0.03306   0.03132   1492990.40
# 1          21  AVAXUSDT  28.34000  29.83000  29.85000  28.22000     80469.57
# 2          32  WAXPUSDT   0.10390   0.10780   0.10870   0.10390    400233.00
# 3          43  REEFUSDT   0.00350   0.00368   0.00368   0.00350  19295055.00
# 4          54  LINKUSDT   6.70000   6.93000   6.93000   6.68000    109406.14
#
#        OM5m      CM5m      HM5m  ...  SMA200M1w     MACD1w  MACDSIGNAL1w  \
# 0   0.03187   0.03141   0.03200  ...        NaN  -0.025720     -0.017258
# 1  28.24000  28.34000  28.40000  ...        NaN -15.683587     -4.073532
# 2   0.10430   0.10370   0.10460  ...        NaN  -0.137762     -0.102387
# 3   0.00355   0.00351   0.00355  ...        NaN  -0.007438     -0.006759
# 4   6.73000   6.70000   6.76000  ...        NaN  -7.520805     -6.279995
#
# ...

# %%
MLDATA
# Out:
#      Unnamed: 0  Indicator         O5m         C5m         H5m         L5m  \
# 0            10   ANKRUSDT     0.03149     0.03292     0.03306     0.03132
# 1            21   AVAXUSDT    28.34000    29.83000    29.85000    28.22000
# 2            32   WAXPUSDT     0.10390     0.10780     0.10870     0.10390
# 3            43   REEFUSDT     0.00350     0.00368     0.00368     0.00350
# 4            54   LINKUSDT     6.70000     6.93000     6.93000     6.68000
# ..          ...        ...         ...         ...         ...         ...
# 320         666  THETAUSDT     1.24600     1.23900     1.24600     1.23600
# 321         677   MANAUSDT     0.72300     0.71440     0.72410     0.71420
# 322         688   PAXGUSDT  1856.00000  1858.00000  1858.00000  1856.00000
# 323         699    INJUSDT     1.88600     1.87900     1.88800     1.87900
# 324         710   PERPUSDT     1.20000     1.20000     1.20000     1.20000
#
# ...
