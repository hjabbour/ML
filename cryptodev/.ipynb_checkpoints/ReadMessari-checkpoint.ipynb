# %%
import pandas as pd
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
#from selenium.webdriver.firefox.options import Options
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# # Read using BS

# %%
options = Options()
options.headless = True

# %%
#driver = webdriver.Chrome(options=options)
driver = webdriver.Chrome()

# %%
URL = "https://messari.io/screener/closest-from-ath-DFF36925"
#URL = "https://lunarcrush.com/markets?metric=social_volume"
driver.get(URL)
driver.implicitly_wait(60)

#page = requests.get(URL)
soup = BeautifulSoup(driver.page_source, 'lxml')


#soup = BeautifulSoup(page.content, "html.parser")

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
#print(soup.prettify())
tables = soup.find_all('table')
divs=soup.find_all('div', attrs={'class': 'jss186'})
#rally=soup.find('Rally')
#print(tables)
#print(divs)

# %%
data = []
for title in soup.find_all('div', attrs={'class': 'jss186'}):
     data.append(list(title.stripped_strings))

# %%
panadas=pd.DataFrame(data)
panadas
# Out:
#       0                                   1  2        3              4   \
# 0   1547                           TaleCraft  ·    CRAFT         $0.527
# 1   1548                        MetaverseAir  ·     MVRS      $0.000760
# 2   1549                           BNS Token  ·      BNS        $0.0490
# 3   1550                      Ethereum Money  ·   ETHMNY     $0.0000290
# 4   1551                                 B21  ·      B21        $0.0312
# 5   1552  Unicly Genesis MoonCats Collection  ·     UGMC         $0.221
# 6   1553                             NoahArk  ·      NRK         $0.969
# 7   1554                      MUD Guild Game  ·      MGG         $0.557
# 8   1555                           hi Dollar  ·       HI         $0.141
# 9   1556                           Front Row  ·      FRR         $0.203
# 10  1557                                 MVL  ·      MVL       $0.00923
# 11  1558                            Mindsync  ·      MAI        $0.0184
# 12  1559                              KRAUSE  ·  $KRAUSE         $0.557
# 13  1560                         Bolt Dollar  ·      BTD        $0.0475
# 14  1561                    Platypus Finance  ·      PTP          $3.91
# 15  1562              Sunder Goverance Token  ·   SUNDER        $0.0194
# 16  1563                             Nemesis  ·      NMS       $0.00645
# 17  1564                         EthereumMax  ·     EMAX  $0.0000000177
# 18  1565                             pBTC35A  ·  PBTC35A         $80.04
# 19  1566                               Creds  ·   $CREDS         $0.400
# 20  1567                         YVS Finance  ·      YVS         $0.120
# 21  1568                      SingularityDAO  ·     SDAO          $1.00
# 22  1569                           Meta Pets  ·       MP   $0.000000876
# 23  1570                        Wrapped CELO  ·    WCELO          $4.04
# 24  1571              Fantums of Opera Token  ·      FOO        $0.0693
# 25  1572                               KROWN  ·      KRW     $0.0000793
# 26  1573                               iFARM  ·    IFARM        $138.79
# 27  1574         Reflexer Ungovernance Token  ·      FLX        $156.69
# 28  1575                    Creator Platform  ·      CTR        $0.0389
# 29  1576                     Vikings Finance  ·      VAL          $7.39
# 30  1577            Bitpanda Ecosystem Token  ·     BEST         $0.862
# 31  1578                        Yeld Finance  ·     YELD          $3.80
# 32  1579              r/CryptoCurrency Moons  ·     MOON        $0.0814
# 33  1580      Bitcoin Volatility Index Token  ·     BTCV         $94.99
# 34  1581                               Radix  ·      XRD             --
# 35  1582                      Yoshi.exchange  ·    YOSHI          $1.34
# 36  1583                  KONGZ Vault (NFTX)  ·    KONGZ     $85,790.71
#
#         5   6          7   8   9                         10    11
# 0   -5.37%  --      $7.97  --  --                        --    --
# 1       --  --      $0.00  --  --                        --    --
# 2   -4.66%  --     $25.02  --  --                        --    --
# 3       --  --     $56.84  --  --                        --    --
# 4   -0.17%  --  $1,436.96  --  --                        --    --
# 5       --  --      $0.00  --  --                        --    --
# 6       --  --    $524.28  --  --                        --    --
# 7       --  --    $250.76  --  --                        --    --
# 8       --  --      $0.00  --  --                        --    --
# 9       --  --      $0.00  --  --                        --    --
# 10      --  --     $81.19  --  --                        --    --
# 11      --  --    $432.99  --  --                        --    --
# 12      --  --    $842.83  --  --                        --    --
# 13      --  --      $0.00  --  --                        --    --
# 14      --  --    $249.58  --  --                        --    --
# 15      --  --    $821.83  --  --                        --    --
# 16      --  --  $5,649.57  --  --                        --    --
# 17      --  --     $21.57  --  --                        --    --
# 18      --  --  $3,567.36  --  --                        --    --
# 19      --  --      $0.00  --  --                        --    --
# 20      --  --      $0.00  --  --                        --    --
# 21      --  --    $968.38  --  --                        --    --
# 22      --  --    $448.10  --  --                        --    --
# 23      --  --      $0.00  --  --                        --    --
# 24  +2.36%  --      $0.00  --  --                        --    --
# 25      --  --      $0.00  --  --                        --    --
# 26      --  --  $1,755.63  --  --                        --    --
# 27      --  --    $223.24  --  --                        --    --
# 28      --  --    $590.29  --  --                        --    --
# 29      --  --      $0.00  --  --                        --    --
# 30      --  --     $25.85  --  --                        --    --
# 31      --  --    $148.42  --  --                        --    --
# 32      --  --     $22.34  --  --                        --    --
# 33      --  --    $997.35  --  --                        --    --
# 34      --  --         --  --  --  Smart Contract Platforms  None
# 35  -4.41%  --      $0.00  --  --                        --    --
# 36      --  --    $199.91  --  --                        --    --

# %% [markdown]
# # Read web & HTML data

# %%
#pd.read_html('https://messari.io/screener/closest-from-ath-DFF36925')
#wiki_data = pd.read_html('https://messari.io/screener/closest-from-ath-DFF36925')

# %%
#wiki_data = pd.read_html('https://en.wikipedia.org/wiki/Lebanon', match='Christian')
#wiki_data[0].head()
