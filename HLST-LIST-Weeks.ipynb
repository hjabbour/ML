# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
## choose either white list or read from fix entries 

fixentries= pd.read_csv('fixentries.csv')
fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
whitelist[0]
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')
# Out:
# 'CAKEUSDT'

# %%
#whitelist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, ADADOWN/USDT, BOND/USDT, DCR/USDT, DOTDOWN/USDT, GNO/USDT, NBS/USDT, SXPUP/USDT, EOSDOWN/USDT, YFIUP/USDT, RIF/USDT, LTCDOWN/USDT, XLMUP/USDT, YFIDOWN/USDT, LINKDOWN/USDT, TRXUP/USDT, BCHUP/USDT, XTZUP/USDT, SXPDOWN/USDT, UNIDOWN/USDT, XTZDOWN/USDT, BCHDOWN/USDT, TRXDOWN/USDT, XLMDOWN/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
#whitelist =str(fixentries['Indicator'])

startdate = '2020-01-01'
enddate = '2022-02-22'
intervals = ['1w']
#intervals = ['8h']

# %%
def updown (number):
    if number > 0 :
        return "UP" 
    else :
        return "DOWN"

def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

# %%
#whitelist=whitelist.lstrip()
#array = whitelist.split(",")
array = whitelist
array
wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(fixentries['Indicator'])
final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            #dflive=dflive.loc[(dflive.open_time>start)]
            if dflive.size > 300 :
                # if level
                
                

                dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
                dflive['RSI'] = FRSI(dflive['c'])
                dflive['STRSI'] = STRSIA(dflive['c'])[0]
                dflive['STRSIK'] = STRSIA(dflive['c'])[1]
                dflive['STRSID'] = STRSIA(dflive['c'])[2]



                #print(dflive)


                lastrow = dflive.iloc[-1]
                beforelast = dflive.iloc[-2]
                now = float(lastrow.c)
                RSI = float(lastrow.RSI)
                RSIM = float(beforelast.RSI)
                STRSI = float(lastrow.STRSI)
                STRSIK = float(lastrow.STRSIK)
                STRSID = float(lastrow.STRSID)
                STRSIKM = float(beforelast.STRSIK)
                STRSIDM = float(beforelast.STRSID)



                tuple =(symbol,RSI,RSIM,STRSI,STRSIK,STRSID,STRSIKM,STRSIDM)
                table.append(tuple)
                #print(table)
                del dflive
            else:
                pass
            #print("name is: ",array[0] ,alth,altl)


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','RSI','RSIM','STRSI','STRSIK','STRSIKM','STRSID','STRSIDM'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'RSI':('RSI'+interval),'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSIKM':('STRSIKM'+interval),'STRSID':('STRSID'+interval),'STRSIDM':('STRSIDM'+interval)})
    test.set_index(['Indicator'])
    final=final.merge(test,how='left',on=['Indicator'])
            

final
# Out:
#     Indicator      RSI1w     RSIM1w   STRSI1w      STRSIK1w     STRSIKM1w  \
# 0    CAKEUSDT  34.574207  34.729201  0.000000  0.000000e+00  3.040069e-02
# 1    GLMRUSDT        NaN        NaN       NaN           NaN           NaN
# 2      SCUSDT  38.430515  37.458467  0.097225  3.240825e-02  2.130606e-02
# 3     HNTUSDT  43.533866  43.772754  0.000000  0.000000e+00  3.546030e-03
# 4   TFUELUSDT  39.822592  39.531863  0.360593  3.497878e-01  3.824239e-01
# 5   AUDIOUSDT  37.844121  37.553721  0.023831  7.943546e-03  2.623291e-02
# 6     MIRUSDT  37.923532  36.255310  1.000000  8.041725e-01  5.224569e-01
# 7     ANTUSDT  45.424184  45.864955  0.000000  5.676941e-02  8.863775e-02
# 8    ALGOUSDT  35.366742  35.629716  0.000000  0.000000e+00  0.000000e+00
# 9   1INCHUSDT  36.687928  36.611796  0.007795  2.598355e-03  4.566997e-03
# 10    KSMUSDT  37.763245  36.961556  0.082547  3.394739e-02  1.907704e-02
# 11  SUSHIUSDT  35.006615  34.938659  0.004985  1.661661e-03  2.630439e-02
# 12    XLMUSDT  35.773226  35.122235  0.060607  2.334907e-02  5.463410e-02
# 13   COTIUSDT  38.668920  38.612756  0.003747  1.249113e-03  3.693946e-03
# 14    WINUSDT  39.745487  39.689132  0.137351  8.575345e-02  4.954694e-02
# 15    OMGUSDT  42.076447  39.750329  0.385099  1.283664e-01  5.075449e-02
# 16   GALAUSDT  50.542695  50.479112       NaN           NaN           NaN
# 17   FLUXUSDT        NaN        NaN       NaN           NaN           NaN
# 18    FILUSDT  33.071478  33.448810  0.042294  8.945338e-02  9.977206e-02
# 19    VETUSDT  37.300629  37.787331  0.041675  4.526101e-02  3.642502e-02
# 20   SCRTUSDT        NaN        NaN       NaN           NaN           NaN
# 21   WAXPUSDT  44.396698  43.927098  0.035101           NaN           NaN
# 22    ZILUSDT  36.549004  35.794077  0.084077  2.802563e-02  5.134354e-02
# 23   REEFUSDT  35.374209  35.411067  0.000000  0.000000e+00  2.596583e-02
# 24   LINKUSDT  37.870491  38.161373  0.000000  1.480297e-16  2.590520e-16
# 25   ROSEUSDT  47.111946  47.989592  0.025211  3.052820e-02  1.755096e-02
# 26    CRVUSDT  40.756585  41.094297  0.000000  0.000000e+00  0.000000e+00
# 27   DENTUSDT  41.214177  40.482584  0.087298  2.909927e-02  3.642795e-02
# 28    ONEUSDT  41.557223  41.726787  0.000000  0.000000e+00  1.412405e-03
# 29   BANDUSDT  37.523908  38.463198  0.342071  3.190007e-01  3.082954e-01
# 30    RAYUSDT  39.338591  39.579914  0.001311  5.843016e-03           NaN
# 31   VTHOUSDT  34.218527  34.863281  0.000000  2.009557e-02  1.868224e-02
# 32    ZRXUSDT  37.511134  36.831486  0.073083  3.896973e-02  7.090345e-02
#
#         STRSID1w  STRSIDM1w
# 0   2.432432e-02   0.067145
# 1            NaN        NaN
# 2   1.108553e-03   0.040003
# 3   0.000000e+00   0.023855
# 4   3.714366e-01   0.421500
# 5   1.380646e-02   0.061603
# 6   5.215570e-01   0.313891
# 7   8.930195e-02   0.138478
# 8   0.000000e+00   0.010172
# 9   0.000000e+00   0.018680
# 10  6.431592e-03   0.027377
# 11  1.916524e-02   0.067119
# 12  3.987171e-02   0.108635
# 13  0.000000e+00   0.025735
# 14  4.039453e-02   0.041583
# 15  9.251859e-18   0.025362
# 16           NaN        NaN
# 17           NaN        NaN
# 18  1.046062e-01   0.107865
# 19  3.487047e-02   0.045049
# 20           NaN        NaN
# 21           NaN        NaN
# 22  3.360779e-02   0.101283
# 23  2.124526e-02   0.058765
# 24  1.480297e-16   0.011625
# 25  2.212469e-02   0.019470
# 26  0.000000e+00   0.010669
# 27  2.154849e-02   0.066036
# 28  0.000000e+00   0.017087
# 29  3.445522e-01   0.292470
# 30  5.405915e-03        NaN
# 31  2.009557e-02   0.021897
# 32  5.918480e-02   0.117706

# %%
final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
final = final.dropna(subset=['RSI1w'])
final
# Out:
#     Indicator      RSI1w     RSIM1w   STRSI1w      STRSIK1w     STRSIKM1w  \
# 0    CAKEUSDT  34.574207  34.729201  0.000000  0.000000e+00  3.040069e-02
# 2      SCUSDT  38.430515  37.458467  0.097225  3.240825e-02  2.130606e-02
# 3     HNTUSDT  43.533866  43.772754  0.000000  0.000000e+00  3.546030e-03
# 4   TFUELUSDT  39.822592  39.531863  0.360593  3.497878e-01  3.824239e-01
# 5   AUDIOUSDT  37.844121  37.553721  0.023831  7.943546e-03  2.623291e-02
# 6     MIRUSDT  37.923532  36.255310  1.000000  8.041725e-01  5.224569e-01
# 7     ANTUSDT  45.424184  45.864955  0.000000  5.676941e-02  8.863775e-02
# 8    ALGOUSDT  35.366742  35.629716  0.000000  0.000000e+00  0.000000e+00
# 9   1INCHUSDT  36.687928  36.611796  0.007795  2.598355e-03  4.566997e-03
# 10    KSMUSDT  37.763245  36.961556  0.082547  3.394739e-02  1.907704e-02
# 11  SUSHIUSDT  35.006615  34.938659  0.004985  1.661661e-03  2.630439e-02
# 12    XLMUSDT  35.773226  35.122235  0.060607  2.334907e-02  5.463410e-02
# 13   COTIUSDT  38.668920  38.612756  0.003747  1.249113e-03  3.693946e-03
# 14    WINUSDT  39.745487  39.689132  0.137351  8.575345e-02  4.954694e-02
# 15    OMGUSDT  42.076447  39.750329  0.385099  1.283664e-01  5.075449e-02
# 16   GALAUSDT  50.542695  50.479112       NaN           NaN           NaN
# 18    FILUSDT  33.071478  33.448810  0.042294  8.945338e-02  9.977206e-02
# 19    VETUSDT  37.300629  37.787331  0.041675  4.526101e-02  3.642502e-02
# 21   WAXPUSDT  44.396698  43.927098  0.035101           NaN           NaN
# 22    ZILUSDT  36.549004  35.794077  0.084077  2.802563e-02  5.134354e-02
# 23   REEFUSDT  35.374209  35.411067  0.000000  0.000000e+00  2.596583e-02
# 24   LINKUSDT  37.870491  38.161373  0.000000  1.480297e-16  2.590520e-16
# 25   ROSEUSDT  47.111946  47.989592  0.025211  3.052820e-02  1.755096e-02
# 26    CRVUSDT  40.756585  41.094297  0.000000  0.000000e+00  0.000000e+00
# 27   DENTUSDT  41.214177  40.482584  0.087298  2.909927e-02  3.642795e-02
# 28    ONEUSDT  41.557223  41.726787  0.000000  0.000000e+00  1.412405e-03
# 29   BANDUSDT  37.523908  38.463198  0.342071  3.190007e-01  3.082954e-01
# 30    RAYUSDT  39.338591  39.579914  0.001311  5.843016e-03           NaN
# 31   VTHOUSDT  34.218527  34.863281  0.000000  2.009557e-02  1.868224e-02
# 32    ZRXUSDT  37.511134  36.831486  0.073083  3.896973e-02  7.090345e-02
#
#         STRSID1w  STRSIDM1w
# 0   2.432432e-02   0.067145
# 2   1.108553e-03   0.040003
# 3   0.000000e+00   0.023855
# 4   3.714366e-01   0.421500
# 5   1.380646e-02   0.061603
# 6   5.215570e-01   0.313891
# 7   8.930195e-02   0.138478
# 8   0.000000e+00   0.010172
# 9   0.000000e+00   0.018680
# 10  6.431592e-03   0.027377
# 11  1.916524e-02   0.067119
# 12  3.987171e-02   0.108635
# 13  0.000000e+00   0.025735
# 14  4.039453e-02   0.041583
# 15  9.251859e-18   0.025362
# 16           NaN        NaN
# 18  1.046062e-01   0.107865
# 19  3.487047e-02   0.045049
# 21           NaN        NaN
# 22  3.360779e-02   0.101283
# 23  2.124526e-02   0.058765
# 24  1.480297e-16   0.011625
# 25  2.212469e-02   0.019470
# 26  0.000000e+00   0.010669
# 27  2.154849e-02   0.066036
# 28  0.000000e+00   0.017087
# 29  3.445522e-01   0.292470
# 30  5.405915e-03        NaN
# 31  2.009557e-02   0.021897
# 32  5.918480e-02   0.117706

# %%
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1)]
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1) & (AllTime['RSI'] > AllTime['RSIM'])]
#drop = final.loc[ (((final['RSI8h'] < final['RSIM8h']) | (final['STRSIK4h'] <= final['STRSID4h'])))]
#drop = final.loc[(final['RSI2h'] > final['RSIM2h'])]
#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK2h'] < final['STRSID2h']))]


#1day going uo
#drop = final.loc[((final['RSI1d'] > final['RSIM1d']) & (final['STRSIK1d'] > final['STRSID1d']))]

# 1 day going down
#drop = final.loc[((final['RSI1d'] < final['RSIM1d']) & (final['STRSIK1d'] < final['STRSID1d']))]


# 3 days going down

#drop = final.loc[((final['RSI3d'] < final['RSIM3d']) & (final['STRSIK3d'] < final['STRSID3d']))]

# 1 day going down 


#drop = final.loc[((final['RSI1d'] < final['RSIM1d']) & (final['STRSIK1d'] < final['STRSID1d']))]


# 1 week going up

#drop = final.loc[((final['RSI1w'] > final['RSIM1w']) & (final['STRSIK1w'] > final['STRSID1w']))]

# 1 week  going up

drop = final.loc[((final['RSI1w'] > final['RSIM1w']) | (final['STRSIK1w'] > final['STRSID1w']) | (final['STRSIK1w'] > final['STRSIKM1w']))]

#drop = final.loc[((final['RSI1w'] > final['RSIM1w']) & (final['STRSIK1w'] > final['STRSID1w']))]

#drop = final.loc[((final['RSI1d'] < final['RSIM1d']) & (final['STRSIK1d'] < final['STRSID1d']))]


# 3 days going up
#drop = final.loc[((final['RSI3d'] > final['RSIM3d']) | (final['STRSIK3d'] > final['STRSID3d']))]
#drop = final.loc[((final['RSI3d'] > final['RSIM3d']) & (final['STRSIK3d'] > final['STRSID3d']))]




#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']))]
#drop = final.loc[((final['RSI4h'] > final['RSIM4h']) & (final['STRSIK4h'] > final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']))]
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']) & (final['RSI8h'] < final['RSIM8h']) )]


#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK4h'] > 0.9))]


#drop = final.loc[((final['STRSI12h'] > 0.7))]

#drop = final.loc[ (final['RSI1h'] < final['RSIM1h'])]

#drop = AllTime.loc[((AllTime['RSI'] > AllTime['RSIM']) | (AllTime['STRSIK'] >= AllTime['STRSID']))]

#drop = AllTime.loc[ (AllTime['STRSI'] < 0.9) & (AllTime['STRSIK'] > AllTime['STRSID'])]



#drop = AllTime.loc[(AllTime['MONTH'] < 70)]
#drop = AllTime.loc[(AllTime['MONTH'] < 80)&(AllTime['2MONTH'] < 70)&(AllTime['ALLTIME'] < 40)]
#drop = AllTime.loc[(AllTime['MONTH'] <70)&(AllTime['2MONTH'] > (AllTime['3MONTH']))]

#drop = drop.sort_values(by=['RSI1h'],ascending=False,inplace = True)
#drop = drop.loc[(drop['ALLTIME'] < drop['3MONTH'])]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','Current']]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','STRSI']]

drop

print("Low  RSI")
print(drop.iloc[0:60,0:14])
print(drop.iloc[60:110,])
print(drop.iloc[110:160,])
#del drop
# Out:
# Low  RSI
#     Indicator      RSI1w     RSIM1w   STRSI1w  STRSIK1w  STRSIKM1w  \
# 2      SCUSDT  38.430515  37.458467  0.097225  0.032408   0.021306
# 4   TFUELUSDT  39.822592  39.531863  0.360593  0.349788   0.382424
# 5   AUDIOUSDT  37.844121  37.553721  0.023831  0.007944   0.026233
# 6     MIRUSDT  37.923532  36.255310  1.000000  0.804172   0.522457
# 9   1INCHUSDT  36.687928  36.611796  0.007795  0.002598   0.004567
# 10    KSMUSDT  37.763245  36.961556  0.082547  0.033947   0.019077
# 11  SUSHIUSDT  35.006615  34.938659  0.004985  0.001662   0.026304
# 12    XLMUSDT  35.773226  35.122235  0.060607  0.023349   0.054634
# 13   COTIUSDT  38.668920  38.612756  0.003747  0.001249   0.003694
# 14    WINUSDT  39.745487  39.689132  0.137351  0.085753   0.049547
# 15    OMGUSDT  42.076447  39.750329  0.385099  0.128366   0.050754
# 16   GALAUSDT  50.542695  50.479112       NaN       NaN        NaN
# 19    VETUSDT  37.300629  37.787331  0.041675  0.045261   0.036425
# 21   WAXPUSDT  44.396698  43.927098  0.035101       NaN        NaN
# 22    ZILUSDT  36.549004  35.794077  0.084077  0.028026   0.051344
# 25   ROSEUSDT  47.111946  47.989592  0.025211  0.030528   0.017551
# 27   DENTUSDT  41.214177  40.482584  0.087298  0.029099   0.036428
# 29   BANDUSDT  37.523908  38.463198  0.342071  0.319001   0.308295
# 30    RAYUSDT  39.338591  39.579914  0.001311  0.005843        NaN
# 31   VTHOUSDT  34.218527  34.863281  0.000000  0.020096   0.018682
# 32    ZRXUSDT  37.511134  36.831486  0.073083  0.038970   0.070903
#
#         STRSID1w  STRSIDM1w
# 2   1.108553e-03   0.040003
# 4   3.714366e-01   0.421500
# 5   1.380646e-02   0.061603
# 6   5.215570e-01   0.313891
# 9   0.000000e+00   0.018680
# 10  6.431592e-03   0.027377
# 11  1.916524e-02   0.067119
# 12  3.987171e-02   0.108635
# 13  0.000000e+00   0.025735
# 14  4.039453e-02   0.041583
# 15  9.251859e-18   0.025362
# 16           NaN        NaN
# 19  3.487047e-02   0.045049
# 21           NaN        NaN
# 22  3.360779e-02   0.101283
# 25  2.212469e-02   0.019470
# 27  2.154849e-02   0.066036
# 29  3.445522e-01   0.292470
# 30  5.405915e-03        NaN
# 31  2.009557e-02   0.021897
# 32  5.918480e-02   0.117706
# Empty DataFrame
# Columns: [Indicator, RSI1w, RSIM1w, STRSI1w, STRSIK1w, STRSIKM1w, STRSID1w, STRSIDM1w]
# Index: []
# Empty DataFrame
# Columns: [Indicator, RSI1w, RSIM1w, STRSI1w, STRSIK1w, STRSIKM1w, STRSID1w, STRSIDM1w]
# Index: []

# %%
#save
