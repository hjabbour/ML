# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json

#Data Source(Pandas Data Reader)

# %%
## draft 
import os
live = pd.to_datetime('today')
start = pd.to_datetime('2021-02-01')
end = pd.to_datetime('2021-06-30')

root_url = 'https://api.binance.com/api/v1/klines'
symbol = 'STEEMETH'
interval = '1h'
url = root_url + '?symbol=' + symbol + '&interval=' + interval
print(url)
# Out:
# https://api.binance.com/api/v1/klines?symbol=STEEMETH&interval=1h

# %%
import os
live = pd.to_datetime('today')
start = pd.to_datetime('2021-02-01')
end = pd.to_datetime('2021-06-30')

root_url = 'https://api.binance.com/api/v1/klines'
symbol = 'STEEMETH'
interval = '1h'
url = root_url + '?symbol=' + symbol + '&interval=' + interval
print(url)



## adjust the timeperiods fro 15 x 4 or it will be 15min 1 hour and 2 hours 
## from 5 minutes charts the multiplier should be x12 from 5 to 60 

#ada2021 = ada15.loc[(ada15['date']> start)& (ada15['date']< end)].copy()
directory = 'BN-main'
table = []
for filename in os.listdir(directory):
    if filename.endswith('1h.json'):
        df = pd.read_json(directory+'/'+filename)
        df.columns=['date','open','high','low','close','volume']
        df.date = pd.to_datetime(df['date'],unit='ms')
        df = df.loc[(df['date']> start)& (df['date']< end)].copy()
        alth = df.high.max()
        altl = df.low.min()
        
        
        #now = df.close[df.close.idxmax()]
#get the live price 
        array = filename.split("_")
        symbol =array[0]+'USDT'
        url = root_url + '?symbol=' + symbol + '&interval=' + interval
        data = json.loads(requests.get(url).text)
        dflive = pd.DataFrame(data ,columns =['open_time',
              'o', 'h', 'l', 'c', 'v',
              'close_time', 'qav', 'num_trades',
              'taker_base_vol', 'taker_quote_vol', 'ignore'])
        dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
        lastrow = dflive.iloc[-1]
        now= float(lastrow.c)
        #dflive.index = [dt.datetime.fromtimestamp(x/1000.0) for x in df.close_time]
        
        
        #indicator =  data.DataReader(array[0]+'-USD', 'stooq',end,live)
        #price = indicator.loc[indicator.Close.idxmax()]
        #now = price.Close
        tuple =(array[0] ,alth,altl,now)
        table.append(tuple)
        #print("name is: ",array[0] ,alth,altl)
        
    else:
        continue
table[0]
AllTime = pd.DataFrame(table,columns=['Indicator','ATH','ATL','Current'])
AllTime['percent']=(AllTime['Current']/AllTime['ATH'])*100
AllTime.sort_values(by=['percent'],ascending=True,inplace = True)
#AllTime.sort_values(by='ATH',ascending=False)
#AllTime.to_csv("alltimeHL.csv", mode="w")
#data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')
AllTime
# Out:
# https://api.binance.com/api/v1/klines?symbol=STEEMETH&interval=1h
#    Indicator           ATH           ATL       Current     percent
# 2        WIN      0.002970      0.000104      0.000654   22.030303
# 38       MBL      0.043380      0.001528      0.010338   23.831259
# 55       NBS      0.052000      0.008240      0.014890   28.634615
# 46       KEY      0.034750      0.002810      0.009990   28.748201
# 52      DENT      0.022700      0.000334      0.006683   29.440529
# 6         SC      0.064000      0.006655      0.020610   32.203125
# 42      PERL      0.296320      0.037000      0.096570   32.589768
# 29       BTT      0.013578      0.000372      0.004618   34.011902
# 48      STMX      0.099672      0.002959      0.034550   34.663697
# 56       EOS     14.900000      2.893000      5.253000   35.255034
# 35       HOT      0.031600      0.000731      0.011630   36.803797
# 7        ETC    179.830000      7.300000     67.320000   37.435356
# 19       ONT      2.958300      0.508800      1.119600   37.846060
# 8        NEO    141.000000     21.872000     54.860000   38.907801
# 0      STORJ      3.833000      0.414100      1.503600   39.227759
