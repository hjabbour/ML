# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
## choose either white list or read from fix entries 

#fixentries= pd.read_csv('fixoneasy.csv')
fixentries= pd.read_csv('fixentries.csv')

fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
whitelist[0]
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')
# Out:
# 'MIRUSDT'

# %%
#alllist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, ADADOWN/USDT, BOND/USDT, DCR/USDT, DOTDOWN/USDT, GNO/USDT, NBS/USDT, SXPUP/USDT, EOSDOWN/USDT, YFIUP/USDT, RIF/USDT, LTCDOWN/USDT, XLMUP/USDT, YFIDOWN/USDT, LINKDOWN/USDT, TRXUP/USDT, BCHUP/USDT, XTZUP/USDT, SXPDOWN/USDT, UNIDOWN/USDT, XTZDOWN/USDT, BCHDOWN/USDT, TRXDOWN/USDT, XLMDOWN/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
#whitelist =str(fixentries['Indicator'])

startdate = '2020-01-01'
enddate = pd.to_datetime('today')
intervals = ['2h','4h','8h','12h','1d','3d']
#intervals = ['8h']

# %%
def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

# %%
#alllist=alllist.lstrip()
#array = alllist.split(",")
#array = whitelist
array = whitelist
array

wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(symbols,columns =['Indicator'])
#final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            dflive=dflive.loc[(dflive.open_time>start)]

            dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
            dflive['RSI'] = FRSI(dflive['c'])
            dflive['STRSI'] = STRSIA(dflive['c'])[0]
            dflive['STRSIK'] = STRSIA(dflive['c'])[1]
            dflive['STRSID'] = STRSIA(dflive['c'])[2]



            #print(dflive)


            lastrow = dflive.iloc[-1]
            beforelast = dflive.iloc[-2]
            now = float(lastrow.c)
            RSI = float(lastrow.RSI)
            RSIM = float(beforelast.RSI)
            STRSI = float(lastrow.STRSI)
            STRSIK = float(lastrow.STRSIK)
            STRSIKM = float(beforelast.STRSIK)
            STRSID = float(lastrow.STRSID)
            STRSIDM = float(beforelast.STRSID)


            tuple =(symbol,RSI,RSIM,STRSI,STRSIK,STRSIKM,STRSID,STRSIDM)
            table.append(tuple)
            #print(table)
            del dflive
            #print("name is: ",array[0] ,alth,altl)


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','RSI','RSIM','STRSI','STRSIK','STRSIKM','STRSID','STRSIDM'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'RSI':('RSI'+interval),'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSIKM':('STRSIKM'+interval),'STRSID':('STRSID'+interval),'STRSIDM':('STRSIDM'+interval)})
    test.set_index(['Indicator'])
    final=final.merge(test,how='left',on=['Indicator'])
            

final
# Out:
#        Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 0        MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# 1        MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# 2        MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# 3        MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# 4        MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# ...          ...        ...        ...       ...       ...        ...
# 17275  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
# 17276  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
# 17277  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
# 17278  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
# 17279  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 0      0.318542   0.237346  51.052272  51.562662  ...   0.343596  0.318542
# 1      0.318542   0.237346  51.052272  51.562662  ...   0.343596  0.318542
# 2      0.318542   0.237346  51.052272  51.562662  ...   0.343596  0.318542
# 3      0.318542   0.237346  51.052272  51.562662  ...   0.343596  0.318542
# 4      0.318542   0.237346  51.052272  51.562662  ...   0.343596  0.318542
# ...         ...        ...        ...        ...  ...        ...       ...
# 17275  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
# 17276  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
# 17277  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
# 17278  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
# 17279  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 0       0.237346  51.052272  51.562662  0.612655  0.438980   0.343596
# 1       0.237346  54.336398  54.816128  0.295710  0.365421   0.345533
# 2       0.237346  55.039261  54.691135  0.145015  0.243794   0.377334
# 3       0.237346  54.688589  54.436074  0.639070  0.626451   0.653036
# 4       0.237346  52.402289  52.207216  0.653294  0.675878   0.665699
# ...          ...        ...        ...       ...       ...        ...
# 17275   0.416223  59.388450  59.681855  0.877342  0.850457   0.813996
# 17276   0.416223  53.155113  51.468791  0.949195  0.874925   0.891860
# 17277   0.416223  49.663749  48.183071  0.992271  0.953782   0.956359
# 17278   0.416223  41.897119  40.738321  1.000000  0.904352   0.616111
# 17279   0.416223  35.331006  35.409321  0.319264  0.214736   0.108315
#
#        STRSID3d  STRSIDM3d
# 0      0.318542   0.237346
# 1      0.313429   0.238757
# 2      0.378401   0.502363
# 3      0.640718   0.641312
# 4      0.708491   0.740478
# ...         ...        ...
# 17275  0.808475   0.780881
# 17276  0.903901   0.943102
# 17277  0.942456   0.904734
# 17278  0.642194   0.416223
# 17279  0.122515   0.102452
#
# [17280 rows x 43 columns]

# %%
#final.Indicator

# %%
final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
final
# Out:
#        Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 719      MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# 1439    GLMRUSDT  54.539554  54.687750  0.512961  0.345458   0.337004
# 2159    CAKEUSDT  52.789902  52.315938  0.144383  0.088124   0.090202
# 2879     IMXUSDT  57.124229  56.259375  0.507799  0.312719   0.373796
# 3599      SCUSDT  62.173971  61.908726  0.358174  0.220693   0.216239
# 4319     CRVUSDT  67.667572  67.385927  0.600095  0.393226   0.377979
# 5039    MOVRUSDT  54.415884  52.992673  0.392637  0.237215   0.174537
# 5759     RAYUSDT  58.619491  57.982680  0.315683  0.202074   0.119866
# 6479   TFUELUSDT  62.119970  60.868690  0.349675  0.205161   0.209671
# 7199     HNTUSDT  51.963414  50.565747  0.273764  0.156624   0.162779
# 7919   AUDIOUSDT  61.489699  62.597960  0.407342  0.330752   0.228657
# 8639     SRMUSDT  59.307016  60.168960  0.379767  0.273565   0.252632
# 9359     WINUSDT  64.499384  65.731573  0.394106  0.346320   0.347727
# 10079   VTHOUSDT  59.701965  58.304874  0.269844  0.156138   0.071191
# 10799    KSMUSDT  64.990622  67.249613  0.093447  0.112032   0.212779
# 11519   ALGOUSDT  52.746589  53.542357  0.229185  0.170324   0.203441
# 12239    XLMUSDT  57.871026  59.450546  0.248647  0.200824   0.224463
# 12959  1INCHUSDT  59.797139  62.194603  0.240491  0.222697   0.256594
# 13679    OMGUSDT  70.551314  68.151989  0.893254  0.531556   0.307056
# 14399    ZRXUSDT  55.626887  55.756136  0.276458  0.187052   0.192345
# 15119    GRTUSDT  60.875745  60.745410  0.438968  0.289944   0.197053
# 15839    ZILUSDT  59.187954  59.266902  0.211465  0.142260   0.144944
# 16559   WAXPUSDT  60.113375  59.934513  0.187227  0.119138   0.246193
# 17279  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 719    0.318542   0.237346  54.336398  54.816128  ...   0.665699  0.708491
# 1439   0.324022   0.330286  54.633665  54.842131  ...   0.533562  0.573677
# 2159   0.076178   0.063538  52.953670  52.623704  ...   0.442548  0.480596
# 2879   0.336760   0.371582  55.100101  54.369261  ...   0.330303  0.373590
# 3599   0.195085   0.170963  67.203286  66.999572  ...   0.787041  0.805513
# 4319   0.369230   0.390821  70.034213  69.793835  ...   0.533790  0.577862
# 5039   0.159984   0.103646  52.562035  51.960992  ...   0.275930  0.314203
# 5759   0.114986   0.055302  59.719518  59.187941  ...   0.442831  0.492926
# 6479   0.184953   0.170657  63.613916  62.697916  ...   0.395272  0.442028
# 7199   0.138938   0.119199  54.131265  52.969433  ...   0.803013  0.833538
# 7919   0.210576   0.122407  62.012452  62.978103  ...   0.309018  0.379725
# 8639   0.210618   0.169498  63.420759  64.326017  ...   0.699945  0.724739
# 9359   0.329986   0.321059  63.823337  64.726857  ...   0.536157  0.574443
# 10079  0.084735   0.046950  66.652771  65.376144  ...   0.612498  0.618400
# 10799  0.240166   0.417960  66.951004  68.584269  ...   0.602202  0.617145
# 11519  0.161542   0.141272  55.421248  56.255059  ...   0.811518  0.848573
# 12239  0.185623   0.178592  60.600100  61.814736  ...   0.716597  0.748969
# 12959  0.199047   0.189091  61.853982  63.976298  ...   0.651121  0.682582
# 13679  0.313858   0.190284  69.630661  67.835648  ...   0.735856  0.758132
# 14399  0.158947   0.129079  60.224710  60.366063  ...   0.484337  0.536431
# 15119  0.185256   0.112100  61.650697  61.488188  ...   0.299802  0.353053
# 15839  0.120125   0.097096  62.788831  62.861512  ...   0.628469  0.657152
# 16559  0.227755   0.335486  63.647735  63.521589  ...   0.738257  0.753081
# 17279  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 719     0.740478  41.794779  39.675569  1.000000  0.810960   0.653845
# 1439    0.433589  17.927187  16.237943       NaN       NaN        NaN
# 2159    0.312407  30.701568  31.135863  0.443833  0.372224   0.340709
# 2879    0.194417  24.351199  24.424139       NaN       NaN        NaN
# 3599    0.624050  39.115594  38.568339  0.693685  0.522048   0.366121
# 4319    0.381026  41.747994  41.157839  0.463677  0.316689   0.162130
# 5039    0.200844  25.680911  25.323448  0.665130  0.625587   0.608011
# 5759    0.278935  29.028228  28.334965  0.383884  0.224269   0.096308
# 6479    0.305752  46.651009  41.913379  0.770812  0.593798   0.512945
# 7199    0.762198  43.633245  40.270374  0.577489  0.377001   0.205059
# 7919    0.198268  34.828752  33.408872  0.595973  0.415538   0.278851
# 8639    0.538816  35.500059  35.226176  0.752654  0.623107   0.506755
# 9359    0.374117  38.183724  33.400876  0.617202  0.310485   0.203283
# 10079   0.392999  37.780386  31.925407  0.943239  0.636282   0.497779
# 10799   0.402545  34.687060  32.412755  0.422739  0.189868   0.048956
# 11519   0.750635  36.588050  36.726576  0.597960  0.542189   0.342869
# 12239   0.600103  39.784325  40.012603  0.592716  0.558968   0.440260
# 12959   0.535942  36.317633  36.180787  0.625644  0.487126   0.278578
# 13679   0.586622  41.673637  36.173703  0.838637  0.367374   0.118612
# 14399   0.383237  40.700373  40.899958  0.732542  0.677937   0.579122
# 15119   0.178786  38.865866  34.560204  0.586071  0.359707   0.254858
# 15839   0.472448  37.788005  37.826201  0.720301  0.636074   0.491245
# 16559   0.606741  44.284923  40.466172  0.758719  0.474470   0.297409
# 17279   0.416223  35.331006  35.409321  0.319264  0.214736   0.108315
#
#        STRSID3d  STRSIDM3d
# 719    0.677803   0.644636
# 1439        NaN        NaN
# 2159   0.356097   0.407981
# 2879        NaN        NaN
# 3599   0.395814   0.376683
# 4319   0.170764   0.076792
# 5039   0.622009   0.656582
# 5759   0.111575   0.081596
# 6479   0.567960   0.622819
# 7199   0.274079   0.264446
# 7919   0.315559   0.300743
# 8639   0.532530   0.536192
# 9359   0.277963   0.349308
# 10079  0.561851   0.592217
# 10799  0.089586   0.063714
# 11519  0.340757   0.173383
# 12239  0.455512   0.392422
# 12959  0.293879   0.190247
# 13679  0.224991   0.238537
# 14399  0.596636   0.577581
# 15119  0.330384   0.412491
# 15839  0.511259   0.450199
# 16559  0.369630   0.392436
# 17279  0.122515   0.102452
#
# [24 rows x 43 columns]

# %%
#Rules

rule12under = (final['STRSIK12h'] < final['STRSID12h'])
rule12over = (final['STRSIK12h'] > final['STRSID12h'])
rule12kdown = (final['STRSIK12h'] < final['STRSIKM12h'])
rule12kup = (final['STRSIK12h'] > final['STRSIKM12h'])
rule12RSIup = (final['RSI12h'] > final['RSIM12h'])
rule12RSIdown = (final['RSI12h'] < final['RSIM12h'])




rule8under = (final['STRSIK8h']< final['STRSID8h'])
rule8over = (final['STRSIK8h'] > final['STRSID8h'])
rule8kdown = (final['STRSIK8h']< final['STRSIKM8h'])
rule8kup = (final['STRSIK8h'] > final['STRSIKM8h'])
rule8RSIup = (final['RSI8h'] > final['RSIM8h'])
rule8RSIdown = (final['RSI8h'] < final['RSIM8h'])



rule4under = (final['STRSIK4h']< final['STRSID4h'])
rule4over = (final['STRSIK4h'] > final['STRSID4h'])
rule4kdown = (final['STRSIK4h']< final['STRSIKM4h'])
rule4kup = (final['STRSIK4h'] > final['STRSIKM4h'])
rule4RSIup = (final['RSI4h'] > final['RSIM4h'])
rule4RSIdown = (final['RSI4h'] < final['RSIM4h'])



rule2under = (final['STRSIK2h']< final['STRSID2h'])
rule2over = (final['STRSIK2h'] > final['STRSID2h'])
rule2kdown = (final['STRSIK2h']< final['STRSIKM2h'])
rule2kup = (final['STRSIK2h'] > final['STRSIKM2h'])
rule2RSIup = (final['RSI2h'] > final['RSIM2h'])
rule2RSIdown = (final['RSI2h'] < final['RSIM2h'])



rule1dunder = (final['STRSIK1d']< final['STRSID1d'])
rule1dover = (final['STRSIK1d'] > final['STRSID1d'])
rule1dkdown = (final['STRSIK1d']< final['STRSIKM1d'])
rule1dkup = (final['STRSIK1d'] > final['STRSIKM1d'])
rule1dRSIup = (final['RSI1d'] > final['RSIM1d'])
rule1dRSIdown = (final['RSI1d'] < final['RSIM1d'])




rule3dunder = (final['STRSIK3d']< final['STRSID3d'])
rule3dover = (final['STRSIK3d'] > final['STRSID3d'])
rule3dkdown = (final['STRSIK3d']< final['STRSIKM3d'])
rule3dkup = (final['STRSIK3d'] > final['STRSIKM3d'])
rule3dRSIup = (final['RSI3d'] > final['RSIM3d'])
rule3dRSIdown = (final['RSI3d'] < final['RSIM3d'])



rule13over = (final['STRSIK3d'] > final['STRSID3d']) & (final['STRSIK1d'] > final['STRSID1d'])
rule13under =(final['STRSIK3d'] < final['STRSID3d']) & (final['STRSIK1d'] < final['STRSID1d'])




final.dropna()
# Out:
#        Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 719      MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# 2159    CAKEUSDT  52.789902  52.315938  0.144383  0.088124   0.090202
# 3599      SCUSDT  62.173971  61.908726  0.358174  0.220693   0.216239
# 4319     CRVUSDT  67.667572  67.385927  0.600095  0.393226   0.377979
# 5039    MOVRUSDT  54.415884  52.992673  0.392637  0.237215   0.174537
# 5759     RAYUSDT  58.619491  57.982680  0.315683  0.202074   0.119866
# 6479   TFUELUSDT  62.119970  60.868690  0.349675  0.205161   0.209671
# 7199     HNTUSDT  51.963414  50.565747  0.273764  0.156624   0.162779
# 7919   AUDIOUSDT  61.489699  62.597960  0.407342  0.330752   0.228657
# 8639     SRMUSDT  59.307016  60.168960  0.379767  0.273565   0.252632
# 9359     WINUSDT  64.499384  65.731573  0.394106  0.346320   0.347727
# 10079   VTHOUSDT  59.701965  58.304874  0.269844  0.156138   0.071191
# 10799    KSMUSDT  64.990622  67.249613  0.093447  0.112032   0.212779
# 11519   ALGOUSDT  52.746589  53.542357  0.229185  0.170324   0.203441
# 12239    XLMUSDT  57.871026  59.450546  0.248647  0.200824   0.224463
# 12959  1INCHUSDT  59.797139  62.194603  0.240491  0.222697   0.256594
# 13679    OMGUSDT  70.551314  68.151989  0.893254  0.531556   0.307056
# 14399    ZRXUSDT  55.626887  55.756136  0.276458  0.187052   0.192345
# 15119    GRTUSDT  60.875745  60.745410  0.438968  0.289944   0.197053
# 15839    ZILUSDT  59.187954  59.266902  0.211465  0.142260   0.144944
# 16559   WAXPUSDT  60.113375  59.934513  0.187227  0.119138   0.246193
# 17279  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 719    0.318542   0.237346  54.336398  54.816128  ...   0.665699  0.708491
# 2159   0.076178   0.063538  52.953670  52.623704  ...   0.442548  0.480596
# 3599   0.195085   0.170963  67.203286  66.999572  ...   0.787041  0.805513
# 4319   0.369230   0.390821  70.034213  69.793835  ...   0.533790  0.577862
# 5039   0.159984   0.103646  52.562035  51.960992  ...   0.275930  0.314203
# 5759   0.114986   0.055302  59.719518  59.187941  ...   0.442831  0.492926
# 6479   0.184953   0.170657  63.613916  62.697916  ...   0.395272  0.442028
# 7199   0.138938   0.119199  54.131265  52.969433  ...   0.803013  0.833538
# 7919   0.210576   0.122407  62.012452  62.978103  ...   0.309018  0.379725
# 8639   0.210618   0.169498  63.420759  64.326017  ...   0.699945  0.724739
# 9359   0.329986   0.321059  63.823337  64.726857  ...   0.536157  0.574443
# 10079  0.084735   0.046950  66.652771  65.376144  ...   0.612498  0.618400
# 10799  0.240166   0.417960  66.951004  68.584269  ...   0.602202  0.617145
# 11519  0.161542   0.141272  55.421248  56.255059  ...   0.811518  0.848573
# 12239  0.185623   0.178592  60.600100  61.814736  ...   0.716597  0.748969
# 12959  0.199047   0.189091  61.853982  63.976298  ...   0.651121  0.682582
# 13679  0.313858   0.190284  69.630661  67.835648  ...   0.735856  0.758132
# 14399  0.158947   0.129079  60.224710  60.366063  ...   0.484337  0.536431
# 15119  0.185256   0.112100  61.650697  61.488188  ...   0.299802  0.353053
# 15839  0.120125   0.097096  62.788831  62.861512  ...   0.628469  0.657152
# 16559  0.227755   0.335486  63.647735  63.521589  ...   0.738257  0.753081
# 17279  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 719     0.740478  41.794779  39.675569  1.000000  0.810960   0.653845
# 2159    0.312407  30.701568  31.135863  0.443833  0.372224   0.340709
# 3599    0.624050  39.115594  38.568339  0.693685  0.522048   0.366121
# 4319    0.381026  41.747994  41.157839  0.463677  0.316689   0.162130
# 5039    0.200844  25.680911  25.323448  0.665130  0.625587   0.608011
# 5759    0.278935  29.028228  28.334965  0.383884  0.224269   0.096308
# 6479    0.305752  46.651009  41.913379  0.770812  0.593798   0.512945
# 7199    0.762198  43.633245  40.270374  0.577489  0.377001   0.205059
# 7919    0.198268  34.828752  33.408872  0.595973  0.415538   0.278851
# 8639    0.538816  35.500059  35.226176  0.752654  0.623107   0.506755
# 9359    0.374117  38.183724  33.400876  0.617202  0.310485   0.203283
# 10079   0.392999  37.780386  31.925407  0.943239  0.636282   0.497779
# 10799   0.402545  34.687060  32.412755  0.422739  0.189868   0.048956
# 11519   0.750635  36.588050  36.726576  0.597960  0.542189   0.342869
# 12239   0.600103  39.784325  40.012603  0.592716  0.558968   0.440260
# 12959   0.535942  36.317633  36.180787  0.625644  0.487126   0.278578
# 13679   0.586622  41.673637  36.173703  0.838637  0.367374   0.118612
# 14399   0.383237  40.700373  40.899958  0.732542  0.677937   0.579122
# 15119   0.178786  38.865866  34.560204  0.586071  0.359707   0.254858
# 15839   0.472448  37.788005  37.826201  0.720301  0.636074   0.491245
# 16559   0.606741  44.284923  40.466172  0.758719  0.474470   0.297409
# 17279   0.416223  35.331006  35.409321  0.319264  0.214736   0.108315
#
#        STRSID3d  STRSIDM3d
# 719    0.677803   0.644636
# 2159   0.356097   0.407981
# 3599   0.395814   0.376683
# 4319   0.170764   0.076792
# 5039   0.622009   0.656582
# 5759   0.111575   0.081596
# 6479   0.567960   0.622819
# 7199   0.274079   0.264446
# 7919   0.315559   0.300743
# 8639   0.532530   0.536192
# 9359   0.277963   0.349308
# 10079  0.561851   0.592217
# 10799  0.089586   0.063714
# 11519  0.340757   0.173383
# 12239  0.455512   0.392422
# 12959  0.293879   0.190247
# 13679  0.224991   0.238537
# 14399  0.596636   0.577581
# 15119  0.330384   0.412491
# 15839  0.511259   0.450199
# 16559  0.369630   0.392436
# 17279  0.122515   0.102452
#
# [22 rows x 43 columns]

# %%
# 1 and 3 days view

# 1 and 3 days pointing up

drop = final.loc[( (final['STRSIK3d'] > final['STRSID3d']) & (final['STRSIK1d'] > final['STRSID1d'])  )]


# One day and 3 days pointing up

#drop = final.loc[((final['STRSIK3d'] > final['STRSIKM3d']) & (final['STRSIK1d'] > final['STRSIKM1d']) & (final['STRSIK3d'] < final['STRSID3d']) )]

# one day and 3 days crossed 

#drop = final.loc[( (final['STRSIK3d'] > final['STRSID3d']) & (final['STRSIK1d'] > final['STRSID1d']) )]

# 3 days crossed 

#drop = final.loc[( (final['STRSIK3d'] > final['STRSID3d']) )]

# one day crossed 

#drop = final.loc[( (final['STRSIK1d'] > final['STRSID1d']) )]


# one day crossed up and 1 day and  3 days pointing up 

#drop = final.loc[( (final['STRSIK1d'] > final['STRSID1d']) & (final['STRSIK3d'] > final['STRSIKM3d']) & (final['STRSIK1d'] > final['STRSIKM1d'])  )]

#drop = final.loc[( rule1dover & rule1dkup & rule12under &rule12kdown & rule8under & rule8kdown)]

#drop = final.loc[( rule1dover & rule1dkup & rule12under &rule12kdown)]


#drop = final.loc[(rule3dkup & rule12kdown & rule8under & rule8kdown & rule12RSIup & rule8RSIup & rule3dRSIup & rule1dRSIup)]


# one day crossed  up and  3 days pointing down

#drop = final.loc[( (final['STRSIK1d'] > final['STRSID1d']) & (final['STRSIK3d'] < final['STRSIKM3d']) )]



drop
# Out:
#        Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 2159    CAKEUSDT  52.789902  52.315938  0.144383  0.088124   0.090202
# 3599      SCUSDT  62.173971  61.908726  0.358174  0.220693   0.216239
# 4319     CRVUSDT  67.667572  67.385927  0.600095  0.393226   0.377979
# 5039    MOVRUSDT  54.415884  52.992673  0.392637  0.237215   0.174537
# 5759     RAYUSDT  58.619491  57.982680  0.315683  0.202074   0.119866
# 6479   TFUELUSDT  62.119970  60.868690  0.349675  0.205161   0.209671
# 7199     HNTUSDT  51.963414  50.565747  0.273764  0.156624   0.162779
# 7919   AUDIOUSDT  61.489699  62.597960  0.407342  0.330752   0.228657
# 8639     SRMUSDT  59.307016  60.168960  0.379767  0.273565   0.252632
# 9359     WINUSDT  64.499384  65.731573  0.394106  0.346320   0.347727
# 10079   VTHOUSDT  59.701965  58.304874  0.269844  0.156138   0.071191
# 10799    KSMUSDT  64.990622  67.249613  0.093447  0.112032   0.212779
# 11519   ALGOUSDT  52.746589  53.542357  0.229185  0.170324   0.203441
# 12239    XLMUSDT  57.871026  59.450546  0.248647  0.200824   0.224463
# 12959  1INCHUSDT  59.797139  62.194603  0.240491  0.222697   0.256594
# 13679    OMGUSDT  70.551314  68.151989  0.893254  0.531556   0.307056
# 14399    ZRXUSDT  55.626887  55.756136  0.276458  0.187052   0.192345
# 15119    GRTUSDT  60.875745  60.745410  0.438968  0.289944   0.197053
# 15839    ZILUSDT  59.187954  59.266902  0.211465  0.142260   0.144944
# 16559   WAXPUSDT  60.113375  59.934513  0.187227  0.119138   0.246193
# 17279  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 2159   0.076178   0.063538  52.953670  52.623704  ...   0.442548  0.480596
# 3599   0.195085   0.170963  67.203286  66.999572  ...   0.787041  0.805513
# 4319   0.369230   0.390821  70.034213  69.793835  ...   0.533790  0.577862
# 5039   0.159984   0.103646  52.562035  51.960992  ...   0.275930  0.314203
# 5759   0.114986   0.055302  59.719518  59.187941  ...   0.442831  0.492926
# 6479   0.184953   0.170657  63.613916  62.697916  ...   0.395272  0.442028
# 7199   0.138938   0.119199  54.131265  52.969433  ...   0.803013  0.833538
# 7919   0.210576   0.122407  62.012452  62.978103  ...   0.309018  0.379725
# 8639   0.210618   0.169498  63.420759  64.326017  ...   0.699945  0.724739
# 9359   0.329986   0.321059  63.823337  64.726857  ...   0.536157  0.574443
# 10079  0.084735   0.046950  66.652771  65.376144  ...   0.612498  0.618400
# 10799  0.240166   0.417960  66.951004  68.584269  ...   0.602202  0.617145
# 11519  0.161542   0.141272  55.421248  56.255059  ...   0.811518  0.848573
# 12239  0.185623   0.178592  60.600100  61.814736  ...   0.716597  0.748969
# 12959  0.199047   0.189091  61.853982  63.976298  ...   0.651121  0.682582
# 13679  0.313858   0.190284  69.630661  67.835648  ...   0.735856  0.758132
# 14399  0.158947   0.129079  60.224710  60.366063  ...   0.484337  0.536431
# 15119  0.185256   0.112100  61.650697  61.488188  ...   0.299802  0.353053
# 15839  0.120125   0.097096  62.788831  62.861512  ...   0.628469  0.657152
# 16559  0.227755   0.335486  63.647735  63.521589  ...   0.738257  0.753081
# 17279  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 2159    0.312407  30.701568  31.135863  0.443833  0.372224   0.340709
# 3599    0.624050  39.115594  38.568339  0.693685  0.522048   0.366121
# 4319    0.381026  41.747994  41.157839  0.463677  0.316689   0.162130
# 5039    0.200844  25.680911  25.323448  0.665130  0.625587   0.608011
# 5759    0.278935  29.028228  28.334965  0.383884  0.224269   0.096308
# 6479    0.305752  46.651009  41.913379  0.770812  0.593798   0.512945
# 7199    0.762198  43.633245  40.270374  0.577489  0.377001   0.205059
# 7919    0.198268  34.828752  33.408872  0.595973  0.415538   0.278851
# 8639    0.538816  35.500059  35.226176  0.752654  0.623107   0.506755
# 9359    0.374117  38.183724  33.400876  0.617202  0.310485   0.203283
# 10079   0.392999  37.780386  31.925407  0.943239  0.636282   0.497779
# 10799   0.402545  34.687060  32.412755  0.422739  0.189868   0.048956
# 11519   0.750635  36.588050  36.726576  0.597960  0.542189   0.342869
# 12239   0.600103  39.784325  40.012603  0.592716  0.558968   0.440260
# 12959   0.535942  36.317633  36.180787  0.625644  0.487126   0.278578
# 13679   0.586622  41.673637  36.173703  0.838637  0.367374   0.118612
# 14399   0.383237  40.700373  40.899958  0.732542  0.677937   0.579122
# 15119   0.178786  38.865866  34.560204  0.586071  0.359707   0.254858
# 15839   0.472448  37.788005  37.826201  0.720301  0.636074   0.491245
# 16559   0.606741  44.284923  40.466172  0.758719  0.474470   0.297409
# 17279   0.416223  35.331006  35.409321  0.319264  0.214736   0.108315
#
#        STRSID3d  STRSIDM3d
# 2159   0.356097   0.407981
# 3599   0.395814   0.376683
# 4319   0.170764   0.076792
# 5039   0.622009   0.656582
# 5759   0.111575   0.081596
# 6479   0.567960   0.622819
# 7199   0.274079   0.264446
# 7919   0.315559   0.300743
# 8639   0.532530   0.536192
# 9359   0.277963   0.349308
# 10079  0.561851   0.592217
# 10799  0.089586   0.063714
# 11519  0.340757   0.173383
# 12239  0.455512   0.392422
# 12959  0.293879   0.190247
# 13679  0.224991   0.238537
# 14399  0.596636   0.577581
# 15119  0.330384   0.412491
# 15839  0.511259   0.450199
# 16559  0.369630   0.392436
# 17279  0.122515   0.102452
#
# [21 rows x 43 columns]

# %%
# 12 H up down
drop = final.loc[(rule12kdown & rule12RSIdown)]
#drop = final.loc[(rule12kdown & rule12RSIup)]

drop
# Out:
#        Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 719      MIRUSDT  51.052272  51.562662  0.612655  0.438980   0.343596
# 5039    MOVRUSDT  54.415884  52.992673  0.392637  0.237215   0.174537
# 5759     RAYUSDT  58.619491  57.982680  0.315683  0.202074   0.119866
# 10079   VTHOUSDT  59.701965  58.304874  0.269844  0.156138   0.071191
# 17279  SUSHIUSDT  57.990159  58.320256  0.461964  0.307073   0.226218
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 719    0.318542   0.237346  54.336398  54.816128  ...   0.665699  0.708491
# 5039   0.159984   0.103646  52.562035  51.960992  ...   0.275930  0.314203
# 5759   0.114986   0.055302  59.719518  59.187941  ...   0.442831  0.492926
# 10079  0.084735   0.046950  66.652771  65.376144  ...   0.612498  0.618400
# 17279  0.202141   0.128711  59.388450  59.681855  ...   0.616111  0.642194
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 719     0.740478  41.794779  39.675569  1.000000  0.810960   0.653845
# 5039    0.200844  25.680911  25.323448  0.665130  0.625587   0.608011
# 5759    0.278935  29.028228  28.334965  0.383884  0.224269   0.096308
# 10079   0.392999  37.780386  31.925407  0.943239  0.636282   0.497779
# 17279   0.416223  35.331006  35.409321  0.319264  0.214736   0.108315
#
#        STRSID3d  STRSIDM3d
# 719    0.677803   0.644636
# 5039   0.622009   0.656582
# 5759   0.111575   0.081596
# 10079  0.561851   0.592217
# 17279  0.122515   0.102452
#
# [5 rows x 43 columns]

# %%
# test rules 

# 1 day still down on daily 12h 8h
#drop = final.loc[( rule1dunder & rule1dkdown & rule12under &rule12kdown & rule8under & rule8kdown)]

# 3 days still room down 

#drop = final.loc[(rule1dover & rule12over & rule8under)]

# same as above but RSI going up on daily

#drop = final.loc[( rule3dunder & rule3dkdown & rule1dunder & rule1dkdown & rule1dRSIup)]


# # same as above but RSI going up on 1day not yet on 12h

#drop = final.loc[( rule3dunder & rule3dkdown & rule1dunder & rule1dkup & rule1dRSIup & rule12kup)]

## # # same as above but RSI going up on 8h

#drop = final.loc[( rule3dunder & rule3dkdown & rule1dunder & rule1dkdown & rule1dRSIup & rule12kdown & rule8kdown & rule8RSIup )]

#Live rule

#drop = final.loc[(rule1dRSIup & rule12RSIup & rule8RSIdown & rule8kup & rule8over & rule4kup & rule2over & rule2kup) ]

#drop = final.loc[(rule8under & rule8kdown & rule4under & rule4kdown & (final['STRSIK4h'] < 0.8) ) ]


drop = final.loc[(rule8under & rule8kdown & rule4under & rule4kdown ) ]

#drop = final.loc[(rule8kdown & rule4kdown ) | (rule8RSIup & rule4RSIdown & rule2RSIdown) ]

#drop = final.loc[(rule8under & rule8kdown & rule4under & rule4kdown & (final['STRSIK4h'] < 0.2) ) ]


#drop = final.loc[(rule8RSIup & rule4RSIdown) ]


drop
# Out:
#       Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 1439   GLMRUSDT  54.539554  54.687750  0.512961  0.345458   0.337004
# 2159   CAKEUSDT  52.789902  52.315938  0.144383  0.088124   0.090202
# 5759    RAYUSDT  58.619491  57.982680  0.315683  0.202074   0.119866
# 10799   KSMUSDT  64.990622  67.249613  0.093447  0.112032   0.212779
# 11519  ALGOUSDT  52.746589  53.542357  0.229185  0.170324   0.203441
# 12239   XLMUSDT  57.871026  59.450546  0.248647  0.200824   0.224463
# 14399   ZRXUSDT  55.626887  55.756136  0.276458  0.187052   0.192345
# 16559  WAXPUSDT  60.113375  59.934513  0.187227  0.119138   0.246193
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 1439   0.324022   0.330286  54.633665  54.842131  ...   0.533562  0.573677
# 2159   0.076178   0.063538  52.953670  52.623704  ...   0.442548  0.480596
# 5759   0.114986   0.055302  59.719518  59.187941  ...   0.442831  0.492926
# 10799  0.240166   0.417960  66.951004  68.584269  ...   0.602202  0.617145
# 11519  0.161542   0.141272  55.421248  56.255059  ...   0.811518  0.848573
# 12239  0.185623   0.178592  60.600100  61.814736  ...   0.716597  0.748969
# 14399  0.158947   0.129079  60.224710  60.366063  ...   0.484337  0.536431
# 16559  0.227755   0.335486  63.647735  63.521589  ...   0.738257  0.753081
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 1439    0.433589  17.927187  16.237943       NaN       NaN        NaN
# 2159    0.312407  30.701568  31.135863  0.443833  0.372224   0.340709
# 5759    0.278935  29.028228  28.334965  0.383884  0.224269   0.096308
# 10799   0.402545  34.687060  32.412755  0.422739  0.189868   0.048956
# 11519   0.750635  36.588050  36.726576  0.597960  0.542189   0.342869
# 12239   0.600103  39.784325  40.012603  0.592716  0.558968   0.440260
# 14399   0.383237  40.700373  40.899958  0.732542  0.677937   0.579122
# 16559   0.606741  44.284923  40.466172  0.758719  0.474470   0.297409
#
#        STRSID3d  STRSIDM3d
# 1439        NaN        NaN
# 2159   0.356097   0.407981
# 5759   0.111575   0.081596
# 10799  0.089586   0.063714
# 11519  0.340757   0.173383
# 12239  0.455512   0.392422
# 14399  0.596636   0.577581
# 16559  0.369630   0.392436
#
# [8 rows x 43 columns]

# %%
# Split RSI and STCH  tables 
#finalRSI = final.loc[:,['Indicator','RSI2h','RSIM2h','RSI4h','RSIM4h','RSI8h','RSIM8h','RSI12h','RSIM12h','RSI1d','RSIM1d','RSI3d','RSIM3d']]
#finalSTRSIK = final.loc[:,['Indicator','STRSIK2h','STRSIKM2h','STRSIK4h','STRSIKM4h','STRSIK8h','STRSIKM8h','STRSIK12h','STRSIKM12h','STRSIK1d','STRSIKM1d','STRSIK3d','STRSIKM3d','STRSID2h','STRSIDM2h','STRSID4h','STRSIDM4h','STRSID8h','STRSIDM8h','STRSID12h','STRSIDM12h','STRSID1d','STRSIDM1d','STRSID3d','STRSIDM3d']]
finalRSI = final.loc[:,['Indicator','RSI2h','RSIM2h','RSI4h','RSIM4h','RSI8h','RSIM8h','RSI12h','RSIM12h','RSI1d','RSIM1d','RSI3d','RSIM3d']]
finalSTRSIK = final.loc[:,['Indicator','STRSIK2h','STRSIKM2h','STRSIK4h','STRSIKM4h','STRSIK8h','STRSIKM8h','STRSIK12h','STRSIKM12h','STRSIK1d','STRSIKM1d','STRSIK3d','STRSIKM3d','STRSID2h','STRSIDM2h','STRSID4h','STRSIDM4h','STRSID8h','STRSIDM8h','STRSID12h','STRSIDM12h','STRSID1d','STRSIDM1d','STRSID3d','STRSIDM3d']]
#finalST = 
finalSTRSIK
# Out:
#        Indicator  STRSIK2h  STRSIKM2h  STRSIK4h  STRSIKM4h  STRSIK8h  \
# 719      MIRUSDT  0.438980   0.343596  0.365421   0.345533  0.243794
# 1439    GLMRUSDT  0.345458   0.337004  0.762498   0.779840  0.910952
# 2159    CAKEUSDT  0.088124   0.090202  0.590537   0.617344  0.727707
# 2879     IMXUSDT  0.312719   0.373796  0.943659   0.915143  0.928655
# 3599      SCUSDT  0.220693   0.216239  1.000000   0.972102  0.991242
# 4319     CRVUSDT  0.393226   0.377979  1.000000   1.000000  1.000000
# 5039    MOVRUSDT  0.237215   0.174537  0.711002   0.674053  0.775582
# 5759     RAYUSDT  0.202074   0.119866  0.744143   0.751894  0.871662
# 6479   TFUELUSDT  0.205161   0.209671  0.876394   0.830488  0.973415
# 7199     HNTUSDT  0.156624   0.162779  0.503066   0.501631  0.651469
# 7919   AUDIOUSDT  0.330752   0.228657  0.949962   0.948763  0.955003
# 8639     SRMUSDT  0.273565   0.252632  0.965996   0.945364  0.968880
# 9359     WINUSDT  0.346320   0.347727  0.988736   0.975189  0.997363
# 10079   VTHOUSDT  0.156138   0.071191  0.861501   0.850696  0.942720
# 10799    KSMUSDT  0.112032   0.212779  0.920188   0.955905  0.998131
# 11519   ALGOUSDT  0.170324   0.203441  0.707028   0.708818  0.816159
# 12239    XLMUSDT  0.200824   0.224463  0.964087   0.970710  0.977011
# 12959  1INCHUSDT  0.222697   0.256594  0.966527   0.980273  0.993723
# 13679    OMGUSDT  0.531556   0.307056  1.000000   0.985006  1.000000
# 14399    ZRXUSDT  0.187052   0.192345  0.840965   0.860481  0.916223
# 15119    GRTUSDT  0.289944   0.197053  0.965283   0.909351  0.949785
# 15839    ZILUSDT  0.142260   0.144944  0.780397   0.747465  0.838594
# 16559   WAXPUSDT  0.119138   0.246193  0.855075   0.900527  0.927724
# 17279  SUSHIUSDT  0.307073   0.226218  0.850457   0.813996  0.874925
#
#        STRSIKM8h  STRSIK12h  STRSIKM12h  STRSIK1d  ...  STRSID4h  STRSIDM4h  \
# 719     0.377334   0.626451    0.653036  0.675878  ...  0.313429   0.238757
# 1439    0.924115   0.967931    0.976882  0.736601  ...  0.774580   0.757209
# 2159    0.832704   0.958873    0.982780  0.692789  ...  0.623381   0.660306
# 2879    0.938877   0.983277    0.990469  0.614451  ...  0.907109   0.858460
# 3599    0.985533   0.994234    0.994234  0.989610  ...  0.975929   0.954703
# 4319    1.000000   1.000000    1.000000  0.833301  ...  1.000000   1.000000
# 5039    0.832638   0.947689    0.963585  0.468418  ...  0.686061   0.697281
# 5759    0.908026   0.955224    0.963744  0.766153  ...  0.764382   0.810638
# 6479    0.933556   0.986601    0.986601  0.623705  ...  0.850764   0.835610
# 7199    0.721685   0.861779    0.925698  0.901741  ...  0.524303   0.573315
# 7919    0.955003   0.988619    0.988619  0.642352  ...  0.939237   0.941297
# 8639    0.951492   0.986259    0.986259  0.929359  ...  0.933829   0.896093
# 9359    0.997363   1.000000    1.000000  0.838523  ...  0.975640   0.956558
# 10079   0.961429   0.973971    0.981514  0.890245  ...  0.870864   0.901250
# 10799   1.000000   0.999115    1.000000  0.884561  ...  0.948004   0.972826
# 11519   0.860706   0.924929    0.953846  0.947774  ...  0.721382   0.736150
# 12239   0.985724   0.976951    0.987409  0.934774  ...  0.966369   0.954207
# 12959   0.991821   1.000000    1.000000  0.871203  ...  0.964787   0.956903
# 13679   0.999270   0.999255    0.999255  0.952554  ...  0.990004   0.978553
# 14399   0.957090   0.969384    0.983638  0.735241  ...  0.858193   0.862850
# 15119   0.944412   0.990914    0.990914  0.591336  ...  0.909467   0.880206
# 15839   0.885653   0.991166    0.995745  0.885103  ...  0.747405   0.735298
# 16559   0.978507   0.979182    1.000000  0.915980  ...  0.897786   0.922150
# 17279   0.891860   0.953782    0.956359  0.904352  ...  0.808475   0.780881
#
#        STRSID8h  STRSIDM8h  STRSID12h  STRSIDM12h  STRSID1d  STRSIDM1d  \
# 719    0.378401   0.502363   0.640718    0.641312  0.708491   0.740478
# 1439   0.923447   0.942994   0.948868    0.910358  0.573677   0.433589
# 2159   0.828753   0.919518   0.971272    0.942382  0.480596   0.312407
# 2879   0.935469   0.959251   0.960603    0.902216  0.373590   0.194417
# 3599   0.987436   0.988452   0.976167    0.933410  0.805513   0.624050
# 4319   1.000000   1.000000   0.962305    0.887086  0.577862   0.381026
# 5039   0.843421   0.918228   0.925643    0.861998  0.314203   0.200844
# 5759   0.919785   0.962565   0.955393    0.907971  0.492926   0.278935
# 6479   0.948286   0.943861   0.976659    0.948724  0.442028   0.305752
# 7199   0.736393   0.820150   0.894304    0.872700  0.833538   0.762198
# 7919   0.962503   0.977502   0.962299    0.892826  0.379725   0.198268
# 8639   0.957748   0.962325   0.968560    0.925681  0.724739   0.538816
# 9359   0.997363   0.998242   0.972838    0.905795  0.574443   0.374117
# 10079  0.968050   0.987143   0.972071    0.942428  0.618400   0.392999
# 10799  0.999377   1.000000   0.973356    0.916786  0.617145   0.402545
# 11519  0.866750   0.912298   0.936922    0.909298  0.848573   0.750635
# 12239  0.982820   0.972860   0.951229    0.887032  0.748969   0.600103
# 12959  0.992455   0.988608   0.971880    0.918072  0.682582   0.535942
# 13679  0.999513   0.999270   0.982010    0.934852  0.758132   0.586622
# 14399  0.948908   0.976834   0.980323    0.959470  0.536431   0.383237
# 15119  0.950989   0.965937   0.965486    0.902016  0.353053   0.178786
# 15839  0.885192   0.938994   0.975641    0.932453  0.657152   0.472448
# 16559  0.961579   0.984938   0.973258    0.933308  0.753081   0.606741
# 17279  0.903901   0.943102   0.942456    0.904734  0.642194   0.416223
#
#        STRSID3d  STRSIDM3d
# 719    0.677803   0.644636
# 1439        NaN        NaN
# 2159   0.356097   0.407981
# 2879        NaN        NaN
# 3599   0.395814   0.376683
# 4319   0.170764   0.076792
# 5039   0.622009   0.656582
# 5759   0.111575   0.081596
# 6479   0.567960   0.622819
# 7199   0.274079   0.264446
# 7919   0.315559   0.300743
# 8639   0.532530   0.536192
# 9359   0.277963   0.349308
# 10079  0.561851   0.592217
# 10799  0.089586   0.063714
# 11519  0.340757   0.173383
# 12239  0.455512   0.392422
# 12959  0.293879   0.190247
# 13679  0.224991   0.238537
# 14399  0.596636   0.577581
# 15119  0.330384   0.412491
# 15839  0.511259   0.450199
# 16559  0.369630   0.392436
# 17279  0.122515   0.102452
#
# [24 rows x 25 columns]

# %%
drop = final.loc[( rule1dover & rule1dkup & rule12under &rule12kdown & rule8under & rule4kdown)]
drop
# Out:
#       Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 2159   CAKEUSDT  52.789902  52.315938  0.144383  0.088124   0.090202
# 5759    RAYUSDT  58.619491  57.982680  0.315683  0.202074   0.119866
# 11519  ALGOUSDT  52.746589  53.542357  0.229185  0.170324   0.203441
# 14399   ZRXUSDT  55.626887  55.756136  0.276458  0.187052   0.192345
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 2159   0.076178   0.063538  52.953670  52.623704  ...   0.442548  0.480596
# 5759   0.114986   0.055302  59.719518  59.187941  ...   0.442831  0.492926
# 11519  0.161542   0.141272  55.421248  56.255059  ...   0.811518  0.848573
# 14399  0.158947   0.129079  60.224710  60.366063  ...   0.484337  0.536431
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 2159    0.312407  30.701568  31.135863  0.443833  0.372224   0.340709
# 5759    0.278935  29.028228  28.334965  0.383884  0.224269   0.096308
# 11519   0.750635  36.588050  36.726576  0.597960  0.542189   0.342869
# 14399   0.383237  40.700373  40.899958  0.732542  0.677937   0.579122
#
#        STRSID3d  STRSIDM3d
# 2159   0.356097   0.407981
# 5759   0.111575   0.081596
# 11519  0.340757   0.173383
# 14399  0.596636   0.577581
#
# [4 rows x 43 columns]

# %%
drop12 = drop.loc[:]

## check the 12 hour status 
## crossed on the 12 hours 
#drop12 = final.loc[((final['STRSIK12h'] > final['STRSID12h']))]

##  12 hours still going down 
rule12under = (final['STRSIK12h'] < final['STRSID12h'])
rule12kdown = (final['STRSIK12h'] < final['STRSIKM12h'])
rule8under = (final['STRSIK8h']< final['STRSID8h'])
rule8kdown = (final['STRSIK8h']< final['STRSIKM8h'])
rule8kup = (final['STRSIK8h'] > final['STRSIKM8h'])


drop12 = drop.loc[(rule12kdown)]
drop12 = drop12.loc[:,['Indicator','STRSIK12h','STRSIKM12h','STRSIK8h','STRSIKM8h','STRSID12h','STRSIDM12h','STRSID8h','STRSIDM8h']]
drop8 = drop12.loc[(rule8kdown)]

drop8
# Out:
#       Indicator  STRSIK12h  STRSIKM12h  STRSIK8h  STRSIKM8h  STRSID12h  \
# 2159   CAKEUSDT   0.958873    0.982780  0.727707   0.832704   0.971272
# 5759    RAYUSDT   0.955224    0.963744  0.871662   0.908026   0.955393
# 11519  ALGOUSDT   0.924929    0.953846  0.816159   0.860706   0.936922
# 14399   ZRXUSDT   0.969384    0.983638  0.916223   0.957090   0.980323
#
#        STRSIDM12h  STRSID8h  STRSIDM8h
# 2159     0.942382  0.828753   0.919518
# 5759     0.907971  0.919785   0.962565
# 11519    0.909298  0.866750   0.912298
# 14399    0.959470  0.948908   0.976834

# %%
## WILL GO DOWN still K > D , K are dropping on 4 hour 
drop = final.loc[((final['STRSIK8h'] < final['STRSIKM8h']) & (final['STRSIK4h'] < final['STRSIKM4h']) &  (final['STRSIK8h'] < final['STRSID8h']) &  (final['STRSIK4h'] < final['STRSID4h']) )]
drop
# Out:
#       Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 1439   GLMRUSDT  54.539554  54.687750  0.512961  0.345458   0.337004
# 2159   CAKEUSDT  52.789902  52.315938  0.144383  0.088124   0.090202
# 5759    RAYUSDT  58.619491  57.982680  0.315683  0.202074   0.119866
# 10799   KSMUSDT  64.990622  67.249613  0.093447  0.112032   0.212779
# 11519  ALGOUSDT  52.746589  53.542357  0.229185  0.170324   0.203441
# 12239   XLMUSDT  57.871026  59.450546  0.248647  0.200824   0.224463
# 14399   ZRXUSDT  55.626887  55.756136  0.276458  0.187052   0.192345
# 16559  WAXPUSDT  60.113375  59.934513  0.187227  0.119138   0.246193
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 1439   0.324022   0.330286  54.633665  54.842131  ...   0.533562  0.573677
# 2159   0.076178   0.063538  52.953670  52.623704  ...   0.442548  0.480596
# 5759   0.114986   0.055302  59.719518  59.187941  ...   0.442831  0.492926
# 10799  0.240166   0.417960  66.951004  68.584269  ...   0.602202  0.617145
# 11519  0.161542   0.141272  55.421248  56.255059  ...   0.811518  0.848573
# 12239  0.185623   0.178592  60.600100  61.814736  ...   0.716597  0.748969
# 14399  0.158947   0.129079  60.224710  60.366063  ...   0.484337  0.536431
# 16559  0.227755   0.335486  63.647735  63.521589  ...   0.738257  0.753081
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 1439    0.433589  17.927187  16.237943       NaN       NaN        NaN
# 2159    0.312407  30.701568  31.135863  0.443833  0.372224   0.340709
# 5759    0.278935  29.028228  28.334965  0.383884  0.224269   0.096308
# 10799   0.402545  34.687060  32.412755  0.422739  0.189868   0.048956
# 11519   0.750635  36.588050  36.726576  0.597960  0.542189   0.342869
# 12239   0.600103  39.784325  40.012603  0.592716  0.558968   0.440260
# 14399   0.383237  40.700373  40.899958  0.732542  0.677937   0.579122
# 16559   0.606741  44.284923  40.466172  0.758719  0.474470   0.297409
#
#        STRSID3d  STRSIDM3d
# 1439        NaN        NaN
# 2159   0.356097   0.407981
# 5759   0.111575   0.081596
# 10799  0.089586   0.063714
# 11519  0.340757   0.173383
# 12239  0.455512   0.392422
# 14399  0.596636   0.577581
# 16559  0.369630   0.392436
#
# [8 rows x 43 columns]

# %%
## filter find RSI divergence for going down on 8 and 4 hours

drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['RSI8h'] < final['RSIM8h']) & (final['STRSIK8h'] < final['STRSIKM8h']) & (final['STRSIK4h'] < final['STRSIKM4h']) &  (final['STRSIK8h'] < final['STRSID8h']) &  (final['STRSIK4h'] < final['STRSID4h']) )]
drop
# Out:
#       Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 1439   GLMRUSDT  54.539554  54.687750  0.512961  0.345458   0.337004
# 10799   KSMUSDT  64.990622  67.249613  0.093447  0.112032   0.212779
# 11519  ALGOUSDT  52.746589  53.542357  0.229185  0.170324   0.203441
# 12239   XLMUSDT  57.871026  59.450546  0.248647  0.200824   0.224463
# 14399   ZRXUSDT  55.626887  55.756136  0.276458  0.187052   0.192345
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 1439   0.324022   0.330286  54.633665  54.842131  ...   0.533562  0.573677
# 10799  0.240166   0.417960  66.951004  68.584269  ...   0.602202  0.617145
# 11519  0.161542   0.141272  55.421248  56.255059  ...   0.811518  0.848573
# 12239  0.185623   0.178592  60.600100  61.814736  ...   0.716597  0.748969
# 14399  0.158947   0.129079  60.224710  60.366063  ...   0.484337  0.536431
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 1439    0.433589  17.927187  16.237943       NaN       NaN        NaN
# 10799   0.402545  34.687060  32.412755  0.422739  0.189868   0.048956
# 11519   0.750635  36.588050  36.726576  0.597960  0.542189   0.342869
# 12239   0.600103  39.784325  40.012603  0.592716  0.558968   0.440260
# 14399   0.383237  40.700373  40.899958  0.732542  0.677937   0.579122
#
#        STRSID3d  STRSIDM3d
# 1439        NaN        NaN
# 10799  0.089586   0.063714
# 11519  0.340757   0.173383
# 12239  0.455512   0.392422
# 14399  0.596636   0.577581
#
# [5 rows x 43 columns]

# %%
## WILL GO DOWN still K > D , K are dropping on 4 hour and 8 hours still above D and over 0.8 
drop = final.loc[((final['STRSIK8h'] < final['STRSIKM8h']) & (final['STRSIK4h'] < final['STRSIKM4h']) & (final['STRSIK4h'] > 0.8) &  (final['STRSIK8h'] > final['STRSID8h']))]
drop
# Out:
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSIKM2h, STRSID2h, STRSIDM2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSIKM4h, STRSID4h, STRSIDM4h, RSI8h, RSIM8h, STRSI8h, STRSIK8h, STRSIKM8h, STRSID8h, STRSIDM8h, RSI12h, RSIM12h, STRSI12h, STRSIK12h, STRSIKM12h, STRSID12h, STRSIDM12h, RSI1d, RSIM1d, STRSI1d, STRSIK1d, STRSIKM1d, STRSID1d, STRSIDM1d, RSI3d, RSIM3d, STRSI3d, STRSIK3d, STRSIKM3d, STRSID3d, STRSIDM3d]
# Index: []
#
# [0 rows x 43 columns]

# %%
## Will go up above 0.8 k 4 and 8 still going up

drop = final.loc[((final['STRSIK8h'] > final['STRSIKM8h']) & (final['STRSIK4h'] > final['STRSIKM4h']) & (final['STRSIK8h'] > 0.8) &  (final['STRSIK8h'] > final['STRSID8h']))]
drop
# Out:
#        Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSIKM2h  \
# 3599      SCUSDT  62.173971  61.908726  0.358174  0.220693   0.216239
# 6479   TFUELUSDT  62.119970  60.868690  0.349675  0.205161   0.209671
# 8639     SRMUSDT  59.307016  60.168960  0.379767  0.273565   0.252632
# 13679    OMGUSDT  70.551314  68.151989  0.893254  0.531556   0.307056
#
#        STRSID2h  STRSIDM2h      RSI4h     RSIM4h  ...  STRSIKM1d  STRSID1d  \
# 3599   0.195085   0.170963  67.203286  66.999572  ...   0.787041  0.805513
# 6479   0.184953   0.170657  63.613916  62.697916  ...   0.395272  0.442028
# 8639   0.210618   0.169498  63.420759  64.326017  ...   0.699945  0.724739
# 13679  0.313858   0.190284  69.630661  67.835648  ...   0.735856  0.758132
#
#        STRSIDM1d      RSI3d     RSIM3d   STRSI3d  STRSIK3d  STRSIKM3d  \
# 3599    0.624050  39.115594  38.568339  0.693685  0.522048   0.366121
# 6479    0.305752  46.651009  41.913379  0.770812  0.593798   0.512945
# 8639    0.538816  35.500059  35.226176  0.752654  0.623107   0.506755
# 13679   0.586622  41.673637  36.173703  0.838637  0.367374   0.118612
#
#        STRSID3d  STRSIDM3d
# 3599   0.395814   0.376683
# 6479   0.567960   0.622819
# 8639   0.532530   0.536192
# 13679  0.224991   0.238537
#
# [4 rows x 43 columns]

# %%
## under 0.2 and will go down
## WILL GO DOWN still K > D , K are dropping on 4 hour and 8 hours still above D and under 0.2
drop = final.loc[((final['STRSIK8h'] < final['STRSIKM8h']) & (final['STRSIK4h'] < final['STRSIKM4h']) & (final['STRSIK4h'] < 0.2) &  (final['STRSIK8h'] > final['STRSID8h']))]
drop
# Out:
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSIKM2h, STRSID2h, STRSIDM2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSIKM4h, STRSID4h, STRSIDM4h, RSI8h, RSIM8h, STRSI8h, STRSIK8h, STRSIKM8h, STRSID8h, STRSIDM8h, RSI12h, RSIM12h, STRSI12h, STRSIK12h, STRSIKM12h, STRSID12h, STRSIDM12h, RSI1d, RSIM1d, STRSI1d, STRSIK1d, STRSIKM1d, STRSID1d, STRSIDM1d, RSI3d, RSIM3d, STRSI3d, STRSIK3d, STRSIKM3d, STRSID3d, STRSIDM3d]
# Index: []
#
# [0 rows x 43 columns]

# %%
## Will go up under k 4 and 8 still going up

drop = final.loc[((final['STRSIK8h'] > final['STRSIKM8h']) & (final['STRSIK4h'] > final['STRSIKM4h']) & (final['STRSIK8h'] < 0.2) &  (final['STRSIK8h'] > final['STRSID8h']))]
drop
# Out:
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSIKM2h, STRSID2h, STRSIDM2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSIKM4h, STRSID4h, STRSIDM4h, RSI8h, RSIM8h, STRSI8h, STRSIK8h, STRSIKM8h, STRSID8h, STRSIDM8h, RSI12h, RSIM12h, STRSI12h, STRSIK12h, STRSIKM12h, STRSID12h, STRSIDM12h, RSI1d, RSIM1d, STRSI1d, STRSIK1d, STRSIKM1d, STRSID1d, STRSIDM1d, RSI3d, RSIM3d, STRSI3d, STRSIK3d, STRSIKM3d, STRSID3d, STRSIDM3d]
# Index: []
#
# [0 rows x 43 columns]

# %%
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1)]
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1) & (AllTime['RSI'] > AllTime['RSIM'])]
#drop = final.loc[ (((final['RSI8h'] < final['RSIM8h']) | (final['STRSIK4h'] <= final['STRSID4h'])))]
#drop = final.loc[(final['RSI2h'] > final['RSIM2h'])]
#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK2h'] < final['STRSID2h']))]

#4 
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']))]

#4 and 8

#drop = final.loc[((final['RSI4h'] > final['RSIM4h']) & (final['STRSIK4h'] > final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']))]
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']) & (final['RSI8h'] < final['RSIM8h']) )]
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['RSI8h'] < final['RSIM8h']) )]


## WILL GO DOWN still K > D , K are dropping on 4 hour and 8 hours still above D and over 0.8 
drop = final.loc[((final['STRSIK8h'] < final['STRSIKM8h']) & (final['STRSIK4h'] < final['STRSIKM4h']) & (final['STRSIK4h'] > 0.8) &  (final['STRSIK8h'] > final['STRSID8h']))]



# K M before finding dropping K which is still above D 

#drop = final.loc[((final['STRSIK8h'] > final['STRSIKM8h']) & (final['STRSIK4h'] < final['STRSIKM4h']) & (final['STRSIK4h'] > 0.8))]



#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK4h'] > 0.9))]




#drop = final.loc[((final['STRSI12h'] > 0.7))]

#drop = final.loc[ (final['RSI1h'] < final['RSIM1h'])]

#drop = AllTime.loc[((AllTime['RSI'] > AllTime['RSIM']) | (AllTime['STRSIK'] >= AllTime['STRSID']))]

#drop = AllTime.loc[ (AllTime['STRSI'] < 0.9) & (AllTime['STRSIK'] > AllTime['STRSID'])]



#drop = AllTime.loc[(AllTime['MONTH'] < 70)]
#drop = AllTime.loc[(AllTime['MONTH'] < 80)&(AllTime['2MONTH'] < 70)&(AllTime['ALLTIME'] < 40)]
#drop = AllTime.loc[(AllTime['MONTH'] <70)&(AllTime['2MONTH'] > (AllTime['3MONTH']))]

#drop = drop.sort_values(by=['RSI1h'],ascending=False,inplace = True)
#drop = drop.loc[(drop['ALLTIME'] < drop['3MONTH'])]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','Current']]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','STRSI']]

drop

print("Low  RSI")
print(drop.iloc[0:60,0:14])
print(drop.iloc[60:110,])
print(drop.iloc[110:160,])
#del drop
# Out:
# Low  RSI
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSIKM2h, STRSID2h, STRSIDM2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSIKM4h, STRSID4h]
# Index: []
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSIKM2h, STRSID2h, STRSIDM2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSIKM4h, STRSID4h, STRSIDM4h, RSI8h, RSIM8h, STRSI8h, STRSIK8h, STRSIKM8h, STRSID8h, STRSIDM8h, RSI12h, RSIM12h, STRSI12h, STRSIK12h, STRSIKM12h, STRSID12h, STRSIDM12h, RSI1d, RSIM1d, STRSI1d, STRSIK1d, STRSIKM1d, STRSID1d, STRSIDM1d, RSI3d, RSIM3d, STRSI3d, STRSIK3d, STRSIKM3d, STRSID3d, STRSIDM3d]
# Index: []
#
# [0 rows x 43 columns]
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSIKM2h, STRSID2h, STRSIDM2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSIKM4h, STRSID4h, STRSIDM4h, RSI8h, RSIM8h, STRSI8h, STRSIK8h, STRSIKM8h, STRSID8h, STRSIDM8h, RSI12h, RSIM12h, STRSI12h, STRSIK12h, STRSIKM12h, STRSID12h, STRSIDM12h, RSI1d, RSIM1d, STRSI1d, STRSIK1d, STRSIKM1d, STRSID1d, STRSIDM1d, RSI3d, RSIM3d, STRSI3d, STRSIK3d, STRSIKM3d, STRSID3d, STRSIDM3d]
# Index: []
#
# [0 rows x 43 columns]

# %%
#save = drop[['Indicator','RSI','STRSI']]
#save = save.rename(columns={'STRSI': 'STRSI1','RSI':'RSI1'})
#save
#save.to_csv("strsi1KD.csv")
RSITABLE = drop[['Indicator', 'RSI2h', 'RSIM2h','RSI4h', 'RSIM4h','RSI8h', 'RSIM8h']]
sort1 = RSITABLE.sort_values(by=['RSI2h'],ascending=True,inplace = True)


RSITABLE
# Out:
# /Users/hjabbour/opt/anaconda3/envs/cryptodev/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, RSI4h, RSIM4h, RSI8h, RSIM8h]
# Index: []

# %%
STCHTABLE = drop[['Indicator','STRSIK2h', 'STRSID2h','STRSIK4h', 'STRSID4h','STRSIK8h', 'STRSID8h']]
STCHTABLE
# Out:
# Empty DataFrame
# Columns: [Indicator, STRSIK2h, STRSID2h, STRSIK4h, STRSID4h, STRSIK8h, STRSID8h]
# Index: []

# %%
# High 8 hours going down
STCHTABLEH = STCHTABLE.loc[STCHTABLE['STRSID8h']> 0.8]
STCHTABLEH
#save
# Out:
# Empty DataFrame
# Columns: [Indicator, STRSIK2h, STRSID2h, STRSIK4h, STRSID4h, STRSIK8h, STRSID8h]
# Index: []

# %%
del final, whitelist ,dflive
