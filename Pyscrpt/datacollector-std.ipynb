# %%
## need to add open close for each time frame ,
## support resistance
##  pivots ,https://towardsdatascience.com/pivot-points-calculation-in-python-for-day-trading-659c1e92d323 
## and write it down each 15 minutes to create data set for AI ML bot 
## bot with GAN or CAN

# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
## choose either white list or read from fix entries 

#fixentries= pd.read_csv('easyband.csv')
#fixentries= pd.read_csv('fixoneasy.csv')
#fixentries= pd.read_csv('fixentries.csv')
fixentries= pd.read_csv('entries.csv')


fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
#whitelist
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')

# %%
#alllist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, ADADOWN/USDT, BOND/USDT, DCR/USDT, DOTDOWN/USDT, GNO/USDT, NBS/USDT, SXPUP/USDT, EOSDOWN/USDT, YFIUP/USDT, RIF/USDT, LTCDOWN/USDT, XLMUP/USDT, YFIDOWN/USDT, LINKDOWN/USDT, TRXUP/USDT, BCHUP/USDT, XTZUP/USDT, SXPDOWN/USDT, UNIDOWN/USDT, XTZDOWN/USDT, BCHDOWN/USDT, TRXDOWN/USDT, XLMDOWN/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
#whitelist =str(fixentries['Indicator'])

startdate = '2020-01-01'
enddate = pd.to_datetime('today')
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']
#intervals = ['8h']

# %%
#print (enddate)

# %%
def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

#Calulate SMA 
def SMA(series,size):
    sma = series.rolling(size).mean()
    return sma
#Calculate SMA55

## MACD 
def MMACD(series,fast=5,slow=35,sig=5):
    ## defaults original f 12, s 26, s9
    exp1 = series.ewm(span=fast, adjust=False).mean()
    exp2 = series.ewm(span=slow, adjust=False).mean()
    macd = exp1-exp2
    signal = macd.ewm(span=sig, adjust=False).mean()
    return macd,signal
## Bottom price 
def FBOTTOMP (series,size):
    bottomp=series.rolling(size).min()
    return bottomp
## top price 
def FTOPP (series,size):
    topp=series.rolling(size).max()
    return topp

# %%
#alllist=alllist.lstrip()
#array = alllist.split(",")
#array = whitelist
array = whitelist
array

wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(symbols,columns =['Indicator'])
final.set_index(['Indicator'],inplace=True)
#final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            dflive=dflive.loc[(dflive.open_time>start)]
            
            if dflive.size > 300 :
                
                
                

                dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
                dflive['RSI'] = FRSI(dflive['c'])
                dflive['STRSI'] = STRSIA(dflive['c'])[0]
                dflive['STRSIK'] = STRSIA(dflive['c'])[1]
                dflive['STRSID'] = STRSIA(dflive['c'])[2]
                dflive['SMA21'] = SMA(dflive['c'],21)
                dflive['SMA55'] = SMA(dflive['c'],55)
                dflive['SMA100'] = SMA(dflive['c'],100)
                dflive['SMA200'] = SMA(dflive['c'],200)
                dflive['MACD'] = MMACD(dflive['c'])[0]
                dflive['MACDSIGNAL'] = MMACD(dflive['c'])[1]
                dflive['BTTOMP'] = FBOTTOMP(dflive['l'],10)
                dflive['TPP'] = FTOPP(dflive['h'],10)


                
                



                #print(dflive)


                lastrow = dflive.iloc[-1]
                beforelast = dflive.iloc[-2]
                row5minus = dflive.iloc[-10]
                O = float(lastrow.o)
                C = float(lastrow.c)
                H = float(lastrow.h)
                L = float(lastrow.l)
                V = float(lastrow.v)
                OM = float(beforelast.o)
                CM = float(beforelast.c)
                HM = float(beforelast.h)
                LM = float(beforelast.l)
                VM = float(beforelast.v)
                RSI = float(lastrow.RSI)
                RSIM = float(beforelast.RSI)
                STRSI = float(lastrow.STRSI)
                STRSIK = float(lastrow.STRSIK)
                STRSIKM = float(beforelast.STRSIK)
                STRSID = float(lastrow.STRSID)
                STRSIDM = float(beforelast.STRSID)
                SMA21 = float(lastrow.SMA21)
                SMA21M = float(beforelast.SMA21)
                SMA55 = float(lastrow.SMA55)
                SMA55M = float(beforelast.SMA55)
                SMA100 = float(lastrow.SMA100)
                SMA100M = float(beforelast.SMA100)
                SMA200 = float(lastrow.SMA200)
                SMA200M = float(beforelast.SMA200)
                MACD = float(lastrow.MACD)
                MACDSIGNAL = float(lastrow.MACDSIGNAL)
                MACDM = float(beforelast.MACD)
                MACDSIGNALM = float(beforelast.MACDSIGNAL)
                BTTOMP = lastrow.BTTOMP
                TPP = lastrow.TPP
                BTTOMPM = row5minus.BTTOMP
                TPPM = row5minus.TPP


                tuple =(symbol,O,C,H,L,V,OM,CM,HM,LM,VM,RSI,RSIM,STRSI,STRSIK,STRSIKM,STRSID,STRSIDM,SMA21,SMA21M,SMA55,SMA55M,SMA100,SMA100M,SMA200,SMA200M,MACD,MACDSIGNAL,MACDM,MACDSIGNALM,BTTOMP,TPP,BTTOMPM,TPPM)
                table.append(tuple)
                #print(table)
                del dflive
            else:
                pass
            #print("name is: ",array[0])


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','O','C','H','L','V','OM','CM','HM','LM','VM','RSI','RSIM','STRSI','STRSIK','STRSIKM','STRSID','STRSIDM','SMA21','SMA21M','SMA55','SMA55M','SMA100','SMA100M','SMA200','SMA200M','MACD','MACDSIGNAL','MACDM','MACDSIGNALM','BOTTOMP','TOPP','BOTTOMPM','TOPPM'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'O':('O'+interval),'OM':('OM'+interval),'C':('C'+interval),'CM':('CM'+interval),'H':('H'+interval),'HM':('HM'+interval),'L':('L'+interval),'LM':('LM'+interval),'V':('V'+interval),'VM':('VM'+interval),'RSI':('RSI'+interval),\
                                 'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSIKM':('STRSIKM'+interval),\
                                 'STRSID':('STRSID'+interval),'STRSIDM':('STRSIDM'+interval),'SMA21':('SMA21'+interval),'SMA21M':('SMA21M'+interval),\
                                 'SMA55':('SMA55'+interval),'SMA55M':('SMA55M'+interval),'SMA100':('SMA100'+interval),'SMA100M':('SMA100M'+interval),\
                                 'SMA200':('SMA200'+interval),'SMA200M':('SMA200M'+interval),'MACD':('MACD'+interval),'MACDSIGNAL':('MACDSIGNAL'+interval),'MACDM':('MACDM'+interval),'MACDSIGNALM':('MACDSIGNALM'+interval),'BOTTOMP':('BOTTOMP'+interval),'TOPP':('TOPP'+interval),'BOTTOMPM':('BOTTOMPM'+interval),'TOPPM':('TOPPM'+interval)})
    #test.set_index(['Indicator'],inplace=True)
    final=final.merge(test,how='left',on=['Indicator'])
    final=final.drop_duplicates(subset='Indicator',keep='last')
    #final.set_index(['Indicator'],inplace=True)

    del test
    ## add the current date column
            
final['Time'] = pd.to_datetime('today')

#final
#final.reset_index(inplace=True)

# %%
#final.Indicator

# %%
import os.path

file_exists = os.path.exists("MLDATATOP"+str(date.today())+".csv")



#final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
#final['Time'] = pd.to_datetime('today')
#final.to_csv("MLDATATOP.csv")
#final.to_csv("MLSTRSIMACDBTTOP.csv")
if file_exists :
    final.to_csv("MLDATATOP"+str(date.today())+".csv", mode='a', index=True, header=False)
else :
    final.to_csv("MLDATATOP"+str(date.today())+".csv")
    
#final.to_csv("MLDATATOP"+str(date.today())+".csv")
## adding to two files the first file i thought there is a column missmatch
#final.to_csv('MLSTRSIMACDBTTOP.csv', mode='a', index=True, header=False)
final.to_csv('MLDATATOP.csv', mode='a', index=True, header=False)
#final.reset_index(inplace=True)

final.head()
# Out:
#    Indicator       O5m       C5m       H5m       L5m         V5m      OM5m  \
# 10  ANKRUSDT   0.04017   0.04007   0.04017   0.04007   122613.70   0.04017
# 21  AVAXUSDT  26.38000  26.39000  26.41000  26.33000    11398.82  26.48000
# 32  WAXPUSDT   0.13370   0.13370   0.13380   0.13350   105016.00   0.13370
# 43  REEFUSDT   0.00454   0.00453   0.00455   0.00453  2325873.00   0.00455
# 54  LINKUSDT   7.95000   7.93000   7.97000   7.92000    20410.11   7.97000
#
#         CM5m      HM5m      LM5m  ...  SMA200M1w     MACD1w  MACDSIGNAL1w  \
# 10   0.04018   0.04024   0.04016  ...        NaN  -0.029676     -0.026902
# 21  26.38000  26.50000  26.37000  ...        NaN -28.386248    -21.782894
# 32   0.13370   0.13380   0.13340  ...        NaN  -0.146982     -0.138353
# 43   0.00455   0.00455   0.00454  ...        NaN  -0.007150     -0.007188
# 54   7.95000   7.97000   7.94000  ...        NaN  -7.687530     -7.544872
#
#       MACDM1w  MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w    TOPPM1w  \
# 10  -0.030210      -0.025515    0.02504   0.09761     0.05107    0.10295
# 21 -27.535423     -18.481217   21.35000  98.08000    64.25000  103.62000
# 32  -0.150811      -0.134038    0.08010   0.38560     0.24170    0.39500
# 43  -0.007411      -0.007207    0.00274   0.01257     0.00788    0.01430
# 54  -8.016431      -7.473542    5.53000  18.08000    11.40000   19.54000
#
#                          Time
# 10 2022-06-06 09:57:35.436539
# 21 2022-06-06 09:57:35.436539
# 32 2022-06-06 09:57:35.436539
# 43 2022-06-06 09:57:35.436539
# 54 2022-06-06 09:57:35.436539
#
# [5 rows x 365 columns]

# %%
final.tail()
# Out:
#      Indicator      O5m      C5m      H5m     L5m       V5m     OM5m     CM5m  \
# 546   BANDUSDT  1.71900  1.71800  1.71900  1.7170     621.1  1.72200  1.72200
# 557  1INCHUSDT  0.88100  0.87900  0.88100  0.8790    4189.9  0.88200  0.88200
# 568  AUDIOUSDT  0.42000  0.41900  0.42000  0.4190   31409.1  0.42100  0.42000
# 579   IOTXUSDT  0.03516  0.03515  0.03516  0.0351  142380.0  0.03523  0.03516
# 590   CTSIUSDT  0.22490  0.22440  0.22490  0.2242   64294.0  0.22450  0.22490
#
#         HM5m     LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w   MACDM1w  \
# 546  1.72200  1.72200  ...        NaN -2.518348     -2.433749 -2.582067
# 557  0.88200  0.88100  ...        NaN -0.875332     -0.859259 -0.889159
# 568  0.42200  0.42000  ...        NaN -0.597304     -0.534968 -0.598807
# 579  0.03523  0.03516  ...        NaN -0.029308     -0.025293 -0.028904
# 590  0.22550  0.22420  ...        NaN -0.191208     -0.194365 -0.201459
#
#      MACDSIGNALM1w  BOTTOMP1w   TOPP1w  BOTTOMPM1w  TOPPM1w  \
# 546      -2.391450    1.27300  5.58700     3.07600  5.63500
# 557      -0.851222    0.70500  2.00400     1.18100  2.10000
# 568      -0.503801    0.29700  1.82200     0.65300  1.82200
# 579      -0.023285    0.02139  0.10273     0.06206  0.12078
# 590      -0.195944    0.12780  0.50110     0.28170  0.56200
#
#                           Time
# 546 2022-06-06 09:57:35.436539
# 557 2022-06-06 09:57:35.436539
# 568 2022-06-06 09:57:35.436539
# 579 2022-06-06 09:57:35.436539
# 590 2022-06-06 09:57:35.436539
#
# [5 rows x 365 columns]

# %%
HIHI15m = (final['TOPP15m'] > final['TOPPM15m'])
HIHI1h = (final['TOPP1h'] > final['TOPPM1h'])
HIHI2h = (final['TOPP2h'] > final['TOPPM2h'])
HIHI30m = (final['TOPP30m'] > final['TOPPM30m'])
HIHI4h = (final['TOPP4h'] > final['TOPPM4h'])
HIHI5m = (final['TOPP5m'] > final['TOPPM5m'])
HILO15m = (final['BOTTOMP15m'] > final['BOTTOMPM15m'])
HILO1h = (final['BOTTOMP1h'] > final['BOTTOMPM1h'])
HILO2h = (final['BOTTOMP2h'] > final['BOTTOMPM2h'])
HILO30m = (final['BOTTOMP30m'] > final['BOTTOMPM30m'])
HILO4h = (final['BOTTOMP4h'] > final['BOTTOMPM4h'])
HILO5m = (final['BOTTOMP5m'] > final['BOTTOMPM5m'])
LOHI15m = (final['TOPP15m'] < final['TOPPM15m'])
LOHI1h = (final['TOPP1h'] < final['TOPPM1h'])
LOHI2h = (final['TOPP2h'] < final['TOPPM2h'])
LOHI30m = (final['TOPP30m'] < final['TOPPM30m'])
LOHI4h = (final['TOPP4h'] < final['TOPPM4h'])
LOHI5m = (final['TOPP5m'] < final['TOPPM5m'])
LOLO15m = (final['BOTTOMP15m'] < final['BOTTOMPM15m'])
LOLO1h = (final['BOTTOMP1h'] < final['BOTTOMPM1h'])
LOLO2h = (final['BOTTOMP2h'] < final['BOTTOMPM2h'])
LOLO30m = (final['BOTTOMP30m'] < final['BOTTOMPM30m'])
LOLO4h = (final['BOTTOMP4h'] < final['BOTTOMPM4h'])
LOLO5m = (final['BOTTOMP5m'] < final['BOTTOMPM5m'])




MACDCROSS12h =  (final['MACD12h'] > final['MACDSIGNAL12h'])
MACDCROSS1d =  (final['MACD1d'] > final['MACDSIGNAL1d'])
MACDCROSS1w =  (final['MACD1w'] > final['MACDSIGNAL1w'])
MACDCROSS3d =  (final['MACD3d'] > final['MACDSIGNAL3d'])
MACDCROSS4h =  (final['MACD4h'] > final['MACDSIGNAL4h'])
MACDCROSS8h =  (final['MACD8h'] > final['MACDSIGNAL8h'])

MACDD12h = (final['MACD12h'] < final['MACDM12h'])
MACDD1d = (final['MACD1d'] < final['MACDM1d'])
MACDD1w = (final['MACD1w'] < final['MACDM1w'])
MACDD3d = (final['MACD3d'] < final['MACDM3d'])
MACDD4h = (final['MACD4h'] < final['MACDM4h'])
MACDD8h = (final['MACD8h'] < final['MACDM8h'])

MACDGAPD12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) > (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPD1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) > (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPD1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) > (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPD3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) > (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPD4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) > (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPD8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) > (final['MACDM8h'] - final['MACDSIGNALM8h']) )
MACDGAPU12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) < (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPU1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) < (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPU1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) < (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPU3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) < (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPU4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) < (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPU8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) < (final['MACDM8h'] - final['MACDSIGNALM8h']) )

MACDU12h = (final['MACD12h'] > final['MACDM12h'])
MACDU1d = (final['MACD1d'] > final['MACDM1d'])
MACDU1w = (final['MACD1w'] > final['MACDM1w'])
MACDU3d = (final['MACD3d'] > final['MACDM3d'])
MACDU4h = (final['MACD4h'] > final['MACDM4h'])
MACDU8h = (final['MACD8h'] > final['MACDM8h'])

bottom12h = (final['STRSIK12h']< 0.2)
bottom1d = (final['STRSIK1d']< 0.2)
bottom1h = (final['STRSIK1h']< 0.2)
bottom1w = (final['STRSIK1w']< 0.2)
bottom2h = (final['STRSIK2h']< 0.2)
bottom3d = (final['STRSIK3d']< 0.2)
bottom4h = (final['STRSIK4h']< 0.2)
bottom8h = (final['STRSIK8h']< 0.2)
bottom30m = (final['STRSIK30m'] < 0.2)
bottom15m = (final['STRSIK15m'] < 0.2)
bottom5m = (final['STRSIK5m'] < 0.2)

bottomr12h = (final['RSI12h'] < 30)
bottomr1d = (final['RSI1d'] < 30)
bottomr1h = (final['RSI1h'] < 30)
bottomr1w = (final['RSI1w'] < 30)
bottomr2h = (final['RSI2h'] < 30)
bottomr3d = (final['RSI3d'] < 30)
bottomr4h = (final['RSI4h'] < 30)
bottomr8h = (final['RSI8h'] < 30)
bottomr30m = (final['RSI30m'] < 30)
bottomr15m = (final['RSI15m'] < 30)
bottomr5m = (final['RSI5m'] < 30)






room12h = (final['STRSIK12h'] < 0.8)
room1d = (final['STRSIK1d'] < 0.8)
room1h = (final['STRSIK1h'] < 0.8)
room1w = (final['STRSIK1w'] < 0.8)
room2h = (final['STRSIK2h'] < 0.8)
room3d = (final['STRSIK3d'] < 0.8)
room4h = (final['STRSIK4h'] < 0.8)
room8h = (final['STRSIK8h'] < 0.8)
room30m = (final['STRSIK30m'] < 0.8)
room15m = (final['STRSIK15m'] < 0.8)
room5m = (final['STRSIK5m'] < 0.8)


roomr12h = (final['RSI12h'] < 70)
roomr1d = (final['RSI1d'] < 70)
roomr1h = (final['RSI1h'] < 70)
roomr1w = (final['RSI1w'] < 70)
roomr2h = (final['RSI2h'] < 70)
roomr3d = (final['RSI3d'] < 70)
roomr4h = (final['RSI4h'] < 70)
roomr8h = (final['RSI8h'] < 70)
roomr30m = (final['RSI30m'] < 70)
roomr15m = (final['RSI15m'] < 70)
roomr5m = (final['RSI5m'] < 70)


rule12hRSIdown = (final['RSI12h'] < final['RSIM12h'])
rule12hRSIup = (final['RSI12h'] > final['RSIM12h'])
rule12hkdown = (final['STRSIK12h'] < final['STRSIKM12h'])
rule12hkup = (final['STRSIK12h'] > final['STRSIKM12h'])
rule12hover = (final['STRSIK12h'] > final['STRSID12h'])
rule12hunder = (final['STRSIK12h'] < final['STRSID12h'])
rule1hRSIdown = (final['RSI1h'] < final['RSIM1h'])
rule1hRSIup = (final['RSI1h'] > final['RSIM1h'])
rule1dRSIdown = (final['RSI1d'] < final['RSIM1d'])
rule1dRSIup = (final['RSI1d'] > final['RSIM1d'])
rule1dkdown = (final['STRSIK1d']< final['STRSIKM1d'])
rule1dkup = (final['STRSIK1d'] > final['STRSIKM1d'])
rule1dover = (final['STRSIK1d'] > final['STRSID1d'])
rule1dunder = (final['STRSIK1d']< final['STRSID1d'])
rule1hkdown = (final['STRSIK1h']< final['STRSIKM1h'])
rule1hkup = (final['STRSIK1h'] > final['STRSIKM1h'])
rule1hover = (final['STRSIK1h'] > final['STRSID1h'])
rule1hunder = (final['STRSIK1h']< final['STRSID1h'])
rule1wRSIdown = (final['RSI1w'] < final['RSIM1w'])
rule1wRSIup = (final['RSI1w'] > final['RSIM1w'])
rule1wkdown = (final['STRSIK1w']< final['STRSIKM1w'])
rule1wkup = (final['STRSIK1w'] > final['STRSIKM1w'])
rule1wover = (final['STRSIK1w'] > final['STRSID1w'])
rule1wunder = (final['STRSIK1w']< final['STRSID1w'])
rule2hRSIdown = (final['RSI2h'] < final['RSIM2h'])
rule2hRSIup = (final['RSI2h'] > final['RSIM2h'])
rule2hkdown = (final['STRSIK2h']< final['STRSIKM2h'])
rule2hkup = (final['STRSIK2h'] > final['STRSIKM2h'])
rule2hover = (final['STRSIK2h'] > final['STRSID2h'])
rule2hunder = (final['STRSIK2h']< final['STRSID2h'])
rule3dRSIdown = (final['RSI3d'] < final['RSIM3d'])
rule3dRSIup = (final['RSI3d'] > final['RSIM3d'])
rule3dkdown = (final['STRSIK3d']< final['STRSIKM3d'])
rule3dkup = (final['STRSIK3d'] > final['STRSIKM3d'])
rule3dover = (final['STRSIK3d'] > final['STRSID3d'])
rule3dunder = (final['STRSIK3d']< final['STRSID3d'])
rule4hRSIdown = (final['RSI4h'] < final['RSIM4h'])
rule4hRSIup = (final['RSI4h'] > final['RSIM4h'])
rule4hkdown = (final['STRSIK4h']< final['STRSIKM4h'])
rule4hkup = (final['STRSIK4h'] > final['STRSIKM4h'])
rule4hover = (final['STRSIK4h'] > final['STRSID4h'])
rule4hunder = (final['STRSIK4h']< final['STRSID4h'])

rule8hRSIdown = (final['RSI8h'] < final['RSIM8h'])
rule8hRSIup = (final['RSI8h'] > final['RSIM8h'])
rule8hkdown = (final['STRSIK8h']< final['STRSIKM8h'])
rule8hkup = (final['STRSIK8h'] > final['STRSIKM8h'])
rule8hover = (final['STRSIK8h'] > final['STRSID8h'])
rule8hunder = (final['STRSIK8h']< final['STRSID8h'])

rule30mRSIdown = (final['RSI30m'] < final['RSIM30m'])
rule30mRSIup = (final['RSI30m'] > final['RSIM30m'])
rule30mkdown = (final['STRSIK30m']< final['STRSIKM30m'])
rule30mkup = (final['STRSIK30m'] > final['STRSIKM30m'])
rule30mover = (final['STRSIK30m'] > final['STRSID30m'])
rule30munder = (final['STRSIK30m']< final['STRSID30m'])

rule15mRSIdown = (final['RSI15m'] < final['RSIM15m'])
rule15mRSIup = (final['RSI15m'] > final['RSIM15m'])
rule15mkdown = (final['STRSIK15m']< final['STRSIKM15m'])
rule15mkup = (final['STRSIK15m'] > final['STRSIKM15m'])
rule15mover = (final['STRSIK15m'] > final['STRSID15m'])
rule15munder = (final['STRSIK15m']< final['STRSID15m'])

rule5mRSIdown = (final['RSI5m'] < final['RSIM5m'])
rule5mRSIup = (final['RSI5m'] > final['RSIM5m'])
rule5mkdown = (final['STRSIK5m']< final['STRSIKM5m'])
rule5mkup = (final['STRSIK5m'] > final['STRSIKM5m'])
rule5mover = (final['STRSIK5m'] > final['STRSID5m'])
rule5munder = (final['STRSIK5m']< final['STRSID5m'])

shift12h = (rule12hunder & (rule12hkup | rule12hRSIup))
shift1d = (rule1dunder & (rule1dkup | rule1dRSIup))
shift1h = (rule1hunder & (rule1hkup | rule1hRSIup))
shift1w = (rule1wunder & (rule1wkup | rule1wRSIup))
shift2h = (rule2hunder & (rule2hkup | rule2hRSIup))
shift3d = (rule3dunder & (rule3dkup | rule3dRSIup))
shift4h = (rule4hunder & (rule4hkup | rule4hRSIup))
shift8h = (rule8hunder & (rule8hkup | rule8hRSIup))
shift30m = (rule30munder & (rule30mkup | rule30mRSIup))
shift15m = (rule15munder & (rule15mkup | rule15mRSIup))
shift5m = (rule5munder & (rule5mkup | rule5mRSIup))



stk12hcross = (final['STRSIKM12h'] < final['STRSIDM12h']) & (final['STRSIK12h'] > final['STRSID12h'])
stk15mcross = (final['STRSIKM15m'] < final['STRSIDM15m']) & (final['STRSIK15m'] > final['STRSID15m'])
stk1hcross = (final['STRSIKM1h'] < final['STRSIDM1h']) & (final['STRSIK1h'] > final['STRSID1h'])
stk1dcross = (final['STRSIKM1d'] < final['STRSIDM1d']) & (final['STRSIK1d'] > final['STRSID1d'])
stk1wcross = (final['STRSIKM1w'] < final['STRSIDM1w']) & (final['STRSIK1w'] > final['STRSID1w'])
stk2hcross = (final['STRSIKM2h'] < final['STRSIDM2h']) & (final['STRSIK2h'] > final['STRSID2h'])
stk30mcross = (final['STRSIKM30m'] < final['STRSIDM30m']) & (final['STRSIK30m'] > final['STRSID30m'])
stk3dcross = (final['STRSIKM3d'] < final['STRSIDM3d']) & (final['STRSIK3d'] > final['STRSID3d'])
stk4hcross = (final['STRSIKM4h'] < final['STRSIDM4h']) & (final['STRSIK4h'] > final['STRSID4h'])
stk5mcross = (final['STRSIKM5m'] < final['STRSIDM5m']) & (final['STRSIK5m'] > final['STRSID5m'])
stk8hcross = (final['STRSIKM8h'] < final['STRSIDM8h']) & (final['STRSIK8h'] > final['STRSID8h'])

top12h = (final['STRSIK12h'] > 0.8)
top1d = (final['STRSIK1d'] > 0.8)
top1h = (final['STRSIK1h'] > 0.8)
top1w = (final['STRSIK1w'] > 0.8)
top2h = (final['STRSIK2h'] > 0.8)
top3d = (final['STRSIK3d'] > 0.8)
top4h = (final['STRSIK4h'] > 0.8)
top8h = (final['STRSIK8h'] > 0.8)
top30m = (final['STRSIK30m'] > 0.8)
top15m = (final['STRSIK15m'] > 0.8)
top5m = (final['STRSIK5m'] > 0.8)



topr12h = (final['RSI12h'] > 70)
topr1d = (final['RSI1d'] > 70)
topr1h = (final['RSI1h'] > 70)
topr1w = (final['RSI1w'] > 70)
topr2h = (final['RSI2h'] > 70)
topr3d = (final['RSI3d'] > 70)
topr4h = (final['RSI4h'] > 70)
topr8h = (final['RSI8h'] > 70)
topr30m = (final['RSI30m'] > 70)
topr15m = (final['RSI15m'] > 70)
topr5m = (final['RSI5m'] > 70)




uptrend12h = (rule12hover & (rule12hkup & rule12hRSIup))
uptrend1d = (rule1dover & (rule1dkup & rule1dRSIup))
uptrend1h = (rule1hover & (rule1hkup & rule1hRSIup))
uptrend1w = (rule1wover & (rule1wkup & rule1wRSIup))
uptrend2h = (rule2hover & (rule2hkup & rule2hRSIup))
uptrend3d = (rule3dover & (rule3dkup & rule3dRSIup))
uptrend4h = (rule4hover & (rule4hkup & rule4hRSIup))
uptrend8h = (rule8hover & (rule8hkup & rule8hRSIup))
uptrend30m = (rule30mover & (rule30mkup & rule30mRSIup))
uptrend15m = (rule15mover & (rule15mkup & rule15mRSIup))
uptrend5m = (rule5mover & (rule5mkup & rule5mRSIup))




downtrend12h = (rule12hunder & (rule12hkdown & rule12hRSIdown))
downtrend1d = (rule1dunder & (rule1dkdown & rule1dRSIdown))
downtrend1h = (rule1hunder & (rule1hkdown & rule1hRSIdown))
downtrend1w = (rule1wunder & (rule1wkdown & rule1wRSIdown))
downtrend2h = (rule2hunder & (rule2hkdown & rule2hRSIdown))
downtrend3d = (rule3dunder & (rule3dkdown & rule3dRSIdown))
downtrend4h = (rule4hunder & (rule4hkdown & rule4hRSIdown))
downtrend8h = (rule8hunder & (rule8hkdown & rule8hRSIdown))
downtrend30m = (rule30munder & (rule30mkdown & rule30mRSIdown))
downtrend15m = (rule15munder & (rule15mkdown & rule15mRSIdown))
downtrend5m = (rule5munder & (rule5mkdown & rule5mRSIdown))


dshift12h = (rule12hover & (rule12hkdown | rule12hRSIdown))
dshift1d = (rule1dover & (rule1dkdown | rule1dRSIdown))
dshift1h = (rule1hover & (rule1hkdown | rule1hRSIdown))
dshift1w = (rule1wover & (rule1wkdown | rule1wRSIdown))
dshift2h = (rule2hover & (rule2hkdown | rule2hRSIdown))
dshift3d = (rule3dover & (rule3dkdown | rule3dRSIdown))
dshift4h = (rule4hover & (rule4hkdown | rule4hRSIdown))
dshift8h = (rule8hover & (rule8hkdown | rule8hRSIdown))
dshift30m = (rule30mover & (rule30mkdown | rule30mRSIdown))
dshift15m = (rule15mover & (rule15mkdown | rule15mRSIdown))
dshift5m = (rule5mover & (rule5mkdown | rule5mRSIdown))

# %%
wshift = final.loc[shift1w]
wshift
# Out:
#      Indicator      O5m      C5m      H5m      L5m         V5m     OM5m  \
# 109    ZRXUSDT  0.42610  0.42530  0.42610  0.42520    28076.00  0.42510
# 239   CAKEUSDT  4.45000  4.44000  4.45200  4.43800     3580.40  4.45500
# 283   LINAUSDT  0.00977  0.00976  0.00978  0.00974   428861.93  0.00980
# 491    ZILUSDT  0.05190  0.05177  0.05191  0.05172  1264069.60  0.05196
# 535    FTMUSDT  0.37380  0.37310  0.37400  0.37290   328842.00  0.37370
# 568  AUDIOUSDT  0.42000  0.41900  0.42000  0.41900    31409.10  0.42100
# 579   IOTXUSDT  0.03516  0.03515  0.03516  0.03510   142380.00  0.03523
#
#         CM5m     HM5m     LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w  \
# 109  0.42630  0.42630  0.42480  ...        NaN -0.236145     -0.204119
# 239  4.44800  4.45600  4.44800  ...        NaN -4.610669     -4.414374
# 283  0.00977  0.00980  0.00976  ...        NaN -0.019377     -0.019416
# 491  0.05191  0.05200  0.05188  ...        NaN -0.018169     -0.011594
# 535  0.37390  0.37460  0.37350  ...        NaN -0.726179     -0.663086
# 568  0.42000  0.42200  0.42000  ...        NaN -0.597304     -0.534968
# 579  0.03516  0.03523  0.03516  ...        NaN -0.029308     -0.025293
#
#       MACDM1w  MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w   TOPPM1w  \
# 109 -0.236902      -0.188106    0.29650   1.18380     0.45000   0.95000
# 239 -4.661598      -4.316227    3.28800  10.99000     5.30000  10.99000
# 283 -0.019917      -0.019435    0.00575   0.03480     0.01633   0.03160
# 491 -0.017098      -0.008307    0.03999   0.16411     0.03317   0.23070
# 535 -0.734478      -0.631540    0.23960   1.64570     1.03450   2.40380
# 568 -0.598807      -0.503801    0.29700   1.82200     0.65300   1.82200
# 579 -0.028904      -0.023285    0.02139   0.10273     0.06206   0.12078
#
#                           Time
# 109 2022-06-06 09:57:35.436539
# 239 2022-06-06 09:57:35.436539
# 283 2022-06-06 09:57:35.436539
# 491 2022-06-06 09:57:35.436539
# 535 2022-06-06 09:57:35.436539
# 568 2022-06-06 09:57:35.436539
# 579 2022-06-06 09:57:35.436539
#
# [7 rows x 365 columns]

# %% [markdown]
# # Summary  draft rules

# %%
#final.reset_index(inplace=True)

#final.set_index(['Indicator'],inplace=True)

# drop = final.loc[bottom4h & (shift4h | rule4over)]
#drop = final.loc[(bottom4h | (uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[((uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[(uptrend8h | shift8h) & (uptrend12h | shift12h) & (uptrend1d | shift1d)]
#drop = final.loc[(uptrend2h | shift2h) & (uptrend4h | shift4h) ]
#drop = final.loc[(uptrend4h | shift4h)]

#drop = final.loc[bottom8h | (shift8h | rule8over)]
#drop = final.loc[bottom12h | (shift12h | rule12over)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[bottom12h | (shift12h | uptrend12h)]
#drop = final.loc[bottom1d | (shift1d | uptrend1d)]
#drop = final.loc[top4h]
#drop = final.loc[(uptrend3d)]
#drop = final.loc[dshift4h]
#drop = final.loc[shift2h]

#drop = final.loc[(bottom4h & bottom12h & bottom3d)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[(downtrend8h & downtrend4h & downtrend12h)]
#drop = final.loc[(bottom4h & bottom2h & bottom3d)]
#drop = final.loc[shift3d & bottom4h]

#drop = final.loc[(bottom12h)]
#drop = final.loc[ ((rule4kup |rule4RSIup))]

#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend4h | shift4h) ]
#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) ]

# 4 hours will go down or slow down
#drop = final.loc[( (bottom3d) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) & dshift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) &  (uptrend2h | shift2h) &  (uptrend1h | shift1h)]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]

#drop = final.loc[( (bottom4h) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h)) ]
#drop = final.loc[((bottom1d) & (bottom3d))]
#drop = drop.loc[( (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h))]
#drop = final.loc[dshift4h]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) & (downtrend2h |dshift2h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[dshift2h]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h) & (bottom2h))]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h))]

#drop= final.loc[(shift4h) & (shift12h)]
#drop = final.loc[(dshift4h | downtrend4h)]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (dshift4h | downtrend4h))]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (shift2h))]

#drop = final.loc[downtrend1d & downtrend12h & downtrend8h & downtrend4h]
#drop = final.loc[top8h]

#drop



    

#bottomtable['bottoms'] = bottomtable.apply(get_key(listb,bottomtable.loc('Indicator'),axis=1)

#bottomtable
#reversetable
#bottomstable = pd.DataFrame(reversetable,columns=['Indicator','Bottoms'])
#print (bottomstable)
#listb
#listd = pd.DataFrame(listb,columns=['Bottoms','Indicator'])
#print (listb)
#print(reversetable)
#listd.head()
#test = final.loc[(MACDGAP3d)]
test = final.loc[(MACDCROSS3d)]
test = final.loc[(MACDCROSS1d)]
test = final.loc[(MACDGAPU3d)]
test = final.loc[(MACDGAPD3d)& rule3dover & rule3dRSIup]
#macd3d = final.loc[(MACDGAPU3d)& rule3dRSIup]
macd1d = final.loc[(MACDGAPD1d)& rule1dRSIup]
macd3du = final.loc[(MACDGAPU3d)]
macd3dd = final.loc[(MACDGAPD3d)]
macd1du = final.loc[(MACDGAPU1d)]
macd1dd = final.loc[(MACDGAPD1d)]
macd1wu = final.loc[(MACDGAPU1w)]
macd1wd = final.loc[(MACDGAPD1w)]

macd3d1d = final.loc[(MACDGAPD1d &  (MACDGAPD3d)  & rule3dRSIup & rule1dRSIup )]
macd1dcross = final.loc[MACDCROSS1d]
macd12hcross = final.loc[MACDCROSS12h]
macd8hcross = final.loc[MACDCROSS8h]
macd4hcross = final.loc[MACDCROSS4h]
macd3dcross = final.loc[MACDCROSS3d]
stk3d = final.loc[stk3dcross]
stk1w = final.loc[stk1wcross]
macd3dd
#macd12hcross
#macd12hcross
#macd4hcross
#macd3d1d
#macd1d
#pmacdu = macd3du[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdu['diff']=abs(macd3du['MACD3d'])-abs(macd3du['MACDSIGNAL3d'])
#pmacdu['diffm']=abs(macd3du['MACDM3d'])-abs(macd3du['MACDSIGNALM3d'])

#pmacdd = macd3dd[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdd['diff']=abs(macd3dd['MACD3d'])-abs(macd3dd['MACDSIGNAL3d'])
#pmacdd['diffm']=abs(macd3dd['MACDM3d'])-abs(macd3dd['MACDSIGNALM3d'])
#final.set_index(['Indicator'],inplace=True)

#final.reset_index(inplace=True)
test1h = final[['Indicator','BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]
#test1h = final[['BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]

test15 = final[['Indicator','BOTTOMP15m','BOTTOMPM15m','TOPP15m','TOPPM15m']]
#test15.set_index(['Indicator'],inplace=True)
test5 = final[['Indicator','BOTTOMP5m','BOTTOMPM5m','TOPP5m','TOPPM5m']]
test30 = final[['Indicator','BOTTOMP30m','BOTTOMPM30m','TOPP30m','TOPPM30m']]
#test30.set_index(['Indicator'],inplace=True)

test2h = final[['Indicator','BOTTOMP2h','BOTTOMPM2h','TOPP2h','TOPPM2h']]

test4h = final[['Indicator','BOTTOMP4h','BOTTOMPM4h','TOPP4h','TOPPM4h']]

#final.set_index(['Indicator'],inplace=True)

higherhi = test15.loc[HIHI15m & HILO15m]
#higherhi = test30.loc[HIHI30m & HILO30m]
#higherhi = test1h.loc[HIHI1h & HILO1h]
#higherhi = test2h.loc[HIHI2h & HILO2h]

#higherhi = test4h.loc[HIHI4h & HILO4h]

lowhi = test15.loc[LOHI15m & LOLO15m]
lowhi = test5.loc[LOHI5m & LOLO5m]
#lowhi = test1h.loc[LOHI1h & LOLO1h]
lowhi = test30.loc[LOHI30m & LOLO30m]
lowhi = test2h.loc[LOHI2h & LOLO2h]
lowhi = test4h.loc[LOHI4h & LOLO4h]

higherhi = test5.loc[HIHI5m & HILO5m]
higherhi = test2h.loc[HIHI2h & HILO2h]
higherhi = test4h.loc[HIHI4h & HILO4h]


#higherhi = test15.loc[HIHI15m ]
#higherhi = test.loc[HIHI1h]
#higherhi = test5.loc[HIHI5m ]
#higherlo = test5.loc[HILO5m ]
#higherlo = test15.loc[HILO15m ]


higherhi
stk3d
macd3dd
macd1wd
#macd3dd
#macd1dd
#macd1du
#lowhi
# Out:
#      Indicator        O5m        C5m        H5m        L5m           V5m  \
# 10    ANKRUSDT   0.040170   0.040070   0.040170   0.040070  1.226137e+05
# 21    AVAXUSDT  26.380000  26.390000  26.410000  26.330000  1.139882e+04
# 32    WAXPUSDT   0.133700   0.133700   0.133800   0.133500  1.050160e+05
# 43    REEFUSDT   0.004540   0.004530   0.004550   0.004530  2.325873e+06
# 54    LINKUSDT   7.950000   7.930000   7.970000   7.920000  2.041011e+04
# 65      ARUSDT  13.470000  13.460000  13.480000  13.440000  3.122200e+02
# 76    ATOMUSDT   9.510000   9.490000   9.510000   9.480000  2.234290e+03
# 87     MIRUSDT   0.273630   0.272850   0.273630   0.272280  4.216600e+04
# 98    ALGOUSDT   0.404500   0.404400   0.405000   0.403900  2.867370e+05
# 109    ZRXUSDT   0.426100   0.425300   0.426100   0.425200  2.807600e+04
# 120    XTZUSDT   2.099000   2.099000   2.100000   2.095000  1.224370e+04
# 131    KSMUSDT  71.700000  71.300000  71.700000  71.200000  2.564672e+03
# 142   NEARUSDT   5.519000   5.522000   5.523000   5.510000  2.484040e+04
# 153    WINUSDT   0.000155   0.000155   0.000155   0.000155  7.908607e+07
# 164   DENTUSDT   0.001290   0.001287   0.001290   0.001286  6.809869e+06
# 175    LRCUSDT   0.542300   0.538200   0.542600   0.538100  6.356800e+04
# 186    CRVUSDT   1.271000   1.270000   1.271000   1.269000  1.481940e+04
# 196    IMXUSDT   1.044000   1.039000   1.044000   1.038000  1.706544e+04
# 206   SCRTUSDT   1.465000   1.465000   1.465000   1.465000  9.830000e+01
# 217    RENUSDT   0.149900   0.149700   0.149900   0.149600  1.121100e+04
# 228  SUSHIUSDT   1.648000   1.643000   1.648000   1.641000  1.259890e+04
# 239   CAKEUSDT   4.450000   4.440000   4.452000   4.438000  3.580400e+03
# 250    XLMUSDT   0.147200   0.146900   0.147200   0.146700  1.501370e+05
# 261    HNTUSDT  10.050000  10.090000  10.100000  10.050000  7.110510e+03
# 272    OMGUSDT   2.594000   2.597000   2.597000   2.588000  8.179000e+03
# 283   LINAUSDT   0.009770   0.009760   0.009780   0.009740  4.288619e+05
# 294   FLUXUSDT   0.684000   0.683000   0.684000   0.683000  1.572300e+03
# 305    SRMUSDT   1.070000   1.070000   1.070000   1.069000  3.427900e+03
# 316   VTHOUSDT   0.001964   0.001958   0.001964   0.001957  6.619220e+05
# 327    ANTUSDT   1.868000   1.862000   1.869000   1.861000  5.617200e+03
# 338    RAYUSDT   0.935000   0.934000   0.936000   0.931000  1.188300e+04
# 349   ROSEUSDT   0.069460   0.069470   0.069480   0.069300  1.276926e+06
# 360   MOVRUSDT  21.800000  21.800000  21.900000  21.800000  2.792880e+02
# 371  TFUELUSDT   0.064700   0.064900   0.064900   0.064600  2.157180e+05
# 381   GLMRUSDT   1.410700   1.405000   1.411000   1.402100  3.237900e+04
# 392   COTIUSDT   0.124000   0.124000   0.124100   0.123900  2.465300e+04
# 403    ONEUSDT   0.042600   0.042570   0.042610   0.042510  4.548525e+05
# 414    VETUSDT   0.031670   0.031630   0.031700   0.031600  1.271688e+06
# 425   RUNEUSDT   3.163000   3.163000   3.166000   3.153000  1.340190e+04
# 436   CELRUSDT   0.019270   0.019220   0.019270   0.019180  2.266375e+06
# 447    ONTUSDT   0.320000   0.319700   0.320100   0.319200  6.264800e+04
# 458   GALAUSDT   0.077040   0.076950   0.077060   0.076760  1.319862e+06
# 469    GRTUSDT   0.163300   0.163300   0.163500   0.163000  1.638730e+05
# 480    DOTUSDT   9.730000   9.740000   9.740000   9.710000  8.778520e+03
# 491    ZILUSDT   0.051900   0.051770   0.051910   0.051720  1.264070e+06
# 502    FILUSDT   7.650000   7.640000   7.650000   7.630000  1.571421e+04
# 513     SCUSDT   0.005790   0.005790   0.005790   0.005790  1.231307e+06
# 524  MATICUSDT   0.621000   0.620000   0.622000   0.618000  2.157745e+05
# 535    FTMUSDT   0.373800   0.373100   0.374000   0.372900  3.288420e+05
# 546   BANDUSDT   1.719000   1.718000   1.719000   1.717000  6.211000e+02
# 557  1INCHUSDT   0.881000   0.879000   0.881000   0.879000  4.189900e+03
# 568  AUDIOUSDT   0.420000   0.419000   0.420000   0.419000  3.140910e+04
# 579   IOTXUSDT   0.035160   0.035150   0.035160   0.035100  1.423800e+05
# 590   CTSIUSDT   0.224900   0.224400   0.224900   0.224200  6.429400e+04
#
#           OM5m       CM5m       HM5m       LM5m  ...  SMA200M1w      MACD1w  \
# 10    0.040170   0.040180   0.040240   0.040160  ...        NaN   -0.029676
# 21   26.480000  26.380000  26.500000  26.370000  ...        NaN  -28.386248
# 32    0.133700   0.133700   0.133800   0.133400  ...        NaN   -0.146982
# 43    0.004550   0.004550   0.004550   0.004540  ...        NaN   -0.007150
# 54    7.970000   7.950000   7.970000   7.940000  ...        NaN   -7.687530
# 65   13.490000  13.480000  13.500000  13.470000  ...        NaN  -15.234406
# 76    9.510000   9.510000   9.520000   9.500000  ...        NaN  -10.907603
# 87    0.274100   0.273730   0.274100   0.273730  ...        NaN   -1.430011
# 98    0.404800   0.404500   0.405100   0.404300  ...        NaN   -0.447978
# 109   0.425100   0.426300   0.426300   0.424800  ...        NaN   -0.236145
# 120   2.102000   2.099000   2.104000   2.099000  ...        NaN   -1.254122
# 131  71.600000  71.600000  71.700000  71.600000  ...        NaN  -99.611279
# 142   5.533000   5.520000   5.538000   5.519000  ...        NaN   -3.072429
# 153   0.000155   0.000155   0.000155   0.000155  ...        NaN   -0.000167
# 164   0.001294   0.001290   0.001295   0.001290  ...        NaN   -0.001489
# 175   0.540000   0.542600   0.543600   0.540000  ...        NaN   -0.325859
# 186   1.272000   1.271000   1.273000   1.271000  ...        NaN   -1.087599
# 196   1.044000   1.044000   1.047000   1.043000  ...        NaN   -0.585477
# 206   1.465000   1.466000   1.466000   1.465000  ...        NaN   -1.922457
# 217   0.150000   0.149900   0.150100   0.149700  ...        NaN   -0.230103
# 228   1.647000   1.649000   1.649000   1.642000  ...        NaN   -2.954830
# 239   4.455000   4.448000   4.456000   4.448000  ...        NaN   -4.610669
# 250   0.147200   0.147100   0.147400   0.147000  ...        NaN   -0.070886
# 261   9.900000  10.050000  10.100000   9.900000  ...        NaN   -9.463000
# 272   2.599000   2.595000   2.599000   2.593000  ...        NaN   -2.258349
# 283   0.009800   0.009770   0.009800   0.009760  ...        NaN   -0.019377
# 294   0.686000   0.683000   0.686000   0.683000  ...        NaN   -0.671497
# 305   1.073000   1.070000   1.073000   1.070000  ...        NaN   -1.701530
# 316   0.001967   0.001961   0.001969   0.001961  ...        NaN   -0.002436
# 327   1.871000   1.870000   1.873000   1.868000  ...        NaN   -2.319455
# 338   0.937000   0.934000   0.938000   0.934000  ...        NaN   -2.824798
# 349   0.069760   0.069440   0.069790   0.069350  ...        NaN   -0.110427
# 360  21.800000  21.800000  21.900000  21.800000  ...        NaN -100.539975
# 371   0.065000   0.064800   0.065000   0.064800  ...        NaN   -0.097872
# 381   1.415700   1.410700   1.416000   1.408000  ...        NaN   -1.752356
# 392   0.124600   0.124100   0.124600   0.124100  ...        NaN   -0.108755
# 403   0.042650   0.042610   0.042690   0.042600  ...        NaN   -0.081041
# 414   0.031710   0.031670   0.031730   0.031660  ...        NaN   -0.029831
# 425   3.173000   3.163000   3.177000   3.158000  ...        NaN   -2.750038
# 436   0.019270   0.019260   0.019300   0.019260  ...        NaN   -0.027916
# 447   0.320700   0.320000   0.321400   0.319600  ...        NaN   -0.256045
# 458   0.077240   0.077050   0.077330   0.077010  ...        NaN   -0.099809
# 469   0.163200   0.163300   0.163400   0.163100  ...        NaN   -0.279242
# 480   9.740000   9.730000   9.750000   9.720000  ...        NaN   -9.006006
# 491   0.051960   0.051910   0.052000   0.051880  ...        NaN   -0.018169
# 502   7.640000   7.660000   7.660000   7.640000  ...        NaN  -18.936131
# 513   0.005790   0.005790   0.005800   0.005790  ...        NaN   -0.004976
# 524   0.621000   0.622000   0.622000   0.620000  ...        NaN   -0.576699
# 535   0.373700   0.373900   0.374600   0.373500  ...        NaN   -0.726179
# 546   1.722000   1.722000   1.722000   1.722000  ...        NaN   -2.518348
# 557   0.882000   0.882000   0.882000   0.881000  ...        NaN   -0.875332
# 568   0.421000   0.420000   0.422000   0.420000  ...        NaN   -0.597304
# 579   0.035230   0.035160   0.035230   0.035160  ...        NaN   -0.029308
# 590   0.224500   0.224900   0.225500   0.224200  ...        NaN   -0.191208
#
#      MACDSIGNAL1w     MACDM1w  MACDSIGNALM1w  BOTTOMP1w      TOPP1w  \
# 10      -0.026902   -0.030210      -0.025515   0.025040    0.097610
# 21     -21.782894  -27.535423     -18.481217  21.350000   98.080000
# 32      -0.138353   -0.150811      -0.134038   0.080100    0.385600
# 43      -0.007188   -0.007411      -0.007207   0.002740    0.012570
# 54      -7.544872   -8.016431      -7.473542   5.530000   18.080000
# 65     -13.649903  -15.223640     -12.857651   9.880000   40.920000
# 76      -9.276248  -10.765640      -8.460571   8.550000   32.540000
# 87      -1.384997   -1.456199      -1.362490   0.196680    2.269000
# 98      -0.428207   -0.455027      -0.418321   0.352700    0.936800
# 109     -0.204119   -0.236902      -0.188106   0.296500    1.183800
# 120     -1.223173   -1.315792      -1.207699   1.451000    4.042000
# 131    -94.860660 -101.045319     -92.485351  62.300000  202.000000
# 142     -1.676394   -2.780161      -0.978376   4.675000   19.788000
# 153     -0.000161   -0.000171      -0.000158   0.000131    0.000371
# 164     -0.001431   -0.001540      -0.001402   0.000837    0.003738
# 175     -0.301467   -0.337469      -0.289271   0.325900    1.195000
# 186     -0.969227   -1.086946      -0.910041   0.987000    2.997000
# 196     -0.659167   -0.632802      -0.696012   0.675000    1.397000
# 206     -1.938472   -1.976645      -1.946479   1.400000    3.241000
# 217     -0.220162   -0.234791      -0.215192   0.121200    0.501500
# 228     -3.050712   -3.095903      -3.098654   1.082000    4.475000
# 239     -4.414374   -4.661598      -4.316227   3.288000   10.990000
# 250     -0.071175   -0.074844      -0.071319   0.104200    0.237100
# 261     -8.882183   -9.995430      -8.591774   6.540000   28.000000
# 272     -2.158974   -2.310379      -2.109286   1.911000    6.068000
# 283     -0.019416   -0.019917      -0.019435   0.005750    0.034800
# 294     -0.589142   -0.668645      -0.547964   0.560000    2.100000
# 305     -1.653204   -1.734091      -1.629041   0.971000    3.292000
# 316     -0.002370   -0.002494      -0.002336   0.001389    0.005384
# 327     -2.123035   -2.346525      -2.024825   1.098000    6.221000
# 338     -2.813946   -2.891125      -2.808519   0.851000    3.666000
# 349     -0.092405   -0.109661      -0.083394   0.055130    0.330750
# 360   -106.759956 -104.843071    -109.869946  19.200000   89.000000
# 371     -0.090494   -0.099301      -0.086805   0.051400    0.218000
# 381     -1.919718   -1.876837      -2.003400   1.050000    2.222800
# 392     -0.101919   -0.111547      -0.098501   0.084100    0.340000
# 403     -0.075596   -0.081980      -0.072874   0.031910    0.169260
# 414     -0.028378   -0.030495      -0.027651   0.024000    0.082880
# 425     -2.146365   -2.734201      -1.844528   2.364000   11.980000
# 436     -0.026156   -0.028599      -0.025276   0.010830    0.070250
# 447     -0.250149   -0.269535      -0.247200   0.190800    0.672100
# 458     -0.087239   -0.099386      -0.080955   0.049350    0.266610
# 469     -0.271476   -0.286322      -0.267593   0.118000    0.517400
# 480     -8.398733   -9.094000      -8.095097   7.300000   23.230000
# 491     -0.011594   -0.017098      -0.008307   0.039990    0.164110
# 502    -19.042514  -19.468827     -19.095705   6.710000   26.570000
# 513     -0.004795   -0.005141      -0.004704   0.003500    0.014020
# 524     -0.495451   -0.573804      -0.454827   0.501000    1.689000
# 535     -0.663086   -0.734478      -0.631540   0.239600    1.645700
# 546     -2.433749   -2.582067      -2.391450   1.273000    5.587000
# 557     -0.859259   -0.889159      -0.851222   0.705000    2.004000
# 568     -0.534968   -0.598807      -0.503801   0.297000    1.822000
# 579     -0.025293   -0.028904      -0.023285   0.021390    0.102730
# 590     -0.194365   -0.201459      -0.195944   0.127800    0.501100
#
#      BOTTOMPM1w     TOPPM1w                       Time
# 10     0.051070    0.102950 2022-06-06 09:57:35.436539
# 21    64.250000  103.620000 2022-06-06 09:57:35.436539
# 32     0.241700    0.395000 2022-06-06 09:57:35.436539
# 43     0.007880    0.014300 2022-06-06 09:57:35.436539
# 54    11.400000   19.540000 2022-06-06 09:57:35.436539
# 65    22.190000   42.560000 2022-06-06 09:57:35.436539
# 76    21.400000   34.690000 2022-06-06 09:57:35.436539
# 87     0.994000    2.447000 2022-06-06 09:57:35.436539
# 98     0.673600    1.102000 2022-06-06 09:57:35.436539
# 109    0.450000    0.950000 2022-06-06 09:57:35.436539
# 120    2.560000    4.606000 2022-06-06 09:57:35.436539
# 131  105.200000  207.200000 2022-06-06 09:57:35.436539
# 142    7.385000   19.788000 2022-06-06 09:57:35.436539
# 153    0.000243    0.000418 2022-06-06 09:57:35.436539
# 164    0.001934    0.003989 2022-06-06 09:57:35.436539
# 175    0.626800    1.362000 2022-06-06 09:57:35.436539
# 186    1.868000    3.723000 2022-06-06 09:57:35.436539
# 196    0.675000    2.130000 2022-06-06 09:57:35.436539
# 206    1.984000    5.297000 2022-06-06 09:57:35.436539
# 217    0.247400    0.531400 2022-06-06 09:57:35.436539
# 228    2.753000    5.086000 2022-06-06 09:57:35.436539
# 239    5.300000   10.990000 2022-06-06 09:57:35.436539
# 250    0.161700    0.257100 2022-06-06 09:57:35.436539
# 261   19.480000   32.000000 2022-06-06 09:57:35.436539
# 272    3.326000    6.278000 2022-06-06 09:57:35.436539
# 283    0.016330    0.031600 2022-06-06 09:57:35.436539
# 294    1.133000    2.100000 2022-06-06 09:57:35.436539
# 305    1.652000    3.708000 2022-06-06 09:57:35.436539
# 316    0.002738    0.007077 2022-06-06 09:57:35.436539
# 327    4.089000    8.883000 2022-06-06 09:57:35.436539
# 338    2.268000    4.420000 2022-06-06 09:57:35.436539
# 349    0.181740    0.396420 2022-06-06 09:57:35.436539
# 360   44.200000  116.000000 2022-06-06 09:57:35.436539
# 371    0.135500    0.244900 2022-06-06 09:57:35.436539
# 381    1.611900    4.500000 2022-06-06 09:57:35.436539
# 392    0.170800    0.340000 2022-06-06 09:57:35.436539
# 403    0.109700    0.236000 2022-06-06 09:57:35.436539
# 414    0.039050    0.089360 2022-06-06 09:57:35.436539
# 425    3.015000   13.203000 2022-06-06 09:57:35.436539
# 436    0.030890    0.084370 2022-06-06 09:57:35.436539
# 447    0.424400    0.703500 2022-06-06 09:57:35.436539
# 458    0.177960    0.395800 2022-06-06 09:57:35.436539
# 469    0.302300    0.550700 2022-06-06 09:57:35.436539
# 480   14.050000   23.850000 2022-06-06 09:57:35.436539
# 491    0.033170    0.230700 2022-06-06 09:57:35.436539
# 502   16.500000   28.150000 2022-06-06 09:57:35.436539
# 513    0.007220    0.014740 2022-06-06 09:57:35.436539
# 524    1.245000    2.101000 2022-06-06 09:57:35.436539
# 535    1.034500    2.403800 2022-06-06 09:57:35.436539
# 546    3.076000    5.635000 2022-06-06 09:57:35.436539
# 557    1.181000    2.100000 2022-06-06 09:57:35.436539
# 568    0.653000    1.822000 2022-06-06 09:57:35.436539
# 579    0.062060    0.120780 2022-06-06 09:57:35.436539
# 590    0.281700    0.562000 2022-06-06 09:57:35.436539
#
# [54 rows x 365 columns]

# %% [markdown]
# # Functions

# %%
#DRAFT functions display
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        

## return a list of timeframes per ta indicator taname  for specific sympbol
#series to list 
def srtolist(final:pd,taname)->[]:
    #ta = globals()[taname]
    array = final[taname].values
    array= str(array[0]).split(",")
    
    #for k in range(0,len(array)):
            #print (k)
            #print (f" {taname} = {array[k]} \n")
    return array

# list to string 
def ltos (mylist)->str:
    mystring = ''
    for x in mylist:
        if not mystring:
            mystring+=x
        else:
            mystring+=","+x
    return mystring

def get_key(my_dict,val):
        keylist = []
        for key, value in my_dict.items():
             if val in value:
                keylist.append(key)
        return keylist
    
def to_df(final:pd ,func,name):
    listb = func(final)
    res = list(sorted({ele for val in listb.values() for ele in val}))
    reversetable = []
    for indi in res:
        ttuple = (indi,ltos(get_key(listb,indi)))
        reversetable.append(ttuple)
    dframe = pd.DataFrame(reversetable,columns=['Indicator',name])
    return dframe
                                                
    
def tops(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['top'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : query.append(i)
        toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def uptrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['uptrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def downtrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['downtrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def shift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['shift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def dshift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['dshift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def topr(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['topr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['bottomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottoms(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    bottomlist ={}
    for i in intervals:
        var = globals()['bottom'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            bottomlist[i]=test['Indicator'].tolist()
 
    return bottomlist

def room(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['room'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def roomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['roomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsiup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsidown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']         
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stover(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'over']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stunder(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'under']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkdown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def stkcross(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['stk'+i+'cross']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    
    return toplist


def buyzones(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        for item in lrsiup :
            if item in lroomr:
                if item in lroom:
                    buy.append(item)
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final
  


#not used but defined for later 
def mergetables(final:pd,*arg)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(arg)):
        test = indicators.merge(arg[i] ,how="left",on="Indicator")
        indicators = test
    return test

# call the function and merge the tables 
def callfun(final:pd,*var)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(var)):
        test=to_df(final ,globals()[var[i]],var[i])
        indicators=indicators.merge(test ,how="left",on="Indicator")
    return indicators


def wrjson(wl,name):
    test = json.dumps(wl)
    with open(name, "w") as wlf:
        json.dump(test, wlf,indent=4)
        
def frtolist(final:pd)->[]:
    whitelist = []
    wl = []
    whitelist = final['Indicator'].tolist()
    for i in range(0 ,len(whitelist)):
        #print (str(whitelist[i].replace('USDT',"/USDT")))
        wl.append(str(whitelist[i].replace('USDT',"/USDT")))
    return wl

# %%
newframe=callfun(final,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','shift'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['rsiup','bottoms','bottomr'],ascending=[False,False,False])

newframe.to_csv("allindi"+str(date.today())+".csv")

test = newframe.loc[(newframe['downtrend'] <= '1h')]
test = newframe.loc[(newframe['bottomr'] >= '12h')]
#test = newframe.loc[(newframe['rsidown'] >= '2h')]
#test = newframe.loc[(newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '2h,4h') & (newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '12h') & (newframe['bottomr'] >= '1') ]
#test = newframe.loc[(newframe['bottomr'] >= '1') & (newframe['rsiup'] >= '1')]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['rsidown'].notnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['shift'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['rsidown'].isnull()) & (newframe['tops'] <='4h') & (newframe['topr'].isnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['topr'].isnull()) ]

#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['topr'].isnull()) & (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['stkdown'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') ]
#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['uptrend'].notnull()) ]

#test = newframe.loc[(newframe['shift'].isnull()) &  (newframe['uptrend'].isnull()) ]

#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]
#test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]

#test = newframe.loc[(newframe['rsiup'].notnull()) & (newframe['bottoms'].notnull())  & (newframe['uptrend'].notnull())]


test = newframe.loc[(newframe['rsiup'] <= '8h') & (newframe['bottoms'].notnull())]

test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['stover'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['bottoms'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull())]

test = newframe.loc[(newframe['rsiup'] >= '1h,2h,4h') ]


#test = newframe.loc[(newframe['bottomr'] <= '12h') &  (newframe['bottoms'] <= '12h') ]
#test = newframe.loc[(newframe['bottomr'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]
#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkup'].notnull()))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]

#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h'))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h')) & (newframe['bottomr'].notnull())]




#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[(newframe['tops'].isnull()) &  (newframe['rsidown'].isnull()) ]


#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]

#test = newframe.loc[(newframe['rsiup'] <= '1w') & (newframe['bottoms'] >= '4h') &  (newframe['shift'].notnull())]


#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['rsidown'].isnull()) | (newframe['rsidown'] <= '1') ]

#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) & (newframe['downtrend'].isnull()) ]
#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) ]

#test = newframe.loc[(newframe['shift'] >= '12h,1d,3d')]

newframe

test
# Out:
#     Indicator       stkcross                                rsiup  \
# 35   COTIUSDT       4h,8h,1d                      8h,12h,1d,3d,1w
# 53   CTSIUSDT            NaN                      8h,12h,1d,3d,1w
# 41   GALAUSDT            12h                      8h,12h,1d,3d,1w
# 21   CAKEUSDT            15m                      8h,12h,1d,3d,1w
# 22    XLMUSDT             4h                      8h,12h,1d,3d,1w
# 8    ALGOUSDT             1w                      8h,12h,1d,3d,1w
# 4    LINKUSDT            15m                      8h,12h,1d,3d,1w
# 6    ATOMUSDT      12h,1d,1w                      8h,12h,1d,3d,1w
# 47  MATICUSDT         12h,1d                      8h,12h,1d,3d,1w
# 51  AUDIOUSDT         12h,1d                      8h,12h,1d,3d,1w
# 13    WINUSDT             1d                      8h,12h,1d,3d,1w
# 29    ANTUSDT         12h,1d                      8h,12h,1d,3d,1w
# 11    KSMUSDT   8h,12h,1d,1w                      8h,12h,1d,3d,1w
# 20  SUSHIUSDT          8h,1d                      8h,12h,1d,3d,1w
# 26   FLUXUSDT      8h,12h,1d                      8h,12h,1d,3d,1w
# 45    FILUSDT   1h,12h,1d,1w                      8h,12h,1d,3d,1w
# 5      ARUSDT          1d,3d                      8h,12h,1d,3d,1w
# 18   SCRTUSDT   8h,12h,3d,1w                      8h,12h,1d,3d,1w
# 28   VTHOUSDT       8h,1d,1w                      8h,12h,1d,3d,1w
# 40    ONTUSDT             1d                      8h,12h,1d,3d,1w
# 17    IMXUSDT             1d                      8h,12h,1d,3d,1w
# 7     MIRUSDT         8h,12h                         8h,12h,1d,1w
# 33  TFUELUSDT            NaN                   5m,8h,12h,1d,3d,1w
# 43    DOTUSDT             1d                   5m,8h,12h,1d,3d,1w
# 31   ROSEUSDT            15m                   5m,8h,12h,1d,3d,1w
# 27    SRMUSDT       1d,3d,1w                   5m,8h,12h,1d,3d,1w
# 12   NEARUSDT       2h,1d,1w               5m,30m,8h,12h,1d,3d,1w
# 1    AVAXUSDT             4h            5m,30m,1h,8h,12h,1d,3d,1w
# 24    OMGUSDT    1h,4h,1d,1w      5m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 23    HNTUSDT          4h,8h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 0    ANKRUSDT             2h                  30m,8h,12h,1d,3d,1w
# 36    ONEUSDT         12h,1d                  30m,8h,12h,1d,3d,1w
# 25   LINAUSDT  15m,8h,12h,1d            30m,2h,4h,8h,12h,1d,3d,1w
# 52   IOTXUSDT      4h,8h,12h               30m,1h,8h,12h,1d,3d,1w
# 50  1INCHUSDT             1w            30m,1h,2h,8h,12h,1d,3d,1w
# 19    RENUSDT      15m,1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38   RUNEUSDT         12h,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15    LRCUSDT   1h,2h,8h,12h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 10    XTZUSDT          1h,1d         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2    WAXPUSDT         30m,8h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46     SCUSDT          1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30    RAYUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 48    FTMUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 16    CRVUSDT          1d,1w                2h,4h,8h,12h,1d,3d,1w
# 14   DENTUSDT      2h,12h,1d                2h,4h,8h,12h,1d,3d,1w
# 34   GLMRUSDT            NaN                2h,4h,8h,12h,1d,3d,1w
# 32   MOVRUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 44    ZILUSDT         12h,1d                   1h,8h,12h,1d,3d,1w
# 3    REEFUSDT            12h                   1h,8h,12h,1d,3d,1w
# 49   BANDUSDT  15m,4h,12h,1d                   1h,8h,12h,1d,3d,1w
# 39   CELRUSDT      8h,12h,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 37    VETUSDT   4h,12h,1d,1w             1h,2h,4h,8h,12h,1d,3d,1w
#
#                    rsidown                 tops           bottoms  \
# 35     5m,15m,30m,1h,2h,4h            30m,1h,2h             5m,1w
# 53     5m,15m,30m,1h,2h,4h      2h,8h,12h,1d,3d     5m,15m,30m,1w
# 41     5m,15m,30m,1h,2h,4h          1h,2h,4h,8h         5m,15m,1w
# 21     5m,15m,30m,1h,2h,4h             2h,4h,8h         5m,15m,1w
# 22     5m,15m,30m,1h,2h,4h          1h,2h,1d,3d         5m,15m,1w
# 8      5m,15m,30m,1h,2h,4h       1h,2h,4h,8h,1d         5m,15m,1w
# 4      5m,15m,30m,1h,2h,4h      2h,4h,8h,12h,1d         5m,15m,1w
# 6      5m,15m,30m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 47     5m,15m,30m,1h,2h,4h                2h,4h         5m,15m,1w
# 51         5m,15m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 13        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 29     5m,15m,30m,1h,2h,4h                2h,4h     5m,15m,12h,1w
# 11     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 20     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 26        15m,30m,1h,2h,4h                1h,2h            5m,15m
# 45            5m,30m,2h,4h         30m,1h,2h,4h         15m,3d,1w
# 5          5m,15m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 18     5m,15m,30m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 28     5m,15m,30m,1h,2h,4h             1h,2h,4h            15m,1w
# 40     5m,15m,30m,1h,2h,4h          2h,4h,8h,1d            15m,1w
# 17     5m,15m,30m,1h,2h,4h          2h,4h,3d,1w               15m
# 7   5m,15m,30m,1h,2h,4h,3d                1h,2h  5m,15m,8h,12h,1w
# 33        15m,30m,1h,2h,4h      1h,2h,4h,12h,1d         5m,15m,1w
# 43                1h,2h,4h             1h,2h,4h         5m,15m,1w
# 31        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 27        15m,30m,1h,2h,4h                2h,4h         15m,3d,1w
# 12            15m,1h,2h,4h             2h,4h,1d      5m,15m,3d,1w
# 1                15m,2h,4h   30m,1h,2h,4h,8h,1d            15m,1w
# 24                     15m         30m,1h,2h,4h                1w
# 23                     NaN  5m,15m,30m,1h,2h,1d                1w
# 0          5m,15m,1h,2h,4h          1h,2h,4h,1d            15m,1w
# 36         5m,15m,1h,2h,4h                   2h            15m,1w
# 25               5m,15m,1h         30m,1h,2h,4h                1w
# 52            5m,15m,2h,4h         30m,1h,2h,4h         12h,1d,1w
# 50                  5m,15m             1h,2h,4h     15m,12h,1d,1w
# 19                      5m             1h,2h,4h             3d,1w
# 38                     15m         30m,1h,2h,1d             3d,1w
# 15                  5m,15m     15m,30m,1h,2h,4h                1w
# 10                     15m      30m,1h,2h,4h,8h                1w
# 2                      15m       5m,1h,2h,4h,1d                1w
# 46                     15m      30m,1h,2h,4h,1d                1w
# 30              15m,30m,1h             1h,2h,4h             5m,1w
# 48           5m,15m,30m,1h         30m,1h,2h,4h         5m,15m,1w
# 16           5m,15m,30m,1h             1h,2h,4h         5m,15m,1w
# 14              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
# 34           5m,15m,30m,1h       1h,2h,4h,8h,1d                5m
# 32                     NaN         30m,1h,2h,4h               15m
# 44        5m,15m,30m,2h,4h             1h,2h,4h                5m
# 3         5m,15m,30m,2h,4h             2h,4h,1d            15m,1w
# 49              5m,15m,30m      30m,1h,2h,4h,1d            15m,1w
# 39              5m,15m,30m      30m,1h,2h,4h,1d             5m,1w
# 37              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
#
#                 topr   bottomr                            stover  \
# 35               NaN       NaN                 2h,4h,8h,1d,3d,1w
# 53               NaN       NaN               15m,8h,12h,1d,3d,1w
# 41               NaN        3d                2h,8h,12h,1d,3d,1w
# 21               NaN       NaN               15m,2h,8h,12h,1d,3d
# 22               NaN       NaN                 2h,4h,8h,1d,3d,1w
# 8                NaN       NaN             1h,2h,8h,12h,1d,3d,1w
# 4              2h,4h       NaN            15m,2h,8h,12h,1d,3d,1w
# 6                NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 47               NaN       NaN                2h,8h,12h,1d,3d,1w
# 51               NaN       NaN                2h,4h,8h,12h,1d,3d
# 13               NaN       NaN             1h,2h,8h,12h,1d,3d,1w
# 29               NaN       NaN                2h,8h,12h,1d,3d,1w
# 11               NaN       NaN                2h,8h,12h,1d,3d,1w
# 20               NaN       NaN          5m,2h,4h,8h,12h,1d,3d,1w
# 26               NaN       NaN                2h,4h,8h,12h,1d,3d
# 45               NaN     3d,1w          5m,1h,2h,8h,12h,1d,3d,1w
# 5                NaN        3d            15m,2h,8h,12h,1d,3d,1w
# 18               NaN  1d,3d,1w                2h,4h,8h,12h,3d,1w
# 28               NaN       NaN             2h,4h,8h,12h,1d,3d,1w
# 40               NaN       NaN            15m,2h,8h,12h,1d,3d,1w
# 17               NaN       NaN            15m,2h,8h,12h,1d,3d,1w
# 7                NaN     3d,1w                2h,4h,8h,12h,3d,1w
# 33                1h        3d             5m,2h,8h,12h,1d,3d,1w
# 43               NaN       NaN                2h,8h,12h,1d,3d,1w
# 31               NaN       NaN             15m,2h,4h,8h,1d,3d,1w
# 27               NaN       NaN                2h,8h,12h,1d,3d,1w
# 12               NaN       NaN                    2h,8h,1d,3d,1w
# 1             30m,1h        3d                2h,4h,12h,1d,3d,1w
# 24         30m,1h,2h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 23  5m,15m,30m,1h,2h       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 0                NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 36               NaN       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 25               NaN       NaN         5m,15m,2h,4h,8h,12h,1d,3d
# 52               NaN       NaN                5m,2h,4h,8h,12h,3d
# 50               NaN       NaN               15m,2h,4h,8h,12h,1w
# 19               NaN       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 38     15m,30m,1h,2h       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 15               30m       NaN     15m,30m,1h,2h,4h,8h,12h,3d,1w
# 10     15m,30m,1h,2h       NaN      5m,15m,1h,2h,8h,12h,1d,3d,1w
# 2                NaN       NaN         5m,15m,30m,2h,4h,8h,3d,1w
# 46            30m,1h       NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 30                1h        3d             2h,4h,8h,12h,1d,3d,1w
# 48               NaN       NaN                2h,4h,8h,12h,1d,3d
# 16                1h       NaN             2h,4h,8h,12h,1d,3d,1w
# 14               NaN       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 34               NaN       NaN                4h,8h,12h,1d,3d,1w
# 32         30m,1h,2h        1w         30m,1h,2h,4h,8h,12h,1d,3d
# 44               NaN       NaN                2h,4h,8h,12h,1d,3d
# 3                NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 49               NaN       NaN      15m,1h,2h,4h,8h,12h,1d,3d,1w
# 39            30m,1h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 37                1h       NaN             2h,4h,8h,12h,1d,3d,1w
#
#                                 room                                roomr  \
# 35         5m,15m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 53               5m,15m,30m,1h,4h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 41           5m,15m,30m,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 21        5m,15m,30m,1h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 22           5m,15m,30m,4h,8h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8               5m,15m,30m,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4                5m,15m,30m,1h,3d,1w        5m,15m,30m,1h,8h,12h,1d,3d,1w
# 6         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 47     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 51        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 29     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 11        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 20        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 26        5m,15m,30m,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 45            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 18        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 28        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40           5m,15m,30m,1h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17           5m,15m,30m,1h,8h,12h,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 7      5m,15m,30m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 33               5m,15m,30m,8h,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 43        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 31            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 27     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12        5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1                   5m,15m,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 24            5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 23                   4h,8h,12h,3d,1w                   4h,8h,12h,1d,3d,1w
# 0            5m,15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 36  5m,15m,30m,1h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 25            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 52            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 50        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 19        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38            5m,15m,4h,8h,12h,3d,1w                5m,4h,8h,12h,1d,3d,1w
# 15                5m,8h,12h,1d,3d,1w      5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 10               5m,15m,12h,1d,3d,1w                5m,4h,8h,12h,1d,3d,1w
# 2               15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 30        5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 48            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16        5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 14            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 34              5m,15m,30m,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 32            5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 44        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3         5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 49               5m,15m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 39               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 37            5m,15m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
#
#                  stunder                             stkup  \
# 35     5m,15m,30m,1h,12h             2h,4h,8h,12h,1d,3d,1w
# 53       5m,30m,1h,2h,4h                      8h,12h,3d,1w
# 41      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 21       5m,30m,1h,4h,1w                   2h,8h,12h,1d,3d
# 22     5m,15m,30m,1h,12h                 2h,4h,8h,1d,3d,1w
# 8          5m,15m,30m,4h                   2h,8h,12h,1d,1w
# 4           5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 6              30m,1h,4h                2h,8h,12h,1d,3d,1w
# 47      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 51      5m,15m,30m,1h,1w                2h,8h,12h,1d,3d,1w
# 13         5m,15m,30m,4h             1h,2h,8h,12h,1d,3d,1w
# 29      5m,15m,30m,1h,4h                   2h,8h,12h,1d,3d
# 11      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 20            15m,30m,1h                2h,8h,12h,1d,3d,1w
# 26         5m,15m,30m,1h                   2h,8h,12h,1d,3d
# 45            15m,30m,4h         15m,1h,2h,8h,12h,1d,3d,1w
# 5           5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 18      5m,15m,30m,1h,1d             1h,2h,8h,12h,1d,3d,1w
# 28         5m,15m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 40          5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 17          5m,30m,1h,4h                      2h,8h,12h,1d
# 7       5m,15m,30m,1h,1d                2h,4h,8h,12h,3d,1w
# 33         15m,30m,1h,4h                5m,8h,12h,1d,3d,1w
# 43      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 31         5m,30m,1h,12h                2h,8h,12h,1d,3d,1w
# 27      5m,15m,30m,1h,4h                   8h,12h,1d,3d,1w
# 12  5m,15m,30m,1h,4h,12h             1h,2h,8h,12h,1d,3d,1w
# 1       5m,15m,30m,1h,8h                   2h,12h,1d,3d,1w
# 24            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 23               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 0              30m,1h,4h            15m,2h,8h,12h,1d,3d,1w
# 36             5m,30m,1h                2h,8h,12h,1d,3d,1w
# 25             30m,1h,1w         5m,15m,2h,4h,8h,12h,1d,3d
# 52      15m,30m,1h,1d,1w                   2h,8h,12h,1d,3d
# 50       5m,30m,1h,1d,3d                   2h,8h,12h,1d,1w
# 19               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 38             5m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 15                 5m,1d     15m,30m,1h,2h,8h,12h,1d,3d,1w
# 10                   30m      5m,15m,1h,2h,8h,12h,1d,3d,1w
# 2              1h,12h,1d         15m,30m,1h,4h,8h,1d,3d,1w
# 46                   NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 30         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 48      5m,15m,30m,1h,1w                   2h,8h,12h,1d,3d
# 16         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 14            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 34      5m,15m,30m,1h,2h                   8h,12h,1d,3d,1w
# 32                5m,15m                2h,8h,12h,1d,3d,1w
# 44      5m,15m,30m,1h,1w                      8h,12h,1d,3d
# 3              30m,1h,4h                2h,8h,12h,1d,3d,1w
# 49                5m,30m          1h,2h,4h,8h,12h,1d,3d,1w
# 39            5m,15m,30m             2h,4h,8h,12h,1d,3d,1w
# 37         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
#
#                    stkdown                      uptrend        dshift  \
# 35           5m,15m,30m,1h                  8h,1d,3d,1w         2h,4h
# 53         5m,30m,1h,2h,4h                 8h,12h,3d,1w           15m
# 41        5m,15m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 21         5m,30m,1h,4h,1w                 8h,12h,1d,3d        15m,2h
# 22           5m,30m,1h,12h                  8h,1d,3d,1w         2h,4h
# 8      5m,15m,30m,1h,4h,3d                 8h,12h,1d,1w      1h,2h,3d
# 4             5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 6             5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 47            5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 51        5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 13           5m,15m,30m,4h              8h,12h,1d,3d,1w         1h,2h
# 29     5m,15m,30m,1h,4h,1w                 8h,12h,1d,3d         2h,1w
# 11            5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 20               30m,1h,4h              8h,12h,1d,3d,1w      5m,2h,4h
# 26        5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 45               5m,30m,4h              8h,12h,1d,3d,1w         5m,2h
# 5             5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 18           5m,15m,30m,4h                 8h,12h,3d,1w         2h,4h
# 28           5m,15m,30m,1h              8h,12h,1d,3d,1w         2h,4h
# 40            5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 17      5m,30m,1h,4h,3d,1w                    8h,12h,1d  15m,2h,3d,1w
# 7            15m,30m,1h,1d                    8h,12h,1w      2h,4h,3d
# 33        15m,30m,1h,2h,4h           5m,8h,12h,1d,3d,1w            2h
# 43        5m,15m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 31            5m,30m,1h,4h                  8h,1d,3d,1w     15m,2h,4h
# 27     5m,15m,30m,1h,2h,4h              8h,12h,1d,3d,1w            2h
# 12           5m,15m,30m,4h                  8h,1d,3d,1w            2h
# 1         5m,15m,30m,1h,4h                 12h,1d,3d,1w         2h,4h
# 24              5m,15m,30m        1h,2h,8h,12h,1d,3d,1w           NaN
# 23                     NaN  5m,15m,1h,2h,4h,8h,1d,3d,1w           NaN
# 0             5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 36            5m,30m,1h,4h              8h,12h,1d,3d,1w     15m,2h,4h
# 25               30m,1h,1w           2h,4h,8h,12h,1d,3d        5m,15m
# 52     5m,15m,30m,1h,4h,1w                    8h,12h,3d      5m,2h,4h
# 50        5m,15m,30m,1h,3d                 2h,8h,12h,1w           15m
# 19                     30m         1h,2h,4h,8h,1d,3d,1w            5m
# 38              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           15m
# 15                      5m       30m,1h,2h,8h,12h,3d,1w           15m
# 10                     30m        1h,2h,8h,12h,1d,3d,1w           15m
# 2                      12h              30m,4h,8h,3d,1w           15m
# 46                     NaN    30m,1h,2h,8h,12h,1d,3d,1w           15m
# 30              15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 48        5m,15m,30m,1h,1w              2h,8h,12h,1d,3d           NaN
# 16              15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 14              5m,15m,30m           2h,8h,12h,1d,3d,1w           NaN
# 34           15m,30m,1h,2h              8h,12h,1d,3d,1w           NaN
# 32                  5m,15m              2h,8h,12h,1d,3d           NaN
# 44  5m,15m,30m,1h,2h,4h,1w                 8h,12h,1d,3d         2h,4h
# 3             5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 49              5m,15m,30m           1h,8h,12h,1d,3d,1w           15m
# 39              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           NaN
# 37           5m,15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
#
#            downtrend          shift
# 35     5m,15m,30m,1h            12h
# 53   5m,30m,1h,2h,4h            NaN
# 41  5m,15m,30m,1h,4h            NaN
# 21      5m,30m,1h,4h             1w
# 22         5m,30m,1h            12h
# 8      5m,15m,30m,4h            NaN
# 4       5m,30m,1h,4h            NaN
# 6          30m,1h,4h            NaN
# 47      5m,30m,1h,4h            NaN
# 51         5m,15m,1h             1w
# 13        15m,30m,4h            NaN
# 29  5m,15m,30m,1h,4h            NaN
# 11      5m,30m,1h,4h            NaN
# 20            30m,1h            NaN
# 26        15m,30m,1h            NaN
# 45            30m,4h            15m
# 5           5m,1h,4h            NaN
# 18        5m,15m,30m          1h,1d
# 28     5m,15m,30m,1h            NaN
# 40      5m,30m,1h,4h            NaN
# 17      5m,30m,1h,4h            NaN
# 7         15m,30m,1h             1d
# 33     15m,30m,1h,4h            NaN
# 43             1h,4h             5m
# 31            30m,1h         5m,12h
# 27     15m,30m,1h,4h             5m
# 12            15m,4h  5m,30m,1h,12h
# 1                15m   5m,30m,1h,8h
# 24               15m         5m,30m
# 23               NaN        30m,12h
# 0              1h,4h            30m
# 36             5m,1h            30m
# 25                1h         30m,1w
# 52               15m   30m,1h,1d,1w
# 50                5m   30m,1h,1d,3d
# 19               NaN        30m,12h
# 38               NaN         30m,1h
# 15                5m             1d
# 10               NaN            30m
# 2                NaN      1h,12h,1d
# 46               NaN            NaN
# 30        15m,30m,1h            NaN
# 48     5m,15m,30m,1h             1w
# 16        15m,30m,1h            NaN
# 14        5m,15m,30m            NaN
# 34        15m,30m,1h             2h
# 32               NaN            NaN
# 44        5m,15m,30m          1h,1w
# 3             30m,4h             1h
# 49            5m,30m            NaN
# 39        5m,15m,30m            NaN
# 37        5m,15m,30m             1h

# %%
test3 = buyzones(test)
test3
# Out:
#     Indicator       stkcross                                rsiup  \
# 0    COTIUSDT       4h,8h,1d                      8h,12h,1d,3d,1w
# 1    CTSIUSDT            NaN                      8h,12h,1d,3d,1w
# 2    GALAUSDT            12h                      8h,12h,1d,3d,1w
# 3    CAKEUSDT            15m                      8h,12h,1d,3d,1w
# 4     XLMUSDT             4h                      8h,12h,1d,3d,1w
# 5    ALGOUSDT             1w                      8h,12h,1d,3d,1w
# 6    LINKUSDT            15m                      8h,12h,1d,3d,1w
# 7    ATOMUSDT      12h,1d,1w                      8h,12h,1d,3d,1w
# 8   MATICUSDT         12h,1d                      8h,12h,1d,3d,1w
# 9   AUDIOUSDT         12h,1d                      8h,12h,1d,3d,1w
# 10    WINUSDT             1d                      8h,12h,1d,3d,1w
# 11    ANTUSDT         12h,1d                      8h,12h,1d,3d,1w
# 12    KSMUSDT   8h,12h,1d,1w                      8h,12h,1d,3d,1w
# 13  SUSHIUSDT          8h,1d                      8h,12h,1d,3d,1w
# 14   FLUXUSDT      8h,12h,1d                      8h,12h,1d,3d,1w
# 15    FILUSDT   1h,12h,1d,1w                      8h,12h,1d,3d,1w
# 16     ARUSDT          1d,3d                      8h,12h,1d,3d,1w
# 17   SCRTUSDT   8h,12h,3d,1w                      8h,12h,1d,3d,1w
# 18   VTHOUSDT       8h,1d,1w                      8h,12h,1d,3d,1w
# 19    ONTUSDT             1d                      8h,12h,1d,3d,1w
# 20    IMXUSDT             1d                      8h,12h,1d,3d,1w
# 21    MIRUSDT         8h,12h                         8h,12h,1d,1w
# 22  TFUELUSDT            NaN                   5m,8h,12h,1d,3d,1w
# 23    DOTUSDT             1d                   5m,8h,12h,1d,3d,1w
# 24   ROSEUSDT            15m                   5m,8h,12h,1d,3d,1w
# 25    SRMUSDT       1d,3d,1w                   5m,8h,12h,1d,3d,1w
# 26   NEARUSDT       2h,1d,1w               5m,30m,8h,12h,1d,3d,1w
# 27   AVAXUSDT             4h            5m,30m,1h,8h,12h,1d,3d,1w
# 28    OMGUSDT    1h,4h,1d,1w      5m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 29    HNTUSDT          4h,8h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30   ANKRUSDT             2h                  30m,8h,12h,1d,3d,1w
# 31    ONEUSDT         12h,1d                  30m,8h,12h,1d,3d,1w
# 32   LINAUSDT  15m,8h,12h,1d            30m,2h,4h,8h,12h,1d,3d,1w
# 33   IOTXUSDT      4h,8h,12h               30m,1h,8h,12h,1d,3d,1w
# 34  1INCHUSDT             1w            30m,1h,2h,8h,12h,1d,3d,1w
# 35    RENUSDT      15m,1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 36   RUNEUSDT         12h,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 37    LRCUSDT   1h,2h,8h,12h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38    XTZUSDT          1h,1d         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 39   WAXPUSDT         30m,8h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40     SCUSDT          1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 41    RAYUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 42    FTMUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 43    CRVUSDT          1d,1w                2h,4h,8h,12h,1d,3d,1w
# 44   DENTUSDT      2h,12h,1d                2h,4h,8h,12h,1d,3d,1w
# 45   GLMRUSDT            NaN                2h,4h,8h,12h,1d,3d,1w
# 46   MOVRUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 47    ZILUSDT         12h,1d                   1h,8h,12h,1d,3d,1w
# 48   REEFUSDT            12h                   1h,8h,12h,1d,3d,1w
# 49   BANDUSDT  15m,4h,12h,1d                   1h,8h,12h,1d,3d,1w
# 50   CELRUSDT      8h,12h,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 51    VETUSDT   4h,12h,1d,1w             1h,2h,4h,8h,12h,1d,3d,1w
#
#                    rsidown                 tops           bottoms  \
# 0      5m,15m,30m,1h,2h,4h            30m,1h,2h             5m,1w
# 1      5m,15m,30m,1h,2h,4h      2h,8h,12h,1d,3d     5m,15m,30m,1w
# 2      5m,15m,30m,1h,2h,4h          1h,2h,4h,8h         5m,15m,1w
# 3      5m,15m,30m,1h,2h,4h             2h,4h,8h         5m,15m,1w
# 4      5m,15m,30m,1h,2h,4h          1h,2h,1d,3d         5m,15m,1w
# 5      5m,15m,30m,1h,2h,4h       1h,2h,4h,8h,1d         5m,15m,1w
# 6      5m,15m,30m,1h,2h,4h      2h,4h,8h,12h,1d         5m,15m,1w
# 7      5m,15m,30m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 8      5m,15m,30m,1h,2h,4h                2h,4h         5m,15m,1w
# 9          5m,15m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 10        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 11     5m,15m,30m,1h,2h,4h                2h,4h     5m,15m,12h,1w
# 12     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 13     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 14        15m,30m,1h,2h,4h                1h,2h            5m,15m
# 15            5m,30m,2h,4h         30m,1h,2h,4h         15m,3d,1w
# 16         5m,15m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 17     5m,15m,30m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 18     5m,15m,30m,1h,2h,4h             1h,2h,4h            15m,1w
# 19     5m,15m,30m,1h,2h,4h          2h,4h,8h,1d            15m,1w
# 20     5m,15m,30m,1h,2h,4h          2h,4h,3d,1w               15m
# 21  5m,15m,30m,1h,2h,4h,3d                1h,2h  5m,15m,8h,12h,1w
# 22        15m,30m,1h,2h,4h      1h,2h,4h,12h,1d         5m,15m,1w
# 23                1h,2h,4h             1h,2h,4h         5m,15m,1w
# 24        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 25        15m,30m,1h,2h,4h                2h,4h         15m,3d,1w
# 26            15m,1h,2h,4h             2h,4h,1d      5m,15m,3d,1w
# 27               15m,2h,4h   30m,1h,2h,4h,8h,1d            15m,1w
# 28                     15m         30m,1h,2h,4h                1w
# 29                     NaN  5m,15m,30m,1h,2h,1d                1w
# 30         5m,15m,1h,2h,4h          1h,2h,4h,1d            15m,1w
# 31         5m,15m,1h,2h,4h                   2h            15m,1w
# 32               5m,15m,1h         30m,1h,2h,4h                1w
# 33            5m,15m,2h,4h         30m,1h,2h,4h         12h,1d,1w
# 34                  5m,15m             1h,2h,4h     15m,12h,1d,1w
# 35                      5m             1h,2h,4h             3d,1w
# 36                     15m         30m,1h,2h,1d             3d,1w
# 37                  5m,15m     15m,30m,1h,2h,4h                1w
# 38                     15m      30m,1h,2h,4h,8h                1w
# 39                     15m       5m,1h,2h,4h,1d                1w
# 40                     15m      30m,1h,2h,4h,1d                1w
# 41              15m,30m,1h             1h,2h,4h             5m,1w
# 42           5m,15m,30m,1h         30m,1h,2h,4h         5m,15m,1w
# 43           5m,15m,30m,1h             1h,2h,4h         5m,15m,1w
# 44              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
# 45           5m,15m,30m,1h       1h,2h,4h,8h,1d                5m
# 46                     NaN         30m,1h,2h,4h               15m
# 47        5m,15m,30m,2h,4h             1h,2h,4h                5m
# 48        5m,15m,30m,2h,4h             2h,4h,1d            15m,1w
# 49              5m,15m,30m      30m,1h,2h,4h,1d            15m,1w
# 50              5m,15m,30m      30m,1h,2h,4h,1d             5m,1w
# 51              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
#
#                 topr   bottomr                            stover  \
# 0                NaN       NaN                 2h,4h,8h,1d,3d,1w
# 1                NaN       NaN               15m,8h,12h,1d,3d,1w
# 2                NaN        3d                2h,8h,12h,1d,3d,1w
# 3                NaN       NaN               15m,2h,8h,12h,1d,3d
# 4                NaN       NaN                 2h,4h,8h,1d,3d,1w
# 5                NaN       NaN             1h,2h,8h,12h,1d,3d,1w
# 6              2h,4h       NaN            15m,2h,8h,12h,1d,3d,1w
# 7                NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 8                NaN       NaN                2h,8h,12h,1d,3d,1w
# 9                NaN       NaN                2h,4h,8h,12h,1d,3d
# 10               NaN       NaN             1h,2h,8h,12h,1d,3d,1w
# 11               NaN       NaN                2h,8h,12h,1d,3d,1w
# 12               NaN       NaN                2h,8h,12h,1d,3d,1w
# 13               NaN       NaN          5m,2h,4h,8h,12h,1d,3d,1w
# 14               NaN       NaN                2h,4h,8h,12h,1d,3d
# 15               NaN     3d,1w          5m,1h,2h,8h,12h,1d,3d,1w
# 16               NaN        3d            15m,2h,8h,12h,1d,3d,1w
# 17               NaN  1d,3d,1w                2h,4h,8h,12h,3d,1w
# 18               NaN       NaN             2h,4h,8h,12h,1d,3d,1w
# 19               NaN       NaN            15m,2h,8h,12h,1d,3d,1w
# 20               NaN       NaN            15m,2h,8h,12h,1d,3d,1w
# 21               NaN     3d,1w                2h,4h,8h,12h,3d,1w
# 22                1h        3d             5m,2h,8h,12h,1d,3d,1w
# 23               NaN       NaN                2h,8h,12h,1d,3d,1w
# 24               NaN       NaN             15m,2h,4h,8h,1d,3d,1w
# 25               NaN       NaN                2h,8h,12h,1d,3d,1w
# 26               NaN       NaN                    2h,8h,1d,3d,1w
# 27            30m,1h        3d                2h,4h,12h,1d,3d,1w
# 28         30m,1h,2h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 29  5m,15m,30m,1h,2h       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 30               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 31               NaN       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 32               NaN       NaN         5m,15m,2h,4h,8h,12h,1d,3d
# 33               NaN       NaN                5m,2h,4h,8h,12h,3d
# 34               NaN       NaN               15m,2h,4h,8h,12h,1w
# 35               NaN       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 36     15m,30m,1h,2h       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 37               30m       NaN     15m,30m,1h,2h,4h,8h,12h,3d,1w
# 38     15m,30m,1h,2h       NaN      5m,15m,1h,2h,8h,12h,1d,3d,1w
# 39               NaN       NaN         5m,15m,30m,2h,4h,8h,3d,1w
# 40            30m,1h       NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 41                1h        3d             2h,4h,8h,12h,1d,3d,1w
# 42               NaN       NaN                2h,4h,8h,12h,1d,3d
# 43                1h       NaN             2h,4h,8h,12h,1d,3d,1w
# 44               NaN       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 45               NaN       NaN                4h,8h,12h,1d,3d,1w
# 46         30m,1h,2h        1w         30m,1h,2h,4h,8h,12h,1d,3d
# 47               NaN       NaN                2h,4h,8h,12h,1d,3d
# 48               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 49               NaN       NaN      15m,1h,2h,4h,8h,12h,1d,3d,1w
# 50            30m,1h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 51                1h       NaN             2h,4h,8h,12h,1d,3d,1w
#
#                                 room                                roomr  \
# 0          5m,15m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1                5m,15m,30m,1h,4h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2            5m,15m,30m,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3         5m,15m,30m,1h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4            5m,15m,30m,4h,8h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5               5m,15m,30m,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 6                5m,15m,30m,1h,3d,1w        5m,15m,30m,1h,8h,12h,1d,3d,1w
# 7         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8      5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 9         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 10            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 11     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 14        5m,15m,30m,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 18        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 19           5m,15m,30m,1h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 20           5m,15m,30m,1h,8h,12h,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 21     5m,15m,30m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 22               5m,15m,30m,8h,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 23        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 24            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 25     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 26        5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 27                  5m,15m,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 28            5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 29                   4h,8h,12h,3d,1w                   4h,8h,12h,1d,3d,1w
# 30           5m,15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 31  5m,15m,30m,1h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 32            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 33            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 34        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 36            5m,15m,4h,8h,12h,3d,1w                5m,4h,8h,12h,1d,3d,1w
# 37                5m,8h,12h,1d,3d,1w      5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 38               5m,15m,12h,1d,3d,1w                5m,4h,8h,12h,1d,3d,1w
# 39              15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 41        5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 42            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 43        5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 44            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 45              5m,15m,30m,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46            5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 47        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 48        5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 49               5m,15m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 50               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 51            5m,15m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
#
#                  stunder                             stkup  \
# 0      5m,15m,30m,1h,12h             2h,4h,8h,12h,1d,3d,1w
# 1        5m,30m,1h,2h,4h                      8h,12h,3d,1w
# 2       5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 3        5m,30m,1h,4h,1w                   2h,8h,12h,1d,3d
# 4      5m,15m,30m,1h,12h                 2h,4h,8h,1d,3d,1w
# 5          5m,15m,30m,4h                   2h,8h,12h,1d,1w
# 6           5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 7              30m,1h,4h                2h,8h,12h,1d,3d,1w
# 8       5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 9       5m,15m,30m,1h,1w                2h,8h,12h,1d,3d,1w
# 10         5m,15m,30m,4h             1h,2h,8h,12h,1d,3d,1w
# 11      5m,15m,30m,1h,4h                   2h,8h,12h,1d,3d
# 12      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 13            15m,30m,1h                2h,8h,12h,1d,3d,1w
# 14         5m,15m,30m,1h                   2h,8h,12h,1d,3d
# 15            15m,30m,4h         15m,1h,2h,8h,12h,1d,3d,1w
# 16          5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 17      5m,15m,30m,1h,1d             1h,2h,8h,12h,1d,3d,1w
# 18         5m,15m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 19          5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 20          5m,30m,1h,4h                      2h,8h,12h,1d
# 21      5m,15m,30m,1h,1d                2h,4h,8h,12h,3d,1w
# 22         15m,30m,1h,4h                5m,8h,12h,1d,3d,1w
# 23      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 24         5m,30m,1h,12h                2h,8h,12h,1d,3d,1w
# 25      5m,15m,30m,1h,4h                   8h,12h,1d,3d,1w
# 26  5m,15m,30m,1h,4h,12h             1h,2h,8h,12h,1d,3d,1w
# 27      5m,15m,30m,1h,8h                   2h,12h,1d,3d,1w
# 28            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 29               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 30             30m,1h,4h            15m,2h,8h,12h,1d,3d,1w
# 31             5m,30m,1h                2h,8h,12h,1d,3d,1w
# 32             30m,1h,1w         5m,15m,2h,4h,8h,12h,1d,3d
# 33      15m,30m,1h,1d,1w                   2h,8h,12h,1d,3d
# 34       5m,30m,1h,1d,3d                   2h,8h,12h,1d,1w
# 35               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 36             5m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 37                 5m,1d     15m,30m,1h,2h,8h,12h,1d,3d,1w
# 38                   30m      5m,15m,1h,2h,8h,12h,1d,3d,1w
# 39             1h,12h,1d         15m,30m,1h,4h,8h,1d,3d,1w
# 40                   NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 41         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 42      5m,15m,30m,1h,1w                   2h,8h,12h,1d,3d
# 43         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 44            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 45      5m,15m,30m,1h,2h                   8h,12h,1d,3d,1w
# 46                5m,15m                2h,8h,12h,1d,3d,1w
# 47      5m,15m,30m,1h,1w                      8h,12h,1d,3d
# 48             30m,1h,4h                2h,8h,12h,1d,3d,1w
# 49                5m,30m          1h,2h,4h,8h,12h,1d,3d,1w
# 50            5m,15m,30m             2h,4h,8h,12h,1d,3d,1w
# 51         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
#
#                    stkdown                      uptrend        dshift  \
# 0            5m,15m,30m,1h                  8h,1d,3d,1w         2h,4h
# 1          5m,30m,1h,2h,4h                 8h,12h,3d,1w           15m
# 2         5m,15m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 3          5m,30m,1h,4h,1w                 8h,12h,1d,3d        15m,2h
# 4            5m,30m,1h,12h                  8h,1d,3d,1w         2h,4h
# 5      5m,15m,30m,1h,4h,3d                 8h,12h,1d,1w      1h,2h,3d
# 6             5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 7             5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 8             5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 9         5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 10           5m,15m,30m,4h              8h,12h,1d,3d,1w         1h,2h
# 11     5m,15m,30m,1h,4h,1w                 8h,12h,1d,3d         2h,1w
# 12            5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 13               30m,1h,4h              8h,12h,1d,3d,1w      5m,2h,4h
# 14        5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 15               5m,30m,4h              8h,12h,1d,3d,1w         5m,2h
# 16            5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 17           5m,15m,30m,4h                 8h,12h,3d,1w         2h,4h
# 18           5m,15m,30m,1h              8h,12h,1d,3d,1w         2h,4h
# 19            5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 20      5m,30m,1h,4h,3d,1w                    8h,12h,1d  15m,2h,3d,1w
# 21           15m,30m,1h,1d                    8h,12h,1w      2h,4h,3d
# 22        15m,30m,1h,2h,4h           5m,8h,12h,1d,3d,1w            2h
# 23        5m,15m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 24            5m,30m,1h,4h                  8h,1d,3d,1w     15m,2h,4h
# 25     5m,15m,30m,1h,2h,4h              8h,12h,1d,3d,1w            2h
# 26           5m,15m,30m,4h                  8h,1d,3d,1w            2h
# 27        5m,15m,30m,1h,4h                 12h,1d,3d,1w         2h,4h
# 28              5m,15m,30m        1h,2h,8h,12h,1d,3d,1w           NaN
# 29                     NaN  5m,15m,1h,2h,4h,8h,1d,3d,1w           NaN
# 30            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 31            5m,30m,1h,4h              8h,12h,1d,3d,1w     15m,2h,4h
# 32               30m,1h,1w           2h,4h,8h,12h,1d,3d        5m,15m
# 33     5m,15m,30m,1h,4h,1w                    8h,12h,3d      5m,2h,4h
# 34        5m,15m,30m,1h,3d                 2h,8h,12h,1w           15m
# 35                     30m         1h,2h,4h,8h,1d,3d,1w            5m
# 36              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           15m
# 37                      5m       30m,1h,2h,8h,12h,3d,1w           15m
# 38                     30m        1h,2h,8h,12h,1d,3d,1w           15m
# 39                     12h              30m,4h,8h,3d,1w           15m
# 40                     NaN    30m,1h,2h,8h,12h,1d,3d,1w           15m
# 41              15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 42        5m,15m,30m,1h,1w              2h,8h,12h,1d,3d           NaN
# 43              15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 44              5m,15m,30m           2h,8h,12h,1d,3d,1w           NaN
# 45           15m,30m,1h,2h              8h,12h,1d,3d,1w           NaN
# 46                  5m,15m              2h,8h,12h,1d,3d           NaN
# 47  5m,15m,30m,1h,2h,4h,1w                 8h,12h,1d,3d         2h,4h
# 48            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 49              5m,15m,30m           1h,8h,12h,1d,3d,1w           15m
# 50              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           NaN
# 51           5m,15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
#
#            downtrend          shift             buyzones
# 0      5m,15m,30m,1h            12h      8h,12h,1d,3d,1w
# 1    5m,30m,1h,2h,4h            NaN                   1w
# 2   5m,15m,30m,1h,4h            NaN         12h,1d,3d,1w
# 3       5m,30m,1h,4h             1w         12h,1d,3d,1w
# 4          5m,30m,1h            12h            8h,12h,1w
# 5      5m,15m,30m,4h            NaN            12h,3d,1w
# 6       5m,30m,1h,4h            NaN                3d,1w
# 7          30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 8       5m,30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 9          5m,15m,1h             1w      8h,12h,1d,3d,1w
# 10        15m,30m,4h            NaN      8h,12h,1d,3d,1w
# 11  5m,15m,30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 12      5m,30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 13            30m,1h            NaN      8h,12h,1d,3d,1w
# 14        15m,30m,1h            NaN         8h,12h,1d,3d
# 15            30m,4h            15m      8h,12h,1d,3d,1w
# 16          5m,1h,4h            NaN      8h,12h,1d,3d,1w
# 17        5m,15m,30m          1h,1d      8h,12h,1d,3d,1w
# 18     5m,15m,30m,1h            NaN      8h,12h,1d,3d,1w
# 19      5m,30m,1h,4h            NaN            12h,3d,1w
# 20      5m,30m,1h,4h            NaN            8h,12h,1d
# 21        15m,30m,1h             1d         8h,12h,1d,1w
# 22     15m,30m,1h,4h            NaN          5m,8h,3d,1w
# 23             1h,4h             5m   5m,8h,12h,1d,3d,1w
# 24            30m,1h         5m,12h   5m,8h,12h,1d,3d,1w
# 25     15m,30m,1h,4h             5m   5m,8h,12h,1d,3d,1w
# 26            15m,4h  5m,30m,1h,12h  5m,30m,8h,12h,3d,1w
# 27               15m   5m,30m,1h,8h         5m,12h,3d,1w
# 28               15m         5m,30m   5m,8h,12h,1d,3d,1w
# 29               NaN        30m,12h      4h,8h,12h,3d,1w
# 30             1h,4h            30m     30m,8h,12h,3d,1w
# 31             5m,1h            30m  30m,8h,12h,1d,3d,1w
# 32                1h         30m,1w      8h,12h,1d,3d,1w
# 33               15m   30m,1h,1d,1w      8h,12h,1d,3d,1w
# 34                5m   30m,1h,1d,3d  30m,8h,12h,1d,3d,1w
# 35               NaN        30m,12h  30m,8h,12h,1d,3d,1w
# 36               NaN         30m,1h      4h,8h,12h,3d,1w
# 37                5m             1d      8h,12h,1d,3d,1w
# 38               NaN            30m         12h,1d,3d,1w
# 39               NaN      1h,12h,1d     30m,8h,12h,3d,1w
# 40               NaN            NaN         8h,12h,3d,1w
# 41        15m,30m,1h            NaN      8h,12h,1d,3d,1w
# 42     5m,15m,30m,1h             1w      8h,12h,1d,3d,1w
# 43        15m,30m,1h            NaN      8h,12h,1d,3d,1w
# 44        5m,15m,30m            NaN      8h,12h,1d,3d,1w
# 45        15m,30m,1h             2h            12h,3d,1w
# 46               NaN            NaN      8h,12h,1d,3d,1w
# 47        5m,15m,30m          1h,1w      8h,12h,1d,3d,1w
# 48            30m,4h             1h      1h,8h,12h,3d,1w
# 49            5m,30m            NaN         8h,12h,3d,1w
# 50        5m,15m,30m            NaN         8h,12h,3d,1w
# 51        5m,15m,30m             1h      8h,12h,1d,3d,1w

# %%
## Indicator check
test1 = newframe.loc[(newframe['Indicator'] == 'WINUSDT')]
test1
# Out:
#    Indicator stkcross            rsiup           rsidown          tops  \
# 13   WINUSDT       1d  8h,12h,1d,3d,1w  15m,30m,1h,2h,4h  30m,1h,2h,4h
#
#       bottoms topr bottomr                 stover                    room  \
# 13  5m,15m,1w  NaN     NaN  1h,2h,8h,12h,1d,3d,1w  5m,15m,8h,12h,1d,3d,1w
#
#                                   roomr        stunder                  stkup  \
# 13  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,4h  1h,2h,8h,12h,1d,3d,1w
#
#           stkdown          uptrend dshift   downtrend shift
# 13  5m,15m,30m,4h  8h,12h,1d,3d,1w  1h,2h  15m,30m,4h   NaN

# %%
#list(set(list1 + list2))

test2 = newframe.loc[(newframe['Indicator'] == 'BTCUSDT')]['rsidown']
test2
buy =[]
lstkup =srtolist(test1,'stkup')
lrsiup = srtolist(test1,'rsiup')
lshift = srtolist(test1,'shift')
lroom = srtolist(test1,'room')
lroomr = srtolist(test1,'roomr')
luptrend = srtolist(test1,'uptrend')

#luptrend=list(set(luptrend + lshift))

for item in lrsiup :
    if item in lroomr:
        if item in lroom:
                buy.append(item)
  
print(buy)
# Out:
# ['8h', '12h', '1d', '3d', '1w']

# %%
# Indicators for the week shift

newframe=callfun(wshift,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])

newframe=buyzones(newframe)
newframe
# Out:
#    Indicator       stkcross                       rsiup              rsidown  \
# 0   CAKEUSDT            15m             8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h
# 1    FTMUSDT             1d       2h,4h,8h,12h,1d,3d,1w        5m,15m,30m,1h
# 2  AUDIOUSDT         12h,1d             8h,12h,1d,3d,1w      5m,15m,1h,2h,4h
# 3    ZILUSDT         12h,1d          1h,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h
# 4   LINAUSDT  15m,8h,12h,1d   30m,2h,4h,8h,12h,1d,3d,1w            5m,15m,1h
# 5    ZRXUSDT             1d  15m,30m,1h,8h,12h,1d,3d,1w             5m,2h,4h
# 6   IOTXUSDT      4h,8h,12h      30m,1h,8h,12h,1d,3d,1w         5m,15m,2h,4h
#
#            tops    bottoms topr bottomr                     stover  \
# 0      2h,4h,8h  5m,15m,1w  NaN     NaN        15m,2h,8h,12h,1d,3d
# 1  30m,1h,2h,4h  5m,15m,1w  NaN     NaN         2h,4h,8h,12h,1d,3d
# 2      1h,2h,4h  5m,15m,1w  NaN     NaN         2h,4h,8h,12h,1d,3d
# 3      1h,2h,4h         5m  NaN     NaN         2h,4h,8h,12h,1d,3d
# 4  30m,1h,2h,4h         1w  NaN     NaN  5m,15m,2h,4h,8h,12h,1d,3d
# 5   2h,4h,8h,1d     15m,1w   1h     NaN     5m,15m,2h,8h,12h,1d,3d
# 6  30m,1h,2h,4h  12h,1d,1w  NaN     NaN         5m,2h,4h,8h,12h,3d
#
#                          room                                roomr  \
# 0  5m,15m,30m,1h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1      5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2  5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3  5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4      5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5     5m,15m,30m,1h,12h,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 6      5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#             stunder                      stkup                 stkdown  \
# 0   5m,30m,1h,4h,1w            2h,8h,12h,1d,3d         5m,30m,1h,4h,1w
# 1  5m,15m,30m,1h,1w            2h,8h,12h,1d,3d        5m,15m,30m,1h,1w
# 2  5m,15m,30m,1h,1w         2h,8h,12h,1d,3d,1w        5m,15m,30m,1h,4h
# 3  5m,15m,30m,1h,1w               8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,1w
# 4         30m,1h,1w  5m,15m,2h,4h,8h,12h,1d,3d               30m,1h,1w
# 5      30m,1h,4h,1w     15m,2h,8h,12h,1d,3d,1w            5m,30m,1h,4h
# 6  15m,30m,1h,1d,1w            2h,8h,12h,1d,3d     5m,15m,30m,1h,4h,1w
#
#               uptrend    dshift      downtrend         shift  \
# 0        8h,12h,1d,3d    15m,2h   5m,30m,1h,4h            1w
# 1     2h,8h,12h,1d,3d       NaN  5m,15m,30m,1h            1w
# 2        8h,12h,1d,3d     2h,4h      5m,15m,1h            1w
# 3        8h,12h,1d,3d     2h,4h     5m,15m,30m         1h,1w
# 4  2h,4h,8h,12h,1d,3d    5m,15m             1h        30m,1w
# 5    15m,8h,12h,1d,3d     5m,2h             4h     30m,1h,1w
# 6           8h,12h,3d  5m,2h,4h            15m  30m,1h,1d,1w
#
#             buyzones
# 0       12h,1d,3d,1w
# 1    8h,12h,1d,3d,1w
# 2    8h,12h,1d,3d,1w
# 3    8h,12h,1d,3d,1w
# 4    8h,12h,1d,3d,1w
# 5  15m,30m,12h,3d,1w
# 6    8h,12h,1d,3d,1w

# %%
# Indicators for the 3d Cross
newframe=callfun(macd1dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='1d'))]


test
# Out:
#    Indicator      stkcross                      rsiup                 rsidown  \
# 6    MIRUSDT        8h,12h               8h,12h,1d,1w  5m,15m,30m,1h,2h,4h,3d
# 43   FILUSDT  1h,12h,1d,1w            8h,12h,1d,3d,1w            5m,30m,2h,4h
# 1   AVAXUSDT            4h  5m,30m,1h,8h,12h,1d,3d,1w               15m,2h,4h
# 17  SCRTUSDT  8h,12h,3d,1w            8h,12h,1d,3d,1w     5m,15m,30m,1h,2h,4h
#
#                   tops           bottoms    topr   bottomr  \
# 6                1h,2h  5m,15m,8h,12h,1w     NaN     3d,1w
# 43        30m,1h,2h,4h         15m,3d,1w     NaN     3d,1w
# 1   30m,1h,2h,4h,8h,1d            15m,1w  30m,1h        3d
# 17            1h,2h,4h         15m,3d,1w     NaN  1d,3d,1w
#
#                       stover                           room  \
# 6         2h,4h,8h,12h,3d,1w  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 43  5m,1h,2h,8h,12h,1d,3d,1w         5m,15m,8h,12h,1d,3d,1w
# 1         2h,4h,12h,1d,3d,1w               5m,15m,12h,3d,1w
# 17        2h,4h,8h,12h,3d,1w     5m,15m,30m,8h,12h,1d,3d,1w
#
#                                   roomr           stunder  \
# 6   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,1d
# 43  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w        15m,30m,4h
# 1          5m,15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,8h
# 17  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,1d
#
#                         stkup           stkdown          uptrend    dshift  \
# 6          2h,4h,8h,12h,3d,1w     15m,30m,1h,1d        8h,12h,1w  2h,4h,3d
# 43  15m,1h,2h,8h,12h,1d,3d,1w         5m,30m,4h  8h,12h,1d,3d,1w     5m,2h
# 1             2h,12h,1d,3d,1w  5m,15m,30m,1h,4h     12h,1d,3d,1w     2h,4h
# 17      1h,2h,8h,12h,1d,3d,1w     5m,15m,30m,4h     8h,12h,3d,1w     2h,4h
#
#      downtrend         shift
# 6   15m,30m,1h            1d
# 43      30m,4h           15m
# 1          15m  5m,30m,1h,8h
# 17  5m,15m,30m         1h,1d

# %%
## MACD 3d gap and rsi up
newframe=callfun(macd3dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['rsiup'].notnull()) &  (newframe['rsidown'] >= "1w" )]



test=buyzones(test)
test
# Out:
#     Indicator       stkcross                                rsiup  \
# 0     MIRUSDT         8h,12h                         8h,12h,1d,1w
# 1     FILUSDT   1h,12h,1d,1w                      8h,12h,1d,3d,1w
# 2     RAYUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 3    GALAUSDT            12h                      8h,12h,1d,3d,1w
# 4   TFUELUSDT            NaN                   5m,8h,12h,1d,3d,1w
# 5      ARUSDT          1d,3d                      8h,12h,1d,3d,1w
# 6    AVAXUSDT             4h            5m,30m,1h,8h,12h,1d,3d,1w
# 7    MOVRUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 8    SCRTUSDT   8h,12h,3d,1w                      8h,12h,1d,3d,1w
# 9    COTIUSDT       4h,8h,1d                      8h,12h,1d,3d,1w
# 10   CELRUSDT      8h,12h,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 11   NEARUSDT       2h,1d,1w               5m,30m,8h,12h,1d,3d,1w
# 12   CTSIUSDT            NaN                      8h,12h,1d,3d,1w
# 13   LINKUSDT            15m                      8h,12h,1d,3d,1w
# 14   ATOMUSDT      12h,1d,1w                      8h,12h,1d,3d,1w
# 15   ALGOUSDT             1w                      8h,12h,1d,3d,1w
# 16   CAKEUSDT            15m                      8h,12h,1d,3d,1w
# 17    XLMUSDT             4h                      8h,12h,1d,3d,1w
# 18  MATICUSDT         12h,1d                      8h,12h,1d,3d,1w
# 19    CRVUSDT          1d,1w                2h,4h,8h,12h,1d,3d,1w
# 20    FTMUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 21   DENTUSDT      2h,12h,1d                2h,4h,8h,12h,1d,3d,1w
# 22    VETUSDT   4h,12h,1d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 23  AUDIOUSDT         12h,1d                      8h,12h,1d,3d,1w
# 24    GRTUSDT      15m,4h,1w              15m,30m,8h,12h,1d,3d,1w
# 25    DOTUSDT             1d                   5m,8h,12h,1d,3d,1w
# 26    WINUSDT             1d                      8h,12h,1d,3d,1w
# 27   ROSEUSDT            15m                   5m,8h,12h,1d,3d,1w
# 28    KSMUSDT   8h,12h,1d,1w                      8h,12h,1d,3d,1w
# 29  SUSHIUSDT          8h,1d                      8h,12h,1d,3d,1w
# 30    ANTUSDT         12h,1d                      8h,12h,1d,3d,1w
# 31   FLUXUSDT      8h,12h,1d                      8h,12h,1d,3d,1w
# 32    ZILUSDT         12h,1d                   1h,8h,12h,1d,3d,1w
# 33   GLMRUSDT            NaN                2h,4h,8h,12h,1d,3d,1w
# 34    RENUSDT      15m,1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35   RUNEUSDT         12h,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 36   LINAUSDT  15m,8h,12h,1d            30m,2h,4h,8h,12h,1d,3d,1w
# 37    LRCUSDT   1h,2h,8h,12h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38   WAXPUSDT         30m,8h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 39    XTZUSDT          1h,1d         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40    OMGUSDT    1h,4h,1d,1w      5m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 41     SCUSDT          1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 42    HNTUSDT          4h,8h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 43    SRMUSDT       1d,3d,1w                   5m,8h,12h,1d,3d,1w
# 44    ZRXUSDT             1d           15m,30m,1h,8h,12h,1d,3d,1w
# 45   REEFUSDT            12h                   1h,8h,12h,1d,3d,1w
# 46   VTHOUSDT       8h,1d,1w                      8h,12h,1d,3d,1w
# 47    ONTUSDT             1d                      8h,12h,1d,3d,1w
# 48   BANDUSDT  15m,4h,12h,1d                   1h,8h,12h,1d,3d,1w
# 49   ANKRUSDT             2h                  30m,8h,12h,1d,3d,1w
# 50    ONEUSDT         12h,1d                  30m,8h,12h,1d,3d,1w
# 51  1INCHUSDT             1w            30m,1h,2h,8h,12h,1d,3d,1w
# 52    IMXUSDT             1d                      8h,12h,1d,3d,1w
# 53   IOTXUSDT      4h,8h,12h               30m,1h,8h,12h,1d,3d,1w
#
#                    rsidown                 tops           bottoms  \
# 0   5m,15m,30m,1h,2h,4h,3d                1h,2h  5m,15m,8h,12h,1w
# 1             5m,30m,2h,4h         30m,1h,2h,4h         15m,3d,1w
# 2               15m,30m,1h             1h,2h,4h             5m,1w
# 3      5m,15m,30m,1h,2h,4h          1h,2h,4h,8h         5m,15m,1w
# 4         15m,30m,1h,2h,4h      1h,2h,4h,12h,1d         5m,15m,1w
# 5          5m,15m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 6                15m,2h,4h   30m,1h,2h,4h,8h,1d            15m,1w
# 7                      NaN         30m,1h,2h,4h               15m
# 8      5m,15m,30m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 9      5m,15m,30m,1h,2h,4h            30m,1h,2h             5m,1w
# 10              5m,15m,30m      30m,1h,2h,4h,1d             5m,1w
# 11            15m,1h,2h,4h             2h,4h,1d      5m,15m,3d,1w
# 12     5m,15m,30m,1h,2h,4h      2h,8h,12h,1d,3d     5m,15m,30m,1w
# 13     5m,15m,30m,1h,2h,4h      2h,4h,8h,12h,1d         5m,15m,1w
# 14     5m,15m,30m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 15     5m,15m,30m,1h,2h,4h       1h,2h,4h,8h,1d         5m,15m,1w
# 16     5m,15m,30m,1h,2h,4h             2h,4h,8h         5m,15m,1w
# 17     5m,15m,30m,1h,2h,4h          1h,2h,1d,3d         5m,15m,1w
# 18     5m,15m,30m,1h,2h,4h                2h,4h         5m,15m,1w
# 19           5m,15m,30m,1h             1h,2h,4h         5m,15m,1w
# 20           5m,15m,30m,1h         30m,1h,2h,4h         5m,15m,1w
# 21              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
# 22              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
# 23         5m,15m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 24                1h,2h,4h                1h,1d         5m,15m,1w
# 25                1h,2h,4h             1h,2h,4h         5m,15m,1w
# 26        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 27        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 28     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 29     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 30     5m,15m,30m,1h,2h,4h                2h,4h     5m,15m,12h,1w
# 31        15m,30m,1h,2h,4h                1h,2h            5m,15m
# 32        5m,15m,30m,2h,4h             1h,2h,4h                5m
# 33           5m,15m,30m,1h       1h,2h,4h,8h,1d                5m
# 34                      5m             1h,2h,4h             3d,1w
# 35                     15m         30m,1h,2h,1d             3d,1w
# 36               5m,15m,1h         30m,1h,2h,4h                1w
# 37                  5m,15m     15m,30m,1h,2h,4h                1w
# 38                     15m       5m,1h,2h,4h,1d                1w
# 39                     15m      30m,1h,2h,4h,8h                1w
# 40                     15m         30m,1h,2h,4h                1w
# 41                     15m      30m,1h,2h,4h,1d                1w
# 42                     NaN  5m,15m,30m,1h,2h,1d                1w
# 43        15m,30m,1h,2h,4h                2h,4h         15m,3d,1w
# 44                5m,2h,4h          2h,4h,8h,1d            15m,1w
# 45        5m,15m,30m,2h,4h             2h,4h,1d            15m,1w
# 46     5m,15m,30m,1h,2h,4h             1h,2h,4h            15m,1w
# 47     5m,15m,30m,1h,2h,4h          2h,4h,8h,1d            15m,1w
# 48              5m,15m,30m      30m,1h,2h,4h,1d            15m,1w
# 49         5m,15m,1h,2h,4h          1h,2h,4h,1d            15m,1w
# 50         5m,15m,1h,2h,4h                   2h            15m,1w
# 51                  5m,15m             1h,2h,4h     15m,12h,1d,1w
# 52     5m,15m,30m,1h,2h,4h          2h,4h,3d,1w               15m
# 53            5m,15m,2h,4h         30m,1h,2h,4h         12h,1d,1w
#
#                 topr   bottomr                            stover  \
# 0                NaN     3d,1w                2h,4h,8h,12h,3d,1w
# 1                NaN     3d,1w          5m,1h,2h,8h,12h,1d,3d,1w
# 2                 1h        3d             2h,4h,8h,12h,1d,3d,1w
# 3                NaN        3d                2h,8h,12h,1d,3d,1w
# 4                 1h        3d             5m,2h,8h,12h,1d,3d,1w
# 5                NaN        3d            15m,2h,8h,12h,1d,3d,1w
# 6             30m,1h        3d                2h,4h,12h,1d,3d,1w
# 7          30m,1h,2h        1w         30m,1h,2h,4h,8h,12h,1d,3d
# 8                NaN  1d,3d,1w                2h,4h,8h,12h,3d,1w
# 9                NaN       NaN                 2h,4h,8h,1d,3d,1w
# 10            30m,1h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 11               NaN       NaN                    2h,8h,1d,3d,1w
# 12               NaN       NaN               15m,8h,12h,1d,3d,1w
# 13             2h,4h       NaN            15m,2h,8h,12h,1d,3d,1w
# 14               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 15               NaN       NaN             1h,2h,8h,12h,1d,3d,1w
# 16               NaN       NaN               15m,2h,8h,12h,1d,3d
# 17               NaN       NaN                 2h,4h,8h,1d,3d,1w
# 18               NaN       NaN                2h,8h,12h,1d,3d,1w
# 19                1h       NaN             2h,4h,8h,12h,1d,3d,1w
# 20               NaN       NaN                2h,4h,8h,12h,1d,3d
# 21               NaN       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 22                1h       NaN             2h,4h,8h,12h,1d,3d,1w
# 23               NaN       NaN                2h,4h,8h,12h,1d,3d
# 24               NaN       NaN             5m,15m,2h,4h,1d,3d,1w
# 25               NaN       NaN                2h,8h,12h,1d,3d,1w
# 26               NaN       NaN             1h,2h,8h,12h,1d,3d,1w
# 27               NaN       NaN             15m,2h,4h,8h,1d,3d,1w
# 28               NaN       NaN                2h,8h,12h,1d,3d,1w
# 29               NaN       NaN          5m,2h,4h,8h,12h,1d,3d,1w
# 30               NaN       NaN                2h,8h,12h,1d,3d,1w
# 31               NaN       NaN                2h,4h,8h,12h,1d,3d
# 32               NaN       NaN                2h,4h,8h,12h,1d,3d
# 33               NaN       NaN                4h,8h,12h,1d,3d,1w
# 34               NaN       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 35     15m,30m,1h,2h       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 36               NaN       NaN         5m,15m,2h,4h,8h,12h,1d,3d
# 37               30m       NaN     15m,30m,1h,2h,4h,8h,12h,3d,1w
# 38               NaN       NaN         5m,15m,30m,2h,4h,8h,3d,1w
# 39     15m,30m,1h,2h       NaN      5m,15m,1h,2h,8h,12h,1d,3d,1w
# 40         30m,1h,2h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 41            30m,1h       NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 42  5m,15m,30m,1h,2h       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 43               NaN       NaN                2h,8h,12h,1d,3d,1w
# 44                1h       NaN            5m,15m,2h,8h,12h,1d,3d
# 45               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 46               NaN       NaN             2h,4h,8h,12h,1d,3d,1w
# 47               NaN       NaN            15m,2h,8h,12h,1d,3d,1w
# 48               NaN       NaN      15m,1h,2h,4h,8h,12h,1d,3d,1w
# 49               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 50               NaN       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 51               NaN       NaN               15m,2h,4h,8h,12h,1w
# 52               NaN       NaN            15m,2h,8h,12h,1d,3d,1w
# 53               NaN       NaN                5m,2h,4h,8h,12h,3d
#
#                                 room                                roomr  \
# 0      5m,15m,30m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1             5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2         5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 3            5m,15m,30m,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4                5m,15m,30m,8h,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 6                   5m,15m,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 7             5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 8         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 9          5m,15m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 10               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 11        5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12               5m,15m,30m,1h,4h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13               5m,15m,30m,1h,3d,1w        5m,15m,30m,1h,8h,12h,1d,3d,1w
# 14        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15              5m,15m,30m,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16        5m,15m,30m,1h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17           5m,15m,30m,4h,8h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 18     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 19        5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 20            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 21            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 22            5m,15m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 23        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 24     5m,15m,30m,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 25        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 26            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 27            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 28        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 29        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 31        5m,15m,30m,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 32        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 33              5m,15m,30m,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 34        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35            5m,15m,4h,8h,12h,3d,1w                5m,4h,8h,12h,1d,3d,1w
# 36            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 37                5m,8h,12h,1d,3d,1w      5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 38              15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 39               5m,15m,12h,1d,3d,1w                5m,4h,8h,12h,1d,3d,1w
# 40            5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 41               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 42                   4h,8h,12h,3d,1w                   4h,8h,12h,1d,3d,1w
# 43     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 44           5m,15m,30m,1h,12h,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 45        5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 47           5m,15m,30m,1h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 48               5m,15m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 49           5m,15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 50  5m,15m,30m,1h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 51        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 52           5m,15m,30m,1h,8h,12h,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 53            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                  stunder                             stkup  \
# 0       5m,15m,30m,1h,1d                2h,4h,8h,12h,3d,1w
# 1             15m,30m,4h         15m,1h,2h,8h,12h,1d,3d,1w
# 2          5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 3       5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 4          15m,30m,1h,4h                5m,8h,12h,1d,3d,1w
# 5           5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 6       5m,15m,30m,1h,8h                   2h,12h,1d,3d,1w
# 7                 5m,15m                2h,8h,12h,1d,3d,1w
# 8       5m,15m,30m,1h,1d             1h,2h,8h,12h,1d,3d,1w
# 9      5m,15m,30m,1h,12h             2h,4h,8h,12h,1d,3d,1w
# 10            5m,15m,30m             2h,4h,8h,12h,1d,3d,1w
# 11  5m,15m,30m,1h,4h,12h             1h,2h,8h,12h,1d,3d,1w
# 12       5m,30m,1h,2h,4h                      8h,12h,3d,1w
# 13          5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 14             30m,1h,4h                2h,8h,12h,1d,3d,1w
# 15         5m,15m,30m,4h                   2h,8h,12h,1d,1w
# 16       5m,30m,1h,4h,1w                   2h,8h,12h,1d,3d
# 17     5m,15m,30m,1h,12h                 2h,4h,8h,1d,3d,1w
# 18      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 19         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 20      5m,15m,30m,1h,1w                   2h,8h,12h,1d,3d
# 21            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 22         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 23      5m,15m,30m,1h,1w                2h,8h,12h,1d,3d,1w
# 24         30m,1h,8h,12h             5m,15m,2h,4h,1d,3d,1w
# 25      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 26         5m,15m,30m,4h             1h,2h,8h,12h,1d,3d,1w
# 27         5m,30m,1h,12h                2h,8h,12h,1d,3d,1w
# 28      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 29            15m,30m,1h                2h,8h,12h,1d,3d,1w
# 30      5m,15m,30m,1h,4h                   2h,8h,12h,1d,3d
# 31         5m,15m,30m,1h                   2h,8h,12h,1d,3d
# 32      5m,15m,30m,1h,1w                      8h,12h,1d,3d
# 33      5m,15m,30m,1h,2h                   8h,12h,1d,3d,1w
# 34               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 35             5m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 36             30m,1h,1w         5m,15m,2h,4h,8h,12h,1d,3d
# 37                 5m,1d     15m,30m,1h,2h,8h,12h,1d,3d,1w
# 38             1h,12h,1d         15m,30m,1h,4h,8h,1d,3d,1w
# 39                   30m      5m,15m,1h,2h,8h,12h,1d,3d,1w
# 40            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 41                   NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 42               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 43      5m,15m,30m,1h,4h                   8h,12h,1d,3d,1w
# 44          30m,1h,4h,1w            15m,2h,8h,12h,1d,3d,1w
# 45             30m,1h,4h                2h,8h,12h,1d,3d,1w
# 46         5m,15m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 47          5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 48                5m,30m          1h,2h,4h,8h,12h,1d,3d,1w
# 49             30m,1h,4h            15m,2h,8h,12h,1d,3d,1w
# 50             5m,30m,1h                2h,8h,12h,1d,3d,1w
# 51       5m,30m,1h,1d,3d                   2h,8h,12h,1d,1w
# 52          5m,30m,1h,4h                      2h,8h,12h,1d
# 53      15m,30m,1h,1d,1w                   2h,8h,12h,1d,3d
#
#                    stkdown                      uptrend        dshift  \
# 0            15m,30m,1h,1d                    8h,12h,1w      2h,4h,3d
# 1                5m,30m,4h              8h,12h,1d,3d,1w         5m,2h
# 2               15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 3         5m,15m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 4         15m,30m,1h,2h,4h           5m,8h,12h,1d,3d,1w            2h
# 5             5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 6         5m,15m,30m,1h,4h                 12h,1d,3d,1w         2h,4h
# 7                   5m,15m              2h,8h,12h,1d,3d           NaN
# 8            5m,15m,30m,4h                 8h,12h,3d,1w         2h,4h
# 9            5m,15m,30m,1h                  8h,1d,3d,1w         2h,4h
# 10              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           NaN
# 11           5m,15m,30m,4h                  8h,1d,3d,1w            2h
# 12         5m,30m,1h,2h,4h                 8h,12h,3d,1w           15m
# 13            5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 14            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 15     5m,15m,30m,1h,4h,3d                 8h,12h,1d,1w      1h,2h,3d
# 16         5m,30m,1h,4h,1w                 8h,12h,1d,3d        15m,2h
# 17           5m,30m,1h,12h                  8h,1d,3d,1w         2h,4h
# 18            5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 19              15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 20        5m,15m,30m,1h,1w              2h,8h,12h,1d,3d           NaN
# 21              5m,15m,30m           2h,8h,12h,1d,3d,1w           NaN
# 22           5m,15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 23        5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 24           30m,1h,8h,12h                 15m,1d,3d,1w         2h,4h
# 25        5m,15m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 26           5m,15m,30m,4h              8h,12h,1d,3d,1w         1h,2h
# 27            5m,30m,1h,4h                  8h,1d,3d,1w     15m,2h,4h
# 28            5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 29               30m,1h,4h              8h,12h,1d,3d,1w      5m,2h,4h
# 30     5m,15m,30m,1h,4h,1w                 8h,12h,1d,3d         2h,1w
# 31        5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 32  5m,15m,30m,1h,2h,4h,1w                 8h,12h,1d,3d         2h,4h
# 33           15m,30m,1h,2h              8h,12h,1d,3d,1w           NaN
# 34                     30m         1h,2h,4h,8h,1d,3d,1w            5m
# 35              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           15m
# 36               30m,1h,1w           2h,4h,8h,12h,1d,3d        5m,15m
# 37                      5m       30m,1h,2h,8h,12h,3d,1w           15m
# 38                     12h              30m,4h,8h,3d,1w           15m
# 39                     30m        1h,2h,8h,12h,1d,3d,1w           15m
# 40              5m,15m,30m        1h,2h,8h,12h,1d,3d,1w           NaN
# 41                     NaN    30m,1h,2h,8h,12h,1d,3d,1w           15m
# 42                     NaN  5m,15m,1h,2h,4h,8h,1d,3d,1w           NaN
# 43     5m,15m,30m,1h,2h,4h              8h,12h,1d,3d,1w            2h
# 44            5m,30m,1h,4h             15m,8h,12h,1d,3d         5m,2h
# 45            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 46           5m,15m,30m,1h              8h,12h,1d,3d,1w         2h,4h
# 47            5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 48              5m,15m,30m           1h,8h,12h,1d,3d,1w           15m
# 49            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 50            5m,30m,1h,4h              8h,12h,1d,3d,1w     15m,2h,4h
# 51        5m,15m,30m,1h,3d                 2h,8h,12h,1w           15m
# 52      5m,30m,1h,4h,3d,1w                    8h,12h,1d  15m,2h,3d,1w
# 53     5m,15m,30m,1h,4h,1w                    8h,12h,3d      5m,2h,4h
#
#            downtrend          shift              buyzones
# 0         15m,30m,1h             1d          8h,12h,1d,1w
# 1             30m,4h            15m       8h,12h,1d,3d,1w
# 2         15m,30m,1h            NaN       8h,12h,1d,3d,1w
# 3   5m,15m,30m,1h,4h            NaN          12h,1d,3d,1w
# 4      15m,30m,1h,4h            NaN           5m,8h,3d,1w
# 5           5m,1h,4h            NaN       8h,12h,1d,3d,1w
# 6                15m   5m,30m,1h,8h          5m,12h,3d,1w
# 7                NaN            NaN       8h,12h,1d,3d,1w
# 8         5m,15m,30m          1h,1d       8h,12h,1d,3d,1w
# 9      5m,15m,30m,1h            12h       8h,12h,1d,3d,1w
# 10        5m,15m,30m            NaN          8h,12h,3d,1w
# 11            15m,4h  5m,30m,1h,12h   5m,30m,8h,12h,3d,1w
# 12   5m,30m,1h,2h,4h            NaN                    1w
# 13      5m,30m,1h,4h            NaN                 3d,1w
# 14         30m,1h,4h            NaN       8h,12h,1d,3d,1w
# 15     5m,15m,30m,4h            NaN             12h,3d,1w
# 16      5m,30m,1h,4h             1w          12h,1d,3d,1w
# 17         5m,30m,1h            12h             8h,12h,1w
# 18      5m,30m,1h,4h            NaN       8h,12h,1d,3d,1w
# 19        15m,30m,1h            NaN       8h,12h,1d,3d,1w
# 20     5m,15m,30m,1h             1w       8h,12h,1d,3d,1w
# 21        5m,15m,30m            NaN       8h,12h,1d,3d,1w
# 22        5m,15m,30m             1h       8h,12h,1d,3d,1w
# 23         5m,15m,1h             1w       8h,12h,1d,3d,1w
# 24                1h     30m,8h,12h  15m,30m,8h,12h,3d,1w
# 25             1h,4h             5m    5m,8h,12h,1d,3d,1w
# 26        15m,30m,4h            NaN       8h,12h,1d,3d,1w
# 27            30m,1h         5m,12h    5m,8h,12h,1d,3d,1w
# 28      5m,30m,1h,4h            NaN       8h,12h,1d,3d,1w
# 29            30m,1h            NaN       8h,12h,1d,3d,1w
# 30  5m,15m,30m,1h,4h            NaN       8h,12h,1d,3d,1w
# 31        15m,30m,1h            NaN          8h,12h,1d,3d
# 32        5m,15m,30m          1h,1w       8h,12h,1d,3d,1w
# 33        15m,30m,1h             2h             12h,3d,1w
# 34               NaN        30m,12h   30m,8h,12h,1d,3d,1w
# 35               NaN         30m,1h       4h,8h,12h,3d,1w
# 36                1h         30m,1w       8h,12h,1d,3d,1w
# 37                5m             1d       8h,12h,1d,3d,1w
# 38               NaN      1h,12h,1d      30m,8h,12h,3d,1w
# 39               NaN            30m          12h,1d,3d,1w
# 40               15m         5m,30m    5m,8h,12h,1d,3d,1w
# 41               NaN            NaN          8h,12h,3d,1w
# 42               NaN        30m,12h       4h,8h,12h,3d,1w
# 43     15m,30m,1h,4h             5m    5m,8h,12h,1d,3d,1w
# 44                4h      30m,1h,1w     15m,30m,12h,3d,1w
# 45            30m,4h             1h       1h,8h,12h,3d,1w
# 46     5m,15m,30m,1h            NaN       8h,12h,1d,3d,1w
# 47      5m,30m,1h,4h            NaN             12h,3d,1w
# 48            5m,30m            NaN          8h,12h,3d,1w
# 49             1h,4h            30m      30m,8h,12h,3d,1w
# 50             5m,1h            30m   30m,8h,12h,1d,3d,1w
# 51                5m   30m,1h,1d,3d   30m,8h,12h,1d,3d,1w
# 52      5m,30m,1h,4h            NaN             8h,12h,1d
# 53               15m   30m,1h,1d,1w       8h,12h,1d,3d,1w

# %%
## MACD gap 1 Week and rsi up
newframe=callfun(macd1wd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]


test=buyzones(test)
test=test.loc[test['buyzones']>='1h']
test
# Out:
#     Indicator       stkcross                                rsiup  \
# 0     MIRUSDT         8h,12h                         8h,12h,1d,1w
# 1     FILUSDT   1h,12h,1d,1w                      8h,12h,1d,3d,1w
# 2     RAYUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 4   TFUELUSDT            NaN                   5m,8h,12h,1d,3d,1w
# 5      ARUSDT          1d,3d                      8h,12h,1d,3d,1w
# 6    AVAXUSDT             4h            5m,30m,1h,8h,12h,1d,3d,1w
# 7    MOVRUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 8    SCRTUSDT   8h,12h,3d,1w                      8h,12h,1d,3d,1w
# 9    COTIUSDT       4h,8h,1d                      8h,12h,1d,3d,1w
# 10   CELRUSDT      8h,12h,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 11   NEARUSDT       2h,1d,1w               5m,30m,8h,12h,1d,3d,1w
# 12   CTSIUSDT            NaN                      8h,12h,1d,3d,1w
# 13   LINKUSDT            15m                      8h,12h,1d,3d,1w
# 14   ATOMUSDT      12h,1d,1w                      8h,12h,1d,3d,1w
# 17    XLMUSDT             4h                      8h,12h,1d,3d,1w
# 18  MATICUSDT         12h,1d                      8h,12h,1d,3d,1w
# 19    CRVUSDT          1d,1w                2h,4h,8h,12h,1d,3d,1w
# 20    FTMUSDT             1d                2h,4h,8h,12h,1d,3d,1w
# 21   DENTUSDT      2h,12h,1d                2h,4h,8h,12h,1d,3d,1w
# 22    VETUSDT   4h,12h,1d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 23  AUDIOUSDT         12h,1d                      8h,12h,1d,3d,1w
# 25    DOTUSDT             1d                   5m,8h,12h,1d,3d,1w
# 26    WINUSDT             1d                      8h,12h,1d,3d,1w
# 27   ROSEUSDT            15m                   5m,8h,12h,1d,3d,1w
# 28    KSMUSDT   8h,12h,1d,1w                      8h,12h,1d,3d,1w
# 29  SUSHIUSDT          8h,1d                      8h,12h,1d,3d,1w
# 30    ANTUSDT         12h,1d                      8h,12h,1d,3d,1w
# 31   FLUXUSDT      8h,12h,1d                      8h,12h,1d,3d,1w
# 32    ZILUSDT         12h,1d                   1h,8h,12h,1d,3d,1w
# 34    RENUSDT      15m,1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35   RUNEUSDT         12h,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 36   LINAUSDT  15m,8h,12h,1d            30m,2h,4h,8h,12h,1d,3d,1w
# 37    LRCUSDT   1h,2h,8h,12h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38   WAXPUSDT         30m,8h         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40    OMGUSDT    1h,4h,1d,1w      5m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 41     SCUSDT          1d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 42    HNTUSDT          4h,8h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 43    SRMUSDT       1d,3d,1w                   5m,8h,12h,1d,3d,1w
# 45   REEFUSDT            12h                   1h,8h,12h,1d,3d,1w
# 46   VTHOUSDT       8h,1d,1w                      8h,12h,1d,3d,1w
# 48   BANDUSDT  15m,4h,12h,1d                   1h,8h,12h,1d,3d,1w
# 49   ANKRUSDT             2h                  30m,8h,12h,1d,3d,1w
# 50    ONEUSDT         12h,1d                  30m,8h,12h,1d,3d,1w
# 51  1INCHUSDT             1w            30m,1h,2h,8h,12h,1d,3d,1w
# 52    IMXUSDT             1d                      8h,12h,1d,3d,1w
# 53   IOTXUSDT      4h,8h,12h               30m,1h,8h,12h,1d,3d,1w
#
#                    rsidown                 tops           bottoms  \
# 0   5m,15m,30m,1h,2h,4h,3d                1h,2h  5m,15m,8h,12h,1w
# 1             5m,30m,2h,4h         30m,1h,2h,4h         15m,3d,1w
# 2               15m,30m,1h             1h,2h,4h             5m,1w
# 4         15m,30m,1h,2h,4h      1h,2h,4h,12h,1d         5m,15m,1w
# 5          5m,15m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 6                15m,2h,4h   30m,1h,2h,4h,8h,1d            15m,1w
# 7                      NaN         30m,1h,2h,4h               15m
# 8      5m,15m,30m,1h,2h,4h             1h,2h,4h         15m,3d,1w
# 9      5m,15m,30m,1h,2h,4h            30m,1h,2h             5m,1w
# 10              5m,15m,30m      30m,1h,2h,4h,1d             5m,1w
# 11            15m,1h,2h,4h             2h,4h,1d      5m,15m,3d,1w
# 12     5m,15m,30m,1h,2h,4h      2h,8h,12h,1d,3d     5m,15m,30m,1w
# 13     5m,15m,30m,1h,2h,4h      2h,4h,8h,12h,1d         5m,15m,1w
# 14     5m,15m,30m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 17     5m,15m,30m,1h,2h,4h          1h,2h,1d,3d         5m,15m,1w
# 18     5m,15m,30m,1h,2h,4h                2h,4h         5m,15m,1w
# 19           5m,15m,30m,1h             1h,2h,4h         5m,15m,1w
# 20           5m,15m,30m,1h         30m,1h,2h,4h         5m,15m,1w
# 21              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
# 22              5m,15m,30m         30m,1h,2h,4h         5m,15m,1w
# 23         5m,15m,1h,2h,4h             1h,2h,4h         5m,15m,1w
# 25                1h,2h,4h             1h,2h,4h         5m,15m,1w
# 26        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 27        15m,30m,1h,2h,4h         30m,1h,2h,4h         5m,15m,1w
# 28     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 29     5m,15m,30m,1h,2h,4h             1h,2h,4h     5m,15m,12h,1w
# 30     5m,15m,30m,1h,2h,4h                2h,4h     5m,15m,12h,1w
# 31        15m,30m,1h,2h,4h                1h,2h            5m,15m
# 32        5m,15m,30m,2h,4h             1h,2h,4h                5m
# 34                      5m             1h,2h,4h             3d,1w
# 35                     15m         30m,1h,2h,1d             3d,1w
# 36               5m,15m,1h         30m,1h,2h,4h                1w
# 37                  5m,15m     15m,30m,1h,2h,4h                1w
# 38                     15m       5m,1h,2h,4h,1d                1w
# 40                     15m         30m,1h,2h,4h                1w
# 41                     15m      30m,1h,2h,4h,1d                1w
# 42                     NaN  5m,15m,30m,1h,2h,1d                1w
# 43        15m,30m,1h,2h,4h                2h,4h         15m,3d,1w
# 45        5m,15m,30m,2h,4h             2h,4h,1d            15m,1w
# 46     5m,15m,30m,1h,2h,4h             1h,2h,4h            15m,1w
# 48              5m,15m,30m      30m,1h,2h,4h,1d            15m,1w
# 49         5m,15m,1h,2h,4h          1h,2h,4h,1d            15m,1w
# 50         5m,15m,1h,2h,4h                   2h            15m,1w
# 51                  5m,15m             1h,2h,4h     15m,12h,1d,1w
# 52     5m,15m,30m,1h,2h,4h          2h,4h,3d,1w               15m
# 53            5m,15m,2h,4h         30m,1h,2h,4h         12h,1d,1w
#
#                 topr   bottomr                            stover  \
# 0                NaN     3d,1w                2h,4h,8h,12h,3d,1w
# 1                NaN     3d,1w          5m,1h,2h,8h,12h,1d,3d,1w
# 2                 1h        3d             2h,4h,8h,12h,1d,3d,1w
# 4                 1h        3d             5m,2h,8h,12h,1d,3d,1w
# 5                NaN        3d            15m,2h,8h,12h,1d,3d,1w
# 6             30m,1h        3d                2h,4h,12h,1d,3d,1w
# 7          30m,1h,2h        1w         30m,1h,2h,4h,8h,12h,1d,3d
# 8                NaN  1d,3d,1w                2h,4h,8h,12h,3d,1w
# 9                NaN       NaN                 2h,4h,8h,1d,3d,1w
# 10            30m,1h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 11               NaN       NaN                    2h,8h,1d,3d,1w
# 12               NaN       NaN               15m,8h,12h,1d,3d,1w
# 13             2h,4h       NaN            15m,2h,8h,12h,1d,3d,1w
# 14               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 17               NaN       NaN                 2h,4h,8h,1d,3d,1w
# 18               NaN       NaN                2h,8h,12h,1d,3d,1w
# 19                1h       NaN             2h,4h,8h,12h,1d,3d,1w
# 20               NaN       NaN                2h,4h,8h,12h,1d,3d
# 21               NaN       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 22                1h       NaN             2h,4h,8h,12h,1d,3d,1w
# 23               NaN       NaN                2h,4h,8h,12h,1d,3d
# 25               NaN       NaN                2h,8h,12h,1d,3d,1w
# 26               NaN       NaN             1h,2h,8h,12h,1d,3d,1w
# 27               NaN       NaN             15m,2h,4h,8h,1d,3d,1w
# 28               NaN       NaN                2h,8h,12h,1d,3d,1w
# 29               NaN       NaN          5m,2h,4h,8h,12h,1d,3d,1w
# 30               NaN       NaN                2h,8h,12h,1d,3d,1w
# 31               NaN       NaN                2h,4h,8h,12h,1d,3d
# 32               NaN       NaN                2h,4h,8h,12h,1d,3d
# 34               NaN       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 35     15m,30m,1h,2h       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 36               NaN       NaN         5m,15m,2h,4h,8h,12h,1d,3d
# 37               30m       NaN     15m,30m,1h,2h,4h,8h,12h,3d,1w
# 38               NaN       NaN         5m,15m,30m,2h,4h,8h,3d,1w
# 40         30m,1h,2h       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 41            30m,1h       NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 42  5m,15m,30m,1h,2h       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 43               NaN       NaN                2h,8h,12h,1d,3d,1w
# 45               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 46               NaN       NaN             2h,4h,8h,12h,1d,3d,1w
# 48               NaN       NaN      15m,1h,2h,4h,8h,12h,1d,3d,1w
# 49               NaN       NaN         5m,15m,2h,8h,12h,1d,3d,1w
# 50               NaN       NaN         15m,2h,4h,8h,12h,1d,3d,1w
# 51               NaN       NaN               15m,2h,4h,8h,12h,1w
# 52               NaN       NaN            15m,2h,8h,12h,1d,3d,1w
# 53               NaN       NaN                5m,2h,4h,8h,12h,3d
#
#                                 room                                roomr  \
# 0      5m,15m,30m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1             5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2         5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 4                5m,15m,30m,8h,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 6                   5m,15m,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 7             5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 8         5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 9          5m,15m,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 10               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 11        5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12               5m,15m,30m,1h,4h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13               5m,15m,30m,1h,3d,1w        5m,15m,30m,1h,8h,12h,1d,3d,1w
# 14        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17           5m,15m,30m,4h,8h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 18     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 19        5m,15m,30m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 20            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 21            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 22            5m,15m,8h,12h,1d,3d,1w     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 23        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 25        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 26            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 27            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 28        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 29        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 31        5m,15m,30m,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 32        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 34        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35            5m,15m,4h,8h,12h,3d,1w                5m,4h,8h,12h,1d,3d,1w
# 36            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 37                5m,8h,12h,1d,3d,1w      5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 38              15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40            5m,15m,8h,12h,1d,3d,1w            5m,15m,4h,8h,12h,1d,3d,1w
# 41               5m,15m,8h,12h,3d,1w         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 42                   4h,8h,12h,3d,1w                   4h,8h,12h,1d,3d,1w
# 43     5m,15m,30m,1h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 45        5m,15m,30m,1h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 48               5m,15m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 49           5m,15m,30m,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 50  5m,15m,30m,1h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 51        5m,15m,30m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 52           5m,15m,30m,1h,8h,12h,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 53            5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                  stunder                             stkup  \
# 0       5m,15m,30m,1h,1d                2h,4h,8h,12h,3d,1w
# 1             15m,30m,4h         15m,1h,2h,8h,12h,1d,3d,1w
# 2          5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 4          15m,30m,1h,4h                5m,8h,12h,1d,3d,1w
# 5           5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 6       5m,15m,30m,1h,8h                   2h,12h,1d,3d,1w
# 7                 5m,15m                2h,8h,12h,1d,3d,1w
# 8       5m,15m,30m,1h,1d             1h,2h,8h,12h,1d,3d,1w
# 9      5m,15m,30m,1h,12h             2h,4h,8h,12h,1d,3d,1w
# 10            5m,15m,30m             2h,4h,8h,12h,1d,3d,1w
# 11  5m,15m,30m,1h,4h,12h             1h,2h,8h,12h,1d,3d,1w
# 12       5m,30m,1h,2h,4h                      8h,12h,3d,1w
# 13          5m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 14             30m,1h,4h                2h,8h,12h,1d,3d,1w
# 17     5m,15m,30m,1h,12h                 2h,4h,8h,1d,3d,1w
# 18      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 19         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 20      5m,15m,30m,1h,1w                   2h,8h,12h,1d,3d
# 21            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 22         5m,15m,30m,1h                2h,8h,12h,1d,3d,1w
# 23      5m,15m,30m,1h,1w                2h,8h,12h,1d,3d,1w
# 25      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 26         5m,15m,30m,4h             1h,2h,8h,12h,1d,3d,1w
# 27         5m,30m,1h,12h                2h,8h,12h,1d,3d,1w
# 28      5m,15m,30m,1h,4h                2h,8h,12h,1d,3d,1w
# 29            15m,30m,1h                2h,8h,12h,1d,3d,1w
# 30      5m,15m,30m,1h,4h                   2h,8h,12h,1d,3d
# 31         5m,15m,30m,1h                   2h,8h,12h,1d,3d
# 32      5m,15m,30m,1h,1w                      8h,12h,1d,3d
# 34               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 35             5m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 36             30m,1h,1w         5m,15m,2h,4h,8h,12h,1d,3d
# 37                 5m,1d     15m,30m,1h,2h,8h,12h,1d,3d,1w
# 38             1h,12h,1d         15m,30m,1h,4h,8h,1d,3d,1w
# 40            5m,15m,30m             1h,2h,8h,12h,1d,3d,1w
# 41                   NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 42               30m,12h   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 43      5m,15m,30m,1h,4h                   8h,12h,1d,3d,1w
# 45             30m,1h,4h                2h,8h,12h,1d,3d,1w
# 46         5m,15m,30m,1h             2h,4h,8h,12h,1d,3d,1w
# 48                5m,30m          1h,2h,4h,8h,12h,1d,3d,1w
# 49             30m,1h,4h            15m,2h,8h,12h,1d,3d,1w
# 50             5m,30m,1h                2h,8h,12h,1d,3d,1w
# 51       5m,30m,1h,1d,3d                   2h,8h,12h,1d,1w
# 52          5m,30m,1h,4h                      2h,8h,12h,1d
# 53      15m,30m,1h,1d,1w                   2h,8h,12h,1d,3d
#
#                    stkdown                      uptrend        dshift  \
# 0            15m,30m,1h,1d                    8h,12h,1w      2h,4h,3d
# 1                5m,30m,4h              8h,12h,1d,3d,1w         5m,2h
# 2               15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 4         15m,30m,1h,2h,4h           5m,8h,12h,1d,3d,1w            2h
# 5             5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 6         5m,15m,30m,1h,4h                 12h,1d,3d,1w         2h,4h
# 7                   5m,15m              2h,8h,12h,1d,3d           NaN
# 8            5m,15m,30m,4h                 8h,12h,3d,1w         2h,4h
# 9            5m,15m,30m,1h                  8h,1d,3d,1w         2h,4h
# 10              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           NaN
# 11           5m,15m,30m,4h                  8h,1d,3d,1w            2h
# 12         5m,30m,1h,2h,4h                 8h,12h,3d,1w           15m
# 13            5m,30m,1h,4h              8h,12h,1d,3d,1w        15m,2h
# 14            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 17           5m,30m,1h,12h                  8h,1d,3d,1w         2h,4h
# 18            5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 19              15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 20        5m,15m,30m,1h,1w              2h,8h,12h,1d,3d           NaN
# 21              5m,15m,30m           2h,8h,12h,1d,3d,1w           NaN
# 22           5m,15m,30m,1h           2h,8h,12h,1d,3d,1w           NaN
# 23        5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 25        5m,15m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 26           5m,15m,30m,4h              8h,12h,1d,3d,1w         1h,2h
# 27            5m,30m,1h,4h                  8h,1d,3d,1w     15m,2h,4h
# 28            5m,30m,1h,4h              8h,12h,1d,3d,1w            2h
# 29               30m,1h,4h              8h,12h,1d,3d,1w      5m,2h,4h
# 30     5m,15m,30m,1h,4h,1w                 8h,12h,1d,3d         2h,1w
# 31        5m,15m,30m,1h,4h                 8h,12h,1d,3d         2h,4h
# 32  5m,15m,30m,1h,2h,4h,1w                 8h,12h,1d,3d         2h,4h
# 34                     30m         1h,2h,4h,8h,1d,3d,1w            5m
# 35              5m,15m,30m        2h,4h,8h,12h,1d,3d,1w           15m
# 36               30m,1h,1w           2h,4h,8h,12h,1d,3d        5m,15m
# 37                      5m       30m,1h,2h,8h,12h,3d,1w           15m
# 38                     12h              30m,4h,8h,3d,1w           15m
# 40              5m,15m,30m        1h,2h,8h,12h,1d,3d,1w           NaN
# 41                     NaN    30m,1h,2h,8h,12h,1d,3d,1w           15m
# 42                     NaN  5m,15m,1h,2h,4h,8h,1d,3d,1w           NaN
# 43     5m,15m,30m,1h,2h,4h              8h,12h,1d,3d,1w            2h
# 45            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 46           5m,15m,30m,1h              8h,12h,1d,3d,1w         2h,4h
# 48              5m,15m,30m           1h,8h,12h,1d,3d,1w           15m
# 49            5m,30m,1h,4h              8h,12h,1d,3d,1w     5m,15m,2h
# 50            5m,30m,1h,4h              8h,12h,1d,3d,1w     15m,2h,4h
# 51        5m,15m,30m,1h,3d                 2h,8h,12h,1w           15m
# 52      5m,30m,1h,4h,3d,1w                    8h,12h,1d  15m,2h,3d,1w
# 53     5m,15m,30m,1h,4h,1w                    8h,12h,3d      5m,2h,4h
#
#            downtrend          shift             buyzones
# 0         15m,30m,1h             1d         8h,12h,1d,1w
# 1             30m,4h            15m      8h,12h,1d,3d,1w
# 2         15m,30m,1h            NaN      8h,12h,1d,3d,1w
# 4      15m,30m,1h,4h            NaN          5m,8h,3d,1w
# 5           5m,1h,4h            NaN      8h,12h,1d,3d,1w
# 6                15m   5m,30m,1h,8h         5m,12h,3d,1w
# 7                NaN            NaN      8h,12h,1d,3d,1w
# 8         5m,15m,30m          1h,1d      8h,12h,1d,3d,1w
# 9      5m,15m,30m,1h            12h      8h,12h,1d,3d,1w
# 10        5m,15m,30m            NaN         8h,12h,3d,1w
# 11            15m,4h  5m,30m,1h,12h  5m,30m,8h,12h,3d,1w
# 12   5m,30m,1h,2h,4h            NaN                   1w
# 13      5m,30m,1h,4h            NaN                3d,1w
# 14         30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 17         5m,30m,1h            12h            8h,12h,1w
# 18      5m,30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 19        15m,30m,1h            NaN      8h,12h,1d,3d,1w
# 20     5m,15m,30m,1h             1w      8h,12h,1d,3d,1w
# 21        5m,15m,30m            NaN      8h,12h,1d,3d,1w
# 22        5m,15m,30m             1h      8h,12h,1d,3d,1w
# 23         5m,15m,1h             1w      8h,12h,1d,3d,1w
# 25             1h,4h             5m   5m,8h,12h,1d,3d,1w
# 26        15m,30m,4h            NaN      8h,12h,1d,3d,1w
# 27            30m,1h         5m,12h   5m,8h,12h,1d,3d,1w
# 28      5m,30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 29            30m,1h            NaN      8h,12h,1d,3d,1w
# 30  5m,15m,30m,1h,4h            NaN      8h,12h,1d,3d,1w
# 31        15m,30m,1h            NaN         8h,12h,1d,3d
# 32        5m,15m,30m          1h,1w      8h,12h,1d,3d,1w
# 34               NaN        30m,12h  30m,8h,12h,1d,3d,1w
# 35               NaN         30m,1h      4h,8h,12h,3d,1w
# 36                1h         30m,1w      8h,12h,1d,3d,1w
# 37                5m             1d      8h,12h,1d,3d,1w
# 38               NaN      1h,12h,1d     30m,8h,12h,3d,1w
# 40               15m         5m,30m   5m,8h,12h,1d,3d,1w
# 41               NaN            NaN         8h,12h,3d,1w
# 42               NaN        30m,12h      4h,8h,12h,3d,1w
# 43     15m,30m,1h,4h             5m   5m,8h,12h,1d,3d,1w
# 45            30m,4h             1h      1h,8h,12h,3d,1w
# 46     5m,15m,30m,1h            NaN      8h,12h,1d,3d,1w
# 48            5m,30m            NaN         8h,12h,3d,1w
# 49             1h,4h            30m     30m,8h,12h,3d,1w
# 50             5m,1h            30m  30m,8h,12h,1d,3d,1w
# 51                5m   30m,1h,1d,3d  30m,8h,12h,1d,3d,1w
# 52      5m,30m,1h,4h            NaN            8h,12h,1d
# 53               15m   30m,1h,1d,1w      8h,12h,1d,3d,1w

# %%
## MACD gap 1 Week stk cross
newframe=callfun(stk1w,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['downtrend'].isnull()) ]



test=buyzones(test)
#test=test.loc[test['buyzones']>='1h']
test
# Out:
#     Indicator      stkcross                            rsiup  \
# 0     FILUSDT  1h,12h,1d,1w                  8h,12h,1d,3d,1w
# 1    SCRTUSDT  8h,12h,3d,1w                  8h,12h,1d,3d,1w
# 2    CELRUSDT     8h,12h,1w         1h,2h,4h,8h,12h,1d,3d,1w
# 3    NEARUSDT      2h,1d,1w           5m,30m,8h,12h,1d,3d,1w
# 4    ATOMUSDT     12h,1d,1w                  8h,12h,1d,3d,1w
# 5    ALGOUSDT            1w                  8h,12h,1d,3d,1w
# 6     CRVUSDT         1d,1w            2h,4h,8h,12h,1d,3d,1w
# 7     VETUSDT  4h,12h,1d,1w         1h,2h,4h,8h,12h,1d,3d,1w
# 8     GRTUSDT     15m,4h,1w          15m,30m,8h,12h,1d,3d,1w
# 9     KSMUSDT  8h,12h,1d,1w                  8h,12h,1d,3d,1w
# 10    RENUSDT     15m,1d,1w     30m,1h,2h,4h,8h,12h,1d,3d,1w
# 11   RUNEUSDT        12h,1w     30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12    OMGUSDT   1h,4h,1d,1w  5m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13     SCUSDT         1d,1w     30m,1h,2h,4h,8h,12h,1d,3d,1w
# 14    SRMUSDT      1d,3d,1w               5m,8h,12h,1d,3d,1w
# 15   VTHOUSDT      8h,1d,1w                  8h,12h,1d,3d,1w
# 16  1INCHUSDT            1w        30m,1h,2h,8h,12h,1d,3d,1w
#
#                 rsidown             tops        bottoms           topr  \
# 0          5m,30m,2h,4h     30m,1h,2h,4h      15m,3d,1w            NaN
# 1   5m,15m,30m,1h,2h,4h         1h,2h,4h      15m,3d,1w            NaN
# 2            5m,15m,30m  30m,1h,2h,4h,1d          5m,1w         30m,1h
# 3          15m,1h,2h,4h         2h,4h,1d   5m,15m,3d,1w            NaN
# 4   5m,15m,30m,1h,2h,4h         1h,2h,4h      5m,15m,1w            NaN
# 5   5m,15m,30m,1h,2h,4h   1h,2h,4h,8h,1d      5m,15m,1w            NaN
# 6         5m,15m,30m,1h         1h,2h,4h      5m,15m,1w             1h
# 7            5m,15m,30m     30m,1h,2h,4h      5m,15m,1w             1h
# 8              1h,2h,4h            1h,1d      5m,15m,1w            NaN
# 9   5m,15m,30m,1h,2h,4h         1h,2h,4h  5m,15m,12h,1w            NaN
# 10                   5m         1h,2h,4h          3d,1w            NaN
# 11                  15m     30m,1h,2h,1d          3d,1w  15m,30m,1h,2h
# 12                  15m     30m,1h,2h,4h             1w      30m,1h,2h
# 13                  15m  30m,1h,2h,4h,1d             1w         30m,1h
# 14     15m,30m,1h,2h,4h            2h,4h      15m,3d,1w            NaN
# 15  5m,15m,30m,1h,2h,4h         1h,2h,4h         15m,1w            NaN
# 16               5m,15m         1h,2h,4h  15m,12h,1d,1w            NaN
#
#      bottomr                            stover                           room  \
# 0      3d,1w          5m,1h,2h,8h,12h,1d,3d,1w         5m,15m,8h,12h,1d,3d,1w
# 1   1d,3d,1w                2h,4h,8h,12h,3d,1w     5m,15m,30m,8h,12h,1d,3d,1w
# 2        NaN          1h,2h,4h,8h,12h,1d,3d,1w            5m,15m,8h,12h,3d,1w
# 3        NaN                    2h,8h,1d,3d,1w     5m,15m,30m,1h,8h,12h,3d,1w
# 4        NaN         5m,15m,2h,8h,12h,1d,3d,1w     5m,15m,30m,8h,12h,1d,3d,1w
# 5        NaN             1h,2h,8h,12h,1d,3d,1w           5m,15m,30m,12h,3d,1w
# 6        NaN             2h,4h,8h,12h,1d,3d,1w     5m,15m,30m,8h,12h,1d,3d,1w
# 7        NaN             2h,4h,8h,12h,1d,3d,1w         5m,15m,8h,12h,1d,3d,1w
# 8        NaN             5m,15m,2h,4h,1d,3d,1w  5m,15m,30m,2h,4h,8h,12h,3d,1w
# 9        NaN                2h,8h,12h,1d,3d,1w     5m,15m,30m,8h,12h,1d,3d,1w
# 10       NaN       5m,15m,1h,2h,4h,8h,1d,3d,1w     5m,15m,30m,8h,12h,1d,3d,1w
# 11       NaN         15m,2h,4h,8h,12h,1d,3d,1w         5m,15m,4h,8h,12h,3d,1w
# 12       NaN          1h,2h,4h,8h,12h,1d,3d,1w         5m,15m,8h,12h,1d,3d,1w
# 13       NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w            5m,15m,8h,12h,3d,1w
# 14       NaN                2h,8h,12h,1d,3d,1w  5m,15m,30m,1h,8h,12h,1d,3d,1w
# 15       NaN             2h,4h,8h,12h,1d,3d,1w     5m,15m,30m,8h,12h,1d,3d,1w
# 16       NaN               15m,2h,4h,8h,12h,1w     5m,15m,30m,8h,12h,1d,3d,1w
#
#                                   roomr               stunder  \
# 0   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w            15m,30m,4h
# 1   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w      5m,15m,30m,1h,1d
# 2          5m,15m,2h,4h,8h,12h,1d,3d,1w            5m,15m,30m
# 3   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,4h,12h
# 4   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             30m,1h,4h
# 5   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         5m,15m,30m,4h
# 6      5m,15m,30m,2h,4h,8h,12h,1d,3d,1w         5m,15m,30m,1h
# 7      5m,15m,30m,2h,4h,8h,12h,1d,3d,1w         5m,15m,30m,1h
# 8   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         30m,1h,8h,12h
# 9   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w      5m,15m,30m,1h,4h
# 10  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w               30m,12h
# 11                5m,4h,8h,12h,1d,3d,1w             5m,30m,1h
# 12            5m,15m,4h,8h,12h,1d,3d,1w            5m,15m,30m
# 13         5m,15m,2h,4h,8h,12h,1d,3d,1w                   NaN
# 14  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w      5m,15m,30m,1h,4h
# 15  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         5m,15m,30m,1h
# 16  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       5m,30m,1h,1d,3d
#
#                                stkup              stkdown  \
# 0          15m,1h,2h,8h,12h,1d,3d,1w            5m,30m,4h
# 1              1h,2h,8h,12h,1d,3d,1w        5m,15m,30m,4h
# 2              2h,4h,8h,12h,1d,3d,1w           5m,15m,30m
# 3              1h,2h,8h,12h,1d,3d,1w        5m,15m,30m,4h
# 4                 2h,8h,12h,1d,3d,1w         5m,30m,1h,4h
# 5                    2h,8h,12h,1d,1w  5m,15m,30m,1h,4h,3d
# 6                 2h,8h,12h,1d,3d,1w           15m,30m,1h
# 7                 2h,8h,12h,1d,3d,1w        5m,15m,30m,1h
# 8              5m,15m,2h,4h,1d,3d,1w        30m,1h,8h,12h
# 9                 2h,8h,12h,1d,3d,1w         5m,30m,1h,4h
# 10   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w                  30m
# 11             2h,4h,8h,12h,1d,3d,1w           5m,15m,30m
# 12             1h,2h,8h,12h,1d,3d,1w           5m,15m,30m
# 13  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w                  NaN
# 14                   8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h
# 15             2h,4h,8h,12h,1d,3d,1w        5m,15m,30m,1h
# 16                   2h,8h,12h,1d,1w     5m,15m,30m,1h,3d
#
#                       uptrend     dshift      downtrend          shift  \
# 0             8h,12h,1d,3d,1w      5m,2h         30m,4h            15m
# 1                8h,12h,3d,1w      2h,4h     5m,15m,30m          1h,1d
# 2       2h,4h,8h,12h,1d,3d,1w        NaN     5m,15m,30m            NaN
# 3                 8h,1d,3d,1w         2h         15m,4h  5m,30m,1h,12h
# 4             8h,12h,1d,3d,1w  5m,15m,2h      30m,1h,4h            NaN
# 5                8h,12h,1d,1w   1h,2h,3d  5m,15m,30m,4h            NaN
# 6          2h,8h,12h,1d,3d,1w        NaN     15m,30m,1h            NaN
# 7          2h,8h,12h,1d,3d,1w        NaN     5m,15m,30m             1h
# 8                15m,1d,3d,1w      2h,4h             1h     30m,8h,12h
# 9             8h,12h,1d,3d,1w         2h   5m,30m,1h,4h            NaN
# 10       1h,2h,4h,8h,1d,3d,1w         5m            NaN        30m,12h
# 11      2h,4h,8h,12h,1d,3d,1w        15m            NaN         30m,1h
# 12      1h,2h,8h,12h,1d,3d,1w        NaN            15m         5m,30m
# 13  30m,1h,2h,8h,12h,1d,3d,1w        15m            NaN            NaN
# 14            8h,12h,1d,3d,1w         2h  15m,30m,1h,4h             5m
# 15            8h,12h,1d,3d,1w      2h,4h  5m,15m,30m,1h            NaN
# 16               2h,8h,12h,1w        15m             5m   30m,1h,1d,3d
#
#                 buyzones
# 0        8h,12h,1d,3d,1w
# 1        8h,12h,1d,3d,1w
# 2           8h,12h,3d,1w
# 3    5m,30m,8h,12h,3d,1w
# 4        8h,12h,1d,3d,1w
# 5              12h,3d,1w
# 6        8h,12h,1d,3d,1w
# 7        8h,12h,1d,3d,1w
# 8   15m,30m,8h,12h,3d,1w
# 9        8h,12h,1d,3d,1w
# 10   30m,8h,12h,1d,3d,1w
# 11       4h,8h,12h,3d,1w
# 12    5m,8h,12h,1d,3d,1w
# 13          8h,12h,3d,1w
# 14    5m,8h,12h,1d,3d,1w
# 15       8h,12h,1d,3d,1w
# 16   30m,8h,12h,1d,3d,1w

# %%
## testing the transformation of whitlist 
#test = newframe.loc[(newframe['rsiup']>= '1') &  (newframe['bottoms'].notnull()) ]
test
#print(test['Indicator'])
whitelist = []
wl = []
whitelist = test['Indicator'].tolist()
#whitelist= test['Indicator']
#whitelist.apply(str.replace("USDT","/USDT"))
print(whitelist)
#whitelist.apply(replace('USDT',"/USDT"))
for i in range(0 ,len(whitelist)):
    #print (i)
    print (str(whitelist[i].replace('USDT',"/USDT")))
    wl.append(str(whitelist[i].replace('USDT',"/USDT")))

print(wl)
test
def frtolist(final:pd)->[]:
    whitelist = []
    wl = []
    whitelist = final['Indicator'].tolist()
    for i in range(0 ,len(whitelist)):
        print (str(whitelist[i].replace('USDT',"/USDT")))
        wl.append(str(whitelist[i].replace('USDT',"/USDT")))
    return wl
    

    
def wrjson(wl,name):
    test = json.dumps(wl)
    with open(name, "w") as wlf:
        json.dump(test, wlf,indent=4)
# Out:
# ['FILUSDT', 'SCRTUSDT', 'CELRUSDT', 'NEARUSDT', 'ATOMUSDT', 'ALGOUSDT', 'CRVUSDT', 'VETUSDT', 'GRTUSDT', 'KSMUSDT', 'RENUSDT', 'RUNEUSDT', 'OMGUSDT', 'SCUSDT', 'SRMUSDT', 'VTHOUSDT', '1INCHUSDT']
# FIL/USDT
# SCRT/USDT
# CELR/USDT
# NEAR/USDT
# ATOM/USDT
# ALGO/USDT
# CRV/USDT
# VET/USDT
# GRT/USDT
# KSM/USDT
# REN/USDT
# RUNE/USDT
# OMG/USDT
# SC/USDT
# SRM/USDT
# VTHO/USDT
# 1INCH/USDT
# ['FIL/USDT', 'SCRT/USDT', 'CELR/USDT', 'NEAR/USDT', 'ATOM/USDT', 'ALGO/USDT', 'CRV/USDT', 'VET/USDT', 'GRT/USDT', 'KSM/USDT', 'REN/USDT', 'RUNE/USDT', 'OMG/USDT', 'SC/USDT', 'SRM/USDT', 'VTHO/USDT', '1INCH/USDT']

# %%
white =  frtolist(test)
print(white)      
wrjson(white,"whitelistfile.json")
# Out:
# FIL/USDT
# SCRT/USDT
# CELR/USDT
# NEAR/USDT
# ATOM/USDT
# ALGO/USDT
# CRV/USDT
# VET/USDT
# GRT/USDT
# KSM/USDT
# REN/USDT
# RUNE/USDT
# OMG/USDT
# SC/USDT
# SRM/USDT
# VTHO/USDT
# 1INCH/USDT
# ['FIL/USDT', 'SCRT/USDT', 'CELR/USDT', 'NEAR/USDT', 'ATOM/USDT', 'ALGO/USDT', 'CRV/USDT', 'VET/USDT', 'GRT/USDT', 'KSM/USDT', 'REN/USDT', 'RUNE/USDT', 'OMG/USDT', 'SC/USDT', 'SRM/USDT', 'VTHO/USDT', '1INCH/USDT']

# %%
test = newframe.loc[(newframe['Indicator'] == 'BTCUSDT')]
print(test['Indicator'])
# Out:
# Series([], Name: Indicator, dtype: object)

# %% [markdown]
# # Create a function to filter the above
#     - things at the bottom and going up then go  down in timeframes
#     - 1d Bottom
#         - check 12 Bottom either going towards it
#         - At the bottom of 12
#         - Already moved from the bottom of 12
