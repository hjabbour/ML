# %%
## need to add open close for each time frame ,
## support resistance
##  pivots ,https://towardsdatascience.com/pivot-points-calculation-in-python-for-day-trading-659c1e92d323 
## and write it down each 15 minutes to create data set for AI ML bot 
## bot with GAN or CAN

# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
print(pd.to_datetime('today'))
# Out:
# 2022-06-24 10:39:13.836107

# %%
##Connect to Mongo DB  
from arctic import Arctic
connection = Arctic("mongodb://root:rootpassword@192.168.2.205:27017")
#client.initialize_library('crypto')
cryptolib = connection['crypto']
#cryptolib.stats()

# %%
## choose either white list or read from fix entries 

#fixentries= pd.read_csv('easyband.csv')
#fixentries= pd.read_csv('fixoneasy.csv')
#fixentries= pd.read_csv('fixentries.csv')
fixentries= pd.read_csv('../entries.csv')


fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
#whitelist
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')

fixentries
# Out:
#     Unnamed: 0  Indicator  lowest_entry
# 0            0   ANKRUSDT       0.05415
# 1            1   AVAXUSDT      16.60000
# 2            2   WAXPUSDT       0.25510
# 3            3   REEFUSDT       0.00806
# 4            4   LINKUSDT       7.00000
# ..         ...        ...           ...
# 59          59  STORJUSDT       0.44810
# 60          60  THETAUSDT       2.80000
# 61          61   MANAUSDT       1.65000
# 62          62   PAXGUSDT    1785.00000
# 63          63   PERPUSDT       2.22000
#
# [64 rows x 3 columns]

# %%
#alllist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, ADADOWN/USDT, BOND/USDT, DCR/USDT, DOTDOWN/USDT, GNO/USDT, NBS/USDT, SXPUP/USDT, EOSDOWN/USDT, YFIUP/USDT, RIF/USDT, LTCDOWN/USDT, XLMUP/USDT, YFIDOWN/USDT, LINKDOWN/USDT, TRXUP/USDT, BCHUP/USDT, XTZUP/USDT, SXPDOWN/USDT, UNIDOWN/USDT, XTZDOWN/USDT, BCHDOWN/USDT, TRXDOWN/USDT, XLMDOWN/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
#whitelist =str(fixentries['Indicator'])

startdate = '2020-01-01'
enddate = pd.to_datetime('today')
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']
#intervals = ['8h']

# %%
#print (enddate)

# %%
def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

#Calulate SMA 
def SMA(series,size):
    sma = series.rolling(size).mean()
    return sma
#Calculate SMA55

## MACD 
def MMACD(series,fast=5,slow=35,sig=5):
    ## defaults original f 12, s 26, s9
    exp1 = series.ewm(span=fast, adjust=False).mean()
    exp2 = series.ewm(span=slow, adjust=False).mean()
    macd = exp1-exp2
    signal = macd.ewm(span=sig, adjust=False).mean()
    return macd,signal
## Bottom price 
def FBOTTOMP (series,size):
    bottomp=series.rolling(size).min()
    return bottomp
## top price 
def FTOPP (series,size):
    topp=series.rolling(size).max()
    return topp

# %%
#alllist=alllist.lstrip()
#array = alllist.split(",")
#array = whitelist
array = whitelist
array

wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(symbols,columns =['Indicator'])
final.set_index(['Indicator'],inplace=True)
#final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            dflive=dflive.loc[(dflive.open_time>start)]
            
            if dflive.size > 300 :
                
                
                

                dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
                dflive['RSI'] = FRSI(dflive['c'])
                dflive['STRSI'] = STRSIA(dflive['c'])[0]
                dflive['STRSIK'] = STRSIA(dflive['c'])[1]
                dflive['STRSID'] = STRSIA(dflive['c'])[2]
                dflive['SMA21'] = SMA(dflive['c'],21)
                dflive['SMA55'] = SMA(dflive['c'],55)
                dflive['SMA100'] = SMA(dflive['c'],100)
                dflive['SMA200'] = SMA(dflive['c'],200)
                dflive['MACD'] = MMACD(dflive['c'])[0]
                dflive['MACDSIGNAL'] = MMACD(dflive['c'])[1]
                dflive['BTTOMP'] = FBOTTOMP(dflive['l'],10)
                dflive['TPP'] = FTOPP(dflive['h'],10)


                
                



                #print(dflive)


                lastrow = dflive.iloc[-1]
                beforelast = dflive.iloc[-2]
                row5minus = dflive.iloc[-10]
                O = float(lastrow.o)
                C = float(lastrow.c)
                H = float(lastrow.h)
                L = float(lastrow.l)
                V = float(lastrow.v)
                OM = float(beforelast.o)
                CM = float(beforelast.c)
                HM = float(beforelast.h)
                LM = float(beforelast.l)
                VM = float(beforelast.v)
                RSI = float(lastrow.RSI)
                RSIM = float(beforelast.RSI)
                STRSI = float(lastrow.STRSI)
                STRSIK = float(lastrow.STRSIK)
                STRSIKM = float(beforelast.STRSIK)
                STRSID = float(lastrow.STRSID)
                STRSIDM = float(beforelast.STRSID)
                SMA21 = float(lastrow.SMA21)
                SMA21M = float(beforelast.SMA21)
                SMA55 = float(lastrow.SMA55)
                SMA55M = float(beforelast.SMA55)
                SMA100 = float(lastrow.SMA100)
                SMA100M = float(beforelast.SMA100)
                SMA200 = float(lastrow.SMA200)
                SMA200M = float(beforelast.SMA200)
                MACD = float(lastrow.MACD)
                MACDSIGNAL = float(lastrow.MACDSIGNAL)
                MACDM = float(beforelast.MACD)
                MACDSIGNALM = float(beforelast.MACDSIGNAL)
                BTTOMP = lastrow.BTTOMP
                TPP = lastrow.TPP
                BTTOMPM = row5minus.BTTOMP
                TPPM = row5minus.TPP


                tuple =(symbol,O,C,H,L,V,OM,CM,HM,LM,VM,RSI,RSIM,STRSI,STRSIK,STRSIKM,STRSID,STRSIDM,SMA21,SMA21M,SMA55,SMA55M,SMA100,SMA100M,SMA200,SMA200M,MACD,MACDSIGNAL,MACDM,MACDSIGNALM,BTTOMP,TPP,BTTOMPM,TPPM)
                table.append(tuple)
                #print(table)
                del dflive
            else:
                pass
            #print("name is: ",array[0])


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','O','C','H','L','V','OM','CM','HM','LM','VM','RSI','RSIM','STRSI','STRSIK','STRSIKM','STRSID','STRSIDM','SMA21','SMA21M','SMA55','SMA55M','SMA100','SMA100M','SMA200','SMA200M','MACD','MACDSIGNAL','MACDM','MACDSIGNALM','BOTTOMP','TOPP','BOTTOMPM','TOPPM'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'O':('O'+interval),'OM':('OM'+interval),'C':('C'+interval),'CM':('CM'+interval),'H':('H'+interval),'HM':('HM'+interval),'L':('L'+interval),'LM':('LM'+interval),'V':('V'+interval),'VM':('VM'+interval),'RSI':('RSI'+interval),\
                                 'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSIKM':('STRSIKM'+interval),\
                                 'STRSID':('STRSID'+interval),'STRSIDM':('STRSIDM'+interval),'SMA21':('SMA21'+interval),'SMA21M':('SMA21M'+interval),\
                                 'SMA55':('SMA55'+interval),'SMA55M':('SMA55M'+interval),'SMA100':('SMA100'+interval),'SMA100M':('SMA100M'+interval),\
                                 'SMA200':('SMA200'+interval),'SMA200M':('SMA200M'+interval),'MACD':('MACD'+interval),'MACDSIGNAL':('MACDSIGNAL'+interval),'MACDM':('MACDM'+interval),'MACDSIGNALM':('MACDSIGNALM'+interval),'BOTTOMP':('BOTTOMP'+interval),'TOPP':('TOPP'+interval),'BOTTOMPM':('BOTTOMPM'+interval),'TOPPM':('TOPPM'+interval)})
    #test.set_index(['Indicator'],inplace=True)
    final=final.merge(test,how='left',on=['Indicator'])
    final=final.drop_duplicates(subset='Indicator',keep='last')
    #final.set_index(['Indicator'],inplace=True)

    del test
    ## add the current date column
            
final['Time'] = pd.to_datetime('today')

#final
#final.reset_index(inplace=True)

# %%
#final.Indicator

# %%
import os.path

file_exists = os.path.exists("MLDATATOP"+str(date.today())+".csv")



#final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
#final['Time'] = pd.to_datetime('today')
#final.to_csv("MLDATATOP.csv")
#final.to_csv("MLSTRSIMACDBTTOP.csv")
if file_exists :
    final.to_csv("MLDATATOP"+str(date.today())+".csv", mode='a', index=True, header=False)
else :
    final.to_csv("MLDATATOP"+str(date.today())+".csv")
    
#final.to_csv("MLDATATOP"+str(date.today())+".csv")
## adding to two files the first file i thought there is a column missmatch
#final.to_csv('MLSTRSIMACDBTTOP.csv', mode='a', index=True, header=False)
final.to_csv('MLDATATOP.csv', mode='a', index=True, header=False)
#final.reset_index(inplace=True)

final.head()
# Out:
#    Indicator       O5m       C5m       H5m       L5m         V5m      OM5m  \
# 10  ANKRUSDT   0.03057   0.03055   0.03060   0.03052   201624.60   0.03054
# 21  AVAXUSDT  19.45000  19.34000  19.46000  19.28000    17438.98  19.40000
# 32  WAXPUSDT   0.09400   0.09380   0.09420   0.09380    23434.00   0.09420
# 43  REEFUSDT   0.00362   0.00361   0.00362   0.00360  2723206.00   0.00362
# 54  LINKUSDT   7.01000   6.99000   7.02000   6.98000    28332.55   7.01000
#
#         CM5m      HM5m      LM5m  ...  SMA200M1w     MACD1w  MACDSIGNAL1w  \
# 10   0.03057   0.03063   0.03052  ...        NaN  -0.033468     -0.031120
# 21  19.45000  19.47000  19.37000  ...        NaN -32.501432    -28.185875
# 32   0.09410   0.09430   0.09410  ...        NaN  -0.158771     -0.151855
# 43   0.00362   0.00362   0.00361  ...        NaN  -0.007116     -0.007253
# 54   7.01000   7.03000   7.00000  ...        NaN  -7.624480     -7.737080
#
#       MACDM1w  MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w    TOPPM1w  \
# 10  -0.034034      -0.029947    0.02301   0.08674     0.05107    0.10295
# 21 -32.818503     -26.028097   13.71000  81.31000    64.45000  103.62000
# 32  -0.161358      -0.148398    0.07500   0.29050     0.24170    0.39500
# 43  -0.007379      -0.007321    0.00274   0.01044     0.00788    0.01280
# 54  -7.984842      -7.793380    5.30000  14.50000    11.40000   18.32000
#
#                          Time
# 10 2022-06-24 10:43:17.472351
# 21 2022-06-24 10:43:17.472351
# 32 2022-06-24 10:43:17.472351
# 43 2022-06-24 10:43:17.472351
# 54 2022-06-24 10:43:17.472351
#
# [5 rows x 365 columns]

# %%
final.tail()
# Out:
#      Indicator        O5m        C5m        H5m        L5m          V5m  \
# 656  STORJUSDT     0.9220     0.9252     0.9273     0.9200   43614.0000
# 667  THETAUSDT     1.3920     1.3770     1.3950     1.3750  115570.8000
# 678   MANAUSDT     0.9013     0.8999     0.9023     0.8975   67752.0000
# 689   PAXGUSDT  1829.0000  1829.0000  1829.0000  1829.0000       0.2955
# 700   PERPUSDT     0.7550     0.7540     0.7560     0.7530   10031.9200
#
#           OM5m       CM5m       HM5m       LM5m  ...  SMA200M1w     MACD1w  \
# 656     0.9193     0.9227     0.9264     0.9175  ...        NaN  -0.357648
# 667     1.3790     1.3920     1.3920     1.3780  ...        NaN  -1.828704
# 678     0.9017     0.9011     0.9044     0.9011  ...        NaN  -0.836883
# 689  1829.0000  1828.0000  1829.0000  1828.0000  ...        NaN -17.184723
# 700     0.7560     0.7550     0.7560     0.7540  ...        NaN  -4.335662
#
#      MACDSIGNAL1w   MACDM1w  MACDSIGNALM1w  BOTTOMP1w     TOPP1w  BOTTOMPM1w  \
# 656     -0.417773 -0.482229      -0.447836     0.3292     1.3921      0.7714
# 667     -1.887232 -1.953317      -1.916496     0.9560     3.5410      2.2710
# 678     -0.772203 -0.862268      -0.739863     0.6290     2.2347      1.9557
# 689     -5.343504 -8.645826       0.577105  1791.0000  1999.0000   1845.0000
# 700     -4.418005 -4.489119      -4.459176     0.5020     5.0500      3.6000
#
#        TOPPM1w                       Time
# 656     1.6522 2022-06-24 10:43:17.472351
# 667     4.3900 2022-06-24 10:43:17.472351
# 678     3.4000 2022-06-24 10:43:17.472351
# 689  2076.0000 2022-06-24 10:43:17.472351
# 700     6.5300 2022-06-24 10:43:17.472351
#
# [5 rows x 365 columns]

# %%
cryptolib.append('MLDATATOP',final)
# Out:
# VersionedItem(symbol=MLDATATOP,library=arctic.crypto,data=<class 'NoneType'>,version=87,metadata=None,host=mongodb://root:rootpassword@192.168.2.205:27017)

# %%
from arctic.date import DateRange

#custom_range = DateRange('2022-06-11', '2022-06-12')

#fromdb = cryptolib.read('MLDATATOP',date_range=custom_range).data
fromdb = cryptolib.read('MLDATATOP').data
cryptolib.list_symbols()
cryptolib.list_versions()

formdbsort=fromdb.sort_values(by='Time',ascending=True)
formdbsort=formdbsort.loc[formdbsort['Indicator']=='HNTUSDT']
formdbsort
# Out:
# /Users/hjabbour/opt/anaconda3/envs/cryptodev/lib/python3.8/site-packages/arctic/date/_mktz.py:32: PytzUsageWarning: The zone attribute is specific to pytz's interface; please migrate to a new time zone provider. For more details on how to do so, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   zone = tzlocal.get_localzone().zone
#       Indicator    O5m    C5m    H5m    L5m      V5m   OM5m   CM5m   HM5m  \
# index
# 261     HNTUSDT   9.15   9.15   9.15   9.15     0.00   9.12   9.15   9.15
# 261     HNTUSDT   8.25   8.17   8.25   8.17   416.82   8.20   8.24   8.27
# 261     HNTUSDT   8.10   8.14   8.14   8.06  1073.77   8.05   8.11   8.12
# 261     HNTUSDT   7.79   7.88   7.89   7.79  3029.25   7.75   7.79   7.79
# 261     HNTUSDT   7.92   7.93   7.94   7.89   984.09   7.94   7.92   8.00
# ...         ...    ...    ...    ...    ...      ...    ...    ...    ...
# 261     HNTUSDT  10.17  10.13  10.17  10.13  3133.52  10.10  10.17  10.17
# 261     HNTUSDT  10.47  10.43  10.48  10.42   624.96  10.43  10.46  10.48
# 261     HNTUSDT  10.37  10.36  10.38  10.36    71.81  10.37  10.38  10.39
# 261     HNTUSDT  10.13  10.11  10.14  10.10   461.74  10.13  10.13  10.16
# 261     HNTUSDT  10.53  10.50  10.53  10.48  1146.45  10.52  10.53  10.56
#
#         LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w   MACDM1w  MACDSIGNALM1w  \
# index         ...
# 261     9.11  ...        NaN -9.738000     -8.973849 -9.995430      -8.591774
# 261     8.20  ...        NaN -9.765180     -9.274046 -9.901889      -9.028479
# 261     8.03  ...        NaN -9.767958     -9.274972 -9.901889      -9.028479
# 261     7.72  ...        NaN -9.812402     -9.289787 -9.901889      -9.028479
# 261     7.90  ...        NaN -9.817958     -9.291639 -9.901889      -9.028479
# ...      ...  ...        ...       ...           ...       ...            ...
# 261    10.10  ...        NaN -8.418174     -8.798015 -8.906847      -8.987935
# 261    10.43  ...        NaN -8.329286     -8.768385 -8.906847      -8.987935
# 261    10.35  ...        NaN -8.351508     -8.775793 -8.906847      -8.987935
# 261    10.13  ...        NaN -8.432063     -8.802644 -8.906847      -8.987935
# 261    10.52  ...        NaN -8.318174     -8.764681 -8.906847      -8.987935
#
#        BOTTOMP1w  TOPP1w  BOTTOMPM1w  TOPPM1w                       Time
# index
# 261         6.54   28.00       19.48    32.00 2022-06-13 01:28:36.910066
# 261         6.54   22.08       19.48    32.00 2022-06-13 08:44:27.632136
# 261         6.54   22.08       19.48    32.00 2022-06-13 09:21:10.183001
# 261         6.54   22.08       19.48    32.00 2022-06-13 10:14:09.668714
# 261         6.54   22.08       19.48    32.00 2022-06-13 10:54:43.236504
# ...          ...     ...         ...      ...                        ...
# 261         6.54   20.06       17.08    28.63 2022-06-22 23:22:23.615301
# 261         6.54   20.06       17.08    28.63 2022-06-23 09:22:15.433436
# 261         6.54   20.06       17.08    28.63 2022-06-23 17:20:06.427676
# 261         6.54   20.06       17.08    28.63 2022-06-23 20:06:25.124847
# 261         6.54   20.06       17.08    28.63 2022-06-24 10:43:17.472351
#
# [86 rows x 365 columns]

# %%
HIHI15m = (final['TOPP15m'] > final['TOPPM15m'])
HIHI1h = (final['TOPP1h'] > final['TOPPM1h'])
HIHI2h = (final['TOPP2h'] > final['TOPPM2h'])
HIHI30m = (final['TOPP30m'] > final['TOPPM30m'])
HIHI4h = (final['TOPP4h'] > final['TOPPM4h'])
HIHI5m = (final['TOPP5m'] > final['TOPPM5m'])
HILO15m = (final['BOTTOMP15m'] > final['BOTTOMPM15m'])
HILO1h = (final['BOTTOMP1h'] > final['BOTTOMPM1h'])
HILO2h = (final['BOTTOMP2h'] > final['BOTTOMPM2h'])
HILO30m = (final['BOTTOMP30m'] > final['BOTTOMPM30m'])
HILO4h = (final['BOTTOMP4h'] > final['BOTTOMPM4h'])
HILO5m = (final['BOTTOMP5m'] > final['BOTTOMPM5m'])
LOHI15m = (final['TOPP15m'] < final['TOPPM15m'])
LOHI1h = (final['TOPP1h'] < final['TOPPM1h'])
LOHI2h = (final['TOPP2h'] < final['TOPPM2h'])
LOHI30m = (final['TOPP30m'] < final['TOPPM30m'])
LOHI4h = (final['TOPP4h'] < final['TOPPM4h'])
LOHI5m = (final['TOPP5m'] < final['TOPPM5m'])
LOLO15m = (final['BOTTOMP15m'] < final['BOTTOMPM15m'])
LOLO1h = (final['BOTTOMP1h'] < final['BOTTOMPM1h'])
LOLO2h = (final['BOTTOMP2h'] < final['BOTTOMPM2h'])
LOLO30m = (final['BOTTOMP30m'] < final['BOTTOMPM30m'])
LOLO4h = (final['BOTTOMP4h'] < final['BOTTOMPM4h'])
LOLO5m = (final['BOTTOMP5m'] < final['BOTTOMPM5m'])




MACDCROSS12h =  (final['MACD12h'] > final['MACDSIGNAL12h'])
MACDCROSS1d =  (final['MACD1d'] > final['MACDSIGNAL1d'])
MACDCROSS1w =  (final['MACD1w'] > final['MACDSIGNAL1w'])
MACDCROSS3d =  (final['MACD3d'] > final['MACDSIGNAL3d'])
MACDCROSS4h =  (final['MACD4h'] > final['MACDSIGNAL4h'])
MACDCROSS8h =  (final['MACD8h'] > final['MACDSIGNAL8h'])

MACDD12h = (final['MACD12h'] < final['MACDM12h'])
MACDD1d = (final['MACD1d'] < final['MACDM1d'])
MACDD1w = (final['MACD1w'] < final['MACDM1w'])
MACDD3d = (final['MACD3d'] < final['MACDM3d'])
MACDD4h = (final['MACD4h'] < final['MACDM4h'])
MACDD8h = (final['MACD8h'] < final['MACDM8h'])

MACDGAPD12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) > (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPD1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) > (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPD1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) > (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPD3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) > (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPD4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) > (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPD8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) > (final['MACDM8h'] - final['MACDSIGNALM8h']) )
MACDGAPU12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) < (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPU1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) < (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPU1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) < (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPU3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) < (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPU4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) < (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPU8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) < (final['MACDM8h'] - final['MACDSIGNALM8h']) )

MACDU12h = (final['MACD12h'] > final['MACDM12h'])
MACDU1d = (final['MACD1d'] > final['MACDM1d'])
MACDU1w = (final['MACD1w'] > final['MACDM1w'])
MACDU3d = (final['MACD3d'] > final['MACDM3d'])
MACDU4h = (final['MACD4h'] > final['MACDM4h'])
MACDU8h = (final['MACD8h'] > final['MACDM8h'])

bottom12h = (final['STRSIK12h']< 0.2)
bottom1d = (final['STRSIK1d']< 0.2)
bottom1h = (final['STRSIK1h']< 0.2)
bottom1w = (final['STRSIK1w']< 0.2)
bottom2h = (final['STRSIK2h']< 0.2)
bottom3d = (final['STRSIK3d']< 0.2)
bottom4h = (final['STRSIK4h']< 0.2)
bottom8h = (final['STRSIK8h']< 0.2)
bottom30m = (final['STRSIK30m'] < 0.2)
bottom15m = (final['STRSIK15m'] < 0.2)
bottom5m = (final['STRSIK5m'] < 0.2)

bottomr12h = (final['RSI12h'] < 30)
bottomr1d = (final['RSI1d'] < 30)
bottomr1h = (final['RSI1h'] < 30)
bottomr1w = (final['RSI1w'] < 30)
bottomr2h = (final['RSI2h'] < 30)
bottomr3d = (final['RSI3d'] < 30)
bottomr4h = (final['RSI4h'] < 30)
bottomr8h = (final['RSI8h'] < 30)
bottomr30m = (final['RSI30m'] < 30)
bottomr15m = (final['RSI15m'] < 30)
bottomr5m = (final['RSI5m'] < 30)






room12h = (final['STRSIK12h'] < 0.8)
room1d = (final['STRSIK1d'] < 0.8)
room1h = (final['STRSIK1h'] < 0.8)
room1w = (final['STRSIK1w'] < 0.8)
room2h = (final['STRSIK2h'] < 0.8)
room3d = (final['STRSIK3d'] < 0.8)
room4h = (final['STRSIK4h'] < 0.8)
room8h = (final['STRSIK8h'] < 0.8)
room30m = (final['STRSIK30m'] < 0.8)
room15m = (final['STRSIK15m'] < 0.8)
room5m = (final['STRSIK5m'] < 0.8)


roomr12h = (final['RSI12h'] < 70)
roomr1d = (final['RSI1d'] < 70)
roomr1h = (final['RSI1h'] < 70)
roomr1w = (final['RSI1w'] < 70)
roomr2h = (final['RSI2h'] < 70)
roomr3d = (final['RSI3d'] < 70)
roomr4h = (final['RSI4h'] < 70)
roomr8h = (final['RSI8h'] < 70)
roomr30m = (final['RSI30m'] < 70)
roomr15m = (final['RSI15m'] < 70)
roomr5m = (final['RSI5m'] < 70)


rule12hRSIdown = (final['RSI12h'] < final['RSIM12h'])
rule12hRSIup = (final['RSI12h'] > final['RSIM12h'])
rule12hkdown = (final['STRSIK12h'] < final['STRSIKM12h'])
rule12hkup = (final['STRSIK12h'] > final['STRSIKM12h'])
rule12hover = (final['STRSIK12h'] > final['STRSID12h'])
rule12hunder = (final['STRSIK12h'] < final['STRSID12h'])
rule1hRSIdown = (final['RSI1h'] < final['RSIM1h'])
rule1hRSIup = (final['RSI1h'] > final['RSIM1h'])
rule1dRSIdown = (final['RSI1d'] < final['RSIM1d'])
rule1dRSIup = (final['RSI1d'] > final['RSIM1d'])
rule1dkdown = (final['STRSIK1d']< final['STRSIKM1d'])
rule1dkup = (final['STRSIK1d'] > final['STRSIKM1d'])
rule1dover = (final['STRSIK1d'] > final['STRSID1d'])
rule1dunder = (final['STRSIK1d']< final['STRSID1d'])
rule1hkdown = (final['STRSIK1h']< final['STRSIKM1h'])
rule1hkup = (final['STRSIK1h'] > final['STRSIKM1h'])
rule1hover = (final['STRSIK1h'] > final['STRSID1h'])
rule1hunder = (final['STRSIK1h']< final['STRSID1h'])
rule1wRSIdown = (final['RSI1w'] < final['RSIM1w'])
rule1wRSIup = (final['RSI1w'] > final['RSIM1w'])
rule1wkdown = (final['STRSIK1w']< final['STRSIKM1w'])
rule1wkup = (final['STRSIK1w'] > final['STRSIKM1w'])
rule1wover = (final['STRSIK1w'] > final['STRSID1w'])
rule1wunder = (final['STRSIK1w']< final['STRSID1w'])
rule2hRSIdown = (final['RSI2h'] < final['RSIM2h'])
rule2hRSIup = (final['RSI2h'] > final['RSIM2h'])
rule2hkdown = (final['STRSIK2h']< final['STRSIKM2h'])
rule2hkup = (final['STRSIK2h'] > final['STRSIKM2h'])
rule2hover = (final['STRSIK2h'] > final['STRSID2h'])
rule2hunder = (final['STRSIK2h']< final['STRSID2h'])
rule3dRSIdown = (final['RSI3d'] < final['RSIM3d'])
rule3dRSIup = (final['RSI3d'] > final['RSIM3d'])
rule3dkdown = (final['STRSIK3d']< final['STRSIKM3d'])
rule3dkup = (final['STRSIK3d'] > final['STRSIKM3d'])
rule3dover = (final['STRSIK3d'] > final['STRSID3d'])
rule3dunder = (final['STRSIK3d']< final['STRSID3d'])
rule4hRSIdown = (final['RSI4h'] < final['RSIM4h'])
rule4hRSIup = (final['RSI4h'] > final['RSIM4h'])
rule4hkdown = (final['STRSIK4h']< final['STRSIKM4h'])
rule4hkup = (final['STRSIK4h'] > final['STRSIKM4h'])
rule4hover = (final['STRSIK4h'] > final['STRSID4h'])
rule4hunder = (final['STRSIK4h']< final['STRSID4h'])

rule8hRSIdown = (final['RSI8h'] < final['RSIM8h'])
rule8hRSIup = (final['RSI8h'] > final['RSIM8h'])
rule8hkdown = (final['STRSIK8h']< final['STRSIKM8h'])
rule8hkup = (final['STRSIK8h'] > final['STRSIKM8h'])
rule8hover = (final['STRSIK8h'] > final['STRSID8h'])
rule8hunder = (final['STRSIK8h']< final['STRSID8h'])

rule30mRSIdown = (final['RSI30m'] < final['RSIM30m'])
rule30mRSIup = (final['RSI30m'] > final['RSIM30m'])
rule30mkdown = (final['STRSIK30m']< final['STRSIKM30m'])
rule30mkup = (final['STRSIK30m'] > final['STRSIKM30m'])
rule30mover = (final['STRSIK30m'] > final['STRSID30m'])
rule30munder = (final['STRSIK30m']< final['STRSID30m'])

rule15mRSIdown = (final['RSI15m'] < final['RSIM15m'])
rule15mRSIup = (final['RSI15m'] > final['RSIM15m'])
rule15mkdown = (final['STRSIK15m']< final['STRSIKM15m'])
rule15mkup = (final['STRSIK15m'] > final['STRSIKM15m'])
rule15mover = (final['STRSIK15m'] > final['STRSID15m'])
rule15munder = (final['STRSIK15m']< final['STRSID15m'])

rule5mRSIdown = (final['RSI5m'] < final['RSIM5m'])
rule5mRSIup = (final['RSI5m'] > final['RSIM5m'])
rule5mkdown = (final['STRSIK5m']< final['STRSIKM5m'])
rule5mkup = (final['STRSIK5m'] > final['STRSIKM5m'])
rule5mover = (final['STRSIK5m'] > final['STRSID5m'])
rule5munder = (final['STRSIK5m']< final['STRSID5m'])

shift12h = (rule12hunder & (rule12hkup | rule12hRSIup))
shift1d = (rule1dunder & (rule1dkup | rule1dRSIup))
shift1h = (rule1hunder & (rule1hkup | rule1hRSIup))
shift1w = (rule1wunder & (rule1wkup | rule1wRSIup))
shift2h = (rule2hunder & (rule2hkup | rule2hRSIup))
shift3d = (rule3dunder & (rule3dkup | rule3dRSIup))
shift4h = (rule4hunder & (rule4hkup | rule4hRSIup))
shift8h = (rule8hunder & (rule8hkup | rule8hRSIup))
shift30m = (rule30munder & (rule30mkup | rule30mRSIup))
shift15m = (rule15munder & (rule15mkup | rule15mRSIup))
shift5m = (rule5munder & (rule5mkup | rule5mRSIup))



stk12hcross = (final['STRSIKM12h'] < final['STRSIDM12h']) & (final['STRSIK12h'] > final['STRSID12h'])
stk15mcross = (final['STRSIKM15m'] < final['STRSIDM15m']) & (final['STRSIK15m'] > final['STRSID15m'])
stk1hcross = (final['STRSIKM1h'] < final['STRSIDM1h']) & (final['STRSIK1h'] > final['STRSID1h'])
stk1dcross = (final['STRSIKM1d'] < final['STRSIDM1d']) & (final['STRSIK1d'] > final['STRSID1d'])
stk1wcross = (final['STRSIKM1w'] < final['STRSIDM1w']) & (final['STRSIK1w'] > final['STRSID1w'])
stk2hcross = (final['STRSIKM2h'] < final['STRSIDM2h']) & (final['STRSIK2h'] > final['STRSID2h'])
stk30mcross = (final['STRSIKM30m'] < final['STRSIDM30m']) & (final['STRSIK30m'] > final['STRSID30m'])
stk3dcross = (final['STRSIKM3d'] < final['STRSIDM3d']) & (final['STRSIK3d'] > final['STRSID3d'])
stk4hcross = (final['STRSIKM4h'] < final['STRSIDM4h']) & (final['STRSIK4h'] > final['STRSID4h'])
stk5mcross = (final['STRSIKM5m'] < final['STRSIDM5m']) & (final['STRSIK5m'] > final['STRSID5m'])
stk8hcross = (final['STRSIKM8h'] < final['STRSIDM8h']) & (final['STRSIK8h'] > final['STRSID8h'])

top12h = (final['STRSIK12h'] > 0.8)
top1d = (final['STRSIK1d'] > 0.8)
top1h = (final['STRSIK1h'] > 0.8)
top1w = (final['STRSIK1w'] > 0.8)
top2h = (final['STRSIK2h'] > 0.8)
top3d = (final['STRSIK3d'] > 0.8)
top4h = (final['STRSIK4h'] > 0.8)
top8h = (final['STRSIK8h'] > 0.8)
top30m = (final['STRSIK30m'] > 0.8)
top15m = (final['STRSIK15m'] > 0.8)
top5m = (final['STRSIK5m'] > 0.8)



topr12h = (final['RSI12h'] > 70)
topr1d = (final['RSI1d'] > 70)
topr1h = (final['RSI1h'] > 70)
topr1w = (final['RSI1w'] > 70)
topr2h = (final['RSI2h'] > 70)
topr3d = (final['RSI3d'] > 70)
topr4h = (final['RSI4h'] > 70)
topr8h = (final['RSI8h'] > 70)
topr30m = (final['RSI30m'] > 70)
topr15m = (final['RSI15m'] > 70)
topr5m = (final['RSI5m'] > 70)




uptrend12h = (rule12hover & (rule12hkup & rule12hRSIup))
uptrend1d = (rule1dover & (rule1dkup & rule1dRSIup))
uptrend1h = (rule1hover & (rule1hkup & rule1hRSIup))
uptrend1w = (rule1wover & (rule1wkup & rule1wRSIup))
uptrend2h = (rule2hover & (rule2hkup & rule2hRSIup))
uptrend3d = (rule3dover & (rule3dkup & rule3dRSIup))
uptrend4h = (rule4hover & (rule4hkup & rule4hRSIup))
uptrend8h = (rule8hover & (rule8hkup & rule8hRSIup))
uptrend30m = (rule30mover & (rule30mkup & rule30mRSIup))
uptrend15m = (rule15mover & (rule15mkup & rule15mRSIup))
uptrend5m = (rule5mover & (rule5mkup & rule5mRSIup))




downtrend12h = (rule12hunder & (rule12hkdown & rule12hRSIdown))
downtrend1d = (rule1dunder & (rule1dkdown & rule1dRSIdown))
downtrend1h = (rule1hunder & (rule1hkdown & rule1hRSIdown))
downtrend1w = (rule1wunder & (rule1wkdown & rule1wRSIdown))
downtrend2h = (rule2hunder & (rule2hkdown & rule2hRSIdown))
downtrend3d = (rule3dunder & (rule3dkdown & rule3dRSIdown))
downtrend4h = (rule4hunder & (rule4hkdown & rule4hRSIdown))
downtrend8h = (rule8hunder & (rule8hkdown & rule8hRSIdown))
downtrend30m = (rule30munder & (rule30mkdown & rule30mRSIdown))
downtrend15m = (rule15munder & (rule15mkdown & rule15mRSIdown))
downtrend5m = (rule5munder & (rule5mkdown & rule5mRSIdown))


dshift12h = (rule12hover & (rule12hkdown | rule12hRSIdown))
dshift1d = (rule1dover & (rule1dkdown | rule1dRSIdown))
dshift1h = (rule1hover & (rule1hkdown | rule1hRSIdown))
dshift1w = (rule1wover & (rule1wkdown | rule1wRSIdown))
dshift2h = (rule2hover & (rule2hkdown | rule2hRSIdown))
dshift3d = (rule3dover & (rule3dkdown | rule3dRSIdown))
dshift4h = (rule4hover & (rule4hkdown | rule4hRSIdown))
dshift8h = (rule8hover & (rule8hkdown | rule8hRSIdown))
dshift30m = (rule30mover & (rule30mkdown | rule30mRSIdown))
dshift15m = (rule15mover & (rule15mkdown | rule15mRSIdown))
dshift5m = (rule5mover & (rule5mkdown | rule5mRSIdown))

# %%
wshift = final.loc[shift1w]
wshift
# Out:
#     Indicator           O5m           C5m           H5m           L5m  \
# 32   WAXPUSDT      0.094000      0.093800      0.094200      0.093800
# 43   REEFUSDT      0.003620      0.003610      0.003620      0.003600
# 109   ZRXUSDT      0.289900      0.288500      0.289900      0.288500
# 120   XTZUSDT      1.456000      1.454000      1.456000      1.452000
# 153   WINUSDT      0.000116      0.000116      0.000116      0.000116
# 164  DENTUSDT      0.000954      0.000951      0.000955      0.000949
# 239  CAKEUSDT      3.256000      3.249000      3.256000      3.245000
# 250   XLMUSDT      0.124500      0.124500      0.124800      0.124300
# 360  MOVRUSDT     11.700000     11.600000     11.700000     11.600000
# 447   ONTUSDT      0.240900      0.240100      0.240900      0.239900
# 469   GRTUSDT      0.111500      0.111100      0.111500      0.110900
# 491   ZILUSDT      0.046660      0.046500      0.046700      0.046430
# 546  BANDUSDT      1.442000      1.439000      1.442000      1.438000
# 579  IOTXUSDT      0.028520      0.028500      0.028530      0.028400
# 590  CTSIUSDT      0.161200      0.161200      0.161400      0.160600
# 634   BTCUSDT  20943.420000  20883.840000  20947.000000  20873.420000
# 645   ADAUSDT      0.488600      0.488000      0.488700      0.487100
#
#               V5m          OM5m          CM5m          HM5m          LM5m  \
# 32   2.343400e+04      0.094200      0.094100      0.094300      0.094100
# 43   2.723206e+06      0.003620      0.003620      0.003620      0.003610
# 109  2.883000e+03      0.289900      0.289900      0.290200      0.289100
# 120  5.886600e+03      1.457000      1.457000      1.459000      1.456000
# 153  7.836056e+07      0.000116      0.000116      0.000116      0.000116
# 164  6.167691e+06      0.000952      0.000953      0.000955      0.000952
# 239  6.141150e+03      3.251000      3.256000      3.263000      3.250000
# 250  2.779070e+05      0.124400      0.124600      0.124600      0.124400
# 360  8.194300e+01     11.600000     11.700000     11.700000     11.600000
# 447  1.820500e+04      0.240500      0.240900      0.241100      0.240500
# 469  1.180320e+05      0.111200      0.111500      0.111700      0.111100
# 491  3.211218e+06      0.046660      0.046660      0.046770      0.046650
# 546  1.951900e+03      1.437000      1.442000      1.443000      1.436000
# 579  6.643860e+05      0.028500      0.028510      0.028550      0.028470
# 590  2.314700e+04      0.161200      0.161100      0.161300      0.161100
# 634  1.546710e+02  20935.090000  20943.420000  20962.170000  20935.000000
# 645  3.933581e+05      0.488400      0.488600      0.489600      0.488300
#
#      ...  SMA200M1w        MACD1w  MACDSIGNAL1w       MACDM1w  MACDSIGNALM1w  \
# 32   ...        NaN     -0.158771     -0.151855     -0.161358      -0.148398
# 43   ...        NaN     -0.007116     -0.007253     -0.007379      -0.007321
# 109  ...        NaN     -0.302135     -0.262971     -0.298077      -0.243389
# 120  ...        NaN     -1.474901     -1.380095     -1.466543      -1.332692
# 153  ...        NaN     -0.000174     -0.000169     -0.000176      -0.000167
# 164  ...        NaN     -0.001564     -0.001528     -0.001605      -0.001511
# 239  ...        NaN     -4.965260     -4.748586     -4.986259      -4.640250
# 250  ...        NaN     -0.077750     -0.076636     -0.080684      -0.076079
# 360  ...        NaN    -96.523448   -102.080746    -99.910125    -104.859395
# 447  ...        NaN     -0.276910     -0.270086     -0.284262      -0.266674
# 469  ...        NaN     -0.288219     -0.284365     -0.294898      -0.282437
# 491  ...        NaN     -0.024283     -0.019593     -0.025870      -0.017248
# 546  ...        NaN     -2.494560     -2.497415     -2.573845      -2.498843
# 579  ...        NaN     -0.032562     -0.029766     -0.033037      -0.028369
# 590  ...        NaN     -0.204521     -0.201979     -0.207024      -0.200708
# 634  ...        NaN -12792.121176 -10501.183095 -11795.723960   -9355.714055
# 645  ...        NaN     -0.459700     -0.457789     -0.471662      -0.456833
#
#         BOTTOMP1w        TOPP1w    BOTTOMPM1w       TOPPM1w  \
# 32       0.075000      0.290500      0.241700      0.395000
# 43       0.002740      0.010440      0.007880      0.012800
# 109      0.222900      1.183800      0.450000      1.183800
# 120      1.195000      3.272000      2.560000      4.192000
# 153      0.000099      0.000329      0.000243      0.000418
# 164      0.000749      0.002910      0.001934      0.003989
# 239      2.486000      9.780000      5.300000     10.990000
# 250      0.100100      0.213700      0.161700      0.241700
# 360      9.800000     63.000000     44.200000    108.000000
# 447      0.190500      0.614900      0.424400      0.703500
# 469      0.089000      0.410900      0.302300      0.550700
# 491      0.029370      0.135400      0.033170      0.230700
# 546      1.181000      4.144000      3.076000      5.635000
# 579      0.021390      0.081270      0.062060      0.114800
# 590      0.127800      0.404600      0.281700      0.547400
# 634  17622.000000  42976.000000  34322.280000  48189.840000
# 645      0.401900      0.976000      0.746000      1.246000
#
#                           Time
# 32  2022-06-24 10:43:17.472351
# 43  2022-06-24 10:43:17.472351
# 109 2022-06-24 10:43:17.472351
# 120 2022-06-24 10:43:17.472351
# 153 2022-06-24 10:43:17.472351
# 164 2022-06-24 10:43:17.472351
# 239 2022-06-24 10:43:17.472351
# 250 2022-06-24 10:43:17.472351
# 360 2022-06-24 10:43:17.472351
# 447 2022-06-24 10:43:17.472351
# 469 2022-06-24 10:43:17.472351
# 491 2022-06-24 10:43:17.472351
# 546 2022-06-24 10:43:17.472351
# 579 2022-06-24 10:43:17.472351
# 590 2022-06-24 10:43:17.472351
# 634 2022-06-24 10:43:17.472351
# 645 2022-06-24 10:43:17.472351
#
# [17 rows x 365 columns]

# %% [markdown]
# # Summary  draft rules

# %%
#final.reset_index(inplace=True)

#final.set_index(['Indicator'],inplace=True)

# drop = final.loc[bottom4h & (shift4h | rule4over)]
#drop = final.loc[(bottom4h | (uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[((uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[(uptrend8h | shift8h) & (uptrend12h | shift12h) & (uptrend1d | shift1d)]
#drop = final.loc[(uptrend2h | shift2h) & (uptrend4h | shift4h) ]
#drop = final.loc[(uptrend4h | shift4h)]

#drop = final.loc[bottom8h | (shift8h | rule8over)]
#drop = final.loc[bottom12h | (shift12h | rule12over)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[bottom12h | (shift12h | uptrend12h)]
#drop = final.loc[bottom1d | (shift1d | uptrend1d)]
#drop = final.loc[top4h]
#drop = final.loc[(uptrend3d)]
#drop = final.loc[dshift4h]
#drop = final.loc[shift2h]

#drop = final.loc[(bottom4h & bottom12h & bottom3d)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[(downtrend8h & downtrend4h & downtrend12h)]
#drop = final.loc[(bottom4h & bottom2h & bottom3d)]
#drop = final.loc[shift3d & bottom4h]

#drop = final.loc[(bottom12h)]
#drop = final.loc[ ((rule4kup |rule4RSIup))]

#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend4h | shift4h) ]
#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) ]

# 4 hours will go down or slow down
#drop = final.loc[( (bottom3d) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) & dshift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) &  (uptrend2h | shift2h) &  (uptrend1h | shift1h)]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]

#drop = final.loc[( (bottom4h) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h)) ]
#drop = final.loc[((bottom1d) & (bottom3d))]
#drop = drop.loc[( (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h))]
#drop = final.loc[dshift4h]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) & (downtrend2h |dshift2h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[dshift2h]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h) & (bottom2h))]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h))]

#drop= final.loc[(shift4h) & (shift12h)]
#drop = final.loc[(dshift4h | downtrend4h)]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (dshift4h | downtrend4h))]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (shift2h))]

#drop = final.loc[downtrend1d & downtrend12h & downtrend8h & downtrend4h]
#drop = final.loc[top8h]

#drop



    

#bottomtable['bottoms'] = bottomtable.apply(get_key(listb,bottomtable.loc('Indicator'),axis=1)

#bottomtable
#reversetable
#bottomstable = pd.DataFrame(reversetable,columns=['Indicator','Bottoms'])
#print (bottomstable)
#listb
#listd = pd.DataFrame(listb,columns=['Bottoms','Indicator'])
#print (listb)
#print(reversetable)
#listd.head()
#test = final.loc[(MACDGAP3d)]
test = final.loc[(MACDCROSS3d)]
test = final.loc[(MACDCROSS1d)]
test = final.loc[(MACDGAPU3d)]
test = final.loc[(MACDGAPD3d)& rule3dover & rule3dRSIup]
#macd3d = final.loc[(MACDGAPU3d)& rule3dRSIup]
macd1d = final.loc[(MACDGAPD1d)& rule1dRSIup]
macd3du = final.loc[(MACDGAPU3d)]
macd3dd = final.loc[(MACDGAPD3d)]
macd1du = final.loc[(MACDGAPU1d)]
macd1dd = final.loc[(MACDGAPD1d)]
macd1wu = final.loc[(MACDGAPU1w)]
macd1wd = final.loc[(MACDGAPD1w)]

macd3d1d = final.loc[(MACDGAPD1d &  (MACDGAPD3d)  & rule3dRSIup & rule1dRSIup )]
macd1dcross = final.loc[MACDCROSS1d]
macd12hcross = final.loc[MACDCROSS12h]
macd8hcross = final.loc[MACDCROSS8h]
macd4hcross = final.loc[MACDCROSS4h]
macd3dcross = final.loc[MACDCROSS3d]
stk3d = final.loc[stk3dcross]
stk1w = final.loc[stk1wcross]
macd3dd
#macd12hcross
#macd12hcross
#macd4hcross
#macd3d1d
#macd1d
#pmacdu = macd3du[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdu['diff']=abs(macd3du['MACD3d'])-abs(macd3du['MACDSIGNAL3d'])
#pmacdu['diffm']=abs(macd3du['MACDM3d'])-abs(macd3du['MACDSIGNALM3d'])

#pmacdd = macd3dd[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdd['diff']=abs(macd3dd['MACD3d'])-abs(macd3dd['MACDSIGNAL3d'])
#pmacdd['diffm']=abs(macd3dd['MACDM3d'])-abs(macd3dd['MACDSIGNALM3d'])
#final.set_index(['Indicator'],inplace=True)

#final.reset_index(inplace=True)
test1h = final[['Indicator','BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]
#test1h = final[['BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]

test15 = final[['Indicator','BOTTOMP15m','BOTTOMPM15m','TOPP15m','TOPPM15m']]
#test15.set_index(['Indicator'],inplace=True)
test5 = final[['Indicator','BOTTOMP5m','BOTTOMPM5m','TOPP5m','TOPPM5m']]
test30 = final[['Indicator','BOTTOMP30m','BOTTOMPM30m','TOPP30m','TOPPM30m']]
#test30.set_index(['Indicator'],inplace=True)

test2h = final[['Indicator','BOTTOMP2h','BOTTOMPM2h','TOPP2h','TOPPM2h']]

test4h = final[['Indicator','BOTTOMP4h','BOTTOMPM4h','TOPP4h','TOPPM4h']]

#final.set_index(['Indicator'],inplace=True)

higherhi = test15.loc[HIHI15m & HILO15m]
#higherhi = test30.loc[HIHI30m & HILO30m]
#higherhi = test1h.loc[HIHI1h & HILO1h]
#higherhi = test2h.loc[HIHI2h & HILO2h]

#higherhi = test4h.loc[HIHI4h & HILO4h]

lowhi = test15.loc[LOHI15m & LOLO15m]
lowhi = test5.loc[LOHI5m & LOLO5m]
#lowhi = test1h.loc[LOHI1h & LOLO1h]
lowhi = test30.loc[LOHI30m & LOLO30m]
lowhi = test2h.loc[LOHI2h & LOLO2h]
lowhi = test4h.loc[LOHI4h & LOLO4h]

higherhi5 = test5.loc[HIHI5m & HILO5m]
higherhi2 = test2h.loc[HIHI2h & HILO2h]
higherhi4 = test4h.loc[HIHI4h & HILO4h]


#higherhi = test15.loc[HIHI15m ]
#higherhi = test.loc[HIHI1h]
#higherhi = test5.loc[HIHI5m ]
#higherlo = test5.loc[HILO5m ]
#higherlo = test15.loc[HILO15m ]


higherhi
stk3d
macd3dd
macd1wd
#macd3dd
#macd1dd
#macd1du
#lowhi
hihi5macd1w=macd1wd.loc[HIHI5m & HILO5m &rule1hRSIup &room1h & rule2hRSIup & room2h & rule4hRSIup & room4h]
rsiup54h=final.loc[rule5mRSIup  &rule15mRSIup &rule30mRSIup  &rule1hRSIup & rule2hRSIup & rule4hRSIup & room4h]

hihi5macd1w
#higherhi5
rsiup54h
# Out:
# Empty DataFrame
# Columns: [Indicator, O5m, C5m, H5m, L5m, V5m, OM5m, CM5m, HM5m, LM5m, VM5m, RSI5m, RSIM5m, STRSI5m, STRSIK5m, STRSIKM5m, STRSID5m, STRSIDM5m, SMA215m, SMA21M5m, SMA555m, SMA55M5m, SMA1005m, SMA100M5m, SMA2005m, SMA200M5m, MACD5m, MACDSIGNAL5m, MACDM5m, MACDSIGNALM5m, BOTTOMP5m, TOPP5m, BOTTOMPM5m, TOPPM5m, O15m, C15m, H15m, L15m, V15m, OM15m, CM15m, HM15m, LM15m, VM15m, RSI15m, RSIM15m, STRSI15m, STRSIK15m, STRSIKM15m, STRSID15m, STRSIDM15m, SMA2115m, SMA21M15m, SMA5515m, SMA55M15m, SMA10015m, SMA100M15m, SMA20015m, SMA200M15m, MACD15m, MACDSIGNAL15m, MACDM15m, MACDSIGNALM15m, BOTTOMP15m, TOPP15m, BOTTOMPM15m, TOPPM15m, O30m, C30m, H30m, L30m, V30m, OM30m, CM30m, HM30m, LM30m, VM30m, RSI30m, RSIM30m, STRSI30m, STRSIK30m, STRSIKM30m, STRSID30m, STRSIDM30m, SMA2130m, SMA21M30m, SMA5530m, SMA55M30m, SMA10030m, SMA100M30m, SMA20030m, SMA200M30m, MACD30m, MACDSIGNAL30m, MACDM30m, MACDSIGNALM30m, BOTTOMP30m, TOPP30m, BOTTOMPM30m, TOPPM30m, ...]
# Index: []
#
# [0 rows x 365 columns]

# %% [markdown]
# # Functions

# %%
#DRAFT functions display
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        

## return a list of timeframes per ta indicator taname  for specific sympbol
#series to list 
def srtolist(final:pd,taname)->[]:
    #ta = globals()[taname]
    array = final[taname].values
    array= str(array[0]).split(",")
    
    #for k in range(0,len(array)):
            #print (k)
            #print (f" {taname} = {array[k]} \n")
    return array

# list to string 
def ltos (mylist)->str:
    mystring = ''
    for x in mylist:
        if not mystring:
            mystring+=x
        else:
            mystring+=","+x
    return mystring

def get_key(my_dict,val):
        keylist = []
        for key, value in my_dict.items():
             if val in value:
                keylist.append(key)
        return keylist
    
def to_df(final:pd ,func,name):
    listb = func(final)
    res = list(sorted({ele for val in listb.values() for ele in val}))
    reversetable = []
    for indi in res:
        ttuple = (indi,ltos(get_key(listb,indi)))
        reversetable.append(ttuple)
    dframe = pd.DataFrame(reversetable,columns=['Indicator',name])
    return dframe
                                                
    
def tops(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['top'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : query.append(i)
        toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def uptrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['uptrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def downtrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['downtrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def shift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['shift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def dshift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['dshift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def topr(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['topr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['bottomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottoms(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    bottomlist ={}
    for i in intervals:
        var = globals()['bottom'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            bottomlist[i]=test['Indicator'].tolist()
 
    return bottomlist

def room(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['room'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def roomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['roomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsiup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsidown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']         
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stover(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'over']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stunder(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'under']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkdown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def stkcross(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['stk'+i+'cross']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    
    return toplist


def buyzones(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        for item in lrsiup :
            if item in lroomr:
                if item in lroom:
                    buy.append(item)
                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final
  

def buyzonesa(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        buyindex = []
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        lrsidown= srtolist(test1,'rsidown')
        lstkup= srtolist(test1,'stkup')
        
        for item in lrsiup :
            if item in lroomr:
                if item in lroom:
                    buy.append(item)
        for item in buy:
            #print(item)
            #print(intervals.index(item))
            buyindex.append(intervals.index(item))
        
        for l,n in zip(buy,buyindex):
            if intervals[n]=='1w':
                if intervals[n-1] in lrsidown:
                    buy.remove(l)
                continue
            if intervals[n]=='5m':
                if intervals[n+1] not in lroomr:
                    buy.remove(l)
                continue
            if intervals[n+1] not in lroomr:
                buy.remove(l)
                continue
            if intervals[n-1] in lrsidown:
                buy.remove(l)
                continue
            
                
            #print(f"buy ={l} index={intervals[n+1]}")                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final  



def buyzonesb(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        buyindex = []
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        lrsidown= srtolist(test1,'rsidown')
        lstkup= srtolist(test1,'stkup')
        lstbottom= srtolist(test1,'bottoms')
        lstbottomr= srtolist(test1,'bottomr')
        
        
        for item in lstbottom :
            if item in rsiup:
                buy.append(item)
        for item in buy:
            #print(item)
            #print(intervals.index(item))
            buyindex.append(intervals.index(item))
        
        for l,n in zip(buy,buyindex):
            if intervals[n]=='1w':
                if intervals[n-1] in lrsidown:
                    buy.remove(l)
                continue
            if intervals[n]=='5m':
                if intervals[n+1] not in lroomr:
                    buy.remove(l)
                continue
            if intervals[n+1] not in lroomr:
                buy.remove(l)
                continue
            if intervals[n-1] in lrsidown:
                buy.remove(l)
                continue
            
                
            #print(f"buy ={l} index={intervals[n+1]}")                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final

#not used but defined for later 
def mergetables(final:pd,*arg)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(arg)):
        test = indicators.merge(arg[i] ,how="left",on="Indicator")
        indicators = test
    return test

# call the function and merge the tables 
def callfun(final:pd,*var)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(var)):
        test=to_df(final ,globals()[var[i]],var[i])
        indicators=indicators.merge(test ,how="left",on="Indicator")
    return indicators


def wrjson(wl,name):
    test = json.dumps(wl)
    with open(name, "w") as wlf:
        json.dump(test, wlf,indent=4)
        
def frtolist(final:pd)->[]:
    whitelist = []
    wl = []
    whitelist = final['Indicator'].tolist()
    for i in range(0 ,len(whitelist)):
        #print (str(whitelist[i].replace('USDT',"/USDT")))
        wl.append(str(whitelist[i].replace('USDT',"/USDT")))
    if len(wl)==0:
        wl.append('BUSD/USDT')
    return wl

# %%
newframe=callfun(final,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','shift'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['rsiup','bottoms','bottomr'],ascending=[False,False,False])

newframe.to_csv("allindi"+str(date.today())+".csv")

test = newframe.loc[(newframe['downtrend'] <= '1h')]
test = newframe.loc[(newframe['bottomr'] >= '12h')]
#test = newframe.loc[(newframe['rsidown'] >= '2h')]
#test = newframe.loc[(newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '2h,4h') & (newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '12h') & (newframe['bottomr'] >= '1') ]
#test = newframe.loc[(newframe['bottomr'] >= '1') & (newframe['rsiup'] >= '1')]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['rsidown'].notnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['shift'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['rsidown'].isnull()) & (newframe['tops'] <='4h') & (newframe['topr'].isnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['topr'].isnull()) ]

#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['topr'].isnull()) & (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['stkdown'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') ]
#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['uptrend'].notnull()) ]

#test = newframe.loc[(newframe['shift'].isnull()) &  (newframe['uptrend'].isnull()) ]

#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]
#test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]

#test = newframe.loc[(newframe['rsiup'].notnull()) & (newframe['bottoms'].notnull())  & (newframe['uptrend'].notnull())]


test = newframe.loc[(newframe['rsiup'] <= '8h') & (newframe['bottoms'].notnull())]

test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['stover'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['bottoms'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull())]

test = newframe.loc[(newframe['rsiup'] >= '1h,2h,4h') ]


#test = newframe.loc[(newframe['bottomr'] <= '12h') &  (newframe['bottoms'] <= '12h') ]
#test = newframe.loc[(newframe['bottomr'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]
#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkup'].notnull()))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]

#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h'))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h')) & (newframe['bottomr'].notnull())]




#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[(newframe['tops'].isnull()) &  (newframe['rsidown'].isnull()) ]


#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]

#test = newframe.loc[(newframe['rsiup'] <= '1w') & (newframe['bottoms'] >= '4h') &  (newframe['shift'].notnull())]


#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['rsidown'].isnull()) | (newframe['rsidown'] <= '1') ]

#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) & (newframe['downtrend'].isnull()) ]
#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) ]

#test = newframe.loc[(newframe['shift'] >= '12h,1d,3d')]

#newframe

#test

# %%
 

test3 = buyzonesa(test)
test3=test3.pivot(index='buyzones',columns='Indicator')
test3.stack()
# Out:
#                               stkcross                                rsiup  \
# buyzones            Indicator
#                     CRVUSDT         1w                                   1w
#                     MIRUSDT        NaN                                  30m
#                     PERPUSDT        1w                                   1w
#                     RAYUSDT         1w                                   1w
# 1d                  GLMRUSDT     3d,1w                            8h,12h,1d
# 1d,3d,1w            BANDUSDT       NaN                          8h,1d,3d,1w
#                     COTIUSDT       15m                1h,2h,8h,12h,1d,3d,1w
#                     OMGUSDT      3d,1w                      8h,12h,1d,3d,1w
#                     VETUSDT         1w                1h,2h,8h,12h,1d,3d,1w
#                     WINUSDT         3d                   1h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT         3d            30m,1h,2h,8h,12h,1d,3d,1w
# 1w                  AUDIOUSDT       1w                      8h,12h,1d,3d,1w
#                     BTCUSDT         3d                                3d,1w
#                     RUNEUSDT        1w                                3d,1w
#                     SOLUSDT        30m                                3d,1w
#                     SUSHIUSDT   15m,1w                                3d,1w
# 2h,1d,3d,1w         GALAUSDT        1w                1h,2h,8h,12h,1d,3d,1w
# 2h,1w               GRTUSDT        NaN                             2h,3d,1w
# 2h,3d,1w            KSMUSDT        NaN                   2h,8h,12h,1d,3d,1w
#                     MANAUSDT       15m                1h,2h,8h,12h,1d,3d,1w
# 2h,8h,1d,3d,1w      ADAUSDT     15m,3d                1h,2h,8h,12h,1d,3d,1w
# 2h,8h,3d,1w         LINKUSDT       NaN                1h,2h,8h,12h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT          1w            30m,1h,2h,8h,12h,1d,3d,1w
# 30m,2h,1w           ATOMUSDT       30m               30m,2h,8h,12h,1d,3d,1w
#                     CAKEUSDT       NaN                      30m,2h,8h,3d,1w
# 30m,8h,1d,1w        ANTUSDT     15m,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3d,1w               AVAXUSDT        1w                      8h,12h,1d,3d,1w
#                     CELRUSDT    12h,1w                1h,2h,8h,12h,1d,3d,1w
#                     DENTUSDT       15m                1h,2h,8h,12h,1d,3d,1w
#                     DOTUSDT         1d                      8h,12h,1d,3d,1w
#                     FTMUSDT         1w                      8h,12h,1d,3d,1w
#                     LRCUSDT      3d,1w                      8h,12h,1d,3d,1w
#                     MATICUSDT       1w                1h,2h,8h,12h,1d,3d,1w
#                     NEARUSDT       NaN                1h,2h,8h,12h,1d,3d,1w
#                     ONTUSDT        NaN                      8h,12h,1d,3d,1w
#                     ROSEUSDT        1w                      8h,12h,1d,3d,1w
#                     SCUSDT         NaN                      8h,12h,1d,3d,1w
#                     ZILUSDT        12h                      8h,12h,1d,3d,1w
# 5m,15m,30m          PAXGUSDT       30m                           5m,15m,30m
# 5m,15m,30m,1d,3d,1w VTHOUSDT     5m,1w           5m,15m,30m,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT       NaN                  5m,15m,30m,1h,2h,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT   15m,1h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w       STORJUSDT       5m                     5m,15m,30m,3d,1w
# 8h,1w               REEFUSDT       NaN                      8h,12h,1d,3d,1w
#                     THETAUSDT      NaN             1h,2h,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT     1h,1w                   4h,8h,12h,1d,3d,1w
#                     RENUSDT     8h,12h                   4h,8h,12h,1d,3d,1w
#
#                                                         rsidown  \
# buyzones            Indicator
#                     CRVUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                     MIRUSDT     5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
#                     PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                     RAYUSDT              5m,15m,4h,8h,12h,1d,3d
# 1d                  GLMRUSDT          5m,15m,30m,1h,2h,4h,3d,1w
# 1d,3d,1w            BANDUSDT                    5m,30m,1h,2h,4h
#                     COTIUSDT                      5m,15m,30m,4h
#                     OMGUSDT                 5m,15m,30m,1h,2h,4h
#                     VETUSDT                       5m,15m,30m,4h
#                     WINUSDT                       5m,15m,30m,4h
# 1h,1d,3d,1w         XTZUSDT                           5m,15m,4h
# 1w                  AUDIOUSDT               5m,15m,30m,1h,2h,4h
#                     BTCUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d
#                     RUNEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d
#                     SOLUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d
#                     SUSHIUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d
# 2h,1d,3d,1w         GALAUSDT                      5m,15m,30m,4h
# 2h,1w               GRTUSDT             5m,15m,30m,4h,8h,12h,1d
# 2h,3d,1w            KSMUSDT                       5m,15m,30m,4h
#                     MANAUSDT                      5m,15m,30m,4h
# 2h,8h,1d,3d,1w      ADAUSDT                       5m,15m,30m,4h
# 2h,8h,3d,1w         LINKUSDT                      5m,15m,30m,4h
# 30m,1h,3d,1w        ARUSDT                                5m,4h
# 30m,2h,1w           ATOMUSDT                              5m,4h
#                     CAKEUSDT                       5m,4h,12h,1d
# 30m,8h,1d,1w        ANTUSDT                                  5m
# 3d,1w               AVAXUSDT                5m,15m,30m,1h,2h,4h
#                     CELRUSDT                      5m,15m,30m,4h
#                     DENTUSDT                      5m,15m,30m,4h
#                     DOTUSDT                               5m,4h
#                     FTMUSDT                 5m,15m,30m,1h,2h,4h
#                     LRCUSDT                 5m,15m,30m,1h,2h,4h
#                     MATICUSDT                        5m,15m,30m
#                     NEARUSDT                      5m,15m,30m,4h
#                     ONTUSDT                     5m,30m,1h,2h,4h
#                     ROSEUSDT                5m,15m,30m,1h,2h,4h
#                     SCUSDT                     5m,15m,30m,1h,4h
#                     ZILUSDT                 5m,15m,30m,1h,2h,4h
# 5m,15m,30m          PAXGUSDT           1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT                              1h,2h
# 5m,15m,30m,1h,2h    CTSIUSDT                    4h,8h,12h,1d,3d
# 5m,15m,30m,1h,8h,1w TFUELUSDT                               NaN
# 5m,15m,30m,1w       STORJUSDT                1h,2h,4h,8h,12h,1d
# 8h,1w               REEFUSDT                         5m,15m,30m
#                     THETAUSDT                        5m,15m,30m
# 8h,3d,1w            MINAUSDT                   5m,15m,30m,1h,2h
#                     RENUSDT                              5m,15m
#
#                                              tops           bottoms  \
# buyzones            Indicator
#                     CRVUSDT          4h,8h,12h,1d     5m,15m,30m,1w
#                     MIRUSDT                12h,1d     5m,15m,30m,1w
#                     PERPUSDT            8h,12h,1d  5m,15m,30m,2h,1w
#                     RAYUSDT          4h,8h,12h,1d        15m,30m,1w
# 1d                  GLMRUSDT            4h,8h,12h     15m,30m,3d,1w
# 1d,3d,1w            BANDUSDT            2h,4h,12h                1w
#                     COTIUSDT         2h,4h,8h,12h        15m,30m,1w
#                     OMGUSDT          2h,4h,8h,12h     5m,15m,30m,1w
#                     VETUSDT          2h,4h,8h,12h        15m,30m,1w
#                     WINUSDT          2h,4h,8h,12h        15m,30m,1w
# 1h,1d,3d,1w         XTZUSDT          2h,4h,8h,12h     5m,15m,30m,1w
# 1w                  AUDIOUSDT     2h,8h,12h,1d,3d         5m,30m,1w
#                     BTCUSDT             4h,8h,12h        15m,30m,1w
#                     RUNEUSDT         4h,8h,12h,1d        15m,30m,1w
#                     SOLUSDT       4h,8h,12h,1d,3d        15m,30m,1w
#                     SUSHIUSDT              12h,1d            30m,1w
# 2h,1d,3d,1w         GALAUSDT            4h,8h,12h        15m,30m,1w
# 2h,1w               GRTUSDT                12h,1d        15m,30m,1w
# 2h,3d,1w            KSMUSDT             4h,12h,1d        15m,30m,1w
#                     MANAUSDT         4h,8h,12h,1d        15m,30m,1w
# 2h,8h,1d,3d,1w      ADAUSDT                    4h        15m,30m,1w
# 2h,8h,3d,1w         LINKUSDT               4h,12h        15m,30m,1w
# 30m,1h,3d,1w        ARUSDT           2h,4h,12h,1d        15m,30m,1w
# 30m,2h,1w           ATOMUSDT      4h,8h,12h,1d,3d     15m,30m,1h,1w
#                     CAKEUSDT         4h,8h,12h,1d        15m,30m,1w
# 30m,8h,1d,1w        ANTUSDT       1h,2h,4h,12h,3d        15m,30m,1w
# 3d,1w               AVAXUSDT   1h,2h,4h,8h,12h,1d         5m,15m,1w
#                     CELRUSDT      2h,4h,8h,12h,1d            30m,1w
#                     DENTUSDT      2h,4h,8h,12h,1d            30m,1w
#                     DOTUSDT             4h,12h,1d        15m,30m,1w
#                     FTMUSDT             2h,12h,1d     5m,15m,30m,1w
#                     LRCUSDT          4h,8h,12h,1d     5m,15m,30m,1w
#                     MATICUSDT     2h,4h,8h,12h,1d        15m,30m,1w
#                     NEARUSDT      2h,4h,8h,12h,1d     15m,30m,3d,1w
#                     ONTUSDT          4h,8h,12h,1d        15m,30m,1w
#                     ROSEUSDT            8h,12h,1d        15m,30m,1w
#                     SCUSDT           4h,8h,12h,1d        15m,30m,1w
#                     ZILUSDT             8h,12h,1d     5m,15m,30m,1w
# 5m,15m,30m          PAXGUSDT                  NaN     15m,4h,8h,12h
# 5m,15m,30m,1d,3d,1w VTHOUSDT      1h,2h,4h,8h,12h         5m,15m,1w
# 5m,15m,30m,1h,2h    CTSIUSDT            4h,8h,12h  5m,15m,30m,1h,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT     2h,4h,12h,1d,3d                1w
# 5m,15m,30m,1w       STORJUSDT        4h,12h,1d,3d            5m,30m
# 8h,1w               REEFUSDT      2h,4h,12h,1d,3d        15m,30m,1w
#                     THETAUSDT  1h,2h,4h,12h,1d,3d                1w
# 8h,3d,1w            MINAUSDT      1h,2h,4h,12h,1d         5m,15m,1w
#                     RENUSDT       1h,2h,4h,12h,1d        15m,30m,1w
#
#                                       topr   bottomr  \
# buyzones            Indicator
#                     CRVUSDT            NaN       NaN
#                     MIRUSDT            NaN     3d,1w
#                     PERPUSDT           NaN  5m,3d,1w
#                     RAYUSDT            NaN        3d
# 1d                  GLMRUSDT           NaN     3d,1w
# 1d,3d,1w            BANDUSDT           NaN       NaN
#                     COTIUSDT           NaN       NaN
#                     OMGUSDT            NaN       NaN
#                     VETUSDT            NaN       NaN
#                     WINUSDT            NaN        3d
# 1h,1d,3d,1w         XTZUSDT            NaN       NaN
# 1w                  AUDIOUSDT          NaN       NaN
#                     BTCUSDT            NaN     3d,1w
#                     RUNEUSDT           NaN       NaN
#                     SOLUSDT            NaN       NaN
#                     SUSHIUSDT          NaN       NaN
# 2h,1d,3d,1w         GALAUSDT           NaN       NaN
# 2h,1w               GRTUSDT            NaN       NaN
# 2h,3d,1w            KSMUSDT            NaN       NaN
#                     MANAUSDT           NaN       NaN
# 2h,8h,1d,3d,1w      ADAUSDT            NaN       NaN
# 2h,8h,3d,1w         LINKUSDT           NaN       NaN
# 30m,1h,3d,1w        ARUSDT             NaN        3d
# 30m,2h,1w           ATOMUSDT           NaN       NaN
#                     CAKEUSDT           NaN       NaN
# 30m,8h,1d,1w        ANTUSDT            NaN       NaN
# 3d,1w               AVAXUSDT         1h,2h        3d
#                     CELRUSDT           NaN       NaN
#                     DENTUSDT           NaN       NaN
#                     DOTUSDT            NaN       NaN
#                     FTMUSDT            NaN       NaN
#                     LRCUSDT            NaN       NaN
#                     MATICUSDT  1h,2h,4h,8h       NaN
#                     NEARUSDT           NaN       NaN
#                     ONTUSDT            NaN       NaN
#                     ROSEUSDT           NaN        3d
#                     SCUSDT             NaN       NaN
#                     ZILUSDT            NaN       NaN
# 5m,15m,30m          PAXGUSDT           NaN       NaN
# 5m,15m,30m,1d,3d,1w VTHOUSDT           NaN       NaN
# 5m,15m,30m,1h,2h    CTSIUSDT           NaN       NaN
# 5m,15m,30m,1h,8h,1w TFUELUSDT          NaN        3d
# 5m,15m,30m,1w       STORJUSDT    4h,8h,12h       NaN
# 8h,1w               REEFUSDT           NaN       NaN
#                     THETAUSDT           1h       NaN
# 8h,3d,1w            MINAUSDT           NaN       NaN
#                     RENUSDT            NaN       NaN
#
#                                                       stover  \
# buyzones            Indicator
#                     CRVUSDT               5m,8h,12h,1d,3d,1w
#                     MIRUSDT                  5m,4h,12h,1d,3d
#                     PERPUSDT                    15m,1d,3d,1w
#                     RAYUSDT               5m,4h,8h,12h,3d,1w
# 1d                  GLMRUSDT           5m,4h,8h,12h,1d,3d,1w
# 1d,3d,1w            BANDUSDT             5m,30m,4h,12h,1d,3d
#                     COTIUSDT          5m,15m,4h,8h,12h,1d,1w
#                     OMGUSDT            5m,4h,8h,12h,1d,3d,1w
#                     VETUSDT            5m,4h,8h,12h,1d,3d,1w
#                     WINUSDT               5m,4h,8h,12h,1d,3d
# 1h,1d,3d,1w         XTZUSDT                  4h,8h,12h,1d,3d
# 1w                  AUDIOUSDT          5m,4h,8h,12h,1d,3d,1w
#                     BTCUSDT                  4h,8h,12h,1d,3d
#                     RUNEUSDT                 8h,12h,1d,3d,1w
#                     SOLUSDT           5m,30m,4h,8h,12h,3d,1w
#                     SUSHIUSDT         5m,15m,4h,12h,1d,3d,1w
# 2h,1d,3d,1w         GALAUSDT           5m,4h,8h,12h,1d,3d,1w
# 2h,1w               GRTUSDT               5m,4h,8h,12h,1d,3d
# 2h,3d,1w            KSMUSDT            5m,4h,8h,12h,1d,3d,1w
#                     MANAUSDT          5m,15m,4h,8h,12h,1d,1w
# 2h,8h,1d,3d,1w      ADAUSDT           5m,15m,4h,8h,12h,1d,3d
# 2h,8h,3d,1w         LINKUSDT              5m,4h,12h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT                4h,8h,12h,1d,3d,1w
# 30m,2h,1w           ATOMUSDT             5m,30m,8h,12h,3d,1w
#                     CAKEUSDT                 5m,8h,12h,1d,3d
# 30m,8h,1d,1w        ANTUSDT        5m,15m,2h,4h,12h,1d,3d,1w
# 3d,1w               AVAXUSDT           5m,4h,8h,12h,1d,3d,1w
#                     CELRUSDT           5m,4h,8h,12h,1d,3d,1w
#                     DENTUSDT          5m,15m,4h,8h,12h,1d,3d
#                     DOTUSDT               5m,4h,8h,12h,1d,1w
#                     FTMUSDT                  4h,12h,1d,3d,1w
#                     LRCUSDT            5m,4h,8h,12h,1d,3d,1w
#                     MATICUSDT                4h,12h,1d,3d,1w
#                     NEARUSDT           5m,4h,8h,12h,1d,3d,1w
#                     ONTUSDT               5m,4h,8h,12h,1d,3d
#                     ROSEUSDT           5m,4h,8h,12h,1d,3d,1w
#                     SCUSDT             5m,4h,8h,12h,1d,3d,1w
#                     ZILUSDT                  4h,8h,12h,1d,3d
# 5m,15m,30m          PAXGUSDT                    5m,30m,1h,2h
# 5m,15m,30m,1d,3d,1w VTHOUSDT           5m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT                 5m,4h,8h,12h,1d
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,4h,8h,12h,3d,1w
# 5m,15m,30m,1w       STORJUSDT             5m,4h,8h,12h,3d,1w
# 8h,1w               REEFUSDT           5m,2h,4h,8h,12h,1d,3d
#                     THETAUSDT  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT           1h,4h,8h,12h,1d,3d,1w
#                     RENUSDT            5m,4h,8h,12h,1d,3d,1w
#
#                                                               room  \
# buyzones            Indicator
#                     CRVUSDT                 5m,15m,30m,1h,2h,3d,1w
#                     MIRUSDT           5m,15m,30m,1h,2h,4h,8h,3d,1w
#                     PERPUSDT             5m,15m,30m,1h,2h,4h,3d,1w
#                     RAYUSDT                 5m,15m,30m,1h,2h,3d,1w
# 1d                  GLMRUSDT             5m,15m,30m,1h,2h,1d,3d,1w
# 1d,3d,1w            BANDUSDT             5m,15m,30m,1h,8h,1d,3d,1w
#                     COTIUSDT                5m,15m,30m,1h,1d,3d,1w
#                     OMGUSDT                 5m,15m,30m,1h,1d,3d,1w
#                     VETUSDT                 5m,15m,30m,1h,1d,3d,1w
#                     WINUSDT                 5m,15m,30m,1h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT                 5m,15m,30m,1h,1d,3d,1w
# 1w                  AUDIOUSDT                  5m,15m,30m,1h,4h,1w
#                     BTCUSDT              5m,15m,30m,1h,2h,1d,3d,1w
#                     RUNEUSDT                5m,15m,30m,1h,2h,3d,1w
#                     SOLUSDT                    5m,15m,30m,1h,2h,1w
#                     SUSHIUSDT         5m,15m,30m,1h,2h,4h,8h,3d,1w
# 2h,1d,3d,1w         GALAUSDT             5m,15m,30m,1h,2h,1d,3d,1w
# 2h,1w               GRTUSDT           5m,15m,30m,1h,2h,4h,8h,3d,1w
# 2h,3d,1w            KSMUSDT              5m,15m,30m,1h,2h,8h,3d,1w
#                     MANAUSDT                5m,15m,30m,1h,2h,3d,1w
# 2h,8h,1d,3d,1w      ADAUSDT       5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 2h,8h,3d,1w         LINKUSDT          5m,15m,30m,1h,2h,8h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT                  5m,15m,30m,1h,8h,3d,1w
# 30m,2h,1w           ATOMUSDT                   5m,15m,30m,1h,2h,1w
#                     CAKEUSDT                5m,15m,30m,1h,2h,3d,1w
# 30m,8h,1d,1w        ANTUSDT                    5m,15m,30m,8h,1d,1w
# 3d,1w               AVAXUSDT                      5m,15m,30m,3d,1w
#                     CELRUSDT                   5m,15m,30m,1h,3d,1w
#                     DENTUSDT                   5m,15m,30m,1h,3d,1w
#                     DOTUSDT              5m,15m,30m,1h,2h,8h,3d,1w
#                     FTMUSDT              5m,15m,30m,1h,4h,8h,3d,1w
#                     LRCUSDT                 5m,15m,30m,1h,2h,3d,1w
#                     MATICUSDT                  5m,15m,30m,1h,3d,1w
#                     NEARUSDT                   5m,15m,30m,1h,3d,1w
#                     ONTUSDT                 5m,15m,30m,1h,2h,3d,1w
#                     ROSEUSDT             5m,15m,30m,1h,2h,4h,3d,1w
#                     SCUSDT                  5m,15m,30m,1h,2h,3d,1w
#                     ZILUSDT              5m,15m,30m,1h,2h,4h,3d,1w
# 5m,15m,30m          PAXGUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT                   5m,15m,30m,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT             5m,15m,30m,1h,2h,1d,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                  5m,15m,30m,1h,8h,1w
# 5m,15m,30m,1w       STORJUSDT               5m,15m,30m,1h,2h,8h,1w
# 8h,1w               REEFUSDT                   5m,15m,30m,1h,8h,1w
#                     THETAUSDT                     5m,15m,30m,8h,1w
# 8h,3d,1w            MINAUSDT                   5m,15m,30m,8h,3d,1w
#                     RENUSDT                    5m,15m,30m,8h,3d,1w
#
#                                                              roomr  \
# buyzones            Indicator
#                     CRVUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1d                  GLMRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1d,3d,1w            BANDUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     COTIUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     OMGUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     VETUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     WINUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1w                  AUDIOUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     RUNEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     SUSHIUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,1d,3d,1w         GALAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,1w               GRTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,3d,1w            KSMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     MANAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,8h,1d,3d,1w      ADAUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,8h,3d,1w         LINKUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,2h,1w           ATOMUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     CAKEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,8h,1d,1w        ANTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3d,1w               AVAXUSDT         5m,15m,30m,4h,8h,12h,1d,3d,1w
#                     CELRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     DENTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     DOTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     FTMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     LRCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     MATICUSDT              5m,15m,30m,12h,1d,3d,1w
#                     NEARUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     ONTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     ROSEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     SCUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     ZILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m          PAXGUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w       STORJUSDT            5m,15m,30m,1h,2h,1d,3d,1w
# 8h,1w               REEFUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     THETAUSDT     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     RENUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                               stunder  \
# buyzones            Indicator
#                     CRVUSDT          15m,30m,1h,2h,4h
#                     MIRUSDT       15m,30m,1h,2h,8h,1w
#                     PERPUSDT   5m,30m,1h,2h,4h,8h,12h
#                     RAYUSDT          15m,30m,1h,2h,1d
# 1d                  GLMRUSDT            15m,30m,1h,2h
# 1d,3d,1w            BANDUSDT          15m,1h,2h,8h,1w
#                     COTIUSDT             30m,1h,2h,3d
#                     OMGUSDT             15m,30m,1h,2h
#                     VETUSDT             15m,30m,1h,2h
#                     WINUSDT          15m,30m,1h,2h,1w
# 1h,1d,3d,1w         XTZUSDT       5m,15m,30m,1h,2h,1w
# 1w                  AUDIOUSDT           15m,30m,1h,2h
#                     BTCUSDT       5m,15m,30m,1h,2h,1w
#                     RUNEUSDT      5m,15m,30m,1h,2h,4h
#                     SOLUSDT              15m,1h,2h,1d
#                     SUSHIUSDT            30m,1h,2h,8h
# 2h,1d,3d,1w         GALAUSDT            15m,30m,1h,2h
# 2h,1w               GRTUSDT          15m,30m,1h,2h,1w
# 2h,3d,1w            KSMUSDT             15m,30m,1h,2h
#                     MANAUSDT             30m,1h,2h,3d
# 2h,8h,1d,3d,1w      ADAUSDT              30m,1h,2h,1w
# 2h,8h,3d,1w         LINKUSDT         15m,30m,1h,2h,8h
# 30m,1h,3d,1w        ARUSDT           5m,15m,30m,1h,2h
# 30m,2h,1w           ATOMUSDT          15m,1h,2h,4h,1d
#                     CAKEUSDT      15m,30m,1h,2h,4h,1w
# 30m,8h,1d,1w        ANTUSDT                 30m,1h,8h
# 3d,1w               AVAXUSDT            15m,30m,1h,2h
#                     CELRUSDT            15m,30m,1h,2h
#                     DENTUSDT             30m,1h,2h,1w
#                     DOTUSDT          15m,30m,1h,2h,3d
#                     FTMUSDT       5m,15m,30m,1h,2h,8h
#                     LRCUSDT             15m,30m,1h,2h
#                     MATICUSDT     5m,15m,30m,1h,2h,8h
#                     NEARUSDT            15m,30m,1h,2h
#                     ONTUSDT          15m,30m,1h,2h,1w
#                     ROSEUSDT            15m,30m,1h,2h
#                     SCUSDT              15m,30m,1h,2h
#                     ZILUSDT       5m,15m,30m,1h,2h,1w
# 5m,15m,30m          PAXGUSDT   15m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT            15m,30m,1h,2h
# 5m,15m,30m,1h,2h    CTSIUSDT      15m,30m,1h,2h,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                   2h,1d
# 5m,15m,30m,1w       STORJUSDT        15m,30m,1h,2h,1d
# 8h,1w               REEFUSDT            15m,30m,1h,1w
#                     THETAUSDT                   1h,2h
# 8h,3d,1w            MINAUSDT            5m,15m,30m,2h
#                     RENUSDT             15m,30m,1h,2h
#
#                                                        stkup  \
# buyzones            Indicator
#                     CRVUSDT                     12h,1d,3d,1w
#                     MIRUSDT                        12h,1d,3d
#                     PERPUSDT                    15m,1d,3d,1w
#                     RAYUSDT           5m,15m,4h,8h,12h,3d,1w
# 1d                  GLMRUSDT       5m,15m,4h,8h,12h,1d,3d,1w
# 1d,3d,1w            BANDUSDT                5m,15m,4h,12h,1d
#                     COTIUSDT       5m,15m,4h,8h,12h,1d,3d,1w
#                     OMGUSDT               4h,8h,12h,1d,3d,1w
#                     VETUSDT           15m,4h,8h,12h,1d,3d,1w
#                     WINUSDT        5m,15m,4h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT           15m,4h,8h,12h,1d,3d,1w
# 1w                  AUDIOUSDT         15m,4h,8h,12h,1d,3d,1w
#                     BTCUSDT                 15m,8h,12h,1d,3d
#                     RUNEUSDT                    12h,1d,3d,1w
#                     SOLUSDT                     8h,12h,3d,1w
#                     SUSHIUSDT               15m,4h,12h,3d,1w
# 2h,1d,3d,1w         GALAUSDT             15m,4h,8h,12h,1d,1w
# 2h,1w               GRTUSDT              5m,15m,4h,12h,1d,3d
# 2h,3d,1w            KSMUSDT           5m,15m,4h,8h,12h,3d,1w
#                     MANAUSDT          5m,15m,4h,8h,12h,1d,1w
# 2h,8h,1d,3d,1w      ADAUSDT                 15m,4h,8h,12h,1d
# 2h,8h,3d,1w         LINKUSDT             15m,4h,12h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT            15m,4h,8h,12h,1d,3d,1w
# 30m,2h,1w           ATOMUSDT                    5m,30m,3d,1w
#                     CAKEUSDT                15m,8h,12h,1d,3d
# 30m,8h,1d,1w        ANTUSDT        5m,15m,1h,2h,4h,12h,1d,1w
# 3d,1w               AVAXUSDT              4h,8h,12h,1d,3d,1w
#                     CELRUSDT          5m,15m,4h,8h,12h,3d,1w
#                     DENTUSDT             15m,4h,8h,12h,1d,3d
#                     DOTUSDT              15m,4h,8h,12h,1d,1w
#                     FTMUSDT                 15m,4h,12h,3d,1w
#                     LRCUSDT               4h,8h,12h,1d,3d,1w
#                     MATICUSDT                   15m,1d,3d,1w
#                     NEARUSDT          15m,4h,8h,12h,1d,3d,1w
#                     ONTUSDT                  4h,8h,12h,1d,3d
#                     ROSEUSDT             15m,4h,8h,12h,3d,1w
#                     SCUSDT             5m,4h,8h,12h,1d,3d,1w
#                     ZILUSDT                     4h,8h,12h,3d
# 5m,15m,30m          PAXGUSDT                    5m,30m,1h,2h
# 5m,15m,30m,1d,3d,1w VTHOUSDT           5m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT             5m,15m,8h,12h,1d,3d
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,4h,8h,12h,3d,1w
# 5m,15m,30m,1w       STORJUSDT             5m,4h,8h,12h,3d,1w
# 8h,1w               REEFUSDT                    4h,8h,12h,1d
#                     THETAUSDT  15m,30m,1h,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT           1h,4h,8h,12h,1d,3d,1w
#                     RENUSDT        15m,1h,4h,8h,12h,1d,3d,1w
#
#                                                  stkdown  \
# buyzones            Indicator
#                     CRVUSDT           5m,30m,1h,2h,4h,8h
#                     MIRUSDT    5m,15m,30m,1h,2h,4h,8h,1w
#                     PERPUSDT      5m,30m,1h,2h,4h,8h,12h
#                     RAYUSDT                 30m,1h,2h,1d
# 1d                  GLMRUSDT                   30m,1h,2h
# 1d,3d,1w            BANDUSDT          30m,1h,2h,8h,3d,1w
#                     COTIUSDT                   30m,1h,2h
#                     OMGUSDT                 5m,30m,1h,2h
#                     VETUSDT                 5m,30m,1h,2h
#                     WINUSDT                    30m,1h,2h
# 1h,1d,3d,1w         XTZUSDT                 5m,30m,1h,2h
# 1w                  AUDIOUSDT               5m,30m,1h,2h
#                     BTCUSDT           5m,30m,1h,2h,4h,1w
#                     RUNEUSDT              5m,1h,2h,4h,8h
#                     SOLUSDT               5m,1h,2h,4h,1d
#                     SUSHIUSDT         5m,30m,1h,2h,8h,1d
# 2h,1d,3d,1w         GALAUSDT             5m,30m,1h,2h,3d
# 2h,1w               GRTUSDT              30m,1h,2h,8h,1w
# 2h,3d,1w            KSMUSDT                    30m,1h,2h
#                     MANAUSDT                30m,1h,2h,3d
# 2h,8h,1d,3d,1w      ADAUSDT           5m,30m,1h,2h,3d,1w
# 2h,8h,3d,1w         LINKUSDT             5m,30m,1h,2h,8h
# 30m,1h,3d,1w        ARUSDT                  5m,30m,1h,2h
# 30m,2h,1w           ATOMUSDT                    1h,2h,4h
#                     CAKEUSDT          5m,30m,1h,2h,4h,1w
# 30m,8h,1d,1w        ANTUSDT                    30m,8h,3d
# 3d,1w               AVAXUSDT                5m,30m,1h,2h
#                     CELRUSDT                   30m,1h,2h
#                     DENTUSDT             5m,30m,1h,2h,1w
#                     DOTUSDT              5m,30m,1h,2h,3d
#                     FTMUSDT              5m,30m,1h,2h,8h
#                     LRCUSDT             5m,15m,30m,1h,2h
#                     MATICUSDT               5m,30m,1h,2h
#                     NEARUSDT                5m,30m,1h,2h
#                     ONTUSDT              5m,30m,1h,2h,1w
#                     ROSEUSDT                5m,30m,1h,2h
#                     SCUSDT                 15m,30m,1h,2h
#                     ZILUSDT              5m,30m,1h,2h,1w
# 5m,15m,30m          PAXGUSDT      15m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT               15m,30m,1h,2h
# 5m,15m,30m,1h,2h    CTSIUSDT             30m,1h,2h,4h,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                        NaN
# 5m,15m,30m,1w       STORJUSDT           15m,30m,1h,2h,1d
# 8h,1w               REEFUSDT            5m,15m,30m,1h,1w
#                     THETAUSDT                         5m
# 8h,3d,1w            MINAUSDT               5m,15m,30m,2h
#                     RENUSDT                       5m,30m
#
#                                                      uptrend  \
# buyzones            Indicator
#                     CRVUSDT                               1w
#                     MIRUSDT                              NaN
#                     PERPUSDT                              1w
#                     RAYUSDT                               1w
# 1d                  GLMRUSDT                       8h,12h,1d
# 1d,3d,1w            BANDUSDT                              1d
#                     COTIUSDT                    8h,12h,1d,1w
#                     OMGUSDT                  8h,12h,1d,3d,1w
#                     VETUSDT                  8h,12h,1d,3d,1w
#                     WINUSDT                     8h,12h,1d,3d
# 1h,1d,3d,1w         XTZUSDT                     8h,12h,1d,3d
# 1w                  AUDIOUSDT                8h,12h,1d,3d,1w
#                     BTCUSDT                               3d
#                     RUNEUSDT                           3d,1w
#                     SOLUSDT                            3d,1w
#                     SUSHIUSDT                          3d,1w
# 2h,1d,3d,1w         GALAUSDT                    8h,12h,1d,1w
# 2h,1w               GRTUSDT                               3d
# 2h,3d,1w            KSMUSDT                     8h,12h,3d,1w
#                     MANAUSDT                    8h,12h,1d,1w
# 2h,8h,1d,3d,1w      ADAUSDT                        8h,12h,1d
# 2h,8h,3d,1w         LINKUSDT                    12h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT                   8h,12h,1d,3d,1w
# 30m,2h,1w           ATOMUSDT                       30m,3d,1w
#                     CAKEUSDT                           8h,3d
# 30m,8h,1d,1w        ANTUSDT                  2h,4h,12h,1d,1w
# 3d,1w               AVAXUSDT                 8h,12h,1d,3d,1w
#                     CELRUSDT                    8h,12h,3d,1w
#                     DENTUSDT                    8h,12h,1d,3d
#                     DOTUSDT                     8h,12h,1d,1w
#                     FTMUSDT                        12h,3d,1w
#                     LRCUSDT                  8h,12h,1d,3d,1w
#                     MATICUSDT                       1d,3d,1w
#                     NEARUSDT                 8h,12h,1d,3d,1w
#                     ONTUSDT                     8h,12h,1d,3d
#                     ROSEUSDT                    8h,12h,3d,1w
#                     SCUSDT                   8h,12h,1d,3d,1w
#                     ZILUSDT                        8h,12h,3d
# 5m,15m,30m          PAXGUSDT                          5m,30m
# 5m,15m,30m,1d,3d,1w VTHOUSDT              5m,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT                              5m
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,4h,8h,12h,3d,1w
# 5m,15m,30m,1w       STORJUSDT                       5m,3d,1w
# 8h,1w               REEFUSDT                       8h,12h,1d
#                     THETAUSDT             4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT              4h,8h,12h,1d,3d,1w
#                     RENUSDT               4h,8h,12h,1d,3d,1w
#
#                                          dshift               downtrend  \
# buyzones            Indicator
#                     CRVUSDT     5m,8h,12h,1d,3d            30m,1h,2h,4h
#                     MIRUSDT     5m,4h,12h,1d,3d         15m,1h,2h,8h,1w
#                     PERPUSDT          15m,1d,3d  5m,30m,1h,2h,4h,8h,12h
#                     RAYUSDT     5m,4h,8h,12h,3d                      1d
# 1d                  GLMRUSDT        5m,4h,3d,1w               30m,1h,2h
# 1d,3d,1w            BANDUSDT       5m,30m,4h,3d                   1h,2h
#                     COTIUSDT          5m,15m,4h                     30m
#                     OMGUSDT               5m,4h               30m,1h,2h
#                     VETUSDT               5m,4h                     30m
#                     WINUSDT               5m,4h                     30m
# 1h,1d,3d,1w         XTZUSDT                  4h                      5m
# 1w                  AUDIOUSDT             5m,4h               30m,1h,2h
#                     BTCUSDT        4h,8h,12h,1d            5m,30m,1h,2h
#                     RUNEUSDT          8h,12h,1d             5m,1h,2h,4h
#                     SOLUSDT    5m,30m,4h,8h,12h                1h,2h,1d
#                     SUSHIUSDT  5m,15m,4h,12h,1d            30m,1h,2h,8h
# 2h,1d,3d,1w         GALAUSDT           5m,4h,3d                     30m
# 2h,1w               GRTUSDT     5m,4h,8h,12h,1d                     30m
# 2h,3d,1w            KSMUSDT               5m,4h                     30m
#                     MANAUSDT          5m,15m,4h                     30m
# 2h,8h,1d,3d,1w      ADAUSDT        5m,15m,4h,3d                     30m
# 2h,8h,3d,1w         LINKUSDT              5m,4h                     30m
# 30m,1h,3d,1w        ARUSDT                   4h                      5m
# 30m,2h,1w           ATOMUSDT                 5m                      4h
#                     CAKEUSDT          5m,12h,1d                      4h
# 30m,8h,1d,1w        ANTUSDT               5m,3d                     NaN
# 3d,1w               AVAXUSDT              5m,4h               30m,1h,2h
#                     CELRUSDT              5m,4h                     30m
#                     DENTUSDT          5m,15m,4h                     30m
#                     DOTUSDT               5m,4h                     NaN
#                     FTMUSDT                  4h            5m,30m,1h,2h
#                     LRCUSDT               5m,4h           15m,30m,1h,2h
#                     MATICUSDT               NaN                  5m,30m
#                     NEARUSDT              5m,4h                     30m
#                     ONTUSDT               5m,4h               30m,1h,2h
#                     ROSEUSDT              5m,4h               30m,1h,2h
#                     SCUSDT                5m,4h              15m,30m,1h
#                     ZILUSDT                  4h            5m,30m,1h,2h
# 5m,15m,30m          PAXGUSDT              1h,2h      4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT                NaN                   1h,2h
# 5m,15m,30m,1h,2h    CTSIUSDT       4h,8h,12h,1d                     NaN
# 5m,15m,30m,1h,8h,1w TFUELUSDT               NaN                     NaN
# 5m,15m,30m,1w       STORJUSDT         4h,8h,12h                1h,2h,1d
# 8h,1w               REEFUSDT                 5m                 15m,30m
#                     THETAUSDT        5m,15m,30m                     NaN
# 8h,3d,1w            MINAUSDT                 1h           5m,15m,30m,2h
#                     RENUSDT                  5m                     NaN
#
#                                              shift
# buyzones            Indicator
#                     CRVUSDT                    NaN
#                     MIRUSDT                    30m
#                     PERPUSDT                   NaN
#                     RAYUSDT                    15m
# 1d                  GLMRUSDT                   15m
# 1d,3d,1w            BANDUSDT             15m,8h,1w
#                     COTIUSDT              1h,2h,3d
#                     OMGUSDT                    NaN
#                     VETUSDT              15m,1h,2h
#                     WINUSDT              15m,1h,1w
# 1h,1d,3d,1w         XTZUSDT       15m,30m,1h,2h,1w
# 1w                  AUDIOUSDT                  15m
#                     BTCUSDT                 15m,1w
#                     RUNEUSDT                   NaN
#                     SOLUSDT                    NaN
#                     SUSHIUSDT                  NaN
# 2h,1d,3d,1w         GALAUSDT             15m,1h,2h
# 2h,1w               GRTUSDT              15m,2h,1w
# 2h,3d,1w            KSMUSDT                 15m,2h
#                     MANAUSDT              1h,2h,3d
# 2h,8h,1d,3d,1w      ADAUSDT               1h,2h,1w
# 2h,8h,3d,1w         LINKUSDT          15m,1h,2h,8h
# 30m,1h,3d,1w        ARUSDT           15m,30m,1h,2h
# 30m,2h,1w           ATOMUSDT                 2h,1d
#                     CAKEUSDT         15m,30m,2h,1w
# 30m,8h,1d,1w        ANTUSDT              30m,1h,8h
# 3d,1w               AVAXUSDT                   NaN
#                     CELRUSDT             15m,1h,2h
#                     DENTUSDT              1h,2h,1w
#                     DOTUSDT                 15m,3d
#                     FTMUSDT                 15m,8h
#                     LRCUSDT                    NaN
#                     MATICUSDT         15m,1h,2h,8h
#                     NEARUSDT             15m,1h,2h
#                     ONTUSDT                     1w
#                     ROSEUSDT                   15m
#                     SCUSDT                     NaN
#                     ZILUSDT                     1w
# 5m,15m,30m          PAXGUSDT                   15m
# 5m,15m,30m,1d,3d,1w VTHOUSDT               15m,30m
# 5m,15m,30m,1h,2h    CTSIUSDT   15m,30m,1h,2h,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                2h,1d
# 5m,15m,30m,1w       STORJUSDT              15m,30m
# 8h,1w               REEFUSDT                    1w
#                     THETAUSDT                1h,2h
# 8h,3d,1w            MINAUSDT                   NaN
#                     RENUSDT                 15m,1h

# %%
# Indicators for the week shift

newframe=callfun(wshift,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])

newframe=buyzonesa(newframe)
newframe
pivotf = newframe.pivot(index='buyzones',columns='Indicator')
pivotf.stack()
# Out:
#                            stkcross                             rsiup  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT       NaN                       8h,1d,3d,1w
#                  WINUSDT         3d                1h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w      XTZUSDT         3d         30m,1h,2h,8h,12h,1d,3d,1w
# 1w               BTCUSDT         3d                             3d,1w
# 2h,1w            GRTUSDT        NaN                          2h,3d,1w
#                  ZRXUSDT        NaN                          1h,2h,1w
# 2h,3d            WAXPUSDT       NaN                       1h,2h,3d,1w
# 2h,8h,1d,3d,1w   ADAUSDT     15m,3d             1h,2h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w     MOVRUSDT       NaN  15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,3d     IOTXUSDT       NaN               15m,30m,1h,2h,3d,1w
# 30m,1w           XLMUSDT     15m,3d  15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,2h,1w        CAKEUSDT       NaN                   30m,2h,8h,3d,1w
# 3d,1w            DENTUSDT       15m             1h,2h,8h,12h,1d,3d,1w
#                  ONTUSDT        NaN                   8h,12h,1d,3d,1w
#                  ZILUSDT        12h                   8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h CTSIUSDT       NaN               5m,15m,30m,1h,2h,1w
# 8h,1w            REEFUSDT       NaN                   8h,12h,1d,3d,1w
#
#                                                   rsidown                tops  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT                 5m,30m,1h,2h,4h           2h,4h,12h
#                  WINUSDT                    5m,15m,30m,4h        2h,4h,8h,12h
# 1h,1d,3d,1w      XTZUSDT                        5m,15m,4h        2h,4h,8h,12h
# 1w               BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d           4h,8h,12h
# 2h,1w            GRTUSDT          5m,15m,30m,4h,8h,12h,1d              12h,1d
#                  ZRXUSDT       5m,15m,30m,4h,8h,12h,1d,3d        4h,8h,12h,1d
# 2h,3d            WAXPUSDT         5m,15m,30m,4h,8h,12h,1d        4h,8h,12h,1d
# 2h,8h,1d,3d,1w   ADAUSDT                    5m,15m,30m,4h                  4h
# 30m,1d,3d,1w     MOVRUSDT                              5m     1h,2h,4h,8h,12h
# 30m,1h,2h,3d     IOTXUSDT                 5m,4h,8h,12h,1d        4h,8h,12h,1d
# 30m,1w           XLMUSDT                               5m  1h,2h,4h,8h,12h,1d
# 30m,2h,1w        CAKEUSDT                    5m,4h,12h,1d        4h,8h,12h,1d
# 3d,1w            DENTUSDT                   5m,15m,30m,4h     2h,4h,8h,12h,1d
#                  ONTUSDT                  5m,30m,1h,2h,4h        4h,8h,12h,1d
#                  ZILUSDT              5m,15m,30m,1h,2h,4h           8h,12h,1d
# 5m,15m,30m,1h,2h CTSIUSDT                 4h,8h,12h,1d,3d           4h,8h,12h
# 8h,1w            REEFUSDT                      5m,15m,30m     2h,4h,12h,1d,3d
#
#                                      bottoms topr   bottomr  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT                 1w  NaN       NaN
#                  WINUSDT          15m,30m,1w  NaN        3d
# 1h,1d,3d,1w      XTZUSDT       5m,15m,30m,1w  NaN       NaN
# 1w               BTCUSDT          15m,30m,1w  NaN     3d,1w
# 2h,1w            GRTUSDT          15m,30m,1w  NaN       NaN
#                  ZRXUSDT          15m,30m,1w  NaN       NaN
# 2h,3d            WAXPUSDT         15m,30m,1w  NaN       NaN
# 2h,8h,1d,3d,1w   ADAUSDT          15m,30m,1w  NaN       NaN
# 30m,1d,3d,1w     MOVRUSDT          5m,15m,3d  NaN  1d,3d,1w
# 30m,1h,2h,3d     IOTXUSDT      15m,30m,1h,1w  NaN       NaN
# 30m,1w           XLMUSDT              30m,1w   1h       NaN
# 30m,2h,1w        CAKEUSDT         15m,30m,1w  NaN       NaN
# 3d,1w            DENTUSDT             30m,1w  NaN       NaN
#                  ONTUSDT          15m,30m,1w  NaN       NaN
#                  ZILUSDT       5m,15m,30m,1w  NaN       NaN
# 5m,15m,30m,1h,2h CTSIUSDT   5m,15m,30m,1h,1w  NaN       NaN
# 8h,1w            REEFUSDT         15m,30m,1w  NaN       NaN
#
#                                             stover  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT      5m,30m,4h,12h,1d,3d
#                  WINUSDT        5m,4h,8h,12h,1d,3d
# 1h,1d,3d,1w      XTZUSDT           4h,8h,12h,1d,3d
# 1w               BTCUSDT           4h,8h,12h,1d,3d
# 2h,1w            GRTUSDT        5m,4h,8h,12h,1d,3d
#                  ZRXUSDT        5m,4h,8h,12h,1d,3d
# 2h,3d            WAXPUSDT          4h,8h,12h,1d,3d
# 2h,8h,1d,3d,1w   ADAUSDT    5m,15m,4h,8h,12h,1d,3d
# 30m,1d,3d,1w     MOVRUSDT          2h,4h,8h,12h,1d
# 30m,1h,2h,3d     IOTXUSDT          5m,8h,12h,1d,3d
# 30m,1w           XLMUSDT       15m,4h,8h,12h,1d,3d
# 30m,2h,1w        CAKEUSDT          5m,8h,12h,1d,3d
# 3d,1w            DENTUSDT   5m,15m,4h,8h,12h,1d,3d
#                  ONTUSDT        5m,4h,8h,12h,1d,3d
#                  ZILUSDT           4h,8h,12h,1d,3d
# 5m,15m,30m,1h,2h CTSIUSDT          5m,4h,8h,12h,1d
# 8h,1w            REEFUSDT    5m,2h,4h,8h,12h,1d,3d
#
#                                                         room  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT          5m,15m,30m,1h,8h,1d,3d,1w
#                  WINUSDT              5m,15m,30m,1h,1d,3d,1w
# 1h,1d,3d,1w      XTZUSDT              5m,15m,30m,1h,1d,3d,1w
# 1w               BTCUSDT           5m,15m,30m,1h,2h,1d,3d,1w
# 2h,1w            GRTUSDT        5m,15m,30m,1h,2h,4h,8h,3d,1w
#                  ZRXUSDT              5m,15m,30m,1h,2h,3d,1w
# 2h,3d            WAXPUSDT             5m,15m,30m,1h,2h,3d,1w
# 2h,8h,1d,3d,1w   ADAUSDT    5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w     MOVRUSDT                5m,15m,30m,1d,3d,1w
# 30m,1h,2h,3d     IOTXUSDT             5m,15m,30m,1h,2h,3d,1w
# 30m,1w           XLMUSDT                    5m,15m,30m,3d,1w
# 30m,2h,1w        CAKEUSDT             5m,15m,30m,1h,2h,3d,1w
# 3d,1w            DENTUSDT                5m,15m,30m,1h,3d,1w
#                  ONTUSDT              5m,15m,30m,1h,2h,3d,1w
#                  ZILUSDT           5m,15m,30m,1h,2h,4h,3d,1w
# 5m,15m,30m,1h,2h CTSIUSDT          5m,15m,30m,1h,2h,1d,3d,1w
# 8h,1w            REEFUSDT                5m,15m,30m,1h,8h,1w
#
#                                                           roomr  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                  WINUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w      XTZUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1w               BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,1w            GRTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                  ZRXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,3d            WAXPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,8h,1d,3d,1w   ADAUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w     MOVRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,3d     IOTXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1w           XLMUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 30m,2h,1w        CAKEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3d,1w            DENTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                  ONTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                  ZILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h CTSIUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8h,1w            REEFUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                         stunder                      stkup  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT       15m,1h,2h,8h,1w           5m,15m,4h,12h,1d
#                  WINUSDT       15m,30m,1h,2h,1w  5m,15m,4h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w      XTZUSDT    5m,15m,30m,1h,2h,1w     15m,4h,8h,12h,1d,3d,1w
# 1w               BTCUSDT    5m,15m,30m,1h,2h,1w           15m,8h,12h,1d,3d
# 2h,1w            GRTUSDT       15m,30m,1h,2h,1w        5m,15m,4h,12h,1d,3d
#                  ZRXUSDT       15m,30m,1h,2h,1w        15m,4h,8h,12h,1d,3d
# 2h,3d            WAXPUSDT   5m,15m,30m,1h,2h,1w           15m,4h,12h,1d,3d
# 2h,8h,1d,3d,1w   ADAUSDT           30m,1h,2h,1w           15m,4h,8h,12h,1d
# 30m,1d,3d,1w     MOVRUSDT   5m,15m,30m,1h,3d,1w        15m,2h,4h,8h,12h,1d
# 30m,1h,2h,3d     IOTXUSDT   15m,30m,1h,2h,4h,1w        5m,15m,1h,8h,12h,3d
# 30m,1w           XLMUSDT        5m,30m,1h,2h,1w     15m,1h,4h,8h,12h,1d,3d
# 30m,2h,1w        CAKEUSDT   15m,30m,1h,2h,4h,1w           15m,8h,12h,1d,3d
# 3d,1w            DENTUSDT          30m,1h,2h,1w        15m,4h,8h,12h,1d,3d
#                  ONTUSDT       15m,30m,1h,2h,1w            4h,8h,12h,1d,3d
#                  ZILUSDT    5m,15m,30m,1h,2h,1w               4h,8h,12h,3d
# 5m,15m,30m,1h,2h CTSIUSDT   15m,30m,1h,2h,3d,1w        5m,15m,8h,12h,1d,3d
# 8h,1w            REEFUSDT         15m,30m,1h,1w               4h,8h,12h,1d
#
#                                        stkdown              uptrend  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT   30m,1h,2h,8h,3d,1w                   1d
#                  WINUSDT             30m,1h,2h         8h,12h,1d,3d
# 1h,1d,3d,1w      XTZUSDT          5m,30m,1h,2h         8h,12h,1d,3d
# 1w               BTCUSDT    5m,30m,1h,2h,4h,1w                   3d
# 2h,1w            GRTUSDT       30m,1h,2h,8h,1w                   3d
#                  ZRXUSDT       5m,30m,1h,2h,1w                  NaN
# 2h,3d            WAXPUSDT   5m,30m,1h,2h,8h,1w                   3d
# 2h,8h,1d,3d,1w   ADAUSDT    5m,30m,1h,2h,3d,1w            8h,12h,1d
# 30m,1d,3d,1w     MOVRUSDT      5m,30m,1h,3d,1w      2h,4h,8h,12h,1d
# 30m,1h,2h,3d     IOTXUSDT      30m,2h,4h,1d,1w                   3d
# 30m,1w           XLMUSDT          5m,30m,2h,1w  15m,4h,8h,12h,1d,3d
# 30m,2h,1w        CAKEUSDT   5m,30m,1h,2h,4h,1w                8h,3d
# 3d,1w            DENTUSDT      5m,30m,1h,2h,1w         8h,12h,1d,3d
#                  ONTUSDT       5m,30m,1h,2h,1w         8h,12h,1d,3d
#                  ZILUSDT       5m,30m,1h,2h,1w            8h,12h,3d
# 5m,15m,30m,1h,2h CTSIUSDT      30m,1h,2h,4h,1w                   5m
# 8h,1w            REEFUSDT     5m,15m,30m,1h,1w            8h,12h,1d
#
#                                         dshift     downtrend  \
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT         5m,30m,4h,3d         1h,2h
#                  WINUSDT                 5m,4h           30m
# 1h,1d,3d,1w      XTZUSDT                    4h            5m
# 1w               BTCUSDT          4h,8h,12h,1d  5m,30m,1h,2h
# 2h,1w            GRTUSDT       5m,4h,8h,12h,1d           30m
#                  ZRXUSDT    5m,4h,8h,12h,1d,3d           30m
# 2h,3d            WAXPUSDT         4h,8h,12h,1d        5m,30m
# 2h,8h,1d,3d,1w   ADAUSDT          5m,15m,4h,3d           30m
# 30m,1d,3d,1w     MOVRUSDT                  NaN            5m
# 30m,1h,2h,3d     IOTXUSDT         5m,8h,12h,1d            4h
# 30m,1w           XLMUSDT                   NaN            5m
# 30m,2h,1w        CAKEUSDT            5m,12h,1d            4h
# 3d,1w            DENTUSDT            5m,15m,4h           30m
#                  ONTUSDT                 5m,4h     30m,1h,2h
#                  ZILUSDT                    4h  5m,30m,1h,2h
# 5m,15m,30m,1h,2h CTSIUSDT         4h,8h,12h,1d           NaN
# 8h,1w            REEFUSDT                   5m       15m,30m
#
#                                           shift
# buyzones         Indicator
# 1d,3d,1w         BANDUSDT             15m,8h,1w
#                  WINUSDT              15m,1h,1w
# 1h,1d,3d,1w      XTZUSDT       15m,30m,1h,2h,1w
# 1w               BTCUSDT                 15m,1w
# 2h,1w            GRTUSDT              15m,2h,1w
#                  ZRXUSDT           15m,1h,2h,1w
# 2h,3d            WAXPUSDT          15m,1h,2h,1w
# 2h,8h,1d,3d,1w   ADAUSDT               1h,2h,1w
# 30m,1d,3d,1w     MOVRUSDT      15m,30m,1h,3d,1w
# 30m,1h,2h,3d     IOTXUSDT      15m,30m,1h,2h,1w
# 30m,1w           XLMUSDT           30m,1h,2h,1w
# 30m,2h,1w        CAKEUSDT         15m,30m,2h,1w
# 3d,1w            DENTUSDT              1h,2h,1w
#                  ONTUSDT                     1w
#                  ZILUSDT                     1w
# 5m,15m,30m,1h,2h CTSIUSDT   15m,30m,1h,2h,3d,1w
# 8h,1w            REEFUSDT                    1w

# %%
# Indicators for the 1d down
newframe=callfun(macd1dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='1d'))]


test=buyzonesa(test)
test

#pivotf = test.pivot(index='buyzones',columns='Indicator',values='Indicator')
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                               stkcross                                rsiup  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT   15m,1h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3d,1w               ROSEUSDT        1w                      8h,12h,1d,3d,1w
# 30m,3d,1w           SCRTUSDT        1d              15m,30m,8h,12h,1d,3d,1w
# 30m,3d              SRMUSDT        15m                        15m,30m,3d,1w
# 30m,1h,3d,1w        ARUSDT          1w            30m,1h,2h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT       NaN     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1w                  BTCUSDT         3d                                3d,1w
# 1d,3d,1w            WINUSDT         3d                   1h,8h,12h,1d,3d,1w
# 1d                  GLMRUSDT     3d,1w                            8h,12h,1d
#                     RAYUSDT         1w                                   1w
#
#                                                      rsidown             tops  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT                            NaN  2h,4h,12h,1d,3d
# 3d,1w               ROSEUSDT             5m,15m,30m,1h,2h,4h        8h,12h,1d
# 30m,3d,1w           SCRTUSDT                     5m,1h,2h,4h  2h,4h,8h,12h,1d
# 30m,3d              SRMUSDT                  5m,4h,8h,12h,1d     4h,8h,12h,1d
# 30m,1h,3d,1w        ARUSDT                             5m,4h     2h,4h,12h,1d
# 30m,1d,3d,1w        MOVRUSDT                              5m  1h,2h,4h,8h,12h
# 1w                  BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d        4h,8h,12h
# 1d,3d,1w            WINUSDT                    5m,15m,30m,4h     2h,4h,8h,12h
# 1d                  GLMRUSDT       5m,15m,30m,1h,2h,4h,3d,1w        4h,8h,12h
#                     RAYUSDT           5m,15m,4h,8h,12h,1d,3d     4h,8h,12h,1d
#
#                                      bottoms topr   bottomr  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT             1w  NaN        3d
# 3d,1w               ROSEUSDT      15m,30m,1w  NaN        3d
# 30m,3d,1w           SCRTUSDT   15m,30m,3d,1w  NaN     3d,1w
# 30m,3d              SRMUSDT    15m,30m,3d,1w  NaN        3d
# 30m,1h,3d,1w        ARUSDT        15m,30m,1w  NaN        3d
# 30m,1d,3d,1w        MOVRUSDT       5m,15m,3d  NaN  1d,3d,1w
# 1w                  BTCUSDT       15m,30m,1w  NaN     3d,1w
# 1d,3d,1w            WINUSDT       15m,30m,1w  NaN        3d
# 1d                  GLMRUSDT   15m,30m,3d,1w  NaN     3d,1w
#                     RAYUSDT       15m,30m,1w  NaN        3d
#
#                                                       stover  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,4h,8h,12h,3d,1w
# 3d,1w               ROSEUSDT           5m,4h,8h,12h,1d,3d,1w
# 30m,3d,1w           SCRTUSDT           5m,4h,8h,12h,1d,3d,1w
# 30m,3d              SRMUSDT        5m,15m,4h,8h,12h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT                4h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT                 2h,4h,8h,12h,1d
# 1w                  BTCUSDT                  4h,8h,12h,1d,3d
# 1d,3d,1w            WINUSDT               5m,4h,8h,12h,1d,3d
# 1d                  GLMRUSDT           5m,4h,8h,12h,1d,3d,1w
#                     RAYUSDT               5m,4h,8h,12h,3d,1w
#
#                                                     room  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT        5m,15m,30m,1h,8h,1w
# 3d,1w               ROSEUSDT   5m,15m,30m,1h,2h,4h,3d,1w
# 30m,3d,1w           SCRTUSDT         5m,15m,30m,1h,3d,1w
# 30m,3d              SRMUSDT       5m,15m,30m,1h,2h,3d,1w
# 30m,1h,3d,1w        ARUSDT        5m,15m,30m,1h,8h,3d,1w
# 30m,1d,3d,1w        MOVRUSDT         5m,15m,30m,1d,3d,1w
# 1w                  BTCUSDT    5m,15m,30m,1h,2h,1d,3d,1w
# 1d,3d,1w            WINUSDT       5m,15m,30m,1h,1d,3d,1w
# 1d                  GLMRUSDT   5m,15m,30m,1h,2h,1d,3d,1w
#                     RAYUSDT       5m,15m,30m,1h,2h,3d,1w
#
#                                                              roomr  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3d,1w               ROSEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,3d,1w           SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,3d              SRMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,3d,1w        ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1w                  BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1d,3d,1w            WINUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1d                  GLMRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                            stunder  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT                2h,1d
# 3d,1w               ROSEUSDT         15m,30m,1h,2h
# 30m,3d,1w           SCRTUSDT         15m,30m,1h,2h
# 30m,3d              SRMUSDT              30m,1h,2h
# 30m,1h,3d,1w        ARUSDT        5m,15m,30m,1h,2h
# 30m,1d,3d,1w        MOVRUSDT   5m,15m,30m,1h,3d,1w
# 1w                  BTCUSDT    5m,15m,30m,1h,2h,1w
# 1d,3d,1w            WINUSDT       15m,30m,1h,2h,1w
# 1d                  GLMRUSDT         15m,30m,1h,2h
#                     RAYUSDT       15m,30m,1h,2h,1d
#
#                                                        stkup  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,4h,8h,12h,3d,1w
# 3d,1w               ROSEUSDT             15m,4h,8h,12h,3d,1w
# 30m,3d,1w           SCRTUSDT          5m,15m,4h,8h,12h,3d,1w
# 30m,3d              SRMUSDT           5m,15m,4h,8h,12h,3d,1w
# 30m,1h,3d,1w        ARUSDT            15m,4h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT             15m,2h,4h,8h,12h,1d
# 1w                  BTCUSDT                 15m,8h,12h,1d,3d
# 1d,3d,1w            WINUSDT        5m,15m,4h,8h,12h,1d,3d,1w
# 1d                  GLMRUSDT       5m,15m,4h,8h,12h,1d,3d,1w
#                     RAYUSDT           5m,15m,4h,8h,12h,3d,1w
#
#                                           stkdown  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT                 NaN
# 3d,1w               ROSEUSDT         5m,30m,1h,2h
# 30m,3d,1w           SCRTUSDT            30m,1h,2h
# 30m,3d              SRMUSDT          30m,1h,2h,1d
# 30m,1h,3d,1w        ARUSDT           5m,30m,1h,2h
# 30m,1d,3d,1w        MOVRUSDT      5m,30m,1h,3d,1w
# 1w                  BTCUSDT    5m,30m,1h,2h,4h,1w
# 1d,3d,1w            WINUSDT             30m,1h,2h
# 1d                  GLMRUSDT            30m,1h,2h
#                     RAYUSDT          30m,1h,2h,1d
#
#                                                      uptrend           dshift  \
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,4h,8h,12h,3d,1w              NaN
# 3d,1w               ROSEUSDT                    8h,12h,3d,1w            5m,4h
# 30m,3d,1w           SCRTUSDT                    8h,12h,3d,1w            5m,4h
# 30m,3d              SRMUSDT                        15m,3d,1w  5m,4h,8h,12h,1d
# 30m,1h,3d,1w        ARUSDT                   8h,12h,1d,3d,1w               4h
# 30m,1d,3d,1w        MOVRUSDT                 2h,4h,8h,12h,1d              NaN
# 1w                  BTCUSDT                               3d     4h,8h,12h,1d
# 1d,3d,1w            WINUSDT                     8h,12h,1d,3d            5m,4h
# 1d                  GLMRUSDT                       8h,12h,1d      5m,4h,3d,1w
#                     RAYUSDT                               1w  5m,4h,8h,12h,3d
#
#                                   downtrend             shift
# buyzones            Indicator
# 5m,15m,30m,1h,8h,1w TFUELUSDT           NaN             2h,1d
# 3d,1w               ROSEUSDT      30m,1h,2h               15m
# 30m,3d,1w           SCRTUSDT          1h,2h           15m,30m
# 30m,3d              SRMUSDT             NaN               30m
# 30m,1h,3d,1w        ARUSDT               5m     15m,30m,1h,2h
# 30m,1d,3d,1w        MOVRUSDT             5m  15m,30m,1h,3d,1w
# 1w                  BTCUSDT    5m,30m,1h,2h            15m,1w
# 1d,3d,1w            WINUSDT             30m         15m,1h,1w
# 1d                  GLMRUSDT      30m,1h,2h               15m
#                     RAYUSDT              1d               15m

# %%
## MACD 3d gap and rsi up
newframe=callfun(macd3dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['rsiup'] > newframe['rsidown']) ]

#test = newframe.loc[(newframe['rsiup'].notnull()) &  (newframe['rsidown'] >= "1w" )]



test=buyzonesa(test)
#test.dropna(subset=['stkcross'],inplace=True)
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                         stkcross                     rsiup  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT     1h,1w        4h,8h,12h,1d,3d,1w
#               RENUSDT     8h,12h        4h,8h,12h,1d,3d,1w
# 8h,1w         REEFUSDT       NaN           8h,12h,1d,3d,1w
#               THETAUSDT      NaN  1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w STORJUSDT       5m          5m,15m,30m,3d,1w
# ...                          ...                       ...
#               IMXUSDT        NaN                       NaN
#               LUNAUSDT       15m                       NaN
#               MIRUSDT        NaN                       30m
#               PERPUSDT        1w                        1w
#               RAYUSDT         1w                        1w
#
#                                                      rsidown  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT                      5m,15m,30m,1h,2h
#               RENUSDT                                 5m,15m
# 8h,1w         REEFUSDT                            5m,15m,30m
#               THETAUSDT                           5m,15m,30m
# 5m,15m,30m,1w STORJUSDT                   1h,2h,4h,8h,12h,1d
# ...                                                      ...
#               IMXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               LUNAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               MIRUSDT        5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
#               PERPUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#               RAYUSDT                 5m,15m,4h,8h,12h,1d,3d
#
#                                        tops           bottoms       topr  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT      1h,2h,4h,12h,1d         5m,15m,1w        NaN
#               RENUSDT       1h,2h,4h,12h,1d        15m,30m,1w        NaN
# 8h,1w         REEFUSDT      2h,4h,12h,1d,3d        15m,30m,1w        NaN
#               THETAUSDT  1h,2h,4h,12h,1d,3d                1w         1h
# 5m,15m,30m,1w STORJUSDT        4h,12h,1d,3d            5m,30m  4h,8h,12h
# ...                                     ...               ...        ...
#               IMXUSDT          4h,8h,12h,1d        5m,15m,30m        NaN
#               LUNAUSDT               8h,12h         30m,3d,1w        NaN
#               MIRUSDT                12h,1d     5m,15m,30m,1w        NaN
#               PERPUSDT            8h,12h,1d  5m,15m,30m,2h,1w        NaN
#               RAYUSDT          4h,8h,12h,1d        15m,30m,1w        NaN
#
#                            bottomr                         stover  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT         NaN          1h,4h,8h,12h,1d,3d,1w
#               RENUSDT          NaN          5m,4h,8h,12h,1d,3d,1w
# 8h,1w         REEFUSDT         NaN          5m,2h,4h,8h,12h,1d,3d
#               THETAUSDT        NaN  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w STORJUSDT        NaN             5m,4h,8h,12h,3d,1w
# ...                            ...                            ...
#               IMXUSDT          NaN          5m,4h,8h,12h,1d,3d,1w
#               LUNAUSDT   12h,1d,3d                  15m,4h,12h,3d
#               MIRUSDT        3d,1w                5m,4h,12h,1d,3d
#               PERPUSDT    5m,3d,1w                   15m,1d,3d,1w
#               RAYUSDT           3d             5m,4h,8h,12h,3d,1w
#
#                                                  room  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT            5m,15m,30m,8h,3d,1w
#               RENUSDT             5m,15m,30m,8h,3d,1w
# 8h,1w         REEFUSDT            5m,15m,30m,1h,8h,1w
#               THETAUSDT              5m,15m,30m,8h,1w
# 5m,15m,30m,1w STORJUSDT        5m,15m,30m,1h,2h,8h,1w
# ...                                               ...
#               IMXUSDT          5m,15m,30m,1h,2h,3d,1w
#               LUNAUSDT   5m,15m,30m,1h,2h,4h,1d,3d,1w
#               MIRUSDT    5m,15m,30m,1h,2h,4h,8h,3d,1w
#               PERPUSDT      5m,15m,30m,1h,2h,4h,3d,1w
#               RAYUSDT          5m,15m,30m,1h,2h,3d,1w
#
#                                                        roomr  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               RENUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8h,1w         REEFUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               THETAUSDT     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w STORJUSDT            5m,15m,30m,1h,2h,1d,3d,1w
# ...                                                      ...
#               IMXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               LUNAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#               RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                         stunder  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT            5m,15m,30m,2h
#               RENUSDT             15m,30m,1h,2h
# 8h,1w         REEFUSDT            15m,30m,1h,1w
#               THETAUSDT                   1h,2h
# 5m,15m,30m,1w STORJUSDT        15m,30m,1h,2h,1d
# ...                                         ...
#               IMXUSDT             15m,30m,1h,2h
#               LUNAUSDT    5m,30m,1h,2h,8h,1d,1w
#               MIRUSDT       15m,30m,1h,2h,8h,1w
#               PERPUSDT   5m,30m,1h,2h,4h,8h,12h
#               RAYUSDT          15m,30m,1h,2h,1d
#
#                                                  stkup  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT           1h,4h,8h,12h,1d,3d,1w
#               RENUSDT        15m,1h,4h,8h,12h,1d,3d,1w
# 8h,1w         REEFUSDT                    4h,8h,12h,1d
#               THETAUSDT  15m,30m,1h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w STORJUSDT             5m,4h,8h,12h,3d,1w
# ...                                                ...
#               IMXUSDT               4h,8h,12h,1d,3d,1w
#               LUNAUSDT                   15m,4h,12h,3d
#               MIRUSDT                        12h,1d,3d
#               PERPUSDT                    15m,1d,3d,1w
#               RAYUSDT           5m,15m,4h,8h,12h,3d,1w
#
#                                            stkdown             uptrend  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT               5m,15m,30m,2h  4h,8h,12h,1d,3d,1w
#               RENUSDT                       5m,30m  4h,8h,12h,1d,3d,1w
# 8h,1w         REEFUSDT            5m,15m,30m,1h,1w           8h,12h,1d
#               THETAUSDT                         5m  4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w STORJUSDT           15m,30m,1h,2h,1d            5m,3d,1w
# ...                                            ...                 ...
#               IMXUSDT                 5m,30m,1h,2h                 NaN
#               LUNAUSDT       5m,30m,1h,2h,8h,1d,1w                 NaN
#               MIRUSDT    5m,15m,30m,1h,2h,4h,8h,1w                 NaN
#               PERPUSDT      5m,30m,1h,2h,4h,8h,12h                  1w
#               RAYUSDT                 30m,1h,2h,1d                  1w
#
#                                         dshift               downtrend  \
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT                      1h           5m,15m,30m,2h
#               RENUSDT                       5m                     NaN
# 8h,1w         REEFUSDT                      5m                 15m,30m
#               THETAUSDT             5m,15m,30m                     NaN
# 5m,15m,30m,1w STORJUSDT              4h,8h,12h                1h,2h,1d
# ...                                        ...                     ...
#               IMXUSDT    5m,4h,8h,12h,1d,3d,1w               30m,1h,2h
#               LUNAUSDT           15m,4h,12h,3d   5m,30m,1h,2h,8h,1d,1w
#               MIRUSDT          5m,4h,12h,1d,3d         15m,1h,2h,8h,1w
#               PERPUSDT               15m,1d,3d  5m,30m,1h,2h,4h,8h,12h
#               RAYUSDT          5m,4h,8h,12h,3d                      1d
#
#                            shift
# buyzones      Indicator
# 8h,3d,1w      MINAUSDT       NaN
#               RENUSDT     15m,1h
# 8h,1w         REEFUSDT        1w
#               THETAUSDT    1h,2h
# 5m,15m,30m,1w STORJUSDT  15m,30m
# ...                          ...
#               IMXUSDT        NaN
#               LUNAUSDT       NaN
#               MIRUSDT        30m
#               PERPUSDT       NaN
#               RAYUSDT        15m
#
# [62 rows x 17 columns]

# %%
## MACD gap 1 Week and rsi up
newframe=callfun(macd1wd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]


test=buyzonesa(test)
#test=test.loc[test['buyzones']>='1h']
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=True)

pivotf.stack()
# Out:
#                                    stkcross  \
# buyzones            Indicator
#                     CRVUSDT              1w
#                     PERPUSDT             1w
#                     RAYUSDT              1w
# 1d                  GLMRUSDT          3d,1w
# 1d,3d,1w            BANDUSDT            NaN
#                     COTIUSDT            15m
#                     OMGUSDT           3d,1w
#                     VETUSDT              1w
#                     WINUSDT              3d
# 1h,1d,3d,1w         XTZUSDT              3d
# 1h,2h,1w            LINAUSDT      15m,3d,1w
# 1w                  AUDIOUSDT            1w
#                     BTCUSDT              3d
#                     RUNEUSDT             1w
#                     SOLUSDT             30m
#                     SUSHIUSDT        15m,1w
# 2h,1d,3d,1w         GALAUSDT             1w
# 2h,1w               GRTUSDT             NaN
# 2h,3d               FLUXUSDT            NaN
#                     WAXPUSDT            NaN
# 2h,3d,1w            KSMUSDT             NaN
#                     MANAUSDT            15m
# 2h,8h,1d,3d,1w      ADAUSDT          15m,3d
# 2h,8h,3d,1w         LINKUSDT            NaN
# 30m,1d,3d,1w        MOVRUSDT            NaN
# 30m,1h,2h           ONEUSDT          15m,2h
# 30m,1h,2h,1w        FILUSDT      15m,30m,1w
# 30m,1h,2h,3d        IOTXUSDT            NaN
# 30m,1h,3d,1w        ALGOUSDT            15m
#                     ARUSDT               1w
# 30m,1w              1INCHUSDT            1w
#                     XLMUSDT          15m,3d
# 30m,2h,1w           ATOMUSDT            30m
#                     CAKEUSDT            NaN
# 30m,3d              SRMUSDT             15m
# 30m,3d,1w           SCRTUSDT             1d
# 30m,4h,8h,3d,1w     ANKRUSDT   5m,15m,1h,1w
# 30m,8h,1d,1w        ANTUSDT          15m,1w
# 3d,1w               AVAXUSDT             1w
#                     CELRUSDT         12h,1w
#                     DENTUSDT            15m
#                     DOTUSDT              1d
#                     FTMUSDT              1w
#                     LRCUSDT           3d,1w
#                     MATICUSDT            1w
#                     NEARUSDT            NaN
#                     ONTUSDT             NaN
#                     ROSEUSDT             1w
#                     SCUSDT              NaN
#                     ZILUSDT             12h
# 5m,15m,30m,1d,3d,1w VTHOUSDT          5m,1w
# 5m,15m,30m,1h,2h    CTSIUSDT            NaN
# 5m,15m,30m,1h,8h,1w TFUELUSDT        15m,1h
# 5m,15m,30m,1w       STORJUSDT            5m
# 8h,1w               REEFUSDT            NaN
#                     THETAUSDT           NaN
# 8h,3d,1w            MINAUSDT          1h,1w
#                     RENUSDT          8h,12h
#
#                                                              rsiup  \
# buyzones            Indicator
#                     CRVUSDT                                     1w
#                     PERPUSDT                                    1w
#                     RAYUSDT                                     1w
# 1d                  GLMRUSDT                             8h,12h,1d
# 1d,3d,1w            BANDUSDT                           8h,1d,3d,1w
#                     COTIUSDT                 1h,2h,8h,12h,1d,3d,1w
#                     OMGUSDT                        8h,12h,1d,3d,1w
#                     VETUSDT                  1h,2h,8h,12h,1d,3d,1w
#                     WINUSDT                     1h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT              30m,1h,2h,8h,12h,1d,3d,1w
# 1h,2h,1w            LINAUSDT                           1h,2h,3d,1w
# 1w                  AUDIOUSDT                      8h,12h,1d,3d,1w
#                     BTCUSDT                                  3d,1w
#                     RUNEUSDT                                 3d,1w
#                     SOLUSDT                                  3d,1w
#                     SUSHIUSDT                                3d,1w
# 2h,1d,3d,1w         GALAUSDT                 1h,2h,8h,12h,1d,3d,1w
# 2h,1w               GRTUSDT                               2h,3d,1w
# 2h,3d               FLUXUSDT                              1h,2h,3d
#                     WAXPUSDT                           1h,2h,3d,1w
# 2h,3d,1w            KSMUSDT                     2h,8h,12h,1d,3d,1w
#                     MANAUSDT                 1h,2h,8h,12h,1d,3d,1w
# 2h,8h,1d,3d,1w      ADAUSDT                  1h,2h,8h,12h,1d,3d,1w
# 2h,8h,3d,1w         LINKUSDT                 1h,2h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT      15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h           ONEUSDT                          15m,30m,1h,2h
# 30m,1h,2h,1w        FILUSDT                       15m,30m,1h,2h,1w
# 30m,1h,2h,3d        IOTXUSDT                   15m,30m,1h,2h,3d,1w
# 30m,1h,3d,1w        ALGOUSDT         15m,30m,1h,2h,8h,12h,1d,3d,1w
#                     ARUSDT               30m,1h,2h,8h,12h,1d,3d,1w
# 30m,1w              1INCHUSDT                           15m,30m,1w
#                     XLMUSDT       15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,2h,1w           ATOMUSDT                30m,2h,8h,12h,1d,3d,1w
#                     CAKEUSDT                       30m,2h,8h,3d,1w
# 30m,3d              SRMUSDT                          15m,30m,3d,1w
# 30m,3d,1w           SCRTUSDT               15m,30m,8h,12h,1d,3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT      15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,8h,1d,1w        ANTUSDT           30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3d,1w               AVAXUSDT                       8h,12h,1d,3d,1w
#                     CELRUSDT                 1h,2h,8h,12h,1d,3d,1w
#                     DENTUSDT                 1h,2h,8h,12h,1d,3d,1w
#                     DOTUSDT                        8h,12h,1d,3d,1w
#                     FTMUSDT                        8h,12h,1d,3d,1w
#                     LRCUSDT                        8h,12h,1d,3d,1w
#                     MATICUSDT                1h,2h,8h,12h,1d,3d,1w
#                     NEARUSDT                 1h,2h,8h,12h,1d,3d,1w
#                     ONTUSDT                        8h,12h,1d,3d,1w
#                     ROSEUSDT                       8h,12h,1d,3d,1w
#                     SCUSDT                         8h,12h,1d,3d,1w
#                     ZILUSDT                        8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT            5m,15m,30m,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT                   5m,15m,30m,1h,2h,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w       STORJUSDT                     5m,15m,30m,3d,1w
# 8h,1w               REEFUSDT                       8h,12h,1d,3d,1w
#                     THETAUSDT             1h,2h,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT                    4h,8h,12h,1d,3d,1w
#                     RENUSDT                     4h,8h,12h,1d,3d,1w
#
#                                                         rsidown  \
# buyzones            Indicator
#                     CRVUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                     PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                     RAYUSDT              5m,15m,4h,8h,12h,1d,3d
# 1d                  GLMRUSDT          5m,15m,30m,1h,2h,4h,3d,1w
# 1d,3d,1w            BANDUSDT                    5m,30m,1h,2h,4h
#                     COTIUSDT                      5m,15m,30m,4h
#                     OMGUSDT                 5m,15m,30m,1h,2h,4h
#                     VETUSDT                       5m,15m,30m,4h
#                     WINUSDT                       5m,15m,30m,4h
# 1h,1d,3d,1w         XTZUSDT                           5m,15m,4h
# 1h,2h,1w            LINAUSDT                    5m,4h,8h,12h,1d
# 1w                  AUDIOUSDT               5m,15m,30m,1h,2h,4h
#                     BTCUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d
#                     RUNEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d
#                     SOLUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d
#                     SUSHIUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d
# 2h,1d,3d,1w         GALAUSDT                      5m,15m,30m,4h
# 2h,1w               GRTUSDT             5m,15m,30m,4h,8h,12h,1d
# 2h,3d               FLUXUSDT         5m,15m,30m,4h,8h,12h,1d,1w
#                     WAXPUSDT            5m,15m,30m,4h,8h,12h,1d
# 2h,3d,1w            KSMUSDT                       5m,15m,30m,4h
#                     MANAUSDT                      5m,15m,30m,4h
# 2h,8h,1d,3d,1w      ADAUSDT                       5m,15m,30m,4h
# 2h,8h,3d,1w         LINKUSDT                      5m,15m,30m,4h
# 30m,1d,3d,1w        MOVRUSDT                                 5m
# 30m,1h,2h           ONEUSDT               5m,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,1w        FILUSDT                        5m,4h,12h,3d
# 30m,1h,2h,3d        IOTXUSDT                    5m,4h,8h,12h,1d
# 30m,1h,3d,1w        ALGOUSDT                              5m,4h
#                     ARUSDT                                5m,4h
# 30m,1w              1INCHUSDT          5m,1h,2h,4h,8h,12h,1d,3d
#                     XLMUSDT                                  5m
# 30m,2h,1w           ATOMUSDT                              5m,4h
#                     CAKEUSDT                       5m,4h,12h,1d
# 30m,3d              SRMUSDT                     5m,4h,8h,12h,1d
# 30m,3d,1w           SCRTUSDT                        5m,1h,2h,4h
# 30m,4h,8h,3d,1w     ANKRUSDT                                 5m
# 30m,8h,1d,1w        ANTUSDT                                  5m
# 3d,1w               AVAXUSDT                5m,15m,30m,1h,2h,4h
#                     CELRUSDT                      5m,15m,30m,4h
#                     DENTUSDT                      5m,15m,30m,4h
#                     DOTUSDT                               5m,4h
#                     FTMUSDT                 5m,15m,30m,1h,2h,4h
#                     LRCUSDT                 5m,15m,30m,1h,2h,4h
#                     MATICUSDT                        5m,15m,30m
#                     NEARUSDT                      5m,15m,30m,4h
#                     ONTUSDT                     5m,30m,1h,2h,4h
#                     ROSEUSDT                5m,15m,30m,1h,2h,4h
#                     SCUSDT                     5m,15m,30m,1h,4h
#                     ZILUSDT                 5m,15m,30m,1h,2h,4h
# 5m,15m,30m,1d,3d,1w VTHOUSDT                              1h,2h
# 5m,15m,30m,1h,2h    CTSIUSDT                    4h,8h,12h,1d,3d
# 5m,15m,30m,1h,8h,1w TFUELUSDT                               NaN
# 5m,15m,30m,1w       STORJUSDT                1h,2h,4h,8h,12h,1d
# 8h,1w               REEFUSDT                         5m,15m,30m
#                     THETAUSDT                        5m,15m,30m
# 8h,3d,1w            MINAUSDT                   5m,15m,30m,1h,2h
#                     RENUSDT                              5m,15m
#
#                                              tops            bottoms  \
# buyzones            Indicator
#                     CRVUSDT          4h,8h,12h,1d      5m,15m,30m,1w
#                     PERPUSDT            8h,12h,1d   5m,15m,30m,2h,1w
#                     RAYUSDT          4h,8h,12h,1d         15m,30m,1w
# 1d                  GLMRUSDT            4h,8h,12h      15m,30m,3d,1w
# 1d,3d,1w            BANDUSDT            2h,4h,12h                 1w
#                     COTIUSDT         2h,4h,8h,12h         15m,30m,1w
#                     OMGUSDT          2h,4h,8h,12h      5m,15m,30m,1w
#                     VETUSDT          2h,4h,8h,12h         15m,30m,1w
#                     WINUSDT          2h,4h,8h,12h         15m,30m,1w
# 1h,1d,3d,1w         XTZUSDT          2h,4h,8h,12h      5m,15m,30m,1w
# 1h,2h,1w            LINAUSDT            4h,8h,12h         15m,30m,1w
# 1w                  AUDIOUSDT     2h,8h,12h,1d,3d          5m,30m,1w
#                     BTCUSDT             4h,8h,12h         15m,30m,1w
#                     RUNEUSDT         4h,8h,12h,1d         15m,30m,1w
#                     SOLUSDT       4h,8h,12h,1d,3d         15m,30m,1w
#                     SUSHIUSDT              12h,1d             30m,1w
# 2h,1d,3d,1w         GALAUSDT            4h,8h,12h         15m,30m,1w
# 2h,1w               GRTUSDT                12h,1d         15m,30m,1w
# 2h,3d               FLUXUSDT         4h,8h,12h,1d                30m
#                     WAXPUSDT         4h,8h,12h,1d         15m,30m,1w
# 2h,3d,1w            KSMUSDT             4h,12h,1d         15m,30m,1w
#                     MANAUSDT         4h,8h,12h,1d         15m,30m,1w
# 2h,8h,1d,3d,1w      ADAUSDT                    4h         15m,30m,1w
# 2h,8h,3d,1w         LINKUSDT               4h,12h         15m,30m,1w
# 30m,1d,3d,1w        MOVRUSDT      1h,2h,4h,8h,12h          5m,15m,3d
# 30m,1h,2h           ONEUSDT                   NaN  1h,2h,4h,8h,3d,1w
# 30m,1h,2h,1w        FILUSDT                12h,1d         15m,30m,1w
# 30m,1h,2h,3d        IOTXUSDT         4h,8h,12h,1d      15m,30m,1h,1w
# 30m,1h,3d,1w        ALGOUSDT      2h,4h,8h,12h,1d         15m,30m,1w
#                     ARUSDT           2h,4h,12h,1d         15m,30m,1w
# 30m,1w              1INCHUSDT           8h,12h,1d         15m,30m,1w
#                     XLMUSDT    1h,2h,4h,8h,12h,1d             30m,1w
# 30m,2h,1w           ATOMUSDT      4h,8h,12h,1d,3d      15m,30m,1h,1w
#                     CAKEUSDT         4h,8h,12h,1d         15m,30m,1w
# 30m,3d              SRMUSDT          4h,8h,12h,1d      15m,30m,3d,1w
# 30m,3d,1w           SCRTUSDT      2h,4h,8h,12h,1d      15m,30m,3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT         1h,2h,12h,1d              5m,1w
# 30m,8h,1d,1w        ANTUSDT       1h,2h,4h,12h,3d         15m,30m,1w
# 3d,1w               AVAXUSDT   1h,2h,4h,8h,12h,1d          5m,15m,1w
#                     CELRUSDT      2h,4h,8h,12h,1d             30m,1w
#                     DENTUSDT      2h,4h,8h,12h,1d             30m,1w
#                     DOTUSDT             4h,12h,1d         15m,30m,1w
#                     FTMUSDT             2h,12h,1d      5m,15m,30m,1w
#                     LRCUSDT          4h,8h,12h,1d      5m,15m,30m,1w
#                     MATICUSDT     2h,4h,8h,12h,1d         15m,30m,1w
#                     NEARUSDT      2h,4h,8h,12h,1d      15m,30m,3d,1w
#                     ONTUSDT          4h,8h,12h,1d         15m,30m,1w
#                     ROSEUSDT            8h,12h,1d         15m,30m,1w
#                     SCUSDT           4h,8h,12h,1d         15m,30m,1w
#                     ZILUSDT             8h,12h,1d      5m,15m,30m,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT      1h,2h,4h,8h,12h          5m,15m,1w
# 5m,15m,30m,1h,2h    CTSIUSDT            4h,8h,12h   5m,15m,30m,1h,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT     2h,4h,12h,1d,3d                 1w
# 5m,15m,30m,1w       STORJUSDT        4h,12h,1d,3d             5m,30m
# 8h,1w               REEFUSDT      2h,4h,12h,1d,3d         15m,30m,1w
#                     THETAUSDT  1h,2h,4h,12h,1d,3d                 1w
# 8h,3d,1w            MINAUSDT      1h,2h,4h,12h,1d          5m,15m,1w
#                     RENUSDT       1h,2h,4h,12h,1d         15m,30m,1w
#
#                                       topr   bottomr  \
# buyzones            Indicator
#                     CRVUSDT            NaN       NaN
#                     PERPUSDT           NaN  5m,3d,1w
#                     RAYUSDT            NaN        3d
# 1d                  GLMRUSDT           NaN     3d,1w
# 1d,3d,1w            BANDUSDT           NaN       NaN
#                     COTIUSDT           NaN       NaN
#                     OMGUSDT            NaN       NaN
#                     VETUSDT            NaN       NaN
#                     WINUSDT            NaN        3d
# 1h,1d,3d,1w         XTZUSDT            NaN       NaN
# 1h,2h,1w            LINAUSDT           NaN       NaN
# 1w                  AUDIOUSDT          NaN       NaN
#                     BTCUSDT            NaN     3d,1w
#                     RUNEUSDT           NaN       NaN
#                     SOLUSDT            NaN       NaN
#                     SUSHIUSDT          NaN       NaN
# 2h,1d,3d,1w         GALAUSDT           NaN       NaN
# 2h,1w               GRTUSDT            NaN       NaN
# 2h,3d               FLUXUSDT           NaN       NaN
#                     WAXPUSDT           NaN       NaN
# 2h,3d,1w            KSMUSDT            NaN       NaN
#                     MANAUSDT           NaN       NaN
# 2h,8h,1d,3d,1w      ADAUSDT            NaN       NaN
# 2h,8h,3d,1w         LINKUSDT           NaN       NaN
# 30m,1d,3d,1w        MOVRUSDT           NaN  1d,3d,1w
# 30m,1h,2h           ONEUSDT            NaN     1d,3d
# 30m,1h,2h,1w        FILUSDT            NaN     3d,1w
# 30m,1h,2h,3d        IOTXUSDT           NaN       NaN
# 30m,1h,3d,1w        ALGOUSDT           NaN       NaN
#                     ARUSDT             NaN        3d
# 30m,1w              1INCHUSDT          NaN       NaN
#                     XLMUSDT             1h       NaN
# 30m,2h,1w           ATOMUSDT           NaN       NaN
#                     CAKEUSDT           NaN       NaN
# 30m,3d              SRMUSDT            NaN        3d
# 30m,3d,1w           SCRTUSDT           NaN     3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT           NaN       NaN
# 30m,8h,1d,1w        ANTUSDT            NaN       NaN
# 3d,1w               AVAXUSDT         1h,2h        3d
#                     CELRUSDT           NaN       NaN
#                     DENTUSDT           NaN       NaN
#                     DOTUSDT            NaN       NaN
#                     FTMUSDT            NaN       NaN
#                     LRCUSDT            NaN       NaN
#                     MATICUSDT  1h,2h,4h,8h       NaN
#                     NEARUSDT           NaN       NaN
#                     ONTUSDT            NaN       NaN
#                     ROSEUSDT           NaN        3d
#                     SCUSDT             NaN       NaN
#                     ZILUSDT            NaN       NaN
# 5m,15m,30m,1d,3d,1w VTHOUSDT           NaN       NaN
# 5m,15m,30m,1h,2h    CTSIUSDT           NaN       NaN
# 5m,15m,30m,1h,8h,1w TFUELUSDT          NaN        3d
# 5m,15m,30m,1w       STORJUSDT    4h,8h,12h       NaN
# 8h,1w               REEFUSDT           NaN       NaN
#                     THETAUSDT           1h       NaN
# 8h,3d,1w            MINAUSDT           NaN       NaN
#                     RENUSDT            NaN       NaN
#
#                                                          stover  \
# buyzones            Indicator
#                     CRVUSDT                  5m,8h,12h,1d,3d,1w
#                     PERPUSDT                       15m,1d,3d,1w
#                     RAYUSDT                  5m,4h,8h,12h,3d,1w
# 1d                  GLMRUSDT              5m,4h,8h,12h,1d,3d,1w
# 1d,3d,1w            BANDUSDT                5m,30m,4h,12h,1d,3d
#                     COTIUSDT             5m,15m,4h,8h,12h,1d,1w
#                     OMGUSDT               5m,4h,8h,12h,1d,3d,1w
#                     VETUSDT               5m,4h,8h,12h,1d,3d,1w
#                     WINUSDT                  5m,4h,8h,12h,1d,3d
# 1h,1d,3d,1w         XTZUSDT                     4h,8h,12h,1d,3d
# 1h,2h,1w            LINAUSDT          5m,15m,4h,8h,12h,1d,3d,1w
# 1w                  AUDIOUSDT             5m,4h,8h,12h,1d,3d,1w
#                     BTCUSDT                     4h,8h,12h,1d,3d
#                     RUNEUSDT                    8h,12h,1d,3d,1w
#                     SOLUSDT              5m,30m,4h,8h,12h,3d,1w
#                     SUSHIUSDT            5m,15m,4h,12h,1d,3d,1w
# 2h,1d,3d,1w         GALAUSDT              5m,4h,8h,12h,1d,3d,1w
# 2h,1w               GRTUSDT                  5m,4h,8h,12h,1d,3d
# 2h,3d               FLUXUSDT         5m,15m,30m,4h,8h,12h,1d,3d
#                     WAXPUSDT                    4h,8h,12h,1d,3d
# 2h,3d,1w            KSMUSDT               5m,4h,8h,12h,1d,3d,1w
#                     MANAUSDT             5m,15m,4h,8h,12h,1d,1w
# 2h,8h,1d,3d,1w      ADAUSDT              5m,15m,4h,8h,12h,1d,3d
# 2h,8h,3d,1w         LINKUSDT                 5m,4h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT                    2h,4h,8h,12h,1d
# 30m,1h,2h           ONEUSDT                       5m,15m,30m,2h
# 30m,1h,2h,1w        FILUSDT          5m,15m,30m,4h,12h,1d,3d,1w
# 30m,1h,2h,3d        IOTXUSDT                    5m,8h,12h,1d,3d
# 30m,1h,3d,1w        ALGOUSDT          5m,15m,4h,8h,12h,1d,3d,1w
#                     ARUSDT                   4h,8h,12h,1d,3d,1w
# 30m,1w              1INCHUSDT                       5m,4h,3d,1w
#                     XLMUSDT                 15m,4h,8h,12h,1d,3d
# 30m,2h,1w           ATOMUSDT                5m,30m,8h,12h,3d,1w
#                     CAKEUSDT                    5m,8h,12h,1d,3d
# 30m,3d              SRMUSDT           5m,15m,4h,8h,12h,1d,3d,1w
# 30m,3d,1w           SCRTUSDT              5m,4h,8h,12h,1d,3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT   5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 30m,8h,1d,1w        ANTUSDT           5m,15m,2h,4h,12h,1d,3d,1w
# 3d,1w               AVAXUSDT              5m,4h,8h,12h,1d,3d,1w
#                     CELRUSDT              5m,4h,8h,12h,1d,3d,1w
#                     DENTUSDT             5m,15m,4h,8h,12h,1d,3d
#                     DOTUSDT                  5m,4h,8h,12h,1d,1w
#                     FTMUSDT                     4h,12h,1d,3d,1w
#                     LRCUSDT               5m,4h,8h,12h,1d,3d,1w
#                     MATICUSDT                   4h,12h,1d,3d,1w
#                     NEARUSDT              5m,4h,8h,12h,1d,3d,1w
#                     ONTUSDT                  5m,4h,8h,12h,1d,3d
#                     ROSEUSDT              5m,4h,8h,12h,1d,3d,1w
#                     SCUSDT                5m,4h,8h,12h,1d,3d,1w
#                     ZILUSDT                     4h,8h,12h,1d,3d
# 5m,15m,30m,1d,3d,1w VTHOUSDT              5m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT                    5m,4h,8h,12h,1d
# 5m,15m,30m,1h,8h,1w TFUELUSDT     5m,15m,30m,1h,4h,8h,12h,3d,1w
# 5m,15m,30m,1w       STORJUSDT                5m,4h,8h,12h,3d,1w
# 8h,1w               REEFUSDT              5m,2h,4h,8h,12h,1d,3d
#                     THETAUSDT     5m,15m,30m,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT              1h,4h,8h,12h,1d,3d,1w
#                     RENUSDT               5m,4h,8h,12h,1d,3d,1w
#
#                                                               room  \
# buyzones            Indicator
#                     CRVUSDT                 5m,15m,30m,1h,2h,3d,1w
#                     PERPUSDT             5m,15m,30m,1h,2h,4h,3d,1w
#                     RAYUSDT                 5m,15m,30m,1h,2h,3d,1w
# 1d                  GLMRUSDT             5m,15m,30m,1h,2h,1d,3d,1w
# 1d,3d,1w            BANDUSDT             5m,15m,30m,1h,8h,1d,3d,1w
#                     COTIUSDT                5m,15m,30m,1h,1d,3d,1w
#                     OMGUSDT                 5m,15m,30m,1h,1d,3d,1w
#                     VETUSDT                 5m,15m,30m,1h,1d,3d,1w
#                     WINUSDT                 5m,15m,30m,1h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT                 5m,15m,30m,1h,1d,3d,1w
# 1h,2h,1w            LINAUSDT             5m,15m,30m,1h,2h,1d,3d,1w
# 1w                  AUDIOUSDT                  5m,15m,30m,1h,4h,1w
#                     BTCUSDT              5m,15m,30m,1h,2h,1d,3d,1w
#                     RUNEUSDT                5m,15m,30m,1h,2h,3d,1w
#                     SOLUSDT                    5m,15m,30m,1h,2h,1w
#                     SUSHIUSDT         5m,15m,30m,1h,2h,4h,8h,3d,1w
# 2h,1d,3d,1w         GALAUSDT             5m,15m,30m,1h,2h,1d,3d,1w
# 2h,1w               GRTUSDT           5m,15m,30m,1h,2h,4h,8h,3d,1w
# 2h,3d               FLUXUSDT                   5m,15m,30m,1h,2h,3d
#                     WAXPUSDT                5m,15m,30m,1h,2h,3d,1w
# 2h,3d,1w            KSMUSDT              5m,15m,30m,1h,2h,8h,3d,1w
#                     MANAUSDT                5m,15m,30m,1h,2h,3d,1w
# 2h,8h,1d,3d,1w      ADAUSDT       5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 2h,8h,3d,1w         LINKUSDT          5m,15m,30m,1h,2h,8h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT                   5m,15m,30m,1d,3d,1w
# 30m,1h,2h           ONEUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,1w        FILUSDT           5m,15m,30m,1h,2h,4h,8h,3d,1w
# 30m,1h,2h,3d        IOTXUSDT                5m,15m,30m,1h,2h,3d,1w
# 30m,1h,3d,1w        ALGOUSDT                   5m,15m,30m,1h,3d,1w
#                     ARUSDT                  5m,15m,30m,1h,8h,3d,1w
# 30m,1w              1INCHUSDT            5m,15m,30m,1h,2h,4h,3d,1w
#                     XLMUSDT                       5m,15m,30m,3d,1w
# 30m,2h,1w           ATOMUSDT                   5m,15m,30m,1h,2h,1w
#                     CAKEUSDT                5m,15m,30m,1h,2h,3d,1w
# 30m,3d              SRMUSDT                 5m,15m,30m,1h,2h,3d,1w
# 30m,3d,1w           SCRTUSDT                   5m,15m,30m,1h,3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT                5m,15m,30m,4h,8h,3d,1w
# 30m,8h,1d,1w        ANTUSDT                    5m,15m,30m,8h,1d,1w
# 3d,1w               AVAXUSDT                      5m,15m,30m,3d,1w
#                     CELRUSDT                   5m,15m,30m,1h,3d,1w
#                     DENTUSDT                   5m,15m,30m,1h,3d,1w
#                     DOTUSDT              5m,15m,30m,1h,2h,8h,3d,1w
#                     FTMUSDT              5m,15m,30m,1h,4h,8h,3d,1w
#                     LRCUSDT                 5m,15m,30m,1h,2h,3d,1w
#                     MATICUSDT                  5m,15m,30m,1h,3d,1w
#                     NEARUSDT                   5m,15m,30m,1h,3d,1w
#                     ONTUSDT                 5m,15m,30m,1h,2h,3d,1w
#                     ROSEUSDT             5m,15m,30m,1h,2h,4h,3d,1w
#                     SCUSDT                  5m,15m,30m,1h,2h,3d,1w
#                     ZILUSDT              5m,15m,30m,1h,2h,4h,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT                   5m,15m,30m,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT             5m,15m,30m,1h,2h,1d,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                  5m,15m,30m,1h,8h,1w
# 5m,15m,30m,1w       STORJUSDT               5m,15m,30m,1h,2h,8h,1w
# 8h,1w               REEFUSDT                   5m,15m,30m,1h,8h,1w
#                     THETAUSDT                     5m,15m,30m,8h,1w
# 8h,3d,1w            MINAUSDT                   5m,15m,30m,8h,3d,1w
#                     RENUSDT                    5m,15m,30m,8h,3d,1w
#
#                                                              roomr  \
# buyzones            Indicator
#                     CRVUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1d                  GLMRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1d,3d,1w            BANDUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     COTIUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     OMGUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     VETUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     WINUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,1w            LINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1w                  AUDIOUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     RUNEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     SUSHIUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,1d,3d,1w         GALAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,1w               GRTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,3d               FLUXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     WAXPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,3d,1w            KSMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     MANAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,8h,1d,3d,1w      ADAUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2h,8h,3d,1w         LINKUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h           ONEUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,1w        FILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,3d        IOTXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,3d,1w        ALGOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1w              1INCHUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     XLMUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 30m,2h,1w           ATOMUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     CAKEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,3d              SRMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,3d,1w           SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,8h,1d,1w        ANTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3d,1w               AVAXUSDT         5m,15m,30m,4h,8h,12h,1d,3d,1w
#                     CELRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     DENTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     DOTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     FTMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     LRCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     MATICUSDT              5m,15m,30m,12h,1d,3d,1w
#                     NEARUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     ONTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     ROSEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     SCUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     ZILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1w       STORJUSDT            5m,15m,30m,1h,2h,1d,3d,1w
# 8h,1w               REEFUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     THETAUSDT     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                     RENUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                stunder  \
# buyzones            Indicator
#                     CRVUSDT           15m,30m,1h,2h,4h
#                     PERPUSDT    5m,30m,1h,2h,4h,8h,12h
#                     RAYUSDT           15m,30m,1h,2h,1d
# 1d                  GLMRUSDT             15m,30m,1h,2h
# 1d,3d,1w            BANDUSDT           15m,1h,2h,8h,1w
#                     COTIUSDT              30m,1h,2h,3d
#                     OMGUSDT              15m,30m,1h,2h
#                     VETUSDT              15m,30m,1h,2h
#                     WINUSDT           15m,30m,1h,2h,1w
# 1h,1d,3d,1w         XTZUSDT        5m,15m,30m,1h,2h,1w
# 1h,2h,1w            LINAUSDT                 30m,1h,2h
# 1w                  AUDIOUSDT            15m,30m,1h,2h
#                     BTCUSDT        5m,15m,30m,1h,2h,1w
#                     RUNEUSDT       5m,15m,30m,1h,2h,4h
#                     SOLUSDT               15m,1h,2h,1d
#                     SUSHIUSDT             30m,1h,2h,8h
# 2h,1d,3d,1w         GALAUSDT             15m,30m,1h,2h
# 2h,1w               GRTUSDT           15m,30m,1h,2h,1w
# 2h,3d               FLUXUSDT                     1h,2h
#                     WAXPUSDT       5m,15m,30m,1h,2h,1w
# 2h,3d,1w            KSMUSDT              15m,30m,1h,2h
#                     MANAUSDT              30m,1h,2h,3d
# 2h,8h,1d,3d,1w      ADAUSDT               30m,1h,2h,1w
# 2h,8h,3d,1w         LINKUSDT          15m,30m,1h,2h,8h
# 30m,1d,3d,1w        MOVRUSDT       5m,15m,30m,1h,3d,1w
# 30m,1h,2h           ONEUSDT         1h,4h,8h,12h,1d,3d
# 30m,1h,2h,1w        FILUSDT                   1h,2h,8h
# 30m,1h,2h,3d        IOTXUSDT       15m,30m,1h,2h,4h,1w
# 30m,1h,3d,1w        ALGOUSDT                 30m,1h,2h
#                     ARUSDT            5m,15m,30m,1h,2h
# 30m,1w              1INCHUSDT  15m,30m,1h,2h,8h,12h,1d
#                     XLMUSDT            5m,30m,1h,2h,1w
# 30m,2h,1w           ATOMUSDT           15m,1h,2h,4h,1d
#                     CAKEUSDT       15m,30m,1h,2h,4h,1w
# 30m,3d              SRMUSDT                  30m,1h,2h
# 30m,3d,1w           SCRTUSDT             15m,30m,1h,2h
# 30m,4h,8h,3d,1w     ANKRUSDT                        8h
# 30m,8h,1d,1w        ANTUSDT                  30m,1h,8h
# 3d,1w               AVAXUSDT             15m,30m,1h,2h
#                     CELRUSDT             15m,30m,1h,2h
#                     DENTUSDT              30m,1h,2h,1w
#                     DOTUSDT           15m,30m,1h,2h,3d
#                     FTMUSDT        5m,15m,30m,1h,2h,8h
#                     LRCUSDT              15m,30m,1h,2h
#                     MATICUSDT      5m,15m,30m,1h,2h,8h
#                     NEARUSDT             15m,30m,1h,2h
#                     ONTUSDT           15m,30m,1h,2h,1w
#                     ROSEUSDT             15m,30m,1h,2h
#                     SCUSDT               15m,30m,1h,2h
#                     ZILUSDT        5m,15m,30m,1h,2h,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT             15m,30m,1h,2h
# 5m,15m,30m,1h,2h    CTSIUSDT       15m,30m,1h,2h,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                    2h,1d
# 5m,15m,30m,1w       STORJUSDT         15m,30m,1h,2h,1d
# 8h,1w               REEFUSDT             15m,30m,1h,1w
#                     THETAUSDT                    1h,2h
# 8h,3d,1w            MINAUSDT             5m,15m,30m,2h
#                     RENUSDT              15m,30m,1h,2h
#
#                                                              stkup  \
# buyzones            Indicator
#                     CRVUSDT                           12h,1d,3d,1w
#                     PERPUSDT                          15m,1d,3d,1w
#                     RAYUSDT                 5m,15m,4h,8h,12h,3d,1w
# 1d                  GLMRUSDT             5m,15m,4h,8h,12h,1d,3d,1w
# 1d,3d,1w            BANDUSDT                      5m,15m,4h,12h,1d
#                     COTIUSDT             5m,15m,4h,8h,12h,1d,3d,1w
#                     OMGUSDT                     4h,8h,12h,1d,3d,1w
#                     VETUSDT                 15m,4h,8h,12h,1d,3d,1w
#                     WINUSDT              5m,15m,4h,8h,12h,1d,3d,1w
# 1h,1d,3d,1w         XTZUSDT                 15m,4h,8h,12h,1d,3d,1w
# 1h,2h,1w            LINAUSDT             5m,15m,4h,8h,12h,1d,3d,1w
# 1w                  AUDIOUSDT               15m,4h,8h,12h,1d,3d,1w
#                     BTCUSDT                       15m,8h,12h,1d,3d
#                     RUNEUSDT                          12h,1d,3d,1w
#                     SOLUSDT                           8h,12h,3d,1w
#                     SUSHIUSDT                     15m,4h,12h,3d,1w
# 2h,1d,3d,1w         GALAUSDT                   15m,4h,8h,12h,1d,1w
# 2h,1w               GRTUSDT                    5m,15m,4h,12h,1d,3d
# 2h,3d               FLUXUSDT                   15m,4h,8h,12h,1d,3d
#                     WAXPUSDT                      15m,4h,12h,1d,3d
# 2h,3d,1w            KSMUSDT                 5m,15m,4h,8h,12h,3d,1w
#                     MANAUSDT                5m,15m,4h,8h,12h,1d,1w
# 2h,8h,1d,3d,1w      ADAUSDT                       15m,4h,8h,12h,1d
# 2h,8h,3d,1w         LINKUSDT                   15m,4h,12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT                   15m,2h,4h,8h,12h,1d
# 30m,1h,2h           ONEUSDT                          5m,15m,30m,2h
# 30m,1h,2h,1w        FILUSDT                   15m,30m,4h,12h,3d,1w
# 30m,1h,2h,3d        IOTXUSDT                   5m,15m,1h,8h,12h,3d
# 30m,1h,3d,1w        ALGOUSDT             5m,15m,4h,8h,12h,1d,3d,1w
#                     ARUSDT                  15m,4h,8h,12h,1d,3d,1w
# 30m,1w              1INCHUSDT                          5m,4h,3d,1w
#                     XLMUSDT                 15m,1h,4h,8h,12h,1d,3d
# 30m,2h,1w           ATOMUSDT                          5m,30m,3d,1w
#                     CAKEUSDT                      15m,8h,12h,1d,3d
# 30m,3d              SRMUSDT                 5m,15m,4h,8h,12h,3d,1w
# 30m,3d,1w           SCRTUSDT                5m,15m,4h,8h,12h,3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,8h,1d,1w        ANTUSDT              5m,15m,1h,2h,4h,12h,1d,1w
# 3d,1w               AVAXUSDT                    4h,8h,12h,1d,3d,1w
#                     CELRUSDT                5m,15m,4h,8h,12h,3d,1w
#                     DENTUSDT                   15m,4h,8h,12h,1d,3d
#                     DOTUSDT                    15m,4h,8h,12h,1d,1w
#                     FTMUSDT                       15m,4h,12h,3d,1w
#                     LRCUSDT                     4h,8h,12h,1d,3d,1w
#                     MATICUSDT                         15m,1d,3d,1w
#                     NEARUSDT                15m,4h,8h,12h,1d,3d,1w
#                     ONTUSDT                        4h,8h,12h,1d,3d
#                     ROSEUSDT                   15m,4h,8h,12h,3d,1w
#                     SCUSDT                   5m,4h,8h,12h,1d,3d,1w
#                     ZILUSDT                           4h,8h,12h,3d
# 5m,15m,30m,1d,3d,1w VTHOUSDT                 5m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT                   5m,15m,8h,12h,1d,3d
# 5m,15m,30m,1h,8h,1w TFUELUSDT        5m,15m,30m,1h,4h,8h,12h,3d,1w
# 5m,15m,30m,1w       STORJUSDT                   5m,4h,8h,12h,3d,1w
# 8h,1w               REEFUSDT                          4h,8h,12h,1d
#                     THETAUSDT        15m,30m,1h,4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT                 1h,4h,8h,12h,1d,3d,1w
#                     RENUSDT              15m,1h,4h,8h,12h,1d,3d,1w
#
#                                                stkdown  \
# buyzones            Indicator
#                     CRVUSDT         5m,30m,1h,2h,4h,8h
#                     PERPUSDT    5m,30m,1h,2h,4h,8h,12h
#                     RAYUSDT               30m,1h,2h,1d
# 1d                  GLMRUSDT                 30m,1h,2h
# 1d,3d,1w            BANDUSDT        30m,1h,2h,8h,3d,1w
#                     COTIUSDT                 30m,1h,2h
#                     OMGUSDT               5m,30m,1h,2h
#                     VETUSDT               5m,30m,1h,2h
#                     WINUSDT                  30m,1h,2h
# 1h,1d,3d,1w         XTZUSDT               5m,30m,1h,2h
# 1h,2h,1w            LINAUSDT                 30m,1h,2h
# 1w                  AUDIOUSDT             5m,30m,1h,2h
#                     BTCUSDT         5m,30m,1h,2h,4h,1w
#                     RUNEUSDT            5m,1h,2h,4h,8h
#                     SOLUSDT             5m,1h,2h,4h,1d
#                     SUSHIUSDT       5m,30m,1h,2h,8h,1d
# 2h,1d,3d,1w         GALAUSDT           5m,30m,1h,2h,3d
# 2h,1w               GRTUSDT            30m,1h,2h,8h,1w
# 2h,3d               FLUXUSDT              5m,30m,1h,2h
#                     WAXPUSDT        5m,30m,1h,2h,8h,1w
# 2h,3d,1w            KSMUSDT                  30m,1h,2h
#                     MANAUSDT              30m,1h,2h,3d
# 2h,8h,1d,3d,1w      ADAUSDT         5m,30m,1h,2h,3d,1w
# 2h,8h,3d,1w         LINKUSDT           5m,30m,1h,2h,8h
# 30m,1d,3d,1w        MOVRUSDT           5m,30m,1h,3d,1w
# 30m,1h,2h           ONEUSDT         1h,4h,8h,12h,1d,3d
# 30m,1h,2h,1w        FILUSDT             5m,1h,2h,8h,1d
# 30m,1h,2h,3d        IOTXUSDT           30m,2h,4h,1d,1w
# 30m,1h,3d,1w        ALGOUSDT                 30m,1h,2h
#                     ARUSDT                5m,30m,1h,2h
# 30m,1w              1INCHUSDT  15m,30m,1h,2h,8h,12h,1d
#                     XLMUSDT               5m,30m,2h,1w
# 30m,2h,1w           ATOMUSDT                  1h,2h,4h
#                     CAKEUSDT        5m,30m,1h,2h,4h,1w
# 30m,3d              SRMUSDT               30m,1h,2h,1d
# 30m,3d,1w           SCRTUSDT                 30m,1h,2h
# 30m,4h,8h,3d,1w     ANKRUSDT                       NaN
# 30m,8h,1d,1w        ANTUSDT                  30m,8h,3d
# 3d,1w               AVAXUSDT              5m,30m,1h,2h
#                     CELRUSDT                 30m,1h,2h
#                     DENTUSDT           5m,30m,1h,2h,1w
#                     DOTUSDT            5m,30m,1h,2h,3d
#                     FTMUSDT            5m,30m,1h,2h,8h
#                     LRCUSDT           5m,15m,30m,1h,2h
#                     MATICUSDT             5m,30m,1h,2h
#                     NEARUSDT              5m,30m,1h,2h
#                     ONTUSDT            5m,30m,1h,2h,1w
#                     ROSEUSDT              5m,30m,1h,2h
#                     SCUSDT               15m,30m,1h,2h
#                     ZILUSDT            5m,30m,1h,2h,1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT             15m,30m,1h,2h
# 5m,15m,30m,1h,2h    CTSIUSDT           30m,1h,2h,4h,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                      NaN
# 5m,15m,30m,1w       STORJUSDT         15m,30m,1h,2h,1d
# 8h,1w               REEFUSDT          5m,15m,30m,1h,1w
#                     THETAUSDT                       5m
# 8h,3d,1w            MINAUSDT             5m,15m,30m,2h
#                     RENUSDT                     5m,30m
#
#                                                      uptrend  \
# buyzones            Indicator
#                     CRVUSDT                               1w
#                     PERPUSDT                              1w
#                     RAYUSDT                               1w
# 1d                  GLMRUSDT                       8h,12h,1d
# 1d,3d,1w            BANDUSDT                              1d
#                     COTIUSDT                    8h,12h,1d,1w
#                     OMGUSDT                  8h,12h,1d,3d,1w
#                     VETUSDT                  8h,12h,1d,3d,1w
#                     WINUSDT                     8h,12h,1d,3d
# 1h,1d,3d,1w         XTZUSDT                     8h,12h,1d,3d
# 1h,2h,1w            LINAUSDT                           3d,1w
# 1w                  AUDIOUSDT                8h,12h,1d,3d,1w
#                     BTCUSDT                               3d
#                     RUNEUSDT                           3d,1w
#                     SOLUSDT                            3d,1w
#                     SUSHIUSDT                          3d,1w
# 2h,1d,3d,1w         GALAUSDT                    8h,12h,1d,1w
# 2h,1w               GRTUSDT                               3d
# 2h,3d               FLUXUSDT                              3d
#                     WAXPUSDT                              3d
# 2h,3d,1w            KSMUSDT                     8h,12h,3d,1w
#                     MANAUSDT                    8h,12h,1d,1w
# 2h,8h,1d,3d,1w      ADAUSDT                        8h,12h,1d
# 2h,8h,3d,1w         LINKUSDT                    12h,1d,3d,1w
# 30m,1d,3d,1w        MOVRUSDT                 2h,4h,8h,12h,1d
# 30m,1h,2h           ONEUSDT                       15m,30m,2h
# 30m,1h,2h,1w        FILUSDT                       15m,30m,1w
# 30m,1h,2h,3d        IOTXUSDT                              3d
# 30m,1h,3d,1w        ALGOUSDT             15m,8h,12h,1d,3d,1w
#                     ARUSDT                   8h,12h,1d,3d,1w
# 30m,1w              1INCHUSDT                             1w
#                     XLMUSDT              15m,4h,8h,12h,1d,3d
# 30m,2h,1w           ATOMUSDT                       30m,3d,1w
#                     CAKEUSDT                           8h,3d
# 30m,3d              SRMUSDT                        15m,3d,1w
# 30m,3d,1w           SCRTUSDT                    8h,12h,3d,1w
# 30m,4h,8h,3d,1w     ANKRUSDT   15m,30m,1h,2h,4h,12h,1d,3d,1w
# 30m,8h,1d,1w        ANTUSDT                  2h,4h,12h,1d,1w
# 3d,1w               AVAXUSDT                 8h,12h,1d,3d,1w
#                     CELRUSDT                    8h,12h,3d,1w
#                     DENTUSDT                    8h,12h,1d,3d
#                     DOTUSDT                     8h,12h,1d,1w
#                     FTMUSDT                        12h,3d,1w
#                     LRCUSDT                  8h,12h,1d,3d,1w
#                     MATICUSDT                       1d,3d,1w
#                     NEARUSDT                 8h,12h,1d,3d,1w
#                     ONTUSDT                     8h,12h,1d,3d
#                     ROSEUSDT                    8h,12h,3d,1w
#                     SCUSDT                   8h,12h,1d,3d,1w
#                     ZILUSDT                        8h,12h,3d
# 5m,15m,30m,1d,3d,1w VTHOUSDT              5m,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h    CTSIUSDT                              5m
# 5m,15m,30m,1h,8h,1w TFUELUSDT  5m,15m,30m,1h,4h,8h,12h,3d,1w
# 5m,15m,30m,1w       STORJUSDT                       5m,3d,1w
# 8h,1w               REEFUSDT                       8h,12h,1d
#                     THETAUSDT             4h,8h,12h,1d,3d,1w
# 8h,3d,1w            MINAUSDT              4h,8h,12h,1d,3d,1w
#                     RENUSDT               4h,8h,12h,1d,3d,1w
#
#                                                 dshift  \
# buyzones            Indicator
#                     CRVUSDT            5m,8h,12h,1d,3d
#                     PERPUSDT                 15m,1d,3d
#                     RAYUSDT            5m,4h,8h,12h,3d
# 1d                  GLMRUSDT               5m,4h,3d,1w
# 1d,3d,1w            BANDUSDT              5m,30m,4h,3d
#                     COTIUSDT                 5m,15m,4h
#                     OMGUSDT                      5m,4h
#                     VETUSDT                      5m,4h
#                     WINUSDT                      5m,4h
# 1h,1d,3d,1w         XTZUSDT                         4h
# 1h,2h,1w            LINAUSDT           5m,4h,8h,12h,1d
# 1w                  AUDIOUSDT                    5m,4h
#                     BTCUSDT               4h,8h,12h,1d
#                     RUNEUSDT                 8h,12h,1d
#                     SOLUSDT           5m,30m,4h,8h,12h
#                     SUSHIUSDT         5m,15m,4h,12h,1d
# 2h,1d,3d,1w         GALAUSDT                  5m,4h,3d
# 2h,1w               GRTUSDT            5m,4h,8h,12h,1d
# 2h,3d               FLUXUSDT   5m,15m,30m,4h,8h,12h,1d
#                     WAXPUSDT              4h,8h,12h,1d
# 2h,3d,1w            KSMUSDT                      5m,4h
#                     MANAUSDT                 5m,15m,4h
# 2h,8h,1d,3d,1w      ADAUSDT               5m,15m,4h,3d
# 2h,8h,3d,1w         LINKUSDT                     5m,4h
# 30m,1d,3d,1w        MOVRUSDT                       NaN
# 30m,1h,2h           ONEUSDT                         5m
# 30m,1h,2h,1w        FILUSDT            5m,4h,12h,1d,3d
# 30m,1h,2h,3d        IOTXUSDT              5m,8h,12h,1d
# 30m,1h,3d,1w        ALGOUSDT                     5m,4h
#                     ARUSDT                          4h
# 30m,1w              1INCHUSDT                 5m,4h,3d
#                     XLMUSDT                        NaN
# 30m,2h,1w           ATOMUSDT                        5m
#                     CAKEUSDT                 5m,12h,1d
# 30m,3d              SRMUSDT            5m,4h,8h,12h,1d
# 30m,3d,1w           SCRTUSDT                     5m,4h
# 30m,4h,8h,3d,1w     ANKRUSDT                        5m
# 30m,8h,1d,1w        ANTUSDT                      5m,3d
# 3d,1w               AVAXUSDT                     5m,4h
#                     CELRUSDT                     5m,4h
#                     DENTUSDT                 5m,15m,4h
#                     DOTUSDT                      5m,4h
#                     FTMUSDT                         4h
#                     LRCUSDT                      5m,4h
#                     MATICUSDT                      NaN
#                     NEARUSDT                     5m,4h
#                     ONTUSDT                      5m,4h
#                     ROSEUSDT                     5m,4h
#                     SCUSDT                       5m,4h
#                     ZILUSDT                         4h
# 5m,15m,30m,1d,3d,1w VTHOUSDT                       NaN
# 5m,15m,30m,1h,2h    CTSIUSDT              4h,8h,12h,1d
# 5m,15m,30m,1h,8h,1w TFUELUSDT                      NaN
# 5m,15m,30m,1w       STORJUSDT                4h,8h,12h
# 8h,1w               REEFUSDT                        5m
#                     THETAUSDT               5m,15m,30m
# 8h,3d,1w            MINAUSDT                        1h
#                     RENUSDT                         5m
#
#                                             downtrend                shift
# buyzones            Indicator
#                     CRVUSDT              30m,1h,2h,4h                  NaN
#                     PERPUSDT   5m,30m,1h,2h,4h,8h,12h                  NaN
#                     RAYUSDT                        1d                  15m
# 1d                  GLMRUSDT                30m,1h,2h                  15m
# 1d,3d,1w            BANDUSDT                    1h,2h            15m,8h,1w
#                     COTIUSDT                      30m             1h,2h,3d
#                     OMGUSDT                 30m,1h,2h                  NaN
#                     VETUSDT                       30m            15m,1h,2h
#                     WINUSDT                       30m            15m,1h,1w
# 1h,1d,3d,1w         XTZUSDT                        5m     15m,30m,1h,2h,1w
# 1h,2h,1w            LINAUSDT                      NaN                1h,2h
# 1w                  AUDIOUSDT               30m,1h,2h                  15m
#                     BTCUSDT              5m,30m,1h,2h               15m,1w
#                     RUNEUSDT              5m,1h,2h,4h                  NaN
#                     SOLUSDT                  1h,2h,1d                  NaN
#                     SUSHIUSDT            30m,1h,2h,8h                  NaN
# 2h,1d,3d,1w         GALAUSDT                      30m            15m,1h,2h
# 2h,1w               GRTUSDT                       30m            15m,2h,1w
# 2h,3d               FLUXUSDT                      NaN                1h,2h
#                     WAXPUSDT                   5m,30m         15m,1h,2h,1w
# 2h,3d,1w            KSMUSDT                       30m               15m,2h
#                     MANAUSDT                      30m             1h,2h,3d
# 2h,8h,1d,3d,1w      ADAUSDT                       30m             1h,2h,1w
# 2h,8h,3d,1w         LINKUSDT                      30m         15m,1h,2h,8h
# 30m,1d,3d,1w        MOVRUSDT                       5m     15m,30m,1h,3d,1w
# 30m,1h,2h           ONEUSDT           4h,8h,12h,1d,3d                   1h
# 30m,1h,2h,1w        FILUSDT                       NaN                1h,2h
# 30m,1h,2h,3d        IOTXUSDT                       4h     15m,30m,1h,2h,1w
# 30m,1h,3d,1w        ALGOUSDT                      NaN            30m,1h,2h
#                     ARUSDT                         5m        15m,30m,1h,2h
# 30m,1w              1INCHUSDT         1h,2h,8h,12h,1d              15m,30m
#                     XLMUSDT                        5m         30m,1h,2h,1w
# 30m,2h,1w           ATOMUSDT                       4h                2h,1d
#                     CAKEUSDT                       4h        15m,30m,2h,1w
# 30m,3d              SRMUSDT                       NaN                  30m
# 30m,3d,1w           SCRTUSDT                    1h,2h              15m,30m
# 30m,4h,8h,3d,1w     ANKRUSDT                      NaN                   8h
# 30m,8h,1d,1w        ANTUSDT                       NaN            30m,1h,8h
# 3d,1w               AVAXUSDT                30m,1h,2h                  NaN
#                     CELRUSDT                      30m            15m,1h,2h
#                     DENTUSDT                      30m             1h,2h,1w
#                     DOTUSDT                       NaN               15m,3d
#                     FTMUSDT              5m,30m,1h,2h               15m,8h
#                     LRCUSDT             15m,30m,1h,2h                  NaN
#                     MATICUSDT                  5m,30m         15m,1h,2h,8h
#                     NEARUSDT                      30m            15m,1h,2h
#                     ONTUSDT                 30m,1h,2h                   1w
#                     ROSEUSDT                30m,1h,2h                  15m
#                     SCUSDT                 15m,30m,1h                  NaN
#                     ZILUSDT              5m,30m,1h,2h                   1w
# 5m,15m,30m,1d,3d,1w VTHOUSDT                    1h,2h              15m,30m
# 5m,15m,30m,1h,2h    CTSIUSDT                      NaN  15m,30m,1h,2h,3d,1w
# 5m,15m,30m,1h,8h,1w TFUELUSDT                     NaN                2h,1d
# 5m,15m,30m,1w       STORJUSDT                1h,2h,1d              15m,30m
# 8h,1w               REEFUSDT                  15m,30m                   1w
#                     THETAUSDT                     NaN                1h,2h
# 8h,3d,1w            MINAUSDT            5m,15m,30m,2h                  NaN
#                     RENUSDT                       NaN               15m,1h

# %%
## MACD gap 1 Week stk cross
newframe=callfun(stk1w,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['uptrend'] < '1d') &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['downtrend'].isnull()) ]



test=buyzones(test)
#test=test.loc[test['buyzones']>='1h']
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                                    stkcross                             rsiup  \
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT          15m,1w      30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,3d,1w         LINAUSDT      15m,3d,1w                       1h,2h,3d,1w
# 15m,30m,4h,8h,3d,1w ANKRUSDT   5m,15m,1h,1w  15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15m,30m,1h,2h,1w    FILUSDT      15m,30m,1w                  15m,30m,1h,2h,1w
#
#                                        rsidown             tops     bottoms  \
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT                 5m  1h,2h,4h,12h,3d  15m,30m,1w
# 1h,2h,3d,1w         LINAUSDT   5m,4h,8h,12h,1d        4h,8h,12h  15m,30m,1w
# 15m,30m,4h,8h,3d,1w ANKRUSDT                5m     1h,2h,12h,1d       5m,1w
# 15m,30m,1h,2h,1w    FILUSDT       5m,4h,12h,3d           12h,1d  15m,30m,1w
#
#                               topr bottomr                            stover  \
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT    NaN     NaN         5m,15m,2h,4h,12h,1d,3d,1w
# 1h,2h,3d,1w         LINAUSDT   NaN     NaN         5m,15m,4h,8h,12h,1d,3d,1w
# 15m,30m,4h,8h,3d,1w ANKRUSDT   NaN     NaN  5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 15m,30m,1h,2h,1w    FILUSDT    NaN   3d,1w        5m,15m,30m,4h,12h,1d,3d,1w
#
#                                                        room  \
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT             5m,15m,30m,8h,1d,1w
# 1h,2h,3d,1w         LINAUSDT      5m,15m,30m,1h,2h,1d,3d,1w
# 15m,30m,4h,8h,3d,1w ANKRUSDT         5m,15m,30m,4h,8h,3d,1w
# 15m,30m,1h,2h,1w    FILUSDT    5m,15m,30m,1h,2h,4h,8h,3d,1w
#
#                                                              roomr    stunder  \
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  30m,1h,8h
# 1h,2h,3d,1w         LINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  30m,1h,2h
# 15m,30m,4h,8h,3d,1w ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         8h
# 15m,30m,1h,2h,1w    FILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w   1h,2h,8h
#
#                                                              stkup  \
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT              5m,15m,1h,2h,4h,12h,1d,1w
# 1h,2h,3d,1w         LINAUSDT             5m,15m,4h,8h,12h,1d,3d,1w
# 15m,30m,4h,8h,3d,1w ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15m,30m,1h,2h,1w    FILUSDT                   15m,30m,4h,12h,3d,1w
#
#                                       stkdown                        uptrend  \
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT         30m,8h,3d                2h,4h,12h,1d,1w
# 1h,2h,3d,1w         LINAUSDT        30m,1h,2h                          3d,1w
# 15m,30m,4h,8h,3d,1w ANKRUSDT              NaN  15m,30m,1h,2h,4h,12h,1d,3d,1w
# 15m,30m,1h,2h,1w    FILUSDT    5m,1h,2h,8h,1d                     15m,30m,1w
#
#                                         dshift downtrend      shift
# buyzones            Indicator
# 30m,8h,1d,1w        ANTUSDT              5m,3d       NaN  30m,1h,8h
# 1h,2h,3d,1w         LINAUSDT   5m,4h,8h,12h,1d       NaN      1h,2h
# 15m,30m,4h,8h,3d,1w ANKRUSDT                5m       NaN         8h
# 15m,30m,1h,2h,1w    FILUSDT    5m,4h,12h,1d,3d       NaN      1h,2h

# %%
#hihi5macd1w
## MACD gap 1 Week and rsiup 5 to 4h 
newframe=callfun(rsiup54h,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['downtrend'].isnull()) ]


test=buyzonesa(test)
#test=test.loc[test['buyzones']>='1h']
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
white =  frtolist(test)
print(white)      
wrjson(white,"whitelistfile.json")
# Out:
# ['BUSD/USDT']

# %%
white =  frtolist(higherhi5)
print(white)      
wrjson(white,"hihi5.json")
# Out:
# ['STORJ/USDT', 'THETA/USDT']

# %%
test = newframe.loc[(newframe['Indicator'] == 'BTCUSDT')]
print(test['Indicator'])
# Out:
# Series([], Name: Indicator, dtype: object)

# %% [markdown]
# # Create a function to filter the above
#     - things at the bottom and going up then go  down in timeframes
#     - 1d Bottom
#         - check 12 Bottom either going towards it
#         - At the bottom of 12
#         - Already moved from the bottom of 12
