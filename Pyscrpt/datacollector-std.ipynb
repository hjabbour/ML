# %%
## need to add open close for each time frame ,
## support resistance
##  pivots ,https://towardsdatascience.com/pivot-points-calculation-in-python-for-day-trading-659c1e92d323 
## and write it down each 15 minutes to create data set for AI ML bot 
## bot with GAN or CAN

# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
## choose either white list or read from fix entries 

#fixentries= pd.read_csv('easyband.csv')
#fixentries= pd.read_csv('fixoneasy.csv')
#fixentries= pd.read_csv('fixentries.csv')
fixentries= pd.read_csv('entries.csv')


fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
#whitelist
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')

# %%
#alllist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, ADADOWN/USDT, BOND/USDT, DCR/USDT, DOTDOWN/USDT, GNO/USDT, NBS/USDT, SXPUP/USDT, EOSDOWN/USDT, YFIUP/USDT, RIF/USDT, LTCDOWN/USDT, XLMUP/USDT, YFIDOWN/USDT, LINKDOWN/USDT, TRXUP/USDT, BCHUP/USDT, XTZUP/USDT, SXPDOWN/USDT, UNIDOWN/USDT, XTZDOWN/USDT, BCHDOWN/USDT, TRXDOWN/USDT, XLMDOWN/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
#whitelist =str(fixentries['Indicator'])

startdate = '2020-01-01'
enddate = pd.to_datetime('today')
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']
#intervals = ['8h']

# %%
#print (enddate)

# %%
def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

#Calulate SMA 
def SMA(series,size):
    sma = series.rolling(size).mean()
    return sma
#Calculate SMA55

## MACD 
def MMACD(series,fast=5,slow=35,sig=5):
    ## defaults original f 12, s 26, s9
    exp1 = series.ewm(span=fast, adjust=False).mean()
    exp2 = series.ewm(span=slow, adjust=False).mean()
    macd = exp1-exp2
    signal = macd.ewm(span=sig, adjust=False).mean()
    return macd,signal
## Bottom price 
def FBOTTOMP (series,size):
    bottomp=series.rolling(size).min()
    return bottomp
## top price 
def FTOPP (series,size):
    topp=series.rolling(size).max()
    return topp

# %%
#alllist=alllist.lstrip()
#array = alllist.split(",")
#array = whitelist
array = whitelist
array

wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(symbols,columns =['Indicator'])
final.set_index(['Indicator'],inplace=True)
#final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            dflive=dflive.loc[(dflive.open_time>start)]
            
            if dflive.size > 300 :
                
                
                

                dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
                dflive['RSI'] = FRSI(dflive['c'])
                dflive['STRSI'] = STRSIA(dflive['c'])[0]
                dflive['STRSIK'] = STRSIA(dflive['c'])[1]
                dflive['STRSID'] = STRSIA(dflive['c'])[2]
                dflive['SMA21'] = SMA(dflive['c'],21)
                dflive['SMA55'] = SMA(dflive['c'],55)
                dflive['SMA100'] = SMA(dflive['c'],100)
                dflive['SMA200'] = SMA(dflive['c'],200)
                dflive['MACD'] = MMACD(dflive['c'])[0]
                dflive['MACDSIGNAL'] = MMACD(dflive['c'])[1]
                dflive['BTTOMP'] = FBOTTOMP(dflive['l'],10)
                dflive['TPP'] = FTOPP(dflive['h'],10)


                
                



                #print(dflive)


                lastrow = dflive.iloc[-1]
                beforelast = dflive.iloc[-2]
                row5minus = dflive.iloc[-10]
                O = float(lastrow.o)
                C = float(lastrow.c)
                H = float(lastrow.h)
                L = float(lastrow.l)
                V = float(lastrow.v)
                OM = float(beforelast.o)
                CM = float(beforelast.c)
                HM = float(beforelast.h)
                LM = float(beforelast.l)
                VM = float(beforelast.v)
                RSI = float(lastrow.RSI)
                RSIM = float(beforelast.RSI)
                STRSI = float(lastrow.STRSI)
                STRSIK = float(lastrow.STRSIK)
                STRSIKM = float(beforelast.STRSIK)
                STRSID = float(lastrow.STRSID)
                STRSIDM = float(beforelast.STRSID)
                SMA21 = float(lastrow.SMA21)
                SMA21M = float(beforelast.SMA21)
                SMA55 = float(lastrow.SMA55)
                SMA55M = float(beforelast.SMA55)
                SMA100 = float(lastrow.SMA100)
                SMA100M = float(beforelast.SMA100)
                SMA200 = float(lastrow.SMA200)
                SMA200M = float(beforelast.SMA200)
                MACD = float(lastrow.MACD)
                MACDSIGNAL = float(lastrow.MACDSIGNAL)
                MACDM = float(beforelast.MACD)
                MACDSIGNALM = float(beforelast.MACDSIGNAL)
                BTTOMP = lastrow.BTTOMP
                TPP = lastrow.TPP
                BTTOMPM = row5minus.BTTOMP
                TPPM = row5minus.TPP


                tuple =(symbol,O,C,H,L,V,OM,CM,HM,LM,VM,RSI,RSIM,STRSI,STRSIK,STRSIKM,STRSID,STRSIDM,SMA21,SMA21M,SMA55,SMA55M,SMA100,SMA100M,SMA200,SMA200M,MACD,MACDSIGNAL,MACDM,MACDSIGNALM,BTTOMP,TPP,BTTOMPM,TPPM)
                table.append(tuple)
                #print(table)
                del dflive
            else:
                pass
            #print("name is: ",array[0])


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','O','C','H','L','V','OM','CM','HM','LM','VM','RSI','RSIM','STRSI','STRSIK','STRSIKM','STRSID','STRSIDM','SMA21','SMA21M','SMA55','SMA55M','SMA100','SMA100M','SMA200','SMA200M','MACD','MACDSIGNAL','MACDM','MACDSIGNALM','BOTTOMP','TOPP','BOTTOMPM','TOPPM'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'O':('O'+interval),'OM':('OM'+interval),'C':('C'+interval),'CM':('CM'+interval),'H':('H'+interval),'HM':('HM'+interval),'L':('L'+interval),'LM':('LM'+interval),'V':('V'+interval),'VM':('VM'+interval),'RSI':('RSI'+interval),\
                                 'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSIKM':('STRSIKM'+interval),\
                                 'STRSID':('STRSID'+interval),'STRSIDM':('STRSIDM'+interval),'SMA21':('SMA21'+interval),'SMA21M':('SMA21M'+interval),\
                                 'SMA55':('SMA55'+interval),'SMA55M':('SMA55M'+interval),'SMA100':('SMA100'+interval),'SMA100M':('SMA100M'+interval),\
                                 'SMA200':('SMA200'+interval),'SMA200M':('SMA200M'+interval),'MACD':('MACD'+interval),'MACDSIGNAL':('MACDSIGNAL'+interval),'MACDM':('MACDM'+interval),'MACDSIGNALM':('MACDSIGNALM'+interval),'BOTTOMP':('BOTTOMP'+interval),'TOPP':('TOPP'+interval),'BOTTOMPM':('BOTTOMPM'+interval),'TOPPM':('TOPPM'+interval)})
    #test.set_index(['Indicator'],inplace=True)
    final=final.merge(test,how='left',on=['Indicator'])
    final=final.drop_duplicates(subset='Indicator',keep='last')
    #final.set_index(['Indicator'],inplace=True)

    del test
    ## add the current date column
            
final['Time'] = pd.to_datetime('today')

#final
#final.reset_index(inplace=True)

# %%
#final.Indicator

# %%
import os.path

file_exists = os.path.exists("MLDATATOP"+str(date.today())+".csv")



#final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
#final['Time'] = pd.to_datetime('today')
#final.to_csv("MLDATATOP.csv")
#final.to_csv("MLSTRSIMACDBTTOP.csv")
if file_exists :
    final.to_csv("MLDATATOP"+str(date.today())+".csv", mode='a', index=True, header=False)
else :
    final.to_csv("MLDATATOP"+str(date.today())+".csv")
    
#final.to_csv("MLDATATOP"+str(date.today())+".csv")
## adding to two files the first file i thought there is a column missmatch
#final.to_csv('MLSTRSIMACDBTTOP.csv', mode='a', index=True, header=False)
final.to_csv('MLDATATOP.csv', mode='a', index=True, header=False)
#final.reset_index(inplace=True)

final.head()
# Out:
#    Indicator       O5m       C5m       H5m       L5m        V5m      OM5m  \
# 10  ANKRUSDT   0.03823   0.03823   0.03823   0.03823    9257.10   0.03825
# 21  AVAXUSDT  24.20000  24.22000  24.23000  24.17000    4249.04  24.13000
# 32  WAXPUSDT   0.12510   0.12500   0.12510   0.12500   13986.00   0.12520
# 43  REEFUSDT   0.00424   0.00425   0.00425   0.00424  971243.00   0.00423
# 54  LINKUSDT   8.54000   8.55000   8.55000   8.53000    6505.76   8.55000
#
#         CM5m      HM5m      LM5m  ...  SMA200M1w     MACD1w  MACDSIGNAL1w  \
# 10   0.03826   0.03830   0.03825  ...        NaN  -0.030157     -0.027062
# 21  24.21000  24.22000  24.13000  ...        NaN -29.000136    -21.987524
# 32   0.12500   0.12530   0.12500  ...        NaN  -0.149371     -0.139149
# 43   0.00423   0.00425   0.00422  ...        NaN  -0.007236     -0.007217
# 54   8.54000   8.57000   8.54000  ...        NaN  -7.509753     -7.485612
#
#       MACDM1w  MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w    TOPPM1w  \
# 10  -0.030210      -0.025515    0.02504   0.09761     0.05107    0.10295
# 21 -27.535423     -18.481217   21.35000  98.08000    64.25000  103.62000
# 32  -0.150811      -0.134038    0.08010   0.38560     0.24170    0.39500
# 43  -0.007411      -0.007207    0.00274   0.01257     0.00788    0.01430
# 54  -8.016431      -7.473542    5.53000  18.08000    11.40000   19.54000
#
#                          Time
# 10 2022-06-09 09:27:54.239655
# 21 2022-06-09 09:27:54.239655
# 32 2022-06-09 09:27:54.239655
# 43 2022-06-09 09:27:54.239655
# 54 2022-06-09 09:27:54.239655
#
# [5 rows x 365 columns]

# %%
final.tail()
# Out:
#      Indicator      O5m      C5m      H5m      L5m    V5m     OM5m     CM5m  \
# 546   BANDUSDT  1.68100  1.68100  1.68100  1.68100    0.0  1.67900  1.68100
# 557  1INCHUSDT  0.81900  0.81900  0.81900  0.81900    0.0  0.81900  0.81900
# 568  AUDIOUSDT  0.43500  0.43500  0.43500  0.43500    0.0  0.43600  0.43500
# 579   IOTXUSDT  0.03422  0.03422  0.03422  0.03422    0.0  0.03422  0.03422
# 590   CTSIUSDT  0.23710  0.23710  0.23710  0.23710  843.0  0.23750  0.23720
#
#         HM5m     LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w   MACDM1w  \
# 546  1.68100  1.67900  ...        NaN -2.526403     -2.436434 -2.582067
# 557  0.81900  0.81900  ...        NaN -0.891721     -0.864722 -0.889159
# 568  0.43600  0.43400  ...        NaN -0.593137     -0.533579 -0.598807
# 579  0.03424  0.03419  ...        NaN -0.029561     -0.025377 -0.028904
# 590  0.23750  0.23680  ...        NaN -0.187569     -0.193152 -0.201459
#
#      MACDSIGNALM1w  BOTTOMP1w   TOPP1w  BOTTOMPM1w  TOPPM1w  \
# 546      -2.391450    1.27300  5.58700     3.07600  5.63500
# 557      -0.851222    0.70500  2.00400     1.18100  2.10000
# 568      -0.503801    0.29700  1.82200     0.65300  1.82200
# 579      -0.023285    0.02139  0.10273     0.06206  0.12078
# 590      -0.195944    0.12780  0.50110     0.28170  0.56200
#
#                           Time
# 546 2022-06-09 09:27:54.239655
# 557 2022-06-09 09:27:54.239655
# 568 2022-06-09 09:27:54.239655
# 579 2022-06-09 09:27:54.239655
# 590 2022-06-09 09:27:54.239655
#
# [5 rows x 365 columns]

# %%
HIHI15m = (final['TOPP15m'] > final['TOPPM15m'])
HIHI1h = (final['TOPP1h'] > final['TOPPM1h'])
HIHI2h = (final['TOPP2h'] > final['TOPPM2h'])
HIHI30m = (final['TOPP30m'] > final['TOPPM30m'])
HIHI4h = (final['TOPP4h'] > final['TOPPM4h'])
HIHI5m = (final['TOPP5m'] > final['TOPPM5m'])
HILO15m = (final['BOTTOMP15m'] > final['BOTTOMPM15m'])
HILO1h = (final['BOTTOMP1h'] > final['BOTTOMPM1h'])
HILO2h = (final['BOTTOMP2h'] > final['BOTTOMPM2h'])
HILO30m = (final['BOTTOMP30m'] > final['BOTTOMPM30m'])
HILO4h = (final['BOTTOMP4h'] > final['BOTTOMPM4h'])
HILO5m = (final['BOTTOMP5m'] > final['BOTTOMPM5m'])
LOHI15m = (final['TOPP15m'] < final['TOPPM15m'])
LOHI1h = (final['TOPP1h'] < final['TOPPM1h'])
LOHI2h = (final['TOPP2h'] < final['TOPPM2h'])
LOHI30m = (final['TOPP30m'] < final['TOPPM30m'])
LOHI4h = (final['TOPP4h'] < final['TOPPM4h'])
LOHI5m = (final['TOPP5m'] < final['TOPPM5m'])
LOLO15m = (final['BOTTOMP15m'] < final['BOTTOMPM15m'])
LOLO1h = (final['BOTTOMP1h'] < final['BOTTOMPM1h'])
LOLO2h = (final['BOTTOMP2h'] < final['BOTTOMPM2h'])
LOLO30m = (final['BOTTOMP30m'] < final['BOTTOMPM30m'])
LOLO4h = (final['BOTTOMP4h'] < final['BOTTOMPM4h'])
LOLO5m = (final['BOTTOMP5m'] < final['BOTTOMPM5m'])




MACDCROSS12h =  (final['MACD12h'] > final['MACDSIGNAL12h'])
MACDCROSS1d =  (final['MACD1d'] > final['MACDSIGNAL1d'])
MACDCROSS1w =  (final['MACD1w'] > final['MACDSIGNAL1w'])
MACDCROSS3d =  (final['MACD3d'] > final['MACDSIGNAL3d'])
MACDCROSS4h =  (final['MACD4h'] > final['MACDSIGNAL4h'])
MACDCROSS8h =  (final['MACD8h'] > final['MACDSIGNAL8h'])

MACDD12h = (final['MACD12h'] < final['MACDM12h'])
MACDD1d = (final['MACD1d'] < final['MACDM1d'])
MACDD1w = (final['MACD1w'] < final['MACDM1w'])
MACDD3d = (final['MACD3d'] < final['MACDM3d'])
MACDD4h = (final['MACD4h'] < final['MACDM4h'])
MACDD8h = (final['MACD8h'] < final['MACDM8h'])

MACDGAPD12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) > (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPD1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) > (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPD1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) > (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPD3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) > (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPD4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) > (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPD8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) > (final['MACDM8h'] - final['MACDSIGNALM8h']) )
MACDGAPU12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) < (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPU1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) < (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPU1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) < (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPU3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) < (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPU4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) < (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPU8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) < (final['MACDM8h'] - final['MACDSIGNALM8h']) )

MACDU12h = (final['MACD12h'] > final['MACDM12h'])
MACDU1d = (final['MACD1d'] > final['MACDM1d'])
MACDU1w = (final['MACD1w'] > final['MACDM1w'])
MACDU3d = (final['MACD3d'] > final['MACDM3d'])
MACDU4h = (final['MACD4h'] > final['MACDM4h'])
MACDU8h = (final['MACD8h'] > final['MACDM8h'])

bottom12h = (final['STRSIK12h']< 0.2)
bottom1d = (final['STRSIK1d']< 0.2)
bottom1h = (final['STRSIK1h']< 0.2)
bottom1w = (final['STRSIK1w']< 0.2)
bottom2h = (final['STRSIK2h']< 0.2)
bottom3d = (final['STRSIK3d']< 0.2)
bottom4h = (final['STRSIK4h']< 0.2)
bottom8h = (final['STRSIK8h']< 0.2)
bottom30m = (final['STRSIK30m'] < 0.2)
bottom15m = (final['STRSIK15m'] < 0.2)
bottom5m = (final['STRSIK5m'] < 0.2)

bottomr12h = (final['RSI12h'] < 30)
bottomr1d = (final['RSI1d'] < 30)
bottomr1h = (final['RSI1h'] < 30)
bottomr1w = (final['RSI1w'] < 30)
bottomr2h = (final['RSI2h'] < 30)
bottomr3d = (final['RSI3d'] < 30)
bottomr4h = (final['RSI4h'] < 30)
bottomr8h = (final['RSI8h'] < 30)
bottomr30m = (final['RSI30m'] < 30)
bottomr15m = (final['RSI15m'] < 30)
bottomr5m = (final['RSI5m'] < 30)






room12h = (final['STRSIK12h'] < 0.8)
room1d = (final['STRSIK1d'] < 0.8)
room1h = (final['STRSIK1h'] < 0.8)
room1w = (final['STRSIK1w'] < 0.8)
room2h = (final['STRSIK2h'] < 0.8)
room3d = (final['STRSIK3d'] < 0.8)
room4h = (final['STRSIK4h'] < 0.8)
room8h = (final['STRSIK8h'] < 0.8)
room30m = (final['STRSIK30m'] < 0.8)
room15m = (final['STRSIK15m'] < 0.8)
room5m = (final['STRSIK5m'] < 0.8)


roomr12h = (final['RSI12h'] < 70)
roomr1d = (final['RSI1d'] < 70)
roomr1h = (final['RSI1h'] < 70)
roomr1w = (final['RSI1w'] < 70)
roomr2h = (final['RSI2h'] < 70)
roomr3d = (final['RSI3d'] < 70)
roomr4h = (final['RSI4h'] < 70)
roomr8h = (final['RSI8h'] < 70)
roomr30m = (final['RSI30m'] < 70)
roomr15m = (final['RSI15m'] < 70)
roomr5m = (final['RSI5m'] < 70)


rule12hRSIdown = (final['RSI12h'] < final['RSIM12h'])
rule12hRSIup = (final['RSI12h'] > final['RSIM12h'])
rule12hkdown = (final['STRSIK12h'] < final['STRSIKM12h'])
rule12hkup = (final['STRSIK12h'] > final['STRSIKM12h'])
rule12hover = (final['STRSIK12h'] > final['STRSID12h'])
rule12hunder = (final['STRSIK12h'] < final['STRSID12h'])
rule1hRSIdown = (final['RSI1h'] < final['RSIM1h'])
rule1hRSIup = (final['RSI1h'] > final['RSIM1h'])
rule1dRSIdown = (final['RSI1d'] < final['RSIM1d'])
rule1dRSIup = (final['RSI1d'] > final['RSIM1d'])
rule1dkdown = (final['STRSIK1d']< final['STRSIKM1d'])
rule1dkup = (final['STRSIK1d'] > final['STRSIKM1d'])
rule1dover = (final['STRSIK1d'] > final['STRSID1d'])
rule1dunder = (final['STRSIK1d']< final['STRSID1d'])
rule1hkdown = (final['STRSIK1h']< final['STRSIKM1h'])
rule1hkup = (final['STRSIK1h'] > final['STRSIKM1h'])
rule1hover = (final['STRSIK1h'] > final['STRSID1h'])
rule1hunder = (final['STRSIK1h']< final['STRSID1h'])
rule1wRSIdown = (final['RSI1w'] < final['RSIM1w'])
rule1wRSIup = (final['RSI1w'] > final['RSIM1w'])
rule1wkdown = (final['STRSIK1w']< final['STRSIKM1w'])
rule1wkup = (final['STRSIK1w'] > final['STRSIKM1w'])
rule1wover = (final['STRSIK1w'] > final['STRSID1w'])
rule1wunder = (final['STRSIK1w']< final['STRSID1w'])
rule2hRSIdown = (final['RSI2h'] < final['RSIM2h'])
rule2hRSIup = (final['RSI2h'] > final['RSIM2h'])
rule2hkdown = (final['STRSIK2h']< final['STRSIKM2h'])
rule2hkup = (final['STRSIK2h'] > final['STRSIKM2h'])
rule2hover = (final['STRSIK2h'] > final['STRSID2h'])
rule2hunder = (final['STRSIK2h']< final['STRSID2h'])
rule3dRSIdown = (final['RSI3d'] < final['RSIM3d'])
rule3dRSIup = (final['RSI3d'] > final['RSIM3d'])
rule3dkdown = (final['STRSIK3d']< final['STRSIKM3d'])
rule3dkup = (final['STRSIK3d'] > final['STRSIKM3d'])
rule3dover = (final['STRSIK3d'] > final['STRSID3d'])
rule3dunder = (final['STRSIK3d']< final['STRSID3d'])
rule4hRSIdown = (final['RSI4h'] < final['RSIM4h'])
rule4hRSIup = (final['RSI4h'] > final['RSIM4h'])
rule4hkdown = (final['STRSIK4h']< final['STRSIKM4h'])
rule4hkup = (final['STRSIK4h'] > final['STRSIKM4h'])
rule4hover = (final['STRSIK4h'] > final['STRSID4h'])
rule4hunder = (final['STRSIK4h']< final['STRSID4h'])

rule8hRSIdown = (final['RSI8h'] < final['RSIM8h'])
rule8hRSIup = (final['RSI8h'] > final['RSIM8h'])
rule8hkdown = (final['STRSIK8h']< final['STRSIKM8h'])
rule8hkup = (final['STRSIK8h'] > final['STRSIKM8h'])
rule8hover = (final['STRSIK8h'] > final['STRSID8h'])
rule8hunder = (final['STRSIK8h']< final['STRSID8h'])

rule30mRSIdown = (final['RSI30m'] < final['RSIM30m'])
rule30mRSIup = (final['RSI30m'] > final['RSIM30m'])
rule30mkdown = (final['STRSIK30m']< final['STRSIKM30m'])
rule30mkup = (final['STRSIK30m'] > final['STRSIKM30m'])
rule30mover = (final['STRSIK30m'] > final['STRSID30m'])
rule30munder = (final['STRSIK30m']< final['STRSID30m'])

rule15mRSIdown = (final['RSI15m'] < final['RSIM15m'])
rule15mRSIup = (final['RSI15m'] > final['RSIM15m'])
rule15mkdown = (final['STRSIK15m']< final['STRSIKM15m'])
rule15mkup = (final['STRSIK15m'] > final['STRSIKM15m'])
rule15mover = (final['STRSIK15m'] > final['STRSID15m'])
rule15munder = (final['STRSIK15m']< final['STRSID15m'])

rule5mRSIdown = (final['RSI5m'] < final['RSIM5m'])
rule5mRSIup = (final['RSI5m'] > final['RSIM5m'])
rule5mkdown = (final['STRSIK5m']< final['STRSIKM5m'])
rule5mkup = (final['STRSIK5m'] > final['STRSIKM5m'])
rule5mover = (final['STRSIK5m'] > final['STRSID5m'])
rule5munder = (final['STRSIK5m']< final['STRSID5m'])

shift12h = (rule12hunder & (rule12hkup | rule12hRSIup))
shift1d = (rule1dunder & (rule1dkup | rule1dRSIup))
shift1h = (rule1hunder & (rule1hkup | rule1hRSIup))
shift1w = (rule1wunder & (rule1wkup | rule1wRSIup))
shift2h = (rule2hunder & (rule2hkup | rule2hRSIup))
shift3d = (rule3dunder & (rule3dkup | rule3dRSIup))
shift4h = (rule4hunder & (rule4hkup | rule4hRSIup))
shift8h = (rule8hunder & (rule8hkup | rule8hRSIup))
shift30m = (rule30munder & (rule30mkup | rule30mRSIup))
shift15m = (rule15munder & (rule15mkup | rule15mRSIup))
shift5m = (rule5munder & (rule5mkup | rule5mRSIup))



stk12hcross = (final['STRSIKM12h'] < final['STRSIDM12h']) & (final['STRSIK12h'] > final['STRSID12h'])
stk15mcross = (final['STRSIKM15m'] < final['STRSIDM15m']) & (final['STRSIK15m'] > final['STRSID15m'])
stk1hcross = (final['STRSIKM1h'] < final['STRSIDM1h']) & (final['STRSIK1h'] > final['STRSID1h'])
stk1dcross = (final['STRSIKM1d'] < final['STRSIDM1d']) & (final['STRSIK1d'] > final['STRSID1d'])
stk1wcross = (final['STRSIKM1w'] < final['STRSIDM1w']) & (final['STRSIK1w'] > final['STRSID1w'])
stk2hcross = (final['STRSIKM2h'] < final['STRSIDM2h']) & (final['STRSIK2h'] > final['STRSID2h'])
stk30mcross = (final['STRSIKM30m'] < final['STRSIDM30m']) & (final['STRSIK30m'] > final['STRSID30m'])
stk3dcross = (final['STRSIKM3d'] < final['STRSIDM3d']) & (final['STRSIK3d'] > final['STRSID3d'])
stk4hcross = (final['STRSIKM4h'] < final['STRSIDM4h']) & (final['STRSIK4h'] > final['STRSID4h'])
stk5mcross = (final['STRSIKM5m'] < final['STRSIDM5m']) & (final['STRSIK5m'] > final['STRSID5m'])
stk8hcross = (final['STRSIKM8h'] < final['STRSIDM8h']) & (final['STRSIK8h'] > final['STRSID8h'])

top12h = (final['STRSIK12h'] > 0.8)
top1d = (final['STRSIK1d'] > 0.8)
top1h = (final['STRSIK1h'] > 0.8)
top1w = (final['STRSIK1w'] > 0.8)
top2h = (final['STRSIK2h'] > 0.8)
top3d = (final['STRSIK3d'] > 0.8)
top4h = (final['STRSIK4h'] > 0.8)
top8h = (final['STRSIK8h'] > 0.8)
top30m = (final['STRSIK30m'] > 0.8)
top15m = (final['STRSIK15m'] > 0.8)
top5m = (final['STRSIK5m'] > 0.8)



topr12h = (final['RSI12h'] > 70)
topr1d = (final['RSI1d'] > 70)
topr1h = (final['RSI1h'] > 70)
topr1w = (final['RSI1w'] > 70)
topr2h = (final['RSI2h'] > 70)
topr3d = (final['RSI3d'] > 70)
topr4h = (final['RSI4h'] > 70)
topr8h = (final['RSI8h'] > 70)
topr30m = (final['RSI30m'] > 70)
topr15m = (final['RSI15m'] > 70)
topr5m = (final['RSI5m'] > 70)




uptrend12h = (rule12hover & (rule12hkup & rule12hRSIup))
uptrend1d = (rule1dover & (rule1dkup & rule1dRSIup))
uptrend1h = (rule1hover & (rule1hkup & rule1hRSIup))
uptrend1w = (rule1wover & (rule1wkup & rule1wRSIup))
uptrend2h = (rule2hover & (rule2hkup & rule2hRSIup))
uptrend3d = (rule3dover & (rule3dkup & rule3dRSIup))
uptrend4h = (rule4hover & (rule4hkup & rule4hRSIup))
uptrend8h = (rule8hover & (rule8hkup & rule8hRSIup))
uptrend30m = (rule30mover & (rule30mkup & rule30mRSIup))
uptrend15m = (rule15mover & (rule15mkup & rule15mRSIup))
uptrend5m = (rule5mover & (rule5mkup & rule5mRSIup))




downtrend12h = (rule12hunder & (rule12hkdown & rule12hRSIdown))
downtrend1d = (rule1dunder & (rule1dkdown & rule1dRSIdown))
downtrend1h = (rule1hunder & (rule1hkdown & rule1hRSIdown))
downtrend1w = (rule1wunder & (rule1wkdown & rule1wRSIdown))
downtrend2h = (rule2hunder & (rule2hkdown & rule2hRSIdown))
downtrend3d = (rule3dunder & (rule3dkdown & rule3dRSIdown))
downtrend4h = (rule4hunder & (rule4hkdown & rule4hRSIdown))
downtrend8h = (rule8hunder & (rule8hkdown & rule8hRSIdown))
downtrend30m = (rule30munder & (rule30mkdown & rule30mRSIdown))
downtrend15m = (rule15munder & (rule15mkdown & rule15mRSIdown))
downtrend5m = (rule5munder & (rule5mkdown & rule5mRSIdown))


dshift12h = (rule12hover & (rule12hkdown | rule12hRSIdown))
dshift1d = (rule1dover & (rule1dkdown | rule1dRSIdown))
dshift1h = (rule1hover & (rule1hkdown | rule1hRSIdown))
dshift1w = (rule1wover & (rule1wkdown | rule1wRSIdown))
dshift2h = (rule2hover & (rule2hkdown | rule2hRSIdown))
dshift3d = (rule3dover & (rule3dkdown | rule3dRSIdown))
dshift4h = (rule4hover & (rule4hkdown | rule4hRSIdown))
dshift8h = (rule8hover & (rule8hkdown | rule8hRSIdown))
dshift30m = (rule30mover & (rule30mkdown | rule30mRSIdown))
dshift15m = (rule15mover & (rule15mkdown | rule15mRSIdown))
dshift5m = (rule5mover & (rule5mkdown | rule5mRSIdown))

# %%
wshift = final.loc[shift1w]
wshift
# Out:
#     Indicator      O5m      C5m      H5m      L5m      V5m     OM5m     CM5m  \
# 196   IMXUSDT  0.96800  0.96900  0.97000  0.96800  3986.41  0.96900  0.96800
# 239  CAKEUSDT  4.43600  4.43800  4.43800  4.43500   874.63  4.43500  4.43500
# 579  IOTXUSDT  0.03422  0.03422  0.03422  0.03422     0.00  0.03422  0.03422
#
#         HM5m     LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w   MACDM1w  \
# 196  0.97200  0.96600  ...        NaN -0.577477     -0.636937 -0.607977
# 239  4.43800  4.43400  ...        NaN -4.610391     -4.414282 -4.661598
# 579  0.03424  0.03419  ...        NaN -0.029561     -0.025377 -0.028904
#
#      MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w   TOPPM1w  \
# 196      -0.666667    0.74800   1.20000     0.67500   2.13000
# 239      -4.316227    3.28800  10.99000     5.30000  10.99000
# 579      -0.023285    0.02139   0.10273     0.06206   0.12078
#
#                           Time
# 196 2022-06-09 09:27:54.239655
# 239 2022-06-09 09:27:54.239655
# 579 2022-06-09 09:27:54.239655
#
# [3 rows x 365 columns]

# %% [markdown]
# # Summary  draft rules

# %%
#final.reset_index(inplace=True)

#final.set_index(['Indicator'],inplace=True)

# drop = final.loc[bottom4h & (shift4h | rule4over)]
#drop = final.loc[(bottom4h | (uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[((uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[(uptrend8h | shift8h) & (uptrend12h | shift12h) & (uptrend1d | shift1d)]
#drop = final.loc[(uptrend2h | shift2h) & (uptrend4h | shift4h) ]
#drop = final.loc[(uptrend4h | shift4h)]

#drop = final.loc[bottom8h | (shift8h | rule8over)]
#drop = final.loc[bottom12h | (shift12h | rule12over)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[bottom12h | (shift12h | uptrend12h)]
#drop = final.loc[bottom1d | (shift1d | uptrend1d)]
#drop = final.loc[top4h]
#drop = final.loc[(uptrend3d)]
#drop = final.loc[dshift4h]
#drop = final.loc[shift2h]

#drop = final.loc[(bottom4h & bottom12h & bottom3d)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[(downtrend8h & downtrend4h & downtrend12h)]
#drop = final.loc[(bottom4h & bottom2h & bottom3d)]
#drop = final.loc[shift3d & bottom4h]

#drop = final.loc[(bottom12h)]
#drop = final.loc[ ((rule4kup |rule4RSIup))]

#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend4h | shift4h) ]
#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) ]

# 4 hours will go down or slow down
#drop = final.loc[( (bottom3d) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) & dshift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) &  (uptrend2h | shift2h) &  (uptrend1h | shift1h)]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]

#drop = final.loc[( (bottom4h) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h)) ]
#drop = final.loc[((bottom1d) & (bottom3d))]
#drop = drop.loc[( (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h))]
#drop = final.loc[dshift4h]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) & (downtrend2h |dshift2h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[dshift2h]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h) & (bottom2h))]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h))]

#drop= final.loc[(shift4h) & (shift12h)]
#drop = final.loc[(dshift4h | downtrend4h)]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (dshift4h | downtrend4h))]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (shift2h))]

#drop = final.loc[downtrend1d & downtrend12h & downtrend8h & downtrend4h]
#drop = final.loc[top8h]

#drop



    

#bottomtable['bottoms'] = bottomtable.apply(get_key(listb,bottomtable.loc('Indicator'),axis=1)

#bottomtable
#reversetable
#bottomstable = pd.DataFrame(reversetable,columns=['Indicator','Bottoms'])
#print (bottomstable)
#listb
#listd = pd.DataFrame(listb,columns=['Bottoms','Indicator'])
#print (listb)
#print(reversetable)
#listd.head()
#test = final.loc[(MACDGAP3d)]
test = final.loc[(MACDCROSS3d)]
test = final.loc[(MACDCROSS1d)]
test = final.loc[(MACDGAPU3d)]
test = final.loc[(MACDGAPD3d)& rule3dover & rule3dRSIup]
#macd3d = final.loc[(MACDGAPU3d)& rule3dRSIup]
macd1d = final.loc[(MACDGAPD1d)& rule1dRSIup]
macd3du = final.loc[(MACDGAPU3d)]
macd3dd = final.loc[(MACDGAPD3d)]
macd1du = final.loc[(MACDGAPU1d)]
macd1dd = final.loc[(MACDGAPD1d)]
macd1wu = final.loc[(MACDGAPU1w)]
macd1wd = final.loc[(MACDGAPD1w)]

macd3d1d = final.loc[(MACDGAPD1d &  (MACDGAPD3d)  & rule3dRSIup & rule1dRSIup )]
macd1dcross = final.loc[MACDCROSS1d]
macd12hcross = final.loc[MACDCROSS12h]
macd8hcross = final.loc[MACDCROSS8h]
macd4hcross = final.loc[MACDCROSS4h]
macd3dcross = final.loc[MACDCROSS3d]
stk3d = final.loc[stk3dcross]
stk1w = final.loc[stk1wcross]
macd3dd
#macd12hcross
#macd12hcross
#macd4hcross
#macd3d1d
#macd1d
#pmacdu = macd3du[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdu['diff']=abs(macd3du['MACD3d'])-abs(macd3du['MACDSIGNAL3d'])
#pmacdu['diffm']=abs(macd3du['MACDM3d'])-abs(macd3du['MACDSIGNALM3d'])

#pmacdd = macd3dd[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdd['diff']=abs(macd3dd['MACD3d'])-abs(macd3dd['MACDSIGNAL3d'])
#pmacdd['diffm']=abs(macd3dd['MACDM3d'])-abs(macd3dd['MACDSIGNALM3d'])
#final.set_index(['Indicator'],inplace=True)

#final.reset_index(inplace=True)
test1h = final[['Indicator','BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]
#test1h = final[['BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]

test15 = final[['Indicator','BOTTOMP15m','BOTTOMPM15m','TOPP15m','TOPPM15m']]
#test15.set_index(['Indicator'],inplace=True)
test5 = final[['Indicator','BOTTOMP5m','BOTTOMPM5m','TOPP5m','TOPPM5m']]
test30 = final[['Indicator','BOTTOMP30m','BOTTOMPM30m','TOPP30m','TOPPM30m']]
#test30.set_index(['Indicator'],inplace=True)

test2h = final[['Indicator','BOTTOMP2h','BOTTOMPM2h','TOPP2h','TOPPM2h']]

test4h = final[['Indicator','BOTTOMP4h','BOTTOMPM4h','TOPP4h','TOPPM4h']]

#final.set_index(['Indicator'],inplace=True)

higherhi = test15.loc[HIHI15m & HILO15m]
#higherhi = test30.loc[HIHI30m & HILO30m]
#higherhi = test1h.loc[HIHI1h & HILO1h]
#higherhi = test2h.loc[HIHI2h & HILO2h]

#higherhi = test4h.loc[HIHI4h & HILO4h]

lowhi = test15.loc[LOHI15m & LOLO15m]
lowhi = test5.loc[LOHI5m & LOLO5m]
#lowhi = test1h.loc[LOHI1h & LOLO1h]
lowhi = test30.loc[LOHI30m & LOLO30m]
lowhi = test2h.loc[LOHI2h & LOLO2h]
lowhi = test4h.loc[LOHI4h & LOLO4h]

higherhi5 = test5.loc[HIHI5m & HILO5m]
higherhi2 = test2h.loc[HIHI2h & HILO2h]
higherhi4 = test4h.loc[HIHI4h & HILO4h]


#higherhi = test15.loc[HIHI15m ]
#higherhi = test.loc[HIHI1h]
#higherhi = test5.loc[HIHI5m ]
#higherlo = test5.loc[HILO5m ]
#higherlo = test15.loc[HILO15m ]


higherhi
stk3d
macd3dd
macd1wd
#macd3dd
#macd1dd
#macd1du
#lowhi
hihi5macd1w=macd1wd.loc[HIHI5m & HILO5m &rule1hRSIup &room1h & rule2hRSIup & room2h]
hihi5macd1w
#higherhi5
# Out:
#      Indicator       O5m       C5m       H5m       L5m         V5m      OM5m  \
# 10    ANKRUSDT  0.038230  0.038230  0.038230  0.038230      9257.1  0.038250
# 109    ZRXUSDT  0.397100  0.396900  0.397100  0.396900      1382.0  0.396400
# 120    XTZUSDT  2.110000  2.112000  2.114000  2.110000      5942.2  2.108000
# 153    WINUSDT  0.000157  0.000157  0.000157  0.000157  62251848.0  0.000157
# 228  SUSHIUSDT  1.496000  1.497000  1.498000  1.495000      7722.0  1.494000
# 316   VTHOUSDT  0.001858  0.001858  0.001858  0.001858     18804.0  0.001857
# 381   GLMRUSDT  1.278800  1.282800  1.284200  1.278700      7912.1  1.278100
# 392   COTIUSDT  0.139600  0.139600  0.140000  0.139000    129224.0  0.139200
# 436   CELRUSDT  0.017690  0.017700  0.017700  0.017690     56497.1  0.017660
# 447    ONTUSDT  0.299600  0.299600  0.299600  0.299600         0.0  0.299600
# 458   GALAUSDT  0.077010  0.076970  0.077010  0.076950     38409.0  0.076930
# 469    GRTUSDT  0.147700  0.147700  0.147700  0.147700      5147.0  0.147600
# 491    ZILUSDT  0.049320  0.049320  0.049320  0.049320         0.0  0.049270
# 557  1INCHUSDT  0.819000  0.819000  0.819000  0.819000         0.0  0.819000
#
#          CM5m      HM5m      LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w  \
# 10   0.038260  0.038300  0.038250  ...        NaN -0.030157     -0.027062
# 109  0.396700  0.397200  0.396400  ...        NaN -0.244257     -0.206823
# 120  2.110000  2.112000  2.108000  ...        NaN -1.249399     -1.221599
# 153  0.000157  0.000157  0.000157  ...        NaN -0.000166     -0.000161
# 228  1.496000  1.496000  1.494000  ...        NaN -2.994552     -3.063953
# 316  0.001858  0.001858  0.001857  ...        NaN -0.002465     -0.002379
# 381  1.278500  1.280700  1.271300  ...        NaN -1.684689     -1.844918
# 392  0.139600  0.139600  0.139100  ...        NaN -0.103644     -0.100216
# 436  0.017680  0.017690  0.017640  ...        NaN -0.028372     -0.026308
# 447  0.299600  0.299700  0.299300  ...        NaN -0.261490     -0.251963
# 458  0.076990  0.077070  0.076880  ...        NaN -0.099764     -0.087225
# 469  0.147700  0.147900  0.147600  ...        NaN -0.283381     -0.272855
# 491  0.049320  0.049380  0.049270  ...        NaN -0.018844     -0.011819
# 557  0.819000  0.819000  0.819000  ...        NaN -0.891721     -0.864722
#
#       MACDM1w  MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w   TOPPM1w  \
# 10  -0.030210      -0.025515   0.025040  0.097610    0.051070  0.102950
# 109 -0.236902      -0.188106   0.296500  1.183800    0.450000  0.950000
# 120 -1.315792      -1.207699   1.451000  4.042000    2.560000  4.606000
# 153 -0.000171      -0.000158   0.000131  0.000371    0.000243  0.000418
# 228 -3.095903      -3.098654   1.082000  4.475000    2.753000  5.086000
# 316 -0.002494      -0.002336   0.001389  0.005384    0.002738  0.007077
# 381 -1.768300      -1.925033   1.050000  1.793800    1.050000  4.500000
# 392 -0.111547      -0.098501   0.084100  0.340000    0.170800  0.340000
# 436 -0.028599      -0.025276   0.010830  0.070250    0.030890  0.084370
# 447 -0.269535      -0.247200   0.190800  0.672100    0.424400  0.703500
# 458 -0.099386      -0.080955   0.049350  0.266610    0.177960  0.395800
# 469 -0.286322      -0.267593   0.118000  0.517400    0.302300  0.550700
# 491 -0.017098      -0.008307   0.039990  0.164110    0.033170  0.230700
# 557 -0.889159      -0.851222   0.705000  2.004000    1.181000  2.100000
#
#                           Time
# 10  2022-06-09 09:27:54.239655
# 109 2022-06-09 09:27:54.239655
# 120 2022-06-09 09:27:54.239655
# 153 2022-06-09 09:27:54.239655
# 228 2022-06-09 09:27:54.239655
# 316 2022-06-09 09:27:54.239655
# 381 2022-06-09 09:27:54.239655
# 392 2022-06-09 09:27:54.239655
# 436 2022-06-09 09:27:54.239655
# 447 2022-06-09 09:27:54.239655
# 458 2022-06-09 09:27:54.239655
# 469 2022-06-09 09:27:54.239655
# 491 2022-06-09 09:27:54.239655
# 557 2022-06-09 09:27:54.239655
#
# [14 rows x 365 columns]

# %% [markdown]
# # Functions

# %%
#DRAFT functions display
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        

## return a list of timeframes per ta indicator taname  for specific sympbol
#series to list 
def srtolist(final:pd,taname)->[]:
    #ta = globals()[taname]
    array = final[taname].values
    array= str(array[0]).split(",")
    
    #for k in range(0,len(array)):
            #print (k)
            #print (f" {taname} = {array[k]} \n")
    return array

# list to string 
def ltos (mylist)->str:
    mystring = ''
    for x in mylist:
        if not mystring:
            mystring+=x
        else:
            mystring+=","+x
    return mystring

def get_key(my_dict,val):
        keylist = []
        for key, value in my_dict.items():
             if val in value:
                keylist.append(key)
        return keylist
    
def to_df(final:pd ,func,name):
    listb = func(final)
    res = list(sorted({ele for val in listb.values() for ele in val}))
    reversetable = []
    for indi in res:
        ttuple = (indi,ltos(get_key(listb,indi)))
        reversetable.append(ttuple)
    dframe = pd.DataFrame(reversetable,columns=['Indicator',name])
    return dframe
                                                
    
def tops(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['top'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : query.append(i)
        toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def uptrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['uptrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def downtrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['downtrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def shift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['shift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def dshift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['dshift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def topr(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['topr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['bottomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottoms(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    bottomlist ={}
    for i in intervals:
        var = globals()['bottom'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            bottomlist[i]=test['Indicator'].tolist()
 
    return bottomlist

def room(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['room'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def roomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['roomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsiup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsidown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']         
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stover(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'over']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stunder(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'under']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkdown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def stkcross(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['stk'+i+'cross']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    
    return toplist


def buyzones(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        for item in lrsiup :
            if item in lroomr:
                if item in lroom:
                    buy.append(item)
                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final
  

def buyzonesa(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        buyindex = []
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        lrsidown= srtolist(test1,'rsidown')
        lstkup= srtolist(test1,'stkup')
        
        for item in lrsiup :
            if item in lroomr:
                if item in lroom:
                    buy.append(item)
        for item in buy:
            #print(item)
            #print(intervals.index(item))
            buyindex.append(intervals.index(item))
        
        for l,n in zip(buy,buyindex):
            if intervals[n]=='1w':
                if intervals[n-1] in lrsidown:
                    buy.remove(l)
                continue
            if intervals[n]=='5m':
                if intervals[n+1] not in lroomr:
                    buy.remove(l)
                continue
            if intervals[n+1] not in lroomr:
                buy.remove(l)
                continue
            if intervals[n-1] in lrsidown:
                buy.remove(l)
                continue
            
                
            #print(f"buy ={l} index={intervals[n+1]}")                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final  


#not used but defined for later 
def mergetables(final:pd,*arg)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(arg)):
        test = indicators.merge(arg[i] ,how="left",on="Indicator")
        indicators = test
    return test

# call the function and merge the tables 
def callfun(final:pd,*var)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(var)):
        test=to_df(final ,globals()[var[i]],var[i])
        indicators=indicators.merge(test ,how="left",on="Indicator")
    return indicators


def wrjson(wl,name):
    test = json.dumps(wl)
    with open(name, "w") as wlf:
        json.dump(test, wlf,indent=4)
        
def frtolist(final:pd)->[]:
    whitelist = []
    wl = []
    whitelist = final['Indicator'].tolist()
    for i in range(0 ,len(whitelist)):
        #print (str(whitelist[i].replace('USDT',"/USDT")))
        wl.append(str(whitelist[i].replace('USDT',"/USDT")))
    if len(wl)==0:
        wl.append('BUSD/USDT')
    return wl

# %%
newframe=callfun(final,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','shift'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['rsiup','bottoms','bottomr'],ascending=[False,False,False])

newframe.to_csv("allindi"+str(date.today())+".csv")

test = newframe.loc[(newframe['downtrend'] <= '1h')]
test = newframe.loc[(newframe['bottomr'] >= '12h')]
#test = newframe.loc[(newframe['rsidown'] >= '2h')]
#test = newframe.loc[(newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '2h,4h') & (newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '12h') & (newframe['bottomr'] >= '1') ]
#test = newframe.loc[(newframe['bottomr'] >= '1') & (newframe['rsiup'] >= '1')]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['rsidown'].notnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['shift'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['rsidown'].isnull()) & (newframe['tops'] <='4h') & (newframe['topr'].isnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['topr'].isnull()) ]

#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['topr'].isnull()) & (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['stkdown'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') ]
#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['uptrend'].notnull()) ]

#test = newframe.loc[(newframe['shift'].isnull()) &  (newframe['uptrend'].isnull()) ]

#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]
#test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]

#test = newframe.loc[(newframe['rsiup'].notnull()) & (newframe['bottoms'].notnull())  & (newframe['uptrend'].notnull())]


test = newframe.loc[(newframe['rsiup'] <= '8h') & (newframe['bottoms'].notnull())]

test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['stover'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['bottoms'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull())]

test = newframe.loc[(newframe['rsiup'] >= '1h,2h,4h') ]


#test = newframe.loc[(newframe['bottomr'] <= '12h') &  (newframe['bottoms'] <= '12h') ]
#test = newframe.loc[(newframe['bottomr'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]
#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkup'].notnull()))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]

#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h'))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h')) & (newframe['bottomr'].notnull())]




#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[(newframe['tops'].isnull()) &  (newframe['rsidown'].isnull()) ]


#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]

#test = newframe.loc[(newframe['rsiup'] <= '1w') & (newframe['bottoms'] >= '4h') &  (newframe['shift'].notnull())]


#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['rsidown'].isnull()) | (newframe['rsidown'] <= '1') ]

#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) & (newframe['downtrend'].isnull()) ]
#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) ]

#test = newframe.loc[(newframe['shift'] >= '12h,1d,3d')]

newframe

test
# Out:
#     Indicator      stkcross                                rsiup  \
# 33  TFUELUSDT    15m,30m,4h         5m,30m,1h,2h,4h,8h,12h,1d,1w
# 4    LINKUSDT            1h                         5m,30m,1h,1w
# 17    IMXUSDT      2h,4h,8h             5m,2h,4h,8h,12h,1d,3d,1w
# 11    KSMUSDT            8h                     5m,15m,8h,12h,1d
# 21   CAKEUSDT           30m                  5m,15m,30m,1h,4h,1w
# 6    ATOMUSDT           NaN        5m,15m,30m,1h,2h,8h,12h,1d,3d
# 13    WINUSDT            2h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 10    XTZUSDT        8h,12h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 18   SCRTUSDT         5m,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12   NEARUSDT  15m,2h,4h,1w     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 31   ROSEUSDT            4h     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 32   MOVRUSDT      5m,2h,1d     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 34   GLMRUSDT        2h,12h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 27    SRMUSDT        15m,4h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 37    VETUSDT      2h,4h,1w        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 7     MIRUSDT        12h,1d        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 25   LINAUSDT     15m,2h,1w               5m,15m,30m,1h,2h,4h,1w
# 5      ARUSDT            2h               5m,15m,30m,1h,2h,4h,1w
# 1    AVAXUSDT           NaN               5m,15m,30m,1h,2h,4h,1w
# 3    REEFUSDT            2h                  5m,15m,30m,1h,2h,4h
# 20  SUSHIUSDT            4h                  5m,15m,30m,1h,2h,4h
# 9     ZRXUSDT           NaN                  5m,15m,30m,1h,2h,4h
# 39   CELRUSDT            4h                  5m,15m,30m,1h,2h,4h
# 8    ALGOUSDT            1w                     5m,15m,30m,1h,1w
# 53   CTSIUSDT           NaN               30m,1h,8h,12h,1d,3d,1w
# 29    ANTUSDT           NaN                  30m,1h,8h,12h,1d,1w
# 45    FILUSDT           NaN                     30m,1h,8h,12h,1d
# 50  1INCHUSDT            2h            30m,1h,2h,4h,8h,12h,1d,3d
# 28   VTHOUSDT            2h               30m,1h,2h,4h,8h,12h,1d
# 2    WAXPUSDT            4h                         30m,1h,2h,4h
# 23    HNTUSDT            8h                2h,4h,8h,12h,1d,3d,1w
# 19    RENUSDT            1w                   2h,4h,8h,12h,1d,1w
#
#                    rsidown             tops          bottoms topr   bottomr  \
# 33                      3d        5m,15m,1d               1w  NaN        3d
# 4   15m,2h,4h,8h,12h,1d,3d     5m,12h,1d,3d     30m,1h,2h,1w  NaN       NaN
# 17                     15m          15m,30m               8h  NaN       NaN
# 11             2h,4h,3d,1w           30m,1h            8h,1w  NaN       NaN
# 21            8h,12h,1d,3d            5m,1d            2h,1w  NaN       NaN
# 6                       1w        5m,30m,1h               1w  NaN        3d
# 13                     NaN           30m,1d            2h,1w  NaN       NaN
# 10                     NaN        15m,1d,3d               1w  NaN       NaN
# 18                     NaN     30m,1h,2h,4h         1d,3d,1w  NaN  1d,3d,1w
# 12                      1w          15m,30m  4h,8h,12h,3d,1w  NaN       NaN
# 31                      1w       15m,30m,1h               1w  NaN        3d
# 32                      1w        5m,15m,4h              NaN  NaN     3d,1w
# 34                   3d,1w          15m,30m               8h  NaN     3d,1w
# 27                   3d,1w          15m,30m            3d,1w  NaN        3d
# 37                   3d,1w       5m,15m,30m               1w  NaN       NaN
# 7                    3d,1w              NaN        12h,1d,1w  NaN     3d,1w
# 25            8h,12h,1d,3d   15m,30m,12h,1d            2h,1w  NaN       NaN
# 5             8h,12h,1d,3d     5m,8h,12h,1d            2h,1w  NaN       NaN
# 1             8h,12h,1d,3d        5m,15m,1d               1w  NaN        3d
# 3          8h,12h,1d,3d,1w           15m,1d        8h,12h,1w  NaN        3d
# 20            8h,12h,3d,1w       5m,15m,30m        8h,12h,1w   5m       NaN
# 9          8h,12h,1d,3d,1w       5m,15m,30m         4h,8h,1w  NaN       NaN
# 39         8h,12h,1d,3d,1w       5m,15m,30m     4h,8h,12h,1w  NaN       NaN
# 8       2h,4h,8h,12h,1d,3d     4h,8h,12h,1d               1w  NaN       NaN
# 53            5m,15m,2h,4h         8h,1d,3d           15m,1w  NaN       NaN
# 29               5m,15m,3d          15m,30m            2h,1w  NaN       NaN
# 45            5m,15m,3d,1w              30m         8h,3d,1w  NaN     3d,1w
# 50                      1w          15m,30m     8h,12h,1d,1w  NaN       NaN
# 28                   3d,1w       5m,15m,30m            2h,1w  NaN       NaN
# 2      15m,8h,12h,1d,3d,1w       5m,15m,30m        8h,12h,1w  NaN       NaN
# 23           5m,15m,30m,1h  1h,2h,12h,1d,3d            5m,1w   8h       NaN
# 19                  5m,15m       15m,30m,1d            2h,1w  NaN       NaN
#
#                               stover                                 room  \
# 33        5m,15m,30m,1h,4h,12h,3d,1w            30m,1h,2h,4h,8h,12h,3d,1w
# 4            5m,15m,30m,1h,12h,3d,1w               15m,30m,1h,2h,4h,8h,1w
# 17                5m,30m,1h,2h,4h,8h          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 11             5m,1h,2h,4h,8h,12h,3d         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 21           5m,15m,30m,1h,4h,12h,3d        15m,30m,1h,2h,4h,8h,12h,3d,1w
# 6             5m,15m,1h,2h,4h,12h,3d            15m,2h,4h,8h,12h,1d,3d,1w
# 13     5m,15m,30m,1h,2h,12h,1d,3d,1w         5m,15m,1h,2h,4h,8h,12h,3d,1w
# 10         30m,1h,4h,8h,12h,1d,3d,1w            5m,30m,1h,2h,4h,8h,12h,1w
# 18       5m,1h,2h,4h,8h,12h,1d,3d,1w               5m,15m,8h,12h,1d,3d,1w
# 12            15m,30m,1h,2h,4h,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 31            15m,30m,1h,2h,4h,3d,1w             5m,2h,4h,8h,12h,1d,3d,1w
# 32  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d            30m,1h,2h,8h,12h,1d,3d,1w
# 34            30m,1h,2h,4h,12h,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 27            5m,15m,30m,1h,2h,4h,3d          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 37         5m,15m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 7           5m,1h,2h,4h,8h,12h,1d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 25         5m,15m,30m,1h,2h,1d,3d,1w                 5m,1h,2h,4h,8h,3d,1w
# 5          5m,30m,1h,2h,12h,1d,3d,1w               15m,30m,1h,2h,4h,3d,1w
# 1         5m,15m,30m,1h,4h,12h,3d,1w            30m,1h,2h,4h,8h,12h,3d,1w
# 3             5m,15m,30m,1h,2h,3d,1w         5m,30m,1h,2h,4h,8h,12h,3d,1w
# 20         5m,15m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 9                5m,15m,30m,1h,2h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 39                   30m,1h,2h,4h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 8           5m,1h,4h,8h,12h,1d,3d,1w               5m,15m,30m,1h,2h,3d,1w
# 53                    5m,2h,1d,3d,1w           5m,15m,30m,1h,2h,4h,12h,1w
# 29             5m,1h,2h,12h,1d,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 45                      15m,1h,2h,3d      5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 50                     15m,30m,1h,2h          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 28              15m,30m,1h,2h,12h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 2              5m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 23          1h,2h,4h,8h,12h,1d,3d,1w                  5m,15m,30m,4h,8h,1w
# 19                1h,2h,12h,1d,3d,1w             5m,1h,2h,4h,8h,12h,3d,1w
#
#                                   roomr                stunder  \
# 33  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w               2h,8h,1d
# 4   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w            2h,4h,8h,1d
# 17  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       15m,12h,1d,3d,1w
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,1d
# 21  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w            2h,8h,1d,1w
# 6   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           30m,8h,1d,1w
# 13  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                  4h,8h
# 10  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              5m,15m,2h
# 18  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                15m,30m
# 12  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,8h,12h,1d
# 31  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,8h,12h,1d
# 32  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                    NaN
# 34  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,15m,8h,1d
# 27  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           8h,12h,1d,1w
# 37  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 7   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,3d
# 25  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              4h,8h,12h
# 5   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              15m,4h,8h
# 1   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w               2h,8h,1d
# 3   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           4h,8h,12h,1d
# 20     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 9   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w        4h,8h,12h,1d,1w
# 39  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           8h,12h,1d,1w
# 8   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,2h
# 53  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w   15m,30m,1h,4h,8h,12h
# 29  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w          15m,30m,4h,8h
# 45  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w    5m,30m,4h,8h,12h,1d
# 50  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,4h,8h,12h,1d,3d,1w
# 28  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         5m,4h,8h,1d,1w
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w          15m,8h,12h,1d
# 23     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w             5m,15m,30m
# 19  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       5m,15m,30m,4h,8h
#
#                                stkup                  stkdown  \
# 33        15m,30m,1h,2h,4h,12h,3d,1w                 5m,8h,1d
# 4                   15m,30m,1h,3d,1w       5m,2h,4h,8h,12h,1d
# 17               30m,1h,2h,4h,8h,12h          5m,15m,1d,3d,1w
# 11             5m,1h,2h,4h,8h,12h,3d               15m,30m,1d
# 21                  15m,30m,1h,4h,3d       5m,2h,8h,12h,1d,1w
# 6                    15m,2h,4h,8h,3d                   12h,1d
# 13      5m,30m,1h,2h,4h,12h,1d,3d,1w                   15m,8h
# 10         30m,1h,2h,8h,12h,1d,3d,1w                    5m,4h
# 18      5m,30m,2h,4h,8h,12h,1d,3d,1w                      15m
# 12               15m,30m,1h,2h,4h,3d             5m,8h,12h,1d
# 31             5m,30m,1h,2h,4h,3d,1w                8h,12h,1d
# 32  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d                       1w
# 34                 1h,2h,4h,8h,3d,1w            5m,15m,12h,1d
# 27            5m,15m,30m,1h,2h,4h,3d                8h,12h,1d
# 37                5m,30m,1h,2h,4h,1w             8h,12h,1d,3d
# 7       5m,30m,1h,2h,4h,8h,12h,1d,1w                   15m,3d
# 25         5m,15m,30m,1h,2h,1d,3d,1w                4h,8h,12h
# 5              5m,30m,1h,2h,1d,3d,1w                4h,8h,12h
# 1                    30m,1h,4h,3d,1w             2h,8h,12h,1d
# 3                15m,30m,1h,2h,3d,1w             4h,8h,12h,1d
# 20             5m,30m,1h,2h,4h,3d,1w                8h,12h,1d
# 9             5m,15m,30m,1h,2h,4h,3d             8h,12h,1d,1w
# 39                   30m,1h,2h,4h,3d             8h,12h,1d,1w
# 8               15m,30m,4h,12h,3d,1w           5m,1h,2h,8h,1d
# 53                    2h,8h,1d,3d,1w     5m,15m,30m,1h,4h,12h
# 29                       1h,2h,1d,3d  5m,15m,30m,4h,8h,12h,1w
# 45                  15m,30m,1h,2h,4h          5m,8h,12h,1d,3d
# 50                      30m,1h,2h,4h   5m,15m,8h,12h,1d,3d,1w
# 28               15m,30m,1h,2h,4h,3d             8h,12h,1d,1w
# 2                 30m,1h,2h,4h,3d,1w         5m,15m,8h,12h,1d
# 23                2h,4h,8h,12h,3d,1w            5m,15m,30m,1h
# 19                    1h,2h,1d,3d,1w         5m,15m,4h,8h,12h
#
#                              uptrend                 dshift      downtrend  \
# 33                  30m,1h,4h,12h,1w                  5m,3d            NaN
# 4                          30m,1h,1w          5m,15m,12h,3d    2h,4h,8h,1d
# 17                          2h,4h,8h                     5m            15m
# 11                         5m,8h,12h               2h,4h,3d            NaN
# 21                     15m,30m,1h,4h              5m,12h,3d          8h,1d
# 6                          15m,2h,3d                    12h            NaN
# 13         5m,30m,1h,2h,12h,1d,3d,1w                    15m            NaN
# 10            30m,1h,8h,12h,1d,3d,1w                     4h            NaN
# 18          5m,2h,4h,8h,12h,1d,3d,1w                    NaN            NaN
# 12               15m,30m,1h,2h,4h,3d                     1w            NaN
# 31                   30m,1h,2h,4h,3d                     1w            NaN
# 32  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d                    NaN            NaN
# 34                          1h,2h,4h              12h,3d,1w            NaN
# 27               5m,15m,30m,1h,2h,4h                     3d            NaN
# 37                   5m,30m,1h,2h,4h                  3d,1w            NaN
# 7              5m,1h,2h,4h,8h,12h,1d                     1w             3d
# 25               5m,15m,30m,1h,2h,1w                  1d,3d         8h,12h
# 5                    5m,30m,1h,2h,1w              12h,1d,3d             8h
# 1                       30m,1h,4h,1w                 12h,3d          8h,1d
# 3                      15m,30m,1h,2h                  3d,1w      8h,12h,1d
# 20                   5m,30m,1h,2h,4h                  3d,1w         8h,12h
# 9                   5m,15m,30m,1h,2h                     3d   8h,12h,1d,1w
# 39                      30m,1h,2h,4h                     3d   8h,12h,1d,1w
# 8                                 1w  5m,1h,4h,8h,12h,1d,3d             2h
# 53                          1d,3d,1w                  5m,2h         15m,4h
# 29                             1h,1d           5m,12h,3d,1w            15m
# 45                                1h                 15m,3d             5m
# 50                         30m,1h,2h                    15m             1w
# 28                         30m,1h,2h                 12h,3d             1w
# 2                       30m,1h,2h,4h               5m,3d,1w  15m,8h,12h,1d
# 23                2h,4h,8h,12h,3d,1w                     1h     5m,15m,30m
# 19                          2h,1d,1w                    12h         5m,15m
#
#                shift
# 33          2h,8h,1d
# 4                NaN
# 17      12h,1d,3d,1w
# 11            15m,1d
# 21                1w
# 6          30m,8h,1d
# 13             4h,8h
# 10         5m,15m,2h
# 18           15m,30m
# 12      5m,8h,12h,1d
# 31      5m,8h,12h,1d
# 32               NaN
# 34      5m,15m,8h,1d
# 27         8h,12h,1d
# 37         8h,12h,1d
# 7            15m,30m
# 25                4h
# 5             15m,4h
# 1                 2h
# 3                 4h
# 20               NaN
# 9                 4h
# 39               NaN
# 8            15m,30m
# 53     30m,1h,8h,12h
# 29            30m,8h
# 45  30m,4h,8h,12h,1d
# 50   4h,8h,12h,1d,3d
# 28          4h,8h,1d
# 2                NaN
# 23               NaN
# 19             4h,8h

# %%
 

test3 = buyzones(test)
test3
# Out:
#     Indicator      stkcross                                rsiup  \
# 0   TFUELUSDT    15m,30m,4h         5m,30m,1h,2h,4h,8h,12h,1d,1w
# 1    LINKUSDT            1h                         5m,30m,1h,1w
# 2     IMXUSDT      2h,4h,8h             5m,2h,4h,8h,12h,1d,3d,1w
# 3     KSMUSDT            8h                     5m,15m,8h,12h,1d
# 4    CAKEUSDT           30m                  5m,15m,30m,1h,4h,1w
# 5    ATOMUSDT           NaN        5m,15m,30m,1h,2h,8h,12h,1d,3d
# 6     WINUSDT            2h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 7     XTZUSDT        8h,12h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8    SCRTUSDT         5m,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 9    NEARUSDT  15m,2h,4h,1w     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 10   ROSEUSDT            4h     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 11   MOVRUSDT      5m,2h,1d     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 12   GLMRUSDT        2h,12h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 13    SRMUSDT        15m,4h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 14    VETUSDT      2h,4h,1w        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 15    MIRUSDT        12h,1d        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 16   LINAUSDT     15m,2h,1w               5m,15m,30m,1h,2h,4h,1w
# 17     ARUSDT            2h               5m,15m,30m,1h,2h,4h,1w
# 18   AVAXUSDT           NaN               5m,15m,30m,1h,2h,4h,1w
# 19   REEFUSDT            2h                  5m,15m,30m,1h,2h,4h
# 20  SUSHIUSDT            4h                  5m,15m,30m,1h,2h,4h
# 21    ZRXUSDT           NaN                  5m,15m,30m,1h,2h,4h
# 22   CELRUSDT            4h                  5m,15m,30m,1h,2h,4h
# 23   ALGOUSDT            1w                     5m,15m,30m,1h,1w
# 24   CTSIUSDT           NaN               30m,1h,8h,12h,1d,3d,1w
# 25    ANTUSDT           NaN                  30m,1h,8h,12h,1d,1w
# 26    FILUSDT           NaN                     30m,1h,8h,12h,1d
# 27  1INCHUSDT            2h            30m,1h,2h,4h,8h,12h,1d,3d
# 28   VTHOUSDT            2h               30m,1h,2h,4h,8h,12h,1d
# 29   WAXPUSDT            4h                         30m,1h,2h,4h
# 30    HNTUSDT            8h                2h,4h,8h,12h,1d,3d,1w
# 31    RENUSDT            1w                   2h,4h,8h,12h,1d,1w
#
#                    rsidown             tops          bottoms topr   bottomr  \
# 0                       3d        5m,15m,1d               1w  NaN        3d
# 1   15m,2h,4h,8h,12h,1d,3d     5m,12h,1d,3d     30m,1h,2h,1w  NaN       NaN
# 2                      15m          15m,30m               8h  NaN       NaN
# 3              2h,4h,3d,1w           30m,1h            8h,1w  NaN       NaN
# 4             8h,12h,1d,3d            5m,1d            2h,1w  NaN       NaN
# 5                       1w        5m,30m,1h               1w  NaN        3d
# 6                      NaN           30m,1d            2h,1w  NaN       NaN
# 7                      NaN        15m,1d,3d               1w  NaN       NaN
# 8                      NaN     30m,1h,2h,4h         1d,3d,1w  NaN  1d,3d,1w
# 9                       1w          15m,30m  4h,8h,12h,3d,1w  NaN       NaN
# 10                      1w       15m,30m,1h               1w  NaN        3d
# 11                      1w        5m,15m,4h              NaN  NaN     3d,1w
# 12                   3d,1w          15m,30m               8h  NaN     3d,1w
# 13                   3d,1w          15m,30m            3d,1w  NaN        3d
# 14                   3d,1w       5m,15m,30m               1w  NaN       NaN
# 15                   3d,1w              NaN        12h,1d,1w  NaN     3d,1w
# 16            8h,12h,1d,3d   15m,30m,12h,1d            2h,1w  NaN       NaN
# 17            8h,12h,1d,3d     5m,8h,12h,1d            2h,1w  NaN       NaN
# 18            8h,12h,1d,3d        5m,15m,1d               1w  NaN        3d
# 19         8h,12h,1d,3d,1w           15m,1d        8h,12h,1w  NaN        3d
# 20            8h,12h,3d,1w       5m,15m,30m        8h,12h,1w   5m       NaN
# 21         8h,12h,1d,3d,1w       5m,15m,30m         4h,8h,1w  NaN       NaN
# 22         8h,12h,1d,3d,1w       5m,15m,30m     4h,8h,12h,1w  NaN       NaN
# 23      2h,4h,8h,12h,1d,3d     4h,8h,12h,1d               1w  NaN       NaN
# 24            5m,15m,2h,4h         8h,1d,3d           15m,1w  NaN       NaN
# 25               5m,15m,3d          15m,30m            2h,1w  NaN       NaN
# 26            5m,15m,3d,1w              30m         8h,3d,1w  NaN     3d,1w
# 27                      1w          15m,30m     8h,12h,1d,1w  NaN       NaN
# 28                   3d,1w       5m,15m,30m            2h,1w  NaN       NaN
# 29     15m,8h,12h,1d,3d,1w       5m,15m,30m        8h,12h,1w  NaN       NaN
# 30           5m,15m,30m,1h  1h,2h,12h,1d,3d            5m,1w   8h       NaN
# 31                  5m,15m       15m,30m,1d            2h,1w  NaN       NaN
#
#                               stover                                 room  \
# 0         5m,15m,30m,1h,4h,12h,3d,1w            30m,1h,2h,4h,8h,12h,3d,1w
# 1            5m,15m,30m,1h,12h,3d,1w               15m,30m,1h,2h,4h,8h,1w
# 2                 5m,30m,1h,2h,4h,8h          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 3              5m,1h,2h,4h,8h,12h,3d         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 4            5m,15m,30m,1h,4h,12h,3d        15m,30m,1h,2h,4h,8h,12h,3d,1w
# 5             5m,15m,1h,2h,4h,12h,3d            15m,2h,4h,8h,12h,1d,3d,1w
# 6      5m,15m,30m,1h,2h,12h,1d,3d,1w         5m,15m,1h,2h,4h,8h,12h,3d,1w
# 7          30m,1h,4h,8h,12h,1d,3d,1w            5m,30m,1h,2h,4h,8h,12h,1w
# 8        5m,1h,2h,4h,8h,12h,1d,3d,1w               5m,15m,8h,12h,1d,3d,1w
# 9             15m,30m,1h,2h,4h,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 10            15m,30m,1h,2h,4h,3d,1w             5m,2h,4h,8h,12h,1d,3d,1w
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d            30m,1h,2h,8h,12h,1d,3d,1w
# 12            30m,1h,2h,4h,12h,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 13            5m,15m,30m,1h,2h,4h,3d          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 14         5m,15m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 15          5m,1h,2h,4h,8h,12h,1d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16         5m,15m,30m,1h,2h,1d,3d,1w                 5m,1h,2h,4h,8h,3d,1w
# 17         5m,30m,1h,2h,12h,1d,3d,1w               15m,30m,1h,2h,4h,3d,1w
# 18        5m,15m,30m,1h,4h,12h,3d,1w            30m,1h,2h,4h,8h,12h,3d,1w
# 19            5m,15m,30m,1h,2h,3d,1w         5m,30m,1h,2h,4h,8h,12h,3d,1w
# 20         5m,15m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 21               5m,15m,30m,1h,2h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 22                   30m,1h,2h,4h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 23          5m,1h,4h,8h,12h,1d,3d,1w               5m,15m,30m,1h,2h,3d,1w
# 24                    5m,2h,1d,3d,1w           5m,15m,30m,1h,2h,4h,12h,1w
# 25             5m,1h,2h,12h,1d,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 26                      15m,1h,2h,3d      5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 27                     15m,30m,1h,2h          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 28              15m,30m,1h,2h,12h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 29             5m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 30          1h,2h,4h,8h,12h,1d,3d,1w                  5m,15m,30m,4h,8h,1w
# 31                1h,2h,12h,1d,3d,1w             5m,1h,2h,4h,8h,12h,3d,1w
#
#                                   roomr                stunder  \
# 0   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w               2h,8h,1d
# 1   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w            2h,4h,8h,1d
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       15m,12h,1d,3d,1w
# 3   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,1d
# 4   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w            2h,8h,1d,1w
# 5   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           30m,8h,1d,1w
# 6   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                  4h,8h
# 7   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              5m,15m,2h
# 8   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                15m,30m
# 9   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,8h,12h,1d
# 10  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,8h,12h,1d
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                    NaN
# 12  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,15m,8h,1d
# 13  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           8h,12h,1d,1w
# 14  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 15  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,3d
# 16  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              4h,8h,12h
# 17  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              15m,4h,8h
# 18  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w               2h,8h,1d
# 19  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           4h,8h,12h,1d
# 20     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 21  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w        4h,8h,12h,1d,1w
# 22  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           8h,12h,1d,1w
# 23  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,2h
# 24  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w   15m,30m,1h,4h,8h,12h
# 25  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w          15m,30m,4h,8h
# 26  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w    5m,30m,4h,8h,12h,1d
# 27  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,4h,8h,12h,1d,3d,1w
# 28  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         5m,4h,8h,1d,1w
# 29  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w          15m,8h,12h,1d
# 30     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w             5m,15m,30m
# 31  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       5m,15m,30m,4h,8h
#
#                                stkup                  stkdown  \
# 0         15m,30m,1h,2h,4h,12h,3d,1w                 5m,8h,1d
# 1                   15m,30m,1h,3d,1w       5m,2h,4h,8h,12h,1d
# 2                30m,1h,2h,4h,8h,12h          5m,15m,1d,3d,1w
# 3              5m,1h,2h,4h,8h,12h,3d               15m,30m,1d
# 4                   15m,30m,1h,4h,3d       5m,2h,8h,12h,1d,1w
# 5                    15m,2h,4h,8h,3d                   12h,1d
# 6       5m,30m,1h,2h,4h,12h,1d,3d,1w                   15m,8h
# 7          30m,1h,2h,8h,12h,1d,3d,1w                    5m,4h
# 8       5m,30m,2h,4h,8h,12h,1d,3d,1w                      15m
# 9                15m,30m,1h,2h,4h,3d             5m,8h,12h,1d
# 10             5m,30m,1h,2h,4h,3d,1w                8h,12h,1d
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d                       1w
# 12                 1h,2h,4h,8h,3d,1w            5m,15m,12h,1d
# 13            5m,15m,30m,1h,2h,4h,3d                8h,12h,1d
# 14                5m,30m,1h,2h,4h,1w             8h,12h,1d,3d
# 15      5m,30m,1h,2h,4h,8h,12h,1d,1w                   15m,3d
# 16         5m,15m,30m,1h,2h,1d,3d,1w                4h,8h,12h
# 17             5m,30m,1h,2h,1d,3d,1w                4h,8h,12h
# 18                   30m,1h,4h,3d,1w             2h,8h,12h,1d
# 19               15m,30m,1h,2h,3d,1w             4h,8h,12h,1d
# 20             5m,30m,1h,2h,4h,3d,1w                8h,12h,1d
# 21            5m,15m,30m,1h,2h,4h,3d             8h,12h,1d,1w
# 22                   30m,1h,2h,4h,3d             8h,12h,1d,1w
# 23              15m,30m,4h,12h,3d,1w           5m,1h,2h,8h,1d
# 24                    2h,8h,1d,3d,1w     5m,15m,30m,1h,4h,12h
# 25                       1h,2h,1d,3d  5m,15m,30m,4h,8h,12h,1w
# 26                  15m,30m,1h,2h,4h          5m,8h,12h,1d,3d
# 27                      30m,1h,2h,4h   5m,15m,8h,12h,1d,3d,1w
# 28               15m,30m,1h,2h,4h,3d             8h,12h,1d,1w
# 29                30m,1h,2h,4h,3d,1w         5m,15m,8h,12h,1d
# 30                2h,4h,8h,12h,3d,1w            5m,15m,30m,1h
# 31                    1h,2h,1d,3d,1w         5m,15m,4h,8h,12h
#
#                              uptrend                 dshift      downtrend  \
# 0                   30m,1h,4h,12h,1w                  5m,3d            NaN
# 1                          30m,1h,1w          5m,15m,12h,3d    2h,4h,8h,1d
# 2                           2h,4h,8h                     5m            15m
# 3                          5m,8h,12h               2h,4h,3d            NaN
# 4                      15m,30m,1h,4h              5m,12h,3d          8h,1d
# 5                          15m,2h,3d                    12h            NaN
# 6          5m,30m,1h,2h,12h,1d,3d,1w                    15m            NaN
# 7             30m,1h,8h,12h,1d,3d,1w                     4h            NaN
# 8           5m,2h,4h,8h,12h,1d,3d,1w                    NaN            NaN
# 9                15m,30m,1h,2h,4h,3d                     1w            NaN
# 10                   30m,1h,2h,4h,3d                     1w            NaN
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d                    NaN            NaN
# 12                          1h,2h,4h              12h,3d,1w            NaN
# 13               5m,15m,30m,1h,2h,4h                     3d            NaN
# 14                   5m,30m,1h,2h,4h                  3d,1w            NaN
# 15             5m,1h,2h,4h,8h,12h,1d                     1w             3d
# 16               5m,15m,30m,1h,2h,1w                  1d,3d         8h,12h
# 17                   5m,30m,1h,2h,1w              12h,1d,3d             8h
# 18                      30m,1h,4h,1w                 12h,3d          8h,1d
# 19                     15m,30m,1h,2h                  3d,1w      8h,12h,1d
# 20                   5m,30m,1h,2h,4h                  3d,1w         8h,12h
# 21                  5m,15m,30m,1h,2h                     3d   8h,12h,1d,1w
# 22                      30m,1h,2h,4h                     3d   8h,12h,1d,1w
# 23                                1w  5m,1h,4h,8h,12h,1d,3d             2h
# 24                          1d,3d,1w                  5m,2h         15m,4h
# 25                             1h,1d           5m,12h,3d,1w            15m
# 26                                1h                 15m,3d             5m
# 27                         30m,1h,2h                    15m             1w
# 28                         30m,1h,2h                 12h,3d             1w
# 29                      30m,1h,2h,4h               5m,3d,1w  15m,8h,12h,1d
# 30                2h,4h,8h,12h,3d,1w                     1h     5m,15m,30m
# 31                          2h,1d,1w                    12h         5m,15m
#
#                shift                       buyzones
# 0           2h,8h,1d         30m,1h,2h,4h,8h,12h,1w
# 1                NaN                      30m,1h,1w
# 2       12h,1d,3d,1w       5m,2h,4h,8h,12h,1d,3d,1w
# 3             15m,1d               5m,15m,8h,12h,1d
# 4                 1w               15m,30m,1h,4h,1w
# 5          30m,8h,1d            15m,2h,8h,12h,1d,3d
# 6              4h,8h   5m,15m,1h,2h,4h,8h,12h,3d,1w
# 7          5m,15m,2h      5m,30m,1h,2h,4h,8h,12h,1w
# 8            15m,30m         5m,15m,8h,12h,1d,3d,1w
# 9       5m,8h,12h,1d       5m,1h,2h,4h,8h,12h,1d,3d
# 10      5m,8h,12h,1d          5m,2h,4h,8h,12h,1d,3d
# 11               NaN         30m,1h,2h,8h,12h,1d,3d
# 12      5m,15m,8h,1d          5m,1h,2h,4h,8h,12h,1d
# 13         8h,12h,1d          5m,1h,2h,4h,8h,12h,1d
# 14         8h,12h,1d             1h,2h,4h,8h,12h,1d
# 15           15m,30m  5m,15m,30m,1h,2h,4h,8h,12h,1d
# 16                4h                 5m,1h,2h,4h,1w
# 17            15m,4h            15m,30m,1h,2h,4h,1w
# 18                2h                30m,1h,2h,4h,1w
# 19                4h                5m,30m,1h,2h,4h
# 20               NaN                       1h,2h,4h
# 21                4h                       1h,2h,4h
# 22               NaN                       1h,2h,4h
# 23           15m,30m               5m,15m,30m,1h,1w
# 24     30m,1h,8h,12h                  30m,1h,12h,1w
# 25            30m,8h                1h,8h,12h,1d,1w
# 26  30m,4h,8h,12h,1d                   1h,8h,12h,1d
# 27   4h,8h,12h,1d,3d          1h,2h,4h,8h,12h,1d,3d
# 28          4h,8h,1d             1h,2h,4h,8h,12h,1d
# 29               NaN                       1h,2h,4h
# 30               NaN                          4h,1w
# 31             4h,8h                2h,4h,8h,12h,1w

# %%
test4 = buyzonesa(test)
test4.sort_values(by=['buyzones'],ascending=[False])
test4
# Out:
#     Indicator      stkcross                                rsiup  \
# 0   TFUELUSDT    15m,30m,4h         5m,30m,1h,2h,4h,8h,12h,1d,1w
# 1    LINKUSDT            1h                         5m,30m,1h,1w
# 2     IMXUSDT      2h,4h,8h             5m,2h,4h,8h,12h,1d,3d,1w
# 3     KSMUSDT            8h                     5m,15m,8h,12h,1d
# 4    CAKEUSDT           30m                  5m,15m,30m,1h,4h,1w
# 5    ATOMUSDT           NaN        5m,15m,30m,1h,2h,8h,12h,1d,3d
# 6     WINUSDT            2h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 7     XTZUSDT        8h,12h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8    SCRTUSDT         5m,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 9    NEARUSDT  15m,2h,4h,1w     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 10   ROSEUSDT            4h     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 11   MOVRUSDT      5m,2h,1d     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 12   GLMRUSDT        2h,12h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 13    SRMUSDT        15m,4h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 14    VETUSDT      2h,4h,1w        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 15    MIRUSDT        12h,1d        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 16   LINAUSDT     15m,2h,1w               5m,15m,30m,1h,2h,4h,1w
# 17     ARUSDT            2h               5m,15m,30m,1h,2h,4h,1w
# 18   AVAXUSDT           NaN               5m,15m,30m,1h,2h,4h,1w
# 19   REEFUSDT            2h                  5m,15m,30m,1h,2h,4h
# 20  SUSHIUSDT            4h                  5m,15m,30m,1h,2h,4h
# 21    ZRXUSDT           NaN                  5m,15m,30m,1h,2h,4h
# 22   CELRUSDT            4h                  5m,15m,30m,1h,2h,4h
# 23   ALGOUSDT            1w                     5m,15m,30m,1h,1w
# 24   CTSIUSDT           NaN               30m,1h,8h,12h,1d,3d,1w
# 25    ANTUSDT           NaN                  30m,1h,8h,12h,1d,1w
# 26    FILUSDT           NaN                     30m,1h,8h,12h,1d
# 27  1INCHUSDT            2h            30m,1h,2h,4h,8h,12h,1d,3d
# 28   VTHOUSDT            2h               30m,1h,2h,4h,8h,12h,1d
# 29   WAXPUSDT            4h                         30m,1h,2h,4h
# 30    HNTUSDT            8h                2h,4h,8h,12h,1d,3d,1w
# 31    RENUSDT            1w                   2h,4h,8h,12h,1d,1w
#
#                    rsidown             tops          bottoms topr   bottomr  \
# 0                       3d        5m,15m,1d               1w  NaN        3d
# 1   15m,2h,4h,8h,12h,1d,3d     5m,12h,1d,3d     30m,1h,2h,1w  NaN       NaN
# 2                      15m          15m,30m               8h  NaN       NaN
# 3              2h,4h,3d,1w           30m,1h            8h,1w  NaN       NaN
# 4             8h,12h,1d,3d            5m,1d            2h,1w  NaN       NaN
# 5                       1w        5m,30m,1h               1w  NaN        3d
# 6                      NaN           30m,1d            2h,1w  NaN       NaN
# 7                      NaN        15m,1d,3d               1w  NaN       NaN
# 8                      NaN     30m,1h,2h,4h         1d,3d,1w  NaN  1d,3d,1w
# 9                       1w          15m,30m  4h,8h,12h,3d,1w  NaN       NaN
# 10                      1w       15m,30m,1h               1w  NaN        3d
# 11                      1w        5m,15m,4h              NaN  NaN     3d,1w
# 12                   3d,1w          15m,30m               8h  NaN     3d,1w
# 13                   3d,1w          15m,30m            3d,1w  NaN        3d
# 14                   3d,1w       5m,15m,30m               1w  NaN       NaN
# 15                   3d,1w              NaN        12h,1d,1w  NaN     3d,1w
# 16            8h,12h,1d,3d   15m,30m,12h,1d            2h,1w  NaN       NaN
# 17            8h,12h,1d,3d     5m,8h,12h,1d            2h,1w  NaN       NaN
# 18            8h,12h,1d,3d        5m,15m,1d               1w  NaN        3d
# 19         8h,12h,1d,3d,1w           15m,1d        8h,12h,1w  NaN        3d
# 20            8h,12h,3d,1w       5m,15m,30m        8h,12h,1w   5m       NaN
# 21         8h,12h,1d,3d,1w       5m,15m,30m         4h,8h,1w  NaN       NaN
# 22         8h,12h,1d,3d,1w       5m,15m,30m     4h,8h,12h,1w  NaN       NaN
# 23      2h,4h,8h,12h,1d,3d     4h,8h,12h,1d               1w  NaN       NaN
# 24            5m,15m,2h,4h         8h,1d,3d           15m,1w  NaN       NaN
# 25               5m,15m,3d          15m,30m            2h,1w  NaN       NaN
# 26            5m,15m,3d,1w              30m         8h,3d,1w  NaN     3d,1w
# 27                      1w          15m,30m     8h,12h,1d,1w  NaN       NaN
# 28                   3d,1w       5m,15m,30m            2h,1w  NaN       NaN
# 29     15m,8h,12h,1d,3d,1w       5m,15m,30m        8h,12h,1w  NaN       NaN
# 30           5m,15m,30m,1h  1h,2h,12h,1d,3d            5m,1w   8h       NaN
# 31                  5m,15m       15m,30m,1d            2h,1w  NaN       NaN
#
#                               stover                                 room  \
# 0         5m,15m,30m,1h,4h,12h,3d,1w            30m,1h,2h,4h,8h,12h,3d,1w
# 1            5m,15m,30m,1h,12h,3d,1w               15m,30m,1h,2h,4h,8h,1w
# 2                 5m,30m,1h,2h,4h,8h          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 3              5m,1h,2h,4h,8h,12h,3d         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 4            5m,15m,30m,1h,4h,12h,3d        15m,30m,1h,2h,4h,8h,12h,3d,1w
# 5             5m,15m,1h,2h,4h,12h,3d            15m,2h,4h,8h,12h,1d,3d,1w
# 6      5m,15m,30m,1h,2h,12h,1d,3d,1w         5m,15m,1h,2h,4h,8h,12h,3d,1w
# 7          30m,1h,4h,8h,12h,1d,3d,1w            5m,30m,1h,2h,4h,8h,12h,1w
# 8        5m,1h,2h,4h,8h,12h,1d,3d,1w               5m,15m,8h,12h,1d,3d,1w
# 9             15m,30m,1h,2h,4h,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 10            15m,30m,1h,2h,4h,3d,1w             5m,2h,4h,8h,12h,1d,3d,1w
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d            30m,1h,2h,8h,12h,1d,3d,1w
# 12            30m,1h,2h,4h,12h,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 13            5m,15m,30m,1h,2h,4h,3d          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 14         5m,15m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 15          5m,1h,2h,4h,8h,12h,1d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16         5m,15m,30m,1h,2h,1d,3d,1w                 5m,1h,2h,4h,8h,3d,1w
# 17         5m,30m,1h,2h,12h,1d,3d,1w               15m,30m,1h,2h,4h,3d,1w
# 18        5m,15m,30m,1h,4h,12h,3d,1w            30m,1h,2h,4h,8h,12h,3d,1w
# 19            5m,15m,30m,1h,2h,3d,1w         5m,30m,1h,2h,4h,8h,12h,3d,1w
# 20         5m,15m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 21               5m,15m,30m,1h,2h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 22                   30m,1h,2h,4h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 23          5m,1h,4h,8h,12h,1d,3d,1w               5m,15m,30m,1h,2h,3d,1w
# 24                    5m,2h,1d,3d,1w           5m,15m,30m,1h,2h,4h,12h,1w
# 25             5m,1h,2h,12h,1d,3d,1w          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 26                      15m,1h,2h,3d      5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 27                     15m,30m,1h,2h          5m,1h,2h,4h,8h,12h,1d,3d,1w
# 28              15m,30m,1h,2h,12h,3d             1h,2h,4h,8h,12h,1d,3d,1w
# 29             5m,30m,1h,2h,4h,3d,1w             1h,2h,4h,8h,12h,1d,3d,1w
# 30          1h,2h,4h,8h,12h,1d,3d,1w                  5m,15m,30m,4h,8h,1w
# 31                1h,2h,12h,1d,3d,1w             5m,1h,2h,4h,8h,12h,3d,1w
#
#                                   roomr                stunder  \
# 0   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w               2h,8h,1d
# 1   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w            2h,4h,8h,1d
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       15m,12h,1d,3d,1w
# 3   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,1d
# 4   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w            2h,8h,1d,1w
# 5   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           30m,8h,1d,1w
# 6   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                  4h,8h
# 7   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              5m,15m,2h
# 8   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                15m,30m
# 9   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,8h,12h,1d
# 10  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,8h,12h,1d
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                    NaN
# 12  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,15m,8h,1d
# 13  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           8h,12h,1d,1w
# 14  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 15  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,3d
# 16  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              4h,8h,12h
# 17  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              15m,4h,8h
# 18  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w               2h,8h,1d
# 19  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           4h,8h,12h,1d
# 20     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 21  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w        4h,8h,12h,1d,1w
# 22  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           8h,12h,1d,1w
# 23  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             15m,30m,2h
# 24  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w   15m,30m,1h,4h,8h,12h
# 25  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w          15m,30m,4h,8h
# 26  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w    5m,30m,4h,8h,12h,1d
# 27  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,4h,8h,12h,1d,3d,1w
# 28  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         5m,4h,8h,1d,1w
# 29  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w          15m,8h,12h,1d
# 30     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w             5m,15m,30m
# 31  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       5m,15m,30m,4h,8h
#
#                                stkup                  stkdown  \
# 0         15m,30m,1h,2h,4h,12h,3d,1w                 5m,8h,1d
# 1                   15m,30m,1h,3d,1w       5m,2h,4h,8h,12h,1d
# 2                30m,1h,2h,4h,8h,12h          5m,15m,1d,3d,1w
# 3              5m,1h,2h,4h,8h,12h,3d               15m,30m,1d
# 4                   15m,30m,1h,4h,3d       5m,2h,8h,12h,1d,1w
# 5                    15m,2h,4h,8h,3d                   12h,1d
# 6       5m,30m,1h,2h,4h,12h,1d,3d,1w                   15m,8h
# 7          30m,1h,2h,8h,12h,1d,3d,1w                    5m,4h
# 8       5m,30m,2h,4h,8h,12h,1d,3d,1w                      15m
# 9                15m,30m,1h,2h,4h,3d             5m,8h,12h,1d
# 10             5m,30m,1h,2h,4h,3d,1w                8h,12h,1d
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d                       1w
# 12                 1h,2h,4h,8h,3d,1w            5m,15m,12h,1d
# 13            5m,15m,30m,1h,2h,4h,3d                8h,12h,1d
# 14                5m,30m,1h,2h,4h,1w             8h,12h,1d,3d
# 15      5m,30m,1h,2h,4h,8h,12h,1d,1w                   15m,3d
# 16         5m,15m,30m,1h,2h,1d,3d,1w                4h,8h,12h
# 17             5m,30m,1h,2h,1d,3d,1w                4h,8h,12h
# 18                   30m,1h,4h,3d,1w             2h,8h,12h,1d
# 19               15m,30m,1h,2h,3d,1w             4h,8h,12h,1d
# 20             5m,30m,1h,2h,4h,3d,1w                8h,12h,1d
# 21            5m,15m,30m,1h,2h,4h,3d             8h,12h,1d,1w
# 22                   30m,1h,2h,4h,3d             8h,12h,1d,1w
# 23              15m,30m,4h,12h,3d,1w           5m,1h,2h,8h,1d
# 24                    2h,8h,1d,3d,1w     5m,15m,30m,1h,4h,12h
# 25                       1h,2h,1d,3d  5m,15m,30m,4h,8h,12h,1w
# 26                  15m,30m,1h,2h,4h          5m,8h,12h,1d,3d
# 27                      30m,1h,2h,4h   5m,15m,8h,12h,1d,3d,1w
# 28               15m,30m,1h,2h,4h,3d             8h,12h,1d,1w
# 29                30m,1h,2h,4h,3d,1w         5m,15m,8h,12h,1d
# 30                2h,4h,8h,12h,3d,1w            5m,15m,30m,1h
# 31                    1h,2h,1d,3d,1w         5m,15m,4h,8h,12h
#
#                              uptrend                 dshift      downtrend  \
# 0                   30m,1h,4h,12h,1w                  5m,3d            NaN
# 1                          30m,1h,1w          5m,15m,12h,3d    2h,4h,8h,1d
# 2                           2h,4h,8h                     5m            15m
# 3                          5m,8h,12h               2h,4h,3d            NaN
# 4                      15m,30m,1h,4h              5m,12h,3d          8h,1d
# 5                          15m,2h,3d                    12h            NaN
# 6          5m,30m,1h,2h,12h,1d,3d,1w                    15m            NaN
# 7             30m,1h,8h,12h,1d,3d,1w                     4h            NaN
# 8           5m,2h,4h,8h,12h,1d,3d,1w                    NaN            NaN
# 9                15m,30m,1h,2h,4h,3d                     1w            NaN
# 10                   30m,1h,2h,4h,3d                     1w            NaN
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d                    NaN            NaN
# 12                          1h,2h,4h              12h,3d,1w            NaN
# 13               5m,15m,30m,1h,2h,4h                     3d            NaN
# 14                   5m,30m,1h,2h,4h                  3d,1w            NaN
# 15             5m,1h,2h,4h,8h,12h,1d                     1w             3d
# 16               5m,15m,30m,1h,2h,1w                  1d,3d         8h,12h
# 17                   5m,30m,1h,2h,1w              12h,1d,3d             8h
# 18                      30m,1h,4h,1w                 12h,3d          8h,1d
# 19                     15m,30m,1h,2h                  3d,1w      8h,12h,1d
# 20                   5m,30m,1h,2h,4h                  3d,1w         8h,12h
# 21                  5m,15m,30m,1h,2h                     3d   8h,12h,1d,1w
# 22                      30m,1h,2h,4h                     3d   8h,12h,1d,1w
# 23                                1w  5m,1h,4h,8h,12h,1d,3d             2h
# 24                          1d,3d,1w                  5m,2h         15m,4h
# 25                             1h,1d           5m,12h,3d,1w            15m
# 26                                1h                 15m,3d             5m
# 27                         30m,1h,2h                    15m             1w
# 28                         30m,1h,2h                 12h,3d             1w
# 29                      30m,1h,2h,4h               5m,3d,1w  15m,8h,12h,1d
# 30                2h,4h,8h,12h,3d,1w                     1h     5m,15m,30m
# 31                          2h,1d,1w                    12h         5m,15m
#
#                shift                       buyzones
# 0           2h,8h,1d            30m,1h,2h,4h,8h,12h
# 1                NaN                          1h,1w
# 2       12h,1d,3d,1w       5m,2h,4h,8h,12h,1d,3d,1w
# 3             15m,1d                  5m,15m,12h,1d
# 4                 1w                  15m,30m,1h,4h
# 5          30m,8h,1d            15m,2h,8h,12h,1d,3d
# 6              4h,8h   5m,15m,1h,2h,4h,8h,12h,3d,1w
# 7          5m,15m,2h      5m,30m,1h,2h,4h,8h,12h,1w
# 8            15m,30m         5m,15m,8h,12h,1d,3d,1w
# 9       5m,8h,12h,1d       5m,1h,2h,4h,8h,12h,1d,3d
# 10      5m,8h,12h,1d          5m,2h,4h,8h,12h,1d,3d
# 11               NaN         30m,1h,2h,8h,12h,1d,3d
# 12      5m,15m,8h,1d          5m,1h,2h,4h,8h,12h,1d
# 13         8h,12h,1d          5m,1h,2h,4h,8h,12h,1d
# 14         8h,12h,1d             1h,2h,4h,8h,12h,1d
# 15           15m,30m  5m,15m,30m,1h,2h,4h,8h,12h,1d
# 16                4h                    5m,1h,2h,4h
# 17            15m,4h               15m,30m,1h,2h,4h
# 18                2h                   30m,1h,2h,4h
# 19                4h                5m,30m,1h,2h,4h
# 20               NaN                       1h,2h,4h
# 21                4h                       1h,2h,4h
# 22               NaN                       1h,2h,4h
# 23           15m,30m                  5m,15m,30m,1h
# 24     30m,1h,8h,12h                      1h,12h,1w
# 25            30m,8h                   1h,8h,12h,1d
# 26  30m,4h,8h,12h,1d                   1h,8h,12h,1d
# 27   4h,8h,12h,1d,3d          1h,2h,4h,8h,12h,1d,3d
# 28          4h,8h,1d             1h,2h,4h,8h,12h,1d
# 29               NaN                       1h,2h,4h
# 30               NaN                             1w
# 31             4h,8h                2h,4h,8h,12h,1w

# %%
# Indicators for the week shift

newframe=callfun(wshift,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])

newframe=buyzonesa(newframe)
newframe
# Out:
#   Indicator  stkcross                          rsiup       rsidown  \
# 0   IMXUSDT  2h,4h,8h       5m,2h,4h,8h,12h,1d,3d,1w           15m
# 1  CAKEUSDT       30m            5m,15m,30m,1h,4h,1w  8h,12h,1d,3d
# 2  IOTXUSDT        4h  15m,30m,1h,2h,4h,8h,12h,1d,1w            3d
#
#          tops bottoms topr bottomr                   stover  \
# 0     15m,30m      8h  NaN     NaN       5m,30m,1h,2h,4h,8h
# 1       5m,1d   2h,1w  NaN     NaN  5m,15m,30m,1h,4h,12h,3d
# 2  15m,30m,1h      1w  NaN     NaN    5m,1h,2h,4h,12h,1d,3d
#
#                             room                                roomr  \
# 0    5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1  15m,30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2       5m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#             stunder                stkup               stkdown        uptrend  \
# 0  15m,12h,1d,3d,1w  30m,1h,2h,4h,8h,12h       5m,15m,1d,3d,1w       2h,4h,8h
# 1       2h,8h,1d,1w     15m,30m,1h,4h,3d    5m,2h,8h,12h,1d,1w  15m,30m,1h,4h
# 2     15m,30m,8h,1w       5m,1h,2h,4h,3d  15m,30m,8h,12h,1d,1w       1h,2h,4h
#
#       dshift downtrend          shift                  buyzones
# 0         5m       15m   12h,1d,3d,1w  5m,2h,4h,8h,12h,1d,3d,1w
# 1  5m,12h,3d     8h,1d             1w             15m,30m,1h,4h
# 2  12h,1d,3d       NaN  15m,30m,8h,1w           2h,4h,8h,12h,1d

# %%
# Indicators for the 3d Cross
newframe=callfun(macd1dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='1d'))]


test=buyzonesa(test)
test
# Out:
#   Indicator stkcross                                rsiup rsidown  \
# 0   MIRUSDT   12h,1d        5m,15m,30m,1h,2h,4h,8h,12h,1d   3d,1w
# 1  ATOMUSDT      NaN        5m,15m,30m,1h,2h,8h,12h,1d,3d      1w
# 2  SCRTUSDT    5m,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w     NaN
#
#            tops    bottoms topr   bottomr                       stover  \
# 0           NaN  12h,1d,1w  NaN     3d,1w     5m,1h,2h,4h,8h,12h,1d,1w
# 1     5m,30m,1h         1w  NaN        3d       5m,15m,1h,2h,4h,12h,3d
# 2  30m,1h,2h,4h   1d,3d,1w  NaN  1d,3d,1w  5m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                   room                                roomr  \
# 0  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1            15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2               5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#         stunder                         stkup stkdown  \
# 0    15m,30m,3d  5m,30m,1h,2h,4h,8h,12h,1d,1w  15m,3d
# 1  30m,8h,1d,1w               15m,2h,4h,8h,3d  12h,1d
# 2       15m,30m  5m,30m,2h,4h,8h,12h,1d,3d,1w     15m
#
#                     uptrend dshift downtrend      shift  \
# 0     5m,1h,2h,4h,8h,12h,1d     1w        3d    15m,30m
# 1                 15m,2h,3d    12h       NaN  30m,8h,1d
# 2  5m,2h,4h,8h,12h,1d,3d,1w    NaN       NaN    15m,30m
#
#                         buyzones
# 0  5m,15m,30m,1h,2h,4h,8h,12h,1d
# 1            15m,2h,8h,12h,1d,3d
# 2         5m,15m,8h,12h,1d,3d,1w

# %%
## MACD 3d gap and rsi up
newframe=callfun(macd3dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['rsiup'] > newframe['rsidown']) ]

#test = newframe.loc[(newframe['rsiup'].notnull()) &  (newframe['rsidown'] >= "1w" )]



test=buyzonesa(test)
test
# Out:
#     Indicator      stkcross                                rsiup  \
# 0     FILUSDT           NaN                     30m,1h,8h,12h,1d
# 1    GLMRUSDT        2h,12h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 2     MIRUSDT        12h,1d        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 3    REEFUSDT            2h                  5m,15m,30m,1h,2h,4h
# 4     SRMUSDT        15m,4h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5     RAYUSDT         2h,4h        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 6     ONEUSDT            4h                     15m,30m,1h,2h,4h
# 7    AVAXUSDT           NaN               5m,15m,30m,1h,2h,4h,1w
# 8   TFUELUSDT    15m,30m,4h         5m,30m,1h,2h,4h,8h,12h,1d,1w
# 9    ATOMUSDT           NaN        5m,15m,30m,1h,2h,8h,12h,1d,3d
# 10   ROSEUSDT            4h     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 11   SCRTUSDT         5m,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12   RUNEUSDT         4h,1w     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13    KSMUSDT            8h                     5m,15m,8h,12h,1d
# 14    DOTUSDT           NaN           15m,30m,1h,4h,8h,12h,1d,3d
# 15    ZILUSDT            4h        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 16  1INCHUSDT            2h            30m,1h,2h,4h,8h,12h,1d,3d
# 17   FLUXUSDT     15m,4h,8h           15m,30m,1h,2h,4h,8h,12h,1d
# 18    IMXUSDT      2h,4h,8h             5m,2h,4h,8h,12h,1d,3d,1w
# 19    HNTUSDT            8h                2h,4h,8h,12h,1d,3d,1w
# 20    CRVUSDT           NaN        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 21    ZRXUSDT           NaN                  5m,15m,30m,1h,2h,4h
# 22    GRTUSDT            1w                     15m,30m,1h,2h,4h
# 23   NEARUSDT  15m,2h,4h,1w     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 24   CELRUSDT            4h                  5m,15m,30m,1h,2h,4h
# 25    FTMUSDT            4h           15m,30m,1h,2h,4h,8h,12h,1d
# 26    ONTUSDT            2h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 27   LINKUSDT            1h                         5m,30m,1h,1w
# 28     ARUSDT            2h               5m,15m,30m,1h,2h,4h,1w
# 29   CAKEUSDT           30m                  5m,15m,30m,1h,4h,1w
# 30   LINAUSDT     15m,2h,1w               5m,15m,30m,1h,2h,4h,1w
# 31    ANTUSDT           NaN                  30m,1h,8h,12h,1d,1w
# 32    RENUSDT            1w                   2h,4h,8h,12h,1d,1w
# 33   VTHOUSDT            2h               30m,1h,2h,4h,8h,12h,1d
# 34    WINUSDT            2h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35   ANKRUSDT            4h           15m,30m,1h,2h,4h,8h,12h,1d
# 36    OMGUSDT        30m,1w            15m,2h,4h,8h,12h,1d,3d,1w
# 37   COTIUSDT        15m,2h     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38    VETUSDT      2h,4h,1w        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 39    LRCUSDT        15m,4h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 40   IOTXUSDT            4h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 41   ALGOUSDT            1w                     5m,15m,30m,1h,1w
# 42   BANDUSDT        15m,4h                     15m,8h,12h,1d,1w
# 43    XTZUSDT        8h,12h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 44   DENTUSDT           15m     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 45  MATICUSDT           NaN     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46  AUDIOUSDT            1w                        15m,30m,1h,1w
# 47   CTSIUSDT           NaN               30m,1h,8h,12h,1d,3d,1w
#
#                    rsidown                     tops          bottoms    topr  \
# 0             5m,15m,3d,1w                      30m         8h,3d,1w     NaN
# 1                    3d,1w                  15m,30m               8h     NaN
# 2                    3d,1w                      NaN        12h,1d,1w     NaN
# 3          8h,12h,1d,3d,1w                   15m,1d        8h,12h,1w     NaN
# 4                    3d,1w                  15m,30m            3d,1w     NaN
# 5                       1w               15m,30m,1d            2h,1w     NaN
# 6          8h,12h,1d,3d,1w                   5m,15m               1w     NaN
# 7             8h,12h,1d,3d                5m,15m,1d               1w     NaN
# 8                       3d                5m,15m,1d               1w     NaN
# 9                       1w                5m,30m,1h               1w     NaN
# 10                      1w               15m,30m,1h               1w     NaN
# 11                     NaN             30m,1h,2h,4h         1d,3d,1w     NaN
# 12                      5m         5m,15m,30m,1h,1d         8h,3d,1w     NaN
# 13             2h,4h,3d,1w                   30m,1h            8h,1w     NaN
# 14                      1w                5m,30m,1h        8h,12h,1w     NaN
# 15                      1w                  15m,30m        8h,12h,1w     NaN
# 16                      1w                  15m,30m     8h,12h,1d,1w     NaN
# 17                   3d,1w            5m,15m,30m,1h           8h,12h     NaN
# 18                     15m                  15m,30m               8h     NaN
# 19           5m,15m,30m,1h          1h,2h,12h,1d,3d            5m,1w      8h
# 20                      1w                  15m,30m      4h,8h,3d,1w     NaN
# 21         8h,12h,1d,3d,1w               5m,15m,30m         4h,8h,1w     NaN
# 22         8h,12h,1d,3d,1w                  15m,30m         4h,8h,1w     NaN
# 23                      1w                  15m,30m  4h,8h,12h,3d,1w     NaN
# 24         8h,12h,1d,3d,1w               5m,15m,30m     4h,8h,12h,1w     NaN
# 25                   3d,1w               5m,15m,30m     4h,8h,12h,1w     NaN
# 26                      3d                  15m,30m            4h,1w     NaN
# 27  15m,2h,4h,8h,12h,1d,3d             5m,12h,1d,3d     30m,1h,2h,1w     NaN
# 28            8h,12h,1d,3d             5m,8h,12h,1d            2h,1w     NaN
# 29            8h,12h,1d,3d                    5m,1d            2h,1w     NaN
# 30            8h,12h,1d,3d           15m,30m,12h,1d            2h,1w     NaN
# 31               5m,15m,3d                  15m,30m            2h,1w     NaN
# 32                  5m,15m               15m,30m,1d            2h,1w     NaN
# 33                   3d,1w               5m,15m,30m            2h,1w     NaN
# 34                     NaN                   30m,1d            2h,1w     NaN
# 35                5m,3d,1w                      15m               1w     NaN
# 36               5m,30m,1h      30m,1h,4h,8h,12h,1d               1w     NaN
# 37                      5m  15m,30m,4h,8h,12h,1d,3d               1w     NaN
# 38                   3d,1w               5m,15m,30m               1w     NaN
# 39                      3d                   5m,30m               1w     NaN
# 40                      3d               15m,30m,1h               1w     NaN
# 41      2h,4h,8h,12h,1d,3d             4h,8h,12h,1d               1w     NaN
# 42                2h,4h,3d                   30m,1d               1w     NaN
# 43                     NaN                15m,1d,3d               1w     NaN
# 44                     NaN               5m,15m,30m               1w     NaN
# 45                     NaN            15m,30m,1h,1d               1w  5m,15m
# 46      2h,4h,8h,12h,1d,3d          5m,4h,8h,12h,1d    15m,30m,1h,1w     NaN
# 47            5m,15m,2h,4h                 8h,1d,3d           15m,1w     NaN
#
#      bottomr                            stover  \
# 0      3d,1w                      15m,1h,2h,3d
# 1      3d,1w            30m,1h,2h,4h,12h,3d,1w
# 2      3d,1w          5m,1h,2h,4h,8h,12h,1d,1w
# 3         3d            5m,15m,30m,1h,2h,3d,1w
# 4         3d            5m,15m,30m,1h,2h,4h,3d
# 5         3d                5m,1h,2h,4h,12h,3d
# 6         3d               5m,15m,30m,1h,4h,3d
# 7         3d        5m,15m,30m,1h,4h,12h,3d,1w
# 8         3d        5m,15m,30m,1h,4h,12h,3d,1w
# 9         3d            5m,15m,1h,2h,4h,12h,3d
# 10        3d            15m,30m,1h,2h,4h,3d,1w
# 11  1d,3d,1w       5m,1h,2h,4h,8h,12h,1d,3d,1w
# 12       NaN         5m,15m,30m,1h,2h,4h,3d,1w
# 13       NaN             5m,1h,2h,4h,8h,12h,3d
# 14       NaN            5m,15m,1h,2h,4h,12h,3d
# 15       NaN                5m,30m,1h,2h,4h,3d
# 16       NaN                     15m,30m,1h,2h
# 17       NaN             5m,15m,1h,2h,4h,8h,3d
# 18       NaN                5m,30m,1h,2h,4h,8h
# 19       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 20       NaN                             1h,2h
# 21       NaN               5m,15m,30m,1h,2h,3d
# 22       NaN               15m,30m,1h,2h,3d,1w
# 23       NaN            15m,30m,1h,2h,4h,3d,1w
# 24       NaN                   30m,1h,2h,4h,3d
# 25       NaN            5m,15m,30m,1h,2h,4h,3d
# 26       NaN                5m,30m,1h,2h,3d,1w
# 27       NaN           5m,15m,30m,1h,12h,3d,1w
# 28       NaN         5m,30m,1h,2h,12h,1d,3d,1w
# 29       NaN           5m,15m,30m,1h,4h,12h,3d
# 30       NaN         5m,15m,30m,1h,2h,1d,3d,1w
# 31       NaN             5m,1h,2h,12h,1d,3d,1w
# 32       NaN                1h,2h,12h,1d,3d,1w
# 33       NaN              15m,30m,1h,2h,12h,3d
# 34       NaN     5m,15m,30m,1h,2h,12h,1d,3d,1w
# 35       NaN         5m,15m,30m,1h,2h,4h,3d,1w
# 36       NaN      30m,1h,2h,4h,8h,12h,1d,3d,1w
# 37       NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 38       NaN         5m,15m,30m,1h,2h,4h,3d,1w
# 39       NaN             5m,15m,1h,2h,4h,3d,1w
# 40       NaN             5m,1h,2h,4h,12h,1d,3d
# 41       NaN          5m,1h,4h,8h,12h,1d,3d,1w
# 42       NaN         5m,15m,1h,2h,4h,12h,3d,1w
# 43       NaN         30m,1h,4h,8h,12h,1d,3d,1w
# 44       NaN            5m,15m,30m,1h,2h,3d,1w
# 45       NaN         30m,1h,2h,4h,12h,1d,3d,1w
# 46       NaN               5m,15m,12h,1d,3d,1w
# 47       NaN                    5m,2h,1d,3d,1w
#
#                                    room                                roomr  \
# 0       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1           5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3          5m,30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4           5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5              5m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 6          30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 7             30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8             30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 9             15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 10             5m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 11               5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12                   2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13         5m,15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 14            15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17                   2h,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 18          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 19                  5m,15m,30m,4h,8h,1w     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 20          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 21             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 22          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 23          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 24             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 25             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 26          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 27               15m,30m,1h,2h,4h,8h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 28               15m,30m,1h,2h,4h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 29        15m,30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30                 5m,1h,2h,4h,8h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 31          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 32             5m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 33             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 34         5m,15m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35      5m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 36                      5m,15m,2h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 37                          5m,1h,2h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 39         15m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40             5m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 41               5m,15m,30m,1h,2h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 42         5m,15m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 43            5m,30m,1h,2h,4h,8h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 44             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 45                5m,2h,4h,8h,12h,3d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46                  15m,30m,1h,2h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 47           5m,15m,30m,1h,2h,4h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                           stunder                             stkup  \
# 0             5m,30m,4h,8h,12h,1d                  15m,30m,1h,2h,4h
# 1                    5m,15m,8h,1d                 1h,2h,4h,8h,3d,1w
# 2                      15m,30m,3d      5m,30m,1h,2h,4h,8h,12h,1d,1w
# 3                    4h,8h,12h,1d               15m,30m,1h,2h,3d,1w
# 4                    8h,12h,1d,1w            5m,15m,30m,1h,2h,4h,3d
# 5                   15m,30m,8h,1d               15m,1h,2h,4h,12h,3d
# 6                    2h,8h,12h,1d            5m,15m,30m,1h,2h,4h,3d
# 7                        2h,8h,1d                   30m,1h,4h,3d,1w
# 8                        2h,8h,1d        15m,30m,1h,2h,4h,12h,3d,1w
# 9                    30m,8h,1d,1w                   15m,2h,4h,8h,3d
# 10                   5m,8h,12h,1d             5m,30m,1h,2h,4h,3d,1w
# 11                        15m,30m      5m,30m,2h,4h,8h,12h,1d,3d,1w
# 12                      8h,12h,1d     5m,15m,30m,1h,2h,4h,12h,3d,1w
# 13                     15m,30m,1d             5m,1h,2h,4h,8h,12h,3d
# 14                      30m,8h,1d         5m,15m,1h,2h,4h,8h,12h,3d
# 15               15m,8h,12h,1d,1w             5m,30m,1h,2h,4h,8h,3d
# 16          5m,4h,8h,12h,1d,3d,1w                      30m,1h,2h,4h
# 17                     30m,12h,1d             5m,15m,1h,2h,4h,8h,3d
# 18               15m,12h,1d,3d,1w               30m,1h,2h,4h,8h,12h
# 19                     5m,15m,30m                2h,4h,8h,12h,3d,1w
# 20  5m,15m,30m,4h,8h,12h,1d,3d,1w                      15m,1h,2h,4h
# 21                4h,8h,12h,1d,1w            5m,15m,30m,1h,2h,4h,3d
# 22                5m,4h,8h,12h,1d                    5m,1h,2h,4h,1w
# 23                   5m,8h,12h,1d               15m,30m,1h,2h,4h,3d
# 24                   8h,12h,1d,1w                   30m,1h,2h,4h,3d
# 25                   8h,12h,1d,1w                5m,15m,1h,2h,4h,3d
# 26                   4h,8h,12h,1d             5m,30m,1h,2h,4h,3d,1w
# 27                    2h,4h,8h,1d                  15m,30m,1h,3d,1w
# 28                      15m,4h,8h             5m,30m,1h,2h,1d,3d,1w
# 29                    2h,8h,1d,1w                  15m,30m,1h,4h,3d
# 30                      4h,8h,12h         5m,15m,30m,1h,2h,1d,3d,1w
# 31                  15m,30m,4h,8h                       1h,2h,1d,3d
# 32               5m,15m,30m,4h,8h                    1h,2h,1d,3d,1w
# 33                 5m,4h,8h,1d,1w               15m,30m,1h,2h,4h,3d
# 34                          4h,8h      5m,30m,1h,2h,4h,12h,1d,3d,1w
# 35                      8h,12h,1d            15m,30m,1h,2h,4h,3d,1w
# 36                         5m,15m      30m,1h,2h,4h,8h,12h,1d,3d,1w
# 37                             4h  5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 38                      8h,12h,1d                5m,30m,1h,2h,4h,1w
# 39                  30m,8h,12h,1d         5m,15m,30m,1h,2h,4h,3d,1w
# 40                  15m,30m,8h,1w                    5m,1h,2h,4h,3d
# 41                     15m,30m,2h              15m,30m,4h,12h,3d,1w
# 42                      30m,8h,1d                5m,15m,1h,2h,3d,1w
# 43                      5m,15m,2h         30m,1h,2h,8h,12h,1d,3d,1w
# 44                   4h,8h,12h,1d            5m,15m,30m,1h,2h,3d,1w
# 45                          5m,8h             1h,2h,4h,8h,12h,3d,1w
# 46                30m,1h,2h,4h,8h                   5m,15m,1d,3d,1w
# 47           15m,30m,1h,4h,8h,12h                    2h,8h,1d,3d,1w
#
#                     stkdown                     uptrend  \
# 0           5m,8h,12h,1d,3d                          1h
# 1             5m,15m,12h,1d                    1h,2h,4h
# 2                    15m,3d       5m,1h,2h,4h,8h,12h,1d
# 3              4h,8h,12h,1d               15m,30m,1h,2h
# 4                 8h,12h,1d         5m,15m,30m,1h,2h,4h
# 5                  5m,8h,1d             1h,2h,4h,12h,3d
# 6                 8h,12h,1d               15m,30m,1h,4h
# 7              2h,8h,12h,1d                30m,1h,4h,1w
# 8                  5m,8h,1d            30m,1h,4h,12h,1w
# 9                    12h,1d                   15m,2h,3d
# 10                8h,12h,1d             30m,1h,2h,4h,3d
# 11                      15m    5m,2h,4h,8h,12h,1d,3d,1w
# 12                    8h,1d      15m,30m,1h,2h,4h,3d,1w
# 13               15m,30m,1d                   5m,8h,12h
# 14                       1d            15m,1h,4h,12h,3d
# 15            15m,12h,1d,1w             30m,1h,2h,4h,3d
# 16   5m,15m,8h,12h,1d,3d,1w                   30m,1h,2h
# 17                   12h,1d             15m,1h,2h,4h,8h
# 18          5m,15m,1d,3d,1w                    2h,4h,8h
# 19            5m,15m,30m,1h          2h,4h,8h,12h,3d,1w
# 20          5m,8h,12h,1d,3d                       1h,2h
# 21             8h,12h,1d,1w            5m,15m,30m,1h,2h
# 22             8h,12h,1d,3d                       1h,2h
# 23             5m,8h,12h,1d         15m,30m,1h,2h,4h,3d
# 24             8h,12h,1d,1w                30m,1h,2h,4h
# 25             8h,12h,1d,1w                15m,1h,2h,4h
# 26                8h,12h,1d                30m,1h,2h,1w
# 27       5m,2h,4h,8h,12h,1d                   30m,1h,1w
# 28                4h,8h,12h             5m,30m,1h,2h,1w
# 29       5m,2h,8h,12h,1d,1w               15m,30m,1h,4h
# 30                4h,8h,12h         5m,15m,30m,1h,2h,1w
# 31  5m,15m,30m,4h,8h,12h,1w                       1h,1d
# 32         5m,15m,4h,8h,12h                    2h,1d,1w
# 33             8h,12h,1d,1w                   30m,1h,2h
# 34                   15m,8h   5m,30m,1h,2h,12h,1d,3d,1w
# 35             5m,8h,12h,1d            15m,30m,1h,2h,4h
# 36                   5m,15m       2h,4h,8h,12h,1d,3d,1w
# 37                      NaN  15m,30m,1h,2h,12h,1d,3d,1w
# 38             8h,12h,1d,3d             5m,30m,1h,2h,4h
# 39                8h,12h,1d             15m,1h,2h,4h,1w
# 40     15m,30m,8h,12h,1d,1w                    1h,2h,4h
# 41           5m,1h,2h,8h,1d                          1w
# 42         30m,4h,8h,12h,1d                      15m,1w
# 43                    5m,4h      30m,1h,8h,12h,1d,3d,1w
# 44             4h,8h,12h,1d         15m,30m,1h,2h,3d,1w
# 45                    5m,1d          1h,2h,4h,12h,3d,1w
# 46      30m,1h,2h,4h,8h,12h                      15m,1w
# 47     5m,15m,30m,1h,4h,12h                    1d,3d,1w
#
#                    dshift     downtrend                    shift  \
# 0                  15m,3d            5m         30m,4h,8h,12h,1d
# 1               12h,3d,1w           NaN             5m,15m,8h,1d
# 2                      1w            3d                  15m,30m
# 3                   3d,1w     8h,12h,1d                       4h
# 4                      3d           NaN                8h,12h,1d
# 5                      5m           NaN            15m,30m,8h,1d
# 6                      3d     8h,12h,1d                       2h
# 7                  12h,3d         8h,1d                       2h
# 8                   5m,3d           NaN                 2h,8h,1d
# 9                     12h           NaN                30m,8h,1d
# 10                     1w           NaN             5m,8h,12h,1d
# 11                    NaN           NaN                  15m,30m
# 12                     5m           NaN                8h,12h,1d
# 13               2h,4h,3d           NaN                   15m,1d
# 14                    NaN           NaN                30m,8h,1d
# 15                    NaN            1w            15m,8h,12h,1d
# 16                    15m            1w          4h,8h,12h,1d,3d
# 17                     3d           NaN               30m,12h,1d
# 18                     5m           15m             12h,1d,3d,1w
# 19                     1h    5m,15m,30m                      NaN
# 20                    NaN           NaN  15m,30m,4h,8h,12h,1d,3d
# 21                     3d  8h,12h,1d,1w                       4h
# 22                  3d,1w     8h,12h,1d                    5m,4h
# 23                     1w           NaN             5m,8h,12h,1d
# 24                     3d  8h,12h,1d,1w                      NaN
# 25                     3d            1w                8h,12h,1d
# 26                     3d           NaN             4h,8h,12h,1d
# 27          5m,15m,12h,3d   2h,4h,8h,1d                      NaN
# 28              12h,1d,3d            8h                   15m,4h
# 29              5m,12h,3d         8h,1d                       1w
# 30                  1d,3d        8h,12h                       4h
# 31           5m,12h,3d,1w           15m                   30m,8h
# 32                    12h        5m,15m                    4h,8h
# 33                 12h,3d            1w                 4h,8h,1d
# 34                    15m           NaN                    4h,8h
# 35               5m,3d,1w           NaN                8h,12h,1d
# 36                 30m,1h            5m                      15m
# 37                     5m           NaN                       4h
# 38                  3d,1w           NaN                8h,12h,1d
# 39                     3d           NaN            30m,8h,12h,1d
# 40              12h,1d,3d           NaN            15m,30m,8h,1w
# 41  5m,1h,4h,8h,12h,1d,3d            2h                  15m,30m
# 42           2h,4h,12h,3d           NaN                    8h,1d
# 43                     4h           NaN                5m,15m,2h
# 44                    NaN           NaN             4h,8h,12h,1d
# 45                     1d           NaN                       8h
# 46              12h,1d,3d      2h,4h,8h                   30m,1h
# 47                  5m,2h        15m,4h            30m,1h,8h,12h
#
#                          buyzones
# 0                    1h,8h,12h,1d
# 1           5m,1h,2h,4h,8h,12h,1d
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d
# 3                 5m,30m,1h,2h,4h
# 4           5m,1h,2h,4h,8h,12h,1d
# 5              1h,2h,4h,8h,12h,3d
# 6                    30m,1h,2h,4h
# 7                    30m,1h,2h,4h
# 8             30m,1h,2h,4h,8h,12h
# 9             15m,2h,8h,12h,1d,3d
# 10          5m,2h,4h,8h,12h,1d,3d
# 11         5m,15m,8h,12h,1d,3d,1w
# 12             2h,4h,8h,12h,3d,1w
# 13                  5m,15m,12h,1d
# 14            15m,4h,8h,12h,1d,3d
# 15          1h,2h,4h,8h,12h,1d,3d
# 16          1h,2h,4h,8h,12h,1d,3d
# 17                2h,4h,8h,12h,1d
# 18       5m,2h,4h,8h,12h,1d,3d,1w
# 19                             1w
# 20          1h,2h,4h,8h,12h,1d,3d
# 21                       1h,2h,4h
# 22                       1h,2h,4h
# 23       5m,1h,2h,4h,8h,12h,1d,3d
# 24                       1h,2h,4h
# 25             1h,2h,4h,8h,12h,1d
# 26             1h,2h,4h,8h,12h,1d
# 27                          1h,1w
# 28               15m,30m,1h,2h,4h
# 29                  15m,30m,1h,4h
# 30                    5m,1h,2h,4h
# 31                   1h,8h,12h,1d
# 32                2h,4h,8h,12h,1w
# 33             1h,2h,4h,8h,12h,1d
# 34   5m,15m,1h,2h,4h,8h,12h,3d,1w
# 35         30m,1h,2h,4h,8h,12h,1d
# 36                          2h,1w
# 37                       1h,2h,1w
# 38             1h,2h,4h,8h,12h,1d
# 39         15m,1h,2h,4h,8h,12h,1d
# 40                2h,4h,8h,12h,1d
# 41                  5m,15m,30m,1h
# 42                     15m,12h,1w
# 43      5m,30m,1h,2h,4h,8h,12h,1w
# 44       1h,2h,4h,8h,12h,1d,3d,1w
# 45             2h,4h,8h,12h,3d,1w
# 46                     15m,30m,1h
# 47                      1h,12h,1w

# %%
## MACD gap 1 Week and rsi up
newframe=callfun(macd1wd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]


test=buyzonesa(test)
#test=test.loc[test['buyzones']>='1h']
test
# Out:
#     Indicator      stkcross                                rsiup  \
# 0     FILUSDT           NaN                     30m,1h,8h,12h,1d
# 1    GLMRUSDT        2h,12h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 2     MIRUSDT        12h,1d        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 3    REEFUSDT            2h                  5m,15m,30m,1h,2h,4h
# 4     SRMUSDT        15m,4h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5     RAYUSDT         2h,4h        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 6     ONEUSDT            4h                     15m,30m,1h,2h,4h
# 7    AVAXUSDT           NaN               5m,15m,30m,1h,2h,4h,1w
# 8   TFUELUSDT    15m,30m,4h         5m,30m,1h,2h,4h,8h,12h,1d,1w
# 9    ATOMUSDT           NaN        5m,15m,30m,1h,2h,8h,12h,1d,3d
# 10   ROSEUSDT            4h     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 11   SCRTUSDT         5m,1d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12   RUNEUSDT         4h,1w     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13    KSMUSDT            8h                     5m,15m,8h,12h,1d
# 14  SUSHIUSDT            4h                  5m,15m,30m,1h,2h,4h
# 15    DOTUSDT           NaN           15m,30m,1h,4h,8h,12h,1d,3d
# 16    ZILUSDT            4h        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 17   WAXPUSDT            4h                         30m,1h,2h,4h
# 18  1INCHUSDT            2h            30m,1h,2h,4h,8h,12h,1d,3d
# 19   FLUXUSDT     15m,4h,8h           15m,30m,1h,2h,4h,8h,12h,1d
# 20    IMXUSDT      2h,4h,8h             5m,2h,4h,8h,12h,1d,3d,1w
# 21    HNTUSDT            8h                2h,4h,8h,12h,1d,3d,1w
# 22    CRVUSDT           NaN        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 23    ZRXUSDT           NaN                  5m,15m,30m,1h,2h,4h
# 24    GRTUSDT            1w                     15m,30m,1h,2h,4h
# 25   GALAUSDT            4h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 26   NEARUSDT  15m,2h,4h,1w     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 27   CELRUSDT            4h                  5m,15m,30m,1h,2h,4h
# 28    FTMUSDT            4h           15m,30m,1h,2h,4h,8h,12h,1d
# 29    ONTUSDT            2h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 30   LINKUSDT            1h                         5m,30m,1h,1w
# 31     ARUSDT            2h               5m,15m,30m,1h,2h,4h,1w
# 32   CAKEUSDT           30m                  5m,15m,30m,1h,4h,1w
# 33   LINAUSDT     15m,2h,1w               5m,15m,30m,1h,2h,4h,1w
# 34    ANTUSDT           NaN                  30m,1h,8h,12h,1d,1w
# 35    RENUSDT            1w                   2h,4h,8h,12h,1d,1w
# 36   VTHOUSDT            2h               30m,1h,2h,4h,8h,12h,1d
# 37    WINUSDT            2h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38   ANKRUSDT            4h           15m,30m,1h,2h,4h,8h,12h,1d
# 39    OMGUSDT        30m,1w            15m,2h,4h,8h,12h,1d,3d,1w
# 40   COTIUSDT        15m,2h     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 41    VETUSDT      2h,4h,1w        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 42    LRCUSDT        15m,4h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 43   IOTXUSDT            4h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 44   ALGOUSDT            1w                     5m,15m,30m,1h,1w
# 45   BANDUSDT        15m,4h                     15m,8h,12h,1d,1w
# 46    XLMUSDT            2h        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 47    XTZUSDT        8h,12h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 48   DENTUSDT           15m     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 49  MATICUSDT           NaN     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 50  AUDIOUSDT            1w                        15m,30m,1h,1w
# 51   CTSIUSDT           NaN               30m,1h,8h,12h,1d,3d,1w
#
#                    rsidown                     tops          bottoms    topr  \
# 0             5m,15m,3d,1w                      30m         8h,3d,1w     NaN
# 1                    3d,1w                  15m,30m               8h     NaN
# 2                    3d,1w                      NaN        12h,1d,1w     NaN
# 3          8h,12h,1d,3d,1w                   15m,1d        8h,12h,1w     NaN
# 4                    3d,1w                  15m,30m            3d,1w     NaN
# 5                       1w               15m,30m,1d            2h,1w     NaN
# 6          8h,12h,1d,3d,1w                   5m,15m               1w     NaN
# 7             8h,12h,1d,3d                5m,15m,1d               1w     NaN
# 8                       3d                5m,15m,1d               1w     NaN
# 9                       1w                5m,30m,1h               1w     NaN
# 10                      1w               15m,30m,1h               1w     NaN
# 11                     NaN             30m,1h,2h,4h         1d,3d,1w     NaN
# 12                      5m         5m,15m,30m,1h,1d         8h,3d,1w     NaN
# 13             2h,4h,3d,1w                   30m,1h            8h,1w     NaN
# 14            8h,12h,3d,1w               5m,15m,30m        8h,12h,1w      5m
# 15                      1w                5m,30m,1h        8h,12h,1w     NaN
# 16                      1w                  15m,30m        8h,12h,1w     NaN
# 17     15m,8h,12h,1d,3d,1w               5m,15m,30m        8h,12h,1w     NaN
# 18                      1w                  15m,30m     8h,12h,1d,1w     NaN
# 19                   3d,1w            5m,15m,30m,1h           8h,12h     NaN
# 20                     15m                  15m,30m               8h     NaN
# 21           5m,15m,30m,1h          1h,2h,12h,1d,3d            5m,1w      8h
# 22                      1w                  15m,30m      4h,8h,3d,1w     NaN
# 23         8h,12h,1d,3d,1w               5m,15m,30m         4h,8h,1w     NaN
# 24         8h,12h,1d,3d,1w                  15m,30m         4h,8h,1w     NaN
# 25                   5m,3d               5m,15m,30m         4h,8h,1w      5m
# 26                      1w                  15m,30m  4h,8h,12h,3d,1w     NaN
# 27         8h,12h,1d,3d,1w               5m,15m,30m     4h,8h,12h,1w     NaN
# 28                   3d,1w               5m,15m,30m     4h,8h,12h,1w     NaN
# 29                      3d                  15m,30m            4h,1w     NaN
# 30  15m,2h,4h,8h,12h,1d,3d             5m,12h,1d,3d     30m,1h,2h,1w     NaN
# 31            8h,12h,1d,3d             5m,8h,12h,1d            2h,1w     NaN
# 32            8h,12h,1d,3d                    5m,1d            2h,1w     NaN
# 33            8h,12h,1d,3d           15m,30m,12h,1d            2h,1w     NaN
# 34               5m,15m,3d                  15m,30m            2h,1w     NaN
# 35                  5m,15m               15m,30m,1d            2h,1w     NaN
# 36                   3d,1w               5m,15m,30m            2h,1w     NaN
# 37                     NaN                   30m,1d            2h,1w     NaN
# 38                5m,3d,1w                      15m               1w     NaN
# 39               5m,30m,1h      30m,1h,4h,8h,12h,1d               1w     NaN
# 40                      5m  15m,30m,4h,8h,12h,1d,3d               1w     NaN
# 41                   3d,1w               5m,15m,30m               1w     NaN
# 42                      3d                   5m,30m               1w     NaN
# 43                      3d               15m,30m,1h               1w     NaN
# 44      2h,4h,8h,12h,1d,3d             4h,8h,12h,1d               1w     NaN
# 45                2h,4h,3d                   30m,1d               1w     NaN
# 46                      1w            5m,15m,30m,3d               1w     NaN
# 47                     NaN                15m,1d,3d               1w     NaN
# 48                     NaN               5m,15m,30m               1w     NaN
# 49                     NaN            15m,30m,1h,1d               1w  5m,15m
# 50      2h,4h,8h,12h,1d,3d          5m,4h,8h,12h,1d    15m,30m,1h,1w     NaN
# 51            5m,15m,2h,4h                 8h,1d,3d           15m,1w     NaN
#
#      bottomr                            stover  \
# 0      3d,1w                      15m,1h,2h,3d
# 1      3d,1w            30m,1h,2h,4h,12h,3d,1w
# 2      3d,1w          5m,1h,2h,4h,8h,12h,1d,1w
# 3         3d            5m,15m,30m,1h,2h,3d,1w
# 4         3d            5m,15m,30m,1h,2h,4h,3d
# 5         3d                5m,1h,2h,4h,12h,3d
# 6         3d               5m,15m,30m,1h,4h,3d
# 7         3d        5m,15m,30m,1h,4h,12h,3d,1w
# 8         3d        5m,15m,30m,1h,4h,12h,3d,1w
# 9         3d            5m,15m,1h,2h,4h,12h,3d
# 10        3d            15m,30m,1h,2h,4h,3d,1w
# 11  1d,3d,1w       5m,1h,2h,4h,8h,12h,1d,3d,1w
# 12       NaN         5m,15m,30m,1h,2h,4h,3d,1w
# 13       NaN             5m,1h,2h,4h,8h,12h,3d
# 14       NaN         5m,15m,30m,1h,2h,4h,3d,1w
# 15       NaN            5m,15m,1h,2h,4h,12h,3d
# 16       NaN                5m,30m,1h,2h,4h,3d
# 17       NaN             5m,30m,1h,2h,4h,3d,1w
# 18       NaN                     15m,30m,1h,2h
# 19       NaN             5m,15m,1h,2h,4h,8h,3d
# 20       NaN                5m,30m,1h,2h,4h,8h
# 21       NaN          1h,2h,4h,8h,12h,1d,3d,1w
# 22       NaN                             1h,2h
# 23       NaN               5m,15m,30m,1h,2h,3d
# 24       NaN               15m,30m,1h,2h,3d,1w
# 25       NaN             5m,15m,1h,2h,4h,3d,1w
# 26       NaN            15m,30m,1h,2h,4h,3d,1w
# 27       NaN                   30m,1h,2h,4h,3d
# 28       NaN            5m,15m,30m,1h,2h,4h,3d
# 29       NaN                5m,30m,1h,2h,3d,1w
# 30       NaN           5m,15m,30m,1h,12h,3d,1w
# 31       NaN         5m,30m,1h,2h,12h,1d,3d,1w
# 32       NaN           5m,15m,30m,1h,4h,12h,3d
# 33       NaN         5m,15m,30m,1h,2h,1d,3d,1w
# 34       NaN             5m,1h,2h,12h,1d,3d,1w
# 35       NaN                1h,2h,12h,1d,3d,1w
# 36       NaN              15m,30m,1h,2h,12h,3d
# 37       NaN     5m,15m,30m,1h,2h,12h,1d,3d,1w
# 38       NaN         5m,15m,30m,1h,2h,4h,3d,1w
# 39       NaN      30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40       NaN  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 41       NaN         5m,15m,30m,1h,2h,4h,3d,1w
# 42       NaN             5m,15m,1h,2h,4h,3d,1w
# 43       NaN             5m,1h,2h,4h,12h,1d,3d
# 44       NaN          5m,1h,4h,8h,12h,1d,3d,1w
# 45       NaN         5m,15m,1h,2h,4h,12h,3d,1w
# 46       NaN  5m,15m,30m,1h,2h,4h,8h,12h,3d,1w
# 47       NaN         30m,1h,4h,8h,12h,1d,3d,1w
# 48       NaN            5m,15m,30m,1h,2h,3d,1w
# 49       NaN         30m,1h,2h,4h,12h,1d,3d,1w
# 50       NaN               5m,15m,12h,1d,3d,1w
# 51       NaN                    5m,2h,1d,3d,1w
#
#                                    room                                roomr  \
# 0       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1           5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3          5m,30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4           5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5              5m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 6          30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 7             30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8             30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 9             15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 10             5m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 11               5m,15m,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 12                   2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 13         5m,15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 14             1h,2h,4h,8h,12h,1d,3d,1w     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15            15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 18          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 19                   2h,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 20          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 21                  5m,15m,30m,4h,8h,1w     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 22          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 23             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 24          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 25             1h,2h,4h,8h,12h,1d,3d,1w     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 26          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 27             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 28             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 29          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30               15m,30m,1h,2h,4h,8h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 31               15m,30m,1h,2h,4h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 32        15m,30m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 33                 5m,1h,2h,4h,8h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 34          5m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 35             5m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 36             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 37         5m,15m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 38      5m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 39                      5m,15m,2h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40                          5m,1h,2h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 41             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 42         15m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 43             5m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 44               5m,15m,30m,1h,2h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 45         5m,15m,1h,2h,4h,8h,12h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46                1h,2h,4h,8h,12h,1d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 47            5m,30m,1h,2h,4h,8h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 48             1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 49                5m,2h,4h,8h,12h,3d,1w         30m,1h,2h,4h,8h,12h,1d,3d,1w
# 50                  15m,30m,1h,2h,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 51           5m,15m,30m,1h,2h,4h,12h,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                           stunder                             stkup  \
# 0             5m,30m,4h,8h,12h,1d                  15m,30m,1h,2h,4h
# 1                    5m,15m,8h,1d                 1h,2h,4h,8h,3d,1w
# 2                      15m,30m,3d      5m,30m,1h,2h,4h,8h,12h,1d,1w
# 3                    4h,8h,12h,1d               15m,30m,1h,2h,3d,1w
# 4                    8h,12h,1d,1w            5m,15m,30m,1h,2h,4h,3d
# 5                   15m,30m,8h,1d               15m,1h,2h,4h,12h,3d
# 6                    2h,8h,12h,1d            5m,15m,30m,1h,2h,4h,3d
# 7                        2h,8h,1d                   30m,1h,4h,3d,1w
# 8                        2h,8h,1d        15m,30m,1h,2h,4h,12h,3d,1w
# 9                    30m,8h,1d,1w                   15m,2h,4h,8h,3d
# 10                   5m,8h,12h,1d             5m,30m,1h,2h,4h,3d,1w
# 11                        15m,30m      5m,30m,2h,4h,8h,12h,1d,3d,1w
# 12                      8h,12h,1d     5m,15m,30m,1h,2h,4h,12h,3d,1w
# 13                     15m,30m,1d             5m,1h,2h,4h,8h,12h,3d
# 14                      8h,12h,1d             5m,30m,1h,2h,4h,3d,1w
# 15                      30m,8h,1d         5m,15m,1h,2h,4h,8h,12h,3d
# 16               15m,8h,12h,1d,1w             5m,30m,1h,2h,4h,8h,3d
# 17                  15m,8h,12h,1d                30m,1h,2h,4h,3d,1w
# 18          5m,4h,8h,12h,1d,3d,1w                      30m,1h,2h,4h
# 19                     30m,12h,1d             5m,15m,1h,2h,4h,8h,3d
# 20               15m,12h,1d,3d,1w               30m,1h,2h,4h,8h,12h
# 21                     5m,15m,30m                2h,4h,8h,12h,3d,1w
# 22  5m,15m,30m,4h,8h,12h,1d,3d,1w                      15m,1h,2h,4h
# 23                4h,8h,12h,1d,1w            5m,15m,30m,1h,2h,4h,3d
# 24                5m,4h,8h,12h,1d                    5m,1h,2h,4h,1w
# 25                      8h,12h,1d                 5m,1h,2h,4h,3d,1w
# 26                   5m,8h,12h,1d               15m,30m,1h,2h,4h,3d
# 27                   8h,12h,1d,1w                   30m,1h,2h,4h,3d
# 28                   8h,12h,1d,1w                5m,15m,1h,2h,4h,3d
# 29                   4h,8h,12h,1d             5m,30m,1h,2h,4h,3d,1w
# 30                    2h,4h,8h,1d                  15m,30m,1h,3d,1w
# 31                      15m,4h,8h             5m,30m,1h,2h,1d,3d,1w
# 32                    2h,8h,1d,1w                  15m,30m,1h,4h,3d
# 33                      4h,8h,12h         5m,15m,30m,1h,2h,1d,3d,1w
# 34                  15m,30m,4h,8h                       1h,2h,1d,3d
# 35               5m,15m,30m,4h,8h                    1h,2h,1d,3d,1w
# 36                 5m,4h,8h,1d,1w               15m,30m,1h,2h,4h,3d
# 37                          4h,8h      5m,30m,1h,2h,4h,12h,1d,3d,1w
# 38                      8h,12h,1d            15m,30m,1h,2h,4h,3d,1w
# 39                         5m,15m      30m,1h,2h,4h,8h,12h,1d,3d,1w
# 40                             4h  5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 41                      8h,12h,1d                5m,30m,1h,2h,4h,1w
# 42                  30m,8h,12h,1d         5m,15m,30m,1h,2h,4h,3d,1w
# 43                  15m,30m,8h,1w                    5m,1h,2h,4h,3d
# 44                     15m,30m,2h              15m,30m,4h,12h,3d,1w
# 45                      30m,8h,1d                5m,15m,1h,2h,3d,1w
# 46                             1d  5m,15m,30m,1h,2h,4h,8h,12h,3d,1w
# 47                      5m,15m,2h         30m,1h,2h,8h,12h,1d,3d,1w
# 48                   4h,8h,12h,1d            5m,15m,30m,1h,2h,3d,1w
# 49                          5m,8h             1h,2h,4h,8h,12h,3d,1w
# 50                30m,1h,2h,4h,8h                   5m,15m,1d,3d,1w
# 51           15m,30m,1h,4h,8h,12h                    2h,8h,1d,3d,1w
#
#                     stkdown                     uptrend  \
# 0           5m,8h,12h,1d,3d                          1h
# 1             5m,15m,12h,1d                    1h,2h,4h
# 2                    15m,3d       5m,1h,2h,4h,8h,12h,1d
# 3              4h,8h,12h,1d               15m,30m,1h,2h
# 4                 8h,12h,1d         5m,15m,30m,1h,2h,4h
# 5                  5m,8h,1d             1h,2h,4h,12h,3d
# 6                 8h,12h,1d               15m,30m,1h,4h
# 7              2h,8h,12h,1d                30m,1h,4h,1w
# 8                  5m,8h,1d            30m,1h,4h,12h,1w
# 9                    12h,1d                   15m,2h,3d
# 10                8h,12h,1d             30m,1h,2h,4h,3d
# 11                      15m    5m,2h,4h,8h,12h,1d,3d,1w
# 12                    8h,1d      15m,30m,1h,2h,4h,3d,1w
# 13               15m,30m,1d                   5m,8h,12h
# 14                8h,12h,1d             5m,30m,1h,2h,4h
# 15                       1d            15m,1h,4h,12h,3d
# 16            15m,12h,1d,1w             30m,1h,2h,4h,3d
# 17         5m,15m,8h,12h,1d                30m,1h,2h,4h
# 18   5m,15m,8h,12h,1d,3d,1w                   30m,1h,2h
# 19                   12h,1d             15m,1h,2h,4h,8h
# 20          5m,15m,1d,3d,1w                    2h,4h,8h
# 21            5m,15m,30m,1h          2h,4h,8h,12h,3d,1w
# 22          5m,8h,12h,1d,3d                       1h,2h
# 23             8h,12h,1d,1w            5m,15m,30m,1h,2h
# 24             8h,12h,1d,3d                       1h,2h
# 25                8h,12h,1d                 1h,2h,4h,1w
# 26             5m,8h,12h,1d         15m,30m,1h,2h,4h,3d
# 27             8h,12h,1d,1w                30m,1h,2h,4h
# 28             8h,12h,1d,1w                15m,1h,2h,4h
# 29                8h,12h,1d                30m,1h,2h,1w
# 30       5m,2h,4h,8h,12h,1d                   30m,1h,1w
# 31                4h,8h,12h             5m,30m,1h,2h,1w
# 32       5m,2h,8h,12h,1d,1w               15m,30m,1h,4h
# 33                4h,8h,12h         5m,15m,30m,1h,2h,1w
# 34  5m,15m,30m,4h,8h,12h,1w                       1h,1d
# 35         5m,15m,4h,8h,12h                    2h,1d,1w
# 36             8h,12h,1d,1w                   30m,1h,2h
# 37                   15m,8h   5m,30m,1h,2h,12h,1d,3d,1w
# 38             5m,8h,12h,1d            15m,30m,1h,2h,4h
# 39                   5m,15m       2h,4h,8h,12h,1d,3d,1w
# 40                      NaN  15m,30m,1h,2h,12h,1d,3d,1w
# 41             8h,12h,1d,3d             5m,30m,1h,2h,4h
# 42                8h,12h,1d             15m,1h,2h,4h,1w
# 43     15m,30m,8h,12h,1d,1w                    1h,2h,4h
# 44           5m,1h,2h,8h,1d                          1w
# 45         30m,4h,8h,12h,1d                      15m,1w
# 46                       1d  15m,30m,1h,2h,4h,8h,12h,3d
# 47                    5m,4h      30m,1h,8h,12h,1d,3d,1w
# 48             4h,8h,12h,1d         15m,30m,1h,2h,3d,1w
# 49                    5m,1d          1h,2h,4h,12h,3d,1w
# 50      30m,1h,2h,4h,8h,12h                      15m,1w
# 51     5m,15m,30m,1h,4h,12h                    1d,3d,1w
#
#                    dshift      downtrend                    shift  \
# 0                  15m,3d             5m         30m,4h,8h,12h,1d
# 1               12h,3d,1w            NaN             5m,15m,8h,1d
# 2                      1w             3d                  15m,30m
# 3                   3d,1w      8h,12h,1d                       4h
# 4                      3d            NaN                8h,12h,1d
# 5                      5m            NaN            15m,30m,8h,1d
# 6                      3d      8h,12h,1d                       2h
# 7                  12h,3d          8h,1d                       2h
# 8                   5m,3d            NaN                 2h,8h,1d
# 9                     12h            NaN                30m,8h,1d
# 10                     1w            NaN             5m,8h,12h,1d
# 11                    NaN            NaN                  15m,30m
# 12                     5m            NaN                8h,12h,1d
# 13               2h,4h,3d            NaN                   15m,1d
# 14                  3d,1w         8h,12h                      NaN
# 15                    NaN            NaN                30m,8h,1d
# 16                    NaN             1w            15m,8h,12h,1d
# 17               5m,3d,1w  15m,8h,12h,1d                      NaN
# 18                    15m             1w          4h,8h,12h,1d,3d
# 19                     3d            NaN               30m,12h,1d
# 20                     5m            15m             12h,1d,3d,1w
# 21                     1h     5m,15m,30m                      NaN
# 22                    NaN            NaN  15m,30m,4h,8h,12h,1d,3d
# 23                     3d   8h,12h,1d,1w                       4h
# 24                  3d,1w      8h,12h,1d                    5m,4h
# 25                  5m,3d            NaN                8h,12h,1d
# 26                     1w            NaN             5m,8h,12h,1d
# 27                     3d   8h,12h,1d,1w                      NaN
# 28                     3d             1w                8h,12h,1d
# 29                     3d            NaN             4h,8h,12h,1d
# 30          5m,15m,12h,3d    2h,4h,8h,1d                      NaN
# 31              12h,1d,3d             8h                   15m,4h
# 32              5m,12h,3d          8h,1d                       1w
# 33                  1d,3d         8h,12h                       4h
# 34           5m,12h,3d,1w            15m                   30m,8h
# 35                    12h         5m,15m                    4h,8h
# 36                 12h,3d             1w                 4h,8h,1d
# 37                    15m            NaN                    4h,8h
# 38               5m,3d,1w            NaN                8h,12h,1d
# 39                 30m,1h             5m                      15m
# 40                     5m            NaN                       4h
# 41                  3d,1w            NaN                8h,12h,1d
# 42                     3d            NaN            30m,8h,12h,1d
# 43              12h,1d,3d            NaN            15m,30m,8h,1w
# 44  5m,1h,4h,8h,12h,1d,3d             2h                  15m,30m
# 45           2h,4h,12h,3d            NaN                    8h,1d
# 46                     1w            NaN                       1d
# 47                     4h            NaN                5m,15m,2h
# 48                    NaN            NaN             4h,8h,12h,1d
# 49                     1d            NaN                       8h
# 50              12h,1d,3d       2h,4h,8h                   30m,1h
# 51                  5m,2h         15m,4h            30m,1h,8h,12h
#
#                          buyzones
# 0                    1h,8h,12h,1d
# 1           5m,1h,2h,4h,8h,12h,1d
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d
# 3                 5m,30m,1h,2h,4h
# 4           5m,1h,2h,4h,8h,12h,1d
# 5              1h,2h,4h,8h,12h,3d
# 6                    30m,1h,2h,4h
# 7                    30m,1h,2h,4h
# 8             30m,1h,2h,4h,8h,12h
# 9             15m,2h,8h,12h,1d,3d
# 10          5m,2h,4h,8h,12h,1d,3d
# 11         5m,15m,8h,12h,1d,3d,1w
# 12             2h,4h,8h,12h,3d,1w
# 13                  5m,15m,12h,1d
# 14                       1h,2h,4h
# 15            15m,4h,8h,12h,1d,3d
# 16          1h,2h,4h,8h,12h,1d,3d
# 17                       1h,2h,4h
# 18          1h,2h,4h,8h,12h,1d,3d
# 19                2h,4h,8h,12h,1d
# 20       5m,2h,4h,8h,12h,1d,3d,1w
# 21                             1w
# 22          1h,2h,4h,8h,12h,1d,3d
# 23                       1h,2h,4h
# 24                       1h,2h,4h
# 25             1h,2h,4h,8h,12h,1d
# 26       5m,1h,2h,4h,8h,12h,1d,3d
# 27                       1h,2h,4h
# 28             1h,2h,4h,8h,12h,1d
# 29             1h,2h,4h,8h,12h,1d
# 30                          1h,1w
# 31               15m,30m,1h,2h,4h
# 32                  15m,30m,1h,4h
# 33                    5m,1h,2h,4h
# 34                   1h,8h,12h,1d
# 35                2h,4h,8h,12h,1w
# 36             1h,2h,4h,8h,12h,1d
# 37   5m,15m,1h,2h,4h,8h,12h,3d,1w
# 38         30m,1h,2h,4h,8h,12h,1d
# 39                          2h,1w
# 40                       1h,2h,1w
# 41             1h,2h,4h,8h,12h,1d
# 42         15m,1h,2h,4h,8h,12h,1d
# 43                2h,4h,8h,12h,1d
# 44                  5m,15m,30m,1h
# 45                     15m,12h,1w
# 46             1h,2h,4h,8h,12h,1d
# 47      5m,30m,1h,2h,4h,8h,12h,1w
# 48       1h,2h,4h,8h,12h,1d,3d,1w
# 49             2h,4h,8h,12h,3d,1w
# 50                     15m,30m,1h
# 51                      1h,12h,1w

# %%
## MACD gap 1 Week stk cross
newframe=callfun(stk1w,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['uptrend'] < '1d') &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['downtrend'].isnull()) ]



test=buyzones(test)
#test=test.loc[test['buyzones']>='1h']
test
# Out:
# Empty DataFrame
# Columns: [stkcross, rsiup, rsidown, tops, bottoms, topr, bottomr, stover, room, roomr, stunder, stkup, stkdown, uptrend, dshift, downtrend, shift, Indicator, buyzones]
# Index: []

# %%
#hihi5macd1w
## MACD gap 1 Week and hihi5m
newframe=callfun(hihi5macd1w,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]


test=buyzonesa(test)
#test=test.loc[test['buyzones']>='1h']
test
# Out:
#     Indicator   stkcross                                rsiup  \
# 0    GLMRUSDT     2h,12h        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 1    ATOMUSDT        NaN        5m,15m,30m,1h,2h,8h,12h,1d,3d
# 2    ROSEUSDT         4h     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 3   SUSHIUSDT         4h                  5m,15m,30m,1h,2h,4h
# 4     ZILUSDT         4h        15m,30m,1h,2h,4h,8h,12h,1d,3d
# 5   1INCHUSDT         2h            30m,1h,2h,4h,8h,12h,1d,3d
# 6    FLUXUSDT  15m,4h,8h           15m,30m,1h,2h,4h,8h,12h,1d
# 7     ZRXUSDT        NaN                  5m,15m,30m,1h,2h,4h
# 8     GRTUSDT         1w                     15m,30m,1h,2h,4h
# 9    GALAUSDT         4h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 10   CELRUSDT         4h                  5m,15m,30m,1h,2h,4h
# 11    ONTUSDT         2h        15m,30m,1h,2h,4h,8h,12h,1d,1w
# 12   VTHOUSDT         2h               30m,1h,2h,4h,8h,12h,1d
# 13    WINUSDT         2h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 14   ANKRUSDT         4h           15m,30m,1h,2h,4h,8h,12h,1d
# 15   COTIUSDT     15m,2h     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 16    XTZUSDT     8h,12h  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17  MATICUSDT        NaN     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#             rsidown                     tops       bottoms    topr bottomr  \
# 0             3d,1w                  15m,30m            8h     NaN   3d,1w
# 1                1w                5m,30m,1h            1w     NaN      3d
# 2                1w               15m,30m,1h            1w     NaN      3d
# 3      8h,12h,3d,1w               5m,15m,30m     8h,12h,1w      5m     NaN
# 4                1w                  15m,30m     8h,12h,1w     NaN     NaN
# 5                1w                  15m,30m  8h,12h,1d,1w     NaN     NaN
# 6             3d,1w            5m,15m,30m,1h        8h,12h     NaN     NaN
# 7   8h,12h,1d,3d,1w               5m,15m,30m      4h,8h,1w     NaN     NaN
# 8   8h,12h,1d,3d,1w                  15m,30m      4h,8h,1w     NaN     NaN
# 9             5m,3d               5m,15m,30m      4h,8h,1w      5m     NaN
# 10  8h,12h,1d,3d,1w               5m,15m,30m  4h,8h,12h,1w     NaN     NaN
# 11               3d                  15m,30m         4h,1w     NaN     NaN
# 12            3d,1w               5m,15m,30m         2h,1w     NaN     NaN
# 13              NaN                   30m,1d         2h,1w     NaN     NaN
# 14         5m,3d,1w                      15m            1w     NaN     NaN
# 15               5m  15m,30m,4h,8h,12h,1d,3d            1w     NaN     NaN
# 16              NaN                15m,1d,3d            1w     NaN     NaN
# 17              NaN            15m,30m,1h,1d            1w  5m,15m     NaN
#
#                               stover                             room  \
# 0             30m,1h,2h,4h,12h,3d,1w      5m,1h,2h,4h,8h,12h,1d,3d,1w
# 1             5m,15m,1h,2h,4h,12h,3d        15m,2h,4h,8h,12h,1d,3d,1w
# 2             15m,30m,1h,2h,4h,3d,1w         5m,2h,4h,8h,12h,1d,3d,1w
# 3          5m,15m,30m,1h,2h,4h,3d,1w         1h,2h,4h,8h,12h,1d,3d,1w
# 4                 5m,30m,1h,2h,4h,3d      5m,1h,2h,4h,8h,12h,1d,3d,1w
# 5                      15m,30m,1h,2h      5m,1h,2h,4h,8h,12h,1d,3d,1w
# 6              5m,15m,1h,2h,4h,8h,3d               2h,4h,8h,12h,1d,3d
# 7                5m,15m,30m,1h,2h,3d         1h,2h,4h,8h,12h,1d,3d,1w
# 8                15m,30m,1h,2h,3d,1w      5m,1h,2h,4h,8h,12h,1d,3d,1w
# 9              5m,15m,1h,2h,4h,3d,1w         1h,2h,4h,8h,12h,1d,3d,1w
# 10                   30m,1h,2h,4h,3d         1h,2h,4h,8h,12h,1d,3d,1w
# 11                5m,30m,1h,2h,3d,1w      5m,1h,2h,4h,8h,12h,1d,3d,1w
# 12              15m,30m,1h,2h,12h,3d         1h,2h,4h,8h,12h,1d,3d,1w
# 13     5m,15m,30m,1h,2h,12h,1d,3d,1w     5m,15m,1h,2h,4h,8h,12h,3d,1w
# 14         5m,15m,30m,1h,2h,4h,3d,1w  5m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 15  5m,15m,30m,1h,2h,8h,12h,1d,3d,1w                      5m,1h,2h,1w
# 16         30m,1h,4h,8h,12h,1d,3d,1w        5m,30m,1h,2h,4h,8h,12h,1w
# 17         30m,1h,2h,4h,12h,1d,3d,1w            5m,2h,4h,8h,12h,3d,1w
#
#                                   roomr                stunder  \
# 0   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,15m,8h,1d
# 1   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           30m,8h,1d,1w
# 2   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,8h,12h,1d
# 3      15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 4   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w       15m,8h,12h,1d,1w
# 5   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,4h,8h,12h,1d,3d,1w
# 6   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w             30m,12h,1d
# 7   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w        4h,8h,12h,1d,1w
# 8   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w        5m,4h,8h,12h,1d
# 9      15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 10  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           8h,12h,1d,1w
# 11  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w           4h,8h,12h,1d
# 12  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w         5m,4h,8h,1d,1w
# 13  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                  4h,8h
# 14  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              8h,12h,1d
# 15  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w                     4h
# 16  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w              5m,15m,2h
# 17         30m,1h,2h,4h,8h,12h,1d,3d,1w                  5m,8h
#
#                                stkup                 stkdown  \
# 0                  1h,2h,4h,8h,3d,1w           5m,15m,12h,1d
# 1                    15m,2h,4h,8h,3d                  12h,1d
# 2              5m,30m,1h,2h,4h,3d,1w               8h,12h,1d
# 3              5m,30m,1h,2h,4h,3d,1w               8h,12h,1d
# 4              5m,30m,1h,2h,4h,8h,3d           15m,12h,1d,1w
# 5                       30m,1h,2h,4h  5m,15m,8h,12h,1d,3d,1w
# 6              5m,15m,1h,2h,4h,8h,3d                  12h,1d
# 7             5m,15m,30m,1h,2h,4h,3d            8h,12h,1d,1w
# 8                     5m,1h,2h,4h,1w            8h,12h,1d,3d
# 9                  5m,1h,2h,4h,3d,1w               8h,12h,1d
# 10                   30m,1h,2h,4h,3d            8h,12h,1d,1w
# 11             5m,30m,1h,2h,4h,3d,1w               8h,12h,1d
# 12               15m,30m,1h,2h,4h,3d            8h,12h,1d,1w
# 13      5m,30m,1h,2h,4h,12h,1d,3d,1w                  15m,8h
# 14            15m,30m,1h,2h,4h,3d,1w            5m,8h,12h,1d
# 15  5m,15m,30m,1h,2h,4h,12h,1d,3d,1w                     NaN
# 16         30m,1h,2h,8h,12h,1d,3d,1w                   5m,4h
# 17             1h,2h,4h,8h,12h,3d,1w                   5m,1d
#
#                        uptrend     dshift     downtrend            shift  \
# 0                     1h,2h,4h  12h,3d,1w           NaN     5m,15m,8h,1d
# 1                    15m,2h,3d        12h           NaN        30m,8h,1d
# 2              30m,1h,2h,4h,3d         1w           NaN     5m,8h,12h,1d
# 3              5m,30m,1h,2h,4h      3d,1w        8h,12h              NaN
# 4              30m,1h,2h,4h,3d        NaN            1w    15m,8h,12h,1d
# 5                    30m,1h,2h        15m            1w  4h,8h,12h,1d,3d
# 6              15m,1h,2h,4h,8h         3d           NaN       30m,12h,1d
# 7             5m,15m,30m,1h,2h         3d  8h,12h,1d,1w               4h
# 8                        1h,2h      3d,1w     8h,12h,1d            5m,4h
# 9                  1h,2h,4h,1w      5m,3d           NaN        8h,12h,1d
# 10                30m,1h,2h,4h         3d  8h,12h,1d,1w              NaN
# 11                30m,1h,2h,1w         3d           NaN     4h,8h,12h,1d
# 12                   30m,1h,2h     12h,3d            1w         4h,8h,1d
# 13   5m,30m,1h,2h,12h,1d,3d,1w        15m           NaN            4h,8h
# 14            15m,30m,1h,2h,4h   5m,3d,1w           NaN        8h,12h,1d
# 15  15m,30m,1h,2h,12h,1d,3d,1w         5m           NaN               4h
# 16      30m,1h,8h,12h,1d,3d,1w         4h           NaN        5m,15m,2h
# 17          1h,2h,4h,12h,3d,1w         1d           NaN               8h
#
#                         buyzones
# 0          5m,1h,2h,4h,8h,12h,1d
# 1            15m,2h,8h,12h,1d,3d
# 2          5m,2h,4h,8h,12h,1d,3d
# 3                       1h,2h,4h
# 4          1h,2h,4h,8h,12h,1d,3d
# 5          1h,2h,4h,8h,12h,1d,3d
# 6                2h,4h,8h,12h,1d
# 7                       1h,2h,4h
# 8                       1h,2h,4h
# 9             1h,2h,4h,8h,12h,1d
# 10                      1h,2h,4h
# 11            1h,2h,4h,8h,12h,1d
# 12            1h,2h,4h,8h,12h,1d
# 13  5m,15m,1h,2h,4h,8h,12h,3d,1w
# 14        30m,1h,2h,4h,8h,12h,1d
# 15                      1h,2h,1w
# 16     5m,30m,1h,2h,4h,8h,12h,1w
# 17            2h,4h,8h,12h,3d,1w

# %%
white =  frtolist(test)
print(white)      
wrjson(white,"whitelistfile.json")
# Out:
# ['GLMR/USDT', 'ATOM/USDT', 'ROSE/USDT', 'SUSHI/USDT', 'ZIL/USDT', '1INCH/USDT', 'FLUX/USDT', 'ZRX/USDT', 'GRT/USDT', 'GALA/USDT', 'CELR/USDT', 'ONT/USDT', 'VTHO/USDT', 'WIN/USDT', 'ANKR/USDT', 'COTI/USDT', 'XTZ/USDT', 'MATIC/USDT']

# %%
white =  frtolist(higherhi5)
print(white)      
wrjson(white,"hihi5.json")
# Out:
# ['ANKR/USDT', 'ATOM/USDT', 'ZRX/USDT', 'XTZ/USDT', 'WIN/USDT', 'IMX/USDT', 'SCRT/USDT', 'REN/USDT', 'SUSHI/USDT', 'FLUX/USDT', 'VTHO/USDT', 'ROSE/USDT', 'GLMR/USDT', 'COTI/USDT', 'CELR/USDT', 'ONT/USDT', 'GALA/USDT', 'GRT/USDT', 'DOT/USDT', 'ZIL/USDT', 'MATIC/USDT', '1INCH/USDT']

# %%
test = newframe.loc[(newframe['Indicator'] == 'BTCUSDT')]
print(test['Indicator'])
# Out:
# Series([], Name: Indicator, dtype: object)

# %% [markdown]
# # Create a function to filter the above
#     - things at the bottom and going up then go  down in timeframes
#     - 1d Bottom
#         - check 12 Bottom either going towards it
#         - At the bottom of 12
#         - Already moved from the bottom of 12
