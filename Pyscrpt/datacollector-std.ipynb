# %%
## need to add open close for each time frame ,
## support resistance
##  pivots ,https://towardsdatascience.com/pivot-points-calculation-in-python-for-day-trading-659c1e92d323 
## and write it down each 15 minutes to create data set for AI ML bot 
## bot with GAN or CAN

# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
##Connect to Mongo DB  
from arctic import Arctic
connection = Arctic("mongodb://root:rootpassword@192.168.2.205:27017")
#client.initialize_library('crypto')
cryptolib = connection['crypto']
#cryptolib.stats()

# %%
## choose either white list or read from fix entries 

#fixentries= pd.read_csv('easyband.csv')
#fixentries= pd.read_csv('fixoneasy.csv')
#fixentries= pd.read_csv('fixentries.csv')
fixentries= pd.read_csv('../entries.csv')


fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
#whitelist
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')

fixentries
# Out:
#     Unnamed: 0  Indicator  lowest_entry
# 0            0   ANKRUSDT       0.05415
# 1            1   AVAXUSDT      33.00000
# 2            2   WAXPUSDT       0.25510
# 3            3   REEFUSDT       0.00806
# 4            4   LINKUSDT      12.00000
# ..         ...        ...           ...
# 59          59  STORJUSDT       0.44810
# 60          60  THETAUSDT       2.80000
# 61          61   MANAUSDT       1.65000
# 62          62   PAXGUSDT    1785.00000
# 63          63   PERPUSDT       2.22000
#
# [64 rows x 3 columns]

# %%
#alllist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, ADADOWN/USDT, BOND/USDT, DCR/USDT, DOTDOWN/USDT, GNO/USDT, NBS/USDT, SXPUP/USDT, EOSDOWN/USDT, YFIUP/USDT, RIF/USDT, LTCDOWN/USDT, XLMUP/USDT, YFIDOWN/USDT, LINKDOWN/USDT, TRXUP/USDT, BCHUP/USDT, XTZUP/USDT, SXPDOWN/USDT, UNIDOWN/USDT, XTZDOWN/USDT, BCHDOWN/USDT, TRXDOWN/USDT, XLMDOWN/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
#whitelist =str(fixentries['Indicator'])

startdate = '2020-01-01'
enddate = pd.to_datetime('today')
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']
#intervals = ['8h']

# %%
#print (enddate)

# %%
def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

#Calulate SMA 
def SMA(series,size):
    sma = series.rolling(size).mean()
    return sma
#Calculate SMA55

## MACD 
def MMACD(series,fast=5,slow=35,sig=5):
    ## defaults original f 12, s 26, s9
    exp1 = series.ewm(span=fast, adjust=False).mean()
    exp2 = series.ewm(span=slow, adjust=False).mean()
    macd = exp1-exp2
    signal = macd.ewm(span=sig, adjust=False).mean()
    return macd,signal
## Bottom price 
def FBOTTOMP (series,size):
    bottomp=series.rolling(size).min()
    return bottomp
## top price 
def FTOPP (series,size):
    topp=series.rolling(size).max()
    return topp

# %%
#alllist=alllist.lstrip()
#array = alllist.split(",")
#array = whitelist
array = whitelist
array

wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(symbols,columns =['Indicator'])
final.set_index(['Indicator'],inplace=True)
#final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            dflive=dflive.loc[(dflive.open_time>start)]
            
            if dflive.size > 300 :
                
                
                

                dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
                dflive['RSI'] = FRSI(dflive['c'])
                dflive['STRSI'] = STRSIA(dflive['c'])[0]
                dflive['STRSIK'] = STRSIA(dflive['c'])[1]
                dflive['STRSID'] = STRSIA(dflive['c'])[2]
                dflive['SMA21'] = SMA(dflive['c'],21)
                dflive['SMA55'] = SMA(dflive['c'],55)
                dflive['SMA100'] = SMA(dflive['c'],100)
                dflive['SMA200'] = SMA(dflive['c'],200)
                dflive['MACD'] = MMACD(dflive['c'])[0]
                dflive['MACDSIGNAL'] = MMACD(dflive['c'])[1]
                dflive['BTTOMP'] = FBOTTOMP(dflive['l'],10)
                dflive['TPP'] = FTOPP(dflive['h'],10)


                
                



                #print(dflive)


                lastrow = dflive.iloc[-1]
                beforelast = dflive.iloc[-2]
                row5minus = dflive.iloc[-10]
                O = float(lastrow.o)
                C = float(lastrow.c)
                H = float(lastrow.h)
                L = float(lastrow.l)
                V = float(lastrow.v)
                OM = float(beforelast.o)
                CM = float(beforelast.c)
                HM = float(beforelast.h)
                LM = float(beforelast.l)
                VM = float(beforelast.v)
                RSI = float(lastrow.RSI)
                RSIM = float(beforelast.RSI)
                STRSI = float(lastrow.STRSI)
                STRSIK = float(lastrow.STRSIK)
                STRSIKM = float(beforelast.STRSIK)
                STRSID = float(lastrow.STRSID)
                STRSIDM = float(beforelast.STRSID)
                SMA21 = float(lastrow.SMA21)
                SMA21M = float(beforelast.SMA21)
                SMA55 = float(lastrow.SMA55)
                SMA55M = float(beforelast.SMA55)
                SMA100 = float(lastrow.SMA100)
                SMA100M = float(beforelast.SMA100)
                SMA200 = float(lastrow.SMA200)
                SMA200M = float(beforelast.SMA200)
                MACD = float(lastrow.MACD)
                MACDSIGNAL = float(lastrow.MACDSIGNAL)
                MACDM = float(beforelast.MACD)
                MACDSIGNALM = float(beforelast.MACDSIGNAL)
                BTTOMP = lastrow.BTTOMP
                TPP = lastrow.TPP
                BTTOMPM = row5minus.BTTOMP
                TPPM = row5minus.TPP


                tuple =(symbol,O,C,H,L,V,OM,CM,HM,LM,VM,RSI,RSIM,STRSI,STRSIK,STRSIKM,STRSID,STRSIDM,SMA21,SMA21M,SMA55,SMA55M,SMA100,SMA100M,SMA200,SMA200M,MACD,MACDSIGNAL,MACDM,MACDSIGNALM,BTTOMP,TPP,BTTOMPM,TPPM)
                table.append(tuple)
                #print(table)
                del dflive
            else:
                pass
            #print("name is: ",array[0])


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','O','C','H','L','V','OM','CM','HM','LM','VM','RSI','RSIM','STRSI','STRSIK','STRSIKM','STRSID','STRSIDM','SMA21','SMA21M','SMA55','SMA55M','SMA100','SMA100M','SMA200','SMA200M','MACD','MACDSIGNAL','MACDM','MACDSIGNALM','BOTTOMP','TOPP','BOTTOMPM','TOPPM'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'O':('O'+interval),'OM':('OM'+interval),'C':('C'+interval),'CM':('CM'+interval),'H':('H'+interval),'HM':('HM'+interval),'L':('L'+interval),'LM':('LM'+interval),'V':('V'+interval),'VM':('VM'+interval),'RSI':('RSI'+interval),\
                                 'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSIKM':('STRSIKM'+interval),\
                                 'STRSID':('STRSID'+interval),'STRSIDM':('STRSIDM'+interval),'SMA21':('SMA21'+interval),'SMA21M':('SMA21M'+interval),\
                                 'SMA55':('SMA55'+interval),'SMA55M':('SMA55M'+interval),'SMA100':('SMA100'+interval),'SMA100M':('SMA100M'+interval),\
                                 'SMA200':('SMA200'+interval),'SMA200M':('SMA200M'+interval),'MACD':('MACD'+interval),'MACDSIGNAL':('MACDSIGNAL'+interval),'MACDM':('MACDM'+interval),'MACDSIGNALM':('MACDSIGNALM'+interval),'BOTTOMP':('BOTTOMP'+interval),'TOPP':('TOPP'+interval),'BOTTOMPM':('BOTTOMPM'+interval),'TOPPM':('TOPPM'+interval)})
    #test.set_index(['Indicator'],inplace=True)
    final=final.merge(test,how='left',on=['Indicator'])
    final=final.drop_duplicates(subset='Indicator',keep='last')
    #final.set_index(['Indicator'],inplace=True)

    del test
    ## add the current date column
            
final['Time'] = pd.to_datetime('today')

#final
#final.reset_index(inplace=True)

# %%
#final.Indicator

# %%
import os.path

file_exists = os.path.exists("MLDATATOP"+str(date.today())+".csv")



#final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
#final['Time'] = pd.to_datetime('today')
#final.to_csv("MLDATATOP.csv")
#final.to_csv("MLSTRSIMACDBTTOP.csv")
if file_exists :
    final.to_csv("MLDATATOP"+str(date.today())+".csv", mode='a', index=True, header=False)
else :
    final.to_csv("MLDATATOP"+str(date.today())+".csv")
    
#final.to_csv("MLDATATOP"+str(date.today())+".csv")
## adding to two files the first file i thought there is a column missmatch
#final.to_csv('MLSTRSIMACDBTTOP.csv', mode='a', index=True, header=False)
final.to_csv('MLDATATOP.csv', mode='a', index=True, header=False)
#final.reset_index(inplace=True)

final.head()
# Out:
#    Indicator       O5m       C5m       H5m       L5m         V5m      OM5m  \
# 10  ANKRUSDT   0.02683   0.02689   0.02690   0.02683    77939.30   0.02684
# 21  AVAXUSDT  16.23000  16.27000  16.27000  16.23000     1842.05  16.14000
# 32  WAXPUSDT   0.08470   0.08480   0.08480   0.08470     1678.00   0.08460
# 43  REEFUSDT   0.00343   0.00344   0.00344   0.00343  1608880.00   0.00343
# 54  LINKUSDT   6.46000   6.47000   6.47000   6.45000    11586.63   6.43000
#
#         CM5m      HM5m      LM5m  ...  SMA200M1w     MACD1w  MACDSIGNAL1w  \
# 10   0.02683   0.02692   0.02680  ...        NaN  -0.034270     -0.030025
# 21  16.23000  16.24000  16.13000  ...        NaN -32.785170    -26.016986
# 32   0.08460   0.08470   0.08430  ...        NaN  -0.161941     -0.148592
# 43   0.00343   0.00343   0.00342  ...        NaN  -0.007354     -0.007313
# 54   6.46000   6.47000   6.42000  ...        NaN  -8.020954     -7.805417
#
#       MACDM1w  MACDSIGNALM1w  BOTTOMP1w    TOPP1w  BOTTOMPM1w    TOPPM1w  \
# 10  -0.032679      -0.027903    0.02357   0.08674     0.05107    0.10295
# 21 -30.936248     -22.632894   14.55000  81.87000    64.45000  103.62000
# 32  -0.157677      -0.141917    0.07520   0.29310     0.24170    0.39500
# 43  -0.007464      -0.007293    0.00274   0.01044     0.00788    0.01430
# 54  -8.145864      -7.697649    5.30000  15.28000    11.40000   19.54000
#
#                          Time
# 10 2022-06-17 10:36:23.912822
# 21 2022-06-17 10:36:23.912822
# 32 2022-06-17 10:36:23.912822
# 43 2022-06-17 10:36:23.912822
# 54 2022-06-17 10:36:23.912822
#
# [5 rows x 365 columns]

# %%
final.tail()
# Out:
#      Indicator        O5m        C5m        H5m        L5m         V5m  \
# 656  STORJUSDT     0.4353     0.4368     0.4388     0.4340  87917.0000
# 667  THETAUSDT     1.2340     1.2350     1.2360     1.2330  19511.0000
# 678   MANAUSDT     0.8344     0.8363     0.8363     0.8334  27281.0000
# 689   PAXGUSDT  1851.0000  1852.0000  1852.0000  1851.0000      0.2158
# 700   PERPUSDT     0.5940     0.5980     0.5980     0.5930   6939.8100
#
#           OM5m       CM5m       HM5m       LM5m  ...  SMA200M1w    MACD1w  \
# 656     0.4334     0.4348     0.4356     0.4323  ...        NaN -0.508285
# 667     1.2230     1.2310     1.2320     1.2230  ...        NaN -1.948595
# 678     0.8304     0.8341     0.8351     0.8302  ...        NaN -0.860268
# 689  1852.0000  1851.0000  1852.0000  1851.0000  ...        NaN -6.145826
# 700     0.5910     0.5940     0.5960     0.5890  ...        NaN -4.488008
#
#      MACDSIGNAL1w   MACDM1w  MACDSIGNALM1w  BOTTOMP1w     TOPP1w  BOTTOMPM1w  \
# 656     -0.456521 -0.496940      -0.430640     0.3292     1.3921      0.7714
# 667     -1.914922 -2.022753      -1.898085     0.9560     3.5410      2.2710
# 678     -0.739196 -0.846298      -0.678661     0.6290     2.2825      2.0335
# 689      1.410438 -1.888582       5.188571  1791.0000  1999.0000   1794.0000
# 700     -4.458806 -4.530224      -4.444204     0.5540     5.0500      3.6000
#
#        TOPPM1w                       Time
# 656     1.6522 2022-06-17 10:36:23.912822
# 667     4.3900 2022-06-17 10:36:23.912822
# 678     3.5497 2022-06-17 10:36:23.912822
# 689  2076.0000 2022-06-17 10:36:23.912822
# 700     6.8000 2022-06-17 10:36:23.912822
#
# [5 rows x 365 columns]

# %%
cryptolib.append('MLDATATOP',final)
# Out:
# VersionedItem(symbol=MLDATATOP,library=arctic.crypto,data=<class 'NoneType'>,version=53,metadata=None,host=mongodb://root:rootpassword@192.168.2.205:27017)

# %%
from arctic.date import DateRange

#custom_range = DateRange('2022-06-11', '2022-06-12')

#fromdb = cryptolib.read('MLDATATOP',date_range=custom_range).data
fromdb = cryptolib.read('MLDATATOP').data
cryptolib.list_symbols()
cryptolib.list_versions()

formdbsort=fromdb.sort_values(by='Time',ascending=True)
formdbsort=formdbsort.loc[formdbsort['Indicator']=='HNTUSDT']
formdbsort
# Out:
# /Users/hjabbour/opt/anaconda3/envs/cryptodev/lib/python3.8/site-packages/arctic/date/_mktz.py:32: PytzUsageWarning: The zone attribute is specific to pytz's interface; please migrate to a new time zone provider. For more details on how to do so, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   zone = tzlocal.get_localzone().zone
#       Indicator    O5m    C5m    H5m    L5m       V5m   OM5m   CM5m   HM5m  \
# index
# 261     HNTUSDT   9.15   9.15   9.15   9.15      0.00   9.12   9.15   9.15
# 261     HNTUSDT   8.25   8.17   8.25   8.17    416.82   8.20   8.24   8.27
# 261     HNTUSDT   8.10   8.14   8.14   8.06   1073.77   8.05   8.11   8.12
# 261     HNTUSDT   7.79   7.88   7.89   7.79   3029.25   7.75   7.79   7.79
# 261     HNTUSDT   7.92   7.93   7.94   7.89    984.09   7.94   7.92   8.00
# 261     HNTUSDT   7.98   7.95   7.99   7.94    360.78   8.03   7.97   8.04
# 261     HNTUSDT   7.70   7.60   7.70   7.60   3858.07   7.80   7.70   7.84
# 261     HNTUSDT   7.61   7.54   7.63   7.54   2151.57   7.76   7.61   7.77
# 253     HNTUSDT   7.74   7.74   7.76   7.73    828.05   7.88   7.74   7.89
# 248     HNTUSDT   7.68   7.70   7.70   7.65   1694.39   7.57   7.65   7.73
# 258     HNTUSDT   7.70   7.67   7.70   7.63   1188.23   7.68   7.68   7.70
# 237     HNTUSDT   7.99   8.00   8.03   7.98   2057.03   8.08   7.99   8.08
# 251     HNTUSDT   7.77   7.76   7.83   7.73   2640.77   7.81   7.77   7.82
# 256     HNTUSDT   7.82   8.05   8.31   7.81  20160.96   7.76   7.82   7.85
# 261     HNTUSDT   8.00   8.11   8.13   7.99   4494.26   7.99   7.99   8.14
# 261     HNTUSDT   8.35   8.32   8.36   8.28   8911.94   8.60   8.35   8.62
# 261     HNTUSDT   8.00   7.95   8.04   7.95   1344.48   8.00   8.01   8.03
# 261     HNTUSDT   8.16   8.17   8.20   8.16    774.88   8.15   8.15   8.16
# 261     HNTUSDT   8.24   8.24   8.26   8.23   5382.12   8.27   8.25   8.30
# 261     HNTUSDT   8.30   8.38   8.42   8.29   4809.01   8.28   8.29   8.30
# 261     HNTUSDT   8.35   8.43   8.43   8.35   2606.07   8.30   8.34   8.42
# 261     HNTUSDT   8.55   8.60   8.63   8.55   2173.94   8.53   8.56   8.59
# 261     HNTUSDT   7.92   8.00   8.02   7.91   4066.80   8.03   7.93   8.03
# 261     HNTUSDT   9.28   9.20   9.28   9.20    528.04   9.24   9.30   9.32
# 261     HNTUSDT   9.98  10.04  10.09   9.92   7394.38  10.00   9.96  10.04
# 261     HNTUSDT   9.74   9.84   9.89   9.69  16055.16   9.91   9.73   9.94
# 261     HNTUSDT   9.71   9.71   9.75   9.63   7478.60   9.61   9.73   9.78
# 261     HNTUSDT   9.60   9.66   9.71   9.60   3387.98   9.62   9.60   9.63
# 261     HNTUSDT   9.54   9.46   9.55   9.43   1983.76   9.47   9.52   9.53
# 261     HNTUSDT   9.65   9.69   9.69   9.65    931.08   9.71   9.65   9.72
# 261     HNTUSDT   9.22   9.21   9.29   9.17  15901.56   9.40   9.21   9.40
# 261     HNTUSDT   9.07   8.99   9.07   8.96   4240.80   9.05   9.06   9.12
# 261     HNTUSDT   8.89   8.91   8.95   8.88   3324.88   8.93   8.90   8.98
# 261     HNTUSDT   8.84   8.79   8.88   8.77   8237.56   8.80   8.84   8.86
# 261     HNTUSDT   8.93   8.97   8.97   8.93    816.51   8.96   8.93   9.01
# 261     HNTUSDT   9.19   9.15   9.21   9.11   3050.09   9.32   9.19   9.35
# 261     HNTUSDT   9.27   9.31   9.39   9.25   3514.35   9.23   9.26   9.26
# 261     HNTUSDT   9.54   9.55   9.56   9.53    494.14   9.55   9.55   9.56
# 261     HNTUSDT   9.37   9.29   9.38   9.26   2664.58   9.32   9.36   9.38
# 261     HNTUSDT   9.89   9.89   9.89   9.85   1751.90   9.87   9.86   9.96
# 261     HNTUSDT  10.12  10.10  10.13  10.08    845.21  10.09  10.13  10.15
# 261     HNTUSDT  11.29  11.36  11.40  11.29   2470.91  11.26  11.30  11.32
# 248     HNTUSDT  10.64  10.55  10.69  10.52   6150.64  10.71  10.65  10.75
# 227     HNTUSDT  10.55  10.52  10.55  10.50   1540.47  10.57  10.55  10.58
# 244     HNTUSDT    NaN    NaN    NaN    NaN       NaN    NaN    NaN    NaN
# 261     HNTUSDT  10.65  10.65  10.65  10.61   1803.64  10.70  10.64  10.73
# 261     HNTUSDT  10.36  10.32  10.38  10.32    858.50  10.39  10.35  10.39
# 261     HNTUSDT  10.39  10.39  10.41  10.39    674.96  10.36  10.39  10.43
# 261     HNTUSDT  10.49  10.50  10.52  10.49   6396.08  10.44  10.49  10.51
# 261     HNTUSDT  10.19  10.22  10.23  10.17   1053.83  10.24  10.19  10.25
# 261     HNTUSDT  10.68  10.67  10.69  10.67    108.04  10.58  10.67  10.71
# 261     HNTUSDT  10.52  10.52  10.53  10.51    624.24  10.48  10.51  10.53
#
#         LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w   MACDM1w  MACDSIGNALM1w  \
# index         ...
# 261     9.11  ...        NaN -9.738000     -8.973849 -9.995430      -8.591774
# 261     8.20  ...        NaN -9.765180     -9.274046 -9.901889      -9.028479
# 261     8.03  ...        NaN -9.767958     -9.274972 -9.901889      -9.028479
# 261     7.72  ...        NaN -9.812402     -9.289787 -9.901889      -9.028479
# 261     7.90  ...        NaN -9.817958     -9.291639 -9.901889      -9.028479
# 261     7.96  ...        NaN -9.812402     -9.289787 -9.901889      -9.028479
# 261     7.64  ...        NaN -9.934624     -9.330527 -9.901889      -9.028479
# 261     7.61  ...        NaN -9.915180     -9.324046 -9.901889      -9.028479
# 253     7.73  ...        NaN -9.892958     -9.316639 -9.901889      -9.028479
# 248     7.57  ...        NaN -9.892958     -9.316639 -9.901889      -9.028479
# 258     7.65  ...        NaN -9.909624     -9.322194 -9.901889      -9.028479
# 237     7.99  ...        NaN -9.817958     -9.291639 -9.901889      -9.028479
# 251     7.75  ...        NaN -9.856847     -9.304602 -9.901889      -9.028479
# 256     7.76  ...        NaN -9.798513     -9.285157 -9.901889      -9.028479
# 261     7.90  ...        NaN -9.795735     -9.284231 -9.901889      -9.028479
# 261     8.31  ...        NaN -9.720735     -9.259231 -9.901889      -9.028479
# 261     7.99  ...        NaN -9.801291     -9.286083 -9.901889      -9.028479
# 261     8.11  ...        NaN -9.740180     -9.265713 -9.901889      -9.028479
# 261     8.25  ...        NaN -9.731847     -9.262935 -9.901889      -9.028479
# 261     8.24  ...        NaN -9.687402     -9.248120 -9.901889      -9.028479
# 261     8.29  ...        NaN -9.687402     -9.248120 -9.901889      -9.028479
# 261     8.51  ...        NaN -9.665180     -9.240713 -9.901889      -9.028479
# 261     7.90  ...        NaN -9.781847     -9.279602 -9.901889      -9.028479
# 261     9.15  ...        NaN -9.462402     -9.173120 -9.901889      -9.028479
# 261     9.92  ...        NaN -9.234624     -9.097194 -9.901889      -9.028479
# 261     9.71  ...        NaN -9.301291     -9.119416 -9.901889      -9.028479
# 261     9.56  ...        NaN -9.320735     -9.125898 -9.901889      -9.028479
# 261     9.49  ...        NaN -9.334624     -9.130527 -9.901889      -9.028479
# 261     9.43  ...        NaN -9.317958     -9.124972 -9.901889      -9.028479
# 261     9.57  ...        NaN -9.342958     -9.133305 -9.901889      -9.028479
# 261     9.20  ...        NaN -9.459624     -9.172194 -9.901889      -9.028479
# 261     9.02  ...        NaN -9.529069     -9.195342 -9.901889      -9.028479
# 261     8.88  ...        NaN -9.520735     -9.192565 -9.901889      -9.028479
# 261     8.78  ...        NaN -9.562402     -9.206453 -9.901889      -9.028479
# 261     8.90  ...        NaN -9.501291     -9.186083 -9.901889      -9.028479
# 261     9.19  ...        NaN -9.465180     -9.174046 -9.901889      -9.028479
# 261     9.22  ...        NaN -9.440180     -9.165713 -9.901889      -9.028479
# 261     9.48  ...        NaN -9.373513     -9.143490 -9.901889      -9.028479
# 261     9.31  ...        NaN -9.440180     -9.165713 -9.901889      -9.028479
# 261     9.81  ...        NaN -9.279069     -9.112009 -9.901889      -9.028479
# 261    10.08  ...        NaN -9.234624     -9.097194 -9.901889      -9.028479
# 261    11.24  ...        NaN -8.865180     -8.974046 -9.901889      -9.028479
# 248    10.63  ...        NaN -9.101291     -9.052750 -9.901889      -9.028479
# 227    10.51  ...        NaN -9.104069     -9.053676 -9.901889      -9.028479
# 244      NaN  ...        NaN -9.115180     -9.057379 -9.901889      -9.028479
# 261    10.64  ...        NaN -9.092958     -9.049972 -9.901889      -9.028479
# 261    10.32  ...        NaN -9.131847     -9.062935 -9.901889      -9.028479
# 261    10.36  ...        NaN -9.137402     -9.064787 -9.901889      -9.028479
# 261    10.40  ...        NaN -9.098513     -9.051824 -9.901889      -9.028479
# 261    10.19  ...        NaN -9.181847     -9.079602 -9.901889      -9.028479
# 261    10.58  ...        NaN -9.051291     -9.036083 -9.901889      -9.028479
# 261    10.46  ...        NaN -9.087402     -9.048120 -9.901889      -9.028479
#
#        BOTTOMP1w  TOPP1w  BOTTOMPM1w  TOPPM1w                       Time
# index
# 261         6.54   28.00       19.48     32.0 2022-06-13 01:28:36.910066
# 261         6.54   22.08       19.48     32.0 2022-06-13 08:44:27.632136
# 261         6.54   22.08       19.48     32.0 2022-06-13 09:21:10.183001
# 261         6.54   22.08       19.48     32.0 2022-06-13 10:14:09.668714
# 261         6.54   22.08       19.48     32.0 2022-06-13 10:54:43.236504
# 261         6.54   22.08       19.48     32.0 2022-06-13 11:35:01.367175
# 261         6.54   22.08       19.48     32.0 2022-06-13 12:51:46.103687
# 261         6.54   22.08       19.48     32.0 2022-06-13 13:46:00.917263
# 253         6.54   22.08       19.48     32.0 2022-06-13 15:14:30.988666
# 248         6.54   22.08       19.48     32.0 2022-06-13 15:43:14.390011
# 258         6.54   22.08       19.48     32.0 2022-06-13 15:47:33.758574
# 237         6.54   22.08       19.48     32.0 2022-06-13 16:46:22.739015
# 251         6.54   22.08       19.48     32.0 2022-06-13 17:08:34.643457
# 256         6.54   22.08       19.48     32.0 2022-06-13 17:38:17.581101
# 261         6.54   22.08       19.48     32.0 2022-06-13 18:25:12.866781
# 261         6.54   22.08       19.48     32.0 2022-06-13 19:57:06.642782
# 261         6.54   22.08       19.48     32.0 2022-06-13 21:41:32.666781
# 261         6.54   22.08       19.48     32.0 2022-06-13 22:25:26.979547
# 261         6.54   22.08       19.48     32.0 2022-06-13 23:07:46.199314
# 261         6.54   22.08       19.48     32.0 2022-06-14 00:01:44.893957
# 261         6.54   22.08       19.48     32.0 2022-06-14 00:06:08.558292
# 261         6.54   22.08       19.48     32.0 2022-06-14 00:35:43.349146
# 261         6.54   22.08       19.48     32.0 2022-06-14 09:03:40.029424
# 261         6.54   22.08       19.48     32.0 2022-06-14 12:09:28.618244
# 261         6.54   22.08       19.48     32.0 2022-06-14 14:46:52.490758
# 261         6.54   22.08       19.48     32.0 2022-06-14 15:27:28.380992
# 261         6.54   22.08       19.48     32.0 2022-06-14 17:12:59.698719
# 261         6.54   22.08       19.48     32.0 2022-06-14 19:42:59.727614
# 261         6.54   22.08       19.48     32.0 2022-06-14 21:03:25.191337
# 261         6.54   22.08       19.48     32.0 2022-06-14 23:14:43.444514
# 261         6.54   22.08       19.48     32.0 2022-06-15 09:31:40.816824
# 261         6.54   22.08       19.48     32.0 2022-06-15 12:07:09.648368
# 261         6.54   22.08       19.48     32.0 2022-06-15 12:35:35.133713
# 261         6.54   22.08       19.48     32.0 2022-06-15 13:06:31.298942
# 261         6.54   22.08       19.48     32.0 2022-06-15 14:09:55.381120
# 261         6.54   22.08       19.48     32.0 2022-06-15 14:29:44.134972
# 261         6.54   22.08       19.48     32.0 2022-06-15 16:53:27.644443
# 261         6.54   22.08       19.48     32.0 2022-06-15 17:34:16.101382
# 261         6.54   22.08       19.48     32.0 2022-06-15 19:38:31.424766
# 261         6.54   22.08       19.48     32.0 2022-06-15 23:04:29.698550
# 261         6.54   22.08       19.48     32.0 2022-06-16 00:15:02.928046
# 261         6.54   22.08       19.48     32.0 2022-06-16 09:26:30.570483
# 248         6.54   22.08       19.48     32.0 2022-06-16 13:12:58.508240
# 227         6.54   22.08       19.48     32.0 2022-06-16 17:00:55.098899
# 244         6.54   22.08       19.48     32.0 2022-06-16 19:22:51.428986
# 261         6.54   22.08       19.48     32.0 2022-06-16 21:25:13.603103
# 261         6.54   22.08       19.48     32.0 2022-06-16 22:02:27.284452
# 261         6.54   22.08       19.48     32.0 2022-06-16 22:10:26.500421
# 261         6.54   22.08       19.48     32.0 2022-06-16 23:28:51.116365
# 261         6.54   22.08       19.48     32.0 2022-06-17 01:07:06.501301
# 261         6.54   22.08       19.48     32.0 2022-06-17 09:14:01.813157
# 261         6.54   22.08       19.48     32.0 2022-06-17 10:36:23.912822
#
# [52 rows x 365 columns]

# %%
HIHI15m = (final['TOPP15m'] > final['TOPPM15m'])
HIHI1h = (final['TOPP1h'] > final['TOPPM1h'])
HIHI2h = (final['TOPP2h'] > final['TOPPM2h'])
HIHI30m = (final['TOPP30m'] > final['TOPPM30m'])
HIHI4h = (final['TOPP4h'] > final['TOPPM4h'])
HIHI5m = (final['TOPP5m'] > final['TOPPM5m'])
HILO15m = (final['BOTTOMP15m'] > final['BOTTOMPM15m'])
HILO1h = (final['BOTTOMP1h'] > final['BOTTOMPM1h'])
HILO2h = (final['BOTTOMP2h'] > final['BOTTOMPM2h'])
HILO30m = (final['BOTTOMP30m'] > final['BOTTOMPM30m'])
HILO4h = (final['BOTTOMP4h'] > final['BOTTOMPM4h'])
HILO5m = (final['BOTTOMP5m'] > final['BOTTOMPM5m'])
LOHI15m = (final['TOPP15m'] < final['TOPPM15m'])
LOHI1h = (final['TOPP1h'] < final['TOPPM1h'])
LOHI2h = (final['TOPP2h'] < final['TOPPM2h'])
LOHI30m = (final['TOPP30m'] < final['TOPPM30m'])
LOHI4h = (final['TOPP4h'] < final['TOPPM4h'])
LOHI5m = (final['TOPP5m'] < final['TOPPM5m'])
LOLO15m = (final['BOTTOMP15m'] < final['BOTTOMPM15m'])
LOLO1h = (final['BOTTOMP1h'] < final['BOTTOMPM1h'])
LOLO2h = (final['BOTTOMP2h'] < final['BOTTOMPM2h'])
LOLO30m = (final['BOTTOMP30m'] < final['BOTTOMPM30m'])
LOLO4h = (final['BOTTOMP4h'] < final['BOTTOMPM4h'])
LOLO5m = (final['BOTTOMP5m'] < final['BOTTOMPM5m'])




MACDCROSS12h =  (final['MACD12h'] > final['MACDSIGNAL12h'])
MACDCROSS1d =  (final['MACD1d'] > final['MACDSIGNAL1d'])
MACDCROSS1w =  (final['MACD1w'] > final['MACDSIGNAL1w'])
MACDCROSS3d =  (final['MACD3d'] > final['MACDSIGNAL3d'])
MACDCROSS4h =  (final['MACD4h'] > final['MACDSIGNAL4h'])
MACDCROSS8h =  (final['MACD8h'] > final['MACDSIGNAL8h'])

MACDD12h = (final['MACD12h'] < final['MACDM12h'])
MACDD1d = (final['MACD1d'] < final['MACDM1d'])
MACDD1w = (final['MACD1w'] < final['MACDM1w'])
MACDD3d = (final['MACD3d'] < final['MACDM3d'])
MACDD4h = (final['MACD4h'] < final['MACDM4h'])
MACDD8h = (final['MACD8h'] < final['MACDM8h'])

MACDGAPD12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) > (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPD1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) > (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPD1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) > (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPD3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) > (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPD4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) > (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPD8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) > (final['MACDM8h'] - final['MACDSIGNALM8h']) )
MACDGAPU12h = ((final['MACD12h'] - final['MACDSIGNAL12h']) < (final['MACDM12h'] - final['MACDSIGNALM12h']) )
MACDGAPU1d = ((final['MACD1d'] - final['MACDSIGNAL1d']) < (final['MACDM1d'] - final['MACDSIGNALM1d']) )
MACDGAPU1w = ((final['MACD1w'] - final['MACDSIGNAL1w']) < (final['MACDM1w'] - final['MACDSIGNALM1w']) )
MACDGAPU3d = ((final['MACD3d'] - final['MACDSIGNAL3d']) < (final['MACDM3d'] - final['MACDSIGNALM3d']) )
MACDGAPU4h = ((final['MACD4h'] - final['MACDSIGNAL4h']) < (final['MACDM4h'] - final['MACDSIGNALM4h']) )
MACDGAPU8h = ((final['MACD8h'] - final['MACDSIGNAL8h']) < (final['MACDM8h'] - final['MACDSIGNALM8h']) )

MACDU12h = (final['MACD12h'] > final['MACDM12h'])
MACDU1d = (final['MACD1d'] > final['MACDM1d'])
MACDU1w = (final['MACD1w'] > final['MACDM1w'])
MACDU3d = (final['MACD3d'] > final['MACDM3d'])
MACDU4h = (final['MACD4h'] > final['MACDM4h'])
MACDU8h = (final['MACD8h'] > final['MACDM8h'])

bottom12h = (final['STRSIK12h']< 0.2)
bottom1d = (final['STRSIK1d']< 0.2)
bottom1h = (final['STRSIK1h']< 0.2)
bottom1w = (final['STRSIK1w']< 0.2)
bottom2h = (final['STRSIK2h']< 0.2)
bottom3d = (final['STRSIK3d']< 0.2)
bottom4h = (final['STRSIK4h']< 0.2)
bottom8h = (final['STRSIK8h']< 0.2)
bottom30m = (final['STRSIK30m'] < 0.2)
bottom15m = (final['STRSIK15m'] < 0.2)
bottom5m = (final['STRSIK5m'] < 0.2)

bottomr12h = (final['RSI12h'] < 30)
bottomr1d = (final['RSI1d'] < 30)
bottomr1h = (final['RSI1h'] < 30)
bottomr1w = (final['RSI1w'] < 30)
bottomr2h = (final['RSI2h'] < 30)
bottomr3d = (final['RSI3d'] < 30)
bottomr4h = (final['RSI4h'] < 30)
bottomr8h = (final['RSI8h'] < 30)
bottomr30m = (final['RSI30m'] < 30)
bottomr15m = (final['RSI15m'] < 30)
bottomr5m = (final['RSI5m'] < 30)






room12h = (final['STRSIK12h'] < 0.8)
room1d = (final['STRSIK1d'] < 0.8)
room1h = (final['STRSIK1h'] < 0.8)
room1w = (final['STRSIK1w'] < 0.8)
room2h = (final['STRSIK2h'] < 0.8)
room3d = (final['STRSIK3d'] < 0.8)
room4h = (final['STRSIK4h'] < 0.8)
room8h = (final['STRSIK8h'] < 0.8)
room30m = (final['STRSIK30m'] < 0.8)
room15m = (final['STRSIK15m'] < 0.8)
room5m = (final['STRSIK5m'] < 0.8)


roomr12h = (final['RSI12h'] < 70)
roomr1d = (final['RSI1d'] < 70)
roomr1h = (final['RSI1h'] < 70)
roomr1w = (final['RSI1w'] < 70)
roomr2h = (final['RSI2h'] < 70)
roomr3d = (final['RSI3d'] < 70)
roomr4h = (final['RSI4h'] < 70)
roomr8h = (final['RSI8h'] < 70)
roomr30m = (final['RSI30m'] < 70)
roomr15m = (final['RSI15m'] < 70)
roomr5m = (final['RSI5m'] < 70)


rule12hRSIdown = (final['RSI12h'] < final['RSIM12h'])
rule12hRSIup = (final['RSI12h'] > final['RSIM12h'])
rule12hkdown = (final['STRSIK12h'] < final['STRSIKM12h'])
rule12hkup = (final['STRSIK12h'] > final['STRSIKM12h'])
rule12hover = (final['STRSIK12h'] > final['STRSID12h'])
rule12hunder = (final['STRSIK12h'] < final['STRSID12h'])
rule1hRSIdown = (final['RSI1h'] < final['RSIM1h'])
rule1hRSIup = (final['RSI1h'] > final['RSIM1h'])
rule1dRSIdown = (final['RSI1d'] < final['RSIM1d'])
rule1dRSIup = (final['RSI1d'] > final['RSIM1d'])
rule1dkdown = (final['STRSIK1d']< final['STRSIKM1d'])
rule1dkup = (final['STRSIK1d'] > final['STRSIKM1d'])
rule1dover = (final['STRSIK1d'] > final['STRSID1d'])
rule1dunder = (final['STRSIK1d']< final['STRSID1d'])
rule1hkdown = (final['STRSIK1h']< final['STRSIKM1h'])
rule1hkup = (final['STRSIK1h'] > final['STRSIKM1h'])
rule1hover = (final['STRSIK1h'] > final['STRSID1h'])
rule1hunder = (final['STRSIK1h']< final['STRSID1h'])
rule1wRSIdown = (final['RSI1w'] < final['RSIM1w'])
rule1wRSIup = (final['RSI1w'] > final['RSIM1w'])
rule1wkdown = (final['STRSIK1w']< final['STRSIKM1w'])
rule1wkup = (final['STRSIK1w'] > final['STRSIKM1w'])
rule1wover = (final['STRSIK1w'] > final['STRSID1w'])
rule1wunder = (final['STRSIK1w']< final['STRSID1w'])
rule2hRSIdown = (final['RSI2h'] < final['RSIM2h'])
rule2hRSIup = (final['RSI2h'] > final['RSIM2h'])
rule2hkdown = (final['STRSIK2h']< final['STRSIKM2h'])
rule2hkup = (final['STRSIK2h'] > final['STRSIKM2h'])
rule2hover = (final['STRSIK2h'] > final['STRSID2h'])
rule2hunder = (final['STRSIK2h']< final['STRSID2h'])
rule3dRSIdown = (final['RSI3d'] < final['RSIM3d'])
rule3dRSIup = (final['RSI3d'] > final['RSIM3d'])
rule3dkdown = (final['STRSIK3d']< final['STRSIKM3d'])
rule3dkup = (final['STRSIK3d'] > final['STRSIKM3d'])
rule3dover = (final['STRSIK3d'] > final['STRSID3d'])
rule3dunder = (final['STRSIK3d']< final['STRSID3d'])
rule4hRSIdown = (final['RSI4h'] < final['RSIM4h'])
rule4hRSIup = (final['RSI4h'] > final['RSIM4h'])
rule4hkdown = (final['STRSIK4h']< final['STRSIKM4h'])
rule4hkup = (final['STRSIK4h'] > final['STRSIKM4h'])
rule4hover = (final['STRSIK4h'] > final['STRSID4h'])
rule4hunder = (final['STRSIK4h']< final['STRSID4h'])

rule8hRSIdown = (final['RSI8h'] < final['RSIM8h'])
rule8hRSIup = (final['RSI8h'] > final['RSIM8h'])
rule8hkdown = (final['STRSIK8h']< final['STRSIKM8h'])
rule8hkup = (final['STRSIK8h'] > final['STRSIKM8h'])
rule8hover = (final['STRSIK8h'] > final['STRSID8h'])
rule8hunder = (final['STRSIK8h']< final['STRSID8h'])

rule30mRSIdown = (final['RSI30m'] < final['RSIM30m'])
rule30mRSIup = (final['RSI30m'] > final['RSIM30m'])
rule30mkdown = (final['STRSIK30m']< final['STRSIKM30m'])
rule30mkup = (final['STRSIK30m'] > final['STRSIKM30m'])
rule30mover = (final['STRSIK30m'] > final['STRSID30m'])
rule30munder = (final['STRSIK30m']< final['STRSID30m'])

rule15mRSIdown = (final['RSI15m'] < final['RSIM15m'])
rule15mRSIup = (final['RSI15m'] > final['RSIM15m'])
rule15mkdown = (final['STRSIK15m']< final['STRSIKM15m'])
rule15mkup = (final['STRSIK15m'] > final['STRSIKM15m'])
rule15mover = (final['STRSIK15m'] > final['STRSID15m'])
rule15munder = (final['STRSIK15m']< final['STRSID15m'])

rule5mRSIdown = (final['RSI5m'] < final['RSIM5m'])
rule5mRSIup = (final['RSI5m'] > final['RSIM5m'])
rule5mkdown = (final['STRSIK5m']< final['STRSIKM5m'])
rule5mkup = (final['STRSIK5m'] > final['STRSIKM5m'])
rule5mover = (final['STRSIK5m'] > final['STRSID5m'])
rule5munder = (final['STRSIK5m']< final['STRSID5m'])

shift12h = (rule12hunder & (rule12hkup | rule12hRSIup))
shift1d = (rule1dunder & (rule1dkup | rule1dRSIup))
shift1h = (rule1hunder & (rule1hkup | rule1hRSIup))
shift1w = (rule1wunder & (rule1wkup | rule1wRSIup))
shift2h = (rule2hunder & (rule2hkup | rule2hRSIup))
shift3d = (rule3dunder & (rule3dkup | rule3dRSIup))
shift4h = (rule4hunder & (rule4hkup | rule4hRSIup))
shift8h = (rule8hunder & (rule8hkup | rule8hRSIup))
shift30m = (rule30munder & (rule30mkup | rule30mRSIup))
shift15m = (rule15munder & (rule15mkup | rule15mRSIup))
shift5m = (rule5munder & (rule5mkup | rule5mRSIup))



stk12hcross = (final['STRSIKM12h'] < final['STRSIDM12h']) & (final['STRSIK12h'] > final['STRSID12h'])
stk15mcross = (final['STRSIKM15m'] < final['STRSIDM15m']) & (final['STRSIK15m'] > final['STRSID15m'])
stk1hcross = (final['STRSIKM1h'] < final['STRSIDM1h']) & (final['STRSIK1h'] > final['STRSID1h'])
stk1dcross = (final['STRSIKM1d'] < final['STRSIDM1d']) & (final['STRSIK1d'] > final['STRSID1d'])
stk1wcross = (final['STRSIKM1w'] < final['STRSIDM1w']) & (final['STRSIK1w'] > final['STRSID1w'])
stk2hcross = (final['STRSIKM2h'] < final['STRSIDM2h']) & (final['STRSIK2h'] > final['STRSID2h'])
stk30mcross = (final['STRSIKM30m'] < final['STRSIDM30m']) & (final['STRSIK30m'] > final['STRSID30m'])
stk3dcross = (final['STRSIKM3d'] < final['STRSIDM3d']) & (final['STRSIK3d'] > final['STRSID3d'])
stk4hcross = (final['STRSIKM4h'] < final['STRSIDM4h']) & (final['STRSIK4h'] > final['STRSID4h'])
stk5mcross = (final['STRSIKM5m'] < final['STRSIDM5m']) & (final['STRSIK5m'] > final['STRSID5m'])
stk8hcross = (final['STRSIKM8h'] < final['STRSIDM8h']) & (final['STRSIK8h'] > final['STRSID8h'])

top12h = (final['STRSIK12h'] > 0.8)
top1d = (final['STRSIK1d'] > 0.8)
top1h = (final['STRSIK1h'] > 0.8)
top1w = (final['STRSIK1w'] > 0.8)
top2h = (final['STRSIK2h'] > 0.8)
top3d = (final['STRSIK3d'] > 0.8)
top4h = (final['STRSIK4h'] > 0.8)
top8h = (final['STRSIK8h'] > 0.8)
top30m = (final['STRSIK30m'] > 0.8)
top15m = (final['STRSIK15m'] > 0.8)
top5m = (final['STRSIK5m'] > 0.8)



topr12h = (final['RSI12h'] > 70)
topr1d = (final['RSI1d'] > 70)
topr1h = (final['RSI1h'] > 70)
topr1w = (final['RSI1w'] > 70)
topr2h = (final['RSI2h'] > 70)
topr3d = (final['RSI3d'] > 70)
topr4h = (final['RSI4h'] > 70)
topr8h = (final['RSI8h'] > 70)
topr30m = (final['RSI30m'] > 70)
topr15m = (final['RSI15m'] > 70)
topr5m = (final['RSI5m'] > 70)




uptrend12h = (rule12hover & (rule12hkup & rule12hRSIup))
uptrend1d = (rule1dover & (rule1dkup & rule1dRSIup))
uptrend1h = (rule1hover & (rule1hkup & rule1hRSIup))
uptrend1w = (rule1wover & (rule1wkup & rule1wRSIup))
uptrend2h = (rule2hover & (rule2hkup & rule2hRSIup))
uptrend3d = (rule3dover & (rule3dkup & rule3dRSIup))
uptrend4h = (rule4hover & (rule4hkup & rule4hRSIup))
uptrend8h = (rule8hover & (rule8hkup & rule8hRSIup))
uptrend30m = (rule30mover & (rule30mkup & rule30mRSIup))
uptrend15m = (rule15mover & (rule15mkup & rule15mRSIup))
uptrend5m = (rule5mover & (rule5mkup & rule5mRSIup))




downtrend12h = (rule12hunder & (rule12hkdown & rule12hRSIdown))
downtrend1d = (rule1dunder & (rule1dkdown & rule1dRSIdown))
downtrend1h = (rule1hunder & (rule1hkdown & rule1hRSIdown))
downtrend1w = (rule1wunder & (rule1wkdown & rule1wRSIdown))
downtrend2h = (rule2hunder & (rule2hkdown & rule2hRSIdown))
downtrend3d = (rule3dunder & (rule3dkdown & rule3dRSIdown))
downtrend4h = (rule4hunder & (rule4hkdown & rule4hRSIdown))
downtrend8h = (rule8hunder & (rule8hkdown & rule8hRSIdown))
downtrend30m = (rule30munder & (rule30mkdown & rule30mRSIdown))
downtrend15m = (rule15munder & (rule15mkdown & rule15mRSIdown))
downtrend5m = (rule5munder & (rule5mkdown & rule5mRSIdown))


dshift12h = (rule12hover & (rule12hkdown | rule12hRSIdown))
dshift1d = (rule1dover & (rule1dkdown | rule1dRSIdown))
dshift1h = (rule1hover & (rule1hkdown | rule1hRSIdown))
dshift1w = (rule1wover & (rule1wkdown | rule1wRSIdown))
dshift2h = (rule2hover & (rule2hkdown | rule2hRSIdown))
dshift3d = (rule3dover & (rule3dkdown | rule3dRSIdown))
dshift4h = (rule4hover & (rule4hkdown | rule4hRSIdown))
dshift8h = (rule8hover & (rule8hkdown | rule8hRSIdown))
dshift30m = (rule30mover & (rule30mkdown | rule30mRSIdown))
dshift15m = (rule15mover & (rule15mkdown | rule15mRSIdown))
dshift5m = (rule5mover & (rule5mkdown | rule5mRSIdown))

# %%
wshift = final.loc[shift1w]
wshift
# Out:
#     Indicator     O5m     C5m     H5m     L5m        V5m    OM5m    CM5m  \
# 196   IMXUSDT  0.7160  0.7190  0.7190  0.7160    2756.44  0.7100  0.7160
# 327   ANTUSDT  1.6320  1.6450  1.6460  1.6270   79817.60  1.6210  1.6320
# 535   FTMUSDT  0.2376  0.2382  0.2382  0.2376  164832.00  0.2362  0.2376
# 546  BANDUSDT  1.4100  1.4160  1.4160  1.4100     355.60  1.4020  1.4090
#
#        HM5m    LM5m  ...  SMA200M1w    MACD1w  MACDSIGNAL1w   MACDM1w  \
# 196  0.7160  0.7100  ...        NaN -0.649932     -0.651281 -0.649400
# 327  1.6350  1.6210  ...        NaN -2.401849     -2.244923 -2.449732
# 535  0.2378  0.2361  ...        NaN -0.770158     -0.708024 -0.767791
# 546  1.4090  1.4010  ...        NaN -2.564678     -2.495787 -2.601125
#
#      MACDSIGNALM1w  BOTTOMP1w  TOPP1w  BOTTOMPM1w  TOPPM1w  \
# 196      -0.651956      0.633  1.2000      0.6750   1.9430
# 327      -2.166461      1.098  4.6480      4.0890   8.2070
# 535      -0.676957      0.194  1.2609      1.0345   2.4038
# 546      -2.461342      1.202  4.1440      3.0760   5.6350
#
#                           Time
# 196 2022-06-17 10:36:23.912822
# 327 2022-06-17 10:36:23.912822
# 535 2022-06-17 10:36:23.912822
# 546 2022-06-17 10:36:23.912822
#
# [4 rows x 365 columns]

# %% [markdown]
# # Summary  draft rules

# %%
#final.reset_index(inplace=True)

#final.set_index(['Indicator'],inplace=True)

# drop = final.loc[bottom4h & (shift4h | rule4over)]
#drop = final.loc[(bottom4h | (uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[((uptrend4h | shift4h)) & (uptrend8h | shift8h) ]
#drop = final.loc[(uptrend8h | shift8h) & (uptrend12h | shift12h) & (uptrend1d | shift1d)]
#drop = final.loc[(uptrend2h | shift2h) & (uptrend4h | shift4h) ]
#drop = final.loc[(uptrend4h | shift4h)]

#drop = final.loc[bottom8h | (shift8h | rule8over)]
#drop = final.loc[bottom12h | (shift12h | rule12over)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[bottom12h | (shift12h | uptrend12h)]
#drop = final.loc[bottom1d | (shift1d | uptrend1d)]
#drop = final.loc[top4h]
#drop = final.loc[(uptrend3d)]
#drop = final.loc[dshift4h]
#drop = final.loc[shift2h]

#drop = final.loc[(bottom4h & bottom12h & bottom3d)]
#drop = final.loc[(uptrend8h)]
#drop = final.loc[(downtrend8h & downtrend4h & downtrend12h)]
#drop = final.loc[(bottom4h & bottom2h & bottom3d)]
#drop = final.loc[shift3d & bottom4h]

#drop = final.loc[(bottom12h)]
#drop = final.loc[ ((rule4kup |rule4RSIup))]

#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend4h | shift4h) ]
#drop = final.loc[((uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) ]

# 4 hours will go down or slow down
#drop = final.loc[( (bottom3d) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) & dshift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) &  (uptrend2h | shift2h) &  (uptrend1h | shift1h)]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]

#drop = final.loc[( (bottom4h) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h)) ]
#drop = final.loc[((bottom1d) & (bottom3d))]
#drop = drop.loc[( (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h))]
#drop = final.loc[dshift4h]

#drop = final.loc[( (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) & (downtrend2h |dshift2h) ]
#drop = final.loc[( (bottom3d) & (uptrend3d | shift3d)) & (uptrend8h | shift8h) & (uptrend1d | shift1d) & (uptrend12h | shift12h) &  (uptrend4h | shift4h) ]
#drop = final.loc[dshift2h]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h) & (bottom2h))]
#drop = final.loc[( (bottom8h) & (bottom12h) & (bottom4h))]

#drop= final.loc[(shift4h) & (shift12h)]
#drop = final.loc[(dshift4h | downtrend4h)]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (dshift4h | downtrend4h))]
#drop = final.loc[( (bottom4h)&(bottom8h) & (bottom12h) & (bottom1d) & (shift2h))]

#drop = final.loc[downtrend1d & downtrend12h & downtrend8h & downtrend4h]
#drop = final.loc[top8h]

#drop



    

#bottomtable['bottoms'] = bottomtable.apply(get_key(listb,bottomtable.loc('Indicator'),axis=1)

#bottomtable
#reversetable
#bottomstable = pd.DataFrame(reversetable,columns=['Indicator','Bottoms'])
#print (bottomstable)
#listb
#listd = pd.DataFrame(listb,columns=['Bottoms','Indicator'])
#print (listb)
#print(reversetable)
#listd.head()
#test = final.loc[(MACDGAP3d)]
test = final.loc[(MACDCROSS3d)]
test = final.loc[(MACDCROSS1d)]
test = final.loc[(MACDGAPU3d)]
test = final.loc[(MACDGAPD3d)& rule3dover & rule3dRSIup]
#macd3d = final.loc[(MACDGAPU3d)& rule3dRSIup]
macd1d = final.loc[(MACDGAPD1d)& rule1dRSIup]
macd3du = final.loc[(MACDGAPU3d)]
macd3dd = final.loc[(MACDGAPD3d)]
macd1du = final.loc[(MACDGAPU1d)]
macd1dd = final.loc[(MACDGAPD1d)]
macd1wu = final.loc[(MACDGAPU1w)]
macd1wd = final.loc[(MACDGAPD1w)]

macd3d1d = final.loc[(MACDGAPD1d &  (MACDGAPD3d)  & rule3dRSIup & rule1dRSIup )]
macd1dcross = final.loc[MACDCROSS1d]
macd12hcross = final.loc[MACDCROSS12h]
macd8hcross = final.loc[MACDCROSS8h]
macd4hcross = final.loc[MACDCROSS4h]
macd3dcross = final.loc[MACDCROSS3d]
stk3d = final.loc[stk3dcross]
stk1w = final.loc[stk1wcross]
macd3dd
#macd12hcross
#macd12hcross
#macd4hcross
#macd3d1d
#macd1d
#pmacdu = macd3du[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdu['diff']=abs(macd3du['MACD3d'])-abs(macd3du['MACDSIGNAL3d'])
#pmacdu['diffm']=abs(macd3du['MACDM3d'])-abs(macd3du['MACDSIGNALM3d'])

#pmacdd = macd3dd[['Indicator','MACD3d','MACDSIGNAL3d','MACDM3d','MACDSIGNALM3d']]
#pmacdd['diff']=abs(macd3dd['MACD3d'])-abs(macd3dd['MACDSIGNAL3d'])
#pmacdd['diffm']=abs(macd3dd['MACDM3d'])-abs(macd3dd['MACDSIGNALM3d'])
#final.set_index(['Indicator'],inplace=True)

#final.reset_index(inplace=True)
test1h = final[['Indicator','BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]
#test1h = final[['BOTTOMP1h','BOTTOMPM1h','TOPP1h','TOPPM1h']]

test15 = final[['Indicator','BOTTOMP15m','BOTTOMPM15m','TOPP15m','TOPPM15m']]
#test15.set_index(['Indicator'],inplace=True)
test5 = final[['Indicator','BOTTOMP5m','BOTTOMPM5m','TOPP5m','TOPPM5m']]
test30 = final[['Indicator','BOTTOMP30m','BOTTOMPM30m','TOPP30m','TOPPM30m']]
#test30.set_index(['Indicator'],inplace=True)

test2h = final[['Indicator','BOTTOMP2h','BOTTOMPM2h','TOPP2h','TOPPM2h']]

test4h = final[['Indicator','BOTTOMP4h','BOTTOMPM4h','TOPP4h','TOPPM4h']]

#final.set_index(['Indicator'],inplace=True)

higherhi = test15.loc[HIHI15m & HILO15m]
#higherhi = test30.loc[HIHI30m & HILO30m]
#higherhi = test1h.loc[HIHI1h & HILO1h]
#higherhi = test2h.loc[HIHI2h & HILO2h]

#higherhi = test4h.loc[HIHI4h & HILO4h]

lowhi = test15.loc[LOHI15m & LOLO15m]
lowhi = test5.loc[LOHI5m & LOLO5m]
#lowhi = test1h.loc[LOHI1h & LOLO1h]
lowhi = test30.loc[LOHI30m & LOLO30m]
lowhi = test2h.loc[LOHI2h & LOLO2h]
lowhi = test4h.loc[LOHI4h & LOLO4h]

higherhi5 = test5.loc[HIHI5m & HILO5m]
higherhi2 = test2h.loc[HIHI2h & HILO2h]
higherhi4 = test4h.loc[HIHI4h & HILO4h]


#higherhi = test15.loc[HIHI15m ]
#higherhi = test.loc[HIHI1h]
#higherhi = test5.loc[HIHI5m ]
#higherlo = test5.loc[HILO5m ]
#higherlo = test15.loc[HILO15m ]


higherhi
stk3d
macd3dd
macd1wd
#macd3dd
#macd1dd
#macd1du
#lowhi
hihi5macd1w=macd1wd.loc[HIHI5m & HILO5m &rule1hRSIup &room1h & rule2hRSIup & room2h & rule4hRSIup & room4h]
rsiup54h=final.loc[rule5mRSIup  &rule15mRSIup &rule30mRSIup  &rule1hRSIup & rule2hRSIup & rule4hRSIup & room4h]

hihi5macd1w
#higherhi5
rsiup54h
# Out:
#      Indicator          O5m          C5m          H5m          L5m  \
# 10    ANKRUSDT      0.02683      0.02689      0.02690      0.02683
# 21    AVAXUSDT     16.23000     16.27000     16.27000     16.23000
# 32    WAXPUSDT      0.08470      0.08480      0.08480      0.08470
# 98    ALGOUSDT      0.30890      0.30960      0.30960      0.30880
# 109    ZRXUSDT      0.26330      0.26390      0.26410      0.26310
# 131    KSMUSDT     49.70000     49.70000     49.70000     49.70000
# 142   NEARUSDT      3.35900      3.37500      3.37700      3.35900
# 206   SCRTUSDT      0.97700      0.97800      0.98000      0.97700
# 228  SUSHIUSDT      0.97700      0.97800      0.97800      0.97500
# 239   CAKEUSDT      2.94200      2.94900      2.95000      2.94200
# 250    XLMUSDT      0.11250      0.11310      0.11310      0.11240
# 283   LINAUSDT      0.00831      0.00834      0.00834      0.00831
# 305    SRMUSDT      0.89300      0.89500      0.89500      0.89300
# 327    ANTUSDT      1.63200      1.64500      1.64600      1.62700
# 338    RAYUSDT      0.67800      0.67900      0.67900      0.67800
# 371  TFUELUSDT      0.04710      0.04760      0.04770      0.04710
# 403    ONEUSDT      0.02588      0.02597      0.02597      0.02587
# 414    VETUSDT      0.02321      0.02329      0.02329      0.02321
# 425   RUNEUSDT      1.72700      1.73300      1.73400      1.72500
# 436   CELRUSDT      0.01341      0.01342      0.01342      0.01339
# 447    ONTUSDT      0.21870      0.21900      0.21900      0.21870
# 458   GALAUSDT      0.05661      0.05665      0.05667      0.05653
# 469    GRTUSDT      0.09970      0.09970      0.09970      0.09960
# 502    FILUSDT      5.39000      5.40000      5.40000      5.38000
# 535    FTMUSDT      0.23760      0.23820      0.23820      0.23760
# 546   BANDUSDT      1.41000      1.41600      1.41600      1.41000
# 601   LUNAUSDT      2.26500      2.26680      2.26680      2.26010
# 612    SOLUSDT     30.82000     30.92000     30.95000     30.79000
# 623   MINAUSDT      0.61900      0.62100      0.62100      0.61900
# 634    BTCUSDT  20725.32000  20792.41000  20797.27000  20719.07000
# 645    ADAUSDT      0.49450      0.49650      0.49660      0.49450
# 667  THETAUSDT      1.23400      1.23500      1.23600      1.23300
# 700   PERPUSDT      0.59400      0.59800      0.59800      0.59300
#
#               V5m         OM5m         CM5m         HM5m         LM5m  ...  \
# 10    77939.30000      0.02684      0.02683      0.02692      0.02680  ...
# 21     1842.05000     16.14000     16.23000     16.24000     16.13000  ...
# 32     1678.00000      0.08460      0.08460      0.08470      0.08430  ...
# 98    25852.00000      0.30760      0.30890      0.30910      0.30750  ...
# 109   13827.00000      0.26150      0.26310      0.26310      0.26140  ...
# 131      17.32900     49.50000     49.60000     49.60000     49.50000  ...
# 142   22960.30000      3.33700      3.35800      3.36100      3.33500  ...
# 206    2691.30000      0.97500      0.97500      0.97500      0.97500  ...
# 228    3413.10000      0.97200      0.97500      0.97600      0.97200  ...
# 239    2362.86000      2.93500      2.94200      2.94400      2.93400  ...
# 250  273438.00000      0.11190      0.11250      0.11250      0.11170  ...
# 283  195865.27000      0.00828      0.00831      0.00831      0.00828  ...
# 305    3892.60000      0.89100      0.89300      0.89400      0.89100  ...
# 327   79817.60000      1.62100      1.63200      1.63500      1.62100  ...
# 338    1095.30000      0.67600      0.67700      0.67700      0.67600  ...
# 371  451762.00000      0.04650      0.04710      0.04710      0.04650  ...
# 403  125852.30000      0.02575      0.02584      0.02588      0.02575  ...
# 414  698881.30000      0.02310      0.02321      0.02321      0.02309  ...
# 425   12313.80000      1.71800      1.72700      1.72800      1.71800  ...
# 436  123682.90000      0.01332      0.01339      0.01340      0.01330  ...
# 447    8581.00000      0.21760      0.21830      0.21840      0.21760  ...
# 458  519925.00000      0.05627      0.05660      0.05660      0.05625  ...
# 469   33645.00000      0.09890      0.09960      0.09970      0.09890  ...
# 502    1926.44000      5.37000      5.38000      5.39000      5.36000  ...
# 535  164832.00000      0.23620      0.23760      0.23780      0.23610  ...
# 546     355.60000      1.40200      1.40900      1.40900      1.40100  ...
# 601    7609.20000      2.24910      2.26440      2.26580      2.24710  ...
# 612    5190.71000     30.62000     30.81000     30.85000     30.60000  ...
# 623    2964.00000      0.61700      0.61900      0.62000      0.61500  ...
# 634     129.27853  20630.88000  20725.32000  20743.00000  20621.79000  ...
# 645  502602.50000      0.49260      0.49440      0.49460      0.49220  ...
# 667   19511.00000      1.22300      1.23100      1.23200      1.22300  ...
# 700    6939.81000      0.59100      0.59400      0.59600      0.58900  ...
#
#      SMA200M1w        MACD1w  MACDSIGNAL1w      MACDM1w  MACDSIGNALM1w  \
# 10         NaN     -0.034270     -0.030025    -0.032679      -0.027903
# 21         NaN    -32.785170    -26.016986   -30.936248     -22.632894
# 32         NaN     -0.161941     -0.148592    -0.157677      -0.141917
# 98         NaN     -0.475089     -0.448748    -0.470089      -0.435577
# 109        NaN     -0.298327     -0.243472    -0.271923      -0.216045
# 131        NaN   -106.243341    -99.914146  -105.277945     -96.749549
# 142        NaN     -4.106451     -2.598820    -3.578262      -1.845005
# 206        NaN     -1.893006     -1.931287    -1.946080      -1.950428
# 228        NaN     -3.081981     -3.092802    -3.097330      -3.098212
# 239        NaN     -5.004037     -4.646176    -4.769280      -4.467245
# 250        NaN     -0.081101     -0.076218    -0.078691      -0.073777
# 283        NaN     -0.019257     -0.019435    -0.019702      -0.019524
# 305        NaN     -1.714673     -1.680113    -1.730419      -1.662834
# 327        NaN     -2.401849     -2.244923    -2.449732      -2.166461
# 338        NaN     -2.833720     -2.832636    -2.879243      -2.832094
# 371        NaN     -0.103057     -0.095725    -0.102567      -0.092059
# 403        NaN     -0.085852     -0.079854    -0.084819      -0.076855
# 414        NaN     -0.032169     -0.030005    -0.031467      -0.028923
# 425        NaN     -3.261182     -2.575501    -3.008927      -2.232661
# 436        NaN     -0.029560     -0.027641    -0.029491      -0.026681
# 447        NaN     -0.284845     -0.266869    -0.279240      -0.257880
# 458        NaN     -0.107098     -0.095061    -0.105217      -0.089042
# 469        NaN     -0.295815     -0.282743    -0.293436      -0.276207
# 502        NaN    -19.207777    -19.218589   -19.480576     -19.223995
# 535        NaN     -0.770158     -0.708024    -0.767791      -0.676957
# 546        NaN     -2.564678     -2.495787    -2.601125      -2.461342
# 601        NaN    -34.577959    -18.007932   -29.807719      -9.722918
# 612        NaN    -50.083819    -42.850499   -48.466082     -39.233839
# 623        NaN     -1.427458     -1.302715    -1.408228      -1.240343
# 634        NaN -11730.182293  -9333.866832 -9731.282089   -8135.709102
# 645        NaN     -0.468440     -0.455759    -0.475597      -0.449418
# 667        NaN     -1.948595     -1.914922    -2.022753      -1.898085
# 700        NaN     -4.488008     -4.458806    -4.530224      -4.444204
#
#        BOTTOMP1w       TOPP1w   BOTTOMPM1w      TOPPM1w  \
# 10       0.02357      0.08674      0.05107      0.10295
# 21      14.55000     81.87000     64.45000    103.62000
# 32       0.07520      0.29310      0.24170      0.39500
# 98       0.27830      0.78620      0.67360      1.10200
# 109      0.22350      1.18380      0.45000      0.95000
# 131     43.00000    186.40000    105.20000    207.20000
# 142      3.03800     17.82000      7.38500     19.78800
# 206      0.91900      2.16000      1.70000      5.04900
# 228      0.87700      3.71400      2.75300      5.08600
# 239      2.73400      9.78000      5.30000     10.99000
# 250      0.10010      0.21370      0.16170      0.25710
# 283      0.00575      0.03480      0.01633      0.03160
# 305      0.81200      2.65700      1.65200      3.70800
# 327      1.09800      4.64800      4.08900      8.20700
# 338      0.63300      2.89200      2.26800      4.42000
# 371      0.03890      0.18700      0.13550      0.24490
# 403      0.02430      0.13198      0.10970      0.23600
# 414      0.02145      0.06566      0.03905      0.08936
# 425      1.64800      9.89100      3.01500     13.20300
# 436      0.01083      0.05491      0.03089      0.08437
# 447      0.19080      0.61490      0.42440      0.70350
# 458      0.04935      0.21827      0.18921      0.39580
# 469      0.09020      0.41090      0.30230      0.55070
# 502      5.00000     22.15000     16.50000     28.15000
# 535      0.19400      1.26090      1.03450      2.40380
# 546      1.20200      4.14400      3.07600      5.63500
# 601      0.00004    119.55000     43.44000    118.09000
# 612     25.86000    111.94000     75.35000    143.51000
# 623      0.55800      2.97700      1.58400      3.54000
# 634  20111.62000  42976.00000  34322.28000  48189.84000
# 645      0.40190      1.03300      0.74600      1.26300
# 667      0.95600      3.54100      2.27100      4.39000
# 700      0.55400      5.05000      3.60000      6.80000
#
#                           Time
# 10  2022-06-17 10:36:23.912822
# 21  2022-06-17 10:36:23.912822
# 32  2022-06-17 10:36:23.912822
# 98  2022-06-17 10:36:23.912822
# 109 2022-06-17 10:36:23.912822
# 131 2022-06-17 10:36:23.912822
# 142 2022-06-17 10:36:23.912822
# 206 2022-06-17 10:36:23.912822
# 228 2022-06-17 10:36:23.912822
# 239 2022-06-17 10:36:23.912822
# 250 2022-06-17 10:36:23.912822
# 283 2022-06-17 10:36:23.912822
# 305 2022-06-17 10:36:23.912822
# 327 2022-06-17 10:36:23.912822
# 338 2022-06-17 10:36:23.912822
# 371 2022-06-17 10:36:23.912822
# 403 2022-06-17 10:36:23.912822
# 414 2022-06-17 10:36:23.912822
# 425 2022-06-17 10:36:23.912822
# 436 2022-06-17 10:36:23.912822
# 447 2022-06-17 10:36:23.912822
# 458 2022-06-17 10:36:23.912822
# 469 2022-06-17 10:36:23.912822
# 502 2022-06-17 10:36:23.912822
# 535 2022-06-17 10:36:23.912822
# 546 2022-06-17 10:36:23.912822
# 601 2022-06-17 10:36:23.912822
# 612 2022-06-17 10:36:23.912822
# 623 2022-06-17 10:36:23.912822
# 634 2022-06-17 10:36:23.912822
# 645 2022-06-17 10:36:23.912822
# 667 2022-06-17 10:36:23.912822
# 700 2022-06-17 10:36:23.912822
#
# [33 rows x 365 columns]

# %% [markdown]
# # Functions

# %%
#DRAFT functions display
intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        

## return a list of timeframes per ta indicator taname  for specific sympbol
#series to list 
def srtolist(final:pd,taname)->[]:
    #ta = globals()[taname]
    array = final[taname].values
    array= str(array[0]).split(",")
    
    #for k in range(0,len(array)):
            #print (k)
            #print (f" {taname} = {array[k]} \n")
    return array

# list to string 
def ltos (mylist)->str:
    mystring = ''
    for x in mylist:
        if not mystring:
            mystring+=x
        else:
            mystring+=","+x
    return mystring

def get_key(my_dict,val):
        keylist = []
        for key, value in my_dict.items():
             if val in value:
                keylist.append(key)
        return keylist
    
def to_df(final:pd ,func,name):
    listb = func(final)
    res = list(sorted({ele for val in listb.values() for ele in val}))
    reversetable = []
    for indi in res:
        ttuple = (indi,ltos(get_key(listb,indi)))
        reversetable.append(ttuple)
    dframe = pd.DataFrame(reversetable,columns=['Indicator',name])
    return dframe
                                                
    
def tops(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['top'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : query.append(i)
        toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def uptrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['uptrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def downtrend(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['downtrend'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def shift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['shift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def dshift(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['dshift'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def topr(final:pd)-> pd :
    #intervals = ['5m','15m','30m','1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['topr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['bottomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def bottoms(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    bottomlist ={}
    for i in intervals:
        var = globals()['bottom'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            bottomlist[i]=test['Indicator'].tolist()
 
    return bottomlist

def room(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['room'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def roomr(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']        
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['roomr'+i]
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsiup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def rsidown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']         
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'RSIdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stover(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'over']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stunder(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'under']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkup(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kup']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist

def stkdown(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['rule'+i+'kdown']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    

    return toplist


def stkcross(final:pd)-> pd :
    #intervals = ['1h','2h','4h','8h','12h','1d','3d','1w']          
    query = []
    toplist ={}
    for i in intervals:
        var = globals()['stk'+i+'cross']
        test = final.loc[(var)]
        #print(test[['Indicator']])
        if len(test.index) > 0 : 
            query.append(i)
            toplist[i]=test['Indicator'].tolist()
        #print(query)
        #print(toplist)    
    return toplist


def buyzones(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        for item in lrsiup :
            if item in lroomr:
                if item in lroom:
                    buy.append(item)
                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final
  

def buyzonesa(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        buyindex = []
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        lrsidown= srtolist(test1,'rsidown')
        lstkup= srtolist(test1,'stkup')
        
        for item in lrsiup :
            if item in lroomr:
                if item in lroom:
                    buy.append(item)
        for item in buy:
            #print(item)
            #print(intervals.index(item))
            buyindex.append(intervals.index(item))
        
        for l,n in zip(buy,buyindex):
            if intervals[n]=='1w':
                if intervals[n-1] in lrsidown:
                    buy.remove(l)
                continue
            if intervals[n]=='5m':
                if intervals[n+1] not in lroomr:
                    buy.remove(l)
                continue
            if intervals[n+1] not in lroomr:
                buy.remove(l)
                continue
            if intervals[n-1] in lrsidown:
                buy.remove(l)
                continue
            
                
            #print(f"buy ={l} index={intervals[n+1]}")                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final  



def buyzonesb(final:pd)->pd :
    ## buy zone based on rsi up and non top 
    toplist ={}
    indicators=final['Indicator'].tolist()
    for indicator in indicators:
        buy =[]
        buyindex = []
        test1 = final.loc[(newframe['Indicator'] == indicator)]
        lrsiup = srtolist(test1,'rsiup')
        lroom = srtolist(test1,'room')
        lroomr = srtolist(test1,'roomr')
        lrsidown= srtolist(test1,'rsidown')
        lstkup= srtolist(test1,'stkup')
        lstbottom= srtolist(test1,'bottoms')
        lstbottomr= srtolist(test1,'bottomr')
        
        
        for item in lstbottom :
            if item in rsiup:
                buy.append(item)
        for item in buy:
            #print(item)
            #print(intervals.index(item))
            buyindex.append(intervals.index(item))
        
        for l,n in zip(buy,buyindex):
            if intervals[n]=='1w':
                if intervals[n-1] in lrsidown:
                    buy.remove(l)
                continue
            if intervals[n]=='5m':
                if intervals[n+1] not in lroomr:
                    buy.remove(l)
                continue
            if intervals[n+1] not in lroomr:
                buy.remove(l)
                continue
            if intervals[n-1] in lrsidown:
                buy.remove(l)
                continue
            
                
            #print(f"buy ={l} index={intervals[n+1]}")                    
        toplist[indicator] = ltos(buy)
        #better keep it as list for manipulation made it string for display
    #print(toplist)
    dframe=pd.DataFrame(toplist.items(), columns=['Indicator', 'buyzones'])
    #dframe = pd.DataFrame.from_dict(toplist,orient='index',columns=['Indicator','buyzones'])
    #tseries = pd.Series(toplist)
    #dframe.index.name='Indicator'
    #tseries.reset_index()
    #dframe = pd.DataFrame(tseries,columns=['Indicator','buyzones'])
    #dframeclomuns['Indicator','buyzones']
    final=final.merge(dframe ,how="left",on="Indicator")
    return final

#not used but defined for later 
def mergetables(final:pd,*arg)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(arg)):
        test = indicators.merge(arg[i] ,how="left",on="Indicator")
        indicators = test
    return test

# call the function and merge the tables 
def callfun(final:pd,*var)->pd:
    indicators=final[['Indicator']]
    for i in range(0,len(var)):
        test=to_df(final ,globals()[var[i]],var[i])
        indicators=indicators.merge(test ,how="left",on="Indicator")
    return indicators


def wrjson(wl,name):
    test = json.dumps(wl)
    with open(name, "w") as wlf:
        json.dump(test, wlf,indent=4)
        
def frtolist(final:pd)->[]:
    whitelist = []
    wl = []
    whitelist = final['Indicator'].tolist()
    for i in range(0 ,len(whitelist)):
        #print (str(whitelist[i].replace('USDT',"/USDT")))
        wl.append(str(whitelist[i].replace('USDT',"/USDT")))
    if len(wl)==0:
        wl.append('BUSD/USDT')
    return wl

# %%
newframe=callfun(final,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','shift'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
newframe=newframe.sort_values(by=['rsiup','bottoms','bottomr'],ascending=[False,False,False])

newframe.to_csv("allindi"+str(date.today())+".csv")

test = newframe.loc[(newframe['downtrend'] <= '1h')]
test = newframe.loc[(newframe['bottomr'] >= '12h')]
#test = newframe.loc[(newframe['rsidown'] >= '2h')]
#test = newframe.loc[(newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '2h,4h') & (newframe['rsiup'] >= '1,2')]
#test = newframe.loc[(newframe['bottoms'] >= '12h') & (newframe['bottomr'] >= '1') ]
#test = newframe.loc[(newframe['bottomr'] >= '1') & (newframe['rsiup'] >= '1')]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['rsidown'].notnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['shift'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['rsidown'].isnull()) & (newframe['tops'] <='4h') & (newframe['topr'].isnull()) ]
#test = newframe.loc[(newframe['bottomr'].notnull()) &  (newframe['stkup'].notnull()) & (newframe['topr'].isnull()) ]

#test = newframe.loc[(newframe['bottoms'].notnull()) &  (newframe['topr'].isnull()) & (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['stkdown'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') ]
#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['uptrend'].notnull()) ]

#test = newframe.loc[(newframe['shift'].isnull()) &  (newframe['uptrend'].isnull()) ]

#test = newframe.loc[(newframe['stunder'] <= '3d') &  (newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]
#test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['rsidown'].isnull())]

#test = newframe.loc[(newframe['rsiup'].notnull()) & (newframe['bottoms'].notnull())  & (newframe['uptrend'].notnull())]


test = newframe.loc[(newframe['rsiup'] <= '8h') & (newframe['bottoms'].notnull())]

test = newframe.loc[(newframe['rsiup'] <= '1d') & (newframe['stover'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['stkup'].notnull()) ]
#test = newframe.loc[(newframe['rsidown'].notnull()) &  (newframe['bottoms'].notnull())]

#test = newframe.loc[(newframe['rsidown'].isnull())]

test = newframe.loc[(newframe['rsiup'] >= '1h,2h,4h') ]


#test = newframe.loc[(newframe['bottomr'] <= '12h') &  (newframe['bottoms'] <= '12h') ]
#test = newframe.loc[(newframe['bottomr'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]
#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkup'].notnull()))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]

#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h'))]

#test = newframe.loc[  ((newframe['stover']>= '4h') | (newframe['stkcross']>='12h')) & (newframe['bottomr'].notnull())]




#test = newframe.loc[(newframe['bottoms'] >= '1d') & ((newframe['stover'].notnull()) | (newframe['stkcross'].notnull()))]

#test = newframe.loc[(newframe['tops'].isnull()) &  (newframe['rsidown'].isnull()) ]


#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]

#test = newframe.loc[(newframe['rsiup'] <= '1w') & (newframe['bottoms'] >= '4h') &  (newframe['shift'].notnull())]


#test = newframe.loc[(newframe['shift'].notnull()) &  (newframe['bottoms'].notnull()) ]

#test = newframe.loc[(newframe['rsidown'].isnull()) | (newframe['rsidown'] <= '1') ]

#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) & (newframe['downtrend'].isnull()) ]
#test = newframe.loc[(newframe['shift'] >= '1h') &  (newframe['dshift'].isnull()) ]

#test = newframe.loc[(newframe['shift'] >= '12h,1d,3d')]

newframe

test
# Out:
#     Indicator  stkcross                          rsiup  \
# 59  STORJUSDT        3d  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 4    LINKUSDT        1h  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 17    IMXUSDT     5m,4h  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 26   FLUXUSDT  5m,4h,3d     5m,15m,30m,4h,8h,12h,1d,3d
# 19    RENUSDT        4h     5m,15m,30m,4h,8h,12h,1d,3d
# ..        ...       ...                            ...
# 34   GLMRUSDT       NaN               5m,15m,30m,1h,2h
# 32   MOVRUSDT     1h,2h                   5m,15m,1h,2h
# 14   DENTUSDT        4h                   4h,8h,12h,1d
# 46     SCUSDT     5m,4h            30m,4h,8h,12h,1d,3d
# 50  1INCHUSDT       NaN         30m,1h,2h,4h,8h,12h,1d
#
#                    rsidown       tops             bottoms topr  \
# 59                   1h,2h     8h,12h         5m,1h,2h,1w  NaN
# 4                    1h,2h        NaN              15m,1w  NaN
# 17                   1h,2h         1h                 NaN  NaN
# 26                1h,2h,1w         1h           5m,15m,3d  NaN
# 19                   1h,1w     30m,1h               3d,1w  NaN
# ..                     ...        ...                 ...  ...
# 34      4h,8h,12h,1d,3d,1w        NaN  30m,1h,2h,1d,3d,1w  NaN
# 32      4h,8h,12h,1d,3d,1w         5m     30m,1h,2h,4h,1d  NaN
# 14  5m,15m,30m,1h,2h,3d,1w     30m,1h            5m,1d,1w  NaN
# 46                      1w  30m,1h,8h         5m,1d,3d,1w  NaN
# 50                   3d,1w    30m,12h            5m,3d,1w  NaN
#
#                          bottomr                     stover  \
# 59                           NaN         5m,1h,12h,1d,3d,1w
# 4                            NaN         5m,1h,2h,12h,1d,1w
# 17                           NaN         5m,1h,2h,4h,12h,1d
# 26                            3d      5m,1h,2h,4h,12h,1d,3d
# 19                            3d      5m,1h,2h,4h,12h,1d,1w
# ..                           ...                        ...
# 34               8h,12h,1d,3d,1w                15m,30m,12h
# 32  30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,15m,30m,1h,2h
# 14                           NaN         5m,1h,2h,4h,12h,1d
# 46                           NaN  5m,30m,1h,2h,4h,12h,1d,1w
# 50                            1d        5m,30m,1h,2h,12h,1d
#
#                                    room                                roomr  \
# 59         5m,15m,30m,1h,2h,4h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 17     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 26        5m,15m,30m,2h,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 19         5m,15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# ..                                  ...                                  ...
# 34  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 32     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 14         5m,15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 46            5m,15m,2h,4h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 50          5m,15m,1h,2h,4h,8h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                     stunder                      stkup  \
# 59         15m,30m,2h,4h,8h      5m,1h,8h,12h,1d,3d,1w
# 4          15m,30m,4h,8h,3d         5m,1h,2h,4h,12h,1w
# 17         15m,30m,8h,3d,1w      5m,1h,2h,4h,8h,12h,1d
# 26               15m,30m,8h   5m,1h,2h,4h,8h,12h,1d,3d
# 19            15m,30m,8h,3d      5m,1h,2h,4h,12h,1d,3d
# ..                      ...                        ...
# 34  5m,1h,2h,4h,8h,1d,3d,1w                 15m,30m,1h
# 32       4h,8h,12h,1d,3d,1w           5m,15m,30m,1h,2h
# 14         15m,30m,8h,3d,1w            1h,2h,4h,12h,1d
# 46                15m,8h,3d  5m,30m,1h,2h,4h,8h,12h,1d
# 50          15m,4h,8h,3d,1w         5m,30m,1h,2h,4h,1d
#
#                      stkdown          uptrend    dshift           downtrend  \
# 59             15m,30m,2h,4h  5m,12h,1d,3d,1w        1h                  2h
# 4           15m,30m,8h,1d,3d        5m,12h,1w  1h,2h,1d                 NaN
# 17             15m,30m,3d,1w     5m,4h,12h,1d     1h,2h                 NaN
# 26                   15m,30m  5m,4h,12h,1d,3d     1h,2h                 NaN
# 19                15m,30m,8h     5m,4h,12h,1d     1h,1w                 NaN
# ..                       ...              ...       ...                 ...
# 34  5m,2h,4h,8h,12h,1d,3d,1w          15m,30m       12h      4h,8h,1d,3d,1w
# 32        4h,8h,12h,1d,3d,1w     5m,15m,1h,2h       NaN  4h,8h,12h,1d,3d,1w
# 14          15m,30m,8h,3d,1w        4h,12h,1d  5m,1h,2h       15m,30m,3d,1w
# 46                    15m,3d    30m,4h,12h,1d        1w                 NaN
# 50             15m,8h,12h,3d     30m,1h,2h,1d       12h                  3d
#
#                shift
# 59     15m,30m,4h,8h
# 4   15m,30m,4h,8h,3d
# 17  15m,30m,8h,3d,1w
# 26        15m,30m,8h
# 19     15m,30m,8h,3d
# ..               ...
# 34          5m,1h,2h
# 32               NaN
# 14                8h
# 46             8h,3d
# 50             4h,8h
#
# [63 rows x 18 columns]

# %%
 

test3 = buyzonesa(test)
test3=test3.pivot(index='buyzones',columns='Indicator')
test3.stack()
# Out:
#                                             stkcross  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT             1h,2h
# 1h,2h,4h,8h,1d            1INCHUSDT              NaN
# 4h,12h,1d,3d              SCUSDT               5m,4h
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT                 1h
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT   15m,1h,1d,3d,1w
# ...                                              ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT               4h
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT             4h,1w
# 5m,2h,4h,12h,1d           ANKRUSDT             5m,4h
# 5m,2h,4h,8h,12h,1d        PERPUSDT            15m,4h
# 8h,12h,1d                 DENTUSDT                4h
#
#                                                                 rsiup  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT                       5m,15m,1h,2h
# 1h,2h,4h,8h,1d            1INCHUSDT            30m,1h,2h,4h,8h,12h,1d
# 4h,12h,1d,3d              SCUSDT                  30m,4h,8h,12h,1d,3d
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d
# ...                                                               ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT        5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT   5m,15m,30m,1h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d           ANKRUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,8h,12h,1d        PERPUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d
# 8h,12h,1d                 DENTUSDT                       4h,8h,12h,1d
#
#                                                     rsidown           tops  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT       4h,8h,12h,1d,3d,1w             5m
# 1h,2h,4h,8h,1d            1INCHUSDT                   3d,1w        30m,12h
# 4h,12h,1d,3d              SCUSDT                         1w      30m,1h,8h
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT                        1w         30m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT                    3d,1w            30m
# ...                                                     ...            ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT                1h,2h,1w         30m,1h
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT                       2h         30m,1h
# 5m,2h,4h,12h,1d           ANKRUSDT                    3d,1w  15m,30m,1h,8h
# 5m,2h,4h,8h,12h,1d        PERPUSDT                    3d,1w     15m,30m,1h
# 8h,12h,1d                 DENTUSDT   5m,15m,30m,1h,2h,3d,1w         30m,1h
#
#                                              bottoms topr  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT   30m,1h,2h,4h,1d  NaN
# 1h,2h,4h,8h,1d            1INCHUSDT         5m,3d,1w  NaN
# 4h,12h,1d,3d              SCUSDT         5m,1d,3d,1w  NaN
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT           2h,3d,1w  NaN
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT             3d,1w  NaN
# ...                                              ...  ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT               1w  NaN
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT                1w  NaN
# 5m,2h,4h,12h,1d           ANKRUSDT             3d,1w  NaN
# 5m,2h,4h,8h,12h,1d        PERPUSDT             1d,1w  NaN
# 8h,12h,1d                 DENTUSDT          5m,1d,1w  NaN
#
#                                                           bottomr  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT   30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d            1INCHUSDT                            1d
# 4h,12h,1d,3d              SCUSDT                              NaN
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT                             NaN
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT                   8h,12h,1d,3d
# ...                                                           ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT                           NaN
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT                            NaN
# 5m,2h,4h,12h,1d           ANKRUSDT                             3d
# 5m,2h,4h,8h,12h,1d        PERPUSDT                   12h,1d,3d,1w
# 8h,12h,1d                 DENTUSDT                            NaN
#
#                                                          stover  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT             5m,15m,30m,1h,2h
# 1h,2h,4h,8h,1d            1INCHUSDT         5m,30m,1h,2h,12h,1d
# 4h,12h,1d,3d              SCUSDT      5m,30m,1h,2h,4h,12h,1d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT           5m,30m,1h,2h,12h,1d
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT    5m,15m,30m,1h,2h,1d,3d,1w
# ...                                                         ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT          5m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT        5m,30m,1h,2h,4h,1d,1w
# 5m,2h,4h,12h,1d           ANKRUSDT       5m,30m,1h,2h,4h,12h,1d
# 5m,2h,4h,8h,12h,1d        PERPUSDT   5m,15m,30m,1h,2h,4h,12h,1d
# 8h,12h,1d                 DENTUSDT           5m,1h,2h,4h,12h,1d
#
#                                                                  room  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT   15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d            1INCHUSDT       5m,15m,1h,2h,4h,8h,1d,3d,1w
# 4h,12h,1d,3d              SCUSDT            5m,15m,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT        5m,15m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT    5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# ...                                                               ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT      5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT       5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d           ANKRUSDT              5m,2h,4h,12h,1d,3d,1w
# 5m,2h,4h,8h,12h,1d        PERPUSDT           5m,2h,4h,8h,12h,1d,3d,1w
# 8h,12h,1d                 DENTUSDT       5m,15m,2h,4h,8h,12h,1d,3d,1w
#
#                                                                    roomr  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d            1INCHUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4h,12h,1d,3d              SCUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# ...                                                                  ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d           ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,8h,12h,1d        PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 8h,12h,1d                 DENTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                 stunder  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT   4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d            1INCHUSDT     15m,4h,8h,3d,1w
# 4h,12h,1d,3d              SCUSDT              15m,8h,3d
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT       15m,4h,8h,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT            4h,8h,12h
# ...                                                 ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT    15m,30m,8h,3d,1w
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT        15m,8h,12h,3d
# 5m,2h,4h,12h,1d           ANKRUSDT         15m,8h,3d,1w
# 5m,2h,4h,8h,12h,1d        PERPUSDT             8h,3d,1w
# 8h,12h,1d                 DENTUSDT     15m,30m,8h,3d,1w
#
#                                                             stkup  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT               5m,15m,30m,1h,2h
# 1h,2h,4h,8h,1d            1INCHUSDT            5m,30m,1h,2h,4h,1d
# 4h,12h,1d,3d              SCUSDT        5m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT             5m,30m,1h,2h,12h,1d
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT   5m,15m,30m,1h,2h,4h,1d,3d,1w
# ...                                                           ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT            5m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT              5m,1h,2h,4h,1d,1w
# 5m,2h,4h,12h,1d           ANKRUSDT          5m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,8h,12h,1d        PERPUSDT      5m,15m,1h,2h,4h,8h,12h,1d
# 8h,12h,1d                 DENTUSDT                1h,2h,4h,12h,1d
#
#                                                 stkdown  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT   4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d            1INCHUSDT       15m,8h,12h,3d
# 4h,12h,1d,3d              SCUSDT                 15m,3d
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT       15m,4h,8h,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT               8h,12h
# ...                                                 ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT       15m,30m,8h,3d
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT        15m,8h,12h,3d
# 5m,2h,4h,12h,1d           ANKRUSDT           15m,30m,3d
# 5m,2h,4h,8h,12h,1d        PERPUSDT                3d,1w
# 8h,12h,1d                 DENTUSDT     15m,30m,8h,3d,1w
#
#                                                     uptrend    dshift  \
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT             5m,15m,1h,2h       NaN
# 1h,2h,4h,8h,1d            1INCHUSDT            30m,1h,2h,1d       12h
# 4h,12h,1d,3d              SCUSDT              30m,4h,12h,1d        1w
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT       5m,30m,1h,2h,12h,1d       NaN
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT      5m,15m,30m,1h,2h,1d     3d,1w
# ...                                                     ...       ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT            5m,4h,12h,1d     1h,2h
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT           5m,1h,4h,1d,1w        2h
# 5m,2h,4h,12h,1d           ANKRUSDT       5m,1h,2h,4h,12h,1d       30m
# 5m,2h,4h,8h,12h,1d        PERPUSDT   5m,15m,1h,2h,4h,12h,1d       NaN
# 8h,12h,1d                 DENTUSDT                4h,12h,1d  5m,1h,2h
#
#                                               downtrend          shift
# buyzones                  Indicator
# 15m,1h,2h                 MOVRUSDT   4h,8h,12h,1d,3d,1w            NaN
# 1h,2h,4h,8h,1d            1INCHUSDT                  3d          4h,8h
# 4h,12h,1d,3d              SCUSDT                    NaN          8h,3d
# 5m,15m,1h,2h,4h,12h,1d,3d ZRXUSDT                    1w   15m,4h,8h,3d
# 5m,15m,1h,2h,4h,8h,12h,1d LUNAUSDT                  NaN      4h,8h,12h
# ...                                                 ...            ...
# 5m,15m,8h,12h,1d,3d       AUDIOUSDT                 NaN  15m,30m,8h,3d
# 5m,15m,8h,12h,1d,3d,1w    MANAUSDT                  NaN  15m,8h,12h,3d
# 5m,2h,4h,12h,1d           ANKRUSDT                   3d         15m,8h
# 5m,2h,4h,8h,12h,1d        PERPUSDT                3d,1w             8h
# 8h,12h,1d                 DENTUSDT        15m,30m,3d,1w             8h
#
# [63 rows x 17 columns]

# %%
test4 = buyzonesa(test)
test4.sort_values(by=['buyzones'],ascending=[False])
test4
# Out:
#     Indicator  stkcross                          rsiup  \
# 0   STORJUSDT        3d  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 1    LINKUSDT        1h  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 2     IMXUSDT     5m,4h  5m,15m,30m,4h,8h,12h,1d,3d,1w
# 3    FLUXUSDT  5m,4h,3d     5m,15m,30m,4h,8h,12h,1d,3d
# 4     RENUSDT        4h     5m,15m,30m,4h,8h,12h,1d,3d
# ..        ...       ...                            ...
# 58   GLMRUSDT       NaN               5m,15m,30m,1h,2h
# 59   MOVRUSDT     1h,2h                   5m,15m,1h,2h
# 60   DENTUSDT        4h                   4h,8h,12h,1d
# 61     SCUSDT     5m,4h            30m,4h,8h,12h,1d,3d
# 62  1INCHUSDT       NaN         30m,1h,2h,4h,8h,12h,1d
#
#                    rsidown       tops             bottoms topr  \
# 0                    1h,2h     8h,12h         5m,1h,2h,1w  NaN
# 1                    1h,2h        NaN              15m,1w  NaN
# 2                    1h,2h         1h                 NaN  NaN
# 3                 1h,2h,1w         1h           5m,15m,3d  NaN
# 4                    1h,1w     30m,1h               3d,1w  NaN
# ..                     ...        ...                 ...  ...
# 58      4h,8h,12h,1d,3d,1w        NaN  30m,1h,2h,1d,3d,1w  NaN
# 59      4h,8h,12h,1d,3d,1w         5m     30m,1h,2h,4h,1d  NaN
# 60  5m,15m,30m,1h,2h,3d,1w     30m,1h            5m,1d,1w  NaN
# 61                      1w  30m,1h,8h         5m,1d,3d,1w  NaN
# 62                   3d,1w    30m,12h            5m,3d,1w  NaN
#
#                          bottomr                     stover  \
# 0                            NaN         5m,1h,12h,1d,3d,1w
# 1                            NaN         5m,1h,2h,12h,1d,1w
# 2                            NaN         5m,1h,2h,4h,12h,1d
# 3                             3d      5m,1h,2h,4h,12h,1d,3d
# 4                             3d      5m,1h,2h,4h,12h,1d,1w
# ..                           ...                        ...
# 58               8h,12h,1d,3d,1w                15m,30m,12h
# 59  30m,1h,2h,4h,8h,12h,1d,3d,1w           5m,15m,30m,1h,2h
# 60                           NaN         5m,1h,2h,4h,12h,1d
# 61                           NaN  5m,30m,1h,2h,4h,12h,1d,1w
# 62                            1d        5m,30m,1h,2h,12h,1d
#
#                                    room                                roomr  \
# 0          5m,15m,30m,1h,2h,4h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 2      5m,15m,30m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 3         5m,15m,30m,2h,4h,8h,12h,1d,3d  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4          5m,15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# ..                                  ...                                  ...
# 58  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 59     15m,30m,1h,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 60         5m,15m,2h,4h,8h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 61            5m,15m,2h,4h,12h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 62          5m,15m,1h,2h,4h,8h,1d,3d,1w  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                     stunder                      stkup  \
# 0          15m,30m,2h,4h,8h      5m,1h,8h,12h,1d,3d,1w
# 1          15m,30m,4h,8h,3d         5m,1h,2h,4h,12h,1w
# 2          15m,30m,8h,3d,1w      5m,1h,2h,4h,8h,12h,1d
# 3                15m,30m,8h   5m,1h,2h,4h,8h,12h,1d,3d
# 4             15m,30m,8h,3d      5m,1h,2h,4h,12h,1d,3d
# ..                      ...                        ...
# 58  5m,1h,2h,4h,8h,1d,3d,1w                 15m,30m,1h
# 59       4h,8h,12h,1d,3d,1w           5m,15m,30m,1h,2h
# 60         15m,30m,8h,3d,1w            1h,2h,4h,12h,1d
# 61                15m,8h,3d  5m,30m,1h,2h,4h,8h,12h,1d
# 62          15m,4h,8h,3d,1w         5m,30m,1h,2h,4h,1d
#
#                      stkdown          uptrend    dshift           downtrend  \
# 0              15m,30m,2h,4h  5m,12h,1d,3d,1w        1h                  2h
# 1           15m,30m,8h,1d,3d        5m,12h,1w  1h,2h,1d                 NaN
# 2              15m,30m,3d,1w     5m,4h,12h,1d     1h,2h                 NaN
# 3                    15m,30m  5m,4h,12h,1d,3d     1h,2h                 NaN
# 4                 15m,30m,8h     5m,4h,12h,1d     1h,1w                 NaN
# ..                       ...              ...       ...                 ...
# 58  5m,2h,4h,8h,12h,1d,3d,1w          15m,30m       12h      4h,8h,1d,3d,1w
# 59        4h,8h,12h,1d,3d,1w     5m,15m,1h,2h       NaN  4h,8h,12h,1d,3d,1w
# 60          15m,30m,8h,3d,1w        4h,12h,1d  5m,1h,2h       15m,30m,3d,1w
# 61                    15m,3d    30m,4h,12h,1d        1w                 NaN
# 62             15m,8h,12h,3d     30m,1h,2h,1d       12h                  3d
#
#                shift                    buyzones
# 0      15m,30m,4h,8h         5m,15m,30m,1d,3d,1w
# 1   15m,30m,4h,8h,3d  5m,15m,30m,8h,12h,1d,3d,1w
# 2   15m,30m,8h,3d,1w  5m,15m,30m,8h,12h,1d,3d,1w
# 3         15m,30m,8h     5m,15m,30m,8h,12h,1d,3d
# 4      15m,30m,8h,3d      5m,15m,4h,8h,12h,1d,3d
# ..               ...                         ...
# 58          5m,1h,2h            5m,15m,30m,1h,2h
# 59               NaN                   15m,1h,2h
# 60                8h                   8h,12h,1d
# 61             8h,3d                4h,12h,1d,3d
# 62             4h,8h              1h,2h,4h,8h,1d
#
# [63 rows x 19 columns]

# %%
# Indicators for the week shift

newframe=callfun(wshift,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')

#newframe=newframe.sort_values(by=['downtrend','dshift','bottoms'],ascending=[True,True,True])
newframe=newframe.sort_values(by=['bottoms','stkup','bottomr'],ascending=[False,True,False])

newframe=buyzonesa(newframe)
newframe
pivotf = newframe.pivot(index='buyzones',columns='Indicator',values='Indicator')
pivotf
# Out:
# Indicator                      ANTUSDT  BANDUSDT  FTMUSDT  IMXUSDT
# buyzones
# 5m,15m,2h,4h,1d                    NaN       NaN  FTMUSDT      NaN
# 5m,15m,2h,4h,8h,12h,1d             NaN  BANDUSDT      NaN      NaN
# 5m,15m,30m,1h,2h,4h,8h,12h,1d  ANTUSDT       NaN      NaN      NaN
# 5m,15m,30m,8h,12h,1d,3d,1w         NaN       NaN      NaN  IMXUSDT

# %%
# Indicators for the 1d down
newframe=callfun(macd1dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='1d'))]


test=buyzonesa(test)
test

#pivotf = test.pivot(index='buyzones',columns='Indicator',values='Indicator')
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                                             stkcross  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT      15m,4h
# 5m,2h,4h,12h,1d                 ANKRUSDT       5m,4h
# 5m,15m,8h,12h,1d,1w             REEFUSDT       5m,4h
# 5m,15m,8h,12h,1d                CRVUSDT           4h
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT           4h
# 5m,15m,4h,8h,12h,1d             ROSEUSDT          4h
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT         1h,4h
#                                 FLUXUSDT    5m,4h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT         NaN
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT           4h
#                                 GRTUSDT           4h
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT    15m,1h,4h
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT      4h,8h
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT          4h
#                                 CAKEUSDT          4h
#                                 KSMUSDT           3d
#                                 ONTUSDT           4h
#                                 SRMUSDT     1h,3d,1w
#                                 SUSHIUSDT         4h
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT        4h,8h
#                                 MATICUSDT         4h
#                                 MINAUSDT         NaN
#                                 ONEUSDT        1h,4h
#                                 RAYUSDT           4h
#                                 VETUSDT           4h
# 5m,15m,2h,4h,1d                 FTMUSDT        1h,3d
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT          4h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT           1w
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT          5m
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT     1h,4h,3d
# 1h,2h,4h,8h,1d                  1INCHUSDT        NaN
#
#                                                                          rsiup  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,12h,1d                 ANKRUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,8h,12h,1d,1w             REEFUSDT            5m,15m,30m,4h,8h,12h,1d,1w
# 5m,15m,8h,12h,1d                CRVUSDT                5m,15m,30m,4h,8h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT             5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,4h,8h,12h,1d             ROSEUSDT            5m,15m,30m,2h,4h,8h,12h,1d
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT              5m,15m,30m,4h,8h,12h,1d,3d
#                                 FLUXUSDT            5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT         5m,15m,30m,2h,4h,8h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                 GRTUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                 CAKEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                 KSMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                 ONTUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                 SRMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                 SUSHIUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                 MATICUSDT           5m,15m,30m,2h,4h,8h,12h,1d
#                                 MINAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                 ONEUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                 RAYUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                 VETUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,1d                 FTMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT             15m,30m,1h,2h,4h,8h,12h,1d
# 1h,2h,4h,8h,1d                  1INCHUSDT               30m,1h,2h,4h,8h,12h,1d
#
#                                             rsidown           tops  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT      3d,1w     15m,30m,1h
# 5m,2h,4h,12h,1d                 ANKRUSDT      3d,1w  15m,30m,1h,8h
# 5m,15m,8h,12h,1d,1w             REEFUSDT      2h,3d         30m,1h
# 5m,15m,8h,12h,1d                CRVUSDT    2h,3d,1w         30m,1h
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT       1h,1w         30m,1h
# 5m,15m,4h,8h,12h,1d             ROSEUSDT   1h,3d,1w         30m,1h
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT     1h,2h,1w            NaN
#                                 FLUXUSDT   1h,2h,1w             1h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT         1w             1h
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT       3d,1w             1h
#                                 GRTUSDT       3d,1w             1h
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT       3d,1w             4h
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT     3d,1w             8h
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT         1w         30m,1h
#                                 CAKEUSDT         1w         30m,1h
#                                 KSMUSDT          1w         30m,1h
#                                 ONTUSDT          1w         30m,1h
#                                 SRMUSDT          1w         30m,1h
#                                 SUSHIUSDT        1w         30m,1h
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT       3d,1w         30m,1h
#                                 MATICUSDT     3d,1w         30m,1h
#                                 MINAUSDT      3d,1w         30m,1h
#                                 ONEUSDT       3d,1w         30m,1h
#                                 RAYUSDT       3d,1w         30m,1h
#                                 VETUSDT       3d,1w         30m,1h
# 5m,15m,2h,4h,1d                 FTMUSDT          3d  30m,1h,8h,12h
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT        NaN      30m,1h,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT         NaN            30m
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT      3d,1w            30m
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT    5m,3d,1w            NaN
# 1h,2h,4h,8h,1d                  1INCHUSDT     3d,1w        30m,12h
#
#                                                  bottoms topr  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT           1d,1w  NaN
# 5m,2h,4h,12h,1d                 ANKRUSDT           3d,1w  NaN
# 5m,15m,8h,12h,1d,1w             REEFUSDT           5m,1w  NaN
# 5m,15m,8h,12h,1d                CRVUSDT         1d,3d,1w  NaN
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT            3d,1w  NaN
# 5m,15m,4h,8h,12h,1d             ROSEUSDT           5m,1w  NaN
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT     15m,30m,3d,1w  NaN
#                                 FLUXUSDT       5m,15m,3d  NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT           2h,1w  NaN
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT            3d,1w  NaN
#                                 GRTUSDT            1d,1w  NaN
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT            1d,1w  NaN
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT          3d,1w  NaN
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT           3d,1w  NaN
#                                 CAKEUSDT     5m,1d,3d,1w  NaN
#                                 KSMUSDT      2h,4h,3d,1w  NaN
#                                 ONTUSDT            1d,1w  NaN
#                                 SRMUSDT         5m,3d,1w  NaN
#                                 SUSHIUSDT          3d,1w  NaN
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT         1d,3d,1w  NaN
#                                 MATICUSDT          1d,1w  NaN
#                                 MINAUSDT           3d,1w  NaN
#                                 ONEUSDT               1w  NaN
#                                 RAYUSDT            3d,1w  NaN
#                                 VETUSDT            3d,1w  NaN
# 5m,15m,2h,4h,1d                 FTMUSDT               1w  NaN
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT        5m,3d,1w  NaN
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT         2h,3d,1w  NaN
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT        5m,1d,1w  NaN
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT            1d,1w  NaN
# 1h,2h,4h,8h,1d                  1INCHUSDT       5m,3d,1w  NaN
#
#                                                    bottomr  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT      12h,1d,3d,1w
# 5m,2h,4h,12h,1d                 ANKRUSDT                3d
# 5m,15m,8h,12h,1d,1w             REEFUSDT                3d
# 5m,15m,8h,12h,1d                CRVUSDT                 1d
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT                 3d
# 5m,15m,4h,8h,12h,1d             ROSEUSDT                3d
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT                  3d
#                                 FLUXUSDT                3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT             3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT           1d,3d,1w
#                                 GRTUSDT                 3d
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT              1d,3d
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT               3d
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT             3d,1w
#                                 CAKEUSDT         12h,1d,3d
#                                 KSMUSDT                 3d
#                                 ONTUSDT                 3d
#                                 SRMUSDT                 3d
#                                 SUSHIUSDT               3d
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT    8h,12h,1d,3d,1w
#                                 MATICUSDT         1d,3d,1w
#                                 MINAUSDT                3d
#                                 ONEUSDT              1d,3d
#                                 RAYUSDT              1d,3d
#                                 VETUSDT                 3d
# 5m,15m,2h,4h,1d                 FTMUSDT                 3d
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT      12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT                 3d
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT                3d
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT              3d,1w
# 1h,2h,4h,8h,1d                  1INCHUSDT               1d
#
#                                                                  stover  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT     5m,15m,30m,1h,2h,4h,12h,1d
# 5m,2h,4h,12h,1d                 ANKRUSDT         5m,30m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,1w             REEFUSDT           5m,1h,2h,4h,1d,3d,1w
# 5m,15m,8h,12h,1d                CRVUSDT              5m,1h,2h,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT           5m,1h,2h,4h,12h,1d,1w
# 5m,15m,4h,8h,12h,1d             ROSEUSDT             5m,1h,2h,4h,12h,1d
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT               5m,1h,2h,4h,12h,1d
#                                 FLUXUSDT          5m,1h,2h,4h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT                 5m,1h,2h,1d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT              5m,1h,2h,4h,12h,1d
#                                 GRTUSDT              5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT          5m,15m,1h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT         5m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT         5m,30m,1h,2h,4h,12h,1d
#                                 CAKEUSDT             5m,1h,2h,4h,12h,1d
#                                 KSMUSDT                  5m,1h,2h,1d,3d
#                                 ONTUSDT          5m,30m,1h,2h,4h,12h,1d
#                                 SRMUSDT            5m,1h,2h,4h,1d,3d,1w
#                                 SUSHIUSDT            5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT    5m,30m,1h,2h,4h,8h,12h,1d,1w
#                                 MATICUSDT        5m,30m,1h,2h,4h,12h,1d
#                                 MINAUSDT                 5m,1h,2h,4h,1d
#                                 ONEUSDT          5m,30m,1h,2h,4h,12h,1d
#                                 RAYUSDT              5m,1h,2h,4h,12h,1d
#                                 VETUSDT              5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                 FTMUSDT       5m,30m,1h,2h,4h,12h,1d,3d
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT   5m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT           5m,30m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT                5m,1h,2h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT       5m,30m,1h,2h,4h,12h,1d,3d
# 1h,2h,4h,8h,1d                  1INCHUSDT           5m,30m,1h,2h,12h,1d
#
#                                                                           room  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT              5m,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d                 ANKRUSDT                 5m,2h,4h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,1w             REEFUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d                CRVUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d             ROSEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 FLUXUSDT         5m,15m,30m,2h,4h,8h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT      5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
#                                 GRTUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT       5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 CAKEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 KSMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 ONTUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 SRMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 SUSHIUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 MATICUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 MINAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 ONEUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 RAYUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 VETUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                 FTMUSDT                  5m,15m,2h,4h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT             5m,15m,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT        5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d                  1INCHUSDT          5m,15m,1h,2h,4h,8h,1d,3d,1w
#
#                                                                          roomr  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d                 ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,1w             REEFUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d                CRVUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d             ROSEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 FLUXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 GRTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 CAKEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 KSMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 ONTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 SRMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 SUSHIUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 MATICUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 MINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 ONEUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 VETUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                 FTMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d                  1INCHUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                         stunder  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT               8h,3d,1w
# 5m,2h,4h,12h,1d                 ANKRUSDT           15m,8h,3d,1w
# 5m,15m,8h,12h,1d,1w             REEFUSDT         15m,30m,8h,12h
# 5m,15m,8h,12h,1d                CRVUSDT        15m,30m,8h,3d,1w
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT           15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d             ROSEUSDT       15m,30m,8h,3d,1w
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT         15m,30m,8h,3d,1w
#                                 FLUXUSDT             15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT   15m,30m,4h,8h,12h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT        15m,30m,8h,3d,1w
#                                 GRTUSDT        15m,30m,8h,3d,1w
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT            30m,2h,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT         15m,30m,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT           15m,8h,3d,1w
#                                 CAKEUSDT       15m,30m,8h,3d,1w
#                                 KSMUSDT       15m,30m,4h,8h,12h
#                                 ONTUSDT            15m,8h,3d,1w
#                                 SRMUSDT          15m,30m,8h,12h
#                                 SUSHIUSDT      15m,30m,8h,3d,1w
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT                  15m,3d
#                                 MATICUSDT          15m,8h,3d,1w
#                                 MINAUSDT   15m,30m,8h,12h,3d,1w
#                                 ONEUSDT               15m,8h,3d
#                                 RAYUSDT        15m,30m,8h,3d,1w
#                                 VETUSDT        15m,30m,8h,3d,1w
# 5m,15m,2h,4h,1d                 FTMUSDT               15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT                 15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT           15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT    15m,30m,4h,8h,3d,1w
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT               15m,8h,1w
# 1h,2h,4h,8h,1d                  1INCHUSDT       15m,4h,8h,3d,1w
#
#                                                                      stkup  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT         5m,15m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,12h,1d                 ANKRUSDT             5m,1h,2h,4h,8h,12h,1d
# 5m,15m,8h,12h,1d,1w             REEFUSDT              5m,1h,2h,4h,1d,3d,1w
# 5m,15m,8h,12h,1d                CRVUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT              5m,1h,2h,4h,12h,1d,3d
# 5m,15m,4h,8h,12h,1d             ROSEUSDT                    5m,1h,2h,4h,1d
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT                     5m,1h,4h,12h,1d
#                                 FLUXUSDT          5m,1h,2h,4h,8h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT                    5m,1h,2h,4h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT                 5m,15m,1h,2h,4h,1d
#                                 GRTUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT             5m,15m,1h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT            5m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT             5m,1h,2h,4h,12h,1d,3d
#                                 CAKEUSDT             5m,1h,2h,4h,8h,12h,1d
#                                 KSMUSDT              5m,15m,1h,2h,4h,1d,3d
#                                 ONTUSDT             5m,30m,1h,2h,4h,12h,1d
#                                 SRMUSDT           5m,15m,1h,2h,4h,8h,1d,3d
#                                 SUSHIUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT          5m,30m,1h,2h,4h,8h,12h,1d
#                                 MATICUSDT            5m,1h,2h,4h,8h,12h,1d
#                                 MINAUSDT                5m,30m,2h,4h,8h,1d
#                                 ONEUSDT         5m,15m,30m,1h,2h,4h,12h,1d
#                                 RAYUSDT                 5m,1h,2h,4h,12h,1d
#                                 VETUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                 FTMUSDT    5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT       5m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT           5m,15m,1h,2h,4h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT             5m,1h,2h,4h,8h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT           5m,1h,2h,4h,8h,12h,1d,3d
# 1h,2h,4h,8h,1d                  1INCHUSDT               5m,30m,1h,2h,4h,1d
#
#                                                      stkdown  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT               3d,1w
# 5m,2h,4h,12h,1d                 ANKRUSDT          15m,30m,3d
# 5m,15m,8h,12h,1d,1w             REEFUSDT      15m,30m,8h,12h
# 5m,15m,8h,12h,1d                CRVUSDT        15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT           15m,30m,8h
# 5m,15m,4h,8h,12h,1d             ROSEUSDT   15m,30m,8h,12h,3d
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT      15m,30m,2h,8h,3d
#                                 FLUXUSDT             15m,30m
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT   15m,30m,8h,12h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT        30m,8h,12h,3d
#                                 GRTUSDT        15m,30m,8h,3d
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT         30m,2h,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT         15m,30m,3d
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT          15m,30m,8h
#                                 CAKEUSDT       15m,30m,3d,1w
#                                 KSMUSDT           30m,8h,12h
#                                 ONTUSDT            15m,8h,3d
#                                 SRMUSDT              30m,12h
#                                 SUSHIUSDT   15m,30m,8h,3d,1w
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT               15m,3d
#                                 MATICUSDT         15m,30m,3d
#                                 MINAUSDT          15m,12h,3d
#                                 ONEUSDT                8h,3d
#                                 RAYUSDT        15m,30m,8h,3d
#                                 VETUSDT        15m,30m,8h,3d
# 5m,15m,2h,4h,1d                 FTMUSDT                  NaN
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT             15m,30m
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT               8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT          15m,30m,3d
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT           15m,30m,1w
# 1h,2h,4h,8h,1d                  1INCHUSDT      15m,8h,12h,3d
#
#                                                              uptrend  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT      5m,15m,1h,2h,4h,12h,1d
# 5m,2h,4h,12h,1d                 ANKRUSDT          5m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,1w             REEFUSDT                 5m,4h,1d,1w
# 5m,15m,8h,12h,1d                CRVUSDT                 5m,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT                 5m,4h,12h,1d
# 5m,15m,4h,8h,12h,1d             ROSEUSDT                 5m,2h,4h,1d
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT                  5m,4h,12h,1d
#                                 FLUXUSDT             5m,4h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT                    5m,2h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT               5m,1h,2h,4h,1d
#                                 GRTUSDT           5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT       5m,15m,1h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT      5m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT          5m,1h,2h,4h,12h,1d
#                                 CAKEUSDT          5m,1h,2h,4h,12h,1d
#                                 KSMUSDT               5m,1h,2h,1d,3d
#                                 ONTUSDT       5m,30m,1h,2h,4h,12h,1d
#                                 SRMUSDT            5m,1h,2h,4h,1d,3d
#                                 SUSHIUSDT         5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT    5m,30m,1h,2h,4h,8h,12h,1d
#                                 MATICUSDT            5m,2h,4h,12h,1d
#                                 MINAUSDT                 5m,2h,4h,1d
#                                 ONEUSDT       5m,30m,1h,2h,4h,12h,1d
#                                 RAYUSDT           5m,1h,2h,4h,12h,1d
#                                 VETUSDT           5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                 FTMUSDT           5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT    5m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT            5m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT             5m,1h,2h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT              1h,2h,4h,12h,1d
# 1h,2h,4h,8h,1d                  1INCHUSDT               30m,1h,2h,1d
#
#                                               dshift downtrend  \
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT         NaN     3d,1w
# 5m,2h,4h,12h,1d                 ANKRUSDT         30m        3d
# 5m,15m,8h,12h,1d,1w             REEFUSDT       2h,3d       NaN
# 5m,15m,8h,12h,1d                CRVUSDT           2h        3d
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT        1h,1w       NaN
# 5m,15m,4h,8h,12h,1d             ROSEUSDT      1h,12h        3d
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT         1h,2h       NaN
#                                 FLUXUSDT       1h,2h       NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT          1w       NaN
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT          12h        3d
#                                 GRTUSDT          NaN        3d
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT          NaN     3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT        NaN        3d
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT         30m       NaN
#                                 CAKEUSDT         NaN        1w
#                                 KSMUSDT          NaN       NaN
#                                 ONTUSDT          NaN       NaN
#                                 SRMUSDT           1w       NaN
#                                 SUSHIUSDT        NaN        1w
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT           1w        3d
#                                 MATICUSDT        30m        3d
#                                 MINAUSDT         NaN        3d
#                                 ONEUSDT          NaN        3d
#                                 RAYUSDT          NaN        3d
#                                 VETUSDT          NaN        3d
# 5m,15m,2h,4h,1d                 FTMUSDT           3d       NaN
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT         30m       NaN
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT          NaN       NaN
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT         NaN        3d
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT    5m,30m,3d        1w
# 1h,2h,4h,8h,1d                  1INCHUSDT        12h        3d
#
#                                                           shift
# buyzones                        Indicator
# 5m,2h,4h,8h,12h,1d              PERPUSDT                     8h
# 5m,2h,4h,12h,1d                 ANKRUSDT                 15m,8h
# 5m,15m,8h,12h,1d,1w             REEFUSDT         15m,30m,8h,12h
# 5m,15m,8h,12h,1d                CRVUSDT              15m,30m,8h
# 5m,15m,4h,8h,12h,1d,3d          RENUSDT           15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d             ROSEUSDT             15m,30m,8h
# 5m,15m,30m,8h,12h,1d,3d         ARUSDT            15m,30m,8h,3d
#                                 FLUXUSDT             15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d   ATOMUSDT   15m,30m,4h,8h,12h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d      FILUSDT              15m,30m,8h
#                                 GRTUSDT              15m,30m,8h
# 5m,15m,30m,1h,2h,8h,12h,1d      WINUSDT                  30m,2h
# 5m,15m,30m,1h,2h,4h,12h,1d      TFUELUSDT               15m,30m
# 5m,15m,2h,4h,8h,12h,1d,3d       AVAXUSDT              15m,8h,3d
#                                 CAKEUSDT          15m,30m,8h,3d
#                                 KSMUSDT       15m,30m,4h,8h,12h
#                                 ONTUSDT               15m,8h,3d
#                                 SRMUSDT          15m,30m,8h,12h
#                                 SUSHIUSDT         15m,30m,8h,3d
# 5m,15m,2h,4h,8h,12h,1d          BTCUSDT                     15m
#                                 MATICUSDT                15m,8h
#                                 MINAUSDT         15m,30m,8h,12h
#                                 ONEUSDT                  15m,8h
#                                 RAYUSDT              15m,30m,8h
#                                 VETUSDT              15m,30m,8h
# 5m,15m,2h,4h,1d                 FTMUSDT               15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w       SCRTUSDT                 15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT           15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d       WAXPUSDT          15m,30m,4h,8h
# 30m,1h,2h,4h,8h,12h,1d          MIRUSDT                  15m,8h
# 1h,2h,4h,8h,1d                  1INCHUSDT                 4h,8h

# %%
## MACD 3d gap and rsi up
newframe=callfun(macd3dd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['rsiup'] > newframe['rsidown']) ]

#test = newframe.loc[(newframe['rsiup'].notnull()) &  (newframe['rsidown'] >= "1w" )]



test=buyzonesa(test)
#test.dropna(subset=['stkcross'],inplace=True)
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                                                    stkcross  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT             4h,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT               4h
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT                 4h
# 5m,15m,4h,8h,12h,1d              DOTUSDT                 5m
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT                1h
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT               1h,4h
#                                  FLUXUSDT          5m,4h,3d
#                                  LRCUSDT                 4h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT              NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT               NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            4h,8h
# 5m,15m,30m,1h,2h                 PAXGUSDT                1h
# 5m,15m,30m,1d,3d,1w              STORJUSDT               3d
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT                4h
#                                  CAKEUSDT                4h
#                                  KSMUSDT                 3d
#                                  LINAUSDT                4h
#                                  ONTUSDT                 4h
#                                  RUNEUSDT               NaN
#                                  SRMUSDT           1h,3d,1w
#                                  SUSHIUSDT               4h
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT                4h
#                                  RAYUSDT                 4h
# 5m,15m,2h,4h,1d                  FTMUSDT              1h,3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                4h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT                 1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT   15m,1h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT                 1h
# 4h,12h,1d,3d                     SCUSDT               5m,4h
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT           1h,4h,3d
# 1h,2h,4h,8h,1d                   1INCHUSDT              NaN
#
#                                                                           rsiup  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT      5m,15m,30m,1h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT           5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT             5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,4h,8h,12h,1d              DOTUSDT                5m,15m,30m,4h,8h,12h,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT         5m,15m,30m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT              5m,15m,30m,4h,8h,12h,1d,3d
#                                  FLUXUSDT            5m,15m,30m,4h,8h,12h,1d,3d
#                                  LRCUSDT             5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT         5m,15m,30m,2h,4h,8h,12h,1d,3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h                 PAXGUSDT                5m,15m,30m,1h,2h,4h,3d
# 5m,15m,30m,1d,3d,1w              STORJUSDT        5m,15m,30m,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  CAKEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  KSMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  LINAUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  ONTUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  RUNEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  SRMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  SUSHIUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  RAYUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 4h,12h,1d,3d                     SCUSDT                     30m,4h,8h,12h,1d,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT             15m,30m,1h,2h,4h,8h,12h,1d
# 1h,2h,4h,8h,1d                   1INCHUSDT               30m,1h,2h,4h,8h,12h,1d
#
#                                                  rsidown           tops  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT             2h         30m,1h
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT      1h,2h,1w         30m,1h
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           1h,1w         30m,1h
# 5m,15m,4h,8h,12h,1d              DOTUSDT        1h,3d,1w         30m,1h
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT          1h,2h            NaN
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT         1h,2h,1w            NaN
#                                  FLUXUSDT       1h,2h,1w             1h
#                                  LRCUSDT        1h,2h,1w             1h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT           NaN             1h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT             1w             1h
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT         3d,1w             8h
# 5m,15m,30m,1h,2h                 PAXGUSDT   8h,12h,1d,1w             4h
# 5m,15m,30m,1d,3d,1w              STORJUSDT         1h,2h         8h,12h
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT             1w         30m,1h
#                                  CAKEUSDT             1w         30m,1h
#                                  KSMUSDT              1w         30m,1h
#                                  LINAUSDT             1w         30m,1h
#                                  ONTUSDT              1w         30m,1h
#                                  RUNEUSDT             1w         30m,1h
#                                  SRMUSDT              1w         30m,1h
#                                  SUSHIUSDT            1w         30m,1h
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT          3d,1w         30m,1h
#                                  RAYUSDT           3d,1w         30m,1h
# 5m,15m,2h,4h,1d                  FTMUSDT              3d  30m,1h,8h,12h
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT            NaN      30m,1h,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT             NaN            30m
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT          3d,1w            30m
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT              1w         30m,8h
# 4h,12h,1d,3d                     SCUSDT               1w      30m,1h,8h
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT        5m,3d,1w            NaN
# 1h,2h,4h,8h,1d                   1INCHUSDT         3d,1w        30m,12h
#
#                                                   bottoms topr       bottomr  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT              1w  NaN           NaN
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT             1w  NaN           NaN
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT            3d,1w  NaN            3d
# 5m,15m,4h,8h,12h,1d              DOTUSDT      5m,2h,4h,1w  NaN           NaN
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT          15m,1w  NaN           NaN
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT     15m,30m,3d,1w  NaN            3d
#                                  FLUXUSDT       5m,15m,3d  NaN            3d
#                                  LRCUSDT               1w  NaN           NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT             1w  NaN           NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT           2h,1w  NaN         3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT          3d,1w  NaN            3d
# 5m,15m,30m,1h,2h                 PAXGUSDT          30m,1h  NaN           NaN
# 5m,15m,30m,1d,3d,1w              STORJUSDT    5m,1h,2h,1w  NaN           NaN
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT           3d,1w  NaN         3d,1w
#                                  CAKEUSDT     5m,1d,3d,1w  NaN     12h,1d,3d
#                                  KSMUSDT      2h,4h,3d,1w  NaN            3d
#                                  LINAUSDT              1w  NaN           NaN
#                                  ONTUSDT            1d,1w  NaN            3d
#                                  RUNEUSDT        1d,3d,1w  NaN           NaN
#                                  SRMUSDT         5m,3d,1w  NaN            3d
#                                  SUSHIUSDT          3d,1w  NaN            3d
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT           3d,1w  NaN           NaN
#                                  RAYUSDT            3d,1w  NaN         1d,3d
# 5m,15m,2h,4h,1d                  FTMUSDT               1w  NaN            3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT        5m,3d,1w  NaN  12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT         2h,3d,1w  NaN            3d
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT           3d,1w  NaN  8h,12h,1d,3d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT         2h,3d,1w  NaN           NaN
# 4h,12h,1d,3d                     SCUSDT       5m,1d,3d,1w  NaN           NaN
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT            1d,1w  NaN         3d,1w
# 1h,2h,4h,8h,1d                   1INCHUSDT       5m,3d,1w  NaN            1d
#
#                                                                   stover  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          5m,30m,1h,2h,4h,1d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT            5m,1h,2h,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           5m,1h,2h,4h,12h,1d,1w
# 5m,15m,4h,8h,12h,1d              DOTUSDT                 5m,30m,1h,2h,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT             5m,1h,2h,12h,1d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT               5m,1h,2h,4h,12h,1d
#                                  FLUXUSDT          5m,1h,2h,4h,12h,1d,3d
#                                  LRCUSDT              5m,1h,2h,4h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT      5m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT                 5m,1h,2h,1d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT         5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h                 PAXGUSDT             5m,1h,8h,12h,1d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT            5m,1h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT         5m,30m,1h,2h,4h,12h,1d
#                                  CAKEUSDT             5m,1h,2h,4h,12h,1d
#                                  KSMUSDT                  5m,1h,2h,1d,3d
#                                  LINAUSDT                 5m,1h,2h,4h,1d
#                                  ONTUSDT          5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                5m,1h,2h,12h,1d
#                                  SRMUSDT            5m,1h,2h,4h,1d,3d,1w
#                                  SUSHIUSDT            5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT          5m,1h,2h,4h,12h,1d,1w
#                                  RAYUSDT              5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT       5m,30m,1h,2h,4h,12h,1d,3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           5m,30m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT      5m,15m,30m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT             5m,30m,1h,2h,12h,1d
# 4h,12h,1d,3d                     SCUSDT        5m,30m,1h,2h,4h,12h,1d,1w
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT       5m,30m,1h,2h,4h,12h,1d,3d
# 1h,2h,4h,8h,1d                   1INCHUSDT           5m,30m,1h,2h,12h,1d
#
#                                                                            room  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d              DOTUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  FLUXUSDT         5m,15m,30m,2h,4h,8h,12h,1d,3d
#                                  LRCUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT      5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h                 PAXGUSDT      5m,15m,30m,1h,2h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT         5m,15m,30m,1h,2h,4h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  CAKEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  KSMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  LINAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  ONTUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  RUNEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  SRMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  SUSHIUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  RAYUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT                  5m,15m,2h,4h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT             5m,15m,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT        5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT           5m,15m,1h,2h,4h,12h,1d,3d,1w
# 4h,12h,1d,3d                     SCUSDT               5m,15m,2h,4h,12h,1d,3d,1w
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d                   1INCHUSDT          5m,15m,1h,2h,4h,8h,1d,3d,1w
#
#                                                                           roomr  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d              DOTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  FLUXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  LRCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h                 PAXGUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  CAKEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  KSMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  LINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  ONTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  RUNEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  SRMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  SUSHIUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4h,12h,1d,3d                     SCUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 1h,2h,4h,8h,1d                   1INCHUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                          stunder  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          15m,8h,12h,3d
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT      15m,30m,8h,3d,1w
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d              DOTUSDT     15m,4h,8h,12h,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT       15m,30m,4h,8h,3d
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT         15m,30m,8h,3d,1w
#                                  FLUXUSDT             15m,30m,8h
#                                  LRCUSDT        15m,30m,8h,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT            15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT   15m,30m,4h,8h,12h,3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT         15m,30m,3d,1w
# 5m,15m,30m,1h,2h                 PAXGUSDT       15m,30m,2h,4h,3d
# 5m,15m,30m,1d,3d,1w              STORJUSDT      15m,30m,2h,4h,8h
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT           15m,8h,3d,1w
#                                  CAKEUSDT       15m,30m,8h,3d,1w
#                                  KSMUSDT       15m,30m,4h,8h,12h
#                                  LINAUSDT   15m,30m,8h,12h,3d,1w
#                                  ONTUSDT            15m,8h,3d,1w
#                                  RUNEUSDT    15m,30m,4h,8h,3d,1w
#                                  SRMUSDT          15m,30m,8h,12h
#                                  SUSHIUSDT      15m,30m,8h,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT          15m,30m,8h,3d
#                                  RAYUSDT        15m,30m,8h,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT               15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                 15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT              4h,8h,12h
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT         15m,4h,8h,3d,1w
# 4h,12h,1d,3d                     SCUSDT                15m,8h,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT               15m,8h,1w
# 1h,2h,4h,8h,1d                   1INCHUSDT       15m,4h,8h,3d,1w
#
#                                                                       stkup  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT                 5m,1h,2h,4h,1d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT              5m,1h,2h,4h,12h,1d,3d
# 5m,15m,4h,8h,12h,1d              DOTUSDT                     5m,1h,2h,4h,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT                5m,1h,2h,4h,12h,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT                     5m,1h,4h,12h,1d
#                                  FLUXUSDT          5m,1h,2h,4h,8h,12h,1d,3d
#                                  LRCUSDT              5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT      5m,15m,1h,2h,4h,8h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT                    5m,1h,2h,4h,1d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h                 PAXGUSDT     5m,15m,30m,1h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT            5m,1h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT             5m,1h,2h,4h,12h,1d,3d
#                                  CAKEUSDT             5m,1h,2h,4h,8h,12h,1d
#                                  KSMUSDT              5m,15m,1h,2h,4h,1d,3d
#                                  LINAUSDT                    5m,1h,2h,4h,1d
#                                  ONTUSDT             5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                    5m,1h,2h,4h,3d
#                                  SRMUSDT           5m,15m,1h,2h,4h,8h,1d,3d
#                                  SUSHIUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT             5m,15m,1h,2h,4h,8h,1d
#                                  RAYUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT    5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT       5m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           5m,15m,1h,2h,4h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT      5m,15m,30m,1h,2h,4h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT                5m,30m,1h,2h,12h,1d
# 4h,12h,1d,3d                     SCUSDT           5m,30m,1h,2h,4h,8h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT           5m,1h,2h,4h,8h,12h,1d,3d
# 1h,2h,4h,8h,1d                   1INCHUSDT               5m,30m,1h,2h,4h,1d
#
#                                                       stkdown  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT       15m,8h,12h,3d
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT      15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           15m,30m,8h
# 5m,15m,4h,8h,12h,1d              DOTUSDT    15m,30m,8h,12h,3d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT    15m,30m,8h,1d,3d
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT      15m,30m,2h,8h,3d
#                                  FLUXUSDT             15m,30m
#                                  LRCUSDT           15m,30m,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT            30m,12h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT   15m,30m,8h,12h,3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT         15m,30m,3d
# 5m,15m,30m,1h,2h                 PAXGUSDT               2h,4h
# 5m,15m,30m,1d,3d,1w              STORJUSDT      15m,30m,2h,4h
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT          15m,30m,8h
#                                  CAKEUSDT       15m,30m,3d,1w
#                                  KSMUSDT           30m,8h,12h
#                                  LINAUSDT    15m,8h,12h,3d,1w
#                                  ONTUSDT            15m,8h,3d
#                                  RUNEUSDT       15m,8h,12h,1d
#                                  SRMUSDT              30m,12h
#                                  SUSHIUSDT   15m,30m,8h,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT              12h,3d
#                                  RAYUSDT        15m,30m,8h,3d
# 5m,15m,2h,4h,1d                  FTMUSDT                  NaN
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT             15m,30m
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT               8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT              8h,12h
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT      15m,4h,8h,3d,1w
# 4h,12h,1d,3d                     SCUSDT                15m,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT           15m,30m,1w
# 1h,2h,4h,8h,1d                   1INCHUSDT      15m,8h,12h,3d
#
#                                                              uptrend  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT             5m,1h,4h,1d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT              5m,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT                5m,4h,12h,1d
# 5m,15m,4h,8h,12h,1d              DOTUSDT                       5m,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT                  5m,12h,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT                 5m,4h,12h,1d
#                                  FLUXUSDT            5m,4h,12h,1d,3d
#                                  LRCUSDT                5m,4h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT      5m,1h,2h,4h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT                   5m,2h,1d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT     5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h                 PAXGUSDT                      5m,1h
# 5m,15m,30m,1d,3d,1w              STORJUSDT           5m,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT         5m,1h,2h,4h,12h,1d
#                                  CAKEUSDT         5m,1h,2h,4h,12h,1d
#                                  KSMUSDT              5m,1h,2h,1d,3d
#                                  LINAUSDT             5m,1h,2h,4h,1d
#                                  ONTUSDT      5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                   5m,1h,2h
#                                  SRMUSDT           5m,1h,2h,4h,1d,3d
#                                  SUSHIUSDT        5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT             5m,1h,2h,4h,1d
#                                  RAYUSDT          5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT          5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           5m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT        5m,15m,30m,1h,2h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT         5m,30m,1h,2h,12h,1d
# 4h,12h,1d,3d                     SCUSDT                30m,4h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT             1h,2h,4h,12h,1d
# 1h,2h,4h,8h,1d                   1INCHUSDT              30m,1h,2h,1d
#
#                                                   dshift downtrend  \
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT             2h       NaN
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         1h,2h       NaN
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           1h,1w       NaN
# 5m,15m,4h,8h,12h,1d              DOTUSDT          30m,1h        3d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT       1h,2h,1d       NaN
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT            1h,2h       NaN
#                                  FLUXUSDT          1h,2h       NaN
#                                  LRCUSDT           1h,2h       NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT           12h       NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT             1w       NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT           NaN        3d
# 5m,15m,30m,1h,2h                 PAXGUSDT   8h,12h,1d,1w       NaN
# 5m,15m,30m,1d,3d,1w              STORJUSDT            1h        2h
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT            30m       NaN
#                                  CAKEUSDT            NaN        1w
#                                  KSMUSDT             NaN       NaN
#                                  LINAUSDT            NaN        1w
#                                  ONTUSDT             NaN       NaN
#                                  RUNEUSDT         12h,1d       NaN
#                                  SRMUSDT              1w       NaN
#                                  SUSHIUSDT           NaN        1w
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT         12h,1w        3d
#                                  RAYUSDT             NaN        3d
# 5m,15m,2h,4h,1d                  FTMUSDT              3d       NaN
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT            30m       NaN
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT             NaN       NaN
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT          3d,1w       NaN
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT             NaN        1w
# 4h,12h,1d,3d                     SCUSDT               1w       NaN
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT       5m,30m,3d        1w
# 1h,2h,4h,8h,1d                   1INCHUSDT           12h        3d
#
#                                                            shift
# buyzones                         Indicator
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          15m,8h,12h,3d
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d              DOTUSDT           15m,4h,8h,12h
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT       15m,30m,4h,8h,3d
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT            15m,30m,8h,3d
#                                  FLUXUSDT             15m,30m,8h
#                                  LRCUSDT           15m,30m,8h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT            15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT   15m,30m,4h,8h,12h,3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT               15m,30m
# 5m,15m,30m,1h,2h                 PAXGUSDT       15m,30m,2h,4h,3d
# 5m,15m,30m,1d,3d,1w              STORJUSDT         15m,30m,4h,8h
# 5m,15m,2h,4h,8h,12h,1d,3d        AVAXUSDT              15m,8h,3d
#                                  CAKEUSDT          15m,30m,8h,3d
#                                  KSMUSDT       15m,30m,4h,8h,12h
#                                  LINAUSDT      15m,30m,8h,12h,3d
#                                  ONTUSDT               15m,8h,3d
#                                  RUNEUSDT       15m,30m,4h,8h,3d
#                                  SRMUSDT          15m,30m,8h,12h
#                                  SUSHIUSDT         15m,30m,8h,3d
# 5m,15m,2h,4h,8h,12h,1d           NEARUSDT             15m,30m,8h
#                                  RAYUSDT              15m,30m,8h
# 5m,15m,2h,4h,1d                  FTMUSDT               15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                 15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT              4h,8h,12h
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT            15m,4h,8h,3d
# 4h,12h,1d,3d                     SCUSDT                    8h,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT                  15m,8h
# 1h,2h,4h,8h,1d                   1INCHUSDT                 4h,8h

# %%
## MACD gap 1 Week and rsi up
newframe=callfun(macd1wd,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]


test=buyzonesa(test)
#test=test.loc[test['buyzones']>='1h']
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                                                    stkcross  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT                4h
# 5m,2h,4h,8h,12h,1d               PERPUSDT            15m,4h
# 5m,2h,4h,12h,1d                  ANKRUSDT             5m,4h
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT             4h,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT               4h
# 5m,15m,8h,12h,1d,1w              REEFUSDT             5m,4h
# 5m,15m,8h,12h,1d                 OMGUSDT                 4h
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT                 4h
# 5m,15m,4h,8h,12h,1d              CELRUSDT                8h
#                                  COTIUSDT                4h
#                                  DOTUSDT                 5m
#                                  ROSEUSDT                4h
#                                  ZILUSDT                 4h
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT                1h
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT               1h,4h
#                                  FLUXUSDT          5m,4h,3d
#                                  LRCUSDT                 4h
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT                 4h
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT             1h,4h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT              NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT               NaN
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT                 4h
#                                  GRTUSDT                 4h
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT                NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            4h,8h
# 5m,15m,30m,1d,3d,1w              STORJUSDT               3d
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT         15m,4h,1w
#                                  AVAXUSDT                4h
#                                  KSMUSDT                 3d
#                                  LINAUSDT                4h
#                                  ONTUSDT                 4h
#                                  RUNEUSDT               NaN
#                                  SRMUSDT           1h,3d,1w
#                                  SUSHIUSDT               4h
#                                  XLMUSDT                NaN
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT             15m,4h
#                                  BANDUSDT                4h
#                                  GALAUSDT                4h
#                                  IOTXUSDT                4h
#                                  MATICUSDT               4h
#                                  MINAUSDT               NaN
#                                  NEARUSDT                4h
#                                  ONEUSDT              1h,4h
#                                  RAYUSDT                 4h
#                                  VETUSDT                 4h
# 5m,15m,2h,4h,1d                  FTMUSDT              1h,3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                4h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT                 1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT   15m,1h,1d,3d,1w
#                                  WAXPUSDT                5m
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT                 1h
# 4h,12h,1d,3d                     SCUSDT               5m,4h
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT           1h,4h,3d
#
#                                                                           rsiup  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT                          4h,8h,12h,1d
# 5m,2h,4h,8h,12h,1d               PERPUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,12h,1d                  ANKRUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT      5m,15m,30m,1h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT           5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,8h,12h,1d,1w              REEFUSDT            5m,15m,30m,4h,8h,12h,1d,1w
# 5m,15m,8h,12h,1d                 OMGUSDT                5m,15m,30m,4h,8h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT             5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,4h,8h,12h,1d              CELRUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  COTIUSDT               5m,15m,30m,4h,8h,12h,1d
#                                  DOTUSDT                5m,15m,30m,4h,8h,12h,1d
#                                  ROSEUSDT            5m,15m,30m,2h,4h,8h,12h,1d
#                                  ZILUSDT             5m,15m,30m,2h,4h,8h,12h,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT         5m,15m,30m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT              5m,15m,30m,4h,8h,12h,1d,3d
#                                  FLUXUSDT            5m,15m,30m,4h,8h,12h,1d,3d
#                                  LRCUSDT             5m,15m,30m,4h,8h,12h,1d,3d
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT             5m,15m,30m,4h,8h,12h,1d,1w
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT            5m,15m,30m,2h,4h,8h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT         5m,15m,30m,2h,4h,8h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  GRTUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1d,3d,1w              STORJUSDT        5m,15m,30m,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  AVAXUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  KSMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  LINAUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  ONTUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  RUNEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  SRMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  SUSHIUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  XLMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
#                                  BANDUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
#                                  GALAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  IOTXUSDT            5m,15m,30m,2h,4h,8h,12h,1d
#                                  MATICUSDT           5m,15m,30m,2h,4h,8h,12h,1d
#                                  MINAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  NEARUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  ONEUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  RAYUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  VETUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  WAXPUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 4h,12h,1d,3d                     SCUSDT                     30m,4h,8h,12h,1d,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT             15m,30m,1h,2h,4h,8h,12h,1d
#
#                                                            rsidown  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT   5m,15m,30m,1h,2h,3d,1w
# 5m,2h,4h,8h,12h,1d               PERPUSDT                    3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT                    3d,1w
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT                       2h
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT                1h,2h,1w
# 5m,15m,8h,12h,1d,1w              REEFUSDT                    2h,3d
# 5m,15m,8h,12h,1d                 OMGUSDT               1h,2h,3d,1w
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT                     1h,1w
# 5m,15m,4h,8h,12h,1d              CELRUSDT                    3d,1w
#                                  COTIUSDT                    3d,1w
#                                  DOTUSDT                  1h,3d,1w
#                                  ROSEUSDT                 1h,3d,1w
#                                  ZILUSDT                  1h,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT                    1h,2h
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT                   1h,2h,1w
#                                  FLUXUSDT                 1h,2h,1w
#                                  LRCUSDT                  1h,2h,1w
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT                  1h,2h,3d
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT                 1h,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT                     NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT                       1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT                     3d,1w
#                                  GRTUSDT                     3d,1w
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT                        3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT                   3d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT                   1h,2h
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT                       1w
#                                  AVAXUSDT                       1w
#                                  KSMUSDT                        1w
#                                  LINAUSDT                       1w
#                                  ONTUSDT                        1w
#                                  RUNEUSDT                       1w
#                                  SRMUSDT                        1w
#                                  SUSHIUSDT                      1w
#                                  XLMUSDT                        1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT                        3d
#                                  BANDUSDT                       3d
#                                  GALAUSDT                    3d,1w
#                                  IOTXUSDT                    3d,1w
#                                  MATICUSDT                   3d,1w
#                                  MINAUSDT                    3d,1w
#                                  NEARUSDT                    3d,1w
#                                  ONEUSDT                     3d,1w
#                                  RAYUSDT                     3d,1w
#                                  VETUSDT                     3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT                        3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                      NaN
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT                       NaN
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT                    3d,1w
#                                  WAXPUSDT                    3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT                        1w
# 4h,12h,1d,3d                     SCUSDT                         1w
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT                  5m,3d,1w
#
#                                                      tops        bottoms topr  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT          30m,1h       5m,1d,1w  NaN
# 5m,2h,4h,8h,12h,1d               PERPUSDT      15m,30m,1h          1d,1w  NaN
# 5m,2h,4h,12h,1d                  ANKRUSDT   15m,30m,1h,8h          3d,1w  NaN
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          30m,1h             1w  NaN
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         30m,1h             1w  NaN
# 5m,15m,8h,12h,1d,1w              REEFUSDT          30m,1h          5m,1w  NaN
# 5m,15m,8h,12h,1d                 OMGUSDT           30m,1h          1d,1w  NaN
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           30m,1h          3d,1w  NaN
# 5m,15m,4h,8h,12h,1d              CELRUSDT       30m,1h,2h             1w  NaN
#                                  COTIUSDT          30m,1h          1d,1w  NaN
#                                  DOTUSDT           30m,1h    5m,2h,4h,1w  NaN
#                                  ROSEUSDT          30m,1h          5m,1w  NaN
#                                  ZILUSDT           30m,1h       5m,3d,1w  NaN
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT             NaN         15m,1w  NaN
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT               NaN  15m,30m,3d,1w  NaN
#                                  FLUXUSDT              1h      5m,15m,3d  NaN
#                                  LRCUSDT               1h             1w  NaN
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT            1h,3d         5m,15m  NaN
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT             NaN          1d,1w  NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT             1h             1w  NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT              1h          2h,1w  NaN
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT               1h          3d,1w  NaN
#                                  GRTUSDT               1h          1d,1w  NaN
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT              NaN          2h,1w  NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT             8h          3d,1w  NaN
# 5m,15m,30m,1d,3d,1w              STORJUSDT         8h,12h    5m,1h,2h,1w  NaN
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT          30m,1h          3d,1w  NaN
#                                  AVAXUSDT          30m,1h          3d,1w  NaN
#                                  KSMUSDT           30m,1h    2h,4h,3d,1w  NaN
#                                  LINAUSDT          30m,1h             1w  NaN
#                                  ONTUSDT           30m,1h          1d,1w  NaN
#                                  RUNEUSDT          30m,1h       1d,3d,1w  NaN
#                                  SRMUSDT           30m,1h       5m,3d,1w  NaN
#                                  SUSHIUSDT         30m,1h          3d,1w  NaN
#                                  XLMUSDT           30m,1h             1w  NaN
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT           30m,1h             1w  NaN
#                                  BANDUSDT          30m,1h             1w  NaN
#                                  GALAUSDT          30m,1h             1w  NaN
#                                  IOTXUSDT          30m,1h             1w  NaN
#                                  MATICUSDT         30m,1h          1d,1w  NaN
#                                  MINAUSDT          30m,1h          3d,1w  NaN
#                                  NEARUSDT          30m,1h          3d,1w  NaN
#                                  ONEUSDT           30m,1h             1w  NaN
#                                  RAYUSDT           30m,1h          3d,1w  NaN
#                                  VETUSDT           30m,1h          3d,1w  NaN
# 5m,15m,2h,4h,1d                  FTMUSDT    30m,1h,8h,12h             1w  NaN
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT       30m,1h,8h       5m,3d,1w  NaN
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT              30m       2h,3d,1w  NaN
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT             30m          3d,1w  NaN
#                                  WAXPUSDT             30m       5m,1d,1w  NaN
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT           30m,8h       2h,3d,1w  NaN
# 4h,12h,1d,3d                     SCUSDT         30m,1h,8h    5m,1d,3d,1w  NaN
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT              NaN          1d,1w  NaN
#
#                                                  bottomr  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT            NaN
# 5m,2h,4h,8h,12h,1d               PERPUSDT   12h,1d,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT             3d
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT            NaN
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT           NaN
# 5m,15m,8h,12h,1d,1w              REEFUSDT             3d
# 5m,15m,8h,12h,1d                 OMGUSDT             NaN
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT              3d
# 5m,15m,4h,8h,12h,1d              CELRUSDT            NaN
#                                  COTIUSDT            NaN
#                                  DOTUSDT             NaN
#                                  ROSEUSDT             3d
#                                  ZILUSDT             NaN
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT            NaN
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT               3d
#                                  FLUXUSDT             3d
#                                  LRCUSDT             NaN
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT             NaN
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT            NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT           NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT          3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT        1d,3d,1w
#                                  GRTUSDT              3d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT             NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            3d
# 5m,15m,30m,1d,3d,1w              STORJUSDT           NaN
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT            NaN
#                                  AVAXUSDT          3d,1w
#                                  KSMUSDT              3d
#                                  LINAUSDT            NaN
#                                  ONTUSDT              3d
#                                  RUNEUSDT            NaN
#                                  SRMUSDT              3d
#                                  SUSHIUSDT            3d
#                                  XLMUSDT             NaN
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT             NaN
#                                  BANDUSDT            NaN
#                                  GALAUSDT            NaN
#                                  IOTXUSDT            NaN
#                                  MATICUSDT      1d,3d,1w
#                                  MINAUSDT             3d
#                                  NEARUSDT            NaN
#                                  ONEUSDT           1d,3d
#                                  RAYUSDT           1d,3d
#                                  VETUSDT              3d
# 5m,15m,2h,4h,1d                  FTMUSDT              3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT              3d
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT   8h,12h,1d,3d
#                                  WAXPUSDT             3d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT             NaN
# 4h,12h,1d,3d                     SCUSDT              NaN
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT           3d,1w
#
#                                                                    stover  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT              5m,1h,2h,4h,12h,1d
# 5m,2h,4h,8h,12h,1d               PERPUSDT      5m,15m,30m,1h,2h,4h,12h,1d
# 5m,2h,4h,12h,1d                  ANKRUSDT          5m,30m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT           5m,30m,1h,2h,4h,1d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT             5m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,1w              REEFUSDT            5m,1h,2h,4h,1d,3d,1w
# 5m,15m,8h,12h,1d                 OMGUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT            5m,1h,2h,4h,12h,1d,1w
# 5m,15m,4h,8h,12h,1d              CELRUSDT           5m,1h,2h,4h,8h,12h,1d
#                                  COTIUSDT           5m,1h,2h,4h,12h,1d,1w
#                                  DOTUSDT                  5m,30m,1h,2h,1d
#                                  ROSEUSDT              5m,1h,2h,4h,12h,1d
#                                  ZILUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT              5m,1h,2h,12h,1d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT                5m,1h,2h,4h,12h,1d
#                                  FLUXUSDT           5m,1h,2h,4h,12h,1d,3d
#                                  LRCUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT            5m,1h,2h,4h,12h,1d,1w
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT                     5m,1h,2h,4h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT       5m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT                  5m,1h,2h,1d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT               5m,1h,2h,4h,12h,1d
#                                  GRTUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT                   5m,1h,2h,1d,3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT          5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1d,3d,1w              STORJUSDT             5m,1h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT   5m,15m,30m,1h,2h,4h,12h,1d,1w
#                                  AVAXUSDT          5m,30m,1h,2h,4h,12h,1d
#                                  KSMUSDT                   5m,1h,2h,1d,3d
#                                  LINAUSDT                  5m,1h,2h,4h,1d
#                                  ONTUSDT           5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                 5m,1h,2h,12h,1d
#                                  SRMUSDT             5m,1h,2h,4h,1d,3d,1w
#                                  SUSHIUSDT             5m,1h,2h,4h,12h,1d
#                                  XLMUSDT            5m,1h,2h,4h,12h,1d,1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT        5m,15m,1h,2h,4h,12h,1d,1w
#                                  BANDUSDT                  5m,1h,2h,4h,1d
#                                  GALAUSDT                  5m,1h,2h,4h,3d
#                                  IOTXUSDT                  5m,1h,2h,4h,1d
#                                  MATICUSDT         5m,30m,1h,2h,4h,12h,1d
#                                  MINAUSDT                  5m,1h,2h,4h,1d
#                                  NEARUSDT           5m,1h,2h,4h,12h,1d,1w
#                                  ONEUSDT           5m,30m,1h,2h,4h,12h,1d
#                                  RAYUSDT               5m,1h,2h,4h,12h,1d
#                                  VETUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT        5m,30m,1h,2h,4h,12h,1d,3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT    5m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT            5m,30m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT       5m,15m,30m,1h,2h,1d,3d,1w
#                                  WAXPUSDT                 5m,1h,2h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT              5m,30m,1h,2h,12h,1d
# 4h,12h,1d,3d                     SCUSDT         5m,30m,1h,2h,4h,12h,1d,1w
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT        5m,30m,1h,2h,4h,12h,1d,3d
#
#                                                                            room  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,8h,12h,1d               PERPUSDT              5m,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT                 5m,2h,4h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,1w              REEFUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d                 OMGUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d              CELRUSDT             5m,15m,4h,8h,12h,1d,3d,1w
#                                  COTIUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  DOTUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  ROSEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  ZILUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  FLUXUSDT         5m,15m,30m,2h,4h,8h,12h,1d,3d
#                                  LRCUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT          5m,15m,30m,2h,4h,8h,12h,1d,1w
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT      5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
#                                  GRTUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT         5m,15m,30m,1h,2h,4h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  AVAXUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  KSMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  LINAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  ONTUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  RUNEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  SRMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  SUSHIUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  XLMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  BANDUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  GALAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  IOTXUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  MATICUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  MINAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  NEARUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  ONEUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  RAYUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  VETUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT                  5m,15m,2h,4h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT             5m,15m,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT        5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  WAXPUSDT       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT           5m,15m,1h,2h,4h,12h,1d,3d,1w
# 4h,12h,1d,3d                     SCUSDT               5m,15m,2h,4h,12h,1d,3d,1w
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                                           roomr  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,8h,12h,1d               PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d,1w              REEFUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,8h,12h,1d                 OMGUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d              CELRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  COTIUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  DOTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  ROSEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  ZILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  FLUXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  LRCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  GRTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  AVAXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  KSMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  LINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  ONTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  RUNEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  SRMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  SUSHIUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  XLMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  BANDUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  GALAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  IOTXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  MATICUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  MINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  NEARUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  ONEUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  VETUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  WAXPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 4h,12h,1d,3d                     SCUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                             stunder  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT          15m,30m,8h,3d,1w
# 5m,2h,4h,8h,12h,1d               PERPUSDT                  8h,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT              15m,8h,3d,1w
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT             15m,8h,12h,3d
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         15m,30m,8h,3d,1w
# 5m,15m,8h,12h,1d,1w              REEFUSDT            15m,30m,8h,12h
# 5m,15m,8h,12h,1d                 OMGUSDT           15m,30m,8h,3d,1w
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT              15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d              CELRUSDT             15m,30m,3d,1w
#                                  COTIUSDT             15m,30m,8h,3d
#                                  DOTUSDT        15m,4h,8h,12h,3d,1w
#                                  ROSEUSDT          15m,30m,8h,3d,1w
#                                  ZILUSDT           15m,30m,8h,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT          15m,30m,4h,8h,3d
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT            15m,30m,8h,3d,1w
#                                  FLUXUSDT                15m,30m,8h
#                                  LRCUSDT           15m,30m,8h,3d,1w
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT              15m,30m,8h,3d
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT   15m,30m,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT               15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT      15m,30m,4h,8h,12h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT           15m,30m,8h,3d,1w
#                                  GRTUSDT           15m,30m,8h,3d,1w
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT       15m,30m,4h,8h,12h,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            15m,30m,3d,1w
# 5m,15m,30m,1d,3d,1w              STORJUSDT         15m,30m,2h,4h,8h
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT                     8h,3d
#                                  AVAXUSDT              15m,8h,3d,1w
#                                  KSMUSDT          15m,30m,4h,8h,12h
#                                  LINAUSDT      15m,30m,8h,12h,3d,1w
#                                  ONTUSDT               15m,8h,3d,1w
#                                  RUNEUSDT       15m,30m,4h,8h,3d,1w
#                                  SRMUSDT             15m,30m,8h,12h
#                                  SUSHIUSDT         15m,30m,8h,3d,1w
#                                  XLMUSDT              15m,30m,8h,3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT                  30m,8h,3d
#                                  BANDUSDT      15m,30m,8h,12h,3d,1w
#                                  GALAUSDT      15m,30m,8h,12h,1d,1w
#                                  IOTXUSDT      15m,30m,8h,12h,3d,1w
#                                  MATICUSDT             15m,8h,3d,1w
#                                  MINAUSDT      15m,30m,8h,12h,3d,1w
#                                  NEARUSDT             15m,30m,8h,3d
#                                  ONEUSDT                  15m,8h,3d
#                                  RAYUSDT           15m,30m,8h,3d,1w
#                                  VETUSDT           15m,30m,8h,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT                  15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                    15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT              15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT                 4h,8h,12h
#                                  WAXPUSDT       15m,30m,4h,8h,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT            15m,4h,8h,3d,1w
# 4h,12h,1d,3d                     SCUSDT                   15m,8h,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT                  15m,8h,1w
#
#                                                                       stkup  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT                   1h,2h,4h,12h,1d
# 5m,2h,4h,8h,12h,1d               PERPUSDT         5m,15m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,12h,1d                  ANKRUSDT             5m,1h,2h,4h,8h,12h,1d
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT                 5m,1h,2h,4h,1d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,1w              REEFUSDT              5m,1h,2h,4h,1d,3d,1w
# 5m,15m,8h,12h,1d                 OMGUSDT              5m,1h,2h,4h,8h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT              5m,1h,2h,4h,12h,1d,3d
# 5m,15m,4h,8h,12h,1d              CELRUSDT             5m,1h,2h,4h,8h,12h,1d
#                                  COTIUSDT             5m,1h,2h,4h,8h,12h,1d
#                                  DOTUSDT                     5m,1h,2h,4h,1d
#                                  ROSEUSDT                    5m,1h,2h,4h,1d
#                                  ZILUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT                5m,1h,2h,4h,12h,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT                     5m,1h,4h,12h,1d
#                                  FLUXUSDT          5m,1h,2h,4h,8h,12h,1d,3d
#                                  LRCUSDT              5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT              5m,1h,2h,4h,12h,1d,1w
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT                       5m,1h,2h,4h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT      5m,15m,1h,2h,4h,8h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT                    5m,1h,2h,4h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT                 5m,15m,1h,2h,4h,1d
#                                  GRTUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT              5m,15m,1h,4h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1d,3d,1w              STORJUSDT            5m,1h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT                5m,15m,1h,2h,4h,1d
#                                  AVAXUSDT             5m,1h,2h,4h,12h,1d,3d
#                                  KSMUSDT              5m,15m,1h,2h,4h,1d,3d
#                                  LINAUSDT                    5m,1h,2h,4h,1d
#                                  ONTUSDT             5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                    5m,1h,2h,4h,3d
#                                  SRMUSDT           5m,15m,1h,2h,4h,8h,1d,3d
#                                  SUSHIUSDT               5m,1h,2h,4h,12h,1d
#                                  XLMUSDT          5m,15m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT          5m,15m,1h,2h,4h,12h,1d,1w
#                                  BANDUSDT              5m,1h,2h,4h,8h,1d,1w
#                                  GALAUSDT                 5m,1h,2h,4h,1d,3d
#                                  IOTXUSDT                    5m,1h,2h,4h,1d
#                                  MATICUSDT            5m,1h,2h,4h,8h,12h,1d
#                                  MINAUSDT                5m,30m,2h,4h,8h,1d
#                                  NEARUSDT             5m,15m,1h,2h,4h,8h,1d
#                                  ONEUSDT         5m,15m,30m,1h,2h,4h,12h,1d
#                                  RAYUSDT                 5m,1h,2h,4h,12h,1d
#                                  VETUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT    5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT       5m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           5m,15m,1h,2h,4h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT      5m,15m,30m,1h,2h,4h,1d,3d,1w
#                                  WAXPUSDT             5m,1h,2h,4h,8h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT                5m,30m,1h,2h,12h,1d
# 4h,12h,1d,3d                     SCUSDT           5m,30m,1h,2h,4h,8h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT           5m,1h,2h,4h,8h,12h,1d,3d
#
#                                                          stkdown  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT       15m,30m,8h,3d,1w
# 5m,2h,4h,8h,12h,1d               PERPUSDT                  3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT             15m,30m,3d
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          15m,8h,12h,3d
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         15m,30m,8h,3d
# 5m,15m,8h,12h,1d,1w              REEFUSDT         15m,30m,8h,12h
# 5m,15m,8h,12h,1d                 OMGUSDT              15m,30m,3d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT              15m,30m,8h
# 5m,15m,4h,8h,12h,1d              CELRUSDT             15m,30m,3d
#                                  COTIUSDT             15m,30m,3d
#                                  DOTUSDT       15m,30m,8h,12h,3d
#                                  ROSEUSDT      15m,30m,8h,12h,3d
#                                  ZILUSDT        15m,30m,8h,3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT       15m,30m,8h,1d,3d
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT         15m,30m,2h,8h,3d
#                                  FLUXUSDT                15m,30m
#                                  LRCUSDT              15m,30m,3d
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT           15m,30m,8h,3d
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT   15m,30m,8h,12h,1d,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT               30m,12h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT      15m,30m,8h,12h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT           30m,8h,12h,3d
#                                  GRTUSDT           15m,30m,8h,3d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT           30m,2h,8h,12h
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            15m,30m,3d
# 5m,15m,30m,1d,3d,1w              STORJUSDT         15m,30m,2h,4h
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT              8h,12h,3d
#                                  AVAXUSDT             15m,30m,8h
#                                  KSMUSDT              30m,8h,12h
#                                  LINAUSDT       15m,8h,12h,3d,1w
#                                  ONTUSDT               15m,8h,3d
#                                  RUNEUSDT          15m,8h,12h,1d
#                                  SRMUSDT                 30m,12h
#                                  SUSHIUSDT      15m,30m,8h,3d,1w
#                                  XLMUSDT                      3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT                   8h,3d
#                                  BANDUSDT             15m,12h,3d
#                                  GALAUSDT         15m,30m,8h,12h
#                                  IOTXUSDT   15m,30m,8h,12h,3d,1w
#                                  MATICUSDT            15m,30m,3d
#                                  MINAUSDT             15m,12h,3d
#                                  NEARUSDT                 12h,3d
#                                  ONEUSDT                   8h,3d
#                                  RAYUSDT           15m,30m,8h,3d
#                                  VETUSDT           15m,30m,8h,3d
# 5m,15m,2h,4h,1d                  FTMUSDT                     NaN
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                15m,30m
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT                  8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT                 8h,12h
#                                  WAXPUSDT             15m,30m,3d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT         15m,4h,8h,3d,1w
# 4h,12h,1d,3d                     SCUSDT                   15m,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT              15m,30m,1w
#
#                                                               uptrend  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT                   4h,12h,1d
# 5m,2h,4h,8h,12h,1d               PERPUSDT      5m,15m,1h,2h,4h,12h,1d
# 5m,2h,4h,12h,1d                  ANKRUSDT          5m,1h,2h,4h,12h,1d
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT              5m,1h,4h,1d,1w
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT               5m,4h,12h,1d
# 5m,15m,8h,12h,1d,1w              REEFUSDT                 5m,4h,1d,1w
# 5m,15m,8h,12h,1d                 OMGUSDT                 5m,4h,12h,1d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT                 5m,4h,12h,1d
# 5m,15m,4h,8h,12h,1d              CELRUSDT       5m,1h,2h,4h,8h,12h,1d
#                                  COTIUSDT                5m,4h,12h,1d
#                                  DOTUSDT                        5m,1d
#                                  ROSEUSDT                 5m,2h,4h,1d
#                                  ZILUSDT              5m,2h,4h,12h,1d
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT                   5m,12h,1w
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT                  5m,4h,12h,1d
#                                  FLUXUSDT             5m,4h,12h,1d,3d
#                                  LRCUSDT                 5m,4h,12h,1d
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT              5m,4h,12h,1d,1w
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT                    5m,2h,4h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT       5m,1h,2h,4h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT                    5m,2h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT               5m,1h,2h,4h,1d
#                                  GRTUSDT           5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT                     5m,1h,1d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT      5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1d,3d,1w              STORJUSDT            5m,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT          5m,15m,1h,2h,4h,1d
#                                  AVAXUSDT          5m,1h,2h,4h,12h,1d
#                                  KSMUSDT               5m,1h,2h,1d,3d
#                                  LINAUSDT              5m,1h,2h,4h,1d
#                                  ONTUSDT       5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                    5m,1h,2h
#                                  SRMUSDT            5m,1h,2h,4h,1d,3d
#                                  SUSHIUSDT         5m,1h,2h,4h,12h,1d
#                                  XLMUSDT           5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT    5m,15m,1h,2h,4h,12h,1d,1w
#                                  BANDUSDT              5m,1h,2h,4h,1d
#                                  GALAUSDT                 5m,1h,2h,4h
#                                  IOTXUSDT                 5m,2h,4h,1d
#                                  MATICUSDT            5m,2h,4h,12h,1d
#                                  MINAUSDT                 5m,2h,4h,1d
#                                  NEARUSDT              5m,1h,2h,4h,1d
#                                  ONEUSDT       5m,30m,1h,2h,4h,12h,1d
#                                  RAYUSDT           5m,1h,2h,4h,12h,1d
#                                  VETUSDT           5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT           5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT    5m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT            5m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT         5m,15m,30m,1h,2h,1d
#                                  WAXPUSDT             5m,1h,2h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT          5m,30m,1h,2h,12h,1d
# 4h,12h,1d,3d                     SCUSDT                 30m,4h,12h,1d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT              1h,2h,4h,12h,1d
#
#                                                dshift      downtrend  \
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT    5m,1h,2h  15m,30m,3d,1w
# 5m,2h,4h,8h,12h,1d               PERPUSDT         NaN          3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT         30m             3d
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          2h            NaN
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT      1h,2h            NaN
# 5m,15m,8h,12h,1d,1w              REEFUSDT       2h,3d            NaN
# 5m,15m,8h,12h,1d                 OMGUSDT        1h,2h             3d
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT        1h,1w            NaN
# 5m,15m,4h,8h,12h,1d              CELRUSDT         NaN             3d
#                                  COTIUSDT          1w             3d
#                                  DOTUSDT       30m,1h             3d
#                                  ROSEUSDT      1h,12h             3d
#                                  ZILUSDT           1h          3d,1w
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT    1h,2h,1d            NaN
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT         1h,2h            NaN
#                                  FLUXUSDT       1h,2h            NaN
#                                  LRCUSDT        1h,2h            NaN
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT        1h,2h             3d
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT          1h             3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT        12h            NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT          1w            NaN
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT          12h             3d
#                                  GRTUSDT          NaN             3d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT        2h,3d            NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT        NaN             3d
# 5m,15m,30m,1d,3d,1w              STORJUSDT         1h             2h
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT      12h,1w            NaN
#                                  AVAXUSDT         30m            NaN
#                                  KSMUSDT          NaN            NaN
#                                  LINAUSDT         NaN             1w
#                                  ONTUSDT          NaN            NaN
#                                  RUNEUSDT      12h,1d            NaN
#                                  SRMUSDT           1w            NaN
#                                  SUSHIUSDT        NaN             1w
#                                  XLMUSDT           1w            NaN
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT          NaN             3d
#                                  BANDUSDT         NaN             3d
#                                  GALAUSDT          3d            NaN
#                                  IOTXUSDT         NaN          3d,1w
#                                  MATICUSDT        30m             3d
#                                  MINAUSDT         NaN             3d
#                                  NEARUSDT      12h,1w             3d
#                                  ONEUSDT          NaN             3d
#                                  RAYUSDT          NaN             3d
#                                  VETUSDT          NaN             3d
# 5m,15m,2h,4h,1d                  FTMUSDT           3d            NaN
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT         30m            NaN
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT          NaN            NaN
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT       3d,1w            NaN
#                                  WAXPUSDT         NaN             3d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT          NaN             1w
# 4h,12h,1d,3d                     SCUSDT            1w            NaN
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT    5m,30m,3d             1w
#
#                                                            shift
# buyzones                         Indicator
# 8h,12h,1d                        DENTUSDT                     8h
# 5m,2h,4h,8h,12h,1d               PERPUSDT                     8h
# 5m,2h,4h,12h,1d                  ANKRUSDT                 15m,8h
# 5m,15m,8h,12h,1d,3d,1w           MANAUSDT          15m,8h,12h,3d
# 5m,15m,8h,12h,1d,3d              AUDIOUSDT         15m,30m,8h,3d
# 5m,15m,8h,12h,1d,1w              REEFUSDT         15m,30m,8h,12h
# 5m,15m,8h,12h,1d                 OMGUSDT              15m,30m,8h
# 5m,15m,4h,8h,12h,1d,3d           RENUSDT           15m,30m,8h,3d
# 5m,15m,4h,8h,12h,1d              CELRUSDT                15m,30m
#                                  COTIUSDT             15m,30m,8h
#                                  DOTUSDT           15m,4h,8h,12h
#                                  ROSEUSDT             15m,30m,8h
#                                  ZILUSDT              15m,30m,8h
# 5m,15m,30m,8h,12h,1d,3d,1w       LINKUSDT       15m,30m,4h,8h,3d
# 5m,15m,30m,8h,12h,1d,3d          ARUSDT            15m,30m,8h,3d
#                                  FLUXUSDT             15m,30m,8h
#                                  LRCUSDT           15m,30m,8h,3d
# 5m,15m,30m,8h,12h,1d,1w          HNTUSDT              15m,30m,8h
# 5m,15m,30m,4h,8h,12h,1d          VTHOUSDT      15m,30m,8h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT            15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d    ATOMUSDT   15m,30m,4h,8h,12h,3d
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT              15m,30m,8h
#                                  GRTUSDT              15m,30m,8h
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT    15m,30m,4h,8h,12h,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT               15m,30m
# 5m,15m,30m,1d,3d,1w              STORJUSDT         15m,30m,4h,8h
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT                  8h,3d
#                                  AVAXUSDT              15m,8h,3d
#                                  KSMUSDT       15m,30m,4h,8h,12h
#                                  LINAUSDT      15m,30m,8h,12h,3d
#                                  ONTUSDT               15m,8h,3d
#                                  RUNEUSDT       15m,30m,4h,8h,3d
#                                  SRMUSDT          15m,30m,8h,12h
#                                  SUSHIUSDT         15m,30m,8h,3d
#                                  XLMUSDT           15m,30m,8h,3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT                  30m,8h
#                                  BANDUSDT      15m,30m,8h,12h,1w
#                                  GALAUSDT      15m,30m,8h,12h,1d
#                                  IOTXUSDT         15m,30m,8h,12h
#                                  MATICUSDT                15m,8h
#                                  MINAUSDT         15m,30m,8h,12h
#                                  NEARUSDT             15m,30m,8h
#                                  ONEUSDT                  15m,8h
#                                  RAYUSDT              15m,30m,8h
#                                  VETUSDT              15m,30m,8h
# 5m,15m,2h,4h,1d                  FTMUSDT               15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                 15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT              4h,8h,12h
#                                  WAXPUSDT          15m,30m,4h,8h
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT            15m,4h,8h,3d
# 4h,12h,1d,3d                     SCUSDT                    8h,3d
# 30m,1h,2h,4h,8h,12h,1d           MIRUSDT                  15m,8h

# %%
## MACD gap 1 Week stk cross
newframe=callfun(stk1w,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
#test = newframe.loc[(newframe['uptrend'] < '1d') &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]
test = newframe.loc[(newframe['downtrend'].isnull()) ]



test=buyzones(test)
#test=test.loc[test['buyzones']>='1h']
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                                                   stkcross  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT             4h,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT         15m,4h,1w
#                                 SRMUSDT           1h,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT                 1w
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT   15m,1h,1d,3d,1w
#
#                                                                          rsiup  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT      5m,15m,30m,1h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                 SRMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#
#                                           rsidown    tops   bottoms topr  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT       2h  30m,1h        1w  NaN
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT       1w  30m,1h     3d,1w  NaN
#                                 SRMUSDT        1w  30m,1h  5m,3d,1w  NaN
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT       NaN     30m  2h,3d,1w  NaN
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT    3d,1w     30m     3d,1w  NaN
#
#                                                 bottomr  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT            NaN
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT            NaN
#                                 SRMUSDT              3d
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT              3d
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT   8h,12h,1d,3d
#
#                                                                   stover  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT           5m,30m,1h,2h,4h,1d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT   5m,15m,30m,1h,2h,4h,12h,1d,1w
#                                 SRMUSDT             5m,1h,2h,4h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT            5m,30m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT       5m,15m,30m,1h,2h,1d,3d,1w
#
#                                                                       room  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT      5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT      5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                 SRMUSDT       5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT    5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT   5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                                          roomr  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                 SRMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                   stunder  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT    15m,8h,12h,3d
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT            8h,3d
#                                 SRMUSDT    15m,30m,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT     15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT        4h,8h,12h
#
#                                                                   stkup  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT              5m,1h,2h,4h,1d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT             5m,15m,1h,2h,4h,1d
#                                 SRMUSDT        5m,15m,1h,2h,4h,8h,1d,3d
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT        5m,15m,1h,2h,4h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT   5m,15m,30m,1h,2h,4h,1d,3d,1w
#
#                                                  stkdown              uptrend  \
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT   15m,8h,12h,3d       5m,1h,4h,1d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT       8h,12h,3d   5m,15m,1h,2h,4h,1d
#                                 SRMUSDT          30m,12h    5m,1h,2h,4h,1d,3d
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT           8h,12h    5m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT          8h,12h  5m,15m,30m,1h,2h,1d
#
#                                            dshift downtrend           shift
# buyzones                        Indicator
# 5m,15m,4h,8h,12h,1d,3d,1w       MANAUSDT       2h       NaN   15m,8h,12h,3d
# 5m,15m,2h,4h,8h,12h,1d,3d       ALGOUSDT   12h,1w       NaN           8h,3d
#                                 SRMUSDT        1w       NaN  15m,30m,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w SOLUSDT       NaN       NaN   15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d       LUNAUSDT    3d,1w       NaN       4h,8h,12h

# %%
#hihi5macd1w
## MACD gap 1 Week and rsiup 5 to 4h 
newframe=callfun(rsiup54h,'stkcross','rsiup','rsidown','tops','bottoms','topr','bottomr','stover','room','roomr','stunder','stkup','stkdown','uptrend','dshift','downtrend','shift')
newframe=newframe.sort_values(by=['bottomr','bottoms','rsidown'],ascending=[False,False,False])
test = newframe.loc[(newframe['shift'].notnull()) & (newframe['uptrend'].notnull()) &  (newframe['bottomr'].notnull()) ]
test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) & (newframe['tops'].isnull()) ]
#test = newframe.loc[ (newframe['stkup'].notnull()) & (newframe['bottomr'] >= '2h') & ((newframe['stover']>= '2h') | (newframe['stkcross']>='3d'))]
#test = newframe.loc[(newframe['uptrend'].notnull()) &  (newframe['rsidown'].isnull()) ]
#test = newframe.loc[(newframe['stkup'].notnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['dshift'].isnull()) &  (newframe['bottoms'].notnull()) ]
#test = newframe.loc[(newframe['downtrend'].isnull()) ]


test=buyzonesa(test)
#test=test.loc[test['buyzones']>='1h']
test
pivotf = test.pivot(index='buyzones',columns='Indicator')
pivotf = pivotf.sort_values(by='buyzones',ascending=False)

pivotf.stack()
# Out:
#                                                    stkcross  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT            15m,4h
# 5m,2h,4h,12h,1d                  ANKRUSDT             5m,4h
# 5m,15m,4h,8h,12h,1d              CELRUSDT                8h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT              NaN
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT                 4h
#                                  GRTUSDT                 4h
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT                NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            4h,8h
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT         15m,4h,1w
#                                  AVAXUSDT                4h
#                                  CAKEUSDT                4h
#                                  KSMUSDT                 3d
#                                  LINAUSDT                4h
#                                  ONTUSDT                 4h
#                                  RUNEUSDT               NaN
#                                  SRMUSDT           1h,3d,1w
#                                  SUSHIUSDT               4h
#                                  XLMUSDT                NaN
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT             15m,4h
#                                  BANDUSDT                4h
#                                  BTCUSDT              4h,8h
#                                  GALAUSDT                4h
#                                  MINAUSDT               NaN
#                                  NEARUSDT                4h
#                                  ONEUSDT              1h,4h
#                                  RAYUSDT                 4h
#                                  VETUSDT                 4h
# 5m,15m,2h,4h,1d                  FTMUSDT              1h,3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                4h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT                 1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT   15m,1h,1d,3d,1w
#                                  WAXPUSDT                5m
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT                 1h
#
#                                                                           rsiup  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,12h,1d                  ANKRUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,4h,8h,12h,1d              CELRUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  GRTUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT        5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  AVAXUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  CAKEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  KSMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  LINAUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  ONTUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  RUNEUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  SRMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  SUSHIUSDT     5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#                                  XLMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
#                                  BANDUSDT      5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
#                                  BTCUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  GALAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  MINAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  NEARUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  ONEUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  RAYUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  VETUSDT          5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
#                                  WAXPUSDT         5m,15m,30m,1h,2h,4h,8h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT       5m,15m,30m,1h,2h,4h,8h,12h,1d,3d
#
#                                            rsidown           tops  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT    3d,1w     15m,30m,1h
# 5m,2h,4h,12h,1d                  ANKRUSDT    3d,1w  15m,30m,1h,8h
# 5m,15m,4h,8h,12h,1d              CELRUSDT    3d,1w      30m,1h,2h
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT     NaN             1h
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT     3d,1w             1h
#                                  GRTUSDT     3d,1w             1h
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT        3d            NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT   3d,1w             8h
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT       1w         30m,1h
#                                  AVAXUSDT       1w         30m,1h
#                                  CAKEUSDT       1w         30m,1h
#                                  KSMUSDT        1w         30m,1h
#                                  LINAUSDT       1w         30m,1h
#                                  ONTUSDT        1w         30m,1h
#                                  RUNEUSDT       1w         30m,1h
#                                  SRMUSDT        1w         30m,1h
#                                  SUSHIUSDT      1w         30m,1h
#                                  XLMUSDT        1w         30m,1h
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT        3d         30m,1h
#                                  BANDUSDT       3d         30m,1h
#                                  BTCUSDT     3d,1w         30m,1h
#                                  GALAUSDT    3d,1w         30m,1h
#                                  MINAUSDT    3d,1w         30m,1h
#                                  NEARUSDT    3d,1w         30m,1h
#                                  ONEUSDT     3d,1w         30m,1h
#                                  RAYUSDT     3d,1w         30m,1h
#                                  VETUSDT     3d,1w         30m,1h
# 5m,15m,2h,4h,1d                  FTMUSDT        3d  30m,1h,8h,12h
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT      NaN      30m,1h,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT       NaN            30m
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT    3d,1w            30m
#                                  WAXPUSDT    3d,1w            30m
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT        1w         30m,8h
#
#                                                 bottoms topr          bottomr  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT         1d,1w  NaN     12h,1d,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT         3d,1w  NaN               3d
# 5m,15m,4h,8h,12h,1d              CELRUSDT            1w  NaN              NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT           1w  NaN              NaN
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT          3d,1w  NaN         1d,3d,1w
#                                  GRTUSDT          1d,1w  NaN               3d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT          2h,1w  NaN              NaN
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT        3d,1w  NaN               3d
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT         3d,1w  NaN              NaN
#                                  AVAXUSDT         3d,1w  NaN            3d,1w
#                                  CAKEUSDT   5m,1d,3d,1w  NaN        12h,1d,3d
#                                  KSMUSDT    2h,4h,3d,1w  NaN               3d
#                                  LINAUSDT            1w  NaN              NaN
#                                  ONTUSDT          1d,1w  NaN               3d
#                                  RUNEUSDT      1d,3d,1w  NaN              NaN
#                                  SRMUSDT       5m,3d,1w  NaN               3d
#                                  SUSHIUSDT        3d,1w  NaN               3d
#                                  XLMUSDT             1w  NaN              NaN
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT             1w  NaN              NaN
#                                  BANDUSDT            1w  NaN              NaN
#                                  BTCUSDT       1d,3d,1w  NaN  8h,12h,1d,3d,1w
#                                  GALAUSDT            1w  NaN              NaN
#                                  MINAUSDT         3d,1w  NaN               3d
#                                  NEARUSDT         3d,1w  NaN              NaN
#                                  ONEUSDT             1w  NaN            1d,3d
#                                  RAYUSDT          3d,1w  NaN            1d,3d
#                                  VETUSDT          3d,1w  NaN               3d
# 5m,15m,2h,4h,1d                  FTMUSDT             1w  NaN               3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT      5m,3d,1w  NaN     12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT       2h,3d,1w  NaN               3d
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT         3d,1w  NaN     8h,12h,1d,3d
#                                  WAXPUSDT      5m,1d,1w  NaN               3d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT       2h,3d,1w  NaN              NaN
#
#                                                                    stover  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT      5m,15m,30m,1h,2h,4h,12h,1d
# 5m,2h,4h,12h,1d                  ANKRUSDT          5m,30m,1h,2h,4h,12h,1d
# 5m,15m,4h,8h,12h,1d              CELRUSDT           5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT       5m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT               5m,1h,2h,4h,12h,1d
#                                  GRTUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT                   5m,1h,2h,1d,3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT          5m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT   5m,15m,30m,1h,2h,4h,12h,1d,1w
#                                  AVAXUSDT          5m,30m,1h,2h,4h,12h,1d
#                                  CAKEUSDT              5m,1h,2h,4h,12h,1d
#                                  KSMUSDT                   5m,1h,2h,1d,3d
#                                  LINAUSDT                  5m,1h,2h,4h,1d
#                                  ONTUSDT           5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                 5m,1h,2h,12h,1d
#                                  SRMUSDT             5m,1h,2h,4h,1d,3d,1w
#                                  SUSHIUSDT             5m,1h,2h,4h,12h,1d
#                                  XLMUSDT            5m,1h,2h,4h,12h,1d,1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT        5m,15m,1h,2h,4h,12h,1d,1w
#                                  BANDUSDT                  5m,1h,2h,4h,1d
#                                  BTCUSDT     5m,30m,1h,2h,4h,8h,12h,1d,1w
#                                  GALAUSDT                  5m,1h,2h,4h,3d
#                                  MINAUSDT                  5m,1h,2h,4h,1d
#                                  NEARUSDT           5m,1h,2h,4h,12h,1d,1w
#                                  ONEUSDT           5m,30m,1h,2h,4h,12h,1d
#                                  RAYUSDT               5m,1h,2h,4h,12h,1d
#                                  VETUSDT               5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT        5m,30m,1h,2h,4h,12h,1d,3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT    5m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT            5m,30m,1h,2h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT       5m,15m,30m,1h,2h,1d,3d,1w
#                                  WAXPUSDT                 5m,1h,2h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT              5m,30m,1h,2h,12h,1d
#
#                                                                            room  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT              5m,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT                 5m,2h,4h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d              CELRUSDT             5m,15m,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT     5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
#                                  GRTUSDT       5m,15m,30m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT     5m,15m,30m,1h,2h,4h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  AVAXUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  CAKEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  KSMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  LINAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  ONTUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  RUNEUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  SRMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  SUSHIUSDT         5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  XLMUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  BANDUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  BTCUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  GALAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  MINAUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  NEARUSDT          5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  ONEUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  RAYUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
#                                  VETUSDT           5m,15m,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT                  5m,15m,2h,4h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT             5m,15m,2h,4h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT        5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  WAXPUSDT       5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT           5m,15m,1h,2h,4h,12h,1d,3d,1w
#
#                                                                           roomr  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,4h,8h,12h,1d              CELRUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  GRTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  AVAXUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  CAKEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  KSMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  LINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  ONTUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  RUNEUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  SRMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  SUSHIUSDT  5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  XLMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  BANDUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  BTCUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  GALAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  MINAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  NEARUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  ONEUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  RAYUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  VETUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#                                  WAXPUSDT   5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT    5m,15m,30m,1h,2h,4h,8h,12h,1d,3d,1w
#
#                                                          stunder  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT               8h,3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT           15m,8h,3d,1w
# 5m,15m,4h,8h,12h,1d              CELRUSDT          15m,30m,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT            15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT        15m,30m,8h,3d,1w
#                                  GRTUSDT        15m,30m,8h,3d,1w
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT    15m,30m,4h,8h,12h,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT         15m,30m,3d,1w
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT                  8h,3d
#                                  AVAXUSDT           15m,8h,3d,1w
#                                  CAKEUSDT       15m,30m,8h,3d,1w
#                                  KSMUSDT       15m,30m,4h,8h,12h
#                                  LINAUSDT   15m,30m,8h,12h,3d,1w
#                                  ONTUSDT            15m,8h,3d,1w
#                                  RUNEUSDT    15m,30m,4h,8h,3d,1w
#                                  SRMUSDT          15m,30m,8h,12h
#                                  SUSHIUSDT      15m,30m,8h,3d,1w
#                                  XLMUSDT           15m,30m,8h,3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT               30m,8h,3d
#                                  BANDUSDT   15m,30m,8h,12h,3d,1w
#                                  BTCUSDT                  15m,3d
#                                  GALAUSDT   15m,30m,8h,12h,1d,1w
#                                  MINAUSDT   15m,30m,8h,12h,3d,1w
#                                  NEARUSDT          15m,30m,8h,3d
#                                  ONEUSDT               15m,8h,3d
#                                  RAYUSDT        15m,30m,8h,3d,1w
#                                  VETUSDT        15m,30m,8h,3d,1w
# 5m,15m,2h,4h,1d                  FTMUSDT               15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT                 15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT              4h,8h,12h
#                                  WAXPUSDT    15m,30m,4h,8h,3d,1w
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT         15m,4h,8h,3d,1w
#
#                                                                       stkup  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT         5m,15m,1h,2h,4h,8h,12h,1d
# 5m,2h,4h,12h,1d                  ANKRUSDT             5m,1h,2h,4h,8h,12h,1d
# 5m,15m,4h,8h,12h,1d              CELRUSDT             5m,1h,2h,4h,8h,12h,1d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT      5m,15m,1h,2h,4h,8h,1d,3d,1w
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT                 5m,15m,1h,2h,4h,1d
#                                  GRTUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT              5m,15m,1h,4h,1d,3d,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT            5m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT                5m,15m,1h,2h,4h,1d
#                                  AVAXUSDT             5m,1h,2h,4h,12h,1d,3d
#                                  CAKEUSDT             5m,1h,2h,4h,8h,12h,1d
#                                  KSMUSDT              5m,15m,1h,2h,4h,1d,3d
#                                  LINAUSDT                    5m,1h,2h,4h,1d
#                                  ONTUSDT             5m,30m,1h,2h,4h,12h,1d
#                                  RUNEUSDT                    5m,1h,2h,4h,3d
#                                  SRMUSDT           5m,15m,1h,2h,4h,8h,1d,3d
#                                  SUSHIUSDT               5m,1h,2h,4h,12h,1d
#                                  XLMUSDT          5m,15m,1h,2h,4h,8h,12h,1d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT          5m,15m,1h,2h,4h,12h,1d,1w
#                                  BANDUSDT              5m,1h,2h,4h,8h,1d,1w
#                                  BTCUSDT          5m,30m,1h,2h,4h,8h,12h,1d
#                                  GALAUSDT                 5m,1h,2h,4h,1d,3d
#                                  MINAUSDT                5m,30m,2h,4h,8h,1d
#                                  NEARUSDT             5m,15m,1h,2h,4h,8h,1d
#                                  ONEUSDT         5m,15m,30m,1h,2h,4h,12h,1d
#                                  RAYUSDT                 5m,1h,2h,4h,12h,1d
#                                  VETUSDT                 5m,1h,2h,4h,12h,1d
# 5m,15m,2h,4h,1d                  FTMUSDT    5m,15m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT       5m,1h,2h,4h,8h,12h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT           5m,15m,1h,2h,4h,1d,3d,1w
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT      5m,15m,30m,1h,2h,4h,1d,3d,1w
#                                  WAXPUSDT             5m,1h,2h,4h,8h,12h,1d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT                5m,30m,1h,2h,12h,1d
#
#                                                      stkdown  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT              3d,1w
# 5m,2h,4h,12h,1d                  ANKRUSDT         15m,30m,3d
# 5m,15m,4h,8h,12h,1d              CELRUSDT         15m,30m,3d
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT           30m,12h
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT       30m,8h,12h,3d
#                                  GRTUSDT       15m,30m,8h,3d
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT       30m,2h,8h,12h
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT        15m,30m,3d
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT          8h,12h,3d
#                                  AVAXUSDT         15m,30m,8h
#                                  CAKEUSDT      15m,30m,3d,1w
#                                  KSMUSDT          30m,8h,12h
#                                  LINAUSDT   15m,8h,12h,3d,1w
#                                  ONTUSDT           15m,8h,3d
#                                  RUNEUSDT      15m,8h,12h,1d
#                                  SRMUSDT             30m,12h
#                                  SUSHIUSDT  15m,30m,8h,3d,1w
#                                  XLMUSDT                  3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT               8h,3d
#                                  BANDUSDT         15m,12h,3d
#                                  BTCUSDT              15m,3d
#                                  GALAUSDT     15m,30m,8h,12h
#                                  MINAUSDT         15m,12h,3d
#                                  NEARUSDT             12h,3d
#                                  ONEUSDT               8h,3d
#                                  RAYUSDT       15m,30m,8h,3d
#                                  VETUSDT       15m,30m,8h,3d
# 5m,15m,2h,4h,1d                  FTMUSDT                 NaN
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT            15m,30m
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT              8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT             8h,12h
#                                  WAXPUSDT         15m,30m,3d
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT     15m,4h,8h,3d,1w
#
#                                                               uptrend  dshift  \
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT      5m,15m,1h,2h,4h,12h,1d     NaN
# 5m,2h,4h,12h,1d                  ANKRUSDT          5m,1h,2h,4h,12h,1d     30m
# 5m,15m,4h,8h,12h,1d              CELRUSDT       5m,1h,2h,4h,8h,12h,1d     NaN
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT       5m,1h,2h,4h,1d,3d,1w     12h
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT               5m,1h,2h,4h,1d     12h
#                                  GRTUSDT           5m,1h,2h,4h,12h,1d     NaN
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT                     5m,1h,1d   2h,3d
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT      5m,1h,2h,4h,8h,12h,1d     NaN
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT          5m,15m,1h,2h,4h,1d  12h,1w
#                                  AVAXUSDT          5m,1h,2h,4h,12h,1d     30m
#                                  CAKEUSDT          5m,1h,2h,4h,12h,1d     NaN
#                                  KSMUSDT               5m,1h,2h,1d,3d     NaN
#                                  LINAUSDT              5m,1h,2h,4h,1d     NaN
#                                  ONTUSDT       5m,30m,1h,2h,4h,12h,1d     NaN
#                                  RUNEUSDT                    5m,1h,2h  12h,1d
#                                  SRMUSDT            5m,1h,2h,4h,1d,3d      1w
#                                  SUSHIUSDT         5m,1h,2h,4h,12h,1d     NaN
#                                  XLMUSDT           5m,1h,2h,4h,12h,1d      1w
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT    5m,15m,1h,2h,4h,12h,1d,1w     NaN
#                                  BANDUSDT              5m,1h,2h,4h,1d     NaN
#                                  BTCUSDT    5m,30m,1h,2h,4h,8h,12h,1d      1w
#                                  GALAUSDT                 5m,1h,2h,4h      3d
#                                  MINAUSDT                 5m,2h,4h,1d     NaN
#                                  NEARUSDT              5m,1h,2h,4h,1d  12h,1w
#                                  ONEUSDT       5m,30m,1h,2h,4h,12h,1d     NaN
#                                  RAYUSDT           5m,1h,2h,4h,12h,1d     NaN
#                                  VETUSDT           5m,1h,2h,4h,12h,1d     NaN
# 5m,15m,2h,4h,1d                  FTMUSDT           5m,1h,2h,4h,12h,1d      3d
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT    5m,1h,2h,4h,12h,1d,3d,1w     30m
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT            5m,1h,2h,1d,3d,1w     NaN
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT         5m,15m,30m,1h,2h,1d   3d,1w
#                                  WAXPUSDT             5m,1h,2h,12h,1d     NaN
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT          5m,30m,1h,2h,12h,1d     NaN
#
#                                            downtrend                 shift
# buyzones                         Indicator
# 5m,2h,4h,8h,12h,1d               PERPUSDT      3d,1w                    8h
# 5m,2h,4h,12h,1d                  ANKRUSDT         3d                15m,8h
# 5m,15m,4h,8h,12h,1d              CELRUSDT         3d               15m,30m
# 5m,15m,30m,2h,4h,8h,12h,1d,3d,1w THETAUSDT       NaN            15m,30m,8h
# 5m,15m,30m,2h,4h,8h,12h,1d       FILUSDT          3d            15m,30m,8h
#                                  GRTUSDT          3d            15m,30m,8h
# 5m,15m,30m,1h,2h,4h,8h,12h,1d    ANTUSDT         NaN  15m,30m,4h,8h,12h,1w
# 5m,15m,30m,1h,2h,4h,12h,1d       TFUELUSDT        3d               15m,30m
# 5m,15m,2h,4h,8h,12h,1d,3d        ALGOUSDT        NaN                 8h,3d
#                                  AVAXUSDT        NaN             15m,8h,3d
#                                  CAKEUSDT         1w         15m,30m,8h,3d
#                                  KSMUSDT         NaN     15m,30m,4h,8h,12h
#                                  LINAUSDT         1w     15m,30m,8h,12h,3d
#                                  ONTUSDT         NaN             15m,8h,3d
#                                  RUNEUSDT        NaN      15m,30m,4h,8h,3d
#                                  SRMUSDT         NaN        15m,30m,8h,12h
#                                  SUSHIUSDT        1w         15m,30m,8h,3d
#                                  XLMUSDT         NaN         15m,30m,8h,3d
# 5m,15m,2h,4h,8h,12h,1d           ADAUSDT          3d                30m,8h
#                                  BANDUSDT         3d     15m,30m,8h,12h,1w
#                                  BTCUSDT          3d                   15m
#                                  GALAUSDT        NaN     15m,30m,8h,12h,1d
#                                  MINAUSDT         3d        15m,30m,8h,12h
#                                  NEARUSDT         3d            15m,30m,8h
#                                  ONEUSDT          3d                15m,8h
#                                  RAYUSDT          3d            15m,30m,8h
#                                  VETUSDT          3d            15m,30m,8h
# 5m,15m,2h,4h,1d                  FTMUSDT         NaN             15m,8h,1w
# 5m,15m,2h,4h,12h,1d,3d,1w        SCRTUSDT        NaN                15m,8h
# 5m,15m,1h,2h,4h,8h,12h,1d,3d,1w  SOLUSDT         NaN         15m,4h,8h,12h
# 5m,15m,1h,2h,4h,8h,12h,1d        LUNAUSDT        NaN             4h,8h,12h
#                                  WAXPUSDT         3d         15m,30m,4h,8h
# 5m,15m,1h,2h,4h,12h,1d,3d        ZRXUSDT          1w          15m,4h,8h,3d

# %%
white =  frtolist(test)
print(white)      
wrjson(white,"whitelistfile.json")
# Out:
# ['BTC/USDT', 'LUNA/USDT', 'AVAX/USDT', 'SRM/USDT', 'WAXP/USDT', 'ANKR/USDT', 'TFUEL/USDT', 'VET/USDT', 'MINA/USDT', 'SUSHI/USDT', 'KSM/USDT', 'SOL/USDT', 'FTM/USDT', 'GRT/USDT', 'ONT/USDT', 'FIL/USDT', 'RAY/USDT', 'ONE/USDT', 'SCRT/USDT', 'PERP/USDT', 'CAKE/USDT', 'NEAR/USDT', 'ALGO/USDT', 'ZRX/USDT', 'ANT/USDT', 'CELR/USDT', 'GALA/USDT', 'BAND/USDT', 'ADA/USDT', 'XLM/USDT', 'LINA/USDT', 'THETA/USDT', 'RUNE/USDT']

# %%
white =  frtolist(higherhi5)
print(white)      
wrjson(white,"hihi5.json")
# Out:
# ['ANKR/USDT', 'XTZ/USDT', 'IMX/USDT', 'ONT/USDT']

# %%
test = newframe.loc[(newframe['Indicator'] == 'BTCUSDT')]
print(test['Indicator'])
# Out:
# 29    BTCUSDT
# Name: Indicator, dtype: object

# %% [markdown]
# # Create a function to filter the above
#     - things at the bottom and going up then go  down in timeframes
#     - 1d Bottom
#         - check 12 Bottom either going towards it
#         - At the bottom of 12
#         - Already moved from the bottom of 12
