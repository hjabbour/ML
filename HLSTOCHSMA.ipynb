# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
whitelist = 'VIDT/USDT, IRIS/USDT, SHIB/USDT,  LINK/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT,RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, BOND/USDT, DCR/USDT, GNO/USDT, NBS/USDT, RIF/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
startdate = '2020-01-01'
enddate = '2022-02-01'
interval = '1d'

# %%
def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

#Calulate SMA 
def SMA(series,size):
    sma = series.rolling(size).mean()
    return sma
#Calculate SMA55

# %%
whitelist=whitelist.lstrip()
array = whitelist.split(",")
array
wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]
for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)


## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
symbol = 'STEEMETH'
#interval = '1d'
url = root_url + '?symbol=' + symbol + '&interval=' + interval
print(url)


directory = 'BN-main'
table = []
   
      
        

for symbol in symbols:
        url = root_url + '?symbol=' + symbol + '&interval=' + interval
        data = json.loads(requests.get(url).text)
        dflive = pd.DataFrame(data ,columns =['open_time',
              'o', 'h', 'l', 'c', 'v',
              'close_time', 'qav', 'num_trades',
              'taker_base_vol', 'taker_quote_vol', 'ignore'])
        dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
        dflive=dflive.loc[(dflive.open_time>start)]
        
        dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
        dflive['RSI'] = FRSI(dflive['c'])
        dflive['RSI4']= FRSI(dflive['c'],56)
        dflive['RSI8']= FRSI(dflive['c'],112)
        dflive['STRSI'] = STRSIA(dflive['c'])[0]
        dflive['STRSIK'] = STRSIA(dflive['c'])[1]
        dflive['STRSID'] = STRSIA(dflive['c'])[2]

        dflive['STRSI4'] = STRSIA(dflive['c'],56,12,12)[0]
        dflive['STRSIK4'] = STRSIA(dflive['c'],56,12,12)[1]
        dflive['STRSID4'] = STRSIA(dflive['c'],56,12,12)[2]

        dflive['STRSI8'] = STRSIA(dflive['c'],112,24,24)[0]
        dflive['STRSIK8'] = STRSIA(dflive['c'],112,24,24)[1]
        dflive['STRSID8'] = STRSIA(dflive['c'],112,24,24)[2]
        dflive['SMA21'] = SMA(dflive['c'],21)
        dflive['SMA55'] = SMA(dflive['c'],55)
        
        
        
        
        lastrow = dflive.iloc[-1]
        now = float(lastrow.c)
        RSI = float(lastrow.RSI)
        RSI4 = float(lastrow.RSI4)
        RSI8 = float(lastrow.RSI8)
        STRSI = float(lastrow.STRSI)
        STRSI4 = float(lastrow.STRSI4)
        STRSI8 = float(lastrow.STRSI8)
        STRSIK4 = float(lastrow.STRSIK4)
        STRSID4 = float(lastrow.STRSID4)
        SMA21 = float(lastrow.SMA21)
        SMA55 = float(lastrow.SMA55)
        
        
        alth = dflive.h.max()
        altl = dflive.l.min()
        
        
        ## past 1 month 
        past_month = end - relativedelta(months=1)
        
        back1Mdata = dflive.loc[(dflive.open_time> past_month)]
        omh = back1Mdata.h.max()
        oml = back1Mdata.l.min()
        ## past 2 month
        
        past_2month = end - relativedelta(months=2)
        back2Mdata = dflive.loc[(dflive.open_time> past_2month)]
        tmh = back2Mdata.h.max()
        tml = back2Mdata.l.min()
        ## past 3 month 
        
        past_3month = end - relativedelta(months=3)
        back3Mdata = dflive.loc[(dflive.open_time> past_3month)]
        thmh = back3Mdata.h.max()
        thml = back3Mdata.l.min()
        
 
        tuple =(symbol,alth,altl,now,omh,oml,tmh,tml,thmh,thml,SMA21,SMA55,RSI,RSI4,RSI8,STRSI,STRSI4,STRSI8,STRSIK4,STRSID4,)
        table.append(tuple)
        del dflive
        #print("name is: ",array[0] ,alth,altl)
        print("name is: ",symbol)
        

table[0]
AllTime = pd.DataFrame(table,columns=['Indicator','ATH','ATL','Current','OMH','OML','TMH','TML','THMH','THML','SMA21','SMA55','RSI','RSI4','RSI8','STRSI','STRSI4','STRSI8','STRSIK4','STRSID4'])
AllTime.ATH=AllTime.ATH.astype(float)
AllTime.ATL=AllTime.ATL.astype(float)
AllTime.Current=AllTime.Current.astype(float)
AllTime.OMH=AllTime.OMH.astype(float)
AllTime.OML=AllTime.OML.astype(float)
AllTime.TMH=AllTime.TMH.astype(float)
AllTime.TML=AllTime.TML.astype(float)
AllTime.THMH=AllTime.THMH.astype(float)
AllTime.THML=AllTime.THML.astype(float)
AllTime.dtypes

AllTime['ALLTIME']=(AllTime['Current']/AllTime['ATH'])*100
AllTime['MONTH']=(AllTime['Current']/AllTime['OMH'])*100
AllTime['2MONTH']=(AllTime['Current']/AllTime['TMH'])*100
AllTime['3MONTH']=(AllTime['Current']/AllTime['THMH'])*100
AllTime['SMADIFF']= abs(AllTime['SMA21']- AllTime['SMA55'])
AllTime['SMARATIO']= (AllTime['SMA21']/AllTime['SMA55'])

AllTime.sort_values(by=['ALLTIME'],ascending=True,inplace = True)
#AllTime.sort_values(by='ATH',ascending=False)
#AllTime.to_csv("alltimeHL.csv", mode="w")
#data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

## Display the Data 
AllTime
# Out:
# https://api.binance.com/api/v1/klines?symbol=STEEMETH&interval=1d
# name is:  VIDTUSDT
# name is:  IRISUSDT
# name is:  SHIBUSDT
# name is:  LINKUSDT
# name is:  MATICUSDT
# name is:  ZRXUSDT
# name is:  ALGOUSDT
# name is:  BTCUSDT
# name is:  ETHUSDT
# name is:  AXSUSDT
# name is:  SOLUSDT
# name is:  MATICUSDT
# name is:  ADAUSDT
# name is:  BNBUSDT
# name is:  FILUSDT
# name is:  XRPUSDT
# name is:  CVCUSDT
# name is:  FTMUSDT
# name is:  ICPUSDT
# name is:  DOGEUSDT
# name is:  XECUSDT
# name is:  IOTAUSDT
# name is:  AVAXUSDT
# name is:  DOTUSDT
# name is:  LTCUSDT
# name is:  EOSUSDT
# name is:  IOSTUSDT
# name is:  STMXUSDT
# name is:  FTTUSDT
# name is:  TWTUSDT
# name is:  ALICEUSDT
# name is:  ATAUSDT
# name is:  ETCUSDT
# name is:  VETUSDT
# name is:  SANDUSDT
# name is:  LINKUSDT
# name is:  THETAUSDT
# name is:  SHIBUSDT
# name is:  CHZUSDT
# name is:  LUNAUSDT
# name is:  IOTXUSDT
# name is:  TRXUSDT
# name is:  TLMUSDT
# name is:  BCHUSDT
# name is:  REEFUSDT
# name is:  CAKEUSDT
# name is:  NEOUSDT
# name is:  RVNUSDT
# name is:  ATOMUSDT
# name is:  SUSHIUSDT
# name is:  ARDRUSDT
# name is:  OMGUSDT
# name is:  GRTUSDT
# name is:  1INCHUSDT
# name is:  AAVEUSDT
# name is:  C98USDT
# name is:  UNIUSDT
# name is:  HBARUSDT
# name is:  CRVUSDT
# name is:  DENTUSDT
# name is:  MBOXUSDT
# name is:  BTTUSDT
# name is:  SRMUSDT
# name is:  YFIUSDT
# name is:  HOTUSDT
# name is:  XLMUSDT
# name is:  FISUSDT
# name is:  REQUSDT
# name is:  SXPUSDT
# name is:  KSMUSDT
# name is:  QNTUSDT
# name is:  NEARUSDT
# name is:  COMPUSDT
# name is:  QTUMUSDT
# name is:  CHRUSDT
# name is:  SCUSDT
# name is:  XVSUSDT
# name is:  ONTUSDT
# name is:  COTIUSDT
# name is:  NKNUSDT
# name is:  RUNEUSDT
# name is:  ANKRUSDT
# name is:  MANAUSDT
# name is:  CTXCUSDT
# name is:  ARUSDT
# name is:  RAYUSDT
# name is:  BAKEUSDT
# name is:  ARPAUSDT
# name is:  XTZUSDT
# name is:  ZILUSDT
# name is:  ONGUSDT
# name is:  ROSEUSDT
# name is:  PNTUSDT
# name is:  ALGOUSDT
# name is:  MINAUSDT
# name is:  WINUSDT
# name is:  AUDIOUSDT
# name is:  STORJUSDT
# name is:  EPSUSDT
# name is:  MDXUSDT
# name is:  ZECUSDT
# name is:  ENJUSDT
# name is:  HIVEUSDT
# name is:  TFUELUSDT
# name is:  WRXUSDT
# name is:  SNXUSDT
# name is:  SKLUSDT
# name is:  LINAUSDT
# name is:  DODOUSDT
# name is:  UNFIUSDT
# name is:  XEMUSDT
# name is:  EGLDUSDT
# name is:  ICXUSDT
# name is:  WAVESUSDT
# name is:  ONEUSDT
# name is:  DASHUSDT
# name is:  KAVAUSDT
# name is:  TKOUSDT
# name is:  OGNUSDT
# name is:  XMRUSDT
# name is:  OCEANUSDT
# name is:  CELOUSDT
# name is:  BATUSDT
# name is:  FUNUSDT
# name is:  LRCUSDT
# name is:  ALPHAUSDT
# name is:  MASKUSDT
# name is:  TRUUSDT
# name is:  DNTUSDT
# name is:  LITUSDT
# name is:  FETUSDT
# name is:  GTCUSDT
# name is:  CELRUSDT
# name is:  DEXEUSDT
# name is:  ZENUSDT
# name is:  WAXPUSDT
# name is:  CTSIUSDT
# name is:  HNTUSDT
# name is:  YFIIUSDT
# name is:  BELUSDT
# name is:  ZRXUSDT
# name is:  DEGOUSDT
# name is:  RSRUSDT
# name is:  COSUSDT
# name is:  FLMUSDT
# name is:  BALUSDT
# name is:  MFTUSDT
# name is:  RLCUSDT
# name is:  KNCUSDT
# name is:  RENUSDT
# name is:  INJUSDT
# name is:  FLOWUSDT
# name is:  SFPUSDT
# name is:  BANDUSDT
# name is:  CTKUSDT
# name is:  SUNUSDT
# name is:  AKROUSDT
# name is:  XVGUSDT
# name is:  NANOUSDT
# name is:  STRAXUSDT
# name is:  PUNDIXUSDT
# name is:  TVKUSDT
# name is:  MKRUSDT
# name is:  CLVUSDT
# name is:  TRBUSDT
# name is:  KEEPUSDT
# name is:  TCTUSDT
# name is:  PONDUSDT
# name is:  LTOUSDT
# name is:  ANTUSDT
# name is:  TOMOUSDT
# name is:  ACMUSDT
# name is:  FIOUSDT
# name is:  VITEUSDT
# name is:  MBLUSDT
# name is:  JSTUSDT
# name is:  MTLUSDT
# name is:  UTKUSDT
# name is:  BLZUSDT
# name is:  ORNUSDT
# name is:  STPTUSDT
# name is:  CFXUSDT
# name is:  OMUSDT
# name is:  PERPUSDT
# name is:  MIRUSDT
# name is:  STXUSDT
# name is:  ERNUSDT
# name is:  TUSDUSDT
# name is:  PSGUSDT
# name is:  NULSUSDT
# name is:  OXTUSDT
# name is:  REPUSDT
# name is:  DATAUSDT
# name is:  WANUSDT
# name is:  BURGERUSDT
# name is:  RAMPUSDT
# name is:  ATMUSDT
# name is:  DGBUSDT
# name is:  DIAUSDT
# name is:  BEAMUSDT
# name is:  UMAUSDT
# name is:  CKBUSDT
# name is:  TRIBEUSDT
# name is:  FARMUSDT
# name is:  BZRXUSDT
# name is:  ALPACAUSDT
# name is:  BTSUSDT
# name is:  FORUSDT
# name is:  HARDUSDT
# name is:  LSKUSDT
# name is:  POLSUSDT
# name is:  FORTHUSDT
# name is:  TORNUSDT
# name is:  VTHOUSDT
# name is:  BTGUSDT
# name is:  QUICKUSDT
# name is:  PAXUSDT
# name is:  MITHUSDT
# name is:  DUSKUSDT
# name is:  WTCUSDT
# name is:  DOCKUSDT
# name is:  AUTOUSDT
# name is:  BTCSTUSDT
# name is:  KLAYUSDT
# name is:  WNXMUSDT
# name is:  KEYUSDT
# name is:  NUUSDT
# name is:  IRISUSDT
# name is:  KMDUSDT
# name is:  TROYUSDT
# name is:  WINGUSDT
# name is:  AIONUSDT
# name is:  PHAUSDT
# name is:  GHSTUSDT
# name is:  PAXGUSDT
# name is:  BNTUSDT
# name is:  AVAUSDT
# name is:  BADGERUSDT
# name is:  PERLUSDT
# name is:  COCOSUSDT
# name is:  GXSUSDT
# name is:  MDTUSDT
# name is:  GTOUSDT
# name is:  FIROUSDT
# name is:  JUVUSDT
# name is:  MLNUSDT
# name is:  LPTUSDT
# name is:  NMRUSDT
# name is:  ASRUSDT
# name is:  OGUSDT
# name is:  BARUSDT
# name is:  DREPUSDT
# name is:  BONDUSDT
# name is:  DCRUSDT
# name is:  GNOUSDT
# name is:  NBSUSDT
# name is:  RIFUSDT
# name is:  SUSDUSDT
#      Indicator        ATH         ATL     Current        OMH         OML  \
# 155    SUNUSDT    54.5600     0.01314     0.01472     0.0233     0.01314
# 216    PAXUSDT   999.0000     0.93880     0.99960        NaN         NaN
# 98     EPSUSDT    22.5000     0.14230     0.15740     0.3248     0.14230
# 18     ICPUSDT  2831.0200    18.06000    21.09000    38.0200    18.06000
# 222  BTCSTUSDT  1000.0000     8.00000    15.17000    26.2900    13.26000
# ..         ...        ...         ...         ...        ...         ...
# 8      ETHUSDT  4868.0000   313.29000  2658.82000  3900.7300  2159.00000
# 17     FTMUSDT     3.4842     0.01264     1.94250     3.3788     1.77000
# 48    ATOMUSDT    44.8000     3.78000    26.35000    44.7000    25.50000
# 233   GHSTUSDT     3.4000     1.50800     2.01400     2.6450     1.97500
# 234   PAXGUSDT  2100.8500  1687.57000  1809.00000  1869.0000  1772.00000
#
#             TMH         TML        THMH        THML  ...    STRSI4    STRSI8  \
# 155     0.03197     0.01314     0.04273     0.01314  ...  0.234925  0.077459
# 216         NaN         NaN         NaN         NaN  ...  0.439738  0.638107
# 98      0.49500     0.14230     0.68570     0.14230  ...  0.105946  0.234329
# 18     41.46000    18.06000    58.30000    18.06000  ...  0.447167  0.743217
# 222    32.77000    13.26000    48.95000    13.26000  ...  0.127675  0.025288
# ..          ...         ...         ...         ...  ...       ...       ...
# 8    4654.88000  2159.00000  4868.00000  2159.00000  ...  0.254114  0.099909
# 17      3.37880     1.15380     3.37880     1.15380  ...  0.226025  0.091471
# 48     44.70000    20.18000    44.70000    20.18000  ...  0.180133  0.103447
# 233     2.98800     1.97500     3.40000     1.97500  ...  0.102865       NaN
# 234  1869.00000  1759.00000  1885.00000  1759.00000  ...  0.309303  0.351389
#
#       STRSIK4   STRSID4    ALLTIME      MONTH     2MONTH     3MONTH  \
# 155  0.096560  0.206449   0.026979  63.175966  46.043165  34.448865
# 216  0.402777  0.470109   0.100060        NaN        NaN        NaN
# 98   0.088328  0.115272   0.699556  48.460591  31.797980  22.954645
# 18   0.356045  0.460398   0.744961  55.470805  50.868307  36.174957
# 222  0.081395  0.103476   1.517000  57.702548  46.292341  30.990807
# ..        ...       ...        ...        ...        ...        ...
# 8    0.138875  0.083515  54.618324  68.162113  57.118981  54.618324
# 17   0.317828  0.480356  55.751679  57.490825  57.490825  57.490825
# 48   0.335843  0.506522  58.816964  58.948546  58.948546  58.948546
# 233  0.052128  0.036514  59.235294  76.143667  67.402945  59.235294
# 234  0.473843  0.715522  86.108004  96.789727  96.789727  95.968170
#
#         SMADIFF  SMARATIO
# 155    0.003540  0.822765
# 216    0.000027  0.999973
# 98     0.049334  0.787165
# 18     2.538009  0.902840
# 222    3.508459  0.828188
# ..          ...       ...
# 8    595.680857  0.823343
# 17     0.187248  1.084785
# 48     1.919152  1.060667
# 233    0.148543  0.933071
# 234    9.731602  1.005364
#
# [258 rows x 26 columns]

# %%
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1)]
drop = AllTime.loc[(AllTime['SMARATIO'] <  1.05 ) &(AllTime['SMARATIO'] > 0.95)& (AllTime['STRSI'] < 0.2) & (AllTime['ALLTIME'] <70) ]
#drop = AllTime.loc[(AllTime['SMARATIO'] <  1 ) &(AllTime['SMARATIO'] > 0.95) & (AllTime['ALLTIME'] <70)]

#drop = AllTime.loc[(AllTime['MONTH'] < 80)&(AllTime[ '2MONTH'] < 70)&(AllTime['ALLTIME'] < 40)]
#drop = AllTime.loc[(AllTime['MONTH'] <70)&(AllTime['2MONTH'] > (AllTime['3MONTH']))]

sort = drop.sort_values(by=['SMARATIO'],ascending=True,inplace = True) 
#drop = drop.loc[(drop['ALLTIME'] < drop['3MONTH'])]
display = drop[['Indicator','ALLTIME','MONTH','SMARATIO','SMADIFF','Current']]

print("Low 4h SMADIFF")
print(display.iloc[0:60,0:14])
print(display.iloc[60:110,])
print(display.iloc[110:160,])
# Out:
# Low 4h SMADIFF
#     Indicator    ALLTIME      MONTH  SMARATIO   SMADIFF  Current
# 223  KLAYUSDT  25.522727  70.187500  0.975669  0.031565   1.1230
# 218  DUSKUSDT  40.032360  43.168044  0.987730  0.008472   0.4701
# Empty DataFrame
# Columns: [Indicator, ALLTIME, MONTH, SMARATIO, SMADIFF, Current]
# Index: []
# Empty DataFrame
# Columns: [Indicator, ALLTIME, MONTH, SMARATIO, SMADIFF, Current]
# Index: []
# /Users/hjabbour/opt/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
