#entrylist =[['ANKRUSDT',0.07684],['AVAXUSDT',57],['WAXPUSDT',0.3818],['REEFUSDT',0.01131],['LINKUSDT',14.15],['ARUSDT',30],['ATOMUSDT',23],['MIRUSDT',2.343],['ALGOUSDT',0.909],['ZRXUSDT',0.60],['XTZUSDT',2.856],['KSMUSDT',163],['NEARUSDT',14],['WINUSDT',0.0003138],['CELRUSDT',0.05063],['DENTUSDT',0.002459],['LRCUSDT',0.7047],['CRVUSDT',3.529],['IMXUSDT',2.709],['SCRTUSDT',5],['RENUSDT',0.2547],['SUSHIUSDT',4.522],['CAKEUSDT',11.24],['XLMUSDT',0.2109],['HNTUSDT',30],['OMGUSDT',4.5],['LINAUSDT',0.024],['MIRUSDT',2.343],['FLUXUSDT',1.523]]
entrylist =[['ANKRUSDT',0.07684],['AVAXUSDT',57],['WAXPUSDT',0.3174],['REEFUSDT',0.01131],['LINKUSDT',14.15],['ARUSDT',30],['ATOMUSDT',23],['MIRUSDT',2.343],['ALGOUSDT',0.909],['ZRXUSDT',0.60],['XTZUSDT',2.856],['KSMUSDT',150],['NEARUSDT',10.320],['WINUSDT',0.0003138],['DENTUSDT',0.002459],['LRCUSDT',0.7047],['CRVUSDT',3.529],['IMXUSDT',2.509],['SCRTUSDT',5],['RENUSDT',0.2547],['SUSHIUSDT',4.522],['CAKEUSDT',11.24],['XLMUSDT',0.2109],['HNTUSDT',30],['OMGUSDT',4.5],['LINAUSDT',0.024],['FLUXUSDT',1.523],['SRMUSDT',2.322],['VTHOUSDT',0.003938],['ANTUSDT',5.616],['RAYUSDT',3.54],['ROSEUSDT',0.30055],['MOVRUSDT',92.9],['TFUELUSDT',0.22],['GLMRUSDT',4.5],['COTIUSDT',0.2277],['ONEUSDT',0.17045],['VETUSDT',0.05138],['RUNEUSDT',3.709],['CELRUSDT',0.05063],['ONTUSDT',0.4652],['GALAUSDT',0.24794]]

startdate = '2020-01-01'
enddate = '2022-02-20'
interval = '4h'
easyband = pd.read_csv('easyband.csv')
#Columns=['Indicator','ALLTIME','CLOSERATIO','SMA100','SMA55']
easyband = pd.DataFrame(easyband,columns=['Indicator','ATH','CLOSERATIO','RED','ORANGE','GREEN'])
#easyband = easyband.loc[:,['Indicator','SMA21','GREENEASY']]
#EASY=float(easyband.loc[(easyband.Indicator=='BANDUSDT')].SMA100.values)
#print(easyband)
#EASY[0]
easyband
# Out:
#       Indicator        ATH  CLOSERATIO         RED      ORANGE      GREEN
# 0     1INCHUSDT    7.87480    0.108449    3.370476    1.685238   0.842619
# 1       BNTUSDT    9.36890    0.108186    4.970286    2.485143   1.242571
# 2      STPTUSDT    0.29375    0.107203    0.178504    0.089252   0.044626
# 3      KAVAUSDT    9.21800    0.106210    7.673048    3.836524   1.918262
# 4      DASHUSDT  478.00000    0.105312  217.133333  108.566667  54.283333
# ..          ...        ...         ...         ...         ...        ...
# 197  BURGERUSDT   29.00000   -0.543377    3.433905    1.716952   0.858476
# 198     MIRUSDT   14.55000   -0.559857    2.983937    1.491969   0.745984
# 199    PONDUSDT    0.31800   -0.580083    0.077444    0.038722   0.019361
# 200     FTMUSDT    3.48420   -0.587232    3.263819    1.631910   0.815955
# 201    LUNAUSDT  119.55000   -0.999999  149.192386   74.596193  37.298096
#
# [202 rows x 6 columns]

# %%
capratio = pd.read_csv('capratio.csv')
capratio = pd.DataFrame(capratio,columns=['Indicator','supply_ratio','cap_ratio'])
capratio
# Out:
#      Indicator  supply_ratio  cap_ratio
# 0    IBEURUSDT      1.000000   1.000000
# 1   RENBTCUSDT      1.000000   1.000000
# 2      BNBUSDT      1.000000   1.000000
# 3      NXMUSDT      1.000000   1.000000
# 4      LPTUSDT      1.000000   1.000000
# ..         ...           ...        ...
# 67    NEXOUSDT      0.560000   0.560000
# 68    ELONUSDT      0.551102   0.551102
# 69    WAXPUSDT      0.529420   0.529420
# 70    EURTUSDT      0.514997   0.514997
# 71     SKLUSDT      0.500283   0.500283
#
# [72 rows x 3 columns]

# %%
#easycap = pd.concat([easyband, capratio], axis=1, join="inner",keys='Indicator')
#easycap =pd.merge(left=easyband, right=capratio, left_on='Indicator', right_on='Indicator')
easycap =easyband.merge(capratio, how = 'left', on ='Indicator')
easycap = easycap.dropna(subset=['cap_ratio'])
easycap.sort_values(by=['cap_ratio'],ascending=False,inplace = True)
easycap
# Out:
#      Indicator           ATH  CLOSERATIO           RED        ORANGE  \
# 1      BNTUSDT      9.368900    0.108186      4.970286      2.485143
# 9      LPTUSDT    101.800000    0.088368     54.577143     27.288571
# 20     OMGUSDT     20.124000    0.033530      9.489810      4.744905
# 89     RENUSDT      1.840000   -0.155119      0.737619      0.368810
# 148   IOTXUSDT      0.263000   -0.290878      0.163639      0.081820
# 38     BATUSDT      1.929000   -0.036833      1.633362      0.816681
# 77     YFIUSDT  95000.000000   -0.122508  45367.424762  22683.712381
# 98     ENJUSDT      4.845000   -0.179336      3.421619      1.710810
# 7      QNTUSDT    430.000000    0.098585    249.047619    124.523810
# 186    ONEUSDT      0.380000   -0.444962      0.337490      0.168745
# 42     XECUSDT      0.000392   -0.048676      0.000171      0.000086
# 79     LRCUSDT      3.850000   -0.127486      2.085010      1.042505
# 111    KSMUSDT    625.000000   -0.193183    351.504762    175.752381
# 37    AAVEUSDT    668.000000   -0.029851    338.504762    169.252381
# 13     SNXUSDT     28.981000    0.059860      9.827714      4.913857
# 35    ANKRUSDT      0.216617   -0.020582      0.154459      0.077230
# 200    FTMUSDT      3.484200   -0.587232      3.263819      1.631910
# 179  SUSHIUSDT     23.430000   -0.406296      8.394762      4.197381
# 29     VETUSDT      0.279829    0.009123      0.119629      0.059814
# 107     ARUSDT     91.080000   -0.187495     70.005714     35.002857
# 21     ADAUSDT      3.101000    0.028733      2.026571      1.013286
# 90     GRTUSDT      2.880730   -0.160425      0.846619      0.423310
# 102  MATICUSDT      2.923000   -0.184502      3.232381      1.616190
# 53    MANAUSDT      5.900000   -0.074228      4.961914      2.480957
# 32    COMPUSDT    911.000000    0.002524    271.714286    135.857143
# 26    NEARUSDT     20.597000    0.016505     25.192190     12.596095
# 39    ALGOUSDT      2.990000   -0.044232      1.866562      0.933281
# 125  AUDIOUSDT      4.990000   -0.242675      2.154952      1.077476
# 99     UMAUSDT     43.998000   -0.179794     13.757524      6.878762
# 25    RUNEUSDT     21.280000    0.017255     12.634000      6.317000
# 27     CHZUSDT      0.944900    0.015431      0.438829      0.219414
# 132   WAXPUSDT      0.983500   -0.252113      0.632181      0.316090
# 19     SKLUSDT      1.244430    0.033838      0.308752      0.154376
#
#             GREEN  supply_ratio  cap_ratio
# 1        1.242571      1.000000   1.000000
# 9       13.644286      1.000000   1.000000
# 20       2.372452      1.000000   1.000000
# 89       0.184405      1.000000   1.000000
# 148      0.040910      0.999427   0.999427
# 38       0.408340      0.998691   0.998691
# 77   11341.856190      0.970154   0.970154
# 98       0.855405      0.934341   0.934341
# 7       62.261905      0.917978   0.917978
# 186      0.084373      0.916981   0.916981
# 42       0.000043      0.907557   0.907557
# 79       0.521252      0.906496   0.906496
# 111     87.876190      0.898010   0.898010
# 37      84.626190      0.857232   0.857232
# 13       2.456929      0.851200   0.851200
# 35       0.038615      0.816290   0.816290
# 200      0.815955      0.800363   0.800363
# 179      2.098690      0.771157   0.771157
# 29       0.029907      0.769908   0.769908
# 107     17.501429      0.759220   0.759220
# 21       0.506643      0.751561   0.751561
# 90       0.211655      0.692962   0.692962
# 102      0.808095      0.687289   0.687289
# 53       1.240479      0.686660   0.686660
# 32      67.928571      0.685609   0.685609
# 26       6.298048      0.683664   0.683664
# 39       0.466640      0.681178   0.681178
# 125      0.538738      0.651973   0.651973
# 99       3.439381      0.618238   0.618238
# 25       3.158500      0.601510   0.601510
# 27       0.109707      0.601207   0.601207
# 132      0.158045      0.529420   0.529420
# 19       0.077188      0.500283   0.500283

# %%
easycaplist = easycap['Indicator']
easycaplist

for item in easycaplist :
    
    x=item.replace('USDT','')
    print('$'+x)
# Out:
# $BNT
# $LPT
# $OMG
# $REN
# $IOTX
# $BAT
# $YFI
# $ENJ
# $QNT
# $ONE
# $XEC
# $LRC
# $KSM
# $AAVE
# $SNX
# $ANKR
# $FTM
# $SUSHI
# $VET
# $AR
# $ADA
# $GRT
# $MATIC
# $MANA
# $COMP
# $NEAR
# $ALGO
# $AUDIO
# $UMA
# $RUNE
# $CHZ
# $WAXP
# $SKL

# %%
entries = pd.DataFrame(entrylist, columns =['Indicator', 'lowest_entry'],dtype = float) 
entries
entries.lowest_entry.astype(float)
indicator_list = entries['Indicator']
#indicator_list
#entries
# Out:
# /Users/hjabbour/opt/anaconda3/envs/cryptodev/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
## Entries for coins with good cap ratio
entries = pd.read_csv('entries.csv')
entries = pd.DataFrame(entries,columns=['Indicator','lowest_entry'])
entriescap =pd.merge(left=entries, right=easycap, left_on='Indicator', right_on='Indicator')

entriescap
# Out:
#     Indicator  lowest_entry         ATH  CLOSERATIO         RED      ORANGE  \
# 0    ANKRUSDT       0.05415    0.216617   -0.020582    0.154459    0.077230
# 1    WAXPUSDT       0.25510    0.983500   -0.252113    0.632181    0.316090
# 2      ARUSDT      14.00000   91.080000   -0.187495   70.005714   35.002857
# 3    ALGOUSDT       0.63000    2.990000   -0.044232    1.866562    0.933281
# 4     KSMUSDT     115.00000  625.000000   -0.193183  351.504762  175.752381
# 5    NEARUSDT       6.10000   20.597000    0.016505   25.192190   12.596095
# 6     LRCUSDT       0.67700    3.850000   -0.127486    2.085010    1.042505
# 7     RENUSDT       0.30470    1.840000   -0.155119    0.737619    0.368810
# 8   SUSHIUSDT       3.50000   23.430000   -0.406296    8.394762    4.197381
# 9     OMGUSDT       4.50000   20.124000    0.033530    9.489810    4.744905
# 10    ONEUSDT       0.03900    0.380000   -0.444962    0.337490    0.168745
# 11    VETUSDT       0.05138    0.279829    0.009123    0.119629    0.059814
# 12   RUNEUSDT       3.70900   21.280000    0.017255   12.634000    6.317000
# 13    GRTUSDT       0.31640    2.880730   -0.160425    0.846619    0.423310
# 14  MATICUSDT       1.40000    2.923000   -0.184502    3.232381    1.616190
# 15    FTMUSDT       0.31000    3.484200   -0.587232    3.263819    1.631910
# 16  AUDIOUSDT       0.37500    4.990000   -0.242675    2.154952    1.077476
# 17   IOTXUSDT       0.02478    0.263000   -0.290878    0.163639    0.081820
# 18    ADAUSDT       0.51000    3.101000    0.028733    2.026571    1.013286
# 19   MANAUSDT       1.65000    5.900000   -0.074228    4.961914    2.480957
#
#         GREEN  supply_ratio  cap_ratio
# 0    0.038615      0.816290   0.816290
# 1    0.158045      0.529420   0.529420
# 2   17.501429      0.759220   0.759220
# 3    0.466640      0.681178   0.681178
# 4   87.876190      0.898010   0.898010
# 5    6.298048      0.683664   0.683664
# 6    0.521252      0.906496   0.906496
# 7    0.184405      1.000000   1.000000
# 8    2.098690      0.771157   0.771157
# 9    2.372452      1.000000   1.000000
# 10   0.084373      0.916981   0.916981
# 11   0.029907      0.769908   0.769908
# 12   3.158500      0.601510   0.601510
# 13   0.211655      0.692962   0.692962
# 14   0.808095      0.687289   0.687289
# 15   0.815955      0.800363   0.800363
# 16   0.538738      0.651973   0.651973
# 17   0.040910      0.999427   0.999427
# 18   0.506643      0.751561   0.751561
# 19   1.240479      0.686660   0.686660
