#entrylist =[['ANKRUSDT',0.07684],['AVAXUSDT',57],['WAXPUSDT',0.3818],['REEFUSDT',0.01131],['LINKUSDT',14.15],['ARUSDT',30],['ATOMUSDT',23],['MIRUSDT',2.343],['ALGOUSDT',0.909],['ZRXUSDT',0.60],['XTZUSDT',2.856],['KSMUSDT',163],['NEARUSDT',14],['WINUSDT',0.0003138],['CELRUSDT',0.05063],['DENTUSDT',0.002459],['LRCUSDT',0.7047],['CRVUSDT',3.529],['IMXUSDT',2.709],['SCRTUSDT',5],['RENUSDT',0.2547],['SUSHIUSDT',4.522],['CAKEUSDT',11.24],['XLMUSDT',0.2109],['HNTUSDT',30],['OMGUSDT',4.5],['LINAUSDT',0.024],['MIRUSDT',2.343],['FLUXUSDT',1.523]]
entrylist =[['ANKRUSDT',0.07684],['AVAXUSDT',57],['WAXPUSDT',0.3174],['REEFUSDT',0.01131],['LINKUSDT',14.15],['ARUSDT',30],['ATOMUSDT',23],['MIRUSDT',2.343],['ALGOUSDT',0.909],['ZRXUSDT',0.60],['XTZUSDT',2.856],['KSMUSDT',150],['NEARUSDT',10.320],['WINUSDT',0.0003138],['DENTUSDT',0.002459],['LRCUSDT',0.7047],['CRVUSDT',3.529],['IMXUSDT',2.509],['SCRTUSDT',5],['RENUSDT',0.2547],['SUSHIUSDT',4.522],['CAKEUSDT',11.24],['XLMUSDT',0.2109],['HNTUSDT',30],['OMGUSDT',4.5],['LINAUSDT',0.024],['FLUXUSDT',1.523],['SRMUSDT',2.322],['VTHOUSDT',0.003938],['ANTUSDT',5.616],['RAYUSDT',3.54],['ROSEUSDT',0.30055],['MOVRUSDT',92.9],['TFUELUSDT',0.22],['GLMRUSDT',4.5],['COTIUSDT',0.2277],['ONEUSDT',0.17045],['VETUSDT',0.05138],['RUNEUSDT',3.709],['CELRUSDT',0.05063],['ONTUSDT',0.4652],['GALAUSDT',0.24794]]

startdate = '2020-01-01'
enddate = '2022-02-20'
interval = '4h'
easyband = pd.read_csv('easyband.csv')
#Columns=['Indicator','ALLTIME','CLOSERATIO','SMA100','SMA55']
easyband = pd.DataFrame(easyband,columns=['Indicator','ALLTIME','CLOSERATIO','SMA21','SMA55','GREENEASY'])
easyband = easyband.loc[:,['Indicator','SMA21','GREENEASY']]
#EASY=float(easyband.loc[(easyband.Indicator=='BANDUSDT')].SMA100.values)
#print(easyband)
#EASY[0]
easyband
# Out:
#    Indicator       SMA21   GREENEASY
# 0    RAYUSDT    7.336333    3.668167
# 1    MDXUSDT    0.594048    0.297024
# 2    CLVUSDT    0.832810    0.416405
# 3   BAKEUSDT    1.304810    0.652405
# 4   BONDUSDT   19.477143    9.738571
# ..       ...         ...         ...
# 61   CFXUSDT    0.226657    0.113329
# 62   EPSUSDT    0.344795    0.172398
# 63  COMPUSDT  225.900000  112.950000
# 64   UNIUSDT   17.768571    8.884286
# 65   TRBUSDT   38.940952   19.470476
#
# [66 rows x 3 columns]

# %%
capratio = pd.read_csv('capratio.csv')
capratio = pd.DataFrame(capratio,columns=['Indicator','supply_ratio','cap_ratio'])
capratio
# Out:
#      Indicator  supply_ratio  cap_ratio
# 0      LPTUSDT      1.000000   1.000000
# 1   RENBTCUSDT      1.000000   1.000000
# 2      UFOUSDT      1.000000   1.000000
# 3   PEOPLEUSDT      1.000000   1.000000
# 4      RENUSDT      1.000000   1.000000
# 5      OMGUSDT      1.000000   1.000000
# 6      BNTUSDT      1.000000   1.000000
# 7     MSOLUSDT      1.000000   1.000000
# 8      NXMUSDT      1.000000   1.000000
# 9     KP3RUSDT      1.000000   1.000000
# 10    HBTCUSDT      1.000000   1.000000
# 11    IOTXUSDT      0.999427   0.999427
# 12     FEIUSDT      0.999043   0.999043
# 13     BATUSDT      0.997057   0.997057
# 14    DESOUSDT      0.974442   0.974442
# 15     YFIUSDT      0.973453   0.973453
# 16     BTTUSDT      0.941917   0.941917
# 17    TIMEUSDT      0.940962   0.940962
# 18     ENJUSDT      0.934341   0.934341
# 19     OHMUSDT      0.927005   0.927005
# 20     QNTUSDT      0.917978   0.917978
# 21     LRCUSDT      0.906496   0.906496
# 22     XECUSDT      0.904131   0.904131
# 23     RPLUSDT      0.899544   0.899544
# 24     KSMUSDT      0.898010   0.898010
# 25     MKRUSDT      0.896312   0.896312
# 26     ONEUSDT      0.890557   0.890557
# 27     SNXUSDT      0.868942   0.868942
# 28    AAVEUSDT      0.851290   0.851290
# 29     ZRXUSDT      0.847496   0.847496
# 30    ANKRUSDT      0.816290   0.816290
# 31     KUBUSDT      0.806818   0.806818
# 32    FLEXUSDT      0.797439   0.797439
# 33   SUSHIUSDT      0.771157   0.771157
# 34      ARUSDT      0.759220   0.759220
# 35     JSTUSDT      0.737417   0.737417
# 36     SYNUSDT      0.703239   0.703239
# 37     SXPUSDT      0.681815   0.681815
# 38    COMPUSDT      0.658577   0.658577
# 39     UMAUSDT      0.615170   0.615170
# 40    RUNEUSDT      0.601510   0.601510
# 41     CHZUSDT      0.601207   0.601207
# 42     FXSUSDT      0.578809   0.578809
# 43     ZECUSDT      0.578695   0.578695
# 44     CHRUSDT      0.567369   0.567369
# 45    CELRUSDT      0.564545   0.564545
# 46   AUDIOUSDT      0.564255   0.564255
# 47    NEXOUSDT      0.560000   0.560000
# 48  TSHAREUSDT      0.558967   0.558967
# 49    ELONUSDT      0.553290   0.553290
# 50    KEEPUSDT      0.549716   0.549716
# 51    WAXPUSDT      0.519118   0.519118
# 52    HEROUSDT      0.515076   0.515076
# 53    EURTUSDT      0.514997   0.514997
# 54     CVXUSDT      0.514672   0.514672

# %%
#easycap = pd.concat([easyband, capratio], axis=1, join="inner",keys='Indicator')
#easycap =pd.merge(left=easyband, right=capratio, left_on='Indicator', right_on='Indicator')
easycap =capratio.merge(easyband, how = 'left', on ='Indicator')

easycap
# Out:
#      Indicator  supply_ratio  cap_ratio       SMA21   GREENEASY
# 0      LPTUSDT      1.000000   1.000000         NaN         NaN
# 1   RENBTCUSDT      1.000000   1.000000         NaN         NaN
# 2      UFOUSDT      1.000000   1.000000         NaN         NaN
# 3   PEOPLEUSDT      1.000000   1.000000         NaN         NaN
# 4      RENUSDT      1.000000   1.000000    0.642305    0.321152
# 5      OMGUSDT      1.000000   1.000000    8.150762    4.075381
# 6      BNTUSDT      1.000000   1.000000         NaN         NaN
# 7     MSOLUSDT      1.000000   1.000000         NaN         NaN
# 8      NXMUSDT      1.000000   1.000000         NaN         NaN
# 9     KP3RUSDT      1.000000   1.000000         NaN         NaN
# 10    HBTCUSDT      1.000000   1.000000         NaN         NaN
# 11    IOTXUSDT      0.999427   0.999427         NaN         NaN
# 12     FEIUSDT      0.999043   0.999043         NaN         NaN
# 13     BATUSDT      0.997057   0.997057         NaN         NaN
# 14    DESOUSDT      0.974442   0.974442         NaN         NaN
# 15     YFIUSDT      0.973453   0.973453         NaN         NaN
# 16     BTTUSDT      0.941917   0.941917         NaN         NaN
# 17    TIMEUSDT      0.940962   0.940962         NaN         NaN
# 18     ENJUSDT      0.934341   0.934341         NaN         NaN
# 19     OHMUSDT      0.927005   0.927005         NaN         NaN
# 20     QNTUSDT      0.917978   0.917978         NaN         NaN
# 21     LRCUSDT      0.906496   0.906496         NaN         NaN
# 22     XECUSDT      0.904131   0.904131         NaN         NaN
# 23     RPLUSDT      0.899544   0.899544         NaN         NaN
# 24     KSMUSDT      0.898010   0.898010  291.119048  145.559524
# 25     MKRUSDT      0.896312   0.896312         NaN         NaN
# 26     ONEUSDT      0.890557   0.890557         NaN         NaN
# 27     SNXUSDT      0.868942   0.868942         NaN         NaN
# 28    AAVEUSDT      0.851290   0.851290         NaN         NaN
# 29     ZRXUSDT      0.847496   0.847496         NaN         NaN
# 30    ANKRUSDT      0.816290   0.816290         NaN         NaN
# 31     KUBUSDT      0.806818   0.806818         NaN         NaN
# 32    FLEXUSDT      0.797439   0.797439         NaN         NaN
# 33   SUSHIUSDT      0.771157   0.771157    7.342952    3.671476
# 34      ARUSDT      0.759220   0.759220         NaN         NaN
# 35     JSTUSDT      0.737417   0.737417         NaN         NaN
# 36     SYNUSDT      0.703239   0.703239         NaN         NaN
# 37     SXPUSDT      0.681815   0.681815         NaN         NaN
# 38    COMPUSDT      0.658577   0.658577  225.900000  112.950000
# 39     UMAUSDT      0.615170   0.615170    9.924048    4.962024
# 40    RUNEUSDT      0.601510   0.601510    7.816952    3.908476
# 41     CHZUSDT      0.601207   0.601207         NaN         NaN
# 42     FXSUSDT      0.578809   0.578809         NaN         NaN
# 43     ZECUSDT      0.578695   0.578695         NaN         NaN
# 44     CHRUSDT      0.567369   0.567369         NaN         NaN
# 45    CELRUSDT      0.564545   0.564545    0.089037    0.044518
# 46   AUDIOUSDT      0.564255   0.564255    1.670143    0.835071
# 47    NEXOUSDT      0.560000   0.560000         NaN         NaN
# 48  TSHAREUSDT      0.558967   0.558967         NaN         NaN
# 49    ELONUSDT      0.553290   0.553290         NaN         NaN
# 50    KEEPUSDT      0.549716   0.549716         NaN         NaN
# 51    WAXPUSDT      0.519118   0.519118         NaN         NaN
# 52    HEROUSDT      0.515076   0.515076         NaN         NaN
# 53    EURTUSDT      0.514997   0.514997         NaN         NaN
# 54     CVXUSDT      0.514672   0.514672         NaN         NaN

# %%
easycaplist = easycap['Indicator']
easycaplist

for item in easycaplist :
    
    x=item.replace('USDT','')
    print('$'+x)
# Out:
# $LPT
# $RENBTC
# $UFO
# $PEOPLE
# $REN
# $OMG
# $BNT
# $MSOL
# $NXM
# $KP3R
# $HBTC
# $IOTX
# $FEI
# $BAT
# $DESO
# $YFI
# $BTT
# $TIME
# $ENJ
# $OHM
# $QNT
# $LRC
# $XEC
# $RPL
# $KSM
# $MKR
# $ONE
# $SNX
# $AAVE
# $ZRX
# $ANKR
# $KUB
# $FLEX
# $SUSHI
# $AR
# $JST
# $SYN
# $SXP
# $COMP
# $UMA
# $RUNE
# $CHZ
# $FXS
# $ZEC
# $CHR
# $CELR
# $AUDIO
# $NEXO
# $TSHARE
# $ELON
# $KEEP
# $WAXP
# $HERO
# $EURT
# $CVX

# %%
entries = pd.DataFrame(entrylist, columns =['Indicator', 'lowest_entry'],dtype = float) 
entries
entries.lowest_entry.astype(float)
indicator_list = entries['Indicator']
#indicator_list
#entries

# %%
## Entries for coins with good cap ratio
entries = pd.read_csv('entries.csv')
entries = pd.DataFrame(entries,columns=['Indicator','lowest_entry'])
entriescap =pd.merge(left=entries, right=capratio, left_on='Indicator', right_on='Indicator')

entriescap
# Out:
#     Indicator  lowest_entry  supply_ratio  cap_ratio
# 0    ANKRUSDT       0.07684      0.816290   0.816290
# 1    WAXPUSDT       0.31740      0.519118   0.519118
# 2      ARUSDT      30.00000      0.759220   0.759220
# 3     ZRXUSDT       0.60000      0.847496   0.847496
# 4     KSMUSDT     150.00000      0.898010   0.898010
# 5     LRCUSDT       0.70470      0.906496   0.906496
# 6     RENUSDT       0.30470      1.000000   1.000000
# 7   SUSHIUSDT       4.00000      0.771157   0.771157
# 8     OMGUSDT       4.50000      1.000000   1.000000
# 9     ONEUSDT       0.13171      0.890557   0.890557
# 10   RUNEUSDT       3.70900      0.601510   0.601510
# 11   CELRUSDT       0.05063      0.564545   0.564545
# 12  AUDIOUSDT       1.00000      0.564255   0.564255
