# %%
import numpy as np 
import pandas as pd 
from datetime import date
#Data Source (Pandas Data Reader)
from pandas_datareader import data
import requests 
import json
from dateutil.relativedelta import relativedelta


#Data Source(Pandas Data Reader)

# %%
## choose either white list or read from fix entries 

fixentries= pd.read_csv('fixentries.csv')
fixentries
whitelist = []
whitelist = fixentries['Indicator'].array
whitelist[0]
#final = pd.DataFrame(fixentries['Indicator']) 
#final.set_index('Indicator')
# Out:
# 'MIRUSDT'

# %%
#whitelist = 'GALA/USDT, ANT/USDT,IMX/USDT, MATIC/USDT, ZRX/USDT,  ALGO/USDT, BTC/USDT, ETH/USDT, AXS/USDT, SOL/USDT, MATIC/USDT, ADA/USDT, BNB/USDT, FIL/USDT, XRP/USDT, CVC/USDT, FTM/USDT, ICP/USDT, DOGE/USDT, XEC/USDT, IOTA/USDT, AVAX/USDT, DOT/USDT, LTC/USDT, EOS/USDT, IOST/USDT, STMX/USDT, FTT/USDT, TWT/USDT, ALICE/USDT, ATA/USDT, ETC/USDT, VET/USDT, SAND/USDT, LINK/USDT, THETA/USDT, SHIB/USDT, CHZ/USDT, LUNA/USDT, IOTX/USDT, TRX/USDT, TLM/USDT, BCH/USDT, REEF/USDT, CAKE/USDT, NEO/USDT, SLP/USDT, RVN/USDT, ATOM/USDT, SUSHI/USDT, ARDR/USDT, OMG/USDT, GRT/USDT, 1INCH/USDT, AAVE/USDT, C98/USDT, UNI/USDT, HBAR/USDT, CRV/USDT, DENT/USDT, MBOX/USDT, BTT/USDT, SRM/USDT, YFI/USDT, HOT/USDT, XLM/USDT, FIS/USDT, REQ/USDT, SXP/USDT, KSM/USDT, QNT/USDT, NEAR/USDT, COMP/USDT, QTUM/USDT, CHR/USDT, SC/USDT, XVS/USDT, ONT/USDT, COTI/USDT, NKN/USDT, RUNE/USDT, ANKR/USDT, MANA/USDT, CTXC/USDT, AR/USDT, RAY/USDT, BAKE/USDT, ARPA/USDT, XTZ/USDT, ZIL/USDT, ONG/USDT, ROSE/USDT, PNT/USDT, ALGO/USDT, MINA/USDT, WIN/USDT, AUDIO/USDT, STORJ/USDT, EPS/USDT, MDX/USDT, ZEC/USDT, ENJ/USDT, HIVE/USDT, TFUEL/USDT, WRX/USDT, SNX/USDT, SKL/USDT, LINA/USDT, DODO/USDT, UNFI/USDT, XEM/USDT, EGLD/USDT, ICX/USDT, WAVES/USDT, ONE/USDT, DASH/USDT, KAVA/USDT, SUPER/USDT, TKO/USDT, OGN/USDT, XMR/USDT, OCEAN/USDT, CELO/USDT, BAT/USDT, FUN/USDT, LRC/USDT, ALPHA/USDT, MASK/USDT, TRU/USDT, DNT/USDT, LIT/USDT, FET/USDT, GTC/USDT, CELR/USDT, DEXE/USDT, ZEN/USDT, WAXP/USDT, CTSI/USDT, HNT/USDT, YFII/USDT, BEL/USDT, ZRX/USDT, DEGO/USDT, RSR/USDT, COS/USDT, FLM/USDT, BAL/USDT, MFT/USDT, RLC/USDT, KNC/USDT, REN/USDT, INJ/USDT, FLOW/USDT, SFP/USDT, BAND/USDT, CTK/USDT, SUN/USDT, AKRO/USDT, XVG/USDT, NANO/USDT, STRAX/USDT, PUNDIX/USDT, TVK/USDT, MKR/USDT, CLV/USDT, TRB/USDT, ETHUP/USDT, KEEP/USDT, TCT/USDT, POND/USDT, LTO/USDT, ANT/USDT, TOMO/USDT, ACM/USDT, FIO/USDT, VITE/USDT, MBL/USDT, JST/USDT, MTL/USDT, UTK/USDT, BLZ/USDT, ORN/USDT, STPT/USDT, CFX/USDT, OM/USDT, PERP/USDT, MIR/USDT, STX/USDT, ERN/USDT, TUSD/USDT, PSG/USDT, NULS/USDT, OXT/USDT, REP/USDT, BNBUP/USDT, DATA/USDT, WAN/USDT, BURGER/USDT, RAMP/USDT, ATM/USDT, DGB/USDT, DIA/USDT, BEAM/USDT, UMA/USDT, ETHDOWN/USDT, CKB/USDT, TRIBE/USDT, FARM/USDT, BTCUP/USDT, BZRX/USDT, ALPACA/USDT, DOTUP/USDT, BTS/USDT, FOR/USDT, ADAUP/USDT, HARD/USDT, LSK/USDT, POLS/USDT, FORTH/USDT, TORN/USDT, VTHO/USDT, BTG/USDT, QUICK/USDT, FILUP/USDT, PAX/USDT, MITH/USDT, SUSHIUP/USDT, BTCDOWN/USDT, XRPDOWN/USDT, BNBDOWN/USDT, DUSK/USDT, XRPUP/USDT, WTC/USDT, DOCK/USDT, AUTO/USDT, BTCST/USDT, KLAY/USDT, WNXM/USDT, KEY/USDT, FILDOWN/USDT, NU/USDT, IRIS/USDT, KMD/USDT, TROY/USDT, WING/USDT, AION/USDT, PHA/USDT, SUSHIDOWN/USDT, EOSUP/USDT, LTCUP/USDT, GHST/USDT, PAXG/USDT, BNT/USDT, AVA/USDT, BADGER/USDT, PERL/USDT, COCOS/USDT, GXS/USDT, MDT/USDT, 1INCHUP/USDT, GTO/USDT, LINKUP/USDT, AAVEUP/USDT, FIRO/USDT, JUV/USDT, MLN/USDT, UNIUP/USDT, LPT/USDT, NMR/USDT, AAVEDOWN/USDT, 1INCHDOWN/USDT, ASR/USDT, OG/USDT, BAR/USDT, DREP/USDT, ADADOWN/USDT, BOND/USDT, DCR/USDT, DOTDOWN/USDT, GNO/USDT, NBS/USDT, SXPUP/USDT, EOSDOWN/USDT, YFIUP/USDT, RIF/USDT, LTCDOWN/USDT, XLMUP/USDT, YFIDOWN/USDT, LINKDOWN/USDT, TRXUP/USDT, BCHUP/USDT, XTZUP/USDT, SXPDOWN/USDT, UNIDOWN/USDT, XTZDOWN/USDT, BCHDOWN/USDT, TRXDOWN/USDT, XLMDOWN/USDT, SUSD/USDT'
#whitelist = 'LINK/USDT, DOT/USDT'
#whitelist =str(fixentries['Indicator'])

startdate = '2020-01-01'
enddate = '2022-02-22'
intervals = ['2h','4h','8h']
#intervals = ['8h']

# %%
def updown (number):
    if number > 0 :
        return "UP" 
    else :
        return "DOWN"


def FRSI(series, period=14):
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    return 100 - (100 / (1 + rs))


# calculating Stoch RSI (gives the same values as TradingView)
# https://www.tradingview.com/wiki/Stochastic_RSI_(STOCH_RSI) 
def STRSIA(series, period=14, smoothK=3, smoothD=3):
    # Calculate RSI 
    delta = series.diff().dropna()
    ups = delta * 0
    downs = ups.copy()
    ups[delta > 0] = delta[delta > 0]
    downs[delta < 0] = -delta[delta < 0]
    ups[ups.index[period-1]] = np.mean( ups[:period] ) #first value is sum of avg gains
    ups = ups.drop(ups.index[:(period-1)])
    downs[downs.index[period-1]] = np.mean( downs[:period] ) #first value is sum of avg losses
    downs = downs.drop(downs.index[:(period-1)])
    rs = ups.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() / \
         downs.ewm(com=period-1,min_periods=0,adjust=False,ignore_na=False).mean() 
    rsi = 100 - 100 / (1 + rs)

    # Calculate StochRSI 
    stochrsi  = (rsi - rsi.rolling(period).min()) / (rsi.rolling(period).max() - rsi.rolling(period).min())
    stochrsi_K = stochrsi.rolling(smoothK).mean()
    stochrsi_D = stochrsi_K.rolling(smoothD).mean()
    return stochrsi, stochrsi_K, stochrsi_D

# %%
#whitelist=whitelist.lstrip()
#array = whitelist.split(",")
array = whitelist
array
wl = []
bl = []
blacklist = ""
whitelist = ""
symbols =[]

for i in range(0 ,len(array)):
    if (array[i].find('DOWN') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])
    elif (array[i].find('UP') != -1):
        bl.append(str(array[i]).lstrip())
        #print ("Contains given substring ")
        blacklist += str(array[i])

    else:
        wl.append(str(array[i]).lstrip().replace("/",""))
        whitelist +=str(array[i]).lstrip()
        #print ("Doesn't contains given substring")
    

    
#symbols to be used to get the prices from binance url
symbols = np.array(wl)

#print(intervals)
## get the data 
import os

live = pd.to_datetime('today')
start = pd.to_datetime(startdate)
end = pd.to_datetime(enddate)

root_url = 'https://api.binance.com/api/v1/klines'
#symbol = 'STEEMETH'
#interval = '1d'
#url = root_url + '?symbol=' + symbol + '&interval=' + interval
#print(url)


directory = 'BN-main'
table = []
interval = ''
final = pd.DataFrame(fixentries['Indicator'])
final.set_index('Indicator')

for interval in intervals:
    

    for symbol in symbols:
            url = root_url + '?symbol=' + symbol + '&interval=' + interval
            data = json.loads(requests.get(url).text)
            dflive = pd.DataFrame(data ,columns =['open_time',
                  'o', 'h', 'l', 'c', 'v',
                  'close_time', 'qav', 'num_trades',
                  'taker_base_vol', 'taker_quote_vol', 'ignore'])
            dflive.open_time = pd.to_datetime(dflive['open_time'],unit='ms')
            dflive=dflive.loc[(dflive.open_time>start)]

            dflive = dflive.astype ({'o': float ,'h':float,'l':float ,'c':float ,'v':float})
            dflive['RSI'] = FRSI(dflive['c'])
            dflive['STRSI'] = STRSIA(dflive['c'])[0]
            dflive['STRSIK'] = STRSIA(dflive['c'])[1]
            dflive['STRSID'] = STRSIA(dflive['c'])[2]



            #print(dflive)


            lastrow = dflive.iloc[-1]
            beforelast = dflive.iloc[-2]
            now = float(lastrow.c)
            RSI = float(lastrow.RSI)
            RSIM = float(beforelast.RSI)
            STRSI = float(lastrow.STRSI)
            STRSIK = float(lastrow.STRSIK)
            STRSID = float(lastrow.STRSID)


            tuple =(symbol,RSI,RSIM,STRSI,STRSIK,STRSID)
            table.append(tuple)
            #print(table)
            del dflive
            #print("name is: ",array[0] ,alth,altl)


    table[0]
    AllTime = pd.DataFrame(table,columns=['Indicator','RSI','RSIM','STRSI','STRSIK','STRSID'])


    #AllTime.Current=AllTime.Current.astype(float)

    AllTime.dtypes


    #AllTime.sort_values(by='ATH',ascending=False)
    #AllTime.to_csv("alltimeHL.csv", mode="w")
    #data.sort_values("Name", axis = 0, ascending = True,inplace = True, na_position ='last')

    ## Display the Data 

    test=AllTime.rename(columns={'RSI':('RSI'+interval),'RSIM':('RSIM'+interval),'STRSI':('STRSI'+interval),'STRSIK':('STRSIK'+interval),'STRSID':('STRSID'+interval)})
    test.set_index(['Indicator'])
    final=final.merge(test,how='left',on=['Indicator'])
            

final
# Out:
#      Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSID2h      RSI4h  \
# 0      MIRUSDT  49.264259  51.562662  0.390894  0.365060  0.293902  49.264259
# 1      MIRUSDT  49.264259  51.562662  0.390894  0.365060  0.293902  49.264259
# 2      MIRUSDT  49.264259  51.562662  0.390894  0.365060  0.293902  49.264259
# 3      MIRUSDT  49.264259  51.562662  0.390894  0.365060  0.293902  52.498607
# 4      MIRUSDT  49.264259  51.562662  0.390894  0.365060  0.293902  52.498607
# ..         ...        ...        ...       ...       ...       ...        ...
# 139  SUSHIUSDT  56.162330  58.320256  0.338412  0.265889  0.188413  56.162330
# 140  SUSHIUSDT  56.162330  58.320256  0.338412  0.265889  0.188413  56.162330
# 141  SUSHIUSDT  56.162330  58.320256  0.338412  0.265889  0.188413  57.618084
# 142  SUSHIUSDT  56.162330  58.320256  0.338412  0.265889  0.188413  57.618084
# 143  SUSHIUSDT  56.162330  58.320256  0.338412  0.265889  0.188413  57.618084
#
#         RSIM4h   STRSI4h  STRSIK4h  STRSID4h      RSI8h     RSIM8h   STRSI8h  \
# 0    51.562662  0.390894  0.365060  0.293902  49.264259  51.562662  0.390894
# 1    51.562662  0.390894  0.365060  0.293902  52.498607  54.816128  0.074512
# 2    51.562662  0.390894  0.365060  0.293902  54.187651  54.691135  0.100045
# 3    54.816128  0.074512  0.291688  0.288852  49.264259  51.562662  0.390894
# 4    54.816128  0.074512  0.291688  0.288852  52.498607  54.816128  0.074512
# ..         ...       ...       ...       ...        ...        ...       ...
# 139  58.320256  0.338412  0.265889  0.188413  57.618084  59.681855  0.766025
# 140  58.320256  0.338412  0.265889  0.188413  52.344056  51.468791  0.897074
# 141  59.681855  0.766025  0.813351  0.796107  56.162330  58.320256  0.338412
# 142  59.681855  0.766025  0.813351  0.796107  57.618084  59.681855  0.766025
# 143  59.681855  0.766025  0.813351  0.796107  52.344056  51.468791  0.897074
#
#      STRSIK8h  STRSID8h
# 0    0.365060  0.293902
# 1    0.291688  0.288852
# 2    0.228804  0.373404
# 3    0.365060  0.293902
# 4    0.291688  0.288852
# ..        ...       ...
# 139  0.813351  0.796107
# 140  0.857551  0.898109
# 141  0.265889  0.188413
# 142  0.813351  0.796107
# 143  0.857551  0.898109
#
# [144 rows x 16 columns]

# %%
final=final.drop_duplicates(subset='Indicator',keep='last')
#final= final.drop(columns=['Current_x','Current_y'])
final
# Out:
#      Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSID2h      RSI4h  \
# 5      MIRUSDT  49.264259  51.562662  0.390894  0.365060  0.293902  52.498607
# 11    GLMRUSDT  53.810462  54.687750  0.441071  0.321494  0.316034  54.221452
# 17    CAKEUSDT  51.286167  52.315938  0.066988  0.062326  0.067578  51.895747
# 23     IMXUSDT  55.146997  56.259375  0.330756  0.253705  0.317088  53.498462
# 29      SCUSDT  61.052499  61.908726  0.259864  0.187923  0.184162  66.177464
# 35     CRVUSDT  66.090578  67.385927  0.485247  0.354943  0.356469  68.556463
# 41    MOVRUSDT  52.582247  52.992673  0.297776  0.205595  0.149444  51.633889
# 47     RAYUSDT  57.227805  57.982680  0.260732  0.183757  0.108881  58.525919
# 53   TFUELUSDT  61.011789  60.868690  0.275399  0.180402  0.176700  63.110658
# 59     HNTUSDT  50.946349  50.565747  0.217256  0.137788  0.132659  53.284971
# 65   AUDIOUSDT  59.050313  62.597960  0.271592  0.285502  0.195493  59.870452
# 71     SRMUSDT  57.335757  60.168960  0.239892  0.226940  0.195076  61.348700
# 77     WINUSDT  62.168590  65.731573  0.170003  0.271620  0.305085  62.089915
# 83    VTHOUSDT  57.439068  58.304874  0.154399  0.117656  0.071908  64.305791
# 89     KSMUSDT  62.624057  67.249613  0.000000  0.080883  0.229783  64.748268
# 95    ALGOUSDT  50.529386  53.542357  0.093915  0.125234  0.146512  53.233497
# 101    XLMUSDT  55.149837  59.450546  0.067451  0.140425  0.165490  57.943446
# 107  1INCHUSDT  58.008267  62.194603  0.100880  0.176160  0.183535  60.060799
# 113    OMGUSDT  68.662630  68.151989  0.742242  0.481218  0.297078  68.225436
# 119    ZRXUSDT  53.458256  55.756136  0.138229  0.140975  0.143589  57.853977
# 125    GRTUSDT  58.598125  60.745410  0.297335  0.242733  0.169519  59.634986
# 131    ZILUSDT  57.133109  59.266902  0.111320  0.108878  0.108998  60.888040
# 137   WAXPUSDT  57.984382  59.934513  0.037324  0.069170  0.211099  61.910320
# 143  SUSHIUSDT  56.162330  58.320256  0.338412  0.265889  0.188413  57.618084
#
#         RSIM4h   STRSI4h  STRSIK4h  STRSID4h      RSI8h     RSIM8h   STRSI8h  \
# 5    54.816128  0.074512  0.291688  0.288852  54.187651  54.691135  0.100045
# 11   54.842131  0.678287  0.753580  0.771607  45.536756  46.854704  0.856316
# 17   52.623704  0.469833  0.572534  0.617380  47.662483  48.969165  0.650405
# 23   54.369261  0.834350  0.909188  0.895618  45.726359  47.085773  0.909775
# 29   66.999572  0.956612  0.985537  0.971108  59.350887  59.547111  0.986431
# 35   69.793835  0.962113  0.987371  0.995790  57.442108  55.677681  1.000000
# 41   51.960992  0.699413  0.696050  0.681077  45.983257  45.608548  0.759988
# 47   59.187941  0.739276  0.730505  0.759836  50.636382  48.892292  0.862019
# 53   62.697916  0.862431  0.867470  0.847790  56.109154  56.269126  0.973859
# 59   52.969433  0.450462  0.489146  0.519663  52.350967  54.116303  0.526964
# 65   62.978103  0.875666  0.921396  0.929714  52.727816  50.101754  1.000000
# 71   64.326017  0.841097  0.929133  0.921541  56.166147  56.258418  0.988937
# 77   64.726857  0.901375  0.967125  0.968437  55.184752  54.915928  1.000000
# 83   65.376144  0.784236  0.826116  0.859069  56.942223  57.129134  0.873113
# 89   68.584269  0.818581  0.895432  0.939752  56.722237  57.788008  0.950374
# 95   56.255059  0.515910  0.660483  0.705867  51.198567  53.188224  0.642908
# 101  61.814736  0.798123  0.923931  0.952984  53.898529  56.104911  0.846327
# 107  63.976298  0.814736  0.938245  0.955359  55.391692  55.735296  0.975567
# 113  67.835648  1.000000  1.000000  0.990004  61.629624  57.556349  1.000000
# 119  60.366063  0.668696  0.798162  0.843925  53.424702  55.412851  0.794579
# 125  61.488188  0.907400  0.934416  0.899178  52.429867  51.853647  0.996809
# 131  62.861512  0.699368  0.754624  0.738814  55.534647  56.562983  0.803896
# 137  63.521589  0.704590  0.828088  0.888790  57.845776  61.218055  0.786468
# 143  59.681855  0.766025  0.813351  0.796107  52.344056  51.468791  0.897074
#
#      STRSIK8h  STRSID8h
# 5    0.228804  0.373404
# 11   0.906629  0.922006
# 17   0.716172  0.824909
# 23   0.908802  0.928852
# 29   0.986719  0.985928
# 35   1.000000  1.000000
# 41   0.752634  0.835772
# 47   0.862032  0.916576
# 53   0.964701  0.945381
# 59   0.631601  0.729770
# 65   0.955003  0.962503
# 71   0.965192  0.956518
# 77   0.997363  0.997363
# 83   0.919134  0.960188
# 89   0.983458  0.994486
# 95   0.780472  0.854854
# 101  0.947241  0.972896
# 107  0.985578  0.989740
# 113  1.000000  0.999513
# 119  0.888616  0.939706
# 125  0.948721  0.950635
# 131  0.820285  0.879089
# 137  0.907330  0.954781
# 143  0.857551  0.898109

# %%
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1)]
#drop = AllTime.loc[(AllTime['RSI'] < 30)& (AllTime['STRSI'] < 0.1) & (AllTime['RSI'] > AllTime['RSIM'])]
#drop = final.loc[ (((final['RSI8h'] < final['RSIM8h']) | (final['STRSIK4h'] <= final['STRSID4h'])))]
#drop = final.loc[(final['RSI2h'] > final['RSIM2h'])]
#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK2h'] < final['STRSID2h']))]


# 8 hours doing down

drop = final.loc[((final['RSI8h'] < final['RSIM8h']) & (final['STRSIK8h'] < final['STRSID8h']))]



#4 
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']))]

#4 and 8 going down RSI down

#drop = final.loc[((final['RSI4h'] > final['RSIM4h']) & (final['STRSIK4h'] > final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']))]
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['STRSIK8h'] < final['STRSID8h']) & (final['RSI8h'] < final['RSIM8h']) )]
#drop = final.loc[((final['RSI4h'] < final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['RSI8h'] < final['RSIM8h']) )]


# 4 and 8 stochastic down RSI up 
#drop = final.loc[((final['RSI4h'] > final['RSIM4h']) & (final['RSI8h'] > final['RSIM8h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['STRSIK8h'] > final['STRSID8h']) )]

#drop = final.loc[((final['RSI4h'] > final['RSIM4h']) & (final['STRSIK4h'] < final['STRSID4h']) & (final['RSI8h'] < final['RSIM8h']) )]



#drop = final.loc[((final['RSI2h'] < final['RSIM2h']) & (final['STRSIK4h'] > 0.9))]




#drop = final.loc[((final['STRSI12h'] > 0.7))]

#drop = final.loc[ (final['RSI1h'] < final['RSIM1h'])]

#drop = AllTime.loc[((AllTime['RSI'] > AllTime['RSIM']) | (AllTime['STRSIK'] >= AllTime['STRSID']))]

#drop = AllTime.loc[ (AllTime['STRSI'] < 0.9) & (AllTime['STRSIK'] > AllTime['STRSID'])]



#drop = AllTime.loc[(AllTime['MONTH'] < 70)]
#drop = AllTime.loc[(AllTime['MONTH'] < 80)&(AllTime['2MONTH'] < 70)&(AllTime['ALLTIME'] < 40)]
#drop = AllTime.loc[(AllTime['MONTH'] <70)&(AllTime['2MONTH'] > (AllTime['3MONTH']))]

#drop = drop.sort_values(by=['RSI1h'],ascending=False,inplace = True)
#drop = drop.loc[(drop['ALLTIME'] < drop['3MONTH'])]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','Current']]
#display = drop[['Indicator','RSI','RSIM','STRSIK','STRSID','STRSI']]

drop

print("Low  RSI")
print(drop.iloc[0:60,0:14])
print(drop.iloc[60:110,])
print(drop.iloc[110:160,])
#del drop
# Out:
# Low  RSI
#      Indicator      RSI2h     RSIM2h   STRSI2h  STRSIK2h  STRSID2h      RSI4h  \
# 5      MIRUSDT  49.264259  51.562662  0.390894  0.365060  0.293902  52.498607
# 11    GLMRUSDT  53.810462  54.687750  0.441071  0.321494  0.316034  54.221452
# 17    CAKEUSDT  51.286167  52.315938  0.066988  0.062326  0.067578  51.895747
# 23     IMXUSDT  55.146997  56.259375  0.330756  0.253705  0.317088  53.498462
# 59     HNTUSDT  50.946349  50.565747  0.217256  0.137788  0.132659  53.284971
# 83    VTHOUSDT  57.439068  58.304874  0.154399  0.117656  0.071908  64.305791
# 89     KSMUSDT  62.624057  67.249613  0.000000  0.080883  0.229783  64.748268
# 95    ALGOUSDT  50.529386  53.542357  0.093915  0.125234  0.146512  53.233497
# 101    XLMUSDT  55.149837  59.450546  0.067451  0.140425  0.165490  57.943446
# 107  1INCHUSDT  58.008267  62.194603  0.100880  0.176160  0.183535  60.060799
# 119    ZRXUSDT  53.458256  55.756136  0.138229  0.140975  0.143589  57.853977
# 131    ZILUSDT  57.133109  59.266902  0.111320  0.108878  0.108998  60.888040
# 137   WAXPUSDT  57.984382  59.934513  0.037324  0.069170  0.211099  61.910320
#
#         RSIM4h   STRSI4h  STRSIK4h  STRSID4h      RSI8h     RSIM8h   STRSI8h
# 5    54.816128  0.074512  0.291688  0.288852  54.187651  54.691135  0.100045
# 11   54.842131  0.678287  0.753580  0.771607  45.536756  46.854704  0.856316
# 17   52.623704  0.469833  0.572534  0.617380  47.662483  48.969165  0.650405
# 23   54.369261  0.834350  0.909188  0.895618  45.726359  47.085773  0.909775
# 59   52.969433  0.450462  0.489146  0.519663  52.350967  54.116303  0.526964
# 83   65.376144  0.784236  0.826116  0.859069  56.942223  57.129134  0.873113
# 89   68.584269  0.818581  0.895432  0.939752  56.722237  57.788008  0.950374
# 95   56.255059  0.515910  0.660483  0.705867  51.198567  53.188224  0.642908
# 101  61.814736  0.798123  0.923931  0.952984  53.898529  56.104911  0.846327
# 107  63.976298  0.814736  0.938245  0.955359  55.391692  55.735296  0.975567
# 119  60.366063  0.668696  0.798162  0.843925  53.424702  55.412851  0.794579
# 131  62.861512  0.699368  0.754624  0.738814  55.534647  56.562983  0.803896
# 137  63.521589  0.704590  0.828088  0.888790  57.845776  61.218055  0.786468
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSID2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSID4h, RSI8h, RSIM8h, STRSI8h, STRSIK8h, STRSID8h]
# Index: []
# Empty DataFrame
# Columns: [Indicator, RSI2h, RSIM2h, STRSI2h, STRSIK2h, STRSID2h, RSI4h, RSIM4h, STRSI4h, STRSIK4h, STRSID4h, RSI8h, RSIM8h, STRSI8h, STRSIK8h, STRSID8h]
# Index: []

# %%
def updown (number):
    if number > 0 :
        return "UP" 
    else :
        return "DOWN"

updown8 = final.loc[:]
updown8['2RSI'] = ((final['RSI2h'] - final['RSIM2h'])) 
updown8['2ST'] = ((final['STRSIK2h'] - final['STRSID2h']))
updown8['4RSI'] = ((final['RSI4h'] - final['RSIM4h'])) 
updown8['4ST'] = ((final['STRSIK4h'] - final['STRSID4h']))
updown8['8RSI'] = ((final['RSI8h'] - final['RSIM8h'])) 
updown8['8ST'] = ((final['STRSIK8h'] - final['STRSID8h']))
#updown8['2RSI'] = "UP" if updown8['2RSI'] > 0 else "down"
updown8['2RSI']=updown8['2RSI'].apply(updown)
updown8['4RSI']= updown8['4RSI'].apply(updown)
updown8['8RSI']= updown8['8RSI'].apply(updown)
updown8['2ST']=updown8['2ST'].apply(updown)
updown8['4ST']=updown8['4ST'].apply(updown)
updown8['8ST']=updown8['8ST'].apply(updown)





updown8 = updown8[['Indicator','2RSI','4RSI','8RSI','2ST','4ST','8ST']]
updown8.to_csv("updown8.csv")
updown8
# Out:
#      Indicator  2RSI  4RSI  8RSI   2ST   4ST   8ST
# 5      MIRUSDT  DOWN  DOWN  DOWN    UP    UP  DOWN
# 11    GLMRUSDT  DOWN  DOWN  DOWN    UP  DOWN  DOWN
# 17    CAKEUSDT  DOWN  DOWN  DOWN  DOWN  DOWN  DOWN
# 23     IMXUSDT  DOWN  DOWN  DOWN  DOWN    UP  DOWN
# 29      SCUSDT  DOWN  DOWN  DOWN    UP    UP    UP
# 35     CRVUSDT  DOWN  DOWN    UP  DOWN  DOWN  DOWN
# 41    MOVRUSDT  DOWN  DOWN    UP    UP    UP  DOWN
# 47     RAYUSDT  DOWN  DOWN    UP    UP  DOWN  DOWN
# 53   TFUELUSDT    UP    UP  DOWN    UP    UP    UP
# 59     HNTUSDT    UP    UP  DOWN    UP  DOWN  DOWN
# 65   AUDIOUSDT  DOWN  DOWN    UP    UP  DOWN  DOWN
# 71     SRMUSDT  DOWN  DOWN  DOWN    UP    UP    UP
# 77     WINUSDT  DOWN  DOWN    UP  DOWN  DOWN  DOWN
# 83    VTHOUSDT  DOWN  DOWN  DOWN    UP  DOWN  DOWN
# 89     KSMUSDT  DOWN  DOWN  DOWN  DOWN  DOWN  DOWN
# 95    ALGOUSDT  DOWN  DOWN  DOWN  DOWN  DOWN  DOWN
# 101    XLMUSDT  DOWN  DOWN  DOWN  DOWN  DOWN  DOWN
# 107  1INCHUSDT  DOWN  DOWN  DOWN  DOWN  DOWN  DOWN
# 113    OMGUSDT    UP    UP    UP    UP    UP    UP
# 119    ZRXUSDT  DOWN  DOWN  DOWN  DOWN  DOWN  DOWN
# 125    GRTUSDT  DOWN  DOWN    UP    UP    UP  DOWN
# 131    ZILUSDT  DOWN  DOWN  DOWN  DOWN    UP  DOWN
# 137   WAXPUSDT  DOWN  DOWN  DOWN  DOWN  DOWN  DOWN
# 143  SUSHIUSDT  DOWN  DOWN    UP    UP    UP  DOWN

# %%
#save = drop[['Indicator','RSI','STRSI']]
#save = save.rename(columns={'STRSI': 'STRSI1','RSI':'RSI1'})
#save
#save.to_csv("strsi1KD.csv")
RSITABLE = drop[['Indicator', 'RSI2h', 'RSIM2h','RSI4h', 'RSIM4h','RSI8h', 'RSIM8h']]
sort1 = RSITABLE.sort_values(by=['RSI2h'],ascending=True,inplace = True)


RSITABLE
# Out:
# /Users/hjabbour/opt/anaconda3/envs/cryptodev/lib/python3.8/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      Indicator      RSI2h     RSIM2h      RSI4h     RSIM4h      RSI8h  \
# 5      MIRUSDT  49.264259  51.562662  52.498607  54.816128  54.187651
# 95    ALGOUSDT  50.529386  53.542357  53.233497  56.255059  51.198567
# 59     HNTUSDT  50.946349  50.565747  53.284971  52.969433  52.350967
# 17    CAKEUSDT  51.286167  52.315938  51.895747  52.623704  47.662483
# 119    ZRXUSDT  53.458256  55.756136  57.853977  60.366063  53.424702
# 11    GLMRUSDT  53.810462  54.687750  54.221452  54.842131  45.536756
# 23     IMXUSDT  55.146997  56.259375  53.498462  54.369261  45.726359
# 101    XLMUSDT  55.149837  59.450546  57.943446  61.814736  53.898529
# 131    ZILUSDT  57.133109  59.266902  60.888040  62.861512  55.534647
# 83    VTHOUSDT  57.439068  58.304874  64.305791  65.376144  56.942223
# 137   WAXPUSDT  57.984382  59.934513  61.910320  63.521589  57.845776
# 107  1INCHUSDT  58.008267  62.194603  60.060799  63.976298  55.391692
# 89     KSMUSDT  62.624057  67.249613  64.748268  68.584269  56.722237
#
#         RSIM8h
# 5    54.691135
# 95   53.188224
# 59   54.116303
# 17   48.969165
# 119  55.412851
# 11   46.854704
# 23   47.085773
# 101  56.104911
# 131  56.562983
# 83   57.129134
# 137  61.218055
# 107  55.735296
# 89   57.788008

# %%
STCHTABLE = drop[['Indicator','STRSIK2h', 'STRSID2h','STRSIK4h', 'STRSID4h','STRSIK8h', 'STRSID8h']]
STCHTABLE
# Out:
#      Indicator  STRSIK2h  STRSID2h  STRSIK4h  STRSID4h  STRSIK8h  STRSID8h
# 5      MIRUSDT  0.365060  0.293902  0.291688  0.288852  0.228804  0.373404
# 11    GLMRUSDT  0.321494  0.316034  0.753580  0.771607  0.906629  0.922006
# 17    CAKEUSDT  0.062326  0.067578  0.572534  0.617380  0.716172  0.824909
# 23     IMXUSDT  0.253705  0.317088  0.909188  0.895618  0.908802  0.928852
# 59     HNTUSDT  0.137788  0.132659  0.489146  0.519663  0.631601  0.729770
# 83    VTHOUSDT  0.117656  0.071908  0.826116  0.859069  0.919134  0.960188
# 89     KSMUSDT  0.080883  0.229783  0.895432  0.939752  0.983458  0.994486
# 95    ALGOUSDT  0.125234  0.146512  0.660483  0.705867  0.780472  0.854854
# 101    XLMUSDT  0.140425  0.165490  0.923931  0.952984  0.947241  0.972896
# 107  1INCHUSDT  0.176160  0.183535  0.938245  0.955359  0.985578  0.989740
# 119    ZRXUSDT  0.140975  0.143589  0.798162  0.843925  0.888616  0.939706
# 131    ZILUSDT  0.108878  0.108998  0.754624  0.738814  0.820285  0.879089
# 137   WAXPUSDT  0.069170  0.211099  0.828088  0.888790  0.907330  0.954781

# %%
#save
